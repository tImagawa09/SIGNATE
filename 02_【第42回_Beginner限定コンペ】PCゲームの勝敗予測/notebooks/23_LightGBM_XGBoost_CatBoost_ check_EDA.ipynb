# %% [markdown]
# # Baseline

# %% [markdown]
# FEなし =>
#
# **LightGBM**<br>
# LightGBM Average accuracy across all folds ===> 0.7793749999999999<br>
# LightGBM Average conf-matrix across all folds  => [[631.8 181.4] [171.6 615.2]]<br>
#
# **XGboost**<br>
# XGB Average accuracy across all folds =======> 0.7762500000000001<br>
# XGB Average conf-matrix across all folds =====>  [[663.8 149.4] [208.6 578.2]]<br>
#
# **CatBoost**<br>
# CatBoost Average accuracy across all folds ======> 0.7747499999999998<br>
# CatBoost Average conf-matrix across all folds ====> [[637.8 175.4] [185.  601.8]]<br>

# %% [markdown]
# # Library

# %%
import pandas as pd
import numpy as np

import optuna
import xgboost as xgb
import lightgbm as lgb
import catboost as cb

from datetime import datetime
from sklearn.model_selection import train_test_split, KFold
from sklearn.metrics import accuracy_score, confusion_matrix, roc_curve, auc
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# # Data Loading

# %%
train = pd.read_csv('../data/train.csv')
test = pd.read_csv('../data/test.csv')

# %% [markdown]
# # Add New Feature

# %%
# 基準
# lgb = 0.7793749999999999
# xgb = 0.7762500000000001
# Cat = 0.7747499999999998

# %%
def add_features(df):                                                                               # lgb=0.7793, xgb=0.7762, cb=0.7747
    # df['assistRate'] = df['blueAssists'] / (df['blueKills'] + 1)                                  # lgb=0.7825, xgb=0.7713, cb=0.7832
    # df['blueHerald'] = (df['blueEliteMonsters'] - df['blueDragons']).clip(lower=0)                # lgb=0.7843, xgb=0.7746, cb=0.7745
    # df['eliteMonsterDragonRatio'] = df['blueEliteMonsters'] / (df['blueDragons'] + 1)             # lgb=0.7857, xgb=0.7782, cb=0.7824
    df['logTotalGold'] = np.log1p(df['blueTotalGold'])                                            # lgb=0.7964, xgb=0.7826, cb=0.7827
    # df['logTotalExperience'] = np.log1p(df['blueTotalExperience'])                                # lgb=0.7876, xgb=0.7722, cb=0.7777
    df['firstBloodKillRatio'] = df['blueFirstBlood'] * df['blueKills']                            # lgb=0.7920, xgb=0.7751, cb=0.7893
    # df['totalCombatPoints'] = df['blueKills'] + df['blueDeaths'] + df['blueAssists']              # lgb=0.7869, xgb=0.7360, cb=0.7870

    total_combat_actions = df['blueKills'] + df['blueDeaths'] + df['blueAssists'] 
    df['killRatio'] = df['blueKills'] / total_combat_actions                                      # lgb=0.7913, xgb=0.7747, cb=0.7811
    # df['deathRatio'] = df['blueDeaths'] / total_combat_actions                                    # lgb=0.7864, xgb=0.7848, cb=0.7860
    # df['assistRatio'] = df['blueAssists'] / total_combat_actions                                  # lgb=0.7863, xgb=0.7746, cb=0.7815

    # df['teamStrength'] = df['blueKills'] + df['blueAssists'] + df['blueEliteMonsters']            # lgb=0.7782, xgb=0.7246, cb=0.7869
    # df['dragonKillImpact'] = df['blueDragons'] / (df['blueKills'] + 1)                            # lgb=0.7870, xgb=0.7694, cb=0.7857
    df['eliteMonsterUtilization'] = df['blueEliteMonsters']\
    / (df['blueKills'] + df['blueAssists'] + 1)                                                   # lgb=0.7900, xgb=0.7746, cb=0.7885
    df['goldExperienceRatio'] = df['blueTotalGold'] / (df['blueTotalExperience'] + 1)             # lgb=0.7911, xgb=0.7324, cb=0.7886
    # df['teamEfficiency'] = \
        # (df['blueKills'] + df['blueAssists'] + df['blueEliteMonsters']) / (df['blueDeaths'] + 1)  # lgb=0.7900, xgb=0.7762, cb=0.7840
    # df['killToMonsterRatio'] = df['blueKills'] / (df['blueEliteMonsters'] + 1)                    # lgb=0.7859, xgb=0.7758, cb=0.7800
    df['avgGoldPerKill'] = df['blueTotalGold'] / (df['blueKills'] + 1)                            # lgb=0.7933, xgb=0.7714, cb=0.7831
    # df['expToKillRatio'] = df['blueTotalExperience'] / (df['blueKills'] + 1)                      # lgb=0.7875, xgb=0.7781, cb=0.7820
    # df['killsMinusDeaths'] = df['blueKills'] - df['blueDeaths']                                   # lgb=0.7791, xgb=0.7879, cb=0.7884
    # df['killDeathRatio'] = df['blueKills'] / (df['blueKills'] + df['blueDeaths'])                 # lgb=0.7879, xgb=0.7752, cb=0.7863
    # df['avgExperiencePerKill'] = df['blueTotalExperience'] / (df['blueKills'] + 1)                # lgb=0.7886, xgb=0.7191, cb=0.7821
    # df['killDeathDiff'] = (df['blueKills'] - df['blueDeaths']).clip(lower=0)                      # lgb=0.7895, xgb=0.7664, cb=0.7883
    # df['eliteMonsterHeraldRatio'] = df['blueEliteMonsters'] / (df['blueHerald'] + 1)              # lgb=0.7885, xgb=0.7553, cb=0.7829
    # df['goldXexperience'] = np.log1p(df['blueTotalGold'] * df['blueTotalExperience'])             # lgb=0.7828, xgb=0.7730, cb=0.7765
    # df['goldPerKill'] = df['blueTotalGold'] / (df['blueKills'] + 1)                               # lgb=0.7805, xgb=0.7525, cb=0.7742
    # df['experiencePerKill'] = df['blueTotalExperience'] / (df['blueKills'] + 1)                   # lgb=0.7809, xgb=0.7795, cb=0.7833
    # df['eliteMonstersPerGold'] = df['blueEliteMonsters'] / df['blueTotalGold']                  # lgb=0., xgb=0., cb=0.
    # df['eliteMonstersPerExperience'] = df['blueEliteMonsters'] / df['blueTotalExperience']      # lgb=0., xgb=0., cb=0.

    
    return df

# %% [markdown]
# - apply

# %%
train = add_features(train)
test = add_features(test)

# %% [markdown]
# # Data

# %%
# データの準備
X = train.drop(['blueWins', 'gameId'], axis=1)
y = train['blueWins']
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2, random_state=0)

test_drop_gameId = test.drop('gameId', axis=1)

# test_drop_gameId_temp = test.drop('gameId', axis=1)

# # 特徴量の標準化
# scaler = StandardScaler()
# X_train = scaler.fit_transform(X_train)
# X_val = scaler.transform(X_val)  # 検証データも同じスケーラーを使用して標準化

# # テストデータも同じスケーラーを使用して標準化
# test_drop_gameId_scaled = scaler.transform(test_drop_gameId_temp)

# # NumPy配列からPandasデータフレームに変換
# X_train = pd.DataFrame(X_train, columns=X.columns)
# X_val = pd.DataFrame(X_val, columns=X.columns)
# test_drop_gameId = pd.DataFrame(test_drop_gameId_scaled, columns=test_drop_gameId_temp.columns)

# %% [markdown]
# # Model

# %% [markdown]
# - variable

# %%
n_splits = 5
kf = KFold(n_splits=n_splits, shuffle=True)

lgb_threshold = 0.5
xgb_threshold = 0.5
cb_threshold = 0.5

# 各フォールドでのスコアを保存するリスト
lgb_fold_scores = []
xgb_fold_scores = []
cb_fold_scores = []

# 各フォール度での混同行列を保存するリスト
lgb_conf_scores = []
xgb_conf_scores = []
cb_conf_scores = []

# testを保存するリスト
lgb_test_predictions = []
xgb_test_predictions = []
cb_test_predictions = []

# %% [markdown]
# ## LightGBM

# %%
for train_index, val_index in kf.split(X):
    X_train_fold, X_val_fold = X.iloc[train_index], X.iloc[val_index]
    y_train_fold, y_val_fold = y[train_index], y[val_index]

    # LightGBMではDMatrixの代わりに普通のデータフレームを使用します
    train_data = lgb.Dataset(X_train_fold, label=y_train_fold)
    val_data = lgb.Dataset(X_val_fold, label=y_val_fold, reference=train_data)

    # Optunaでのハイパーパラメータチューニング
    def objective(trial):
        param = {
            'objective': 'binary',
            'metric': 'binary_logloss',
            'verbosity': -1,
            'boosting_type': 'gbdt',
            'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
            'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
            'num_leaves': trial.suggest_int('num_leaves', 2, 256),
            'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
            'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
            'bagging_freq': trial.suggest_int('bagging_freq', 1, 7),
            'min_child_samples': trial.suggest_int('min_child_samples', 5, 100),
            'feature_pre_filter': False,  # 特徴量の事前フィルタリングを無効化
            'min_data_in_leaf': trial.suggest_int('min_data_in_leaf', 20, 100),  # Optunaでこの値を調整する
        }

        callbacks = lgb.early_stopping(stopping_rounds=100, verbose=False)
        gbm = lgb.train(param, train_data, valid_sets=[val_data], num_boost_round=1000, callbacks=[callbacks])
        preds = gbm.predict(X_val_fold, num_iteration=gbm.best_iteration)
        pred_labels = np.rint(preds)
        accuracy = accuracy_score(y_val_fold, pred_labels)
        return accuracy

    lgb_study = optuna.create_study(direction='maximize')
    lgb_study.optimize(objective, n_trials=100)

    # 各フォールドの最適パラメータでモデルを再学習
    lgb_best_params = lgb_study.best_params
    lgb_best_params['objective'] = 'binary'
    lgb_best_params['metric'] = 'binary_logloss'
    lgb_best_params['verbosity'] = -1

    lgb_final = lgb.train(lgb_best_params, train_data, num_boost_round=lgb_study.best_trial.number)

    # 各フォールドのモデル性能を評価
    lgb_y_val_pred = lgb_final.predict(X_val_fold, num_iteration=lgb_final.best_iteration)
    lgb_y_val_pred_int = np.rint(lgb_y_val_pred)
    lgb_fold_accuracy = accuracy_score(y_val_fold, lgb_y_val_pred_int)
    lgb_fold_scores.append(lgb_fold_accuracy)

    # 混同行列
    lgb_conf_matrix = confusion_matrix(y_val_fold, lgb_y_val_pred_int)
    lgb_conf_scores.append(lgb_conf_matrix)


    # テストデータセットでの予測
    lgb_y_test_pred_fold = lgb_final.predict(test_drop_gameId, num_iteration=lgb_final.best_iteration)
    lgb_test_predictions.append(lgb_y_test_pred_fold)
# Out:
# [I 2024-01-31 09:19:55,132] A new study created in memory with name: no-name-94ec9453-ebde-4df5-b0f1-982fcf692671
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-31 09:19:55,511] Trial 0 finished with value: 0.77875 and parameters: {'lambda_l1': 3.7378042094743015e-05, 'lambda_l2': 0.1594486270975372, 'num_leaves': 200, 'feature_fraction': 0.40513091511222327, 'bagging_fraction': 0.8841223558409659, 'bagging_freq': 1, 'min_child_samples': 90, 'min_data_in_leaf': 38}. Best is trial 0 with value: 0.77875.
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-31 09:19:55,698] Trial 1 finished with value: 0.780625 and parameters: {'lambda_l1': 6.726373024310391e-07, 'lambda_l2': 0.16765882420736156, 'num_leaves': 187, 'feature_fraction': 0.44652861869013816, 'bagging_fraction': 0.8445710761816925, 'bagging_freq': 7, 'min_child_samples': 57, 'min_data_in_leaf': 69}. Best is trial 1 with value: 0.780625.
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-31 09:19:55,849] Trial 2 finished with value: 0.779375 and parameters: {'lambda_l1': 0.00023351740670711745, 'lambda_l2': 0.03469528247881096, 'num_leaves': 192, 'feature_fraction': 0.8412948957870308, 'bagging_fraction': 0.4738871301358118, 'bagging_freq': 3, 'min_child_samples': 100, 'min_data_in_leaf': 39}. Best is trial 1 with value: 0.780625.
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-31 09:19:55,974] Trial 3 finished with value: 0.788125 and parameters: {'lambda_l1': 6.720662940321858e-07, 'lambda_l2': 1.2200972230795433e-06, 'num_leaves': 247, 'feature_fraction': 0.5744197612936439, 'bagging_fraction': 0.5996513052449034, 'bagging_freq': 1, 'min_child_samples': 92, 'min_data_in_leaf': 97}. Best is trial 3 with value: 0.788125.
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-31 09:19:56,091] Trial 4 finished with value: 0.77875 and parameters: {'lambda_l1': 4.007263947921295, 'lambda_l2': 4.69662722745959, 'num_leaves': 150, 'feature_fraction': 0.662396809669513, 'bagging_fraction': 0.5674428578262927, 'bagging_freq': 6, 'min_child_samples': 86, 'min_data_in_leaf': 66}. Best is trial 3 with value: 0.788125.
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-31 09:19:56,365] Trial 5 finished with value: 0.778125 and parameters: {'lambda_l1': 0.0029409089188578135, 'lambda_l2': 8.776142515234833e-05, 'num_leaves': 186, 'feature_fraction': 0.4732690069051127, 'bagging_fraction': 0.8694816238372879, 'bagging_freq': 4, 'min_child_samples': 96, 'min_data_in_leaf': 24}. Best is trial 3 with value: 0.788125.
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-31 09:19:56,538] Trial 6 finished with value: 0.785 and parameters: {'lambda_l1': 0.0003739963244884606, 'lambda_l2': 8.256899557912524, 'num_leaves': 90, 'feature_fraction': 0.7584843530424094, 'bagging_fraction': 0.9672590053648983, 'bagging_freq': 5, 'min_child_samples': 63, 'min_data_in_leaf': 48}. Best is trial 3 with value: 0.788125.
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-31 09:19:56,696] Trial 7 finished with value: 0.785625 and parameters: {'lambda_l1': 1.548321567528519e-07, 'lambda_l2': 4.058697429080888, 'num_leaves': 228, 'feature_fraction': 0.8800727967212939, 'bagging_fraction': 0.44381733595467243, 'bagging_freq': 2, 'min_child_samples': 75, 'min_data_in_leaf': 35}. Best is trial 3 with value: 0.788125.
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-31 09:19:56,874] Trial 8 finished with value: 0.781875 and parameters: {'lambda_l1': 0.0004948520662875261, 'lambda_l2': 1.3463142621015906e-07, 'num_leaves': 106, 'feature_fraction': 0.5782209457365178, 'bagging_fraction': 0.6060167283206841, 'bagging_freq': 2, 'min_child_samples': 5, 'min_data_in_leaf': 74}. Best is trial 3 with value: 0.788125.
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-31 09:19:56,960] Trial 9 finished with value: 0.781875 and parameters: {'lambda_l1': 9.098039985977928e-05, 'lambda_l2': 0.003141839041731867, 'num_leaves': 34, 'feature_fraction': 0.9382677580448558, 'bagging_fraction': 0.40194499413132495, 'bagging_freq': 3, 'min_child_samples': 86, 'min_data_in_leaf': 63}. Best is trial 3 with value: 0.788125.
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-31 09:19:57,124] Trial 10 finished with value: 0.781875 and parameters: {'lambda_l1': 2.3657298177235113e-08, 'lambda_l2': 6.233762909549918e-08, 'num_leaves': 246, 'feature_fraction': 0.6025867440126026, 'bagging_fraction': 0.7019132978473188, 'bagging_freq': 1, 'min_child_samples': 38, 'min_data_in_leaf': 96}. Best is trial 3 with value: 0.788125.
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-31 09:19:57,271] Trial 11 finished with value: 0.7775 and parameters: {'lambda_l1': 1.0483060181588971e-08, 'lambda_l2': 1.6565498709526907e-05, 'num_leaves': 255, 'feature_fraction': 0.9412460405679186, 'bagging_fraction': 0.5089222618535323, 'bagging_freq': 2, 'min_child_samples': 72, 'min_data_in_leaf': 98}. Best is trial 3 with value: 0.788125.
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-31 09:19:57,441] Trial 12 finished with value: 0.781875 and parameters: {'lambda_l1': 9.64339021338494e-07, 'lambda_l2': 2.3905518900778342e-05, 'num_leaves': 228, 'feature_fraction': 0.7442286897963439, 'bagging_fraction': 0.6662188098548096, 'bagging_freq': 1, 'min_child_samples': 36, 'min_data_in_leaf': 83}. Best is trial 3 with value: 0.788125.
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-31 09:19:57,647] Trial 13 finished with value: 0.775 and parameters: {'lambda_l1': 3.561810046708023e-07, 'lambda_l2': 1.1547244680388957e-06, 'num_leaves': 144, 'feature_fraction': 0.8524752877598608, 'bagging_fraction': 0.40057567922537796, 'bagging_freq': 2, 'min_child_samples': 76, 'min_data_in_leaf': 20}. Best is trial 3 with value: 0.788125.
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-31 09:19:57,790] Trial 14 finished with value: 0.779375 and parameters: {'lambda_l1': 5.023866187214644e-06, 'lambda_l2': 0.001051927474205962, 'num_leaves': 220, 'feature_fraction': 0.9983817600627078, 'bagging_fraction': 0.5085862354557226, 'bagging_freq': 3, 'min_child_samples': 73, 'min_data_in_leaf': 83}. Best is trial 3 with value: 0.788125.
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-31 09:19:57,931] Trial 15 finished with value: 0.775 and parameters: {'lambda_l1': 6.374443016839713e-08, 'lambda_l2': 1.0799803260437693e-08, 'num_leaves': 58, 'feature_fraction': 0.53592511369555, 'bagging_fraction': 0.6015990923487602, 'bagging_freq': 4, 'min_child_samples': 49, 'min_data_in_leaf': 52}. Best is trial 3 with value: 0.788125.
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-31 09:19:58,122] Trial 16 finished with value: 0.78 and parameters: {'lambda_l1': 1.4262019187525388e-07, 'lambda_l2': 2.600972114512414e-06, 'num_leaves': 161, 'feature_fraction': 0.6579911410095218, 'bagging_fraction': 0.7043769496650428, 'bagging_freq': 2, 'min_child_samples': 82, 'min_data_in_leaf': 33}. Best is trial 3 with value: 0.788125.
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-31 09:19:58,250] Trial 17 finished with value: 0.785 and parameters: {'lambda_l1': 3.999654658860337e-06, 'lambda_l2': 0.0004947543267099773, 'num_leaves': 7, 'feature_fraction': 0.7188001330013692, 'bagging_fraction': 0.4582357741347186, 'bagging_freq': 1, 'min_child_samples': 67, 'min_data_in_leaf': 56}. Best is trial 3 with value: 0.788125.
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-31 09:19:58,380] Trial 18 finished with value: 0.784375 and parameters: {'lambda_l1': 9.143896586343806e-08, 'lambda_l2': 0.005225686275485009, 'num_leaves': 223, 'feature_fraction': 0.5130613165472937, 'bagging_fraction': 0.5518766922110053, 'bagging_freq': 3, 'min_child_samples': 5, 'min_data_in_leaf': 87}. Best is trial 3 with value: 0.788125.
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-31 09:19:58,550] Trial 19 finished with value: 0.77625 and parameters: {'lambda_l1': 7.262241020241157e-06, 'lambda_l2': 0.00017891272181172897, 'num_leaves': 115, 'feature_fraction': 0.6181117969991141, 'bagging_fraction': 0.6394248554104536, 'bagging_freq': 5, 'min_child_samples': 48, 'min_data_in_leaf': 45}. Best is trial 3 with value: 0.788125.
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-31 09:19:58,753] Trial 20 finished with value: 0.780625 and parameters: {'lambda_l1': 1.9868351851204772e-08, 'lambda_l2': 1.4832493463193905, 'num_leaves': 254, 'feature_fraction': 0.7963750015636054, 'bagging_fraction': 0.5485137335735373, 'bagging_freq': 2, 'min_child_samples': 94, 'min_data_in_leaf': 30}. Best is trial 3 with value: 0.788125.
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-31 09:19:58,998] Trial 21 finished with value: 0.78125 and parameters: {'lambda_l1': 0.0028347493076479537, 'lambda_l2': 9.142423830236535, 'num_leaves': 96, 'feature_fraction': 0.7567610921024474, 'bagging_fraction': 0.7960860705869559, 'bagging_freq': 5, 'min_child_samples': 61, 'min_data_in_leaf': 47}. Best is trial 3 with value: 0.788125.
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-31 09:19:59,316] Trial 22 finished with value: 0.780625 and parameters: {'lambda_l1': 4.845370425929535e-07, 'lambda_l2': 1.004350455740531, 'num_leaves': 68, 'feature_fraction': 0.6798628058731647, 'bagging_fraction': 0.9610720851827067, 'bagging_freq': 5, 'min_child_samples': 64, 'min_data_in_leaf': 45}. Best is trial 3 with value: 0.788125.
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-31 09:19:59,511] Trial 23 finished with value: 0.78125 and parameters: {'lambda_l1': 2.9953910373860592e-05, 'lambda_l2': 8.905144984548745, 'num_leaves': 74, 'feature_fraction': 0.7901081216259717, 'bagging_fraction': 0.7519442828117661, 'bagging_freq': 6, 'min_child_samples': 80, 'min_data_in_leaf': 57}. Best is trial 3 with value: 0.788125.
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-31 09:19:59,843] Trial 24 finished with value: 0.7725 and parameters: {'lambda_l1': 1.4827036894344306e-06, 'lambda_l2': 0.66308556132156, 'num_leaves': 168, 'feature_fraction': 0.6995700449739469, 'bagging_fraction': 0.9703087943559003, 'bagging_freq': 4, 'min_child_samples': 39, 'min_data_in_leaf': 30}. Best is trial 3 with value: 0.788125.
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-31 09:20:00,021] Trial 25 finished with value: 0.771875 and parameters: {'lambda_l1': 7.422241658075904e-08, 'lambda_l2': 0.014623212581971651, 'num_leaves': 134, 'feature_fraction': 0.8793351519322767, 'bagging_fraction': 0.6624309125047619, 'bagging_freq': 6, 'min_child_samples': 22, 'min_data_in_leaf': 73}. Best is trial 3 with value: 0.788125.
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-31 09:20:00,319] Trial 26 finished with value: 0.77875 and parameters: {'lambda_l1': 5.7822001990625575e-06, 'lambda_l2': 0.10435090505856945, 'num_leaves': 232, 'feature_fraction': 0.7845442380737835, 'bagging_fraction': 0.9985919440599882, 'bagging_freq': 7, 'min_child_samples': 69, 'min_data_in_leaf': 52}. Best is trial 3 with value: 0.788125.
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-31 09:20:00,567] Trial 27 finished with value: 0.78 and parameters: {'lambda_l1': 1.1659546857116334e-08, 'lambda_l2': 1.2111977346638272, 'num_leaves': 209, 'feature_fraction': 0.724503871349776, 'bagging_fraction': 0.7432425479334632, 'bagging_freq': 1, 'min_child_samples': 57, 'min_data_in_leaf': 36}. Best is trial 3 with value: 0.788125.
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# ...
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-31 09:22:04,730] Trial 90 finished with value: 0.775625 and parameters: {'lambda_l1': 0.00817074977012284, 'lambda_l2': 0.0007339019642890278, 'num_leaves': 133, 'feature_fraction': 0.5179102109581929, 'bagging_fraction': 0.8145072909785911, 'bagging_freq': 6, 'min_child_samples': 17, 'min_data_in_leaf': 62}. Best is trial 73 with value: 0.788125.
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-31 09:22:04,952] Trial 91 finished with value: 0.783125 and parameters: {'lambda_l1': 0.0002419659112616464, 'lambda_l2': 0.0012955415440760042, 'num_leaves': 28, 'feature_fraction': 0.45110767506855926, 'bagging_fraction': 0.8283638393190674, 'bagging_freq': 6, 'min_child_samples': 48, 'min_data_in_leaf': 73}. Best is trial 73 with value: 0.788125.
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-31 09:22:05,174] Trial 92 finished with value: 0.781875 and parameters: {'lambda_l1': 5.6600820738863455e-05, 'lambda_l2': 0.00039520006596516243, 'num_leaves': 56, 'feature_fraction': 0.4080228265912535, 'bagging_fraction': 0.8431206312469822, 'bagging_freq': 6, 'min_child_samples': 45, 'min_data_in_leaf': 96}. Best is trial 73 with value: 0.788125.
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-31 09:22:05,425] Trial 93 finished with value: 0.778125 and parameters: {'lambda_l1': 0.00022603982386725736, 'lambda_l2': 0.00028103429287484145, 'num_leaves': 236, 'feature_fraction': 0.5098456768686002, 'bagging_fraction': 0.8065246738376086, 'bagging_freq': 6, 'min_child_samples': 35, 'min_data_in_leaf': 65}. Best is trial 73 with value: 0.788125.
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-31 09:22:05,720] Trial 94 finished with value: 0.77875 and parameters: {'lambda_l1': 0.00010123837870038734, 'lambda_l2': 0.002828394118543802, 'num_leaves': 192, 'feature_fraction': 0.6195227204161268, 'bagging_fraction': 0.8695049334761216, 'bagging_freq': 7, 'min_child_samples': 53, 'min_data_in_leaf': 70}. Best is trial 73 with value: 0.788125.
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-31 09:22:06,008] Trial 95 finished with value: 0.788125 and parameters: {'lambda_l1': 0.002282842354524115, 'lambda_l2': 0.0002122671478098081, 'num_leaves': 145, 'feature_fraction': 0.4801993139607051, 'bagging_fraction': 0.8931144488896601, 'bagging_freq': 6, 'min_child_samples': 40, 'min_data_in_leaf': 90}. Best is trial 73 with value: 0.788125.
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-31 09:22:06,279] Trial 96 finished with value: 0.785625 and parameters: {'lambda_l1': 0.002493892626961569, 'lambda_l2': 0.005290765863711307, 'num_leaves': 154, 'feature_fraction': 0.48155658599183465, 'bagging_fraction': 0.8957009971005094, 'bagging_freq': 7, 'min_child_samples': 38, 'min_data_in_leaf': 89}. Best is trial 73 with value: 0.788125.
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-31 09:22:06,623] Trial 97 finished with value: 0.7775 and parameters: {'lambda_l1': 0.004133786937616603, 'lambda_l2': 0.0001889602167997224, 'num_leaves': 146, 'feature_fraction': 0.42518660804609865, 'bagging_fraction': 0.8740713454760635, 'bagging_freq': 5, 'min_child_samples': 40, 'min_data_in_leaf': 85}. Best is trial 73 with value: 0.788125.
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-31 09:22:07,027] Trial 98 finished with value: 0.786875 and parameters: {'lambda_l1': 0.0013890624770013964, 'lambda_l2': 0.0007058822003678494, 'num_leaves': 126, 'feature_fraction': 0.5016374841056905, 'bagging_fraction': 0.9235371181072454, 'bagging_freq': 6, 'min_child_samples': 31, 'min_data_in_leaf': 68}. Best is trial 73 with value: 0.788125.
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-31 09:22:07,295] Trial 99 finished with value: 0.78 and parameters: {'lambda_l1': 0.0018071297453907704, 'lambda_l2': 0.0008209707500007226, 'num_leaves': 122, 'feature_fraction': 0.4986078664840337, 'bagging_fraction': 0.9137785074220017, 'bagging_freq': 7, 'min_child_samples': 30, 'min_data_in_leaf': 58}. Best is trial 73 with value: 0.788125.

# %% [markdown]
# - lgb_平均スコア

# %%
# 全フォールドの平均スコアを計算
lgb_average_score = sum(lgb_fold_scores) / n_splits
print(f"LightGBM Average accuracy across all folds: {lgb_average_score:.4f}")


lgb_average_conf = sum(lgb_conf_scores) / n_splits
print(f"LightGBM Average conf-matrix across all folds: {lgb_average_conf}")
# Out:
# LightGBM Average accuracy across all folds: 0.7881
# LightGBM Average conf-matrix across all folds: [[636.2 177. ]
#  [162.  624.8]]

# %% [markdown]
# - lgb_予測平均

# %%
# 予測の平均を計算
lgb_y_test_pred_avg = np.mean(lgb_test_predictions, axis=0)

# 最終的な予測結果を整数に変換
lgb_y_test_pred_int = (lgb_y_test_pred_avg > lgb_threshold).astype(int)

# %% [markdown]
# - output

# %%
# 現在の日時を取得してフォーマットする
current_time = datetime.now().strftime("%Y%m%d_%H%M%S")
output = f'../data/output/{current_time}_LightGBM_cv{lgb_average_score:.4f}.csv'

submit = pd.DataFrame({
    '0': test['gameId'],
    '1': lgb_y_test_pred_int
})

# カラムヘッダー消去して出力
# ヘッダーなしでCSVファイルとして保存
submit.to_csv(output, header=False, index=False)

# %%
submit
# Out:
#          0  1
# 0        9  1
# 1       15  1
# 2       18  0
# 3       23  0
# 4       31  1
# ...    ... ..
# 1995  9971  0
# 1996  9980  0
# 1997  9983  1
# 1998  9996  1
# 1999  9999  0
#
# [2000 rows x 2 columns]

# %% [markdown]
# ## XGBoost

# %%
for train_index, val_index in kf.split(X):
    X_train_fold, X_val_fold = X.iloc[train_index], X.iloc[val_index]
    y_train_fold, y_val_fold = y[train_index], y[val_index]

    dtrain = xgb.DMatrix(X_train_fold, label=y_train_fold)
    dval = xgb.DMatrix(X_val_fold, label=y_val_fold)
    dtest = xgb.DMatrix(test_drop_gameId)

    # Optunaでのハイパーパラメータチューニング
    def objective(trial):
        param = {
            'verbosity': 0,
            'objective': 'binary:logistic',
            'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
            'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
            'max_depth': trial.suggest_int('max_depth', 3, 9),
            'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
            'subsample': trial.suggest_float('subsample', 0.5, 1),
            'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1)
        }

        bst = xgb.train(param, dtrain, num_boost_round=1000, evals=[(dval, "eval")], early_stopping_rounds=100, verbose_eval=False)
        preds = bst.predict(dval)
        pred_labels = np.rint(preds)
        accuracy = accuracy_score(y_val_fold, pred_labels)
        return accuracy

    xgb_study = optuna.create_study(direction='maximize')
    xgb_study.optimize(objective, n_trials=100)

    # 各フォールドの最適パラメータでモデルを再学習
    xgb_best_params = xgb_study.best_params
    xgb_best_params['objective'] = 'binary:logistic'
    xgb_best_params['verbosity'] = 0

    xgb_final_bst = xgb.train(xgb_best_params, dtrain, num_boost_round=xgb_study.best_trial.number)

    # 各フォールドのモデル性能を評価
    xgb_y_val_pred = xgb_final_bst.predict(dval)
    xgb_y_val_pred_int = np.rint(xgb_y_val_pred)
    fold_accuracy = accuracy_score(y_val_fold, xgb_y_val_pred_int)
    xgb_fold_scores.append(fold_accuracy)

    # 混同行列
    xgb_conf_matrix = confusion_matrix(y_val_fold, xgb_y_val_pred_int)
    xgb_conf_scores.append(xgb_conf_matrix)

    # テストデータセットでの予測
    xgb_y_test_pred_fold = xgb_final_bst.predict(dtest)
    xgb_test_predictions.append(xgb_y_test_pred_fold)
# Out:
# [I 2024-01-31 09:22:07,592] A new study created in memory with name: no-name-23f20c90-0cbe-4af5-a4c4-2026f5b18f8e
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-31 09:22:09,266] Trial 0 finished with value: 0.7075 and parameters: {'alpha': 1.2477686407120435e-06, 'lambda': 0.025045105286557172, 'max_depth': 6, 'eta': 2.657762969351894e-05, 'subsample': 0.7251927680294343, 'colsample_bytree': 0.6315336922187476}. Best is trial 0 with value: 0.7075.
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-31 09:22:09,621] Trial 1 finished with value: 0.776875 and parameters: {'alpha': 1.7698043242960608e-07, 'lambda': 0.13779783355409014, 'max_depth': 9, 'eta': 0.03991509588188657, 'subsample': 0.5094521109240345, 'colsample_bytree': 0.5630991256523281}. Best is trial 1 with value: 0.776875.
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-31 09:22:12,537] Trial 2 finished with value: 0.505625 and parameters: {'alpha': 1.7209851089063173e-06, 'lambda': 6.044958278121905e-07, 'max_depth': 9, 'eta': 3.6923531290602194e-07, 'subsample': 0.8141982614051373, 'colsample_bytree': 0.715261129041399}. Best is trial 1 with value: 0.776875.
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-31 09:22:15,378] Trial 3 finished with value: 0.505625 and parameters: {'alpha': 0.0017434160810075499, 'lambda': 1.908257788781776e-05, 'max_depth': 9, 'eta': 2.0654996500118684e-07, 'subsample': 0.9401079581546136, 'colsample_bytree': 0.5217884120462208}. Best is trial 1 with value: 0.776875.
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-31 09:22:15,588] Trial 4 finished with value: 0.779375 and parameters: {'alpha': 1.5981752655102556e-06, 'lambda': 0.0011885675465136546, 'max_depth': 3, 'eta': 0.17614777066790463, 'subsample': 0.7169751273047645, 'colsample_bytree': 0.8418183707092275}. Best is trial 4 with value: 0.779375.
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-31 09:22:15,755] Trial 5 finished with value: 0.756875 and parameters: {'alpha': 0.49671444106037604, 'lambda': 0.014706822089440609, 'max_depth': 7, 'eta': 0.22623233671400117, 'subsample': 0.6155334621396626, 'colsample_bytree': 0.6589600303009415}. Best is trial 4 with value: 0.779375.
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-31 09:22:16,732] Trial 6 finished with value: 0.505625 and parameters: {'alpha': 0.06983483279932705, 'lambda': 3.26851474812895e-05, 'max_depth': 4, 'eta': 1.6713588409842266e-08, 'subsample': 0.5240321627101592, 'colsample_bytree': 0.5206871020344994}. Best is trial 4 with value: 0.779375.
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-31 09:22:16,890] Trial 7 finished with value: 0.7775 and parameters: {'alpha': 0.0004626435225621448, 'lambda': 1.2942085356058222e-08, 'max_depth': 4, 'eta': 0.21869676876697325, 'subsample': 0.7747504288087492, 'colsample_bytree': 0.7763937377946831}. Best is trial 4 with value: 0.779375.
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-31 09:22:19,007] Trial 8 finished with value: 0.505625 and parameters: {'alpha': 0.3339992675115087, 'lambda': 1.6385117935693333e-08, 'max_depth': 8, 'eta': 9.348522211185696e-06, 'subsample': 0.5680655754074508, 'colsample_bytree': 0.5725576371039955}. Best is trial 4 with value: 0.779375.
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-31 09:22:22,296] Trial 9 finished with value: 0.726875 and parameters: {'alpha': 8.904747035313201e-08, 'lambda': 3.913859346833667e-07, 'max_depth': 9, 'eta': 2.976246310689798e-05, 'subsample': 0.88924400601685, 'colsample_bytree': 0.8473030442753626}. Best is trial 4 with value: 0.779375.
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-31 09:22:23,223] Trial 10 finished with value: 0.754375 and parameters: {'alpha': 1.8472211348734004e-05, 'lambda': 0.0013673719328208365, 'max_depth': 3, 'eta': 0.003132344886038128, 'subsample': 0.6695399654604067, 'colsample_bytree': 0.995998642611506}. Best is trial 4 with value: 0.779375.
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-31 09:22:23,363] Trial 11 finished with value: 0.76125 and parameters: {'alpha': 0.00025442111792194853, 'lambda': 0.0006342625132771013, 'max_depth': 4, 'eta': 0.9927773993249739, 'subsample': 0.7915760098965658, 'colsample_bytree': 0.8062525845878615}. Best is trial 4 with value: 0.779375.
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-31 09:22:24,386] Trial 12 finished with value: 0.775625 and parameters: {'alpha': 2.660217850553633e-05, 'lambda': 2.0262531081352022e-08, 'max_depth': 3, 'eta': 0.008154595046692088, 'subsample': 0.7109794961949976, 'colsample_bytree': 0.8259754621004258}. Best is trial 4 with value: 0.779375.
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-31 09:22:25,664] Trial 13 finished with value: 0.775625 and parameters: {'alpha': 0.0007197956577385399, 'lambda': 0.5072369182847457, 'max_depth': 5, 'eta': 0.0027623108863791524, 'subsample': 0.8084503148331509, 'colsample_bytree': 0.8949749523425125}. Best is trial 4 with value: 0.779375.
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-31 09:22:25,823] Trial 14 finished with value: 0.755 and parameters: {'alpha': 1.391716882183756e-08, 'lambda': 0.00014544297761019044, 'max_depth': 4, 'eta': 0.9442599594566353, 'subsample': 0.6618528392048963, 'colsample_bytree': 0.7523513558861106}. Best is trial 4 with value: 0.779375.
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-31 09:22:26,456] Trial 15 finished with value: 0.784375 and parameters: {'alpha': 0.004847100231562881, 'lambda': 3.868211151048678e-06, 'max_depth': 5, 'eta': 0.027113991249654357, 'subsample': 0.7608601650742497, 'colsample_bytree': 0.7541445706208432}. Best is trial 15 with value: 0.784375.
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-31 09:22:27,932] Trial 16 finished with value: 0.776875 and parameters: {'alpha': 0.009673807346143542, 'lambda': 1.588951962243144e-05, 'max_depth': 6, 'eta': 0.0004796203398535792, 'subsample': 0.989193943684892, 'colsample_bytree': 0.71210181622873}. Best is trial 15 with value: 0.784375.
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-31 09:22:28,521] Trial 17 finished with value: 0.78125 and parameters: {'alpha': 0.011867854599499406, 'lambda': 2.901272136865143e-06, 'max_depth': 5, 'eta': 0.024960554800550185, 'subsample': 0.8560577317803466, 'colsample_bytree': 0.8828409426889865}. Best is trial 15 with value: 0.784375.
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-31 09:22:29,181] Trial 18 finished with value: 0.7775 and parameters: {'alpha': 0.009878215867644414, 'lambda': 1.6958256751316825e-06, 'max_depth': 6, 'eta': 0.015248159942722024, 'subsample': 0.8399021804385793, 'colsample_bytree': 0.9091741766129193}. Best is trial 15 with value: 0.784375.
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-31 09:22:30,457] Trial 19 finished with value: 0.773125 and parameters: {'alpha': 0.0067732453736871175, 'lambda': 2.8939278544280925e-06, 'max_depth': 5, 'eta': 0.00060468397191263, 'subsample': 0.8542186069549064, 'colsample_bytree': 0.8986226150220983}. Best is trial 15 with value: 0.784375.
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-31 09:22:30,860] Trial 20 finished with value: 0.78 and parameters: {'alpha': 0.09117027762652488, 'lambda': 1.8136824910558603e-07, 'max_depth': 5, 'eta': 0.039181375788714376, 'subsample': 0.7647388321695521, 'colsample_bytree': 0.7826529694088215}. Best is trial 15 with value: 0.784375.
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-31 09:22:31,312] Trial 21 finished with value: 0.7825 and parameters: {'alpha': 0.054327929560809, 'lambda': 1.6109011043221097e-07, 'max_depth': 5, 'eta': 0.03169061622470235, 'subsample': 0.7558385467686153, 'colsample_bytree': 0.7831404900108789}. Best is trial 15 with value: 0.784375.
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-31 09:22:31,699] Trial 22 finished with value: 0.7775 and parameters: {'alpha': 0.06270852739402477, 'lambda': 4.9186648428926535e-06, 'max_depth': 5, 'eta': 0.03791267752070269, 'subsample': 0.8774508726361462, 'colsample_bytree': 0.7175922784180557}. Best is trial 15 with value: 0.784375.
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-31 09:22:33,600] Trial 23 finished with value: 0.775 and parameters: {'alpha': 0.004960683841830998, 'lambda': 1.7308977757561668e-07, 'max_depth': 7, 'eta': 0.0009943635426476853, 'subsample': 0.7492290161159894, 'colsample_bytree': 0.7608051131836101}. Best is trial 15 with value: 0.784375.
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-31 09:22:34,907] Trial 24 finished with value: 0.778125 and parameters: {'alpha': 0.029386571641381642, 'lambda': 8.470242009754293e-08, 'max_depth': 7, 'eta': 0.006508583726576011, 'subsample': 0.8131083503735379, 'colsample_bytree': 0.8016534110624115}. Best is trial 15 with value: 0.784375.
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-31 09:22:35,520] Trial 25 finished with value: 0.780625 and parameters: {'alpha': 0.0018205981527499664, 'lambda': 2.5775036354979114e-06, 'max_depth': 5, 'eta': 0.018951127958301704, 'subsample': 0.7544189525435019, 'colsample_bytree': 0.8786900060163298}. Best is trial 15 with value: 0.784375.
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-31 09:22:37,277] Trial 26 finished with value: 0.774375 and parameters: {'alpha': 0.253081530081702, 'lambda': 8.476625097078139e-07, 'max_depth': 6, 'eta': 0.00013739890021288574, 'subsample': 0.9059609066807398, 'colsample_bytree': 0.9412987113032072}. Best is trial 15 with value: 0.784375.
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-31 09:22:38,446] Trial 27 finished with value: 0.774375 and parameters: {'alpha': 0.9264663634212299, 'lambda': 7.308984883398284e-08, 'max_depth': 4, 'eta': 0.003797686463085802, 'subsample': 0.842583797085789, 'colsample_bytree': 0.850313010166418}. Best is trial 15 with value: 0.784375.
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-31 09:22:38,738] Trial 28 finished with value: 0.775 and parameters: {'alpha': 0.02520659911408136, 'lambda': 6.446737147533124e-06, 'max_depth': 5, 'eta': 0.08781608983605702, 'subsample': 0.8148512961095877, 'colsample_bytree': 0.7808673065506857}. Best is trial 15 with value: 0.784375.
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-31 09:22:39,496] Trial 29 finished with value: 0.781875 and parameters: {'alpha': 0.002661163624092274, 'lambda': 6.661861958867125e-07, 'max_depth': 6, 'eta': 0.014013861147222912, 'subsample': 0.7386065889205788, 'colsample_bytree': 0.66918197976446}. Best is trial 15 with value: 0.784375.
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-31 09:22:40,438] Trial 30 finished with value: 0.7775 and parameters: {'alpha': 0.002069538419616066, 'lambda': 3.3537364444342265e-07, 'max_depth': 6, 'eta': 0.009101609540125979, 'subsample': 0.7198322470875477, 'colsample_bytree': 0.6611263388795063}. Best is trial 15 with value: 0.784375.
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-31 09:22:40,681] Trial 31 finished with value: 0.7825 and parameters: {'alpha': 0.029815304684660027, 'lambda': 1.1233044584199968e-06, 'max_depth': 6, 'eta': 0.08630613591296526, 'subsample': 0.7350482565360899, 'colsample_bytree': 0.7306719795607144}. Best is trial 15 with value: 0.784375.
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-31 09:22:40,926] Trial 32 finished with value: 0.783125 and parameters: {'alpha': 0.17075993910685197, 'lambda': 9.911108896445604e-07, 'max_depth': 6, 'eta': 0.099994911000377, 'subsample': 0.6907242774182939, 'colsample_bytree': 0.7311974469681617}. Best is trial 15 with value: 0.784375.
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-31 09:22:41,177] Trial 33 finished with value: 0.77375 and parameters: {'alpha': 0.1588250186047713, 'lambda': 1.0770545911855758e-06, 'max_depth': 7, 'eta': 0.10057191145376128, 'subsample': 0.7011277674336507, 'colsample_bytree': 0.7128149529738209}. Best is trial 15 with value: 0.784375.
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-31 09:22:41,407] Trial 34 finished with value: 0.739375 and parameters: {'alpha': 0.04173896311266174, 'lambda': 7.2958591269572235e-06, 'max_depth': 8, 'eta': 0.42235560808281664, 'subsample': 0.6781413697716328, 'colsample_bytree': 0.7451095291811766}. Best is trial 15 with value: 0.784375.
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-31 09:22:41,770] Trial 35 finished with value: 0.7725 and parameters: {'alpha': 0.13600489035539112, 'lambda': 1.3759778476261355e-06, 'max_depth': 6, 'eta': 0.0660509895108887, 'subsample': 0.7808225620403022, 'colsample_bytree': 0.7369718745638293}. Best is trial 15 with value: 0.784375.
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-31 09:22:42,028] Trial 36 finished with value: 0.766875 and parameters: {'alpha': 0.022485231882506992, 'lambda': 5.23816144338907e-08, 'max_depth': 7, 'eta': 0.07596790644149023, 'subsample': 0.7393722043387084, 'colsample_bytree': 0.6912350098639013}. Best is trial 15 with value: 0.784375.
# ...
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-31 09:32:16,422] Trial 87 finished with value: 0.801875 and parameters: {'alpha': 5.221668137032029e-07, 'lambda': 1.456057919819379e-07, 'max_depth': 8, 'eta': 0.00029810188613692935, 'subsample': 0.6283170456468872, 'colsample_bytree': 0.5427807908725103}. Best is trial 49 with value: 0.80375.
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-31 09:32:18,910] Trial 88 finished with value: 0.79875 and parameters: {'alpha': 7.417934306368282e-07, 'lambda': 2.517196730280123e-07, 'max_depth': 8, 'eta': 0.0024944693510628837, 'subsample': 0.6393295723400406, 'colsample_bytree': 0.5824455006713474}. Best is trial 49 with value: 0.80375.
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-31 09:32:20,554] Trial 89 finished with value: 0.800625 and parameters: {'alpha': 1.7080915493450668e-06, 'lambda': 5.050651732640443e-08, 'max_depth': 6, 'eta': 0.0014202088039598037, 'subsample': 0.606893076106031, 'colsample_bytree': 0.5549079049880259}. Best is trial 49 with value: 0.80375.
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-31 09:32:21,856] Trial 90 finished with value: 0.80125 and parameters: {'alpha': 5.729894722613874e-06, 'lambda': 1.1240793888802599e-07, 'max_depth': 5, 'eta': 0.005605291577239354, 'subsample': 0.6866406441883741, 'colsample_bytree': 0.594788932170151}. Best is trial 49 with value: 0.80375.
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-31 09:32:24,641] Trial 91 finished with value: 0.803125 and parameters: {'alpha': 8.547824497055307e-06, 'lambda': 2.6919088455016814e-07, 'max_depth': 9, 'eta': 0.0018795531708195696, 'subsample': 0.6747565890648074, 'colsample_bytree': 0.533889628956896}. Best is trial 49 with value: 0.80375.
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-31 09:32:27,526] Trial 92 finished with value: 0.798125 and parameters: {'alpha': 9.008435817454984e-06, 'lambda': 2.3833691948869026e-07, 'max_depth': 9, 'eta': 0.0005621289819001638, 'subsample': 0.6557716017818034, 'colsample_bytree': 0.5307850045512407}. Best is trial 49 with value: 0.80375.
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-31 09:32:30,401] Trial 93 finished with value: 0.80125 and parameters: {'alpha': 2.7612730495419966e-06, 'lambda': 3.873598200013077e-07, 'max_depth': 9, 'eta': 0.0011232799710094, 'subsample': 0.674447590400549, 'colsample_bytree': 0.5423341237400171}. Best is trial 49 with value: 0.80375.
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-31 09:32:33,090] Trial 94 finished with value: 0.795625 and parameters: {'alpha': 3.95934908495565e-06, 'lambda': 7.4134125651067e-08, 'max_depth': 9, 'eta': 0.003698289098816815, 'subsample': 0.6376607468040933, 'colsample_bytree': 0.5662884474105301}. Best is trial 49 with value: 0.80375.
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-31 09:32:35,550] Trial 95 finished with value: 0.80625 and parameters: {'alpha': 1.2847515565148823e-06, 'lambda': 1.5565384353764938e-07, 'max_depth': 8, 'eta': 0.0024348105075430527, 'subsample': 0.6778881374973941, 'colsample_bytree': 0.5520548942849308}. Best is trial 95 with value: 0.80625.
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-31 09:32:38,102] Trial 96 finished with value: 0.7975 and parameters: {'alpha': 1.3297005177957782e-06, 'lambda': 1.1811264961058783e-07, 'max_depth': 8, 'eta': 0.0022304382500259665, 'subsample': 0.6940924220389045, 'colsample_bytree': 0.5762197594986748}. Best is trial 95 with value: 0.80625.
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-31 09:32:39,691] Trial 97 finished with value: 0.795625 and parameters: {'alpha': 6.439518393944783e-06, 'lambda': 4.07442330155995e-08, 'max_depth': 8, 'eta': 0.00770647405112836, 'subsample': 0.6513540823399429, 'colsample_bytree': 0.5546824741864975}. Best is trial 95 with value: 0.80625.
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-31 09:32:40,534] Trial 98 finished with value: 0.7975 and parameters: {'alpha': 3.8683597904676735e-07, 'lambda': 1.1801440951214714e-06, 'max_depth': 7, 'eta': 0.017388903824488412, 'subsample': 0.6255272374222585, 'colsample_bytree': 0.5281063556404177}. Best is trial 95 with value: 0.80625.
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_23656\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-31 09:32:42,804] Trial 99 finished with value: 0.801875 and parameters: {'alpha': 1.2807768943893984e-05, 'lambda': 2.546490364909636e-08, 'max_depth': 8, 'eta': 0.0018542255319139171, 'subsample': 0.6796012440272355, 'colsample_bytree': 0.5123773890569053}. Best is trial 95 with value: 0.80625.

# %% [markdown]
# - xgb_平均スコア

# %%
# 全フォールドの平均スコアを計算
xgb_average_score = sum(xgb_fold_scores) / n_splits
print(f"XGB Average accuracy across all folds: {xgb_average_score:.4f}")

xgb_average_conf = sum(xgb_conf_scores) / n_splits
print(f"XGB Average conf-matrix across all folds: {xgb_average_conf}")
# Out:
# XGB Average accuracy across all folds: 0.7702
# XGB Average conf-matrix across all folds: [[668.2 145. ]
#  [222.6 564.2]]

# %% [markdown]
# - xgb_予測平均

# %%
# 予測の平均を計算
xgb_y_test_pred_avg = np.mean(xgb_test_predictions, axis=0)

# 最終的な予測結果を整数に変換
xgb_y_test_pred_int = (xgb_y_test_pred_avg > xgb_threshold).astype(int)

# %% [markdown]
# - output

# %%
# 現在の日時を取得してフォーマットする
current_time = datetime.now().strftime("%Y%m%d_%H%M%S")
output = f'../data/output/{current_time}_XGBoost_cv{xgb_average_score:.4f}.csv'

submit = pd.DataFrame({
    '0': test['gameId'],
    '1': xgb_y_test_pred_int
})

# カラムヘッダー消去して出力
# ヘッダーなしでCSVファイルとして保存
submit.to_csv(output, header=False, index=False)

# %% [markdown]
# ## CatBoost

# %%
for train_index, val_index in kf.split(X):
    X_train_fold, X_val_fold = X.iloc[train_index], X.iloc[val_index]
    y_train_fold, y_val_fold = y[train_index], y[val_index]

    # Optunaでのハイパーパラメータチューニング
    def objective(trial):
        param = {
            'iterations': 1000,
            'depth': trial.suggest_int('depth', 4, 10),
            'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3),
            'random_strength': trial.suggest_int('random_strength', 1, 20),
            'bagging_temperature': trial.suggest_float('bagging_temperature', 0.0, 1.0),
            'l2_leaf_reg': trial.suggest_float('l2_leaf_reg', 1e-3, 100),
            'scale_pos_weight': trial.suggest_float('scale_pos_weight', 0.1, 10.0),
            'loss_function': 'Logloss'
        }

        model = cb.CatBoostClassifier(**param, verbose=False)
        model.fit(X_train_fold, y_train_fold, eval_set=(X_val_fold, y_val_fold), early_stopping_rounds=100)
        preds = model.predict(X_val_fold)
        accuracy = accuracy_score(y_val_fold, preds)
        return accuracy

    cb_study = optuna.create_study(direction='maximize')
    cb_study.optimize(objective, n_trials=100)

    # 各フォールドの最適パラメータでモデルを再学習
    cb_best_params = cb_study.best_params
    cb_best_params['loss_function'] = 'Logloss'
    model_fold = cb.CatBoostClassifier(**cb_best_params, verbose=False)
    model_fold.fit(X_train_fold, y_train_fold)

    # 各フォールドのモデル性能を評価
    cb_y_val_pred = model_fold.predict(X_val_fold)
    cb_fold_accuracy = accuracy_score(y_val_fold, cb_y_val_pred)
    cb_fold_scores.append(cb_fold_accuracy)

    # 混同行列
    cb_conf_matrix = confusion_matrix(y_val_fold, cb_y_val_pred)
    cb_conf_scores.append(cb_conf_matrix)

    # テストデータセットでの予測
    cb_y_test_pred_fold = model_fold.predict(test_drop_gameId)
    cb_test_predictions.append(cb_y_test_pred_fold)
# Out:
# [I 2024-01-31 09:32:43,091] A new study created in memory with name: no-name-96fc946f-c031-49e1-a8fc-6eb956af8e74
# [I 2024-01-31 09:32:45,134] Trial 0 finished with value: 0.68375 and parameters: {'depth': 6, 'learning_rate': 0.1269021228885523, 'random_strength': 18, 'bagging_temperature': 0.9447844585432636, 'l2_leaf_reg': 83.06673773387588, 'scale_pos_weight': 8.158053105527692}. Best is trial 0 with value: 0.68375.
# [I 2024-01-31 09:32:46,274] Trial 1 finished with value: 0.731875 and parameters: {'depth': 6, 'learning_rate': 0.21929932317587866, 'random_strength': 16, 'bagging_temperature': 0.7354860655792282, 'l2_leaf_reg': 79.96522969117848, 'scale_pos_weight': 4.076710485242141}. Best is trial 1 with value: 0.731875.
# [I 2024-01-31 09:32:49,403] Trial 2 finished with value: 0.765625 and parameters: {'depth': 10, 'learning_rate': 0.17770687046888073, 'random_strength': 18, 'bagging_temperature': 0.14905105292827414, 'l2_leaf_reg': 45.382461580598545, 'scale_pos_weight': 2.307400101066122}. Best is trial 2 with value: 0.765625.
# [I 2024-01-31 09:32:50,617] Trial 3 finished with value: 0.778125 and parameters: {'depth': 7, 'learning_rate': 0.09959524857416983, 'random_strength': 1, 'bagging_temperature': 0.6966185118913415, 'l2_leaf_reg': 30.0655268905478, 'scale_pos_weight': 1.8778885406073758}. Best is trial 3 with value: 0.778125.
# [I 2024-01-31 09:32:53,158] Trial 4 finished with value: 0.7125 and parameters: {'depth': 10, 'learning_rate': 0.2369609314766335, 'random_strength': 18, 'bagging_temperature': 0.8666154377330252, 'l2_leaf_reg': 98.36851544725592, 'scale_pos_weight': 4.892350985277103}. Best is trial 3 with value: 0.778125.
# [I 2024-01-31 09:32:55,757] Trial 5 finished with value: 0.690625 and parameters: {'depth': 10, 'learning_rate': 0.23214137465441573, 'random_strength': 13, 'bagging_temperature': 0.3601841573609639, 'l2_leaf_reg': 40.41731588018308, 'scale_pos_weight': 7.4926380484832595}. Best is trial 3 with value: 0.778125.
# [I 2024-01-31 09:32:57,177] Trial 6 finished with value: 0.785 and parameters: {'depth': 9, 'learning_rate': 0.2622694871815432, 'random_strength': 9, 'bagging_temperature': 0.5052166497901484, 'l2_leaf_reg': 58.76080402534709, 'scale_pos_weight': 1.8924957758199266}. Best is trial 6 with value: 0.785.
# [I 2024-01-31 09:32:58,570] Trial 7 finished with value: 0.794375 and parameters: {'depth': 8, 'learning_rate': 0.12960117456285916, 'random_strength': 19, 'bagging_temperature': 0.46175346511580995, 'l2_leaf_reg': 58.68636838111004, 'scale_pos_weight': 0.7045841916034823}. Best is trial 7 with value: 0.794375.
# [I 2024-01-31 09:33:00,369] Trial 8 finished with value: 0.66375 and parameters: {'depth': 9, 'learning_rate': 0.06404860000777891, 'random_strength': 8, 'bagging_temperature': 0.05539096650516795, 'l2_leaf_reg': 36.25214181224907, 'scale_pos_weight': 9.462311524816966}. Best is trial 7 with value: 0.794375.
# [I 2024-01-31 09:33:04,000] Trial 9 finished with value: 0.74625 and parameters: {'depth': 10, 'learning_rate': 0.0961376259197848, 'random_strength': 14, 'bagging_temperature': 0.7018418712234491, 'l2_leaf_reg': 77.18824083381611, 'scale_pos_weight': 3.166169439561672}. Best is trial 7 with value: 0.794375.
# [I 2024-01-31 09:33:07,249] Trial 10 finished with value: 0.70125 and parameters: {'depth': 4, 'learning_rate': 0.010813148060886901, 'random_strength': 4, 'bagging_temperature': 0.3692153547696282, 'l2_leaf_reg': 5.5410567232153625, 'scale_pos_weight': 0.2121558485284849}. Best is trial 7 with value: 0.794375.
# [I 2024-01-31 09:33:08,601] Trial 11 finished with value: 0.70125 and parameters: {'depth': 8, 'learning_rate': 0.2993496252569741, 'random_strength': 9, 'bagging_temperature': 0.4812858834384968, 'l2_leaf_reg': 60.715912719247335, 'scale_pos_weight': 0.18396177320464258}. Best is trial 7 with value: 0.794375.
# [I 2024-01-31 09:33:09,775] Trial 12 finished with value: 0.790625 and parameters: {'depth': 8, 'learning_rate': 0.15957783697311495, 'random_strength': 6, 'bagging_temperature': 0.4981201217055575, 'l2_leaf_reg': 63.634881911156185, 'scale_pos_weight': 1.4580938262589909}. Best is trial 7 with value: 0.794375.
# [I 2024-01-31 09:33:10,981] Trial 13 finished with value: 0.793125 and parameters: {'depth': 8, 'learning_rate': 0.16886978158194232, 'random_strength': 5, 'bagging_temperature': 0.5417522711800367, 'l2_leaf_reg': 65.42217278777638, 'scale_pos_weight': 1.1519107418242167}. Best is trial 7 with value: 0.794375.
# [I 2024-01-31 09:33:12,098] Trial 14 finished with value: 0.739375 and parameters: {'depth': 7, 'learning_rate': 0.1801678539849605, 'random_strength': 2, 'bagging_temperature': 0.22780188136298662, 'l2_leaf_reg': 54.63428129392302, 'scale_pos_weight': 3.4149361453406146}. Best is trial 7 with value: 0.794375.
# [I 2024-01-31 09:33:13,742] Trial 15 finished with value: 0.713125 and parameters: {'depth': 8, 'learning_rate': 0.133792363247983, 'random_strength': 13, 'bagging_temperature': 0.5944702737615104, 'l2_leaf_reg': 69.24759530461344, 'scale_pos_weight': 5.622132028244202}. Best is trial 7 with value: 0.794375.
# [I 2024-01-31 09:33:14,521] Trial 16 finished with value: 0.8025 and parameters: {'depth': 6, 'learning_rate': 0.20610177484933795, 'random_strength': 20, 'bagging_temperature': 0.3208868143721381, 'l2_leaf_reg': 49.477058305068596, 'scale_pos_weight': 1.0472352412589743}. Best is trial 16 with value: 0.8025.
# [I 2024-01-31 09:33:15,514] Trial 17 finished with value: 0.67875 and parameters: {'depth': 5, 'learning_rate': 0.2050041246109807, 'random_strength': 20, 'bagging_temperature': 0.36296884112586797, 'l2_leaf_reg': 48.416317621255175, 'scale_pos_weight': 0.1278837609512744}. Best is trial 16 with value: 0.8025.
# [I 2024-01-31 09:33:16,605] Trial 18 finished with value: 0.759375 and parameters: {'depth': 6, 'learning_rate': 0.1891715024373387, 'random_strength': 20, 'bagging_temperature': 0.23740317460666815, 'l2_leaf_reg': 31.502201215433384, 'scale_pos_weight': 2.8633909281427288}. Best is trial 16 with value: 0.8025.
# [I 2024-01-31 09:33:17,983] Trial 19 finished with value: 0.7975 and parameters: {'depth': 4, 'learning_rate': 0.14250809399830267, 'random_strength': 15, 'bagging_temperature': 0.03057802784972019, 'l2_leaf_reg': 50.95890228172054, 'scale_pos_weight': 1.0003368655354647}. Best is trial 16 with value: 0.8025.
# [I 2024-01-31 09:33:18,747] Trial 20 finished with value: 0.7925 and parameters: {'depth': 4, 'learning_rate': 0.20067106375723298, 'random_strength': 11, 'bagging_temperature': 0.004464678511991171, 'l2_leaf_reg': 21.94299629234163, 'scale_pos_weight': 1.3382853276355133}. Best is trial 16 with value: 0.8025.
# [I 2024-01-31 09:33:20,092] Trial 21 finished with value: 0.8 and parameters: {'depth': 5, 'learning_rate': 0.14259091086623615, 'random_strength': 16, 'bagging_temperature': 0.09848870338944478, 'l2_leaf_reg': 50.29428173673294, 'scale_pos_weight': 0.9463270455539595}. Best is trial 16 with value: 0.8025.
# [I 2024-01-31 09:33:21,408] Trial 22 finished with value: 0.77125 and parameters: {'depth': 5, 'learning_rate': 0.14917019867407785, 'random_strength': 16, 'bagging_temperature': 0.07485885220886149, 'l2_leaf_reg': 49.33894861200761, 'scale_pos_weight': 2.3551273109541495}. Best is trial 16 with value: 0.8025.
# [I 2024-01-31 09:33:22,337] Trial 23 finished with value: 0.795625 and parameters: {'depth': 5, 'learning_rate': 0.16100130873141522, 'random_strength': 16, 'bagging_temperature': 0.15949012198037535, 'l2_leaf_reg': 43.52068671109919, 'scale_pos_weight': 1.0454960615655942}. Best is trial 16 with value: 0.8025.
# [I 2024-01-31 09:33:23,127] Trial 24 finished with value: 0.765625 and parameters: {'depth': 4, 'learning_rate': 0.1939486319548327, 'random_strength': 15, 'bagging_temperature': 0.005742777849860308, 'l2_leaf_reg': 52.4332001229887, 'scale_pos_weight': 2.4184823127043016}. Best is trial 16 with value: 0.8025.
# [I 2024-01-31 09:33:24,250] Trial 25 finished with value: 0.79625 and parameters: {'depth': 5, 'learning_rate': 0.15519129620174668, 'random_strength': 12, 'bagging_temperature': 0.13649217266068175, 'l2_leaf_reg': 50.29257887819656, 'scale_pos_weight': 0.9551451603398813}. Best is trial 16 with value: 0.8025.
# [I 2024-01-31 09:33:26,798] Trial 26 finished with value: 0.790625 and parameters: {'depth': 4, 'learning_rate': 0.11111745943761044, 'random_strength': 17, 'bagging_temperature': 0.2440615623622452, 'l2_leaf_reg': 40.119015814119, 'scale_pos_weight': 1.766510497495235}. Best is trial 16 with value: 0.8025.
# [I 2024-01-31 09:33:28,296] Trial 27 finished with value: 0.740625 and parameters: {'depth': 6, 'learning_rate': 0.14291774816700506, 'random_strength': 14, 'bagging_temperature': 0.09760286100336305, 'l2_leaf_reg': 71.03884498387632, 'scale_pos_weight': 3.618691860243402}. Best is trial 16 with value: 0.8025.
# [I 2024-01-31 09:33:29,388] Trial 28 finished with value: 0.79375 and parameters: {'depth': 5, 'learning_rate': 0.18097856884176053, 'random_strength': 19, 'bagging_temperature': 0.18873337155280737, 'l2_leaf_reg': 54.63513031334522, 'scale_pos_weight': 0.6508776422700173}. Best is trial 16 with value: 0.8025.
# [I 2024-01-31 09:33:31,084] Trial 29 finished with value: 0.76375 and parameters: {'depth': 7, 'learning_rate': 0.1183815248393014, 'random_strength': 17, 'bagging_temperature': 0.30304051601111764, 'l2_leaf_reg': 73.06513352275327, 'scale_pos_weight': 2.652790778442415}. Best is trial 16 with value: 0.8025.
# [I 2024-01-31 09:33:33,032] Trial 30 finished with value: 0.790625 and parameters: {'depth': 6, 'learning_rate': 0.1443483312151375, 'random_strength': 20, 'bagging_temperature': 0.09832449466018763, 'l2_leaf_reg': 89.12899743708427, 'scale_pos_weight': 1.7321427967452232}. Best is trial 16 with value: 0.8025.
# [I 2024-01-31 09:33:34,634] Trial 31 finished with value: 0.794375 and parameters: {'depth': 5, 'learning_rate': 0.16219605237183865, 'random_strength': 11, 'bagging_temperature': 0.14402292218744572, 'l2_leaf_reg': 50.37874421477535, 'scale_pos_weight': 0.9781599100415143}. Best is trial 16 with value: 0.8025.
# [I 2024-01-31 09:33:35,616] Trial 32 finished with value: 0.7975 and parameters: {'depth': 5, 'learning_rate': 0.20877370778885196, 'random_strength': 12, 'bagging_temperature': 0.05822287841982529, 'l2_leaf_reg': 44.58425892459259, 'scale_pos_weight': 0.86634201088066}. Best is trial 16 with value: 0.8025.
# [I 2024-01-31 09:33:36,483] Trial 33 finished with value: 0.771875 and parameters: {'depth': 6, 'learning_rate': 0.20362991211712472, 'random_strength': 15, 'bagging_temperature': 0.05277942918480699, 'l2_leaf_reg': 42.53980398060457, 'scale_pos_weight': 2.068213527888424}. Best is trial 16 with value: 0.8025.
# [I 2024-01-31 09:33:37,522] Trial 34 finished with value: 0.78125 and parameters: {'depth': 4, 'learning_rate': 0.17744607221757702, 'random_strength': 17, 'bagging_temperature': 0.0038816335686904235, 'l2_leaf_reg': 58.05663224576498, 'scale_pos_weight': 0.5236000571747772}. Best is trial 16 with value: 0.8025.
# [I 2024-01-31 09:33:38,507] Trial 35 finished with value: 0.79875 and parameters: {'depth': 5, 'learning_rate': 0.20935199385275788, 'random_strength': 13, 'bagging_temperature': 0.18434018794190446, 'l2_leaf_reg': 46.060248526027856, 'scale_pos_weight': 1.4362308296285928}. Best is trial 16 with value: 0.8025.
# [I 2024-01-31 09:33:39,422] Trial 36 finished with value: 0.785 and parameters: {'depth': 6, 'learning_rate': 0.22305698605815408, 'random_strength': 15, 'bagging_temperature': 0.286743044515419, 'l2_leaf_reg': 36.1252821922157, 'scale_pos_weight': 1.766823026929748}. Best is trial 16 with value: 0.8025.
# [I 2024-01-31 09:33:40,539] Trial 37 finished with value: 0.775625 and parameters: {'depth': 4, 'learning_rate': 0.23664174341239919, 'random_strength': 18, 'bagging_temperature': 0.1993326814889358, 'l2_leaf_reg': 65.84340236171155, 'scale_pos_weight': 2.2992644286024317}. Best is trial 16 with value: 0.8025.
# [I 2024-01-31 09:33:42,122] Trial 38 finished with value: 0.79 and parameters: {'depth': 5, 'learning_rate': 0.2172677484988213, 'random_strength': 13, 'bagging_temperature': 0.15394224141198498, 'l2_leaf_reg': 55.35139334277551, 'scale_pos_weight': 1.3303059618422348}. Best is trial 16 with value: 0.8025.
# [I 2024-01-31 09:33:42,852] Trial 39 finished with value: 0.725 and parameters: {'depth': 7, 'learning_rate': 0.2536832708856025, 'random_strength': 18, 'bagging_temperature': 0.1157118304151298, 'l2_leaf_reg': 46.462088272983785, 'scale_pos_weight': 4.071938985613008}. Best is trial 16 with value: 0.8025.
# [I 2024-01-31 09:33:43,985] Trial 40 finished with value: 0.755 and parameters: {'depth': 6, 'learning_rate': 0.17347550166596332, 'random_strength': 14, 'bagging_temperature': 0.19788273715972304, 'l2_leaf_reg': 62.34508520430006, 'scale_pos_weight': 2.7985430954517145}. Best is trial 16 with value: 0.8025.
# [I 2024-01-31 09:33:44,927] Trial 41 finished with value: 0.795625 and parameters: {'depth': 5, 'learning_rate': 0.21757726071883782, 'random_strength': 12, 'bagging_temperature': 0.05984560352358714, 'l2_leaf_reg': 45.3803301604721, 'scale_pos_weight': 0.7125995038495513}. Best is trial 16 with value: 0.8025.
# [I 2024-01-31 09:33:46,181] Trial 42 finished with value: 0.786875 and parameters: {'depth': 5, 'learning_rate': 0.19040771010267177, 'random_strength': 10, 'bagging_temperature': 0.11954850713536926, 'l2_leaf_reg': 38.713047831443404, 'scale_pos_weight': 1.3295614835304252}. Best is trial 16 with value: 0.8025.
# [I 2024-01-31 09:33:48,114] Trial 43 finished with value: 0.790625 and parameters: {'depth': 4, 'learning_rate': 0.20806277702501774, 'random_strength': 10, 'bagging_temperature': 0.05423248519580211, 'l2_leaf_reg': 46.98533957675602, 'scale_pos_weight': 0.5300946842065071}. Best is trial 16 with value: 0.8025.
# [I 2024-01-31 09:33:49,348] Trial 44 finished with value: 0.674375 and parameters: {'depth': 6, 'learning_rate': 0.24424990080268, 'random_strength': 12, 'bagging_temperature': 0.17888422298945908, 'l2_leaf_reg': 56.77419083390431, 'scale_pos_weight': 0.12776061457155863}. Best is trial 16 with value: 0.8025.
# [I 2024-01-31 09:33:51,400] Trial 45 finished with value: 0.778125 and parameters: {'depth': 5, 'learning_rate': 0.13645471643617635, 'random_strength': 14, 'bagging_temperature': 0.0989782026452186, 'l2_leaf_reg': 42.125283045856605, 'scale_pos_weight': 1.9803084937252686}. Best is trial 16 with value: 0.8025.
# [I 2024-01-31 09:33:52,455] Trial 46 finished with value: 0.796875 and parameters: {'depth': 4, 'learning_rate': 0.22688080181716277, 'random_strength': 8, 'bagging_temperature': 0.29550754340123475, 'l2_leaf_reg': 58.68744114947424, 'scale_pos_weight': 1.3850277853956403}. Best is trial 16 with value: 0.8025.
# [I 2024-01-31 09:33:53,439] Trial 47 finished with value: 0.79875 and parameters: {'depth': 6, 'learning_rate': 0.19366998814570988, 'random_strength': 19, 'bagging_temperature': 0.407309545446109, 'l2_leaf_reg': 51.98775049897718, 'scale_pos_weight': 0.8513414249180379}. Best is trial 16 with value: 0.8025.
# [I 2024-01-31 09:33:54,735] Trial 48 finished with value: 0.78125 and parameters: {'depth': 6, 'learning_rate': 0.18416209088638721, 'random_strength': 19, 'bagging_temperature': 0.41682332043593856, 'l2_leaf_reg': 52.037475906202125, 'scale_pos_weight': 1.6410407015777098}. Best is trial 16 with value: 0.8025.
# [I 2024-01-31 09:33:56,155] Trial 49 finished with value: 0.77625 and parameters: {'depth': 7, 'learning_rate': 0.17340265343011022, 'random_strength': 17, 'bagging_temperature': 0.41315406676507455, 'l2_leaf_reg': 61.98473674590869, 'scale_pos_weight': 0.4910235094497265}. Best is trial 16 with value: 0.8025.
# [I 2024-01-31 09:33:57,532] Trial 50 finished with value: 0.776875 and parameters: {'depth': 6, 'learning_rate': 0.12333992817004256, 'random_strength': 19, 'bagging_temperature': 0.3430383130493554, 'l2_leaf_reg': 53.26484344617849, 'scale_pos_weight': 2.0255544602721236}. Best is trial 16 with value: 0.8025.
# [I 2024-01-31 09:33:58,646] Trial 51 finished with value: 0.800625 and parameters: {'depth': 5, 'learning_rate': 0.21366309105775322, 'random_strength': 16, 'bagging_temperature': 0.2597852123383082, 'l2_leaf_reg': 45.7041188094592, 'scale_pos_weight': 0.962934257376305}. Best is trial 16 with value: 0.8025.
# [I 2024-01-31 09:33:59,757] Trial 52 finished with value: 0.8025 and parameters: {'depth': 5, 'learning_rate': 0.1525661599114442, 'random_strength': 16, 'bagging_temperature': 0.24757134999858188, 'l2_leaf_reg': 48.46930078540004, 'scale_pos_weight': 1.0432680242472114}. Best is trial 16 with value: 0.8025.
# [I 2024-01-31 09:34:00,890] Trial 53 finished with value: 0.760625 and parameters: {'depth': 5, 'learning_rate': 0.19510585342041076, 'random_strength': 16, 'bagging_temperature': 0.2660036557671973, 'l2_leaf_reg': 36.49967419850091, 'scale_pos_weight': 0.3759592436442205}. Best is trial 16 with value: 0.8025.
# [I 2024-01-31 09:34:01,957] Trial 54 finished with value: 0.796875 and parameters: {'depth': 7, 'learning_rate': 0.16973198779151566, 'random_strength': 18, 'bagging_temperature': 0.3372905434908189, 'l2_leaf_reg': 47.787674477758046, 'scale_pos_weight': 1.0899328250876779}. Best is trial 16 with value: 0.8025.
# [I 2024-01-31 09:34:03,009] Trial 55 finished with value: 0.789375 and parameters: {'depth': 6, 'learning_rate': 0.2320019315250667, 'random_strength': 20, 'bagging_temperature': 0.2236358855923001, 'l2_leaf_reg': 57.31221041192636, 'scale_pos_weight': 1.5121519485402664}. Best is trial 16 with value: 0.8025.
# [I 2024-01-31 09:34:04,035] Trial 56 finished with value: 0.801875 and parameters: {'depth': 5, 'learning_rate': 0.21476562205597455, 'random_strength': 18, 'bagging_temperature': 0.2563460539423138, 'l2_leaf_reg': 33.227626197235935, 'scale_pos_weight': 0.7579140307819802}. Best is trial 16 with value: 0.8025.
# [I 2024-01-31 09:34:04,939] Trial 57 finished with value: 0.65875 and parameters: {'depth': 5, 'learning_rate': 0.2118930823917308, 'random_strength': 18, 'bagging_temperature': 0.2636476873686636, 'l2_leaf_reg': 25.14294426618939, 'scale_pos_weight': 0.10303695465979379}. Best is trial 16 with value: 0.8025.
# [I 2024-01-31 09:34:05,756] Trial 58 finished with value: 0.79 and parameters: {'depth': 5, 'learning_rate': 0.2703812814030722, 'random_strength': 16, 'bagging_temperature': 0.21895937774529312, 'l2_leaf_reg': 33.67388716156315, 'scale_pos_weight': 1.2645894163661695}. Best is trial 16 with value: 0.8025.
# [I 2024-01-31 09:34:06,776] Trial 59 finished with value: 0.7825 and parameters: {'depth': 5, 'learning_rate': 0.22295981232521758, 'random_strength': 16, 'bagging_temperature': 0.31946037728257803, 'l2_leaf_reg': 38.5048761095665, 'scale_pos_weight': 0.46338795614763617}. Best is trial 16 with value: 0.8025.
# [I 2024-01-31 09:34:08,535] Trial 60 finished with value: 0.764375 and parameters: {'depth': 9, 'learning_rate': 0.15264561137601512, 'random_strength': 17, 'bagging_temperature': 0.26005895406456336, 'l2_leaf_reg': 41.52623543486281, 'scale_pos_weight': 2.1663610266444797}. Best is trial 16 with value: 0.8025.
# [I 2024-01-31 09:34:09,764] Trial 61 finished with value: 0.791875 and parameters: {'depth': 6, 'learning_rate': 0.19568334976358084, 'random_strength': 19, 'bagging_temperature': 0.30770051700576684, 'l2_leaf_reg': 46.186195225344775, 'scale_pos_weight': 0.720313879352727}. Best is trial 16 with value: 0.8025.
# [I 2024-01-31 09:34:11,057] Trial 62 finished with value: 0.8 and parameters: {'depth': 5, 'learning_rate': 0.18515912702568554, 'random_strength': 19, 'bagging_temperature': 0.39132172884339456, 'l2_leaf_reg': 49.660924257938504, 'scale_pos_weight': 0.8374108557358644}. Best is trial 16 with value: 0.8025.
# [I 2024-01-31 09:34:12,396] Trial 63 finished with value: 0.793125 and parameters: {'depth': 5, 'learning_rate': 0.18393018933619512, 'random_strength': 18, 'bagging_temperature': 0.3817131309340305, 'l2_leaf_reg': 42.9384163352284, 'scale_pos_weight': 1.6051484545433108}. Best is trial 16 with value: 0.8025.
# [I 2024-01-31 09:34:13,725] Trial 64 finished with value: 0.7925 and parameters: {'depth': 5, 'learning_rate': 0.16142726678044142, 'random_strength': 20, 'bagging_temperature': 0.27626143731282576, 'l2_leaf_reg': 49.04583677694667, 'scale_pos_weight': 1.19111632553071}. Best is trial 16 with value: 0.8025.
# [I 2024-01-31 09:34:14,739] Trial 65 finished with value: 0.79875 and parameters: {'depth': 4, 'learning_rate': 0.19871785115394958, 'random_strength': 15, 'bagging_temperature': 0.2351020381126966, 'l2_leaf_reg': 54.60209122726827, 'scale_pos_weight': 0.762026493026444}. Best is trial 16 with value: 0.8025.
# [I 2024-01-31 09:34:15,657] Trial 66 finished with value: 0.74875 and parameters: {'depth': 5, 'learning_rate': 0.21376818122209634, 'random_strength': 17, 'bagging_temperature': 0.1702627815510916, 'l2_leaf_reg': 30.01894380012093, 'scale_pos_weight': 0.29759456583393373}. Best is trial 16 with value: 0.8025.
# [I 2024-01-31 09:34:16,789] Trial 67 finished with value: 0.780625 and parameters: {'depth': 5, 'learning_rate': 0.2037296666525405, 'random_strength': 19, 'bagging_temperature': 0.34232738677789415, 'l2_leaf_reg': 45.11408382173213, 'scale_pos_weight': 1.8054974231973895}. Best is trial 16 with value: 0.8025.
# [I 2024-01-31 09:34:18,232] Trial 68 finished with value: 0.79625 and parameters: {'depth': 4, 'learning_rate': 0.1871047535489765, 'random_strength': 1, 'bagging_temperature': 0.21965628089110753, 'l2_leaf_reg': 49.04614985005468, 'scale_pos_weight': 1.0506368219962061}. Best is trial 16 with value: 0.8025.
# [I 2024-01-31 09:34:19,724] Trial 69 finished with value: 0.763125 and parameters: {'depth': 5, 'learning_rate': 0.16479942177471535, 'random_strength': 13, 'bagging_temperature': 0.3214030951887658, 'l2_leaf_reg': 40.98578255201302, 'scale_pos_weight': 2.5464004268748512}. Best is trial 16 with value: 0.8025.
# [I 2024-01-31 09:34:22,072] Trial 70 finished with value: 0.753125 and parameters: {'depth': 4, 'learning_rate': 0.1493797865261438, 'random_strength': 20, 'bagging_temperature': 0.14625862050309707, 'l2_leaf_reg': 51.96808812058586, 'scale_pos_weight': 3.05925653813427}. Best is trial 16 with value: 0.8025.
# [I 2024-01-31 09:34:23,334] Trial 71 finished with value: 0.795625 and parameters: {'depth': 6, 'learning_rate': 0.20035582599113616, 'random_strength': 19, 'bagging_temperature': 0.384451657133868, 'l2_leaf_reg': 51.655323552585514, 'scale_pos_weight': 0.8412380495530227}. Best is trial 16 with value: 0.8025.
# [I 2024-01-31 09:34:24,672] Trial 72 finished with value: 0.78625 and parameters: {'depth': 6, 'learning_rate': 0.17653106192122256, 'random_strength': 17, 'bagging_temperature': 0.4551312114750253, 'l2_leaf_reg': 60.2869656854279, 'scale_pos_weight': 1.497493199446045}. Best is trial 16 with value: 0.8025.
# [I 2024-01-31 09:34:25,977] Trial 73 finished with value: 0.793125 and parameters: {'depth': 5, 'learning_rate': 0.18859773788672834, 'random_strength': 18, 'bagging_temperature': 0.2859492181678532, 'l2_leaf_reg': 54.09241225645452, 'scale_pos_weight': 0.859645851576172}. Best is trial 16 with value: 0.8025.
# [I 2024-01-31 09:34:26,997] Trial 74 finished with value: 0.77125 and parameters: {'depth': 7, 'learning_rate': 0.2103032294489403, 'random_strength': 16, 'bagging_temperature': 0.25204844159883255, 'l2_leaf_reg': 47.75744645587089, 'scale_pos_weight': 0.39915409062909857}. Best is trial 16 with value: 0.8025.
# [I 2024-01-31 09:34:27,895] Trial 75 finished with value: 0.79875 and parameters: {'depth': 5, 'learning_rate': 0.2190083518852227, 'random_strength': 15, 'bagging_temperature': 0.20770488373834622, 'l2_leaf_reg': 43.519533216243595, 'scale_pos_weight': 1.2417817681258791}. Best is trial 16 with value: 0.8025.
# [I 2024-01-31 09:34:29,069] Trial 76 finished with value: 0.793125 and parameters: {'depth': 6, 'learning_rate': 0.1671136997056081, 'random_strength': 20, 'bagging_temperature': 0.35853046740490574, 'l2_leaf_reg': 55.62405543427438, 'scale_pos_weight': 0.6784887522096448}. Best is trial 16 with value: 0.8025.
# [I 2024-01-31 09:34:30,149] Trial 77 finished with value: 0.79375 and parameters: {'depth': 5, 'learning_rate': 0.1810667923240003, 'random_strength': 18, 'bagging_temperature': 0.18252323847282953, 'l2_leaf_reg': 50.14554530773765, 'scale_pos_weight': 1.0443818615035023}. Best is trial 16 with value: 0.8025.
# [I 2024-01-31 09:34:30,992] Trial 78 finished with value: 0.76625 and parameters: {'depth': 5, 'learning_rate': 0.19489787620363558, 'random_strength': 19, 'bagging_temperature': 0.30776284278348204, 'l2_leaf_reg': 39.15385731089707, 'scale_pos_weight': 2.345952330881551}. Best is trial 16 with value: 0.8025.
# [I 2024-01-31 09:34:31,989] Trial 79 finished with value: 0.789375 and parameters: {'depth': 6, 'learning_rate': 0.2060558106395558, 'random_strength': 14, 'bagging_temperature': 0.24791653420629958, 'l2_leaf_reg': 45.0148554554827, 'scale_pos_weight': 1.6166836448638149}. Best is trial 16 with value: 0.8025.
# [I 2024-01-31 09:34:32,946] Trial 80 finished with value: 0.780625 and parameters: {'depth': 4, 'learning_rate': 0.22818730762586262, 'random_strength': 17, 'bagging_temperature': 0.17932249598108319, 'l2_leaf_reg': 58.229908538078064, 'scale_pos_weight': 1.9327957041119905}. Best is trial 16 with value: 0.8025.
# [I 2024-01-31 09:34:33,750] Trial 81 finished with value: 0.78875 and parameters: {'depth': 4, 'learning_rate': 0.19511977006816442, 'random_strength': 15, 'bagging_temperature': 0.23525007907440526, 'l2_leaf_reg': 53.68127783715826, 'scale_pos_weight': 0.6604343806900255}. Best is trial 16 with value: 0.8025.
# [I 2024-01-31 09:34:34,819] Trial 82 finished with value: 0.80125 and parameters: {'depth': 4, 'learning_rate': 0.20033823396051118, 'random_strength': 16, 'bagging_temperature': 0.24043574384883296, 'l2_leaf_reg': 51.050986651517334, 'scale_pos_weight': 0.8433376679024177}. Best is trial 16 with value: 0.8025.
# [I 2024-01-31 09:34:37,013] Trial 83 finished with value: 0.73125 and parameters: {'depth': 10, 'learning_rate': 0.216491346763251, 'random_strength': 16, 'bagging_temperature': 0.28948088078459583, 'l2_leaf_reg': 50.0339549674582, 'scale_pos_weight': 0.26143538914978903}. Best is trial 16 with value: 0.8025.
# [I 2024-01-31 09:34:38,307] Trial 84 finished with value: 0.79375 and parameters: {'depth': 5, 'learning_rate': 0.15676887187356325, 'random_strength': 18, 'bagging_temperature': 0.206305508663638, 'l2_leaf_reg': 47.528975799666185, 'scale_pos_weight': 0.9870026746614623}. Best is trial 16 with value: 0.8025.
# [I 2024-01-31 09:34:39,335] Trial 85 finished with value: 0.801875 and parameters: {'depth': 4, 'learning_rate': 0.1882806034178287, 'random_strength': 13, 'bagging_temperature': 0.13415124975813203, 'l2_leaf_reg': 44.53798799174829, 'scale_pos_weight': 1.4149242364418981}. Best is trial 16 with value: 0.8025.
# [I 2024-01-31 09:34:40,779] Trial 86 finished with value: 0.8 and parameters: {'depth': 4, 'learning_rate': 0.17223490162881355, 'random_strength': 13, 'bagging_temperature': 0.12519643851090162, 'l2_leaf_reg': 43.48353950803064, 'scale_pos_weight': 1.3949365407543488}. Best is trial 16 with value: 0.8025.
# [I 2024-01-31 09:34:41,945] Trial 87 finished with value: 0.799375 and parameters: {'depth': 4, 'learning_rate': 0.17603512143691682, 'random_strength': 14, 'bagging_temperature': 0.12321709506981132, 'l2_leaf_reg': 41.43449701897194, 'scale_pos_weight': 1.2534072448753015}. Best is trial 16 with value: 0.8025.
# [I 2024-01-31 09:34:43,204] Trial 88 finished with value: 0.78625 and parameters: {'depth': 4, 'learning_rate': 0.18711024101310392, 'random_strength': 14, 'bagging_temperature': 0.16243253358092424, 'l2_leaf_reg': 44.55195498092626, 'scale_pos_weight': 1.8299132066585442}. Best is trial 16 with value: 0.8025.
# [I 2024-01-31 09:34:44,257] Trial 89 finished with value: 0.786875 and parameters: {'depth': 4, 'learning_rate': 0.1368416927690771, 'random_strength': 13, 'bagging_temperature': 0.08892555993745077, 'l2_leaf_reg': 36.62985548161137, 'scale_pos_weight': 0.5707116265175634}. Best is trial 16 with value: 0.8025.
# [I 2024-01-31 09:34:45,699] Trial 90 finished with value: 0.793125 and parameters: {'depth': 4, 'learning_rate': 0.17916937837826238, 'random_strength': 11, 'bagging_temperature': 0.1412677962588058, 'l2_leaf_reg': 56.373799231235054, 'scale_pos_weight': 1.4038430682163392}. Best is trial 16 with value: 0.8025.
# [I 2024-01-31 09:34:47,301] Trial 91 finished with value: 0.80125 and parameters: {'depth': 4, 'learning_rate': 0.17184193930405278, 'random_strength': 14, 'bagging_temperature': 0.13252755967346452, 'l2_leaf_reg': 41.233284068244174, 'scale_pos_weight': 1.1439610201761419}. Best is trial 16 with value: 0.8025.
# [I 2024-01-31 09:34:48,833] Trial 92 finished with value: 0.79625 and parameters: {'depth': 4, 'learning_rate': 0.1690249354236701, 'random_strength': 15, 'bagging_temperature': 0.12043666342996295, 'l2_leaf_reg': 43.110388451362745, 'scale_pos_weight': 1.0899892580582047}. Best is trial 16 with value: 0.8025.
# [I 2024-01-31 09:34:50,597] Trial 93 finished with value: 0.758125 and parameters: {'depth': 4, 'learning_rate': 0.1529357355094362, 'random_strength': 13, 'bagging_temperature': 0.08614310961100474, 'l2_leaf_reg': 40.338200886916624, 'scale_pos_weight': 0.31813215167147524}. Best is trial 16 with value: 0.8025.
# [I 2024-01-31 09:34:52,163] Trial 94 finished with value: 0.800625 and parameters: {'depth': 4, 'learning_rate': 0.15859646579465791, 'random_strength': 12, 'bagging_temperature': 0.031608037900407365, 'l2_leaf_reg': 47.750842001109724, 'scale_pos_weight': 1.5451943671450945}. Best is trial 16 with value: 0.8025.
# [I 2024-01-31 09:34:53,751] Trial 95 finished with value: 0.806875 and parameters: {'depth': 4, 'learning_rate': 0.1601235461987972, 'random_strength': 11, 'bagging_temperature': 0.07005632845794357, 'l2_leaf_reg': 47.69342484004643, 'scale_pos_weight': 0.8697900205554263}. Best is trial 95 with value: 0.806875.
# [I 2024-01-31 09:34:54,912] Trial 96 finished with value: 0.775 and parameters: {'depth': 4, 'learning_rate': 0.14622703451364694, 'random_strength': 12, 'bagging_temperature': 0.03202247659176782, 'l2_leaf_reg': 47.15028445062016, 'scale_pos_weight': 2.1568484306101827}. Best is trial 95 with value: 0.806875.
# [I 2024-01-31 09:34:56,250] Trial 97 finished with value: 0.778125 and parameters: {'depth': 4, 'learning_rate': 0.15841698367761975, 'random_strength': 11, 'bagging_temperature': 0.07837760205700768, 'l2_leaf_reg': 51.528339547367196, 'scale_pos_weight': 0.5291690864771792}. Best is trial 95 with value: 0.806875.
# [I 2024-01-31 09:34:57,565] Trial 98 finished with value: 0.788125 and parameters: {'depth': 4, 'learning_rate': 0.14111736224030336, 'random_strength': 9, 'bagging_temperature': 0.1057860457236076, 'l2_leaf_reg': 48.10983898682478, 'scale_pos_weight': 1.644999741353665}. Best is trial 95 with value: 0.806875.
# [I 2024-01-31 09:34:59,510] Trial 99 finished with value: 0.79125 and parameters: {'depth': 4, 'learning_rate': 0.1617625064173952, 'random_strength': 10, 'bagging_temperature': 0.04041589412705365, 'l2_leaf_reg': 38.16186919228744, 'scale_pos_weight': 1.1152208238790904}. Best is trial 95 with value: 0.806875.
# [I 2024-01-31 09:35:02,986] A new study created in memory with name: no-name-7a66e478-7472-470a-84d9-6b00604dab1e
# [I 2024-01-31 09:35:03,987] Trial 0 finished with value: 0.768125 and parameters: {'depth': 4, 'learning_rate': 0.2253280167173051, 'random_strength': 7, 'bagging_temperature': 0.33627058560308376, 'l2_leaf_reg': 59.18954034831705, 'scale_pos_weight': 0.4392782255773644}. Best is trial 0 with value: 0.768125.
# [I 2024-01-31 09:35:05,865] Trial 1 finished with value: 0.6875 and parameters: {'depth': 8, 'learning_rate': 0.2409138064665333, 'random_strength': 17, 'bagging_temperature': 0.6964298022462414, 'l2_leaf_reg': 87.09537858771688, 'scale_pos_weight': 8.922323545400332}. Best is trial 0 with value: 0.768125.
# [I 2024-01-31 09:35:08,916] Trial 2 finished with value: 0.685 and parameters: {'depth': 9, 'learning_rate': 0.05838933736067938, 'random_strength': 1, 'bagging_temperature': 0.3860810228291226, 'l2_leaf_reg': 44.586979117273366, 'scale_pos_weight': 9.438775226011568}. Best is trial 0 with value: 0.768125.
# [I 2024-01-31 09:35:09,928] Trial 3 finished with value: 0.69125 and parameters: {'depth': 6, 'learning_rate': 0.14917716017647734, 'random_strength': 17, 'bagging_temperature': 0.49572387811454677, 'l2_leaf_reg': 20.1275430295927, 'scale_pos_weight': 8.684356464852275}. Best is trial 0 with value: 0.768125.
# [I 2024-01-31 09:35:10,670] Trial 4 finished with value: 0.681875 and parameters: {'depth': 7, 'learning_rate': 0.19272620369550703, 'random_strength': 7, 'bagging_temperature': 0.12738639718183142, 'l2_leaf_reg': 43.59323465764492, 'scale_pos_weight': 8.796015583231073}. Best is trial 0 with value: 0.768125.
# [I 2024-01-31 09:35:13,860] Trial 5 finished with value: 0.74875 and parameters: {'depth': 7, 'learning_rate': 0.05723215367865677, 'random_strength': 9, 'bagging_temperature': 0.5021702525578976, 'l2_leaf_reg': 52.643353312752524, 'scale_pos_weight': 3.0775983034426955}. Best is trial 0 with value: 0.768125.
# [I 2024-01-31 09:35:21,457] Trial 6 finished with value: 0.739375 and parameters: {'depth': 9, 'learning_rate': 0.0186136528977894, 'random_strength': 14, 'bagging_temperature': 0.7241007531710657, 'l2_leaf_reg': 6.14938333892379, 'scale_pos_weight': 4.195137196624385}. Best is trial 0 with value: 0.768125.
# [I 2024-01-31 09:35:22,288] Trial 7 finished with value: 0.685625 and parameters: {'depth': 4, 'learning_rate': 0.14858917272592023, 'random_strength': 9, 'bagging_temperature': 0.4348030089695373, 'l2_leaf_reg': 17.482774481231445, 'scale_pos_weight': 9.166886345099389}. Best is trial 0 with value: 0.768125.
# [I 2024-01-31 09:35:23,144] Trial 8 finished with value: 0.70875 and parameters: {'depth': 6, 'learning_rate': 0.22445715880587144, 'random_strength': 16, 'bagging_temperature': 0.6795311893587784, 'l2_leaf_reg': 16.97544670850762, 'scale_pos_weight': 7.988928088388244}. Best is trial 0 with value: 0.768125.
# [I 2024-01-31 09:35:24,341] Trial 9 finished with value: 0.68125 and parameters: {'depth': 6, 'learning_rate': 0.23778674007657735, 'random_strength': 10, 'bagging_temperature': 0.8953081062520917, 'l2_leaf_reg': 83.29803719194324, 'scale_pos_weight': 9.61925853733369}. Best is trial 0 with value: 0.768125.
# [I 2024-01-31 09:35:25,236] Trial 10 finished with value: 0.76625 and parameters: {'depth': 5, 'learning_rate': 0.2963738546766833, 'random_strength': 4, 'bagging_temperature': 0.03004130726416926, 'l2_leaf_reg': 99.94842887859627, 'scale_pos_weight': 0.41483227894203045}. Best is trial 0 with value: 0.768125.
# [I 2024-01-31 09:35:26,072] Trial 11 finished with value: 0.703125 and parameters: {'depth': 4, 'learning_rate': 0.2999632582646288, 'random_strength': 4, 'bagging_temperature': 0.0052591282174961895, 'l2_leaf_reg': 95.88202052092313, 'scale_pos_weight': 0.17185069748656004}. Best is trial 0 with value: 0.768125.
# [I 2024-01-31 09:35:26,833] Trial 12 finished with value: 0.71375 and parameters: {'depth': 5, 'learning_rate': 0.29992600256366303, 'random_strength': 4, 'bagging_temperature': 0.20797040360630034, 'l2_leaf_reg': 69.54740070977927, 'scale_pos_weight': 0.18914737393018677}. Best is trial 0 with value: 0.768125.
# [I 2024-01-31 09:35:27,776] Trial 13 finished with value: 0.755625 and parameters: {'depth': 4, 'learning_rate': 0.26070775420261566, 'random_strength': 5, 'bagging_temperature': 0.23292592244640276, 'l2_leaf_reg': 99.96269927426111, 'scale_pos_weight': 1.753962612557583}. Best is trial 0 with value: 0.768125.
# [I 2024-01-31 09:35:28,386] Trial 14 finished with value: 0.76 and parameters: {'depth': 5, 'learning_rate': 0.2776032470213898, 'random_strength': 1, 'bagging_temperature': 0.007684109270249595, 'l2_leaf_reg': 72.23391653836646, 'scale_pos_weight': 1.8452769298199854}. Best is trial 0 with value: 0.768125.
# [I 2024-01-31 09:35:29,648] Trial 15 finished with value: 0.72375 and parameters: {'depth': 5, 'learning_rate': 0.1879751676985347, 'random_strength': 13, 'bagging_temperature': 0.3044339291298909, 'l2_leaf_reg': 62.05524824949305, 'scale_pos_weight': 5.83010048077995}. Best is trial 0 with value: 0.768125.
# [I 2024-01-31 09:35:32,625] Trial 16 finished with value: 0.7725 and parameters: {'depth': 10, 'learning_rate': 0.270143339655173, 'random_strength': 6, 'bagging_temperature': 0.1251253124327497, 'l2_leaf_reg': 86.93769428964002, 'scale_pos_weight': 1.0316047896710767}. Best is trial 16 with value: 0.7725.
# [I 2024-01-31 09:35:35,105] Trial 17 finished with value: 0.76375 and parameters: {'depth': 10, 'learning_rate': 0.25865767140453205, 'random_strength': 7, 'bagging_temperature': 0.3277065199097954, 'l2_leaf_reg': 79.59372511102146, 'scale_pos_weight': 1.758391928831256}. Best is trial 16 with value: 0.7725.
# [I 2024-01-31 09:35:38,828] Trial 18 finished with value: 0.75 and parameters: {'depth': 10, 'learning_rate': 0.20365907185638615, 'random_strength': 13, 'bagging_temperature': 0.12410635112285556, 'l2_leaf_reg': 61.513476202083304, 'scale_pos_weight': 2.865549634117228}. Best is trial 16 with value: 0.7725.
# [I 2024-01-31 09:35:40,653] Trial 19 finished with value: 0.738125 and parameters: {'depth': 8, 'learning_rate': 0.21746512864116807, 'random_strength': 7, 'bagging_temperature': 0.23146023582044248, 'l2_leaf_reg': 87.95836972863673, 'scale_pos_weight': 5.1765658817330324}. Best is trial 16 with value: 0.7725.
# [I 2024-01-31 09:35:41,683] Trial 20 finished with value: 0.78 and parameters: {'depth': 8, 'learning_rate': 0.2620274218604185, 'random_strength': 19, 'bagging_temperature': 0.11345303161205811, 'l2_leaf_reg': 72.51032621683404, 'scale_pos_weight': 1.0526678663001405}. Best is trial 20 with value: 0.78.
# [I 2024-01-31 09:35:43,775] Trial 21 finished with value: 0.776875 and parameters: {'depth': 9, 'learning_rate': 0.2629707527859703, 'random_strength': 20, 'bagging_temperature': 0.12348362437711687, 'l2_leaf_reg': 72.34463559057086, 'scale_pos_weight': 1.1011397885604293}. Best is trial 20 with value: 0.78.
# [I 2024-01-31 09:35:45,941] Trial 22 finished with value: 0.7675 and parameters: {'depth': 9, 'learning_rate': 0.2654752836020329, 'random_strength': 20, 'bagging_temperature': 0.12241471204848031, 'l2_leaf_reg': 74.91362062499483, 'scale_pos_weight': 1.3128549233649203}. Best is trial 20 with value: 0.78.
# [I 2024-01-31 09:35:47,008] Trial 23 finished with value: 0.778125 and parameters: {'depth': 8, 'learning_rate': 0.2745079127810328, 'random_strength': 20, 'bagging_temperature': 0.09513904129346991, 'l2_leaf_reg': 78.90202518096356, 'scale_pos_weight': 1.1148502790642776}. Best is trial 20 with value: 0.78.
# [I 2024-01-31 09:35:48,382] Trial 24 finished with value: 0.750625 and parameters: {'depth': 8, 'learning_rate': 0.2445570595932969, 'random_strength': 20, 'bagging_temperature': 0.0721592465496817, 'l2_leaf_reg': 70.06039437682057, 'scale_pos_weight': 2.5584936476583513}. Best is trial 20 with value: 0.78.
# [I 2024-01-31 09:35:49,382] Trial 25 finished with value: 0.776875 and parameters: {'depth': 7, 'learning_rate': 0.2829428172338466, 'random_strength': 19, 'bagging_temperature': 0.19409718590452935, 'l2_leaf_reg': 79.38652800435203, 'scale_pos_weight': 1.1573675834562853}. Best is trial 20 with value: 0.78.
# [I 2024-01-31 09:35:50,610] Trial 26 finished with value: 0.736875 and parameters: {'depth': 8, 'learning_rate': 0.25221418235227855, 'random_strength': 18, 'bagging_temperature': 0.06960550950750702, 'l2_leaf_reg': 67.11180959308172, 'scale_pos_weight': 3.6380386897594876}. Best is trial 20 with value: 0.78.
# [I 2024-01-31 09:35:52,174] Trial 27 finished with value: 0.75375 and parameters: {'depth': 9, 'learning_rate': 0.2758347360823693, 'random_strength': 15, 'bagging_temperature': 0.18838326458385846, 'l2_leaf_reg': 74.4330471138336, 'scale_pos_weight': 2.227865158982362}. Best is trial 20 with value: 0.78.
# [I 2024-01-31 09:35:53,142] Trial 28 finished with value: 0.78375 and parameters: {'depth': 8, 'learning_rate': 0.2809571477407597, 'random_strength': 18, 'bagging_temperature': 0.29363572981284985, 'l2_leaf_reg': 79.39213873767993, 'scale_pos_weight': 1.0076025600192189}. Best is trial 28 with value: 0.78375.
# [I 2024-01-31 09:35:54,318] Trial 29 finished with value: 0.78125 and parameters: {'depth': 8, 'learning_rate': 0.23228013963814362, 'random_strength': 18, 'bagging_temperature': 0.27916602266468304, 'l2_leaf_reg': 92.73098429200574, 'scale_pos_weight': 0.7787090811998085}. Best is trial 28 with value: 0.78375.
# [I 2024-01-31 09:35:55,224] Trial 30 finished with value: 0.77625 and parameters: {'depth': 7, 'learning_rate': 0.22822784694700327, 'random_strength': 18, 'bagging_temperature': 0.2856772828400933, 'l2_leaf_reg': 89.88874887303248, 'scale_pos_weight': 0.5701843924442578}. Best is trial 28 with value: 0.78375.
# [I 2024-01-31 09:35:56,646] Trial 31 finished with value: 0.78 and parameters: {'depth': 8, 'learning_rate': 0.24310266556240484, 'random_strength': 18, 'bagging_temperature': 0.2747276857629827, 'l2_leaf_reg': 93.38842220104671, 'scale_pos_weight': 0.8112063396068296}. Best is trial 28 with value: 0.78375.
# [I 2024-01-31 09:35:58,199] Trial 32 finished with value: 0.760625 and parameters: {'depth': 8, 'learning_rate': 0.2439972514415421, 'random_strength': 17, 'bagging_temperature': 0.35651904931849066, 'l2_leaf_reg': 92.30830969478605, 'scale_pos_weight': 1.9931170852370101}. Best is trial 28 with value: 0.78375.
# [I 2024-01-31 09:35:59,463] Trial 33 finished with value: 0.77625 and parameters: {'depth': 8, 'learning_rate': 0.21791047251476306, 'random_strength': 15, 'bagging_temperature': 0.27217562591193123, 'l2_leaf_reg': 93.10351889864516, 'scale_pos_weight': 0.5561327830203711}. Best is trial 28 with value: 0.78375.
# [I 2024-01-31 09:36:00,536] Trial 34 finished with value: 0.754375 and parameters: {'depth': 7, 'learning_rate': 0.2413078108328647, 'random_strength': 18, 'bagging_temperature': 0.3908119609568045, 'l2_leaf_reg': 84.51631123158911, 'scale_pos_weight': 2.4423639156226904}. Best is trial 28 with value: 0.78375.
# [I 2024-01-31 09:36:01,673] Trial 35 finished with value: 0.654375 and parameters: {'depth': 8, 'learning_rate': 0.17725719452637317, 'random_strength': 16, 'bagging_temperature': 0.2662877940735751, 'l2_leaf_reg': 91.36396017850862, 'scale_pos_weight': 0.12629402550322755}. Best is trial 28 with value: 0.78375.
# [I 2024-01-31 09:36:03,345] Trial 36 finished with value: 0.763125 and parameters: {'depth': 9, 'learning_rate': 0.2877153706756041, 'random_strength': 12, 'bagging_temperature': 0.34139279147213986, 'l2_leaf_reg': 83.08336940034499, 'scale_pos_weight': 1.6172739310437}. Best is trial 28 with value: 0.78375.
# [I 2024-01-31 09:36:04,983] Trial 37 finished with value: 0.785625 and parameters: {'depth': 7, 'learning_rate': 0.25440530670241474, 'random_strength': 17, 'bagging_temperature': 0.18891263335559438, 'l2_leaf_reg': 94.60576964095628, 'scale_pos_weight': 0.8606154864776314}. Best is trial 37 with value: 0.785625.
# [I 2024-01-31 09:36:06,423] Trial 38 finished with value: 0.765 and parameters: {'depth': 7, 'learning_rate': 0.25689693131670144, 'random_strength': 16, 'bagging_temperature': 0.17293706960408384, 'l2_leaf_reg': 85.61300414300804, 'scale_pos_weight': 1.3361043465905025}. Best is trial 37 with value: 0.785625.
# [I 2024-01-31 09:36:07,269] Trial 39 finished with value: 0.775625 and parameters: {'depth': 6, 'learning_rate': 0.2864077391243166, 'random_strength': 19, 'bagging_temperature': 0.4244394413232577, 'l2_leaf_reg': 54.06904822154579, 'scale_pos_weight': 0.72121507159572}. Best is trial 37 with value: 0.785625.
# [I 2024-01-31 09:36:08,543] Trial 40 finished with value: 0.746875 and parameters: {'depth': 7, 'learning_rate': 0.2072698844726933, 'random_strength': 17, 'bagging_temperature': 0.17988034344165538, 'l2_leaf_reg': 97.65625063967819, 'scale_pos_weight': 3.104130780995093}. Best is trial 37 with value: 0.785625.
# [I 2024-01-31 09:36:10,084] Trial 41 finished with value: 0.781875 and parameters: {'depth': 8, 'learning_rate': 0.23313149419268767, 'random_strength': 19, 'bagging_temperature': 0.24910282256054905, 'l2_leaf_reg': 92.99822471783861, 'scale_pos_weight': 0.7321530150368311}. Best is trial 37 with value: 0.785625.
# [I 2024-01-31 09:36:11,661] Trial 42 finished with value: 0.775 and parameters: {'depth': 8, 'learning_rate': 0.22862623781933553, 'random_strength': 19, 'bagging_temperature': 0.16041906361306751, 'l2_leaf_reg': 87.86883529117388, 'scale_pos_weight': 0.6437652214785726}. Best is trial 37 with value: 0.785625.
# [I 2024-01-31 09:36:12,778] Trial 43 finished with value: 0.7575 and parameters: {'depth': 7, 'learning_rate': 0.23329989579564128, 'random_strength': 17, 'bagging_temperature': 0.24686514335039494, 'l2_leaf_reg': 92.87695331199566, 'scale_pos_weight': 2.2154429175477857}. Best is trial 37 with value: 0.785625.
# [I 2024-01-31 09:36:14,910] Trial 44 finished with value: 0.76625 and parameters: {'depth': 9, 'learning_rate': 0.25240597234643225, 'random_strength': 15, 'bagging_temperature': 0.3223799964597821, 'l2_leaf_reg': 98.6498607651287, 'scale_pos_weight': 1.3712194271663432}. Best is trial 37 with value: 0.785625.
# [I 2024-01-31 09:36:15,697] Trial 45 finished with value: 0.779375 and parameters: {'depth': 7, 'learning_rate': 0.2695968004412163, 'random_strength': 19, 'bagging_temperature': 0.22943702274747027, 'l2_leaf_reg': 81.82295022709127, 'scale_pos_weight': 0.75583493357544}. Best is trial 37 with value: 0.785625.
# [I 2024-01-31 09:36:17,241] Trial 46 finished with value: 0.710625 and parameters: {'depth': 9, 'learning_rate': 0.29039027774615334, 'random_strength': 16, 'bagging_temperature': 0.4805684805591089, 'l2_leaf_reg': 94.68739652780737, 'scale_pos_weight': 0.2095223284431964}. Best is trial 37 with value: 0.785625.
# [I 2024-01-31 09:36:18,091] Trial 47 finished with value: 0.766875 and parameters: {'depth': 6, 'learning_rate': 0.23200951472035394, 'random_strength': 14, 'bagging_temperature': 0.3688058726474963, 'l2_leaf_reg': 79.27270939525121, 'scale_pos_weight': 1.5655589163552932}. Best is trial 37 with value: 0.785625.
# [I 2024-01-31 09:36:19,950] Trial 48 finished with value: 0.761875 and parameters: {'depth': 8, 'learning_rate': 0.13896975346348273, 'random_strength': 11, 'bagging_temperature': 0.30350609015845686, 'l2_leaf_reg': 87.86597984491213, 'scale_pos_weight': 1.9632376319272657}. Best is trial 37 with value: 0.785625.
# [I 2024-01-31 09:36:21,231] Trial 49 finished with value: 0.78125 and parameters: {'depth': 8, 'learning_rate': 0.27548782495049556, 'random_strength': 18, 'bagging_temperature': 0.050639215852947506, 'l2_leaf_reg': 99.8741149452841, 'scale_pos_weight': 0.908790172390703}. Best is trial 37 with value: 0.785625.
# [I 2024-01-31 09:36:22,164] Trial 50 finished with value: 0.759375 and parameters: {'depth': 7, 'learning_rate': 0.280473377485002, 'random_strength': 17, 'bagging_temperature': 0.057844605912246244, 'l2_leaf_reg': 99.96632442931187, 'scale_pos_weight': 0.43582553670960705}. Best is trial 37 with value: 0.785625.
# [I 2024-01-31 09:36:23,388] Trial 51 finished with value: 0.780625 and parameters: {'depth': 8, 'learning_rate': 0.2963175261519201, 'random_strength': 19, 'bagging_temperature': 0.15677435901668982, 'l2_leaf_reg': 96.1796419744939, 'scale_pos_weight': 0.942184874705186}. Best is trial 37 with value: 0.785625.
# [I 2024-01-31 09:36:24,764] Trial 52 finished with value: 0.65875 and parameters: {'depth': 8, 'learning_rate': 0.2965444841908294, 'random_strength': 18, 'bagging_temperature': 0.15994032021132648, 'l2_leaf_reg': 95.80404812627448, 'scale_pos_weight': 0.12959262490963763}. Best is trial 37 with value: 0.785625.
# ...
# [I 2024-01-31 09:43:00,630] Trial 49 finished with value: 0.746875 and parameters: {'depth': 8, 'learning_rate': 0.1356638805868279, 'random_strength': 9, 'bagging_temperature': 0.4492955726306109, 'l2_leaf_reg': 45.042706377858515, 'scale_pos_weight': 2.065982061493863}. Best is trial 19 with value: 0.785.
# [I 2024-01-31 09:43:03,469] Trial 50 finished with value: 0.739375 and parameters: {'depth': 10, 'learning_rate': 0.16238210732470984, 'random_strength': 7, 'bagging_temperature': 0.3490129859514089, 'l2_leaf_reg': 21.87030735879565, 'scale_pos_weight': 3.032133545071625}. Best is trial 19 with value: 0.785.
# [I 2024-01-31 09:43:05,441] Trial 51 finished with value: 0.785 and parameters: {'depth': 9, 'learning_rate': 0.12347325500691014, 'random_strength': 13, 'bagging_temperature': 0.5194812589227282, 'l2_leaf_reg': 38.119513998521754, 'scale_pos_weight': 0.9299943901687724}. Best is trial 19 with value: 0.785.
# [I 2024-01-31 09:43:07,189] Trial 52 finished with value: 0.785 and parameters: {'depth': 9, 'learning_rate': 0.1264297867202067, 'random_strength': 13, 'bagging_temperature': 0.5173841661870265, 'l2_leaf_reg': 34.66884156085565, 'scale_pos_weight': 0.9892769200062851}. Best is trial 19 with value: 0.785.
# [I 2024-01-31 09:43:09,239] Trial 53 finished with value: 0.764375 and parameters: {'depth': 9, 'learning_rate': 0.12676035248542153, 'random_strength': 11, 'bagging_temperature': 0.5236955008950337, 'l2_leaf_reg': 34.20442052199395, 'scale_pos_weight': 0.5006694830424341}. Best is trial 19 with value: 0.785.
# [I 2024-01-31 09:43:11,376] Trial 54 finished with value: 0.76375 and parameters: {'depth': 9, 'learning_rate': 0.14134595716617276, 'random_strength': 13, 'bagging_temperature': 0.6893672983978604, 'l2_leaf_reg': 32.706855850583175, 'scale_pos_weight': 1.56110083566531}. Best is trial 19 with value: 0.785.
# [I 2024-01-31 09:43:14,050] Trial 55 finished with value: 0.77625 and parameters: {'depth': 9, 'learning_rate': 0.08969578173328088, 'random_strength': 12, 'bagging_temperature': 0.5772791629160636, 'l2_leaf_reg': 29.7229169580584, 'scale_pos_weight': 1.0715566321734462}. Best is trial 19 with value: 0.785.
# [I 2024-01-31 09:43:17,415] Trial 56 finished with value: 0.745625 and parameters: {'depth': 10, 'learning_rate': 0.1254586093956426, 'random_strength': 10, 'bagging_temperature': 0.5175362987089815, 'l2_leaf_reg': 48.12858567179245, 'scale_pos_weight': 0.39131574675458913}. Best is trial 19 with value: 0.785.
# [I 2024-01-31 09:43:21,427] Trial 57 finished with value: 0.761875 and parameters: {'depth': 10, 'learning_rate': 0.11083713047523398, 'random_strength': 14, 'bagging_temperature': 0.4669768571095068, 'l2_leaf_reg': 36.69893895690753, 'scale_pos_weight': 1.8337854242563174}. Best is trial 19 with value: 0.785.
# [I 2024-01-31 09:43:23,609] Trial 58 finished with value: 0.775 and parameters: {'depth': 9, 'learning_rate': 0.13386310241535265, 'random_strength': 13, 'bagging_temperature': 0.42067843889173806, 'l2_leaf_reg': 42.4643064571963, 'scale_pos_weight': 1.010623668662617}. Best is trial 19 with value: 0.785.
# [I 2024-01-31 09:43:24,859] Trial 59 finished with value: 0.670625 and parameters: {'depth': 8, 'learning_rate': 0.1458122546287727, 'random_strength': 10, 'bagging_temperature': 0.644066819916471, 'l2_leaf_reg': 13.093418772403009, 'scale_pos_weight': 0.17280159514349858}. Best is trial 19 with value: 0.785.
# [I 2024-01-31 09:43:26,524] Trial 60 finished with value: 0.743125 and parameters: {'depth': 8, 'learning_rate': 0.10481512795987767, 'random_strength': 12, 'bagging_temperature': 0.699660060261866, 'l2_leaf_reg': 27.959293158810905, 'scale_pos_weight': 2.3008070610906524}. Best is trial 19 with value: 0.785.
# [I 2024-01-31 09:43:27,424] Trial 61 finished with value: 0.7725 and parameters: {'depth': 7, 'learning_rate': 0.15259033913983397, 'random_strength': 14, 'bagging_temperature': 0.48199288241242827, 'l2_leaf_reg': 38.18852957252843, 'scale_pos_weight': 1.15514976399913}. Best is trial 19 with value: 0.785.
# [I 2024-01-31 09:43:29,389] Trial 62 finished with value: 0.778125 and parameters: {'depth': 9, 'learning_rate': 0.12591066547266586, 'random_strength': 11, 'bagging_temperature': 0.5404193717429306, 'l2_leaf_reg': 42.108745925224405, 'scale_pos_weight': 0.8319604709747128}. Best is trial 19 with value: 0.785.
# [I 2024-01-31 09:43:30,240] Trial 63 finished with value: 0.775 and parameters: {'depth': 7, 'learning_rate': 0.15973932398494461, 'random_strength': 15, 'bagging_temperature': 0.4259801794572279, 'l2_leaf_reg': 23.66072053935764, 'scale_pos_weight': 1.3576445374132975}. Best is trial 19 with value: 0.785.
# [I 2024-01-31 09:43:31,554] Trial 64 finished with value: 0.74625 and parameters: {'depth': 8, 'learning_rate': 0.12078268964746182, 'random_strength': 19, 'bagging_temperature': 0.4062972287033368, 'l2_leaf_reg': 30.57579736954273, 'scale_pos_weight': 0.40309900042871505}. Best is trial 19 with value: 0.785.
# [I 2024-01-31 09:43:32,561] Trial 65 finished with value: 0.76125 and parameters: {'depth': 6, 'learning_rate': 0.14124048379981502, 'random_strength': 12, 'bagging_temperature': 0.48523854441912745, 'l2_leaf_reg': 48.37867248477785, 'scale_pos_weight': 1.7641020430252867}. Best is trial 19 with value: 0.785.
# [I 2024-01-31 09:43:34,618] Trial 66 finished with value: 0.7775 and parameters: {'depth': 9, 'learning_rate': 0.154312152770814, 'random_strength': 3, 'bagging_temperature': 0.3614105287781088, 'l2_leaf_reg': 34.896130641723275, 'scale_pos_weight': 0.9717652316498194}. Best is trial 19 with value: 0.785.
# [I 2024-01-31 09:43:35,745] Trial 67 finished with value: 0.773125 and parameters: {'depth': 6, 'learning_rate': 0.13534560494209005, 'random_strength': 14, 'bagging_temperature': 0.5621303628803227, 'l2_leaf_reg': 44.30513294605454, 'scale_pos_weight': 0.6078603846805766}. Best is trial 19 with value: 0.785.
# [I 2024-01-31 09:43:36,971] Trial 68 finished with value: 0.745 and parameters: {'depth': 7, 'learning_rate': 0.17327523162426586, 'random_strength': 9, 'bagging_temperature': 0.4526592507371264, 'l2_leaf_reg': 39.60366973781426, 'scale_pos_weight': 2.0973905763978054}. Best is trial 19 with value: 0.785.
# [I 2024-01-31 09:43:38,104] Trial 69 finished with value: 0.76 and parameters: {'depth': 6, 'learning_rate': 0.14518217395072683, 'random_strength': 13, 'bagging_temperature': 0.4984397254121078, 'l2_leaf_reg': 52.87720646413813, 'scale_pos_weight': 1.4828147310117061}. Best is trial 19 with value: 0.785.
# [I 2024-01-31 09:43:39,547] Trial 70 finished with value: 0.776875 and parameters: {'depth': 8, 'learning_rate': 0.11967460586852827, 'random_strength': 15, 'bagging_temperature': 0.5920443582338231, 'l2_leaf_reg': 46.961245012363, 'scale_pos_weight': 1.180073418742409}. Best is trial 19 with value: 0.785.
# [I 2024-01-31 09:43:41,454] Trial 71 finished with value: 0.77875 and parameters: {'depth': 4, 'learning_rate': 0.1158146620381095, 'random_strength': 16, 'bagging_temperature': 0.6504025277204968, 'l2_leaf_reg': 41.501253392328564, 'scale_pos_weight': 0.815289105996134}. Best is trial 19 with value: 0.785.
# [I 2024-01-31 09:43:42,469] Trial 72 finished with value: 0.780625 and parameters: {'depth': 5, 'learning_rate': 0.1311848777380643, 'random_strength': 18, 'bagging_temperature': 0.604735825062536, 'l2_leaf_reg': 39.80755451254505, 'scale_pos_weight': 0.734072467735271}. Best is trial 19 with value: 0.785.
# [I 2024-01-31 09:43:43,820] Trial 73 finished with value: 0.74 and parameters: {'depth': 5, 'learning_rate': 0.13096651656944988, 'random_strength': 18, 'bagging_temperature': 0.6051978174246385, 'l2_leaf_reg': 32.6851546646963, 'scale_pos_weight': 0.36688408783730664}. Best is trial 19 with value: 0.785.
# [I 2024-01-31 09:43:44,769] Trial 74 finished with value: 0.630625 and parameters: {'depth': 6, 'learning_rate': 0.15217027134659877, 'random_strength': 20, 'bagging_temperature': 0.6723867065550542, 'l2_leaf_reg': 36.89670199755489, 'scale_pos_weight': 0.12956454413324003}. Best is trial 19 with value: 0.785.
# [I 2024-01-31 09:43:46,280] Trial 75 finished with value: 0.763125 and parameters: {'depth': 7, 'learning_rate': 0.1296066045228106, 'random_strength': 18, 'bagging_temperature': 0.5155117026254726, 'l2_leaf_reg': 29.432377071360868, 'scale_pos_weight': 1.571245474355144}. Best is trial 19 with value: 0.785.
# [I 2024-01-31 09:43:47,555] Trial 76 finished with value: 0.7725 and parameters: {'depth': 5, 'learning_rate': 0.09375232295574976, 'random_strength': 17, 'bagging_temperature': 0.5559542483527189, 'l2_leaf_reg': 45.60126883685587, 'scale_pos_weight': 0.6233295814286018}. Best is trial 19 with value: 0.785.
# [I 2024-01-31 09:43:48,732] Trial 77 finished with value: 0.77375 and parameters: {'depth': 6, 'learning_rate': 0.14170153749360578, 'random_strength': 19, 'bagging_temperature': 0.7289146673061676, 'l2_leaf_reg': 38.89089627334514, 'scale_pos_weight': 1.2241037299787765}. Best is trial 19 with value: 0.785.
# [I 2024-01-31 09:43:50,112] Trial 78 finished with value: 0.779375 and parameters: {'depth': 8, 'learning_rate': 0.10429158198077088, 'random_strength': 1, 'bagging_temperature': 0.6294881862364328, 'l2_leaf_reg': 49.99037961945187, 'scale_pos_weight': 0.8988421356383365}. Best is trial 19 with value: 0.785.
# [I 2024-01-31 09:43:53,385] Trial 79 finished with value: 0.759375 and parameters: {'depth': 10, 'learning_rate': 0.1217709238597812, 'random_strength': 12, 'bagging_temperature': 0.7732713368327979, 'l2_leaf_reg': 25.07218838496994, 'scale_pos_weight': 1.879966353199365}. Best is trial 19 with value: 0.785.
# [I 2024-01-31 09:43:54,422] Trial 80 finished with value: 0.7675 and parameters: {'depth': 5, 'learning_rate': 0.11101448561678379, 'random_strength': 11, 'bagging_temperature': 0.5427555694417425, 'l2_leaf_reg': 44.041993638635184, 'scale_pos_weight': 1.400255676902418}. Best is trial 19 with value: 0.785.
# [I 2024-01-31 09:43:55,702] Trial 81 finished with value: 0.785625 and parameters: {'depth': 8, 'learning_rate': 0.10497287859289567, 'random_strength': 6, 'bagging_temperature': 0.6068401211461917, 'l2_leaf_reg': 50.28361221772103, 'scale_pos_weight': 0.9272598000737209}. Best is trial 81 with value: 0.785625.
# [I 2024-01-31 09:43:58,146] Trial 82 finished with value: 0.776875 and parameters: {'depth': 9, 'learning_rate': 0.08236152032927666, 'random_strength': 8, 'bagging_temperature': 0.5862515207402866, 'l2_leaf_reg': 34.902715417353036, 'scale_pos_weight': 0.6624166250832102}. Best is trial 81 with value: 0.785625.
# [I 2024-01-31 09:43:59,889] Trial 83 finished with value: 0.7825 and parameters: {'depth': 7, 'learning_rate': 0.13408136403432935, 'random_strength': 3, 'bagging_temperature': 0.6190666885869323, 'l2_leaf_reg': 40.87895447411789, 'scale_pos_weight': 0.9357714338969455}. Best is trial 81 with value: 0.785625.
# [I 2024-01-31 09:44:01,554] Trial 84 finished with value: 0.785625 and parameters: {'depth': 7, 'learning_rate': 0.09574097741412316, 'random_strength': 5, 'bagging_temperature': 0.6696216377734109, 'l2_leaf_reg': 46.58017812251416, 'scale_pos_weight': 1.0077614870130192}. Best is trial 81 with value: 0.785625.
# [I 2024-01-31 09:44:03,402] Trial 85 finished with value: 0.778125 and parameters: {'depth': 7, 'learning_rate': 0.09574509963475127, 'random_strength': 5, 'bagging_temperature': 0.6578726215979847, 'l2_leaf_reg': 55.28095559052391, 'scale_pos_weight': 1.0951865300432955}. Best is trial 81 with value: 0.785625.
# [I 2024-01-31 09:44:05,234] Trial 86 finished with value: 0.741875 and parameters: {'depth': 8, 'learning_rate': 0.1033959464618151, 'random_strength': 4, 'bagging_temperature': 0.6941518293743054, 'l2_leaf_reg': 50.97917839257426, 'scale_pos_weight': 0.39031751945152404}. Best is trial 81 with value: 0.785625.
# [I 2024-01-31 09:44:06,753] Trial 87 finished with value: 0.7575 and parameters: {'depth': 7, 'learning_rate': 0.11085482430802579, 'random_strength': 4, 'bagging_temperature': 0.7226856546319771, 'l2_leaf_reg': 47.376605626916565, 'scale_pos_weight': 1.6597633733874144}. Best is trial 81 with value: 0.785625.
# [I 2024-01-31 09:44:08,620] Trial 88 finished with value: 0.77 and parameters: {'depth': 8, 'learning_rate': 0.09638159749303019, 'random_strength': 2, 'bagging_temperature': 0.6715872695069242, 'l2_leaf_reg': 52.910919494451804, 'scale_pos_weight': 1.3565072718519804}. Best is trial 81 with value: 0.785625.
# [I 2024-01-31 09:44:10,093] Trial 89 finished with value: 0.77375 and parameters: {'depth': 7, 'learning_rate': 0.12256389705536198, 'random_strength': 6, 'bagging_temperature': 0.7562660172762307, 'l2_leaf_reg': 43.0121555808707, 'scale_pos_weight': 0.8745902754244462}. Best is trial 81 with value: 0.785625.
# [I 2024-01-31 09:44:11,920] Trial 90 finished with value: 0.755625 and parameters: {'depth': 9, 'learning_rate': 0.1389429678015832, 'random_strength': 3, 'bagging_temperature': 0.6374426548036936, 'l2_leaf_reg': 28.208781769476012, 'scale_pos_weight': 1.86821680615664}. Best is trial 81 with value: 0.785625.
# [I 2024-01-31 09:44:13,229] Trial 91 finished with value: 0.78125 and parameters: {'depth': 6, 'learning_rate': 0.13121116365985605, 'random_strength': 5, 'bagging_temperature': 0.5832531064254642, 'l2_leaf_reg': 40.39864022616996, 'scale_pos_weight': 0.6536675670650398}. Best is trial 81 with value: 0.785625.
# [I 2024-01-31 09:44:14,598] Trial 92 finished with value: 0.770625 and parameters: {'depth': 6, 'learning_rate': 0.11659391373034093, 'random_strength': 5, 'bagging_temperature': 0.6033926427844232, 'l2_leaf_reg': 46.355391218288815, 'scale_pos_weight': 0.5097105033260397}. Best is trial 81 with value: 0.785625.
# [I 2024-01-31 09:44:15,950] Trial 93 finished with value: 0.783125 and parameters: {'depth': 7, 'learning_rate': 0.10674374501732291, 'random_strength': 2, 'bagging_temperature': 0.6223399820926713, 'l2_leaf_reg': 41.098056374916915, 'scale_pos_weight': 1.0170501865803403}. Best is trial 81 with value: 0.785625.
# [I 2024-01-31 09:44:17,209] Trial 94 finished with value: 0.77375 and parameters: {'depth': 7, 'learning_rate': 0.10469201434699175, 'random_strength': 2, 'bagging_temperature': 0.6237163700816545, 'l2_leaf_reg': 36.74189840870082, 'scale_pos_weight': 0.9911335939377864}. Best is trial 81 with value: 0.785625.
# [I 2024-01-31 09:44:18,318] Trial 95 finished with value: 0.713125 and parameters: {'depth': 6, 'learning_rate': 0.1300974780984173, 'random_strength': 6, 'bagging_temperature': 0.5858489989146191, 'l2_leaf_reg': 41.17820896173829, 'scale_pos_weight': 0.2630334242956819}. Best is trial 81 with value: 0.785625.
# [I 2024-01-31 09:44:19,320] Trial 96 finished with value: 0.78125 and parameters: {'depth': 7, 'learning_rate': 0.14761570080901734, 'random_strength': 2, 'bagging_temperature': 0.5612322073815965, 'l2_leaf_reg': 35.07411229868242, 'scale_pos_weight': 1.2778457325947898}. Best is trial 81 with value: 0.785625.
# [I 2024-01-31 09:44:20,734] Trial 97 finished with value: 0.77625 and parameters: {'depth': 7, 'learning_rate': 0.08620190579979639, 'random_strength': 3, 'bagging_temperature': 0.5701587337122501, 'l2_leaf_reg': 31.956266591971257, 'scale_pos_weight': 1.2583845080347351}. Best is trial 81 with value: 0.785625.
# [I 2024-01-31 09:44:21,789] Trial 98 finished with value: 0.765625 and parameters: {'depth': 7, 'learning_rate': 0.14890713680401757, 'random_strength': 2, 'bagging_temperature': 0.6597678066061871, 'l2_leaf_reg': 35.30581784555567, 'scale_pos_weight': 1.633001010172893}. Best is trial 81 with value: 0.785625.
# [I 2024-01-31 09:44:23,107] Trial 99 finished with value: 0.620625 and parameters: {'depth': 7, 'learning_rate': 0.10664991231248501, 'random_strength': 1, 'bagging_temperature': 0.5466610428760508, 'l2_leaf_reg': 37.183784735472564, 'scale_pos_weight': 0.10116303360886991}. Best is trial 81 with value: 0.785625.

# %% [markdown]
# - Catboost平均スコア

# %%
# 全フォールドの平均スコアを計算
cb_average_score = sum(cb_fold_scores) / n_splits
print(f"CatBoost Average accuracy across all folds: {cb_average_score:.4f}")

cb_average_conf = sum(cb_conf_scores) / n_splits
print(f"CatBoost Average conf-matrix across all folds: {cb_average_conf}")
# Out:
# CatBoost Average accuracy across all folds: 0.7782
# CatBoost Average conf-matrix across all folds: [[633.2 180. ]
#  [174.8 612. ]]

# %% [markdown]
# - CB_予測平均

# %%
# 予測の平均を計算
cb_y_test_pred_avg = np.mean(cb_test_predictions, axis=0)

# 最終的な予測結果を整数に変換
cb_y_test_pred_int = (cb_y_test_pred_avg > cb_threshold).astype(int)

# %% [markdown]
# - output

# %%
# 現在の日時を取得してフォーマットする
current_time = datetime.now().strftime("%Y%m%d_%H%M%S")
output = f'../data/output/{current_time}_CatBoost_cv{cb_average_score:.4f}.csv'

submit = pd.DataFrame({
    '0': test['gameId'],
    '1': cb_y_test_pred_int
})

# カラムヘッダー消去して出力
# ヘッダーなしでCSVファイルとして保存
submit.to_csv(output, header=False, index=False)

# %%
submit
# Out:
#          0  1
# 0        9  1
# 1       15  1
# 2       18  0
# 3       23  0
# 4       31  0
# ...    ... ..
# 1995  9971  0
# 1996  9980  0
# 1997  9983  1
# 1998  9996  1
# 1999  9999  0
#
# [2000 rows x 2 columns]

# %% [markdown]
# # 合成

# %% [markdown]
# - 予測リストに追加

# %%
# 予測結果をNumPy配列に変換
cb_predictions = np.array(cb_y_test_pred_int)  # CatBoostの予測結果
lgb_predictions = np.array(lgb_y_test_pred_int)  # LightGBMの予測結果
xgb_predictions = np.array(xgb_y_test_pred_int)  # XGBoostの予測結果

# 3つのモデルの予測結果を組み合わせる
combined_predictions = np.vstack((cb_predictions, lgb_predictions, xgb_predictions))

# 多数決で最終的な予測を決定（行方向に合計し、1.5より大きい場合は1とする）
final_predictions = np.mean(combined_predictions, axis=0) > 0.5
final_predictions = final_predictions.astype(int)

# 最終的な予測をCSVファイルに保存
merge_submit = pd.DataFrame({
    '0': test['gameId'],  # 適切なID列を使用
    '1': final_predictions
})
merge_submit.to_csv(f'../data/output/{current_time}_final_predictions.csv', index=False)

# %%
merge_submit
# Out:
#          0  1
# 0        9  1
# 1       15  1
# 2       18  0
# 3       23  0
# 4       31  1
# ...    ... ..
# 1995  9971  0
# 1996  9980  0
# 1997  9983  1
# 1998  9996  1
# 1999  9999  0
#
# [2000 rows x 2 columns]

# %% [markdown]
# #

# %% [markdown]
# # Logistic classifier
