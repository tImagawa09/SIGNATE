# %% [markdown]
# # Baseline

# %% [markdown]
# FEなし =>
#
# **LightGBM**<br>
# LightGBM Average accuracy across all folds ===> 0.7793749999999999<br>
# LightGBM Average conf-matrix across all folds  => [[631.8 181.4] [171.6 615.2]]<br>
#
# **XGboost**<br>
# XGB Average accuracy across all folds =======> 0.7762500000000001<br>
# XGB Average conf-matrix across all folds =====>  [[663.8 149.4] [208.6 578.2]]<br>
#
# **CatBoost**<br>
# CatBoost Average accuracy across all folds ======> 0.7747499999999998<br>
# CatBoost Average conf-matrix across all folds ====> [[637.8 175.4] [185.  601.8]]<br>

# %% [markdown]
# # Library

# %%
import pandas as pd
import numpy as np

import optuna
import xgboost as xgb
import lightgbm as lgb
import catboost as cb

from datetime import datetime
from sklearn.model_selection import train_test_split, KFold
from sklearn.metrics import accuracy_score, confusion_matrix, roc_curve, auc
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# # Data Loading

# %%
train = pd.read_csv('../data/train.csv')
test = pd.read_csv('../data/test.csv')

# %% [markdown]
# # Add New Feature

# %%
# 基準
# lgb = 0.7793749999999999
# xgb = 0.7762500000000001
# Cat = 0.7747499999999998

# %%
def add_features(df):                                                                               # lgb=0.7793, xgb=0.7762, cb=0.7747
    # df['assistRate'] = df['blueAssists'] / (df['blueKills'] + 1)                                  # lgb=0.7825, xgb=0.7713, cb=0.7832
    # df['blueHerald'] = (df['blueEliteMonsters'] - df['blueDragons']).clip(lower=0)                # lgb=0.7843, xgb=0.7746, cb=0.7745
    # df['eliteMonsterDragonRatio'] = df['blueEliteMonsters'] / (df['blueDragons'] + 1)             # lgb=0.7857, xgb=0.7782, cb=0.7824
    # df['logTotalGold'] = np.log1p(df['blueTotalGold'])                                            # lgb=0.7964, xgb=0.7826, cb=0.7827
    # df['logTotalExperience'] = np.log1p(df['blueTotalExperience'])                                # lgb=0.7876, xgb=0.7722, cb=0.7777
    # df['firstBloodKillRatio'] = df['blueFirstBlood'] * df['blueKills']                            # lgb=0.7920, xgb=0.7751, cb=0.7893
    # df['totalCombatPoints'] = df['blueKills'] + df['blueDeaths'] + df['blueAssists']              # lgb=0.7869, xgb=0.7360, cb=0.7870

    # total_combat_actions = df['blueKills'] + df['blueDeaths'] + df['blueAssists'] 
    # df['killRatio'] = df['blueKills'] / total_combat_actions                                      # lgb=0.7913, xgb=0.7747, cb=0.7811
    # df['deathRatio'] = df['blueDeaths'] / total_combat_actions                                    # lgb=0.7864, xgb=0.7848, cb=0.7860
    # df['assistRatio'] = df['blueAssists'] / total_combat_actions                                  # lgb=0.7863, xgb=0.7746, cb=0.7815

    # df['teamStrength'] = df['blueKills'] + df['blueAssists'] + df['blueEliteMonsters']            # lgb=0.7782, xgb=0.7246, cb=0.7869
    # df['dragonKillImpact'] = df['blueDragons'] / (df['blueKills'] + 1)                            # lgb=0.7870, xgb=0.7694, cb=0.7857
    # df['eliteMonsterUtilization'] = df['blueEliteMonsters']\
    # / (df['blueKills'] + df['blueAssists'] + 1)                                                   # lgb=0.7900, xgb=0.7746, cb=0.7885
    # df['goldExperienceRatio'] = df['blueTotalGold'] / (df['blueTotalExperience'] + 1)             # lgb=0.7911, xgb=0.7324, cb=0.7886
    # df['teamEfficiency'] = \
        # (df['blueKills'] + df['blueAssists'] + df['blueEliteMonsters']) / (df['blueDeaths'] + 1)  # lgb=0.7900, xgb=0.7762, cb=0.7840
    # df['killToMonsterRatio'] = df['blueKills'] / (df['blueEliteMonsters'] + 1)                    # lgb=0.7859, xgb=0.7758, cb=0.7800
    # df['avgGoldPerKill'] = df['blueTotalGold'] / (df['blueKills'] + 1) # lgb=, xgb=, cb=
    # df['expToKillRatio'] = df['blueTotalExperience'] / (df['blueKills'] + 1) # lgb=, xgb=, cb=
    # df['killsMinusDeaths'] = df['blueKills'] - df['blueDeaths'] # lgb=, xgb=, cb=
    # df['killDeathRatio'] = df['blueKills'] / (df['blueKills'] + df['blueDeaths']) # lgb=, xgb=, cb=
    # df['avgExperiencePerKill'] = df['blueTotalExperience'] / (df['blueKills'] + 1) # lgb=, xgb=, cb=
    # df['killDeathDiff'] = (df['blueKills'] - df['blueDeaths']).clip(lower=0) # lgb=, xgb=, cb=
    # df['eliteMonsterHeraldRatio'] = df['blueEliteMonsters'] / (df['blueHerald'] + 1) # lgb=, xgb=, cb=
    # df['goldXexperience'] = np.log1p(df['blueTotalGold'] * df['blueTotalExperience']) # lgb=, xgb=, cb=
    # df['goldPerKill'] = df['blueTotalGold'] / (df['blueKills'] + 1)  # ゼロ除算を防ぐために+1 # lgb=, xgb=, cb=
    # df['experiencePerKill'] = df['blueTotalExperience'] / (df['blueKills'] + 1)  # ゼロ除算を防ぐために+1 # lgb=, xgb=, cb=
    # df['eliteMonstersPerGold'] = df['blueEliteMonsters'] / df['blueTotalGold'] # lgb=, xgb=, cb=
    # df['eliteMonstersPerExperience'] = df['blueEliteMonsters'] / df['blueTotalExperience'] # lgb=, xgb=, cb=

    
    return df

# %% [markdown]
# - apply

# %%
train = add_features(train)
test = add_features(test)

# %% [markdown]
# # Data

# %%
# データの準備
X = train.drop(['blueWins', 'gameId'], axis=1)
y = train['blueWins']
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2, random_state=0)

test_drop_gameId = test.drop('gameId', axis=1)

# test_drop_gameId_temp = test.drop('gameId', axis=1)

# # 特徴量の標準化
# scaler = StandardScaler()
# X_train = scaler.fit_transform(X_train)
# X_val = scaler.transform(X_val)  # 検証データも同じスケーラーを使用して標準化

# # テストデータも同じスケーラーを使用して標準化
# test_drop_gameId_scaled = scaler.transform(test_drop_gameId_temp)

# # NumPy配列からPandasデータフレームに変換
# X_train = pd.DataFrame(X_train, columns=X.columns)
# X_val = pd.DataFrame(X_val, columns=X.columns)
# test_drop_gameId = pd.DataFrame(test_drop_gameId_scaled, columns=test_drop_gameId_temp.columns)

# %% [markdown]
# # Model

# %% [markdown]
# - variable

# %%
n_splits = 5
kf = KFold(n_splits=n_splits, shuffle=True)

lgb_threshold = 0.5
xgb_threshold = 0.5
cb_threshold = 0.5

# 各フォールドでのスコアを保存するリスト
lgb_fold_scores = []
xgb_fold_scores = []
cb_fold_scores = []

# 各フォール度での混同行列を保存するリスト
lgb_conf_scores = []
xgb_conf_scores = []
cb_conf_scores = []

# testを保存するリスト
lgb_test_predictions = []
xgb_test_predictions = []
cb_test_predictions = []

# %% [markdown]
# ## LightGBM

# %%
for train_index, val_index in kf.split(X):
    X_train_fold, X_val_fold = X.iloc[train_index], X.iloc[val_index]
    y_train_fold, y_val_fold = y[train_index], y[val_index]

    # LightGBMではDMatrixの代わりに普通のデータフレームを使用します
    train_data = lgb.Dataset(X_train_fold, label=y_train_fold)
    val_data = lgb.Dataset(X_val_fold, label=y_val_fold, reference=train_data)

    # Optunaでのハイパーパラメータチューニング
    def objective(trial):
        param = {
            'objective': 'binary',
            'metric': 'binary_logloss',
            'verbosity': -1,
            'boosting_type': 'gbdt',
            'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
            'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
            'num_leaves': trial.suggest_int('num_leaves', 2, 256),
            'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
            'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
            'bagging_freq': trial.suggest_int('bagging_freq', 1, 7),
            'min_child_samples': trial.suggest_int('min_child_samples', 5, 100),
            'feature_pre_filter': False,  # 特徴量の事前フィルタリングを無効化
            'min_data_in_leaf': trial.suggest_int('min_data_in_leaf', 20, 100),  # Optunaでこの値を調整する
        }

        callbacks = lgb.early_stopping(stopping_rounds=100, verbose=False)
        gbm = lgb.train(param, train_data, valid_sets=[val_data], num_boost_round=1000, callbacks=[callbacks])
        preds = gbm.predict(X_val_fold, num_iteration=gbm.best_iteration)
        pred_labels = np.rint(preds)
        accuracy = accuracy_score(y_val_fold, pred_labels)
        return accuracy

    lgb_study = optuna.create_study(direction='maximize')
    lgb_study.optimize(objective, n_trials=100)

    # 各フォールドの最適パラメータでモデルを再学習
    lgb_best_params = lgb_study.best_params
    lgb_best_params['objective'] = 'binary'
    lgb_best_params['metric'] = 'binary_logloss'
    lgb_best_params['verbosity'] = -1

    lgb_final = lgb.train(lgb_best_params, train_data, num_boost_round=lgb_study.best_trial.number)

    # 各フォールドのモデル性能を評価
    lgb_y_val_pred = lgb_final.predict(X_val_fold, num_iteration=lgb_final.best_iteration)
    lgb_y_val_pred_int = np.rint(lgb_y_val_pred)
    lgb_fold_accuracy = accuracy_score(y_val_fold, lgb_y_val_pred_int)
    lgb_fold_scores.append(lgb_fold_accuracy)

    # 混同行列
    lgb_conf_matrix = confusion_matrix(y_val_fold, lgb_y_val_pred_int)
    lgb_conf_scores.append(lgb_conf_matrix)


    # テストデータセットでの予測
    lgb_y_test_pred_fold = lgb_final.predict(test_drop_gameId, num_iteration=lgb_final.best_iteration)
    lgb_test_predictions.append(lgb_y_test_pred_fold)
# Out:
# [I 2024-01-30 16:52:41,055] A new study created in memory with name: no-name-523940c6-8d18-4bc3-b805-2361e75693ed
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-30 16:52:41,201] Trial 0 finished with value: 0.77125 and parameters: {'lambda_l1': 3.1855598818390697e-07, 'lambda_l2': 0.014164871388851743, 'num_leaves': 237, 'feature_fraction': 0.7487639754981783, 'bagging_fraction': 0.6255070589242291, 'bagging_freq': 6, 'min_child_samples': 51, 'min_data_in_leaf': 87}. Best is trial 0 with value: 0.77125.
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-30 16:52:41,499] Trial 1 finished with value: 0.769375 and parameters: {'lambda_l1': 0.0005088701092778383, 'lambda_l2': 1.2887614424064647e-07, 'num_leaves': 107, 'feature_fraction': 0.6020730093981883, 'bagging_fraction': 0.8604540508603906, 'bagging_freq': 2, 'min_child_samples': 9, 'min_data_in_leaf': 21}. Best is trial 0 with value: 0.77125.
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-30 16:52:41,690] Trial 2 finished with value: 0.775625 and parameters: {'lambda_l1': 7.81533085817147e-07, 'lambda_l2': 4.827060658486193e-08, 'num_leaves': 84, 'feature_fraction': 0.49102129442690834, 'bagging_fraction': 0.8621640516418367, 'bagging_freq': 4, 'min_child_samples': 26, 'min_data_in_leaf': 70}. Best is trial 2 with value: 0.775625.
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-30 16:52:41,791] Trial 3 finished with value: 0.775625 and parameters: {'lambda_l1': 0.527136059206538, 'lambda_l2': 6.870234788251816e-07, 'num_leaves': 61, 'feature_fraction': 0.6054684774608202, 'bagging_fraction': 0.5334115706183684, 'bagging_freq': 2, 'min_child_samples': 9, 'min_data_in_leaf': 73}. Best is trial 2 with value: 0.775625.
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-30 16:52:41,871] Trial 4 finished with value: 0.77125 and parameters: {'lambda_l1': 3.914639190050513e-08, 'lambda_l2': 0.0002181026841877791, 'num_leaves': 26, 'feature_fraction': 0.8257926370423918, 'bagging_fraction': 0.5013494875971336, 'bagging_freq': 3, 'min_child_samples': 70, 'min_data_in_leaf': 29}. Best is trial 2 with value: 0.775625.
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-30 16:52:42,004] Trial 5 finished with value: 0.776875 and parameters: {'lambda_l1': 4.024759417238148e-06, 'lambda_l2': 0.04589294640040135, 'num_leaves': 82, 'feature_fraction': 0.7890934441149354, 'bagging_fraction': 0.6952001253337909, 'bagging_freq': 2, 'min_child_samples': 63, 'min_data_in_leaf': 88}. Best is trial 5 with value: 0.776875.
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-30 16:52:42,122] Trial 6 finished with value: 0.774375 and parameters: {'lambda_l1': 3.6019240165440156e-05, 'lambda_l2': 7.40932338845737e-06, 'num_leaves': 178, 'feature_fraction': 0.8731603048651082, 'bagging_fraction': 0.4761490406506843, 'bagging_freq': 5, 'min_child_samples': 17, 'min_data_in_leaf': 83}. Best is trial 5 with value: 0.776875.
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-30 16:52:42,222] Trial 7 finished with value: 0.771875 and parameters: {'lambda_l1': 1.4745976558944006e-08, 'lambda_l2': 1.1391221319368787e-06, 'num_leaves': 24, 'feature_fraction': 0.4808285300104339, 'bagging_fraction': 0.5902911736105612, 'bagging_freq': 2, 'min_child_samples': 8, 'min_data_in_leaf': 35}. Best is trial 5 with value: 0.776875.
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-30 16:52:42,461] Trial 8 finished with value: 0.7725 and parameters: {'lambda_l1': 3.01827428056785, 'lambda_l2': 2.003576255678326e-07, 'num_leaves': 33, 'feature_fraction': 0.48153064892991965, 'bagging_fraction': 0.6280713386741352, 'bagging_freq': 7, 'min_child_samples': 27, 'min_data_in_leaf': 98}. Best is trial 5 with value: 0.776875.
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-30 16:52:42,604] Trial 9 finished with value: 0.77125 and parameters: {'lambda_l1': 0.00013180106047663086, 'lambda_l2': 0.0011389399001262785, 'num_leaves': 111, 'feature_fraction': 0.40425352708124673, 'bagging_fraction': 0.5666251740340914, 'bagging_freq': 1, 'min_child_samples': 67, 'min_data_in_leaf': 41}. Best is trial 5 with value: 0.776875.
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-30 16:52:42,832] Trial 10 finished with value: 0.77375 and parameters: {'lambda_l1': 0.009209314645648581, 'lambda_l2': 7.016323618573628, 'num_leaves': 156, 'feature_fraction': 0.9718632326710058, 'bagging_fraction': 0.7805914970547236, 'bagging_freq': 4, 'min_child_samples': 90, 'min_data_in_leaf': 51}. Best is trial 5 with value: 0.776875.
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-30 16:52:43,004] Trial 11 finished with value: 0.770625 and parameters: {'lambda_l1': 2.170412702528157e-06, 'lambda_l2': 3.32721000650205e-08, 'num_leaves': 78, 'feature_fraction': 0.7211738751145926, 'bagging_fraction': 0.9514944764517292, 'bagging_freq': 4, 'min_child_samples': 45, 'min_data_in_leaf': 64}. Best is trial 5 with value: 0.776875.
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-30 16:52:43,171] Trial 12 finished with value: 0.77375 and parameters: {'lambda_l1': 1.8996430486241033e-06, 'lambda_l2': 1.014390340241427e-08, 'num_leaves': 78, 'feature_fraction': 0.6405614828512193, 'bagging_fraction': 0.7345795956017962, 'bagging_freq': 3, 'min_child_samples': 36, 'min_data_in_leaf': 71}. Best is trial 5 with value: 0.776875.
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-30 16:52:43,321] Trial 13 finished with value: 0.771875 and parameters: {'lambda_l1': 9.389077588005639e-06, 'lambda_l2': 0.11212117354592988, 'num_leaves': 154, 'feature_fraction': 0.7801634212604904, 'bagging_fraction': 0.8148426607066431, 'bagging_freq': 5, 'min_child_samples': 66, 'min_data_in_leaf': 98}. Best is trial 5 with value: 0.776875.
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-30 16:52:43,489] Trial 14 finished with value: 0.773125 and parameters: {'lambda_l1': 2.7919678831454294e-07, 'lambda_l2': 2.4664121899812597e-05, 'num_leaves': 123, 'feature_fraction': 0.6668450410005043, 'bagging_fraction': 0.6967859078009667, 'bagging_freq': 1, 'min_child_samples': 88, 'min_data_in_leaf': 83}. Best is trial 5 with value: 0.776875.
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-30 16:52:43,636] Trial 15 finished with value: 0.77625 and parameters: {'lambda_l1': 7.84675997110638e-06, 'lambda_l2': 2.1896015623082257e-05, 'num_leaves': 60, 'feature_fraction': 0.8811200235837591, 'bagging_fraction': 0.42467127640730584, 'bagging_freq': 3, 'min_child_samples': 32, 'min_data_in_leaf': 55}. Best is trial 5 with value: 0.776875.
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-30 16:52:43,805] Trial 16 finished with value: 0.77375 and parameters: {'lambda_l1': 0.0006678292261005385, 'lambda_l2': 0.0002856432858264427, 'num_leaves': 51, 'feature_fraction': 0.8833237838057242, 'bagging_fraction': 0.4394136257351011, 'bagging_freq': 3, 'min_child_samples': 58, 'min_data_in_leaf': 54}. Best is trial 5 with value: 0.776875.
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-30 16:52:43,970] Trial 17 finished with value: 0.770625 and parameters: {'lambda_l1': 1.9848006746390112e-05, 'lambda_l2': 0.008860697723845096, 'num_leaves': 206, 'feature_fraction': 0.9587346631335424, 'bagging_fraction': 0.4187667744680246, 'bagging_freq': 2, 'min_child_samples': 39, 'min_data_in_leaf': 45}. Best is trial 5 with value: 0.776875.
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-30 16:52:44,103] Trial 18 finished with value: 0.77625 and parameters: {'lambda_l1': 1.086440995389639e-07, 'lambda_l2': 4.0612062142981296e-05, 'num_leaves': 9, 'feature_fraction': 0.8189591027505321, 'bagging_fraction': 0.404442751097277, 'bagging_freq': 1, 'min_child_samples': 80, 'min_data_in_leaf': 60}. Best is trial 5 with value: 0.776875.
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-30 16:52:44,252] Trial 19 finished with value: 0.77625 and parameters: {'lambda_l1': 3.655743293916913e-06, 'lambda_l2': 3.934592911568853e-06, 'num_leaves': 93, 'feature_fraction': 0.9243793662299863, 'bagging_fraction': 0.49583122664259377, 'bagging_freq': 3, 'min_child_samples': 55, 'min_data_in_leaf': 90}. Best is trial 5 with value: 0.776875.
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-30 16:52:44,435] Trial 20 finished with value: 0.774375 and parameters: {'lambda_l1': 1.8797060468812972e-08, 'lambda_l2': 0.3409827696982779, 'num_leaves': 55, 'feature_fraction': 0.9870154895595017, 'bagging_fraction': 0.6253027083159347, 'bagging_freq': 5, 'min_child_samples': 77, 'min_data_in_leaf': 57}. Best is trial 5 with value: 0.776875.
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-30 16:52:44,621] Trial 21 finished with value: 0.771875 and parameters: {'lambda_l1': 1.22790352971896e-07, 'lambda_l2': 2.3605789810885684e-05, 'num_leaves': 5, 'feature_fraction': 0.8063972730729545, 'bagging_fraction': 0.40070270120778906, 'bagging_freq': 1, 'min_child_samples': 80, 'min_data_in_leaf': 63}. Best is trial 5 with value: 0.776875.
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-30 16:52:44,753] Trial 22 finished with value: 0.7825 and parameters: {'lambda_l1': 2.0702352500706456e-07, 'lambda_l2': 7.023721517487173e-05, 'num_leaves': 18, 'feature_fraction': 0.8542822709206874, 'bagging_fraction': 0.4377379513800371, 'bagging_freq': 1, 'min_child_samples': 95, 'min_data_in_leaf': 48}. Best is trial 22 with value: 0.7825.
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-30 16:52:44,986] Trial 23 finished with value: 0.78 and parameters: {'lambda_l1': 1.1279441236739885e-06, 'lambda_l2': 0.0015057220612358388, 'num_leaves': 45, 'feature_fraction': 0.8902214617903376, 'bagging_fraction': 0.4632200324376571, 'bagging_freq': 2, 'min_child_samples': 100, 'min_data_in_leaf': 47}. Best is trial 22 with value: 0.7825.
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-30 16:52:45,135] Trial 24 finished with value: 0.778125 and parameters: {'lambda_l1': 6.394933703403262e-07, 'lambda_l2': 0.0016378553750314643, 'num_leaves': 38, 'feature_fraction': 0.852495204557417, 'bagging_fraction': 0.4718540906028932, 'bagging_freq': 2, 'min_child_samples': 100, 'min_data_in_leaf': 45}. Best is trial 22 with value: 0.7825.
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-30 16:52:45,303] Trial 25 finished with value: 0.775625 and parameters: {'lambda_l1': 3.413054718630364e-07, 'lambda_l2': 0.001762275135983859, 'num_leaves': 41, 'feature_fraction': 0.9203911356641203, 'bagging_fraction': 0.4714450539702628, 'bagging_freq': 1, 'min_child_samples': 97, 'min_data_in_leaf': 46}. Best is trial 22 with value: 0.7825.
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-30 16:52:45,403] Trial 26 finished with value: 0.775625 and parameters: {'lambda_l1': 6.516459974389453e-08, 'lambda_l2': 0.0001148573750579446, 'num_leaves': 9, 'feature_fraction': 0.8412596306127623, 'bagging_fraction': 0.5264113512919332, 'bagging_freq': 2, 'min_child_samples': 99, 'min_data_in_leaf': 37}. Best is trial 22 with value: 0.7825.
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-30 16:52:45,553] Trial 27 finished with value: 0.77 and parameters: {'lambda_l1': 1.090545832439359e-06, 'lambda_l2': 0.001256545566084863, 'num_leaves': 24, 'feature_fraction': 0.9235191838389767, 'bagging_fraction': 0.45995265106766176, 'bagging_freq': 1, 'min_child_samples': 91, 'min_data_in_leaf': 31}. Best is trial 22 with value: 0.7825.
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# ...
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-30 16:54:33,226] Trial 90 finished with value: 0.771875 and parameters: {'lambda_l1': 0.0033934828341805785, 'lambda_l2': 9.58515677741326e-06, 'num_leaves': 111, 'feature_fraction': 0.9093689000615336, 'bagging_fraction': 0.5498830939443098, 'bagging_freq': 4, 'min_child_samples': 41, 'min_data_in_leaf': 49}. Best is trial 28 with value: 0.783125.
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-30 16:54:33,409] Trial 91 finished with value: 0.765625 and parameters: {'lambda_l1': 0.011253243401383029, 'lambda_l2': 1.2769427313305192e-07, 'num_leaves': 104, 'feature_fraction': 0.8999368159580079, 'bagging_fraction': 0.4638978743735546, 'bagging_freq': 5, 'min_child_samples': 94, 'min_data_in_leaf': 60}. Best is trial 28 with value: 0.783125.
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-30 16:54:33,659] Trial 92 finished with value: 0.77625 and parameters: {'lambda_l1': 0.004408418671129845, 'lambda_l2': 7.944765421040979e-08, 'num_leaves': 132, 'feature_fraction': 0.8306805780386888, 'bagging_fraction': 0.4840386478970591, 'bagging_freq': 4, 'min_child_samples': 51, 'min_data_in_leaf': 53}. Best is trial 28 with value: 0.783125.
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-30 16:54:33,860] Trial 93 finished with value: 0.766875 and parameters: {'lambda_l1': 0.0018454028761735104, 'lambda_l2': 4.072639853985055e-08, 'num_leaves': 157, 'feature_fraction': 0.8585930981096063, 'bagging_fraction': 0.47438547337343856, 'bagging_freq': 5, 'min_child_samples': 36, 'min_data_in_leaf': 59}. Best is trial 28 with value: 0.783125.
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-30 16:54:34,086] Trial 94 finished with value: 0.774375 and parameters: {'lambda_l1': 0.008506807361522657, 'lambda_l2': 2.0165358060353562e-07, 'num_leaves': 117, 'feature_fraction': 0.9346831281017247, 'bagging_fraction': 0.5300880067394701, 'bagging_freq': 3, 'min_child_samples': 46, 'min_data_in_leaf': 67}. Best is trial 28 with value: 0.783125.
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-30 16:54:34,360] Trial 95 finished with value: 0.771875 and parameters: {'lambda_l1': 0.003928395550037506, 'lambda_l2': 8.604316650526268e-05, 'num_leaves': 251, 'feature_fraction': 0.8769338648015089, 'bagging_fraction': 0.50802829860819, 'bagging_freq': 4, 'min_child_samples': 40, 'min_data_in_leaf': 61}. Best is trial 28 with value: 0.783125.
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-30 16:54:34,630] Trial 96 finished with value: 0.77 and parameters: {'lambda_l1': 0.0006857073613004521, 'lambda_l2': 4.03044062136137e-07, 'num_leaves': 125, 'feature_fraction': 0.7952915266735744, 'bagging_fraction': 0.45233334239442835, 'bagging_freq': 4, 'min_child_samples': 44, 'min_data_in_leaf': 57}. Best is trial 28 with value: 0.783125.
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-30 16:54:34,866] Trial 97 finished with value: 0.7725 and parameters: {'lambda_l1': 0.0001811965722729691, 'lambda_l2': 7.725894081549104e-07, 'num_leaves': 143, 'feature_fraction': 0.9135546706785964, 'bagging_fraction': 0.4911575439383529, 'bagging_freq': 5, 'min_child_samples': 62, 'min_data_in_leaf': 70}. Best is trial 28 with value: 0.783125.
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-30 16:54:35,037] Trial 98 finished with value: 0.76875 and parameters: {'lambda_l1': 0.017565873801842158, 'lambda_l2': 7.602800189709271e-08, 'num_leaves': 137, 'feature_fraction': 0.8981595662041659, 'bagging_fraction': 0.4708507922788669, 'bagging_freq': 6, 'min_child_samples': 54, 'min_data_in_leaf': 65}. Best is trial 28 with value: 0.783125.
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-30 16:54:35,291] Trial 99 finished with value: 0.779375 and parameters: {'lambda_l1': 0.2776188073217618, 'lambda_l2': 0.0002641473500934421, 'num_leaves': 230, 'feature_fraction': 0.9665871594954786, 'bagging_fraction': 0.4430970420212297, 'bagging_freq': 5, 'min_child_samples': 57, 'min_data_in_leaf': 59}. Best is trial 28 with value: 0.783125.

# %% [markdown]
# - lgb_平均スコア

# %%
# 全フォールドの平均スコアを計算
lgb_average_score = sum(lgb_fold_scores) / n_splits
print(f"LightGBM Average accuracy across all folds: {lgb_average_score:.4f}")


lgb_average_conf = sum(lgb_conf_scores) / n_splits
print(f"LightGBM Average conf-matrix across all folds: {lgb_average_conf}")
# Out:
# LightGBM Average accuracy across all folds: 0.7859
# LightGBM Average conf-matrix across all folds: [[636.2 177. ]
#  [165.6 621.2]]

# %% [markdown]
# - lgb_予測平均

# %%
# 予測の平均を計算
lgb_y_test_pred_avg = np.mean(lgb_test_predictions, axis=0)

# 最終的な予測結果を整数に変換
lgb_y_test_pred_int = (lgb_y_test_pred_avg > lgb_threshold).astype(int)

# %% [markdown]
# - output

# %%
# 現在の日時を取得してフォーマットする
current_time = datetime.now().strftime("%Y%m%d_%H%M%S")
output = f'../data/output/{current_time}_LightGBM_cv{lgb_average_score:.4f}.csv'

submit = pd.DataFrame({
    '0': test['gameId'],
    '1': lgb_y_test_pred_int
})

# カラムヘッダー消去して出力
# ヘッダーなしでCSVファイルとして保存
submit.to_csv(output, header=False, index=False)

# %%
submit
# Out:
#          0  1
# 0        9  1
# 1       15  1
# 2       18  0
# 3       23  0
# 4       31  1
# ...    ... ..
# 1995  9971  0
# 1996  9980  0
# 1997  9983  1
# 1998  9996  1
# 1999  9999  0
#
# [2000 rows x 2 columns]

# %% [markdown]
# ## XGBoost

# %%
for train_index, val_index in kf.split(X):
    X_train_fold, X_val_fold = X.iloc[train_index], X.iloc[val_index]
    y_train_fold, y_val_fold = y[train_index], y[val_index]

    dtrain = xgb.DMatrix(X_train_fold, label=y_train_fold)
    dval = xgb.DMatrix(X_val_fold, label=y_val_fold)
    dtest = xgb.DMatrix(test_drop_gameId)

    # Optunaでのハイパーパラメータチューニング
    def objective(trial):
        param = {
            'verbosity': 0,
            'objective': 'binary:logistic',
            'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
            'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
            'max_depth': trial.suggest_int('max_depth', 3, 9),
            'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
            'subsample': trial.suggest_float('subsample', 0.5, 1),
            'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1)
        }

        bst = xgb.train(param, dtrain, num_boost_round=1000, evals=[(dval, "eval")], early_stopping_rounds=100, verbose_eval=False)
        preds = bst.predict(dval)
        pred_labels = np.rint(preds)
        accuracy = accuracy_score(y_val_fold, pred_labels)
        return accuracy

    xgb_study = optuna.create_study(direction='maximize')
    xgb_study.optimize(objective, n_trials=100)

    # 各フォールドの最適パラメータでモデルを再学習
    xgb_best_params = xgb_study.best_params
    xgb_best_params['objective'] = 'binary:logistic'
    xgb_best_params['verbosity'] = 0

    xgb_final_bst = xgb.train(xgb_best_params, dtrain, num_boost_round=xgb_study.best_trial.number)

    # 各フォールドのモデル性能を評価
    xgb_y_val_pred = xgb_final_bst.predict(dval)
    xgb_y_val_pred_int = np.rint(xgb_y_val_pred)
    fold_accuracy = accuracy_score(y_val_fold, xgb_y_val_pred_int)
    xgb_fold_scores.append(fold_accuracy)

    # 混同行列
    xgb_conf_matrix = confusion_matrix(y_val_fold, xgb_y_val_pred_int)
    xgb_conf_scores.append(xgb_conf_matrix)

    # テストデータセットでの予測
    xgb_y_test_pred_fold = xgb_final_bst.predict(dtest)
    xgb_test_predictions.append(xgb_y_test_pred_fold)
# Out:
# [I 2024-01-30 16:54:35,485] A new study created in memory with name: no-name-559edaa5-a125-41e5-be46-b3e7e4d0ae41
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-30 16:54:36,891] Trial 0 finished with value: 0.50125 and parameters: {'alpha': 0.11041457021336604, 'lambda': 1.6371181528462858e-07, 'max_depth': 6, 'eta': 6.22015780250168e-08, 'subsample': 0.7867903240513218, 'colsample_bytree': 0.9034847336535309}. Best is trial 0 with value: 0.50125.
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-30 16:54:37,074] Trial 1 finished with value: 0.785 and parameters: {'alpha': 0.8313424733429062, 'lambda': 3.5328778562424496e-05, 'max_depth': 5, 'eta': 0.11875290157621979, 'subsample': 0.9785046214557267, 'colsample_bytree': 0.73412056734631}. Best is trial 1 with value: 0.785.
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-30 16:54:37,308] Trial 2 finished with value: 0.784375 and parameters: {'alpha': 1.6886851883065887e-08, 'lambda': 0.002231035097094778, 'max_depth': 4, 'eta': 0.06863043027549572, 'subsample': 0.5764136975950507, 'colsample_bytree': 0.5859356715172528}. Best is trial 1 with value: 0.785.
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-30 16:54:37,468] Trial 3 finished with value: 0.728125 and parameters: {'alpha': 9.027314798439279e-07, 'lambda': 1.2723374466966958e-05, 'max_depth': 8, 'eta': 0.8905068177092444, 'subsample': 0.9917427385355334, 'colsample_bytree': 0.6247410431807154}. Best is trial 1 with value: 0.785.
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-30 16:54:38,422] Trial 4 finished with value: 0.786875 and parameters: {'alpha': 1.8225722402453383e-08, 'lambda': 1.3586418029721624e-06, 'max_depth': 5, 'eta': 0.0009742366339111375, 'subsample': 0.5544791631215134, 'colsample_bytree': 0.7461362694009193}. Best is trial 4 with value: 0.786875.
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-30 16:54:39,639] Trial 5 finished with value: 0.50125 and parameters: {'alpha': 4.0456750856901174e-07, 'lambda': 5.1467003152681314e-06, 'max_depth': 6, 'eta': 3.164683033270076e-08, 'subsample': 0.9467143369224651, 'colsample_bytree': 0.597147027808087}. Best is trial 4 with value: 0.786875.
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-30 16:54:41,548] Trial 6 finished with value: 0.50125 and parameters: {'alpha': 1.5786564808376156e-05, 'lambda': 1.3706640487524132e-07, 'max_depth': 9, 'eta': 6.641453388747176e-08, 'subsample': 0.5298006114609923, 'colsample_bytree': 0.835751002364904}. Best is trial 4 with value: 0.786875.
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-30 16:54:42,355] Trial 7 finished with value: 0.791875 and parameters: {'alpha': 0.0002822942373676743, 'lambda': 8.386095458657842e-08, 'max_depth': 3, 'eta': 0.009287775114528145, 'subsample': 0.6013957604579689, 'colsample_bytree': 0.7427850761567212}. Best is trial 7 with value: 0.791875.
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-30 16:54:43,122] Trial 8 finished with value: 0.50125 and parameters: {'alpha': 1.4535859510450794e-07, 'lambda': 1.4165618929376135e-05, 'max_depth': 3, 'eta': 4.3576133366634365e-06, 'subsample': 0.8262534452437528, 'colsample_bytree': 0.7435656807139288}. Best is trial 7 with value: 0.791875.
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-30 16:54:44,153] Trial 9 finished with value: 0.50125 and parameters: {'alpha': 0.0001277230171349538, 'lambda': 0.038776140933825955, 'max_depth': 5, 'eta': 5.5312732084762535e-08, 'subsample': 0.9484294454757773, 'colsample_bytree': 0.6352784789702789}. Best is trial 7 with value: 0.791875.
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-30 16:54:44,905] Trial 10 finished with value: 0.773125 and parameters: {'alpha': 0.0009957263461275868, 'lambda': 1.0705712461646673e-08, 'max_depth': 3, 'eta': 0.0011634811059592792, 'subsample': 0.6518790548017342, 'colsample_bytree': 0.9539805116313294}. Best is trial 7 with value: 0.791875.
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-30 16:54:45,837] Trial 11 finished with value: 0.7825 and parameters: {'alpha': 1.6852880675098272e-08, 'lambda': 5.066877947715874e-07, 'max_depth': 4, 'eta': 0.0014199778760645948, 'subsample': 0.615837492469645, 'colsample_bytree': 0.8131406774314247}. Best is trial 7 with value: 0.791875.
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-30 16:54:46,785] Trial 12 finished with value: 0.77625 and parameters: {'alpha': 1.2075791580016857e-05, 'lambda': 0.0006437585204391096, 'max_depth': 4, 'eta': 0.0004906507771294521, 'subsample': 0.5121309352570316, 'colsample_bytree': 0.7170539612567949}. Best is trial 7 with value: 0.791875.
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-30 16:54:48,218] Trial 13 finished with value: 0.748125 and parameters: {'alpha': 0.0011010358092688971, 'lambda': 1.312284668954834e-08, 'max_depth': 7, 'eta': 5.930984362437364e-05, 'subsample': 0.6732442710184376, 'colsample_bytree': 0.6746707583269463}. Best is trial 7 with value: 0.791875.
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-30 16:54:48,967] Trial 14 finished with value: 0.789375 and parameters: {'alpha': 1.4688064685167201e-06, 'lambda': 7.847969986381411e-07, 'max_depth': 5, 'eta': 0.009296016748226527, 'subsample': 0.6954420178049594, 'colsample_bytree': 0.8114299657659079}. Best is trial 7 with value: 0.791875.
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-30 16:54:49,752] Trial 15 finished with value: 0.7875 and parameters: {'alpha': 6.665295097547228e-06, 'lambda': 9.24554166711911e-07, 'max_depth': 3, 'eta': 0.010959688498031753, 'subsample': 0.7040908099361539, 'colsample_bytree': 0.5191240401920291}. Best is trial 7 with value: 0.791875.
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-30 16:54:50,334] Trial 16 finished with value: 0.781875 and parameters: {'alpha': 0.00017192009984306697, 'lambda': 0.00015872518595468857, 'max_depth': 7, 'eta': 0.01521924423352037, 'subsample': 0.7222580833200354, 'colsample_bytree': 0.8111990519684722}. Best is trial 7 with value: 0.791875.
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-30 16:54:51,183] Trial 17 finished with value: 0.789375 and parameters: {'alpha': 0.004051643967636001, 'lambda': 6.331416106028759e-08, 'max_depth': 4, 'eta': 0.008274761053198557, 'subsample': 0.599282556124902, 'colsample_bytree': 0.8898579869992009}. Best is trial 7 with value: 0.791875.
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-30 16:54:51,332] Trial 18 finished with value: 0.7475 and parameters: {'alpha': 1.0000603439993966e-06, 'lambda': 1.1739857651816888e-06, 'max_depth': 5, 'eta': 0.7149461928523119, 'subsample': 0.6505982504943864, 'colsample_bytree': 0.9965561011565502}. Best is trial 7 with value: 0.791875.
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-30 16:54:52,916] Trial 19 finished with value: 0.72625 and parameters: {'alpha': 2.2624786622398176e-05, 'lambda': 5.9475081571303187e-08, 'max_depth': 7, 'eta': 4.279881192435069e-05, 'subsample': 0.7579071727435027, 'colsample_bytree': 0.8027089978960488}. Best is trial 7 with value: 0.791875.
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-30 16:54:53,265] Trial 20 finished with value: 0.78 and parameters: {'alpha': 4.57048115945273e-06, 'lambda': 4.407608502234151e-06, 'max_depth': 3, 'eta': 0.07855495847614453, 'subsample': 0.5050660945805825, 'colsample_bytree': 0.6942444524981985}. Best is trial 7 with value: 0.791875.
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-30 16:54:54,115] Trial 21 finished with value: 0.78625 and parameters: {'alpha': 0.0024092298141742876, 'lambda': 4.508610963812117e-08, 'max_depth': 4, 'eta': 0.009772661362163594, 'subsample': 0.6017792040324579, 'colsample_bytree': 0.8690049135410377}. Best is trial 7 with value: 0.791875.
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-30 16:54:54,881] Trial 22 finished with value: 0.78875 and parameters: {'alpha': 0.01545384299337959, 'lambda': 2.3214498339729348e-07, 'max_depth': 4, 'eta': 0.01213177774774257, 'subsample': 0.5806162858780249, 'colsample_bytree': 0.8850279329373902}. Best is trial 7 with value: 0.791875.
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-30 16:54:55,898] Trial 23 finished with value: 0.7925 and parameters: {'alpha': 0.0002391150635467811, 'lambda': 4.2412701853631365e-08, 'max_depth': 5, 'eta': 0.0034768886104848823, 'subsample': 0.6294422309739338, 'colsample_bytree': 0.7902589740366012}. Best is trial 23 with value: 0.7925.
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-30 16:54:57,213] Trial 24 finished with value: 0.788125 and parameters: {'alpha': 7.400328140642296e-05, 'lambda': 3.7995196032018907e-07, 'max_depth': 6, 'eta': 0.0002963082694192477, 'subsample': 0.6394214748231778, 'colsample_bytree': 0.7750870350581968}. Best is trial 23 with value: 0.7925.
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-30 16:54:58,316] Trial 25 finished with value: 0.79 and parameters: {'alpha': 0.00018354385188535372, 'lambda': 2.8254433706993657e-08, 'max_depth': 5, 'eta': 0.00225556169773957, 'subsample': 0.6848866454468797, 'colsample_bytree': 0.7759918374238997}. Best is trial 23 with value: 0.7925.
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-30 16:54:59,662] Trial 26 finished with value: 0.795 and parameters: {'alpha': 0.000386958262197715, 'lambda': 1.129095263515391e-08, 'max_depth': 6, 'eta': 0.0017314875765557262, 'subsample': 0.5602282091460488, 'colsample_bytree': 0.7529888507666368}. Best is trial 26 with value: 0.795.
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-30 16:55:00,968] Trial 27 finished with value: 0.773125 and parameters: {'alpha': 0.00045711893345939556, 'lambda': 1.0047116934247514e-08, 'max_depth': 6, 'eta': 0.00013031417099523812, 'subsample': 0.5446715590306117, 'colsample_bytree': 0.6995452743439822}. Best is trial 26 with value: 0.795.
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-30 16:55:02,740] Trial 28 finished with value: 0.79125 and parameters: {'alpha': 4.629165018214531e-05, 'lambda': 5.7615749730344035e-08, 'max_depth': 8, 'eta': 0.0023842721138219516, 'subsample': 0.5516847322976834, 'colsample_bytree': 0.7724723937267484}. Best is trial 26 with value: 0.795.
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-30 16:55:04,092] Trial 29 finished with value: 0.785625 and parameters: {'alpha': 0.013159844623760861, 'lambda': 1.7058983751720606e-07, 'max_depth': 6, 'eta': 0.00024288242583799522, 'subsample': 0.6227246881850093, 'colsample_bytree': 0.8463144362815238}. Best is trial 26 with value: 0.795.
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-30 16:55:05,693] Trial 30 finished with value: 0.65875 and parameters: {'alpha': 0.00042184152031178417, 'lambda': 1.3383849915882807e-07, 'max_depth': 7, 'eta': 2.698928588631695e-05, 'subsample': 0.5639660322755109, 'colsample_bytree': 0.9179557545110186}. Best is trial 26 with value: 0.795.
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-30 16:55:07,975] Trial 31 finished with value: 0.79625 and parameters: {'alpha': 4.8041889389327325e-05, 'lambda': 3.12852247516923e-08, 'max_depth': 9, 'eta': 0.0014539944783281543, 'subsample': 0.5444794609442605, 'colsample_bytree': 0.7655469697781478}. Best is trial 31 with value: 0.79625.
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-30 16:55:10,173] Trial 32 finished with value: 0.794375 and parameters: {'alpha': 4.750033778989941e-05, 'lambda': 3.4914233014160865e-08, 'max_depth': 9, 'eta': 0.003011157163844126, 'subsample': 0.5853126920403408, 'colsample_bytree': 0.7271691192026679}. Best is trial 31 with value: 0.79625.
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-30 16:55:10,575] Trial 33 finished with value: 0.77875 and parameters: {'alpha': 9.712527291275087e-05, 'lambda': 2.5273008472938917e-08, 'max_depth': 9, 'eta': 0.03912199426091826, 'subsample': 0.5014309597576287, 'colsample_bytree': 0.723731990591421}. Best is trial 31 with value: 0.79625.
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-30 16:55:12,464] Trial 34 finished with value: 0.795 and parameters: {'alpha': 4.229785614498331e-05, 'lambda': 2.588618781181575e-08, 'max_depth': 8, 'eta': 0.0007784081218964797, 'subsample': 0.5781037524387429, 'colsample_bytree': 0.6727508824955051}. Best is trial 31 with value: 0.79625.
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-30 16:55:14,468] Trial 35 finished with value: 0.795 and parameters: {'alpha': 2.8441808967705108e-05, 'lambda': 1.7781209480465777e-08, 'max_depth': 8, 'eta': 0.0005790847488848503, 'subsample': 0.5776043184695754, 'colsample_bytree': 0.6751403727585642}. Best is trial 31 with value: 0.79625.
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-30 16:55:16,365] Trial 36 finished with value: 0.795 and parameters: {'alpha': 3.62189427609634e-05, 'lambda': 1.0036754542451452e-08, 'max_depth': 8, 'eta': 0.0005386468130441168, 'subsample': 0.5389526709323638, 'colsample_bytree': 0.6693377545241443}. Best is trial 31 with value: 0.79625.
# ...
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-30 17:01:16,374] Trial 87 finished with value: 0.7825 and parameters: {'alpha': 0.26152273546331223, 'lambda': 0.3772481374567954, 'max_depth': 4, 'eta': 0.034094793531002615, 'subsample': 0.9830325937593076, 'colsample_bytree': 0.6343084296917135}. Best is trial 72 with value: 0.78875.
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-30 17:01:17,493] Trial 88 finished with value: 0.785 and parameters: {'alpha': 0.010670772674236393, 'lambda': 0.6920067947367696, 'max_depth': 5, 'eta': 0.007756063447982557, 'subsample': 0.9646975360425604, 'colsample_bytree': 0.6057982356984714}. Best is trial 72 with value: 0.78875.
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-30 17:01:18,470] Trial 89 finished with value: 0.784375 and parameters: {'alpha': 0.1219366884565779, 'lambda': 0.13406579121958428, 'max_depth': 4, 'eta': 0.016825843770738043, 'subsample': 0.9398665407222655, 'colsample_bytree': 0.6502827755756504}. Best is trial 72 with value: 0.78875.
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-30 17:01:19,302] Trial 90 finished with value: 0.771875 and parameters: {'alpha': 0.06850647222020545, 'lambda': 0.2726982741015679, 'max_depth': 3, 'eta': 0.003823433725597333, 'subsample': 0.9793838627699716, 'colsample_bytree': 0.8054372659991755}. Best is trial 72 with value: 0.78875.
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-30 17:01:20,269] Trial 91 finished with value: 0.784375 and parameters: {'alpha': 0.6309469262730669, 'lambda': 0.46457830327878785, 'max_depth': 4, 'eta': 0.007080496151588928, 'subsample': 0.9302075312892337, 'colsample_bytree': 0.6264504190215043}. Best is trial 72 with value: 0.78875.
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-30 17:01:21,268] Trial 92 finished with value: 0.783125 and parameters: {'alpha': 0.7530321618428758, 'lambda': 0.5895681731961546, 'max_depth': 4, 'eta': 0.012168069278303474, 'subsample': 0.9628245102580536, 'colsample_bytree': 0.6234507196560698}. Best is trial 72 with value: 0.78875.
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-30 17:01:21,919] Trial 93 finished with value: 0.78375 and parameters: {'alpha': 0.4044634392204497, 'lambda': 0.20881065638581284, 'max_depth': 4, 'eta': 0.02351986164605174, 'subsample': 0.9874036980949124, 'colsample_bytree': 0.6388320021760034}. Best is trial 72 with value: 0.78875.
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-30 17:01:22,936] Trial 94 finished with value: 0.779375 and parameters: {'alpha': 0.15169228561013326, 'lambda': 0.9025852439196631, 'max_depth': 4, 'eta': 0.005331590025399791, 'subsample': 0.9005081940341042, 'colsample_bytree': 0.6168811607135778}. Best is trial 72 with value: 0.78875.
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-30 17:01:24,017] Trial 95 finished with value: 0.781875 and parameters: {'alpha': 0.23071550360966203, 'lambda': 0.4557839101506616, 'max_depth': 5, 'eta': 0.0019435389832981502, 'subsample': 0.9500845942030101, 'colsample_bytree': 0.7824376594230049}. Best is trial 72 with value: 0.78875.
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-30 17:01:24,369] Trial 96 finished with value: 0.78 and parameters: {'alpha': 0.5519354261889599, 'lambda': 0.10330868838480797, 'max_depth': 4, 'eta': 0.06215710289223693, 'subsample': 0.9738762604537268, 'colsample_bytree': 0.6633043708323566}. Best is trial 72 with value: 0.78875.
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-30 17:01:25,099] Trial 97 finished with value: 0.779375 and parameters: {'alpha': 0.04773627276091842, 'lambda': 0.9904642156941096, 'max_depth': 3, 'eta': 0.03219912348319888, 'subsample': 0.9168672025418484, 'colsample_bytree': 0.5896365595845032}. Best is trial 72 with value: 0.78875.
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-30 17:01:25,966] Trial 98 finished with value: 0.781875 and parameters: {'alpha': 0.12145754270579093, 'lambda': 0.07002769018394835, 'max_depth': 3, 'eta': 0.00986384280762817, 'subsample': 0.9998795735195183, 'colsample_bytree': 0.6309887013454917}. Best is trial 72 with value: 0.78875.
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_22092\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-30 17:01:26,893] Trial 99 finished with value: 0.775 and parameters: {'alpha': 0.005804224553454335, 'lambda': 0.17323954138154116, 'max_depth': 4, 'eta': 0.0032877379337747595, 'subsample': 0.9353669286440219, 'colsample_bytree': 0.6056532794847074}. Best is trial 72 with value: 0.78875.

# %% [markdown]
# - xgb_平均スコア

# %%
# 全フォールドの平均スコアを計算
xgb_average_score = sum(xgb_fold_scores) / n_splits
print(f"XGB Average accuracy across all folds: {xgb_average_score:.4f}")

xgb_average_conf = sum(xgb_conf_scores) / n_splits
print(f"XGB Average conf-matrix across all folds: {xgb_average_conf}")
# Out:
# XGB Average accuracy across all folds: 0.7758
# XGB Average conf-matrix across all folds: [[628.8 184.4]
#  [174.4 612.4]]

# %% [markdown]
# - xgb_予測平均

# %%
# 予測の平均を計算
xgb_y_test_pred_avg = np.mean(xgb_test_predictions, axis=0)

# 最終的な予測結果を整数に変換
xgb_y_test_pred_int = (xgb_y_test_pred_avg > xgb_threshold).astype(int)

# %% [markdown]
# - output

# %%
# 現在の日時を取得してフォーマットする
current_time = datetime.now().strftime("%Y%m%d_%H%M%S")
output = f'../data/output/{current_time}_XGBoost_cv{xgb_average_score:.4f}.csv'

submit = pd.DataFrame({
    '0': test['gameId'],
    '1': xgb_y_test_pred_int
})

# カラムヘッダー消去して出力
# ヘッダーなしでCSVファイルとして保存
submit.to_csv(output, header=False, index=False)

# %% [markdown]
# ## CatBoost

# %%
for train_index, val_index in kf.split(X):
    X_train_fold, X_val_fold = X.iloc[train_index], X.iloc[val_index]
    y_train_fold, y_val_fold = y[train_index], y[val_index]

    # Optunaでのハイパーパラメータチューニング
    def objective(trial):
        param = {
            'iterations': 1000,
            'depth': trial.suggest_int('depth', 4, 10),
            'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3),
            'random_strength': trial.suggest_int('random_strength', 1, 20),
            'bagging_temperature': trial.suggest_float('bagging_temperature', 0.0, 1.0),
            'l2_leaf_reg': trial.suggest_float('l2_leaf_reg', 1e-3, 100),
            'scale_pos_weight': trial.suggest_float('scale_pos_weight', 0.1, 10.0),
            'loss_function': 'Logloss'
        }

        model = cb.CatBoostClassifier(**param, verbose=False)
        model.fit(X_train_fold, y_train_fold, eval_set=(X_val_fold, y_val_fold), early_stopping_rounds=100)
        preds = model.predict(X_val_fold)
        accuracy = accuracy_score(y_val_fold, preds)
        return accuracy

    cb_study = optuna.create_study(direction='maximize')
    cb_study.optimize(objective, n_trials=100)

    # 各フォールドの最適パラメータでモデルを再学習
    cb_best_params = cb_study.best_params
    cb_best_params['loss_function'] = 'Logloss'
    model_fold = cb.CatBoostClassifier(**cb_best_params, verbose=False)
    model_fold.fit(X_train_fold, y_train_fold)

    # 各フォールドのモデル性能を評価
    cb_y_val_pred = model_fold.predict(X_val_fold)
    cb_fold_accuracy = accuracy_score(y_val_fold, cb_y_val_pred)
    cb_fold_scores.append(cb_fold_accuracy)

    # 混同行列
    cb_conf_matrix = confusion_matrix(y_val_fold, cb_y_val_pred)
    cb_conf_scores.append(cb_conf_matrix)

    # テストデータセットでの予測
    cb_y_test_pred_fold = model_fold.predict(test_drop_gameId)
    cb_test_predictions.append(cb_y_test_pred_fold)
# Out:
# [I 2024-01-30 17:01:27,050] A new study created in memory with name: no-name-2b2c21d5-7228-4e6c-9f2a-ef998bbb30fa
# [I 2024-01-30 17:01:27,931] Trial 0 finished with value: 0.788125 and parameters: {'depth': 6, 'learning_rate': 0.26914057895058097, 'random_strength': 6, 'bagging_temperature': 0.8560103537312654, 'l2_leaf_reg': 85.08607561582214, 'scale_pos_weight': 1.3661614775406388}. Best is trial 0 with value: 0.788125.
# [I 2024-01-30 17:01:28,781] Trial 1 finished with value: 0.72875 and parameters: {'depth': 7, 'learning_rate': 0.1551089584567397, 'random_strength': 17, 'bagging_temperature': 0.6502428444113829, 'l2_leaf_reg': 39.371496876179236, 'scale_pos_weight': 4.787911321831403}. Best is trial 0 with value: 0.788125.
# [I 2024-01-30 17:01:29,447] Trial 2 finished with value: 0.72875 and parameters: {'depth': 6, 'learning_rate': 0.18416418270116933, 'random_strength': 14, 'bagging_temperature': 0.12578961928524868, 'l2_leaf_reg': 48.659144793053954, 'scale_pos_weight': 4.710313157867452}. Best is trial 0 with value: 0.788125.
# [I 2024-01-30 17:01:30,334] Trial 3 finished with value: 0.70875 and parameters: {'depth': 4, 'learning_rate': 0.1070755456671051, 'random_strength': 6, 'bagging_temperature': 0.855543955338318, 'l2_leaf_reg': 1.4718485248485664, 'scale_pos_weight': 7.916386555380496}. Best is trial 0 with value: 0.788125.
# [I 2024-01-30 17:01:31,031] Trial 4 finished with value: 0.735625 and parameters: {'depth': 5, 'learning_rate': 0.25009369384816876, 'random_strength': 11, 'bagging_temperature': 0.31674085041571587, 'l2_leaf_reg': 53.96295106425101, 'scale_pos_weight': 4.552693369187939}. Best is trial 0 with value: 0.788125.
# [I 2024-01-30 17:01:31,867] Trial 5 finished with value: 0.730625 and parameters: {'depth': 10, 'learning_rate': 0.24833874490914418, 'random_strength': 5, 'bagging_temperature': 0.7721269851043837, 'l2_leaf_reg': 92.92706549655567, 'scale_pos_weight': 3.858383784671219}. Best is trial 0 with value: 0.788125.
# [I 2024-01-30 17:01:35,917] Trial 6 finished with value: 0.715 and parameters: {'depth': 10, 'learning_rate': 0.012818260398368055, 'random_strength': 20, 'bagging_temperature': 0.6287531193001188, 'l2_leaf_reg': 4.579799942825075, 'scale_pos_weight': 6.74931060736666}. Best is trial 0 with value: 0.788125.
# [I 2024-01-30 17:01:36,711] Trial 7 finished with value: 0.714375 and parameters: {'depth': 8, 'learning_rate': 0.205328237688539, 'random_strength': 15, 'bagging_temperature': 0.631476865262905, 'l2_leaf_reg': 54.96981885447833, 'scale_pos_weight': 6.359486987263241}. Best is trial 0 with value: 0.788125.
# [I 2024-01-30 17:01:37,297] Trial 8 finished with value: 0.71875 and parameters: {'depth': 5, 'learning_rate': 0.244556569267868, 'random_strength': 13, 'bagging_temperature': 0.4679392939044992, 'l2_leaf_reg': 19.207488366920117, 'scale_pos_weight': 5.51158599099655}. Best is trial 0 with value: 0.788125.
# [I 2024-01-30 17:01:38,074] Trial 9 finished with value: 0.721875 and parameters: {'depth': 6, 'learning_rate': 0.10844050269454479, 'random_strength': 5, 'bagging_temperature': 0.13531511306795618, 'l2_leaf_reg': 18.294103286509035, 'scale_pos_weight': 5.8674891162475085}. Best is trial 0 with value: 0.788125.
# [I 2024-01-30 17:01:38,674] Trial 10 finished with value: 0.783125 and parameters: {'depth': 8, 'learning_rate': 0.2982210755227905, 'random_strength': 1, 'bagging_temperature': 0.9607301032817248, 'l2_leaf_reg': 99.14882642666677, 'scale_pos_weight': 0.663362780189283}. Best is trial 0 with value: 0.788125.
# [I 2024-01-30 17:01:39,319] Trial 11 finished with value: 0.768125 and parameters: {'depth': 8, 'learning_rate': 0.2977325828595271, 'random_strength': 1, 'bagging_temperature': 0.9985643377438528, 'l2_leaf_reg': 97.5706395730339, 'scale_pos_weight': 0.5111974155708969}. Best is trial 0 with value: 0.788125.
# [I 2024-01-30 17:01:40,172] Trial 12 finished with value: 0.755625 and parameters: {'depth': 8, 'learning_rate': 0.29871182191900736, 'random_strength': 1, 'bagging_temperature': 0.970447604522577, 'l2_leaf_reg': 83.03302371376725, 'scale_pos_weight': 0.3309651992013635}. Best is trial 0 with value: 0.788125.
# [I 2024-01-30 17:01:40,890] Trial 13 finished with value: 0.765 and parameters: {'depth': 9, 'learning_rate': 0.2974794465423456, 'random_strength': 8, 'bagging_temperature': 0.8031549117939475, 'l2_leaf_reg': 78.15842320731934, 'scale_pos_weight': 2.027021449847137}. Best is trial 0 with value: 0.788125.
# [I 2024-01-30 17:01:41,527] Trial 14 finished with value: 0.75375 and parameters: {'depth': 7, 'learning_rate': 0.2609356366039822, 'random_strength': 4, 'bagging_temperature': 0.9060785694440993, 'l2_leaf_reg': 73.25926408255472, 'scale_pos_weight': 2.4313236531351876}. Best is trial 0 with value: 0.788125.
# [I 2024-01-30 17:01:42,175] Trial 15 finished with value: 0.779375 and parameters: {'depth': 6, 'learning_rate': 0.22325584043944596, 'random_strength': 8, 'bagging_temperature': 0.7856365051552048, 'l2_leaf_reg': 99.4394724476915, 'scale_pos_weight': 1.620585662682426}. Best is trial 0 with value: 0.788125.
# [I 2024-01-30 17:01:42,922] Trial 16 finished with value: 0.740625 and parameters: {'depth': 9, 'learning_rate': 0.2701931256390753, 'random_strength': 3, 'bagging_temperature': 0.967283051127492, 'l2_leaf_reg': 84.87444861321212, 'scale_pos_weight': 3.0793123027080593}. Best is trial 0 with value: 0.788125.
# [I 2024-01-30 17:01:43,794] Trial 17 finished with value: 0.788125 and parameters: {'depth': 4, 'learning_rate': 0.21582447616496664, 'random_strength': 8, 'bagging_temperature': 0.8642106013710513, 'l2_leaf_reg': 68.36182769350074, 'scale_pos_weight': 1.1641244115761216}. Best is trial 0 with value: 0.788125.
# [I 2024-01-30 17:01:44,671] Trial 18 finished with value: 0.750625 and parameters: {'depth': 4, 'learning_rate': 0.21197153914368175, 'random_strength': 9, 'bagging_temperature': 0.7152751661397793, 'l2_leaf_reg': 70.39013505729703, 'scale_pos_weight': 3.1989692986407787}. Best is trial 0 with value: 0.788125.
# [I 2024-01-30 17:01:45,438] Trial 19 finished with value: 0.7775 and parameters: {'depth': 5, 'learning_rate': 0.1872699716841058, 'random_strength': 11, 'bagging_temperature': 0.8603642470477211, 'l2_leaf_reg': 64.82759775498481, 'scale_pos_weight': 1.7525526238751685}. Best is trial 0 with value: 0.788125.
# [I 2024-01-30 17:01:46,082] Trial 20 finished with value: 0.789375 and parameters: {'depth': 4, 'learning_rate': 0.2273525547875813, 'random_strength': 7, 'bagging_temperature': 0.5246454607887199, 'l2_leaf_reg': 82.04231938309779, 'scale_pos_weight': 1.2210351184492398}. Best is trial 20 with value: 0.789375.
# [I 2024-01-30 17:01:46,937] Trial 21 finished with value: 0.7825 and parameters: {'depth': 4, 'learning_rate': 0.2375736637167401, 'random_strength': 7, 'bagging_temperature': 0.5337666029478502, 'l2_leaf_reg': 88.38992324882774, 'scale_pos_weight': 1.3359675113807472}. Best is trial 20 with value: 0.789375.
# [I 2024-01-30 17:01:47,726] Trial 22 finished with value: 0.7575 and parameters: {'depth': 5, 'learning_rate': 0.22276972347426063, 'random_strength': 10, 'bagging_temperature': 0.7382680297647717, 'l2_leaf_reg': 79.2426248968534, 'scale_pos_weight': 2.6054917494569088}. Best is trial 20 with value: 0.789375.
# [I 2024-01-30 17:01:48,618] Trial 23 finished with value: 0.693125 and parameters: {'depth': 4, 'learning_rate': 0.2657610256089793, 'random_strength': 7, 'bagging_temperature': 0.875339152341572, 'l2_leaf_reg': 87.73200796109731, 'scale_pos_weight': 0.1593624355780643}. Best is trial 20 with value: 0.789375.
# [I 2024-01-30 17:01:49,186] Trial 24 finished with value: 0.78625 and parameters: {'depth': 5, 'learning_rate': 0.2707653181306926, 'random_strength': 3, 'bagging_temperature': 0.53162851215687, 'l2_leaf_reg': 66.59558817393685, 'scale_pos_weight': 1.1726212214000618}. Best is trial 20 with value: 0.789375.
# [I 2024-01-30 17:01:50,135] Trial 25 finished with value: 0.8 and parameters: {'depth': 4, 'learning_rate': 0.20048295643413724, 'random_strength': 12, 'bagging_temperature': 0.40014204984161167, 'l2_leaf_reg': 76.61967128840801, 'scale_pos_weight': 1.1075717147858768}. Best is trial 25 with value: 0.8.
# [I 2024-01-30 17:01:50,801] Trial 26 finished with value: 0.758125 and parameters: {'depth': 6, 'learning_rate': 0.194839379055225, 'random_strength': 12, 'bagging_temperature': 0.36375510160913005, 'l2_leaf_reg': 78.58689686692504, 'scale_pos_weight': 2.201647230585435}. Best is trial 25 with value: 0.8.
# [I 2024-01-30 17:01:51,677] Trial 27 finished with value: 0.741875 and parameters: {'depth': 7, 'learning_rate': 0.23185890164047707, 'random_strength': 10, 'bagging_temperature': 0.429694601791586, 'l2_leaf_reg': 91.07971861773947, 'scale_pos_weight': 3.412831636139232}. Best is trial 25 with value: 0.8.
# [I 2024-01-30 17:01:52,633] Trial 28 finished with value: 0.795 and parameters: {'depth': 5, 'learning_rate': 0.17175310051226522, 'random_strength': 18, 'bagging_temperature': 0.24110261439133168, 'l2_leaf_reg': 75.87389928775748, 'scale_pos_weight': 1.1485364611523738}. Best is trial 25 with value: 0.8.
# [I 2024-01-30 17:01:53,750] Trial 29 finished with value: 0.79125 and parameters: {'depth': 4, 'learning_rate': 0.16707584888600738, 'random_strength': 19, 'bagging_temperature': 0.27425636647752233, 'l2_leaf_reg': 62.25352959232971, 'scale_pos_weight': 0.8641215285518136}. Best is trial 25 with value: 0.8.
# [I 2024-01-30 17:01:54,550] Trial 30 finished with value: 0.754375 and parameters: {'depth': 5, 'learning_rate': 0.16969099288475695, 'random_strength': 19, 'bagging_temperature': 0.23982056218732886, 'l2_leaf_reg': 60.89251514209425, 'scale_pos_weight': 2.5222615935201356}. Best is trial 25 with value: 0.8.
# [I 2024-01-30 17:01:55,682] Trial 31 finished with value: 0.79375 and parameters: {'depth': 4, 'learning_rate': 0.17279015823338767, 'random_strength': 17, 'bagging_temperature': 0.2753731834045193, 'l2_leaf_reg': 73.81402302964197, 'scale_pos_weight': 0.9645921979044719}. Best is trial 25 with value: 0.8.
# [I 2024-01-30 17:01:56,744] Trial 32 finished with value: 0.780625 and parameters: {'depth': 4, 'learning_rate': 0.15505705507380269, 'random_strength': 17, 'bagging_temperature': 0.25482596214609876, 'l2_leaf_reg': 71.10843276224423, 'scale_pos_weight': 0.6860989130826498}. Best is trial 25 with value: 0.8.
# [I 2024-01-30 17:01:57,689] Trial 33 finished with value: 0.774375 and parameters: {'depth': 4, 'learning_rate': 0.17289341579872516, 'random_strength': 17, 'bagging_temperature': 0.02999346835155625, 'l2_leaf_reg': 61.95669150506241, 'scale_pos_weight': 1.7793736948506984}. Best is trial 25 with value: 0.8.
# [I 2024-01-30 17:01:59,197] Trial 34 finished with value: 0.68125 and parameters: {'depth': 5, 'learning_rate': 0.1310033904765292, 'random_strength': 18, 'bagging_temperature': 0.3680802409457362, 'l2_leaf_reg': 74.67067194041584, 'scale_pos_weight': 0.12494002567662021}. Best is trial 25 with value: 0.8.
# [I 2024-01-30 17:02:00,432] Trial 35 finished with value: 0.79125 and parameters: {'depth': 4, 'learning_rate': 0.17315754959317753, 'random_strength': 15, 'bagging_temperature': 0.23934952291417894, 'l2_leaf_reg': 75.84881933807668, 'scale_pos_weight': 0.8628972664249589}. Best is trial 25 with value: 0.8.
# [I 2024-01-30 17:02:01,423] Trial 36 finished with value: 0.78125 and parameters: {'depth': 5, 'learning_rate': 0.19901005868034807, 'random_strength': 20, 'bagging_temperature': 0.29680216506629054, 'l2_leaf_reg': 59.54201585701541, 'scale_pos_weight': 1.5677152793690607}. Best is trial 25 with value: 0.8.
# [I 2024-01-30 17:02:02,298] Trial 37 finished with value: 0.783125 and parameters: {'depth': 4, 'learning_rate': 0.14879911460651085, 'random_strength': 15, 'bagging_temperature': 0.21747554124788662, 'l2_leaf_reg': 46.57108744798708, 'scale_pos_weight': 0.7180270869479018}. Best is trial 25 with value: 0.8.
# [I 2024-01-30 17:02:03,127] Trial 38 finished with value: 0.764375 and parameters: {'depth': 6, 'learning_rate': 0.19057593040840826, 'random_strength': 18, 'bagging_temperature': 0.15152643326140297, 'l2_leaf_reg': 67.71686143191258, 'scale_pos_weight': 1.9460982201383077}. Best is trial 25 with value: 0.8.
# [I 2024-01-30 17:02:03,908] Trial 39 finished with value: 0.730625 and parameters: {'depth': 5, 'learning_rate': 0.20423831089229846, 'random_strength': 16, 'bagging_temperature': 0.33097396350269914, 'l2_leaf_reg': 56.217143535492326, 'scale_pos_weight': 4.139345380123166}. Best is trial 25 with value: 0.8.
# [I 2024-01-30 17:02:04,926] Trial 40 finished with value: 0.78875 and parameters: {'depth': 4, 'learning_rate': 0.13965094279935958, 'random_strength': 13, 'bagging_temperature': 0.40601185895313097, 'l2_leaf_reg': 51.05316695619513, 'scale_pos_weight': 0.9911249286656061}. Best is trial 25 with value: 0.8.
# [I 2024-01-30 17:02:06,109] Trial 41 finished with value: 0.791875 and parameters: {'depth': 4, 'learning_rate': 0.17189337207625724, 'random_strength': 15, 'bagging_temperature': 0.2815586125785285, 'l2_leaf_reg': 75.42393220601558, 'scale_pos_weight': 0.7742185522864551}. Best is trial 25 with value: 0.8.
# [I 2024-01-30 17:02:07,475] Trial 42 finished with value: 0.785625 and parameters: {'depth': 4, 'learning_rate': 0.16146905285891722, 'random_strength': 14, 'bagging_temperature': 0.28204244520580185, 'l2_leaf_reg': 72.99249125880937, 'scale_pos_weight': 1.195312712716599}. Best is trial 25 with value: 0.8.
# [I 2024-01-30 17:02:08,710] Trial 43 finished with value: 0.77875 and parameters: {'depth': 5, 'learning_rate': 0.17687575018785992, 'random_strength': 19, 'bagging_temperature': 0.3247536575905845, 'l2_leaf_reg': 82.20443579409738, 'scale_pos_weight': 0.5158593826245743}. Best is trial 25 with value: 0.8.
# [I 2024-01-30 17:02:09,807] Trial 44 finished with value: 0.690625 and parameters: {'depth': 4, 'learning_rate': 0.18531905354764078, 'random_strength': 16, 'bagging_temperature': 0.19741480686705415, 'l2_leaf_reg': 65.54799108321468, 'scale_pos_weight': 0.14640902373525}. Best is trial 25 with value: 0.8.
# [I 2024-01-30 17:02:10,824] Trial 45 finished with value: 0.775 and parameters: {'depth': 5, 'learning_rate': 0.1536335985972852, 'random_strength': 18, 'bagging_temperature': 0.19624250786232061, 'l2_leaf_reg': 77.08206987951458, 'scale_pos_weight': 1.6630898213742216}. Best is trial 25 with value: 0.8.
# [I 2024-01-30 17:02:11,791] Trial 46 finished with value: 0.79 and parameters: {'depth': 4, 'learning_rate': 0.16592046832250346, 'random_strength': 16, 'bagging_temperature': 0.28082614715571064, 'l2_leaf_reg': 71.34335693749836, 'scale_pos_weight': 0.818286002073771}. Best is trial 25 with value: 0.8.
# [I 2024-01-30 17:02:13,009] Trial 47 finished with value: 0.7675 and parameters: {'depth': 4, 'learning_rate': 0.18305435617483495, 'random_strength': 14, 'bagging_temperature': 0.17050810940117178, 'l2_leaf_reg': 92.66587204616626, 'scale_pos_weight': 2.1574513724112947}. Best is trial 25 with value: 0.8.
# [I 2024-01-30 17:02:13,742] Trial 48 finished with value: 0.754375 and parameters: {'depth': 5, 'learning_rate': 0.20272733772429077, 'random_strength': 20, 'bagging_temperature': 0.10407788280951522, 'l2_leaf_reg': 85.15061918775652, 'scale_pos_weight': 2.667297953971236}. Best is trial 25 with value: 0.8.
# [I 2024-01-30 17:02:14,835] Trial 49 finished with value: 0.775625 and parameters: {'depth': 6, 'learning_rate': 0.13108617847256296, 'random_strength': 19, 'bagging_temperature': 0.26777677575433056, 'l2_leaf_reg': 79.72756690443744, 'scale_pos_weight': 0.5593590994471905}. Best is trial 25 with value: 0.8.
# [I 2024-01-30 17:02:15,895] Trial 50 finished with value: 0.783125 and parameters: {'depth': 4, 'learning_rate': 0.1630882373895338, 'random_strength': 12, 'bagging_temperature': 0.3454678921667272, 'l2_leaf_reg': 72.25989782778144, 'scale_pos_weight': 1.4734693824242366}. Best is trial 25 with value: 0.8.
# [I 2024-01-30 17:02:16,919] Trial 51 finished with value: 0.790625 and parameters: {'depth': 4, 'learning_rate': 0.17769568180947426, 'random_strength': 15, 'bagging_temperature': 0.2299509116790644, 'l2_leaf_reg': 76.35552460228682, 'scale_pos_weight': 1.022180685533891}. Best is trial 25 with value: 0.8.
# [I 2024-01-30 17:02:17,747] Trial 52 finished with value: 0.781875 and parameters: {'depth': 4, 'learning_rate': 0.19602369004205727, 'random_strength': 15, 'bagging_temperature': 0.30660048089341124, 'l2_leaf_reg': 66.91402706742446, 'scale_pos_weight': 0.7530651923095203}. Best is trial 25 with value: 0.8.
# [I 2024-01-30 17:02:18,887] Trial 53 finished with value: 0.773125 and parameters: {'depth': 4, 'learning_rate': 0.17531997697550455, 'random_strength': 17, 'bagging_temperature': 0.2401547900451969, 'l2_leaf_reg': 74.90023276513071, 'scale_pos_weight': 0.44105749547663636}. Best is trial 25 with value: 0.8.
# [I 2024-01-30 17:02:19,819] Trial 54 finished with value: 0.785 and parameters: {'depth': 5, 'learning_rate': 0.1476281236604943, 'random_strength': 16, 'bagging_temperature': 0.3822186698584733, 'l2_leaf_reg': 63.52944410005116, 'scale_pos_weight': 1.4895468796037001}. Best is trial 25 with value: 0.8.
# [I 2024-01-30 17:02:20,652] Trial 55 finished with value: 0.76125 and parameters: {'depth': 4, 'learning_rate': 0.1909735986393623, 'random_strength': 13, 'bagging_temperature': 0.3148707933404218, 'l2_leaf_reg': 69.51335751374356, 'scale_pos_weight': 1.9747010827276088}. Best is trial 25 with value: 0.8.
# [I 2024-01-30 17:02:21,383] Trial 56 finished with value: 0.788125 and parameters: {'depth': 4, 'learning_rate': 0.21747191471740124, 'random_strength': 18, 'bagging_temperature': 0.43242584770515113, 'l2_leaf_reg': 81.60614910301926, 'scale_pos_weight': 0.9031893339102203}. Best is trial 25 with value: 0.8.
# [I 2024-01-30 17:02:22,477] Trial 57 finished with value: 0.651875 and parameters: {'depth': 5, 'learning_rate': 0.1665708218799454, 'random_strength': 13, 'bagging_temperature': 0.26872583979334463, 'l2_leaf_reg': 74.44750662170178, 'scale_pos_weight': 0.11024683218735187}. Best is trial 25 with value: 0.8.
# [I 2024-01-30 17:02:23,318] Trial 58 finished with value: 0.784375 and parameters: {'depth': 7, 'learning_rate': 0.20583061482368614, 'random_strength': 12, 'bagging_temperature': 0.1862250990984913, 'l2_leaf_reg': 85.46428793158572, 'scale_pos_weight': 1.4001288771094407}. Best is trial 25 with value: 0.8.
# [I 2024-01-30 17:02:24,233] Trial 59 finished with value: 0.79 and parameters: {'depth': 5, 'learning_rate': 0.17886040926646588, 'random_strength': 14, 'bagging_temperature': 0.33233081273994414, 'l2_leaf_reg': 57.468325727898765, 'scale_pos_weight': 0.9970850752338922}. Best is trial 25 with value: 0.8.
# [I 2024-01-30 17:02:25,267] Trial 60 finished with value: 0.761875 and parameters: {'depth': 9, 'learning_rate': 0.15878073887578442, 'random_strength': 19, 'bagging_temperature': 0.11984231311617283, 'l2_leaf_reg': 63.98015674314931, 'scale_pos_weight': 2.2132393778137462}. Best is trial 25 with value: 0.8.
# [I 2024-01-30 17:02:26,198] Trial 61 finished with value: 0.791875 and parameters: {'depth': 4, 'learning_rate': 0.1806999346586108, 'random_strength': 15, 'bagging_temperature': 0.2887273583598446, 'l2_leaf_reg': 77.29931918813021, 'scale_pos_weight': 1.0891513501758276}. Best is trial 25 with value: 0.8.
# [I 2024-01-30 17:02:27,222] Trial 62 finished with value: 0.773125 and parameters: {'depth': 4, 'learning_rate': 0.18975277248858527, 'random_strength': 15, 'bagging_temperature': 0.22117591822732666, 'l2_leaf_reg': 78.16406057590537, 'scale_pos_weight': 0.4337776496626383}. Best is trial 25 with value: 0.8.
# [I 2024-01-30 17:02:28,023] Trial 63 finished with value: 0.79 and parameters: {'depth': 4, 'learning_rate': 0.21133321975669622, 'random_strength': 17, 'bagging_temperature': 0.2902437834127227, 'l2_leaf_reg': 80.92233797316119, 'scale_pos_weight': 1.2594753043131117}. Best is trial 25 with value: 0.8.
# [I 2024-01-30 17:02:28,983] Trial 64 finished with value: 0.790625 and parameters: {'depth': 4, 'learning_rate': 0.18435058656137818, 'random_strength': 16, 'bagging_temperature': 0.3528458240509228, 'l2_leaf_reg': 69.1941611645462, 'scale_pos_weight': 0.9328528068155992}. Best is trial 25 with value: 0.8.
# [I 2024-01-30 17:02:29,865] Trial 65 finished with value: 0.778125 and parameters: {'depth': 4, 'learning_rate': 0.17375676763896564, 'random_strength': 18, 'bagging_temperature': 0.25108828646124803, 'l2_leaf_reg': 74.6973184206103, 'scale_pos_weight': 1.6885217988950325}. Best is trial 25 with value: 0.8.
# [I 2024-01-30 17:02:31,230] Trial 66 finished with value: 0.759375 and parameters: {'depth': 10, 'learning_rate': 0.1685840380935376, 'random_strength': 20, 'bagging_temperature': 0.3975568403777604, 'l2_leaf_reg': 84.37902518334138, 'scale_pos_weight': 0.3657176425677277}. Best is trial 25 with value: 0.8.
# [I 2024-01-30 17:02:32,031] Trial 67 finished with value: 0.78875 and parameters: {'depth': 5, 'learning_rate': 0.19684131017412346, 'random_strength': 17, 'bagging_temperature': 0.2929209204478985, 'l2_leaf_reg': 71.64158580389051, 'scale_pos_weight': 1.2782931571943241}. Best is trial 25 with value: 0.8.
# [I 2024-01-30 17:02:32,946] Trial 68 finished with value: 0.764375 and parameters: {'depth': 6, 'learning_rate': 0.1471129359757269, 'random_strength': 14, 'bagging_temperature': 0.3466674002120606, 'l2_leaf_reg': 88.56797464419208, 'scale_pos_weight': 1.9014500659668307}. Best is trial 25 with value: 0.8.
# [I 2024-01-30 17:02:34,137] Trial 69 finished with value: 0.78625 and parameters: {'depth': 4, 'learning_rate': 0.1580625322780319, 'random_strength': 15, 'bagging_temperature': 0.21240482505340988, 'l2_leaf_reg': 78.06239093947828, 'scale_pos_weight': 0.6961634063719768}. Best is trial 25 with value: 0.8.
# [I 2024-01-30 17:02:35,249] Trial 70 finished with value: 0.74875 and parameters: {'depth': 4, 'learning_rate': 0.18469257328497543, 'random_strength': 11, 'bagging_temperature': 0.2541811351445424, 'l2_leaf_reg': 68.15080198571212, 'scale_pos_weight': 2.746364561010467}. Best is trial 25 with value: 0.8.
# [I 2024-01-30 17:02:36,553] Trial 71 finished with value: 0.790625 and parameters: {'depth': 4, 'learning_rate': 0.1768624030794566, 'random_strength': 15, 'bagging_temperature': 0.2279950142961607, 'l2_leaf_reg': 76.35096298260727, 'scale_pos_weight': 1.0474385501615586}. Best is trial 25 with value: 0.8.
# [I 2024-01-30 17:02:37,881] Trial 72 finished with value: 0.784375 and parameters: {'depth': 4, 'learning_rate': 0.17086329579415796, 'random_strength': 16, 'bagging_temperature': 0.17070502014324793, 'l2_leaf_reg': 76.38803754818561, 'scale_pos_weight': 1.4878769556678435}. Best is trial 25 with value: 0.8.
# [I 2024-01-30 17:02:38,707] Trial 73 finished with value: 0.7825 and parameters: {'depth': 4, 'learning_rate': 0.1939863448600293, 'random_strength': 14, 'bagging_temperature': 0.3090007939197389, 'l2_leaf_reg': 80.56998505369768, 'scale_pos_weight': 0.6794260621760873}. Best is trial 25 with value: 0.8.
# [I 2024-01-30 17:02:40,041] Trial 74 finished with value: 0.788125 and parameters: {'depth': 4, 'learning_rate': 0.18089210086767668, 'random_strength': 17, 'bagging_temperature': 0.22677441107898608, 'l2_leaf_reg': 72.70632947640253, 'scale_pos_weight': 1.0712824655881696}. Best is trial 25 with value: 0.8.
# [I 2024-01-30 17:02:41,541] Trial 75 finished with value: 0.761875 and parameters: {'depth': 5, 'learning_rate': 0.162988328243062, 'random_strength': 12, 'bagging_temperature': 0.26778622009822817, 'l2_leaf_reg': 83.05723185544898, 'scale_pos_weight': 0.361617772990722}. Best is trial 25 with value: 0.8.
# [I 2024-01-30 17:02:42,361] Trial 76 finished with value: 0.773125 and parameters: {'depth': 4, 'learning_rate': 0.20795501784308829, 'random_strength': 19, 'bagging_temperature': 0.38396627717769316, 'l2_leaf_reg': 65.68347908397818, 'scale_pos_weight': 1.7784440805826636}. Best is trial 25 with value: 0.8.
# [I 2024-01-30 17:02:43,290] Trial 77 finished with value: 0.76375 and parameters: {'depth': 5, 'learning_rate': 0.19871803879957387, 'random_strength': 15, 'bagging_temperature': 0.3147954493041172, 'l2_leaf_reg': 70.36734660554457, 'scale_pos_weight': 2.2482507872038244}. Best is trial 25 with value: 0.8.
# [I 2024-01-30 17:02:44,433] Trial 78 finished with value: 0.789375 and parameters: {'depth': 4, 'learning_rate': 0.15145246948940724, 'random_strength': 18, 'bagging_temperature': 0.24568975779663837, 'l2_leaf_reg': 61.822014758584714, 'scale_pos_weight': 1.200419944765299}. Best is trial 25 with value: 0.8.
# [I 2024-01-30 17:02:45,896] Trial 79 finished with value: 0.78875 and parameters: {'depth': 4, 'learning_rate': 0.14178575347648248, 'random_strength': 16, 'bagging_temperature': 0.14772282348394347, 'l2_leaf_reg': 79.1229524627371, 'scale_pos_weight': 0.921583881693155}. Best is trial 25 with value: 0.8.
# [I 2024-01-30 17:02:47,055] Trial 80 finished with value: 0.78125 and parameters: {'depth': 5, 'learning_rate': 0.17312005710006312, 'random_strength': 10, 'bagging_temperature': 0.36236194793968124, 'l2_leaf_reg': 77.2535724307027, 'scale_pos_weight': 0.5774779691024182}. Best is trial 25 with value: 0.8.
# [I 2024-01-30 17:02:48,036] Trial 81 finished with value: 0.79 and parameters: {'depth': 4, 'learning_rate': 0.18202053510293784, 'random_strength': 16, 'bagging_temperature': 0.34418681192265455, 'l2_leaf_reg': 69.94627989163004, 'scale_pos_weight': 0.9649994298253161}. Best is trial 25 with value: 0.8.
# [I 2024-01-30 17:02:49,207] Trial 82 finished with value: 0.783125 and parameters: {'depth': 4, 'learning_rate': 0.18079695892621572, 'random_strength': 17, 'bagging_temperature': 0.286309203486514, 'l2_leaf_reg': 68.42592154035628, 'scale_pos_weight': 1.3727422155741558}. Best is trial 25 with value: 0.8.
# [I 2024-01-30 17:02:50,168] Trial 83 finished with value: 0.7925 and parameters: {'depth': 4, 'learning_rate': 0.18882796971596472, 'random_strength': 16, 'bagging_temperature': 0.2731871048289574, 'l2_leaf_reg': 73.96195970501296, 'scale_pos_weight': 0.7673635276579758}. Best is trial 25 with value: 0.8.
# [I 2024-01-30 17:02:51,045] Trial 84 finished with value: 0.773125 and parameters: {'depth': 4, 'learning_rate': 0.1894324415646454, 'random_strength': 13, 'bagging_temperature': 0.19591800210358187, 'l2_leaf_reg': 74.77445178807777, 'scale_pos_weight': 1.6531047746194152}. Best is trial 25 with value: 0.8.
# [I 2024-01-30 17:02:52,213] Trial 85 finished with value: 0.755625 and parameters: {'depth': 4, 'learning_rate': 0.15877227279855002, 'random_strength': 14, 'bagging_temperature': 0.26692404389751395, 'l2_leaf_reg': 80.0515412850843, 'scale_pos_weight': 0.2938346293977937}. Best is trial 25 with value: 0.8.
# [I 2024-01-30 17:02:53,647] Trial 86 finished with value: 0.789375 and parameters: {'depth': 4, 'learning_rate': 0.16689172164385943, 'random_strength': 18, 'bagging_temperature': 0.3238407566937429, 'l2_leaf_reg': 73.0450720573076, 'scale_pos_weight': 0.6935554406291491}. Best is trial 25 with value: 0.8.
# [I 2024-01-30 17:02:54,393] Trial 87 finished with value: 0.790625 and parameters: {'depth': 5, 'learning_rate': 0.20233224571818925, 'random_strength': 15, 'bagging_temperature': 0.21335791830996972, 'l2_leaf_reg': 75.91018379783073, 'scale_pos_weight': 1.1339023342700507}. Best is trial 25 with value: 0.8.
# [I 2024-01-30 17:02:55,742] Trial 88 finished with value: 0.6575 and parameters: {'depth': 4, 'learning_rate': 0.2135188389487226, 'random_strength': 19, 'bagging_temperature': 0.29771620687386735, 'l2_leaf_reg': 83.92251469772052, 'scale_pos_weight': 0.10706315730716454}. Best is trial 25 with value: 0.8.
# [I 2024-01-30 17:02:57,074] Trial 89 finished with value: 0.770625 and parameters: {'depth': 4, 'learning_rate': 0.19128356765384785, 'random_strength': 14, 'bagging_temperature': 0.2438348115608067, 'l2_leaf_reg': 65.75841252525302, 'scale_pos_weight': 1.8510816569740824}. Best is trial 25 with value: 0.8.
# [I 2024-01-30 17:02:58,118] Trial 90 finished with value: 0.779375 and parameters: {'depth': 4, 'learning_rate': 0.17142594775776354, 'random_strength': 17, 'bagging_temperature': 0.265177128028356, 'l2_leaf_reg': 86.82779472062327, 'scale_pos_weight': 0.501059323752088}. Best is trial 25 with value: 0.8.
# [I 2024-01-30 17:02:59,154] Trial 91 finished with value: 0.789375 and parameters: {'depth': 4, 'learning_rate': 0.18598275990938873, 'random_strength': 16, 'bagging_temperature': 0.3515971332052811, 'l2_leaf_reg': 70.69055606214724, 'scale_pos_weight': 0.824411980677605}. Best is trial 25 with value: 0.8.
# [I 2024-01-30 17:03:00,017] Trial 92 finished with value: 0.78 and parameters: {'depth': 4, 'learning_rate': 0.18393441130731655, 'random_strength': 16, 'bagging_temperature': 0.32660858163535456, 'l2_leaf_reg': 73.01035190895804, 'scale_pos_weight': 1.500632865805518}. Best is trial 25 with value: 0.8.
# [I 2024-01-30 17:03:00,945] Trial 93 finished with value: 0.785625 and parameters: {'depth': 8, 'learning_rate': 0.19818456764344836, 'random_strength': 15, 'bagging_temperature': 0.37103423524627793, 'l2_leaf_reg': 77.17381024160267, 'scale_pos_weight': 0.8738768193169294}. Best is trial 25 with value: 0.8.
# [I 2024-01-30 17:03:02,017] Trial 94 finished with value: 0.7875 and parameters: {'depth': 4, 'learning_rate': 0.16416176110255226, 'random_strength': 17, 'bagging_temperature': 0.28570874554413156, 'l2_leaf_reg': 69.01679007467054, 'scale_pos_weight': 1.1979754905511593}. Best is trial 25 with value: 0.8.
# [I 2024-01-30 17:03:03,048] Trial 95 finished with value: 0.765625 and parameters: {'depth': 5, 'learning_rate': 0.1764351196552521, 'random_strength': 9, 'bagging_temperature': 0.2320722874950775, 'l2_leaf_reg': 82.56147276868995, 'scale_pos_weight': 0.39932927135216595}. Best is trial 25 with value: 0.8.
# [I 2024-01-30 17:03:04,585] Trial 96 finished with value: 0.79 and parameters: {'depth': 4, 'learning_rate': 0.1560603452077254, 'random_strength': 13, 'bagging_temperature': 0.3058448070159595, 'l2_leaf_reg': 67.81805977717457, 'scale_pos_weight': 1.3997292009878597}. Best is trial 25 with value: 0.8.
# [I 2024-01-30 17:03:05,360] Trial 97 finished with value: 0.790625 and parameters: {'depth': 4, 'learning_rate': 0.20569376931183278, 'random_strength': 18, 'bagging_temperature': 0.4271774194693891, 'l2_leaf_reg': 63.48575861394053, 'scale_pos_weight': 0.927029140275899}. Best is trial 25 with value: 0.8.
# [I 2024-01-30 17:03:06,291] Trial 98 finished with value: 0.78125 and parameters: {'depth': 5, 'learning_rate': 0.19022178078726562, 'random_strength': 16, 'bagging_temperature': 0.2076913371131513, 'l2_leaf_reg': 74.20810948559857, 'scale_pos_weight': 0.6223933081771308}. Best is trial 25 with value: 0.8.
# [I 2024-01-30 17:03:07,566] Trial 99 finished with value: 0.7675 and parameters: {'depth': 4, 'learning_rate': 0.16756637012551015, 'random_strength': 20, 'bagging_temperature': 0.17992301533327537, 'l2_leaf_reg': 79.29749780388813, 'scale_pos_weight': 2.049139994350992}. Best is trial 25 with value: 0.8.
# [I 2024-01-30 17:03:10,601] A new study created in memory with name: no-name-44d7d663-94b3-4b1e-891f-cadd807c9697
# [I 2024-01-30 17:03:11,180] Trial 0 finished with value: 0.783125 and parameters: {'depth': 6, 'learning_rate': 0.21542747179729801, 'random_strength': 10, 'bagging_temperature': 0.5972774989222613, 'l2_leaf_reg': 37.92223110778493, 'scale_pos_weight': 0.5537156175061877}. Best is trial 0 with value: 0.783125.
# [I 2024-01-30 17:03:11,832] Trial 1 finished with value: 0.73875 and parameters: {'depth': 9, 'learning_rate': 0.22765879275661466, 'random_strength': 4, 'bagging_temperature': 0.10440731184932639, 'l2_leaf_reg': 5.095881186726142, 'scale_pos_weight': 2.8970599692375827}. Best is trial 0 with value: 0.783125.
# [I 2024-01-30 17:03:12,794] Trial 2 finished with value: 0.691875 and parameters: {'depth': 9, 'learning_rate': 0.23055930751370365, 'random_strength': 13, 'bagging_temperature': 0.6068418964609599, 'l2_leaf_reg': 78.0856097747368, 'scale_pos_weight': 6.909800388901613}. Best is trial 0 with value: 0.783125.
# [I 2024-01-30 17:03:13,522] Trial 3 finished with value: 0.7275 and parameters: {'depth': 10, 'learning_rate': 0.28043717890380376, 'random_strength': 11, 'bagging_temperature': 0.9919948511413211, 'l2_leaf_reg': 68.97665171263897, 'scale_pos_weight': 3.520516167206375}. Best is trial 0 with value: 0.783125.
# [I 2024-01-30 17:03:14,209] Trial 4 finished with value: 0.76875 and parameters: {'depth': 8, 'learning_rate': 0.2962911151418667, 'random_strength': 9, 'bagging_temperature': 0.364001729672898, 'l2_leaf_reg': 78.5067969422265, 'scale_pos_weight': 1.7045993392609822}. Best is trial 0 with value: 0.783125.
# [I 2024-01-30 17:03:15,528] Trial 5 finished with value: 0.68 and parameters: {'depth': 6, 'learning_rate': 0.1232868322089882, 'random_strength': 18, 'bagging_temperature': 0.8665504302291007, 'l2_leaf_reg': 58.257672289195135, 'scale_pos_weight': 8.63041868102904}. Best is trial 0 with value: 0.783125.
# [I 2024-01-30 17:03:16,315] Trial 6 finished with value: 0.734375 and parameters: {'depth': 4, 'learning_rate': 0.14853332515346543, 'random_strength': 13, 'bagging_temperature': 0.7012361822505716, 'l2_leaf_reg': 14.221971898711862, 'scale_pos_weight': 0.2586577626057148}. Best is trial 0 with value: 0.783125.
# [I 2024-01-30 17:03:16,924] Trial 7 finished with value: 0.78 and parameters: {'depth': 7, 'learning_rate': 0.23662231764546293, 'random_strength': 7, 'bagging_temperature': 0.5183890656294522, 'l2_leaf_reg': 60.664829613262526, 'scale_pos_weight': 1.4328180834038993}. Best is trial 0 with value: 0.783125.
# [I 2024-01-30 17:03:20,319] Trial 8 finished with value: 0.705625 and parameters: {'depth': 10, 'learning_rate': 0.018975092922849754, 'random_strength': 15, 'bagging_temperature': 0.457943313388136, 'l2_leaf_reg': 11.218780398184228, 'scale_pos_weight': 6.105009761037738}. Best is trial 0 with value: 0.783125.
# [I 2024-01-30 17:03:21,398] Trial 9 finished with value: 0.78125 and parameters: {'depth': 10, 'learning_rate': 0.176204929321037, 'random_strength': 14, 'bagging_temperature': 0.4989710695599161, 'l2_leaf_reg': 85.66264677329464, 'scale_pos_weight': 1.189365606884573}. Best is trial 0 with value: 0.783125.
# [I 2024-01-30 17:03:22,531] Trial 10 finished with value: 0.72 and parameters: {'depth': 5, 'learning_rate': 0.10591851801007765, 'random_strength': 1, 'bagging_temperature': 0.27335263619433364, 'l2_leaf_reg': 36.0144214097995, 'scale_pos_weight': 4.886597539835739}. Best is trial 0 with value: 0.783125.
# [I 2024-01-30 17:03:23,496] Trial 11 finished with value: 0.743125 and parameters: {'depth': 6, 'learning_rate': 0.18298108284723044, 'random_strength': 20, 'bagging_temperature': 0.7043301588545985, 'l2_leaf_reg': 98.75386768714873, 'scale_pos_weight': 0.28623038072365714}. Best is trial 0 with value: 0.783125.
# [I 2024-01-30 17:03:24,175] Trial 12 finished with value: 0.744375 and parameters: {'depth': 7, 'learning_rate': 0.18472660656493264, 'random_strength': 16, 'bagging_temperature': 0.5633020047062003, 'l2_leaf_reg': 42.627955160112094, 'scale_pos_weight': 2.7666844881141364}. Best is trial 0 with value: 0.783125.
# [I 2024-01-30 17:03:24,956] Trial 13 finished with value: 0.70875 and parameters: {'depth': 5, 'learning_rate': 0.19308017668748748, 'random_strength': 7, 'bagging_temperature': 0.33470726419322494, 'l2_leaf_reg': 33.510546061553505, 'scale_pos_weight': 0.2023354117337821}. Best is trial 0 with value: 0.783125.
# [I 2024-01-30 17:03:25,998] Trial 14 finished with value: 0.7675 and parameters: {'depth': 8, 'learning_rate': 0.10677216397082048, 'random_strength': 10, 'bagging_temperature': 0.7019153266321794, 'l2_leaf_reg': 99.24169664037012, 'scale_pos_weight': 1.8813342947886005}. Best is trial 0 with value: 0.783125.
# [I 2024-01-30 17:03:26,722] Trial 15 finished with value: 0.721875 and parameters: {'depth': 6, 'learning_rate': 0.2691813590580914, 'random_strength': 13, 'bagging_temperature': 0.022702712125842295, 'l2_leaf_reg': 48.276199311183646, 'scale_pos_weight': 3.8531902526357715}. Best is trial 0 with value: 0.783125.
# [I 2024-01-30 17:03:27,513] Trial 16 finished with value: 0.77875 and parameters: {'depth': 8, 'learning_rate': 0.15520650115139834, 'random_strength': 7, 'bagging_temperature': 0.4201413526035046, 'l2_leaf_reg': 31.713896198126083, 'scale_pos_weight': 1.585167651670194}. Best is trial 0 with value: 0.783125.
# [I 2024-01-30 17:03:28,145] Trial 17 finished with value: 0.724375 and parameters: {'depth': 5, 'learning_rate': 0.2503637089937897, 'random_strength': 16, 'bagging_temperature': 0.2624139369700714, 'l2_leaf_reg': 21.693683913995194, 'scale_pos_weight': 4.234371702368227}. Best is trial 0 with value: 0.783125.
# [I 2024-01-30 17:03:28,709] Trial 18 finished with value: 0.784375 and parameters: {'depth': 7, 'learning_rate': 0.20805199541518557, 'random_strength': 4, 'bagging_temperature': 0.608265786208455, 'l2_leaf_reg': 51.464409447215246, 'scale_pos_weight': 0.9570853831354527}. Best is trial 18 with value: 0.784375.
# [I 2024-01-30 17:03:29,617] Trial 19 finished with value: 0.75 and parameters: {'depth': 4, 'learning_rate': 0.21132111043629698, 'random_strength': 1, 'bagging_temperature': 0.6381257449538317, 'l2_leaf_reg': 48.287402875020454, 'scale_pos_weight': 2.787008670412467}. Best is trial 18 with value: 0.784375.
# [I 2024-01-30 17:03:30,172] Trial 20 finished with value: 0.746875 and parameters: {'depth': 7, 'learning_rate': 0.256792878053233, 'random_strength': 4, 'bagging_temperature': 0.8326827128648859, 'l2_leaf_reg': 26.890941202622695, 'scale_pos_weight': 2.325858936255799}. Best is trial 18 with value: 0.784375.
# [I 2024-01-30 17:03:30,812] Trial 21 finished with value: 0.791875 and parameters: {'depth': 7, 'learning_rate': 0.21841420787664825, 'random_strength': 4, 'bagging_temperature': 0.4989015180241904, 'l2_leaf_reg': 38.15923310063132, 'scale_pos_weight': 0.999457482207464}. Best is trial 21 with value: 0.791875.
# [I 2024-01-30 17:03:31,573] Trial 22 finished with value: 0.791875 and parameters: {'depth': 7, 'learning_rate': 0.20178347606829117, 'random_strength': 4, 'bagging_temperature': 0.5340586723038802, 'l2_leaf_reg': 40.564160351221076, 'scale_pos_weight': 0.959153898800536}. Best is trial 21 with value: 0.791875.
# [I 2024-01-30 17:03:32,398] Trial 23 finished with value: 0.786875 and parameters: {'depth': 8, 'learning_rate': 0.21001127821407334, 'random_strength': 3, 'bagging_temperature': 0.4423212172086813, 'l2_leaf_reg': 43.651026909742924, 'scale_pos_weight': 1.0666917696703426}. Best is trial 21 with value: 0.791875.
# [I 2024-01-30 17:03:33,015] Trial 24 finished with value: 0.77375 and parameters: {'depth': 8, 'learning_rate': 0.24440374714370605, 'random_strength': 3, 'bagging_temperature': 0.4207229144256208, 'l2_leaf_reg': 42.29353111269537, 'scale_pos_weight': 1.1165712672554768}. Best is trial 21 with value: 0.791875.
# [I 2024-01-30 17:03:33,665] Trial 25 finished with value: 0.759375 and parameters: {'depth': 9, 'learning_rate': 0.26988855065131523, 'random_strength': 6, 'bagging_temperature': 0.5220344993948631, 'l2_leaf_reg': 24.248609887602623, 'scale_pos_weight': 2.224746626629037}. Best is trial 21 with value: 0.791875.
# [I 2024-01-30 17:03:34,382] Trial 26 finished with value: 0.78875 and parameters: {'depth': 8, 'learning_rate': 0.20847608689352984, 'random_strength': 2, 'bagging_temperature': 0.45054293841515375, 'l2_leaf_reg': 42.3201181984222, 'scale_pos_weight': 0.8415886762590832}. Best is trial 21 with value: 0.791875.
# [I 2024-01-30 17:03:34,969] Trial 27 finished with value: 0.653125 and parameters: {'depth': 7, 'learning_rate': 0.2418219131710075, 'random_strength': 2, 'bagging_temperature': 0.3481743116821855, 'l2_leaf_reg': 30.212091244709463, 'scale_pos_weight': 0.11404710105479277}. Best is trial 21 with value: 0.791875.
# [I 2024-01-30 17:03:35,752] Trial 28 finished with value: 0.735 and parameters: {'depth': 9, 'learning_rate': 0.19732551946325944, 'random_strength': 5, 'bagging_temperature': 0.5056506344713967, 'l2_leaf_reg': 19.70479501043145, 'scale_pos_weight': 3.2137282401487313}. Best is trial 21 with value: 0.791875.
# [I 2024-01-30 17:03:36,615] Trial 29 finished with value: 0.794375 and parameters: {'depth': 6, 'learning_rate': 0.22272850196663282, 'random_strength': 8, 'bagging_temperature': 0.6001495460762375, 'l2_leaf_reg': 39.00292367879178, 'scale_pos_weight': 0.7889158404899533}. Best is trial 29 with value: 0.794375.
# [I 2024-01-30 17:03:37,165] Trial 30 finished with value: 0.75875 and parameters: {'depth': 6, 'learning_rate': 0.22546435315937052, 'random_strength': 9, 'bagging_temperature': 0.6568578720864292, 'l2_leaf_reg': 36.31526319483225, 'scale_pos_weight': 2.084611218517621}. Best is trial 29 with value: 0.794375.
# [I 2024-01-30 17:03:37,863] Trial 31 finished with value: 0.78625 and parameters: {'depth': 7, 'learning_rate': 0.2210320495657291, 'random_strength': 6, 'bagging_temperature': 0.5676409307950527, 'l2_leaf_reg': 40.010777155126604, 'scale_pos_weight': 0.802209854307724}. Best is trial 29 with value: 0.794375.
# [I 2024-01-30 17:03:38,495] Trial 32 finished with value: 0.780625 and parameters: {'depth': 7, 'learning_rate': 0.2120006478712558, 'random_strength': 3, 'bagging_temperature': 0.5590552854237733, 'l2_leaf_reg': 31.258536404217804, 'scale_pos_weight': 0.5761761949537929}. Best is trial 29 with value: 0.794375.
# [I 2024-01-30 17:03:39,215] Trial 33 finished with value: 0.7525 and parameters: {'depth': 6, 'learning_rate': 0.23037354601615767, 'random_strength': 5, 'bagging_temperature': 0.4759394539490713, 'l2_leaf_reg': 37.40620515330023, 'scale_pos_weight': 2.4065708754265493}. Best is trial 29 with value: 0.794375.
# [I 2024-01-30 17:03:40,016] Trial 34 finished with value: 0.775 and parameters: {'depth': 8, 'learning_rate': 0.19938026094045455, 'random_strength': 2, 'bagging_temperature': 0.6175793525839169, 'l2_leaf_reg': 47.42405536903128, 'scale_pos_weight': 1.5955832413679536}. Best is trial 29 with value: 0.794375.
# [I 2024-01-30 17:03:40,682] Trial 35 finished with value: 0.78875 and parameters: {'depth': 5, 'learning_rate': 0.22696661338317559, 'random_strength': 8, 'bagging_temperature': 0.3969235589412536, 'l2_leaf_reg': 54.43681974471422, 'scale_pos_weight': 0.8446947942314168}. Best is trial 29 with value: 0.794375.
# [I 2024-01-30 17:03:41,274] Trial 36 finished with value: 0.768125 and parameters: {'depth': 6, 'learning_rate': 0.2533240304661133, 'random_strength': 11, 'bagging_temperature': 0.46979737002901056, 'l2_leaf_reg': 1.9104334575687787, 'scale_pos_weight': 1.6967399123941562}. Best is trial 29 with value: 0.794375.
# [I 2024-01-30 17:03:41,902] Trial 37 finished with value: 0.78875 and parameters: {'depth': 9, 'learning_rate': 0.28156615416911107, 'random_strength': 5, 'bagging_temperature': 0.5451219311651613, 'l2_leaf_reg': 27.824054614487817, 'scale_pos_weight': 0.6986393467310873}. Best is trial 29 with value: 0.794375.
# [I 2024-01-30 17:03:42,566] Trial 38 finished with value: 0.73 and parameters: {'depth': 7, 'learning_rate': 0.23618036403113254, 'random_strength': 2, 'bagging_temperature': 0.3926027550196781, 'l2_leaf_reg': 58.42145229290574, 'scale_pos_weight': 3.190745491988753}. Best is trial 29 with value: 0.794375.
# [I 2024-01-30 17:03:43,404] Trial 39 finished with value: 0.78375 and parameters: {'depth': 8, 'learning_rate': 0.1684342844685637, 'random_strength': 9, 'bagging_temperature': 0.6695497758889447, 'l2_leaf_reg': 40.21792285390554, 'scale_pos_weight': 1.3114744472066608}. Best is trial 29 with value: 0.794375.
# [I 2024-01-30 17:03:44,228] Trial 40 finished with value: 0.765625 and parameters: {'depth': 6, 'learning_rate': 0.1954722215853428, 'random_strength': 6, 'bagging_temperature': 0.7458577933288161, 'l2_leaf_reg': 52.38584523955424, 'scale_pos_weight': 1.9080006960180413}. Best is trial 29 with value: 0.794375.
# [I 2024-01-30 17:03:44,905] Trial 41 finished with value: 0.79 and parameters: {'depth': 5, 'learning_rate': 0.21683914598779083, 'random_strength': 8, 'bagging_temperature': 0.5837056037237583, 'l2_leaf_reg': 54.8856288820936, 'scale_pos_weight': 0.6922550324670422}. Best is trial 29 with value: 0.794375.
# [I 2024-01-30 17:03:45,615] Trial 42 finished with value: 0.781875 and parameters: {'depth': 5, 'learning_rate': 0.21776255898258784, 'random_strength': 12, 'bagging_temperature': 0.5967976330864243, 'l2_leaf_reg': 64.59562653808212, 'scale_pos_weight': 0.5443984325676858}. Best is trial 29 with value: 0.794375.
# [I 2024-01-30 17:03:46,248] Trial 43 finished with value: 0.781875 and parameters: {'depth': 4, 'learning_rate': 0.2284122037805454, 'random_strength': 8, 'bagging_temperature': 0.49274376261763625, 'l2_leaf_reg': 54.01898664299792, 'scale_pos_weight': 1.2887417348978645}. Best is trial 29 with value: 0.794375.
# [I 2024-01-30 17:03:47,044] Trial 44 finished with value: 0.691875 and parameters: {'depth': 6, 'learning_rate': 0.1712983100990423, 'random_strength': 4, 'bagging_temperature': 0.537476764699653, 'l2_leaf_reg': 45.676578012611536, 'scale_pos_weight': 0.15165166294059507}. Best is trial 29 with value: 0.794375.
# [I 2024-01-30 17:03:47,820] Trial 45 finished with value: 0.786875 and parameters: {'depth': 5, 'learning_rate': 0.2044409345057066, 'random_strength': 8, 'bagging_temperature': 0.5934887580803232, 'l2_leaf_reg': 37.644338931146734, 'scale_pos_weight': 0.7050718885162137}. Best is trial 29 with value: 0.794375.
# [I 2024-01-30 17:03:48,489] Trial 46 finished with value: 0.78125 and parameters: {'depth': 7, 'learning_rate': 0.18594835516163608, 'random_strength': 1, 'bagging_temperature': 0.461458512786272, 'l2_leaf_reg': 43.37643028939533, 'scale_pos_weight': 1.431859121388937}. Best is trial 29 with value: 0.794375.
# [I 2024-01-30 17:03:49,225] Trial 47 finished with value: 0.751875 and parameters: {'depth': 6, 'learning_rate': 0.21844612903830496, 'random_strength': 10, 'bagging_temperature': 0.5181255583048757, 'l2_leaf_reg': 61.85991543718541, 'scale_pos_weight': 2.381185576650416}. Best is trial 29 with value: 0.794375.
# [I 2024-01-30 17:03:49,840] Trial 48 finished with value: 0.771875 and parameters: {'depth': 5, 'learning_rate': 0.18807665031964912, 'random_strength': 6, 'bagging_temperature': 0.5773384007344535, 'l2_leaf_reg': 34.29586225289693, 'scale_pos_weight': 0.48728063512491754}. Best is trial 29 with value: 0.794375.
# [I 2024-01-30 17:03:50,541] Trial 49 finished with value: 0.77125 and parameters: {'depth': 7, 'learning_rate': 0.20233592436544134, 'random_strength': 3, 'bagging_temperature': 0.4867496599100382, 'l2_leaf_reg': 55.77202674643101, 'scale_pos_weight': 1.7877771764481833}. Best is trial 29 with value: 0.794375.
# [I 2024-01-30 17:03:51,509] Trial 50 finished with value: 0.783125 and parameters: {'depth': 8, 'learning_rate': 0.1757638255038761, 'random_strength': 7, 'bagging_temperature': 0.6363282256634583, 'l2_leaf_reg': 49.00728408454417, 'scale_pos_weight': 1.152413117097827}. Best is trial 29 with value: 0.794375.
# [I 2024-01-30 17:03:52,281] Trial 51 finished with value: 0.7975 and parameters: {'depth': 4, 'learning_rate': 0.22355998662448592, 'random_strength': 8, 'bagging_temperature': 0.40781166830714255, 'l2_leaf_reg': 54.828060904182664, 'scale_pos_weight': 0.8227803673720976}. Best is trial 51 with value: 0.7975.
# [I 2024-01-30 17:03:53,007] Trial 52 finished with value: 0.783125 and parameters: {'depth': 4, 'learning_rate': 0.23747907861484188, 'random_strength': 10, 'bagging_temperature': 0.4361556624057946, 'l2_leaf_reg': 45.25193528896131, 'scale_pos_weight': 0.4849620822276017}. Best is trial 51 with value: 0.7975.
# [I 2024-01-30 17:03:53,668] Trial 53 finished with value: 0.67625 and parameters: {'depth': 4, 'learning_rate': 0.2191854403059343, 'random_strength': 5, 'bagging_temperature': 0.37420888522645546, 'l2_leaf_reg': 48.93177460909873, 'scale_pos_weight': 0.13762059999271092}. Best is trial 51 with value: 0.7975.
# ...
# [I 2024-01-30 17:10:47,077] Trial 49 finished with value: 0.794375 and parameters: {'depth': 5, 'learning_rate': 0.22278023593631313, 'random_strength': 6, 'bagging_temperature': 0.33371289827885425, 'l2_leaf_reg': 68.59454214614348, 'scale_pos_weight': 0.8468249149178748}. Best is trial 19 with value: 0.7975.
# [I 2024-01-30 17:10:47,787] Trial 50 finished with value: 0.770625 and parameters: {'depth': 5, 'learning_rate': 0.2733260236128501, 'random_strength': 6, 'bagging_temperature': 0.3301353681630628, 'l2_leaf_reg': 94.33229557238069, 'scale_pos_weight': 1.5054653373029965}. Best is trial 19 with value: 0.7975.
# [I 2024-01-30 17:10:48,626] Trial 51 finished with value: 0.79875 and parameters: {'depth': 4, 'learning_rate': 0.22379619479523416, 'random_strength': 2, 'bagging_temperature': 0.2930297863535001, 'l2_leaf_reg': 67.56960439291113, 'scale_pos_weight': 0.8336061890586497}. Best is trial 51 with value: 0.79875.
# [I 2024-01-30 17:10:49,711] Trial 52 finished with value: 0.77625 and parameters: {'depth': 4, 'learning_rate': 0.2255661057151853, 'random_strength': 2, 'bagging_temperature': 0.4174494395713411, 'l2_leaf_reg': 67.16974126534319, 'scale_pos_weight': 0.4485228198509378}. Best is trial 51 with value: 0.79875.
# [I 2024-01-30 17:10:50,916] Trial 53 finished with value: 0.7775 and parameters: {'depth': 5, 'learning_rate': 0.18504821540026448, 'random_strength': 3, 'bagging_temperature': 0.3548560413095221, 'l2_leaf_reg': 77.41477287918383, 'scale_pos_weight': 0.654039160189086}. Best is trial 51 with value: 0.79875.
# [I 2024-01-30 17:10:51,891] Trial 54 finished with value: 0.7925 and parameters: {'depth': 4, 'learning_rate': 0.21945703150024515, 'random_strength': 1, 'bagging_temperature': 0.190229562576523, 'l2_leaf_reg': 69.69891103533719, 'scale_pos_weight': 0.9333897240533237}. Best is trial 51 with value: 0.79875.
# [I 2024-01-30 17:10:54,395] Trial 55 finished with value: 0.7525 and parameters: {'depth': 4, 'learning_rate': 0.14933693247546218, 'random_strength': 4, 'bagging_temperature': 0.3170288570413681, 'l2_leaf_reg': 83.52239720594704, 'scale_pos_weight': 2.1072290399478097}. Best is trial 51 with value: 0.79875.
# [I 2024-01-30 17:10:55,806] Trial 56 finished with value: 0.760625 and parameters: {'depth': 6, 'learning_rate': 0.25414480383954796, 'random_strength': 6, 'bagging_temperature': 0.2276774215297513, 'l2_leaf_reg': 81.3576434461035, 'scale_pos_weight': 0.3663183349684497}. Best is trial 51 with value: 0.79875.
# [I 2024-01-30 17:10:57,250] Trial 57 finished with value: 0.780625 and parameters: {'depth': 5, 'learning_rate': 0.23504954960780827, 'random_strength': 4, 'bagging_temperature': 0.16820905691456312, 'l2_leaf_reg': 75.11366958192798, 'scale_pos_weight': 1.3717049697231258}. Best is trial 51 with value: 0.79875.
# [I 2024-01-30 17:10:58,001] Trial 58 finished with value: 0.793125 and parameters: {'depth': 4, 'learning_rate': 0.2889793253649639, 'random_strength': 2, 'bagging_temperature': 0.3756915989448497, 'l2_leaf_reg': 72.07161493985639, 'scale_pos_weight': 1.0291091225799467}. Best is trial 51 with value: 0.79875.
# [I 2024-01-30 17:10:58,915] Trial 59 finished with value: 0.759375 and parameters: {'depth': 4, 'learning_rate': 0.2640187128096776, 'random_strength': 8, 'bagging_temperature': 0.39135925714733544, 'l2_leaf_reg': 66.99747325181164, 'scale_pos_weight': 1.9356687769984258}. Best is trial 51 with value: 0.79875.
# [I 2024-01-30 17:10:59,914] Trial 60 finished with value: 0.793125 and parameters: {'depth': 5, 'learning_rate': 0.2891232925234264, 'random_strength': 6, 'bagging_temperature': 0.4478364379892499, 'l2_leaf_reg': 71.21378780463553, 'scale_pos_weight': 1.005899688323326}. Best is trial 51 with value: 0.79875.
# [I 2024-01-30 17:11:00,898] Trial 61 finished with value: 0.795 and parameters: {'depth': 5, 'learning_rate': 0.28890211534625454, 'random_strength': 6, 'bagging_temperature': 0.35494445643441147, 'l2_leaf_reg': 73.7825092036937, 'scale_pos_weight': 1.0329725879065592}. Best is trial 51 with value: 0.79875.
# [I 2024-01-30 17:11:01,781] Trial 62 finished with value: 0.78875 and parameters: {'depth': 4, 'learning_rate': 0.2747398220647021, 'random_strength': 8, 'bagging_temperature': 0.3467707313257708, 'l2_leaf_reg': 73.9320053004565, 'scale_pos_weight': 1.313827450230653}. Best is trial 51 with value: 0.79875.
# [I 2024-01-30 17:11:02,429] Trial 63 finished with value: 0.795625 and parameters: {'depth': 6, 'learning_rate': 0.2885974988517259, 'random_strength': 4, 'bagging_temperature': 0.2904740148294215, 'l2_leaf_reg': 60.06003757182144, 'scale_pos_weight': 0.9101478944767448}. Best is trial 51 with value: 0.79875.
# [I 2024-01-30 17:11:03,155] Trial 64 finished with value: 0.75625 and parameters: {'depth': 6, 'learning_rate': 0.2526611913488727, 'random_strength': 4, 'bagging_temperature': 0.2987486805914798, 'l2_leaf_reg': 60.667421085563674, 'scale_pos_weight': 1.821677176981177}. Best is trial 51 with value: 0.79875.
# [I 2024-01-30 17:11:03,796] Trial 65 finished with value: 0.764375 and parameters: {'depth': 6, 'learning_rate': 0.2789242015338208, 'random_strength': 5, 'bagging_temperature': 0.27288619914869866, 'l2_leaf_reg': 64.97584468823071, 'scale_pos_weight': 0.3602415569205811}. Best is trial 51 with value: 0.79875.
# [I 2024-01-30 17:11:04,597] Trial 66 finished with value: 0.774375 and parameters: {'depth': 7, 'learning_rate': 0.2645115283244538, 'random_strength': 3, 'bagging_temperature': 0.3288280446431377, 'l2_leaf_reg': 60.50788770062235, 'scale_pos_weight': 1.4682289372920643}. Best is trial 51 with value: 0.79875.
# [I 2024-01-30 17:11:05,407] Trial 67 finished with value: 0.789375 and parameters: {'depth': 5, 'learning_rate': 0.24014379371106806, 'random_strength': 7, 'bagging_temperature': 0.42352963080948186, 'l2_leaf_reg': 55.99453900270975, 'scale_pos_weight': 0.7078607849631597}. Best is trial 51 with value: 0.79875.
# [I 2024-01-30 17:11:06,513] Trial 68 finished with value: 0.740625 and parameters: {'depth': 6, 'learning_rate': 0.29902639771086614, 'random_strength': 6, 'bagging_temperature': 0.28976489915842224, 'l2_leaf_reg': 67.62887934561356, 'scale_pos_weight': 2.5738053898863926}. Best is trial 51 with value: 0.79875.
# [I 2024-01-30 17:11:07,295] Trial 69 finished with value: 0.753125 and parameters: {'depth': 5, 'learning_rate': 0.29028833755293404, 'random_strength': 4, 'bagging_temperature': 0.2608006652384142, 'l2_leaf_reg': 78.72228912021112, 'scale_pos_weight': 2.1866857368634807}. Best is trial 51 with value: 0.79875.
# [I 2024-01-30 17:11:07,912] Trial 70 finished with value: 0.79 and parameters: {'depth': 7, 'learning_rate': 0.2759380297293398, 'random_strength': 5, 'bagging_temperature': 0.3673769166190557, 'l2_leaf_reg': 85.13168891625331, 'scale_pos_weight': 0.9165975005243046}. Best is trial 51 with value: 0.79875.
# [I 2024-01-30 17:11:08,812] Trial 71 finished with value: 0.79375 and parameters: {'depth': 4, 'learning_rate': 0.2897464045673892, 'random_strength': 2, 'bagging_temperature': 0.3766036646756687, 'l2_leaf_reg': 69.95335194060578, 'scale_pos_weight': 1.0471561602781776}. Best is trial 51 with value: 0.79875.
# [I 2024-01-30 17:11:09,841] Trial 72 finished with value: 0.78375 and parameters: {'depth': 5, 'learning_rate': 0.2913317007548167, 'random_strength': 1, 'bagging_temperature': 0.3946343443022925, 'l2_leaf_reg': 60.65067351180437, 'scale_pos_weight': 1.2130115987962191}. Best is trial 51 with value: 0.79875.
# [I 2024-01-30 17:11:10,947] Trial 73 finished with value: 0.77125 and parameters: {'depth': 4, 'learning_rate': 0.2560652776848762, 'random_strength': 3, 'bagging_temperature': 0.335825412250889, 'l2_leaf_reg': 70.15404570581259, 'scale_pos_weight': 0.415214012350166}. Best is trial 51 with value: 0.79875.
# [I 2024-01-30 17:11:12,025] Trial 74 finished with value: 0.770625 and parameters: {'depth': 6, 'learning_rate': 0.2809195031225823, 'random_strength': 11, 'bagging_temperature': 0.2947573230583583, 'l2_leaf_reg': 64.69359957922312, 'scale_pos_weight': 1.593784074817202}. Best is trial 51 with value: 0.79875.
# [I 2024-01-30 17:11:13,020] Trial 75 finished with value: 0.7875 and parameters: {'depth': 5, 'learning_rate': 0.2670183390556826, 'random_strength': 5, 'bagging_temperature': 0.24516657219854318, 'l2_leaf_reg': 69.03754399966255, 'scale_pos_weight': 0.8215370739227952}. Best is trial 51 with value: 0.79875.
# [I 2024-01-30 17:11:13,856] Trial 76 finished with value: 0.644375 and parameters: {'depth': 7, 'learning_rate': 0.25935338987837675, 'random_strength': 2, 'bagging_temperature': 0.4853472245076662, 'l2_leaf_reg': 76.31146870421323, 'scale_pos_weight': 0.10615477467681189}. Best is trial 51 with value: 0.79875.
# [I 2024-01-30 17:11:14,839] Trial 77 finished with value: 0.755625 and parameters: {'depth': 4, 'learning_rate': 0.2816385751721797, 'random_strength': 7, 'bagging_temperature': 0.4269890412241374, 'l2_leaf_reg': 64.76464640193292, 'scale_pos_weight': 1.9332014990359636}. Best is trial 51 with value: 0.79875.
# [I 2024-01-30 17:11:15,592] Trial 78 finished with value: 0.788125 and parameters: {'depth': 5, 'learning_rate': 0.29373327515614167, 'random_strength': 3, 'bagging_temperature': 0.36380933796915726, 'l2_leaf_reg': 74.52963784088584, 'scale_pos_weight': 1.1802521085908908}. Best is trial 51 with value: 0.79875.
# [I 2024-01-30 17:11:16,388] Trial 79 finished with value: 0.7725 and parameters: {'depth': 8, 'learning_rate': 0.27040683564483753, 'random_strength': 9, 'bagging_temperature': 0.31664046430021464, 'l2_leaf_reg': 62.09354047681555, 'scale_pos_weight': 0.48865357203655657}. Best is trial 51 with value: 0.79875.
# [I 2024-01-30 17:11:17,213] Trial 80 finished with value: 0.774375 and parameters: {'depth': 6, 'learning_rate': 0.2514974510692861, 'random_strength': 1, 'bagging_temperature': 0.34269485443977415, 'l2_leaf_reg': 57.26859427173042, 'scale_pos_weight': 1.5140253458961705}. Best is trial 51 with value: 0.79875.
# [I 2024-01-30 17:11:18,176] Trial 81 finished with value: 0.805 and parameters: {'depth': 4, 'learning_rate': 0.28739586092413105, 'random_strength': 2, 'bagging_temperature': 0.3825089717435777, 'l2_leaf_reg': 72.17101969162653, 'scale_pos_weight': 0.9747011251082011}. Best is trial 81 with value: 0.805.
# [I 2024-01-30 17:11:18,903] Trial 82 finished with value: 0.790625 and parameters: {'depth': 4, 'learning_rate': 0.28323005348422503, 'random_strength': 2, 'bagging_temperature': 0.39603821904718695, 'l2_leaf_reg': 71.88981365152863, 'scale_pos_weight': 0.8627989609629525}. Best is trial 81 with value: 0.805.
# [I 2024-01-30 17:11:19,853] Trial 83 finished with value: 0.7875 and parameters: {'depth': 4, 'learning_rate': 0.27594468437462605, 'random_strength': 4, 'bagging_temperature': 0.45204561982252606, 'l2_leaf_reg': 78.78296875521654, 'scale_pos_weight': 1.1184211356980405}. Best is trial 81 with value: 0.805.
# [I 2024-01-30 17:11:20,670] Trial 84 finished with value: 0.783125 and parameters: {'depth': 4, 'learning_rate': 0.2645147060239085, 'random_strength': 2, 'bagging_temperature': 0.3851150033102924, 'l2_leaf_reg': 69.0357301733208, 'scale_pos_weight': 0.5805683385784846}. Best is trial 81 with value: 0.805.
# [I 2024-01-30 17:11:21,671] Trial 85 finished with value: 0.766875 and parameters: {'depth': 5, 'learning_rate': 0.2999070701357347, 'random_strength': 6, 'bagging_temperature': 0.2780606361470132, 'l2_leaf_reg': 59.409886007396, 'scale_pos_weight': 1.7374057869587727}. Best is trial 81 with value: 0.805.
# [I 2024-01-30 17:11:22,488] Trial 86 finished with value: 0.7825 and parameters: {'depth': 4, 'learning_rate': 0.28760067231519837, 'random_strength': 3, 'bagging_temperature': 0.41366047439624615, 'l2_leaf_reg': 65.32304449793214, 'scale_pos_weight': 1.3467093785461417}. Best is trial 81 with value: 0.805.
# [I 2024-01-30 17:11:23,201] Trial 87 finished with value: 0.789375 and parameters: {'depth': 4, 'learning_rate': 0.2934876902507285, 'random_strength': 1, 'bagging_temperature': 0.3055361944659352, 'l2_leaf_reg': 73.53571469226009, 'scale_pos_weight': 0.7869348041624451}. Best is trial 81 with value: 0.805.
# [I 2024-01-30 17:11:23,979] Trial 88 finished with value: 0.734375 and parameters: {'depth': 7, 'learning_rate': 0.24561515153428373, 'random_strength': 5, 'bagging_temperature': 0.358914847831037, 'l2_leaf_reg': 68.63456543899734, 'scale_pos_weight': 0.26669118073912723}. Best is trial 81 with value: 0.805.
# [I 2024-01-30 17:11:24,734] Trial 89 finished with value: 0.7875 and parameters: {'depth': 5, 'learning_rate': 0.2739401653490816, 'random_strength': 14, 'bagging_temperature': 0.24227535401014194, 'l2_leaf_reg': 79.70569483845539, 'scale_pos_weight': 1.1570642526137669}. Best is trial 81 with value: 0.805.
# [I 2024-01-30 17:11:25,534] Trial 90 finished with value: 0.781875 and parameters: {'depth': 4, 'learning_rate': 0.22814045036626698, 'random_strength': 8, 'bagging_temperature': 0.3347913957001024, 'l2_leaf_reg': 75.51860482015081, 'scale_pos_weight': 0.5880237316601038}. Best is trial 81 with value: 0.805.
# [I 2024-01-30 17:11:26,302] Trial 91 finished with value: 0.784375 and parameters: {'depth': 4, 'learning_rate': 0.28633935929251925, 'random_strength': 1, 'bagging_temperature': 0.38469917247280266, 'l2_leaf_reg': 73.42842198615517, 'scale_pos_weight': 1.1004067768701336}. Best is trial 81 with value: 0.805.
# [I 2024-01-30 17:11:26,966] Trial 92 finished with value: 0.789375 and parameters: {'depth': 4, 'learning_rate': 0.2921881876635511, 'random_strength': 2, 'bagging_temperature': 0.37297996486884716, 'l2_leaf_reg': 71.94431620808751, 'scale_pos_weight': 0.9793956120993739}. Best is trial 81 with value: 0.805.
# [I 2024-01-30 17:11:27,599] Trial 93 finished with value: 0.765625 and parameters: {'depth': 4, 'learning_rate': 0.2844922916875426, 'random_strength': 2, 'bagging_temperature': 0.3148032458085368, 'l2_leaf_reg': 70.66131999816938, 'scale_pos_weight': 1.655916349358731}. Best is trial 81 with value: 0.805.
# [I 2024-01-30 17:11:28,232] Trial 94 finished with value: 0.75625 and parameters: {'depth': 5, 'learning_rate': 0.2700185318277626, 'random_strength': 3, 'bagging_temperature': 0.4329561402306151, 'l2_leaf_reg': 66.38124677898585, 'scale_pos_weight': 0.3186004444196807}. Best is trial 81 with value: 0.805.
# [I 2024-01-30 17:11:28,999] Trial 95 finished with value: 0.775625 and parameters: {'depth': 9, 'learning_rate': 0.2589679141336849, 'random_strength': 4, 'bagging_temperature': 0.40498628588054664, 'l2_leaf_reg': 62.6413212835899, 'scale_pos_weight': 1.3413742580333303}. Best is trial 81 with value: 0.805.
# [I 2024-01-30 17:11:29,797] Trial 96 finished with value: 0.78375 and parameters: {'depth': 8, 'learning_rate': 0.2770653660777168, 'random_strength': 10, 'bagging_temperature': 0.34631830696314664, 'l2_leaf_reg': 76.80229225810739, 'scale_pos_weight': 0.755327093074169}. Best is trial 81 with value: 0.805.
# [I 2024-01-30 17:11:30,967] Trial 97 finished with value: 0.7575 and parameters: {'depth': 4, 'learning_rate': 0.24006336043480642, 'random_strength': 12, 'bagging_temperature': 0.4688890657123759, 'l2_leaf_reg': 66.55186313832641, 'scale_pos_weight': 2.0412534737546246}. Best is trial 81 with value: 0.805.
# [I 2024-01-30 17:11:31,630] Trial 98 finished with value: 0.796875 and parameters: {'depth': 6, 'learning_rate': 0.2938800471020102, 'random_strength': 7, 'bagging_temperature': 0.37999849715434675, 'l2_leaf_reg': 71.84546752363019, 'scale_pos_weight': 0.9630151219388873}. Best is trial 81 with value: 0.805.
# [I 2024-01-30 17:11:32,402] Trial 99 finished with value: 0.775 and parameters: {'depth': 6, 'learning_rate': 0.297317250985064, 'random_strength': 7, 'bagging_temperature': 0.43517902687813614, 'l2_leaf_reg': 63.881345633568806, 'scale_pos_weight': 1.4838834583364124}. Best is trial 81 with value: 0.805.

# %% [markdown]
# - Catboost平均スコア

# %%
# 全フォールドの平均スコアを計算
cb_average_score = sum(cb_fold_scores) / n_splits
print(f"CatBoost Average accuracy across all folds: {cb_average_score:.4f}")

cb_average_conf = sum(cb_conf_scores) / n_splits
print(f"CatBoost Average conf-matrix across all folds: {cb_average_conf}")
# Out:
# CatBoost Average accuracy across all folds: 0.7800
# CatBoost Average conf-matrix across all folds: [[630.4 182.8]
#  [169.2 617.6]]

# %% [markdown]
# - CB_予測平均

# %%
# 予測の平均を計算
cb_y_test_pred_avg = np.mean(cb_test_predictions, axis=0)

# 最終的な予測結果を整数に変換
cb_y_test_pred_int = (cb_y_test_pred_avg > cb_threshold).astype(int)

# %% [markdown]
# - output

# %%
# 現在の日時を取得してフォーマットする
current_time = datetime.now().strftime("%Y%m%d_%H%M%S")
output = f'../data/output/{current_time}_CatBoost_cv{cb_average_score:.4f}.csv'

submit = pd.DataFrame({
    '0': test['gameId'],
    '1': cb_y_test_pred_int
})

# カラムヘッダー消去して出力
# ヘッダーなしでCSVファイルとして保存
submit.to_csv(output, header=False, index=False)

# %%
submit
# Out:
#          0  1
# 0        9  1
# 1       15  1
# 2       18  1
# 3       23  0
# 4       31  1
# ...    ... ..
# 1995  9971  0
# 1996  9980  0
# 1997  9983  1
# 1998  9996  1
# 1999  9999  0
#
# [2000 rows x 2 columns]

# %% [markdown]
# # 合成

# %% [markdown]
# - 予測リストに追加

# %%
# 予測結果をNumPy配列に変換
cb_predictions = np.array(cb_y_test_pred_int)  # CatBoostの予測結果
lgb_predictions = np.array(lgb_y_test_pred_int)  # LightGBMの予測結果
xgb_predictions = np.array(xgb_y_test_pred_int)  # XGBoostの予測結果

# 3つのモデルの予測結果を組み合わせる
combined_predictions = np.vstack((cb_predictions, lgb_predictions, xgb_predictions))

# 多数決で最終的な予測を決定（行方向に合計し、1.5より大きい場合は1とする）
final_predictions = np.mean(combined_predictions, axis=0) > 0.5
final_predictions = final_predictions.astype(int)

# 最終的な予測をCSVファイルに保存
merge_submit = pd.DataFrame({
    '0': test['gameId'],  # 適切なID列を使用
    '1': final_predictions
})
merge_submit.to_csv(f'../data/output/{current_time}_final_predictions.csv', index=False)

# %%
merge_submit
# Out:
#          0  1
# 0        9  1
# 1       15  1
# 2       18  1
# 3       23  0
# 4       31  1
# ...    ... ..
# 1995  9971  0
# 1996  9980  0
# 1997  9983  1
# 1998  9996  1
# 1999  9999  0
#
# [2000 rows x 2 columns]

# %% [markdown]
# #

# %% [markdown]
# # Logistic classifier
