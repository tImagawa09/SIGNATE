# %% [markdown]
# # Baseline

# %% [markdown]
# FEなし =>
#
# **LightGBM**<br>
# LightGBM Average accuracy across all folds ===> 0.7793749999999999<br>
# LightGBM Average conf-matrix across all folds  => [[631.8 181.4] [171.6 615.2]]<br>
#
# **XGboost**<br>
# XGB Average accuracy across all folds =======> 0.7762500000000001<br>
# XGB Average conf-matrix across all folds =====>  [[663.8 149.4] [208.6 578.2]]<br>
#
# **CatBoost**<br>
# CatBoost Average accuracy across all folds ======> 0.7747499999999998<br>
# CatBoost Average conf-matrix across all folds ====> [[637.8 175.4] [185.  601.8]]<br>

# %% [markdown]
# # Library

# %%
import pandas as pd
import numpy as np

import optuna
import xgboost as xgb
import lightgbm as lgb
import catboost as cb

from datetime import datetime
from sklearn.model_selection import train_test_split, KFold
from sklearn.metrics import accuracy_score, confusion_matrix, roc_curve, auc
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# # Data Loading

# %%
train = pd.read_csv('../data/train.csv')
test = pd.read_csv('../data/test.csv')

# %% [markdown]
# # Add New Feature

# %%
# 基準
# lgb = 0.7793749999999999
# xgb = 0.7762500000000001
# Cat = 0.7747499999999998

# %%
def add_features(df):                                                                               # lgb=0.7793, xgb=0.7762, cb=0.7747
    # df['assistRate'] = df['blueAssists'] / (df['blueKills'] + 1)                                  # lgb=0.7825, xgb=0.7713, cb=0.7832
    # df['blueHerald'] = (df['blueEliteMonsters'] - df['blueDragons']).clip(lower=0)                # lgb=0.7843, xgb=0.7746, cb=0.7745
    # df['eliteMonsterDragonRatio'] = df['blueEliteMonsters'] / (df['blueDragons'] + 1)             # lgb=0.7857, xgb=0.7782, cb=0.7824
    df['logTotalGold'] = np.log1p(df['blueTotalGold'])                                            # lgb=0.7964, xgb=0.7826, cb=0.7827
    # df['logTotalExperience'] = np.log1p(df['blueTotalExperience'])                                # lgb=0.7876, xgb=0.7722, cb=0.7777
    df['firstBloodKillRatio'] = df['blueFirstBlood'] * df['blueKills']                            # lgb=0.7920, xgb=0.7751, cb=0.7893
    # df['totalCombatPoints'] = df['blueKills'] + df['blueDeaths'] + df['blueAssists']              # lgb=0.7869, xgb=0.7360, cb=0.7870

    total_combat_actions = df['blueKills'] + df['blueDeaths'] + df['blueAssists'] 
    df['killRatio'] = df['blueKills'] / total_combat_actions                                      # lgb=0.7913, xgb=0.7747, cb=0.7811
    # df['deathRatio'] = df['blueDeaths'] / total_combat_actions                                    # lgb=0.7864, xgb=0.7848, cb=0.7860
    # df['assistRatio'] = df['blueAssists'] / total_combat_actions                                  # lgb=0.7863, xgb=0.7746, cb=0.7815

    # df['teamStrength'] = df['blueKills'] + df['blueAssists'] + df['blueEliteMonsters']            # lgb=0.7782, xgb=0.7246, cb=0.7869
    # df['dragonKillImpact'] = df['blueDragons'] / (df['blueKills'] + 1)                            # lgb=0.7870, xgb=0.7694, cb=0.7857
    df['eliteMonsterUtilization'] = df['blueEliteMonsters']\
    / (df['blueKills'] + df['blueAssists'] + 1)                                                   # lgb=0.7900, xgb=0.7746, cb=0.7885
    # df['goldExperienceRatio'] = df['blueTotalGold'] / (df['blueTotalExperience'] + 1)             # lgb=0.7911, xgb=0.7324, cb=0.7886
    # df['teamEfficiency'] = \
        # (df['blueKills'] + df['blueAssists'] + df['blueEliteMonsters']) / (df['blueDeaths'] + 1)  # lgb=0.7900, xgb=0.7762, cb=0.7840
    # df['killToMonsterRatio'] = df['blueKills'] / (df['blueEliteMonsters'] + 1)                    # lgb=0.7859, xgb=0.7758, cb=0.7800
    df['avgGoldPerKill'] = df['blueTotalGold'] / (df['blueKills'] + 1)                            # lgb=0.7933, xgb=0.7714, cb=0.7831
    # df['expToKillRatio'] = df['blueTotalExperience'] / (df['blueKills'] + 1)                      # lgb=0.7875, xgb=0.7781, cb=0.7820
    # df['killsMinusDeaths'] = df['blueKills'] - df['blueDeaths']                                   # lgb=0.7791, xgb=0.7879, cb=0.7884
    # df['killDeathRatio'] = df['blueKills'] / (df['blueKills'] + df['blueDeaths'])                 # lgb=0.7879, xgb=0.7752, cb=0.7863
    # df['avgExperiencePerKill'] = df['blueTotalExperience'] / (df['blueKills'] + 1)                # lgb=0.7886, xgb=0.7191, cb=0.7821
    df['killDeathDiff'] = (df['blueKills'] - df['blueDeaths']).clip(lower=0)                      # lgb=0.7895, xgb=0.7664, cb=0.7883
    # df['eliteMonsterHeraldRatio'] = df['blueEliteMonsters'] / (df['blueHerald'] + 1)              # lgb=0.7885, xgb=0.7553, cb=0.7829
    # df['goldXexperience'] = np.log1p(df['blueTotalGold'] * df['blueTotalExperience'])             # lgb=0.7828, xgb=0.7730, cb=0.7765
    # df['goldPerKill'] = df['blueTotalGold'] / (df['blueKills'] + 1)                               # lgb=0.7805, xgb=0.7525, cb=0.7742
    # df['experiencePerKill'] = df['blueTotalExperience'] / (df['blueKills'] + 1)                   # lgb=0.7809, xgb=0.7795, cb=0.7833
    # df['eliteMonstersPerGold'] = df['blueEliteMonsters'] / df['blueTotalGold']                  # lgb=0., xgb=0., cb=0.
    # df['eliteMonstersPerExperience'] = df['blueEliteMonsters'] / df['blueTotalExperience']      # lgb=0., xgb=0., cb=0.

    
    return df

# %% [markdown]
# - apply

# %%
train = add_features(train)
test = add_features(test)

# %% [markdown]
# # Data

# %%
# データの準備
X = train.drop(['blueWins', 'gameId'], axis=1)
y = train['blueWins']
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2, random_state=0)

test_drop_gameId = test.drop('gameId', axis=1)

# test_drop_gameId_temp = test.drop('gameId', axis=1)

# # 特徴量の標準化
# scaler = StandardScaler()
# X_train = scaler.fit_transform(X_train)
# X_val = scaler.transform(X_val)  # 検証データも同じスケーラーを使用して標準化

# # テストデータも同じスケーラーを使用して標準化
# test_drop_gameId_scaled = scaler.transform(test_drop_gameId_temp)

# # NumPy配列からPandasデータフレームに変換
# X_train = pd.DataFrame(X_train, columns=X.columns)
# X_val = pd.DataFrame(X_val, columns=X.columns)
# test_drop_gameId = pd.DataFrame(test_drop_gameId_scaled, columns=test_drop_gameId_temp.columns)

# %% [markdown]
# # Model

# %% [markdown]
# - variable

# %%
n_splits = 5
kf = KFold(n_splits=n_splits, shuffle=True)

lgb_threshold = 0.5
xgb_threshold = 0.5
cb_threshold = 0.5

# 各フォールドでのスコアを保存するリスト
lgb_fold_scores = []
xgb_fold_scores = []
cb_fold_scores = []

# 各フォール度での混同行列を保存するリスト
lgb_conf_scores = []
xgb_conf_scores = []
cb_conf_scores = []

# testを保存するリスト
lgb_test_predictions = []
xgb_test_predictions = []
cb_test_predictions = []

# %% [markdown]
# ## LightGBM

# %%
for train_index, val_index in kf.split(X):
    X_train_fold, X_val_fold = X.iloc[train_index], X.iloc[val_index]
    y_train_fold, y_val_fold = y[train_index], y[val_index]

    # LightGBMではDMatrixの代わりに普通のデータフレームを使用します
    train_data = lgb.Dataset(X_train_fold, label=y_train_fold)
    val_data = lgb.Dataset(X_val_fold, label=y_val_fold, reference=train_data)

    # Optunaでのハイパーパラメータチューニング
    def objective(trial):
        param = {
            'objective': 'binary',
            'metric': 'binary_logloss',
            'verbosity': -1,
            'boosting_type': 'gbdt',
            'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
            'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
            'num_leaves': trial.suggest_int('num_leaves', 2, 256),
            'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
            'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
            'bagging_freq': trial.suggest_int('bagging_freq', 1, 7),
            'min_child_samples': trial.suggest_int('min_child_samples', 5, 100),
            'feature_pre_filter': False,  # 特徴量の事前フィルタリングを無効化
            'min_data_in_leaf': trial.suggest_int('min_data_in_leaf', 20, 100),  # Optunaでこの値を調整する
        }

        callbacks = lgb.early_stopping(stopping_rounds=100, verbose=False)
        gbm = lgb.train(param, train_data, valid_sets=[val_data], num_boost_round=1000, callbacks=[callbacks])
        preds = gbm.predict(X_val_fold, num_iteration=gbm.best_iteration)
        pred_labels = np.rint(preds)
        accuracy = accuracy_score(y_val_fold, pred_labels)
        return accuracy

    lgb_study = optuna.create_study(direction='maximize')
    lgb_study.optimize(objective, n_trials=100)

    # 各フォールドの最適パラメータでモデルを再学習
    lgb_best_params = lgb_study.best_params
    lgb_best_params['objective'] = 'binary'
    lgb_best_params['metric'] = 'binary_logloss'
    lgb_best_params['verbosity'] = -1

    lgb_final = lgb.train(lgb_best_params, train_data, num_boost_round=lgb_study.best_trial.number)

    # 各フォールドのモデル性能を評価
    lgb_y_val_pred = lgb_final.predict(X_val_fold, num_iteration=lgb_final.best_iteration)
    lgb_y_val_pred_int = np.rint(lgb_y_val_pred)
    lgb_fold_accuracy = accuracy_score(y_val_fold, lgb_y_val_pred_int)
    lgb_fold_scores.append(lgb_fold_accuracy)

    # 混同行列
    lgb_conf_matrix = confusion_matrix(y_val_fold, lgb_y_val_pred_int)
    lgb_conf_scores.append(lgb_conf_matrix)


    # テストデータセットでの予測
    lgb_y_test_pred_fold = lgb_final.predict(test_drop_gameId, num_iteration=lgb_final.best_iteration)
    lgb_test_predictions.append(lgb_y_test_pred_fold)
# Out:
# [I 2024-01-30 14:29:23,165] A new study created in memory with name: no-name-17596895-aa53-46fb-ad94-18164af64a9e
# /tmp/ipykernel_30959/729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_30959/729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# /tmp/ipykernel_30959/729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# /tmp/ipykernel_30959/729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-30 14:29:23,983] Trial 0 finished with value: 0.785625 and parameters: {'lambda_l1': 8.090472408217527, 'lambda_l2': 1.8879087441638584e-06, 'num_leaves': 30, 'feature_fraction': 0.9464603876159896, 'bagging_fraction': 0.7377053045101711, 'bagging_freq': 4, 'min_child_samples': 30, 'min_data_in_leaf': 25}. Best is trial 0 with value: 0.785625.
# /tmp/ipykernel_30959/729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_30959/729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# /tmp/ipykernel_30959/729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# /tmp/ipykernel_30959/729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-30 14:29:24,278] Trial 1 finished with value: 0.78125 and parameters: {'lambda_l1': 1.888604524504095e-08, 'lambda_l2': 0.06038817471779718, 'num_leaves': 229, 'feature_fraction': 0.5396784957613516, 'bagging_fraction': 0.4252033584663363, 'bagging_freq': 6, 'min_child_samples': 86, 'min_data_in_leaf': 100}. Best is trial 0 with value: 0.785625.
# /tmp/ipykernel_30959/729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_30959/729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# /tmp/ipykernel_30959/729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# /tmp/ipykernel_30959/729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-30 14:29:24,685] Trial 2 finished with value: 0.789375 and parameters: {'lambda_l1': 0.0001663028238357048, 'lambda_l2': 0.0076601728383213115, 'num_leaves': 57, 'feature_fraction': 0.6311826405713297, 'bagging_fraction': 0.4636642725785787, 'bagging_freq': 4, 'min_child_samples': 10, 'min_data_in_leaf': 26}. Best is trial 2 with value: 0.789375.
# /tmp/ipykernel_30959/729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_30959/729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# /tmp/ipykernel_30959/729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# /tmp/ipykernel_30959/729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-30 14:29:25,186] Trial 3 finished with value: 0.789375 and parameters: {'lambda_l1': 1.1734698237828511e-06, 'lambda_l2': 6.500861518603164e-05, 'num_leaves': 158, 'feature_fraction': 0.9233582782798028, 'bagging_fraction': 0.8944504571770112, 'bagging_freq': 3, 'min_child_samples': 79, 'min_data_in_leaf': 49}. Best is trial 2 with value: 0.789375.
# /tmp/ipykernel_30959/729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_30959/729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# /tmp/ipykernel_30959/729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# /tmp/ipykernel_30959/729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-30 14:29:25,455] Trial 4 finished with value: 0.79 and parameters: {'lambda_l1': 1.1064564807419306e-06, 'lambda_l2': 3.467802808573116e-08, 'num_leaves': 69, 'feature_fraction': 0.5832248379771537, 'bagging_fraction': 0.9257387891664868, 'bagging_freq': 6, 'min_child_samples': 68, 'min_data_in_leaf': 93}. Best is trial 4 with value: 0.79.
# /tmp/ipykernel_30959/729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_30959/729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# /tmp/ipykernel_30959/729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# /tmp/ipykernel_30959/729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-30 14:29:25,716] Trial 5 finished with value: 0.793125 and parameters: {'lambda_l1': 0.00013019398867815637, 'lambda_l2': 4.527698976148029e-06, 'num_leaves': 233, 'feature_fraction': 0.8776974028413633, 'bagging_fraction': 0.6266349934160296, 'bagging_freq': 4, 'min_child_samples': 57, 'min_data_in_leaf': 79}. Best is trial 5 with value: 0.793125.
# /tmp/ipykernel_30959/729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_30959/729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# /tmp/ipykernel_30959/729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# /tmp/ipykernel_30959/729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-30 14:29:26,037] Trial 6 finished with value: 0.795 and parameters: {'lambda_l1': 0.00015755136921152336, 'lambda_l2': 6.762039398251746e-05, 'num_leaves': 162, 'feature_fraction': 0.4420030987284143, 'bagging_fraction': 0.5465513276962128, 'bagging_freq': 2, 'min_child_samples': 42, 'min_data_in_leaf': 82}. Best is trial 6 with value: 0.795.
# /tmp/ipykernel_30959/729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_30959/729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# /tmp/ipykernel_30959/729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# /tmp/ipykernel_30959/729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-30 14:29:26,300] Trial 7 finished with value: 0.793125 and parameters: {'lambda_l1': 2.8755187380468663, 'lambda_l2': 3.9911311588649148, 'num_leaves': 113, 'feature_fraction': 0.6160675391224911, 'bagging_fraction': 0.6346210622631937, 'bagging_freq': 4, 'min_child_samples': 71, 'min_data_in_leaf': 86}. Best is trial 6 with value: 0.795.
# /tmp/ipykernel_30959/729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_30959/729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# /tmp/ipykernel_30959/729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# /tmp/ipykernel_30959/729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-30 14:29:26,622] Trial 8 finished with value: 0.78125 and parameters: {'lambda_l1': 0.2792245144368492, 'lambda_l2': 0.021139650922998594, 'num_leaves': 75, 'feature_fraction': 0.6128395219078902, 'bagging_fraction': 0.7617929258096396, 'bagging_freq': 2, 'min_child_samples': 10, 'min_data_in_leaf': 77}. Best is trial 6 with value: 0.795.
# /tmp/ipykernel_30959/729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_30959/729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# /tmp/ipykernel_30959/729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# /tmp/ipykernel_30959/729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-30 14:29:26,897] Trial 9 finished with value: 0.78625 and parameters: {'lambda_l1': 0.0035837513133885807, 'lambda_l2': 5.290881019584163e-06, 'num_leaves': 187, 'feature_fraction': 0.6681460893289426, 'bagging_fraction': 0.40158983908062834, 'bagging_freq': 6, 'min_child_samples': 62, 'min_data_in_leaf': 36}. Best is trial 6 with value: 0.795.
# /tmp/ipykernel_30959/729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_30959/729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# /tmp/ipykernel_30959/729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# /tmp/ipykernel_30959/729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-30 14:29:27,108] Trial 10 finished with value: 0.78875 and parameters: {'lambda_l1': 0.012150550700395914, 'lambda_l2': 1.0262305705543392e-08, 'num_leaves': 137, 'feature_fraction': 0.40475259319392676, 'bagging_fraction': 0.542639580178815, 'bagging_freq': 1, 'min_child_samples': 37, 'min_data_in_leaf': 63}. Best is trial 6 with value: 0.795.
# /tmp/ipykernel_30959/729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_30959/729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# /tmp/ipykernel_30959/729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# /tmp/ipykernel_30959/729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-30 14:29:27,400] Trial 11 finished with value: 0.796875 and parameters: {'lambda_l1': 9.467422234060454e-05, 'lambda_l2': 0.0002528105983540577, 'num_leaves': 247, 'feature_fraction': 0.8123446815156693, 'bagging_fraction': 0.6078848221108972, 'bagging_freq': 1, 'min_child_samples': 45, 'min_data_in_leaf': 72}. Best is trial 11 with value: 0.796875.
# /tmp/ipykernel_30959/729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_30959/729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# /tmp/ipykernel_30959/729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# /tmp/ipykernel_30959/729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-30 14:29:27,722] Trial 12 finished with value: 0.795 and parameters: {'lambda_l1': 7.792099263051484e-06, 'lambda_l2': 0.00047580386688192747, 'num_leaves': 252, 'feature_fraction': 0.7935516940833388, 'bagging_fraction': 0.546312333065477, 'bagging_freq': 1, 'min_child_samples': 40, 'min_data_in_leaf': 65}. Best is trial 11 with value: 0.796875.
# /tmp/ipykernel_30959/729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_30959/729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# /tmp/ipykernel_30959/729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# /tmp/ipykernel_30959/729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-30 14:29:28,101] Trial 13 finished with value: 0.79125 and parameters: {'lambda_l1': 0.0028689961103403427, 'lambda_l2': 0.0005170743318143362, 'num_leaves': 199, 'feature_fraction': 0.7900894180860235, 'bagging_fraction': 0.5496704191240409, 'bagging_freq': 2, 'min_child_samples': 47, 'min_data_in_leaf': 72}. Best is trial 11 with value: 0.796875.
# /tmp/ipykernel_30959/729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_30959/729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# /tmp/ipykernel_30959/729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# /tmp/ipykernel_30959/729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-30 14:29:28,607] Trial 14 finished with value: 0.79875 and parameters: {'lambda_l1': 1.7001792521712805e-05, 'lambda_l2': 6.179755173797159e-05, 'num_leaves': 186, 'feature_fraction': 0.4702774327118279, 'bagging_fraction': 0.8120250522800317, 'bagging_freq': 2, 'min_child_samples': 22, 'min_data_in_leaf': 52}. Best is trial 14 with value: 0.79875.
# /tmp/ipykernel_30959/729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_30959/729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# /tmp/ipykernel_30959/729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# /tmp/ipykernel_30959/729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-30 14:29:29,104] Trial 15 finished with value: 0.79625 and parameters: {'lambda_l1': 9.492352682095539e-06, 'lambda_l2': 2.876227814448028e-07, 'num_leaves': 200, 'feature_fraction': 0.7548576080162952, 'bagging_fraction': 0.8608563599190706, 'bagging_freq': 1, 'min_child_samples': 100, 'min_data_in_leaf': 53}. Best is trial 14 with value: 0.79875.
# /tmp/ipykernel_30959/729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_30959/729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# /tmp/ipykernel_30959/729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# /tmp/ipykernel_30959/729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-30 14:29:29,532] Trial 16 finished with value: 0.78875 and parameters: {'lambda_l1': 2.243868538865576e-07, 'lambda_l2': 0.681974168244235, 'num_leaves': 248, 'feature_fraction': 0.5123284267746848, 'bagging_fraction': 0.815014535510039, 'bagging_freq': 3, 'min_child_samples': 25, 'min_data_in_leaf': 45}. Best is trial 14 with value: 0.79875.
# /tmp/ipykernel_30959/729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_30959/729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# /tmp/ipykernel_30959/729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# /tmp/ipykernel_30959/729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-30 14:29:30,052] Trial 17 finished with value: 0.783125 and parameters: {'lambda_l1': 1.2751777829369164e-05, 'lambda_l2': 0.0015325789671658556, 'num_leaves': 212, 'feature_fraction': 0.7171190782417727, 'bagging_fraction': 0.9675952112221868, 'bagging_freq': 7, 'min_child_samples': 19, 'min_data_in_leaf': 39}. Best is trial 14 with value: 0.79875.
# /tmp/ipykernel_30959/729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_30959/729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# /tmp/ipykernel_30959/729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# /tmp/ipykernel_30959/729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-30 14:29:30,422] Trial 18 finished with value: 0.786875 and parameters: {'lambda_l1': 0.054446519579449786, 'lambda_l2': 7.849587595751666e-05, 'num_leaves': 103, 'feature_fraction': 0.8539227849579437, 'bagging_fraction': 0.6849439050709402, 'bagging_freq': 3, 'min_child_samples': 20, 'min_data_in_leaf': 56}. Best is trial 14 with value: 0.79875.
# /tmp/ipykernel_30959/729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_30959/729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# /tmp/ipykernel_30959/729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# /tmp/ipykernel_30959/729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-30 14:29:30,809] Trial 19 finished with value: 0.79375 and parameters: {'lambda_l1': 0.0009687647758459732, 'lambda_l2': 0.17906345403314902, 'num_leaves': 176, 'feature_fraction': 0.9975490365121815, 'bagging_fraction': 0.8093249951657175, 'bagging_freq': 2, 'min_child_samples': 50, 'min_data_in_leaf': 69}. Best is trial 14 with value: 0.79875.
# /tmp/ipykernel_30959/729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_30959/729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# /tmp/ipykernel_30959/729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# /tmp/ipykernel_30959/729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-30 14:29:31,054] Trial 20 finished with value: 0.790625 and parameters: {'lambda_l1': 2.099751337604182e-08, 'lambda_l2': 0.003738174922196887, 'num_leaves': 219, 'feature_fraction': 0.48056792243404667, 'bagging_fraction': 0.6693834656526705, 'bagging_freq': 1, 'min_child_samples': 30, 'min_data_in_leaf': 58}. Best is trial 14 with value: 0.79875.
# /tmp/ipykernel_30959/729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_30959/729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# /tmp/ipykernel_30959/729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# /tmp/ipykernel_30959/729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-30 14:29:31,418] Trial 21 finished with value: 0.7875 and parameters: {'lambda_l1': 1.0041791359662639e-05, 'lambda_l2': 3.152025748055514e-07, 'num_leaves': 197, 'feature_fraction': 0.7486650431419104, 'bagging_fraction': 0.8576304213150983, 'bagging_freq': 1, 'min_child_samples': 96, 'min_data_in_leaf': 50}. Best is trial 14 with value: 0.79875.
# /tmp/ipykernel_30959/729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_30959/729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# /tmp/ipykernel_30959/729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# /tmp/ipykernel_30959/729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-30 14:29:31,877] Trial 22 finished with value: 0.795 and parameters: {'lambda_l1': 2.6308810406029023e-05, 'lambda_l2': 3.436875303541174e-07, 'num_leaves': 149, 'feature_fraction': 0.8126788621992294, 'bagging_fraction': 0.7701428336021731, 'bagging_freq': 1, 'min_child_samples': 95, 'min_data_in_leaf': 57}. Best is trial 14 with value: 0.79875.
# /tmp/ipykernel_30959/729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_30959/729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# /tmp/ipykernel_30959/729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# /tmp/ipykernel_30959/729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-30 14:29:32,555] Trial 23 finished with value: 0.786875 and parameters: {'lambda_l1': 1.1969897282315853e-06, 'lambda_l2': 1.3139952833363147e-05, 'num_leaves': 176, 'feature_fraction': 0.7197874675059865, 'bagging_fraction': 0.8643811854879286, 'bagging_freq': 2, 'min_child_samples': 5, 'min_data_in_leaf': 41}. Best is trial 14 with value: 0.79875.
# /tmp/ipykernel_30959/729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_30959/729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# /tmp/ipykernel_30959/729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# /tmp/ipykernel_30959/729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-30 14:29:38,879] Trial 24 finished with value: 0.78375 and parameters: {'lambda_l1': 3.643904468543235e-05, 'lambda_l2': 1.056473175710515e-06, 'num_leaves': 256, 'feature_fraction': 0.839276310945611, 'bagging_fraction': 0.9708781466748296, 'bagging_freq': 1, 'min_child_samples': 59, 'min_data_in_leaf': 33}. Best is trial 14 with value: 0.79875.
# /tmp/ipykernel_30959/729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_30959/729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# /tmp/ipykernel_30959/729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# /tmp/ipykernel_30959/729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-30 14:29:39,672] Trial 25 finished with value: 0.788125 and parameters: {'lambda_l1': 1.228271958499112e-07, 'lambda_l2': 1.1840995929039063e-07, 'num_leaves': 208, 'feature_fraction': 0.7546404677142621, 'bagging_fraction': 0.8273888489706728, 'bagging_freq': 3, 'min_child_samples': 86, 'min_data_in_leaf': 71}. Best is trial 14 with value: 0.79875.
# /tmp/ipykernel_30959/729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_30959/729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# /tmp/ipykernel_30959/729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# /tmp/ipykernel_30959/729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-30 14:29:40,239] Trial 26 finished with value: 0.79125 and parameters: {'lambda_l1': 0.0007568524882582003, 'lambda_l2': 2.254778108761222e-05, 'num_leaves': 234, 'feature_fraction': 0.6762220389588284, 'bagging_fraction': 0.7143287088761553, 'bagging_freq': 2, 'min_child_samples': 72, 'min_data_in_leaf': 52}. Best is trial 14 with value: 0.79875.
# /tmp/ipykernel_30959/729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_30959/729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# /tmp/ipykernel_30959/729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# /tmp/ipykernel_30959/729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-30 14:29:40,498] Trial 27 finished with value: 0.783125 and parameters: {'lambda_l1': 2.515993770047113e-06, 'lambda_l2': 0.0002678830091183267, 'num_leaves': 181, 'feature_fraction': 0.8745756515940234, 'bagging_fraction': 0.6088538682999047, 'bagging_freq': 5, 'min_child_samples': 34, 'min_data_in_leaf': 64}. Best is trial 14 with value: 0.79875.
# /tmp/ipykernel_30959/729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_30959/729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# /tmp/ipykernel_30959/729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# /tmp/ipykernel_30959/729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-30 14:29:40,915] Trial 28 finished with value: 0.790625 and parameters: {'lambda_l1': 1.8516639533152664e-07, 'lambda_l2': 0.001871621804056489, 'num_leaves': 123, 'feature_fraction': 0.7606817355060629, 'bagging_fraction': 0.9368112110134635, 'bagging_freq': 1, 'min_child_samples': 46, 'min_data_in_leaf': 43}. Best is trial 14 with value: 0.79875.
# /tmp/ipykernel_30959/729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_30959/729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# /tmp/ipykernel_30959/729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# /tmp/ipykernel_30959/729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-30 14:29:41,456] Trial 29 finished with value: 0.79 and parameters: {'lambda_l1': 6.751118739557132e-05, 'lambda_l2': 1.2017644092541129e-06, 'num_leaves': 221, 'feature_fraction': 0.9311309352665674, 'bagging_fraction': 0.7418500787610339, 'bagging_freq': 3, 'min_child_samples': 26, 'min_data_in_leaf': 30}. Best is trial 14 with value: 0.79875.
# /tmp/ipykernel_30959/729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_30959/729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
# ...
# /tmp/ipykernel_30959/729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_30959/729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# /tmp/ipykernel_30959/729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# /tmp/ipykernel_30959/729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-30 14:32:38,854] Trial 90 finished with value: 0.783125 and parameters: {'lambda_l1': 0.00014563465155130795, 'lambda_l2': 1.2391726752156107e-07, 'num_leaves': 52, 'feature_fraction': 0.5092688799518302, 'bagging_fraction': 0.918637274813792, 'bagging_freq': 1, 'min_child_samples': 23, 'min_data_in_leaf': 22}. Best is trial 75 with value: 0.789375.
# /tmp/ipykernel_30959/729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_30959/729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# /tmp/ipykernel_30959/729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# /tmp/ipykernel_30959/729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-30 14:32:39,250] Trial 91 finished with value: 0.7825 and parameters: {'lambda_l1': 1.48982177089802e-05, 'lambda_l2': 4.1839714571112864e-07, 'num_leaves': 86, 'feature_fraction': 0.5260470079037555, 'bagging_fraction': 0.8576395392196466, 'bagging_freq': 2, 'min_child_samples': 79, 'min_data_in_leaf': 30}. Best is trial 75 with value: 0.789375.
# /tmp/ipykernel_30959/729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_30959/729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# /tmp/ipykernel_30959/729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# /tmp/ipykernel_30959/729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-30 14:32:39,598] Trial 92 finished with value: 0.779375 and parameters: {'lambda_l1': 9.23901093465331e-06, 'lambda_l2': 1.097003740772171e-06, 'num_leaves': 76, 'feature_fraction': 0.7842873936278925, 'bagging_fraction': 0.8866205328791185, 'bagging_freq': 2, 'min_child_samples': 47, 'min_data_in_leaf': 27}. Best is trial 75 with value: 0.789375.
# /tmp/ipykernel_30959/729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_30959/729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# /tmp/ipykernel_30959/729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# /tmp/ipykernel_30959/729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-30 14:32:40,048] Trial 93 finished with value: 0.78125 and parameters: {'lambda_l1': 4.618833257736377e-06, 'lambda_l2': 2.0981226453994304e-07, 'num_leaves': 95, 'feature_fraction': 0.8172887619799151, 'bagging_fraction': 0.9461172608846361, 'bagging_freq': 1, 'min_child_samples': 89, 'min_data_in_leaf': 24}. Best is trial 75 with value: 0.789375.
# /tmp/ipykernel_30959/729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_30959/729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# /tmp/ipykernel_30959/729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# /tmp/ipykernel_30959/729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-30 14:32:40,439] Trial 94 finished with value: 0.781875 and parameters: {'lambda_l1': 8.495002894961749e-05, 'lambda_l2': 7.488912003220344e-08, 'num_leaves': 90, 'feature_fraction': 0.5550916058102513, 'bagging_fraction': 0.9044815420744408, 'bagging_freq': 1, 'min_child_samples': 86, 'min_data_in_leaf': 35}. Best is trial 75 with value: 0.789375.
# /tmp/ipykernel_30959/729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_30959/729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# /tmp/ipykernel_30959/729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# /tmp/ipykernel_30959/729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-30 14:32:40,745] Trial 95 finished with value: 0.775625 and parameters: {'lambda_l1': 0.0003232893282368137, 'lambda_l2': 1.0202387556397317e-08, 'num_leaves': 229, 'feature_fraction': 0.5855937064816658, 'bagging_fraction': 0.426603928515406, 'bagging_freq': 2, 'min_child_samples': 92, 'min_data_in_leaf': 20}. Best is trial 75 with value: 0.789375.
# /tmp/ipykernel_30959/729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_30959/729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# /tmp/ipykernel_30959/729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# /tmp/ipykernel_30959/729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-30 14:32:41,005] Trial 96 finished with value: 0.776875 and parameters: {'lambda_l1': 1.9274305966313387e-05, 'lambda_l2': 7.522240478549663e-07, 'num_leaves': 39, 'feature_fraction': 0.4281436695624451, 'bagging_fraction': 0.9293229637060051, 'bagging_freq': 4, 'min_child_samples': 50, 'min_data_in_leaf': 23}. Best is trial 75 with value: 0.789375.
# /tmp/ipykernel_30959/729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_30959/729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# /tmp/ipykernel_30959/729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# /tmp/ipykernel_30959/729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-30 14:32:41,337] Trial 97 finished with value: 0.775625 and parameters: {'lambda_l1': 3.7849719333829416e-05, 'lambda_l2': 3.169150717917385e-07, 'num_leaves': 103, 'feature_fraction': 0.9881934069632974, 'bagging_fraction': 0.8891093522985793, 'bagging_freq': 3, 'min_child_samples': 99, 'min_data_in_leaf': 100}. Best is trial 75 with value: 0.789375.
# /tmp/ipykernel_30959/729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_30959/729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# /tmp/ipykernel_30959/729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# /tmp/ipykernel_30959/729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-30 14:32:42,968] Trial 98 finished with value: 0.774375 and parameters: {'lambda_l1': 3.2245781732958147e-06, 'lambda_l2': 0.00012920251294844308, 'num_leaves': 71, 'feature_fraction': 0.7429639291387968, 'bagging_fraction': 0.8612559855571209, 'bagging_freq': 5, 'min_child_samples': 64, 'min_data_in_leaf': 28}. Best is trial 75 with value: 0.789375.
# /tmp/ipykernel_30959/729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_30959/729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# /tmp/ipykernel_30959/729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# /tmp/ipykernel_30959/729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-30 14:32:43,688] Trial 99 finished with value: 0.778125 and parameters: {'lambda_l1': 0.0006690398238067464, 'lambda_l2': 1.8590344812121163e-06, 'num_leaves': 80, 'feature_fraction': 0.5304246842627753, 'bagging_fraction': 0.9675971673968919, 'bagging_freq': 1, 'min_child_samples': 40, 'min_data_in_leaf': 31}. Best is trial 75 with value: 0.789375.

# %% [markdown]
# - lgb_平均スコア

# %%
# 全フォールドの平均スコアを計算
lgb_average_score = sum(lgb_fold_scores) / n_splits
print(f"LightGBM Average accuracy across all folds: {lgb_average_score:.4f}")


lgb_average_conf = sum(lgb_conf_scores) / n_splits
print(f"LightGBM Average conf-matrix across all folds: {lgb_average_conf}")
# Out:
# LightGBM Average accuracy across all folds: 0.7839
# LightGBM Average conf-matrix across all folds: [[630.  183.2]
#  [162.6 624.2]]

# %% [markdown]
# - lgb_予測平均

# %%
# 予測の平均を計算
lgb_y_test_pred_avg = np.mean(lgb_test_predictions, axis=0)

# 最終的な予測結果を整数に変換
lgb_y_test_pred_int = (lgb_y_test_pred_avg > lgb_threshold).astype(int)

# %% [markdown]
# - output

# %%
# 現在の日時を取得してフォーマットする
current_time = datetime.now().strftime("%Y%m%d_%H%M%S")
output = f'../data/output/{current_time}_LightGBM_cv{lgb_average_score:.4f}.csv'

submit = pd.DataFrame({
    '0': test['gameId'],
    '1': lgb_y_test_pred_int
})

# カラムヘッダー消去して出力
# ヘッダーなしでCSVファイルとして保存
submit.to_csv(output, header=False, index=False)

# %%
submit
# Out:
#          0  1
# 0        9  1
# 1       15  1
# 2       18  0
# 3       23  0
# 4       31  1
# ...    ... ..
# 1995  9971  0
# 1996  9980  0
# 1997  9983  1
# 1998  9996  1
# 1999  9999  0
#
# [2000 rows x 2 columns]

# %% [markdown]
# ## XGBoost

# %%
for train_index, val_index in kf.split(X):
    X_train_fold, X_val_fold = X.iloc[train_index], X.iloc[val_index]
    y_train_fold, y_val_fold = y[train_index], y[val_index]

    dtrain = xgb.DMatrix(X_train_fold, label=y_train_fold)
    dval = xgb.DMatrix(X_val_fold, label=y_val_fold)
    dtest = xgb.DMatrix(test_drop_gameId)

    # Optunaでのハイパーパラメータチューニング
    def objective(trial):
        param = {
            'verbosity': 0,
            'objective': 'binary:logistic',
            'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
            'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
            'max_depth': trial.suggest_int('max_depth', 3, 9),
            'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
            'subsample': trial.suggest_float('subsample', 0.5, 1),
            'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1)
        }

        bst = xgb.train(param, dtrain, num_boost_round=1000, evals=[(dval, "eval")], early_stopping_rounds=100, verbose_eval=False)
        preds = bst.predict(dval)
        pred_labels = np.rint(preds)
        accuracy = accuracy_score(y_val_fold, pred_labels)
        return accuracy

    xgb_study = optuna.create_study(direction='maximize')
    xgb_study.optimize(objective, n_trials=100)

    # 各フォールドの最適パラメータでモデルを再学習
    xgb_best_params = xgb_study.best_params
    xgb_best_params['objective'] = 'binary:logistic'
    xgb_best_params['verbosity'] = 0

    xgb_final_bst = xgb.train(xgb_best_params, dtrain, num_boost_round=xgb_study.best_trial.number)

    # 各フォールドのモデル性能を評価
    xgb_y_val_pred = xgb_final_bst.predict(dval)
    xgb_y_val_pred_int = np.rint(xgb_y_val_pred)
    fold_accuracy = accuracy_score(y_val_fold, xgb_y_val_pred_int)
    xgb_fold_scores.append(fold_accuracy)

    # 混同行列
    xgb_conf_matrix = confusion_matrix(y_val_fold, xgb_y_val_pred_int)
    xgb_conf_scores.append(xgb_conf_matrix)

    # テストデータセットでの予測
    xgb_y_test_pred_fold = xgb_final_bst.predict(dtest)
    xgb_test_predictions.append(xgb_y_test_pred_fold)
# Out:
# [I 2024-01-30 14:32:45,186] A new study created in memory with name: no-name-87e7d1a3-84a1-4a83-82d5-72294342982f
# /tmp/ipykernel_30959/458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_30959/458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_30959/458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-30 14:32:45,736] Trial 0 finished with value: 0.778125 and parameters: {'alpha': 3.856590361142648e-06, 'lambda': 0.05025625649752977, 'max_depth': 4, 'eta': 0.5683665687754869, 'subsample': 0.8128337250230036, 'colsample_bytree': 0.694063739106369}. Best is trial 0 with value: 0.778125.
# /tmp/ipykernel_30959/458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_30959/458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_30959/458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-30 14:32:46,228] Trial 1 finished with value: 0.778125 and parameters: {'alpha': 6.454167050774014e-08, 'lambda': 2.303326753608073e-05, 'max_depth': 8, 'eta': 0.1023606643554213, 'subsample': 0.778698825321743, 'colsample_bytree': 0.7221117240598953}. Best is trial 0 with value: 0.778125.
# /tmp/ipykernel_30959/458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_30959/458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_30959/458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-30 14:32:50,633] Trial 2 finished with value: 0.783125 and parameters: {'alpha': 0.007056574392778089, 'lambda': 0.0061927086596266934, 'max_depth': 6, 'eta': 0.00029779452430451944, 'subsample': 0.7906055495646169, 'colsample_bytree': 0.710028916373543}. Best is trial 2 with value: 0.783125.
# /tmp/ipykernel_30959/458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_30959/458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_30959/458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-30 14:32:56,273] Trial 3 finished with value: 0.78375 and parameters: {'alpha': 3.4535896364594366e-08, 'lambda': 0.16438928270117778, 'max_depth': 7, 'eta': 0.00016043097101492906, 'subsample': 0.5260985825874196, 'colsample_bytree': 0.8817967049893625}. Best is trial 3 with value: 0.78375.
# /tmp/ipykernel_30959/458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_30959/458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_30959/458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-30 14:32:59,105] Trial 4 finished with value: 0.785 and parameters: {'alpha': 1.1238166084373085e-06, 'lambda': 6.561299367401645e-05, 'max_depth': 7, 'eta': 0.0002612858712907335, 'subsample': 0.7919470489928662, 'colsample_bytree': 0.5425697086215961}. Best is trial 4 with value: 0.785.
# /tmp/ipykernel_30959/458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_30959/458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_30959/458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-30 14:33:00,577] Trial 5 finished with value: 0.51125 and parameters: {'alpha': 2.30420915164672e-05, 'lambda': 2.1783206931428977e-05, 'max_depth': 5, 'eta': 1.6721717797186698e-06, 'subsample': 0.7915973875076967, 'colsample_bytree': 0.8770645111335142}. Best is trial 4 with value: 0.785.
# /tmp/ipykernel_30959/458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_30959/458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_30959/458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-30 14:33:02,755] Trial 6 finished with value: 0.51125 and parameters: {'alpha': 0.0001235971918268151, 'lambda': 0.24833960714734676, 'max_depth': 7, 'eta': 1.332439644642399e-06, 'subsample': 0.717742205797298, 'colsample_bytree': 0.5127530006174809}. Best is trial 4 with value: 0.785.
# /tmp/ipykernel_30959/458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_30959/458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_30959/458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-30 14:33:04,144] Trial 7 finished with value: 0.69625 and parameters: {'alpha': 1.6736680407074668e-07, 'lambda': 0.25375100283131174, 'max_depth': 4, 'eta': 2.6800742096366285e-05, 'subsample': 0.9256616730711875, 'colsample_bytree': 0.8383300571766129}. Best is trial 4 with value: 0.785.
# /tmp/ipykernel_30959/458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_30959/458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_30959/458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-30 14:33:04,550] Trial 8 finished with value: 0.77125 and parameters: {'alpha': 1.001796949389587e-05, 'lambda': 1.1499825848284625e-07, 'max_depth': 9, 'eta': 0.12881863863012913, 'subsample': 0.6463039933683263, 'colsample_bytree': 0.8901614708477088}. Best is trial 4 with value: 0.785.
# /tmp/ipykernel_30959/458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_30959/458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_30959/458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-30 14:33:08,606] Trial 9 finished with value: 0.51125 and parameters: {'alpha': 3.161305531204216e-08, 'lambda': 9.060767694042827e-07, 'max_depth': 9, 'eta': 8.190815241911602e-08, 'subsample': 0.6067525663829858, 'colsample_bytree': 0.7007939015965052}. Best is trial 4 with value: 0.785.
# /tmp/ipykernel_30959/458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_30959/458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_30959/458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-30 14:33:09,803] Trial 10 finished with value: 0.7825 and parameters: {'alpha': 0.03261649356332674, 'lambda': 0.00028394875079036706, 'max_depth': 3, 'eta': 0.004985531227448186, 'subsample': 0.955851278123488, 'colsample_bytree': 0.5115132091678667}. Best is trial 4 with value: 0.785.
# /tmp/ipykernel_30959/458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_30959/458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_30959/458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-30 14:33:12,122] Trial 11 finished with value: 0.788125 and parameters: {'alpha': 6.331103098533486e-07, 'lambda': 0.0013427182933810197, 'max_depth': 7, 'eta': 0.0005924069301860091, 'subsample': 0.5280101311385335, 'colsample_bytree': 0.965458640891117}. Best is trial 11 with value: 0.788125.
# /tmp/ipykernel_30959/458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_30959/458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_30959/458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-30 14:33:14,285] Trial 12 finished with value: 0.79125 and parameters: {'alpha': 9.505344681699806e-07, 'lambda': 0.0005850659617906664, 'max_depth': 7, 'eta': 0.0031564717816944974, 'subsample': 0.521664742615017, 'colsample_bytree': 0.9943534303027052}. Best is trial 12 with value: 0.79125.
# /tmp/ipykernel_30959/458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_30959/458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_30959/458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-30 14:33:16,225] Trial 13 finished with value: 0.798125 and parameters: {'alpha': 0.0016203980510701415, 'lambda': 0.0016468479868175703, 'max_depth': 6, 'eta': 0.005399941262882031, 'subsample': 0.5009148074954418, 'colsample_bytree': 0.987977245566777}. Best is trial 13 with value: 0.798125.
# /tmp/ipykernel_30959/458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_30959/458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_30959/458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-30 14:33:18,219] Trial 14 finished with value: 0.798125 and parameters: {'alpha': 0.0004779277518970937, 'lambda': 0.006366025908296665, 'max_depth': 6, 'eta': 0.005461663560397355, 'subsample': 0.5012667829590554, 'colsample_bytree': 0.9808027117458115}. Best is trial 13 with value: 0.798125.
# /tmp/ipykernel_30959/458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_30959/458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_30959/458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-30 14:33:19,598] Trial 15 finished with value: 0.80125 and parameters: {'alpha': 0.0008537419593534083, 'lambda': 0.008936826059764228, 'max_depth': 5, 'eta': 0.012224754010513119, 'subsample': 0.6071041941420123, 'colsample_bytree': 0.9487951930697557}. Best is trial 15 with value: 0.80125.
# /tmp/ipykernel_30959/458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_30959/458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_30959/458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-30 14:33:20,083] Trial 16 finished with value: 0.796875 and parameters: {'alpha': 0.0020668892667577753, 'lambda': 0.011785284647542988, 'max_depth': 5, 'eta': 0.03543701369353581, 'subsample': 0.6269460078955333, 'colsample_bytree': 0.7952787825564249}. Best is trial 15 with value: 0.80125.
# /tmp/ipykernel_30959/458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_30959/458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_30959/458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-30 14:33:21,911] Trial 17 finished with value: 0.688125 and parameters: {'alpha': 0.2125316974343991, 'lambda': 0.9695692349135727, 'max_depth': 5, 'eta': 2.1669395868381717e-05, 'subsample': 0.5763127474553931, 'colsample_bytree': 0.61849835248412}. Best is trial 15 with value: 0.80125.
# /tmp/ipykernel_30959/458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_30959/458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_30959/458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-30 14:33:22,987] Trial 18 finished with value: 0.796875 and parameters: {'alpha': 0.583605971895106, 'lambda': 1.0582806324977025e-06, 'max_depth': 3, 'eta': 0.018609021152192432, 'subsample': 0.6711684769470583, 'colsample_bytree': 0.9422540845859545}. Best is trial 15 with value: 0.80125.
# /tmp/ipykernel_30959/458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_30959/458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_30959/458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-30 14:33:23,320] Trial 19 finished with value: 0.765 and parameters: {'alpha': 0.0005868185981162481, 'lambda': 0.02453685797431952, 'max_depth': 6, 'eta': 0.3982261723611216, 'subsample': 0.718977204595643, 'colsample_bytree': 0.9350256158672098}. Best is trial 15 with value: 0.80125.
# /tmp/ipykernel_30959/458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_30959/458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_30959/458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-30 14:33:24,939] Trial 20 finished with value: 0.77875 and parameters: {'alpha': 0.01719689373734971, 'lambda': 0.0017455732620652194, 'max_depth': 4, 'eta': 0.0011435813623754993, 'subsample': 0.5779672054647794, 'colsample_bytree': 0.8273676218658816}. Best is trial 15 with value: 0.80125.
# /tmp/ipykernel_30959/458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_30959/458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_30959/458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-30 14:33:26,489] Trial 21 finished with value: 0.799375 and parameters: {'alpha': 0.00020771112703588975, 'lambda': 0.004720089044106724, 'max_depth': 6, 'eta': 0.009700915856786483, 'subsample': 0.5632317341487276, 'colsample_bytree': 0.9976604469874428}. Best is trial 15 with value: 0.80125.
# /tmp/ipykernel_30959/458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_30959/458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_30959/458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-30 14:33:26,918] Trial 22 finished with value: 0.79625 and parameters: {'alpha': 8.53202320905772e-05, 'lambda': 0.0025113118982423225, 'max_depth': 6, 'eta': 0.052257125200253975, 'subsample': 0.5659615053218033, 'colsample_bytree': 0.9280669817471473}. Best is trial 15 with value: 0.80125.
# /tmp/ipykernel_30959/458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_30959/458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_30959/458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-30 14:33:28,518] Trial 23 finished with value: 0.7975 and parameters: {'alpha': 0.0018519182251146155, 'lambda': 0.00021509651002301955, 'max_depth': 5, 'eta': 0.01259992754026343, 'subsample': 0.6790951419733272, 'colsample_bytree': 0.9918438324536077}. Best is trial 15 with value: 0.80125.
# /tmp/ipykernel_30959/458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_30959/458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_30959/458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-30 14:33:31,599] Trial 24 finished with value: 0.7925 and parameters: {'alpha': 0.00018232781799404577, 'lambda': 0.0625121646961946, 'max_depth': 8, 'eta': 0.0017757384989735587, 'subsample': 0.5665980888906389, 'colsample_bytree': 0.9147706668349039}. Best is trial 15 with value: 0.80125.
# /tmp/ipykernel_30959/458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_30959/458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_30959/458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-30 14:33:33,885] Trial 25 finished with value: 0.74875 and parameters: {'alpha': 0.0032246099369586763, 'lambda': 5.980788848771383e-05, 'max_depth': 6, 'eta': 4.0438097918829445e-05, 'subsample': 0.861476523311997, 'colsample_bytree': 0.9997959122888352}. Best is trial 15 with value: 0.80125.
# /tmp/ipykernel_30959/458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_30959/458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_30959/458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-30 14:33:35,008] Trial 26 finished with value: 0.8025 and parameters: {'alpha': 0.070943212417853, 'lambda': 6.729727604303723e-06, 'max_depth': 5, 'eta': 0.011708975813679978, 'subsample': 0.6015197037077157, 'colsample_bytree': 0.77192876678239}. Best is trial 26 with value: 0.8025.
# /tmp/ipykernel_30959/458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_30959/458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_30959/458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-30 14:33:35,213] Trial 27 finished with value: 0.795 and parameters: {'alpha': 0.10094971648172138, 'lambda': 1.0159808232307425e-08, 'max_depth': 4, 'eta': 0.15135384778908473, 'subsample': 0.6200245076747435, 'colsample_bytree': 0.6460236421816465}. Best is trial 26 with value: 0.8025.
# /tmp/ipykernel_30959/458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_30959/458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_30959/458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-30 14:33:36,802] Trial 28 finished with value: 0.8025 and parameters: {'alpha': 0.07665253184551027, 'lambda': 4.392249976883022e-06, 'max_depth': 5, 'eta': 0.015332257115954121, 'subsample': 0.7214304248562249, 'colsample_bytree': 0.7766291909200304}. Best is trial 26 with value: 0.8025.
# /tmp/ipykernel_30959/458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_30959/458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_30959/458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-30 14:33:37,120] Trial 29 finished with value: 0.746875 and parameters: {'alpha': 0.05120585400477624, 'lambda': 2.454160360200548e-06, 'max_depth': 5, 'eta': 0.9052396795529889, 'subsample': 0.7212293324402889, 'colsample_bytree': 0.7682959608007583}. Best is trial 26 with value: 0.8025.
# /tmp/ipykernel_30959/458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_30959/458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_30959/458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-30 14:33:37,483] Trial 30 finished with value: 0.795 and parameters: {'alpha': 0.6749228340794056, 'lambda': 5.809451372235146e-06, 'max_depth': 4, 'eta': 0.26703837585822526, 'subsample': 0.8361620397911018, 'colsample_bytree': 0.6594843985458603}. Best is trial 26 with value: 0.8025.
# /tmp/ipykernel_30959/458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_30959/458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_30959/458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-30 14:33:38,643] Trial 31 finished with value: 0.796875 and parameters: {'alpha': 0.009691759586428211, 'lambda': 6.929204669212861e-06, 'max_depth': 5, 'eta': 0.018534958537609707, 'subsample': 0.6677865177247656, 'colsample_bytree': 0.8376541065107036}. Best is trial 26 with value: 0.8025.
# /tmp/ipykernel_30959/458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_30959/458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_30959/458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-30 14:33:39,054] Trial 32 finished with value: 0.796875 and parameters: {'alpha': 0.1713977595539784, 'lambda': 7.991114677007728e-08, 'max_depth': 5, 'eta': 0.07676294988946071, 'subsample': 0.5983894356524619, 'colsample_bytree': 0.7538113693213445}. Best is trial 26 with value: 0.8025.
# /tmp/ipykernel_30959/458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_30959/458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_30959/458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-30 14:33:40,438] Trial 33 finished with value: 0.780625 and parameters: {'alpha': 3.773518750641868e-05, 'lambda': 2.0894201573951878e-07, 'max_depth': 5, 'eta': 0.0008733459254799623, 'subsample': 0.7525993504947038, 'colsample_bytree': 0.8075349381992444}. Best is trial 26 with value: 0.8025.
# /tmp/ipykernel_30959/458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_30959/458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_30959/458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-30 14:33:41,822] Trial 34 finished with value: 0.80125 and parameters: {'alpha': 0.0005561720118654757, 'lambda': 6.135722106004459e-06, 'max_depth': 6, 'eta': 0.013488413000796775, 'subsample': 0.5508166824115037, 'colsample_bytree': 0.7328938193653289}. Best is trial 26 with value: 0.8025.
# /tmp/ipykernel_30959/458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_30959/458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_30959/458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-30 14:33:42,684] Trial 35 finished with value: 0.80375 and parameters: {'alpha': 0.005450138486755273, 'lambda': 1.347360954227177e-05, 'max_depth': 4, 'eta': 0.024357283569348666, 'subsample': 0.6954473174180954, 'colsample_bytree': 0.7312308469440649}. Best is trial 35 with value: 0.80375.
# /tmp/ipykernel_30959/458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_30959/458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_30959/458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-30 14:33:43,592] Trial 36 finished with value: 0.7525 and parameters: {'alpha': 0.006412839103125298, 'lambda': 2.897370864885298e-05, 'max_depth': 3, 'eta': 0.00010106512975881076, 'subsample': 0.6835505532665246, 'colsample_bytree': 0.6748324509854974}. Best is trial 35 with value: 0.80375.
# /tmp/ipykernel_30959/458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_30959/458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_30959/458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-30 14:33:44,207] Trial 37 finished with value: 0.7975 and parameters: {'alpha': 0.02867211768868872, 'lambda': 1.793961056814954e-05, 'max_depth': 4, 'eta': 0.05110730245689519, 'subsample': 0.7546983454000735, 'colsample_bytree': 0.78350527168716}. Best is trial 35 with value: 0.80375.
# /tmp/ipykernel_30959/458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_30959/458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_30959/458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-30 14:33:45,664] Trial 38 finished with value: 0.7725 and parameters: {'alpha': 0.0712965460456739, 'lambda': 6.477898399207712e-07, 'max_depth': 4, 'eta': 0.0004678089384741167, 'subsample': 0.6494805782632683, 'colsample_bytree': 0.6062975739755788}. Best is trial 35 with value: 0.80375.
# /tmp/ipykernel_30959/458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_30959/458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_30959/458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# ...
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-30 14:48:36,307] Trial 86 finished with value: 0.79 and parameters: {'alpha': 0.10599923448029985, 'lambda': 0.06344760313409364, 'max_depth': 7, 'eta': 0.001358689023703306, 'subsample': 0.7801621006113569, 'colsample_bytree': 0.6668490717969088}. Best is trial 52 with value: 0.8.
# /tmp/ipykernel_30959/458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_30959/458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_30959/458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-30 14:48:36,633] Trial 87 finished with value: 0.779375 and parameters: {'alpha': 0.001453184416339008, 'lambda': 3.561075515597746e-07, 'max_depth': 7, 'eta': 0.045276810138353885, 'subsample': 0.5725277272758978, 'colsample_bytree': 0.9838066034444338}. Best is trial 52 with value: 0.8.
# /tmp/ipykernel_30959/458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_30959/458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_30959/458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-30 14:48:37,760] Trial 88 finished with value: 0.79875 and parameters: {'alpha': 0.0007155969426621302, 'lambda': 0.18550665093231086, 'max_depth': 5, 'eta': 0.005698695496148123, 'subsample': 0.7079243942320592, 'colsample_bytree': 0.9262091510612134}. Best is trial 52 with value: 0.8.
# /tmp/ipykernel_30959/458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_30959/458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_30959/458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-30 14:48:38,832] Trial 89 finished with value: 0.789375 and parameters: {'alpha': 0.0007965197574140859, 'lambda': 0.20709252074352136, 'max_depth': 4, 'eta': 0.004985739993765183, 'subsample': 0.6674180329940868, 'colsample_bytree': 0.9309324059249059}. Best is trial 52 with value: 0.8.
# /tmp/ipykernel_30959/458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_30959/458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_30959/458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-30 14:48:40,546] Trial 90 finished with value: 0.785 and parameters: {'alpha': 0.007026006714608485, 'lambda': 0.6939986410493515, 'max_depth': 5, 'eta': 0.0007725795493981021, 'subsample': 0.6323196117841071, 'colsample_bytree': 0.9011404916551401}. Best is trial 52 with value: 0.8.
# /tmp/ipykernel_30959/458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_30959/458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_30959/458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-30 14:48:42,280] Trial 91 finished with value: 0.8 and parameters: {'alpha': 0.00035663682305014124, 'lambda': 0.10626017842744408, 'max_depth': 3, 'eta': 0.01404875753760121, 'subsample': 0.7014971087785912, 'colsample_bytree': 0.917206588609663}. Best is trial 52 with value: 0.8.
# /tmp/ipykernel_30959/458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_30959/458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_30959/458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-30 14:48:44,603] Trial 92 finished with value: 0.78125 and parameters: {'alpha': 0.0020742048288385426, 'lambda': 0.3483405219237195, 'max_depth': 4, 'eta': 0.0024844953499543955, 'subsample': 0.7066779772462859, 'colsample_bytree': 0.9211964778341136}. Best is trial 52 with value: 0.8.
# /tmp/ipykernel_30959/458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_30959/458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_30959/458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-30 14:48:45,998] Trial 93 finished with value: 0.7975 and parameters: {'alpha': 0.0009615636207712216, 'lambda': 0.11436194704228084, 'max_depth': 3, 'eta': 0.011497634033567447, 'subsample': 0.6507797021286563, 'colsample_bytree': 0.9438839450725811}. Best is trial 52 with value: 0.8.
# /tmp/ipykernel_30959/458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_30959/458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_30959/458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-30 14:48:47,163] Trial 94 finished with value: 0.8 and parameters: {'alpha': 0.0003249813845315704, 'lambda': 0.058720248544440266, 'max_depth': 3, 'eta': 0.025179597588008123, 'subsample': 0.6824260703980728, 'colsample_bytree': 0.9054635035375782}. Best is trial 52 with value: 0.8.
# /tmp/ipykernel_30959/458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_30959/458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_30959/458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-30 14:48:48,571] Trial 95 finished with value: 0.78375 and parameters: {'alpha': 0.00039617183488247393, 'lambda': 0.023052203449887298, 'max_depth': 3, 'eta': 0.0059907252806420345, 'subsample': 0.6864924585154888, 'colsample_bytree': 0.9143485972028476}. Best is trial 52 with value: 0.8.
# /tmp/ipykernel_30959/458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_30959/458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_30959/458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-30 14:48:50,079] Trial 96 finished with value: 0.511875 and parameters: {'alpha': 4.7292079420135474e-05, 'lambda': 0.06465979687760684, 'max_depth': 3, 'eta': 1.5219973452687729e-05, 'subsample': 0.7193965622364094, 'colsample_bytree': 0.8936790384459004}. Best is trial 52 with value: 0.8.
# /tmp/ipykernel_30959/458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_30959/458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_30959/458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-30 14:48:51,152] Trial 97 finished with value: 0.801875 and parameters: {'alpha': 0.0003748549950575623, 'lambda': 0.1720489397254824, 'max_depth': 3, 'eta': 0.015281189170451149, 'subsample': 0.6958158725438421, 'colsample_bytree': 0.8838677910390038}. Best is trial 97 with value: 0.801875.
# /tmp/ipykernel_30959/458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_30959/458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_30959/458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-30 14:48:52,348] Trial 98 finished with value: 0.79875 and parameters: {'alpha': 0.00015311904338062123, 'lambda': 0.03189756961212156, 'max_depth': 3, 'eta': 0.01323691181469372, 'subsample': 0.6921110089541077, 'colsample_bytree': 0.8775313453520466}. Best is trial 97 with value: 0.801875.
# /tmp/ipykernel_30959/458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_30959/458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_30959/458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-30 14:48:52,699] Trial 99 finished with value: 0.80625 and parameters: {'alpha': 0.0002770731704862932, 'lambda': 0.014334213372524449, 'max_depth': 3, 'eta': 0.10418196441251903, 'subsample': 0.7011292875873101, 'colsample_bytree': 0.8719503292462046}. Best is trial 99 with value: 0.80625.

# %% [markdown]
# - xgb_平均スコア

# %%
# 全フォールドの平均スコアを計算
xgb_average_score = sum(xgb_fold_scores) / n_splits
print(f"XGB Average accuracy across all folds: {xgb_average_score:.4f}")

xgb_average_conf = sum(xgb_conf_scores) / n_splits
print(f"XGB Average conf-matrix across all folds: {xgb_average_conf}")
# Out:
# XGB Average accuracy across all folds: 0.7266
# XGB Average conf-matrix across all folds: [[676.6 136.6]
#  [300.8 486. ]]

# %% [markdown]
# - xgb_予測平均

# %%
# 予測の平均を計算
xgb_y_test_pred_avg = np.mean(xgb_test_predictions, axis=0)

# 最終的な予測結果を整数に変換
xgb_y_test_pred_int = (xgb_y_test_pred_avg > xgb_threshold).astype(int)

# %% [markdown]
# - output

# %%
# 現在の日時を取得してフォーマットする
current_time = datetime.now().strftime("%Y%m%d_%H%M%S")
output = f'../data/output/{current_time}_XGBoost_cv{xgb_average_score:.4f}.csv'

submit = pd.DataFrame({
    '0': test['gameId'],
    '1': xgb_y_test_pred_int
})

# カラムヘッダー消去して出力
# ヘッダーなしでCSVファイルとして保存
submit.to_csv(output, header=False, index=False)

# %% [markdown]
# ## CatBoost

# %%
for train_index, val_index in kf.split(X):
    X_train_fold, X_val_fold = X.iloc[train_index], X.iloc[val_index]
    y_train_fold, y_val_fold = y[train_index], y[val_index]

    # Optunaでのハイパーパラメータチューニング
    def objective(trial):
        param = {
            'iterations': 1000,
            'depth': trial.suggest_int('depth', 4, 10),
            'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3),
            'random_strength': trial.suggest_int('random_strength', 1, 20),
            'bagging_temperature': trial.suggest_float('bagging_temperature', 0.0, 1.0),
            'l2_leaf_reg': trial.suggest_float('l2_leaf_reg', 1e-3, 100),
            'scale_pos_weight': trial.suggest_float('scale_pos_weight', 0.1, 10.0),
            'loss_function': 'Logloss'
        }

        model = cb.CatBoostClassifier(**param, verbose=False)
        model.fit(X_train_fold, y_train_fold, eval_set=(X_val_fold, y_val_fold), early_stopping_rounds=100)
        preds = model.predict(X_val_fold)
        accuracy = accuracy_score(y_val_fold, preds)
        return accuracy

    cb_study = optuna.create_study(direction='maximize')
    cb_study.optimize(objective, n_trials=100)

    # 各フォールドの最適パラメータでモデルを再学習
    cb_best_params = cb_study.best_params
    cb_best_params['loss_function'] = 'Logloss'
    model_fold = cb.CatBoostClassifier(**cb_best_params, verbose=False)
    model_fold.fit(X_train_fold, y_train_fold)

    # 各フォールドのモデル性能を評価
    cb_y_val_pred = model_fold.predict(X_val_fold)
    cb_fold_accuracy = accuracy_score(y_val_fold, cb_y_val_pred)
    cb_fold_scores.append(cb_fold_accuracy)

    # 混同行列
    cb_conf_matrix = confusion_matrix(y_val_fold, cb_y_val_pred)
    cb_conf_scores.append(cb_conf_matrix)

    # テストデータセットでの予測
    cb_y_test_pred_fold = model_fold.predict(test_drop_gameId)
    cb_test_predictions.append(cb_y_test_pred_fold)
# Out:
# [I 2024-01-30 14:48:52,886] A new study created in memory with name: no-name-e9aacf98-38a1-4b1d-9b45-d5c0cd1a8b86
# [I 2024-01-30 14:48:53,927] Trial 0 finished with value: 0.715 and parameters: {'depth': 10, 'learning_rate': 0.2921139170362465, 'random_strength': 9, 'bagging_temperature': 0.022974829855684997, 'l2_leaf_reg': 96.11952373539836, 'scale_pos_weight': 4.520178244990523}. Best is trial 0 with value: 0.715.
# [I 2024-01-30 14:48:54,537] Trial 1 finished with value: 0.755625 and parameters: {'depth': 8, 'learning_rate': 0.1778888765246378, 'random_strength': 3, 'bagging_temperature': 0.6435419668818809, 'l2_leaf_reg': 50.56034011356818, 'scale_pos_weight': 1.9062284619457084}. Best is trial 1 with value: 0.755625.
# [I 2024-01-30 14:48:55,416] Trial 2 finished with value: 0.7675 and parameters: {'depth': 5, 'learning_rate': 0.19661803150061513, 'random_strength': 4, 'bagging_temperature': 0.08186433294070683, 'l2_leaf_reg': 88.274081526673, 'scale_pos_weight': 1.2797015392368813}. Best is trial 2 with value: 0.7675.
# [I 2024-01-30 14:48:56,197] Trial 3 finished with value: 0.776875 and parameters: {'depth': 6, 'learning_rate': 0.10615707051565985, 'random_strength': 15, 'bagging_temperature': 0.6761029737432027, 'l2_leaf_reg': 8.169647983216414, 'scale_pos_weight': 0.7920554566616298}. Best is trial 3 with value: 0.776875.
# [I 2024-01-30 14:48:56,695] Trial 4 finished with value: 0.736875 and parameters: {'depth': 4, 'learning_rate': 0.2730828295106195, 'random_strength': 14, 'bagging_temperature': 0.5222188744370984, 'l2_leaf_reg': 49.80990597598771, 'scale_pos_weight': 2.751594390912245}. Best is trial 3 with value: 0.776875.
# [I 2024-01-30 14:48:58,296] Trial 5 finished with value: 0.689375 and parameters: {'depth': 10, 'learning_rate': 0.10999364611794606, 'random_strength': 16, 'bagging_temperature': 0.08721335406529729, 'l2_leaf_reg': 67.91987485432891, 'scale_pos_weight': 7.25380757022577}. Best is trial 3 with value: 0.776875.
# [I 2024-01-30 14:48:59,740] Trial 6 finished with value: 0.749375 and parameters: {'depth': 5, 'learning_rate': 0.08232546809807519, 'random_strength': 19, 'bagging_temperature': 0.8448428107987712, 'l2_leaf_reg': 79.43699152481965, 'scale_pos_weight': 2.4381609432437137}. Best is trial 3 with value: 0.776875.
# [I 2024-01-30 14:49:00,349] Trial 7 finished with value: 0.724375 and parameters: {'depth': 9, 'learning_rate': 0.27114401597785975, 'random_strength': 10, 'bagging_temperature': 0.7505346006124343, 'l2_leaf_reg': 8.70170769388664, 'scale_pos_weight': 3.13500143391196}. Best is trial 3 with value: 0.776875.
# [I 2024-01-30 14:49:02,435] Trial 8 finished with value: 0.666875 and parameters: {'depth': 7, 'learning_rate': 0.038751226911282764, 'random_strength': 11, 'bagging_temperature': 0.4653996493040037, 'l2_leaf_reg': 61.52196968988217, 'scale_pos_weight': 9.112185915030048}. Best is trial 3 with value: 0.776875.
# [I 2024-01-30 14:49:03,002] Trial 9 finished with value: 0.68875 and parameters: {'depth': 7, 'learning_rate': 0.21940096173229753, 'random_strength': 19, 'bagging_temperature': 0.4689986082887315, 'l2_leaf_reg': 15.224837321138413, 'scale_pos_weight': 0.15806657149866002}. Best is trial 3 with value: 0.776875.
# [I 2024-01-30 14:49:03,907] Trial 10 finished with value: 0.700625 and parameters: {'depth': 6, 'learning_rate': 0.12232777075833592, 'random_strength': 7, 'bagging_temperature': 0.9346607858369291, 'l2_leaf_reg': 29.645618109381587, 'scale_pos_weight': 6.05744259260275}. Best is trial 3 with value: 0.776875.
# [I 2024-01-30 14:49:04,955] Trial 11 finished with value: 0.72625 and parameters: {'depth': 5, 'learning_rate': 0.18367700455642383, 'random_strength': 1, 'bagging_temperature': 0.25357065335311035, 'l2_leaf_reg': 96.6533937517352, 'scale_pos_weight': 0.20841286104875245}. Best is trial 3 with value: 0.776875.
# [I 2024-01-30 14:49:05,812] Trial 12 finished with value: 0.768125 and parameters: {'depth': 4, 'learning_rate': 0.2240985389665319, 'random_strength': 5, 'bagging_temperature': 0.2592798569133642, 'l2_leaf_reg': 30.907470125228286, 'scale_pos_weight': 1.2618460362178068}. Best is trial 3 with value: 0.776875.
# [I 2024-01-30 14:49:06,511] Trial 13 finished with value: 0.72 and parameters: {'depth': 4, 'learning_rate': 0.2374260238891609, 'random_strength': 14, 'bagging_temperature': 0.25591803565711063, 'l2_leaf_reg': 27.480738393284494, 'scale_pos_weight': 4.154868220058183}. Best is trial 3 with value: 0.776875.
# [I 2024-01-30 14:49:07,261] Trial 14 finished with value: 0.78125 and parameters: {'depth': 6, 'learning_rate': 0.14969403495947722, 'random_strength': 6, 'bagging_temperature': 0.3114868868537152, 'l2_leaf_reg': 0.6075036279307104, 'scale_pos_weight': 1.1326888661394134}. Best is trial 14 with value: 0.78125.
# [I 2024-01-30 14:49:07,971] Trial 15 finished with value: 0.72 and parameters: {'depth': 6, 'learning_rate': 0.14082520689470343, 'random_strength': 13, 'bagging_temperature': 0.6518810315347632, 'l2_leaf_reg': 0.4836137821752676, 'scale_pos_weight': 3.6557869403512737}. Best is trial 14 with value: 0.78125.
# [I 2024-01-30 14:49:09,177] Trial 16 finished with value: 0.70625 and parameters: {'depth': 6, 'learning_rate': 0.0643760291224992, 'random_strength': 7, 'bagging_temperature': 0.37880332520257265, 'l2_leaf_reg': 17.037729574177543, 'scale_pos_weight': 5.8814652839437604}. Best is trial 14 with value: 0.78125.
# [I 2024-01-30 14:49:10,107] Trial 17 finished with value: 0.774375 and parameters: {'depth': 8, 'learning_rate': 0.09077059090649987, 'random_strength': 7, 'bagging_temperature': 0.9976972428989437, 'l2_leaf_reg': 0.8679803286261727, 'scale_pos_weight': 1.3405503773977265}. Best is trial 14 with value: 0.78125.
# [I 2024-01-30 14:49:13,565] Trial 18 finished with value: 0.7075 and parameters: {'depth': 7, 'learning_rate': 0.019402032740845843, 'random_strength': 17, 'bagging_temperature': 0.6171308236487938, 'l2_leaf_reg': 40.13787461045736, 'scale_pos_weight': 5.505287779959494}. Best is trial 14 with value: 0.78125.
# [I 2024-01-30 14:49:14,199] Trial 19 finished with value: 0.660625 and parameters: {'depth': 6, 'learning_rate': 0.15149578929827404, 'random_strength': 12, 'bagging_temperature': 0.34278024015709935, 'l2_leaf_reg': 19.37296962060372, 'scale_pos_weight': 9.558363367742546}. Best is trial 14 with value: 0.78125.
# [I 2024-01-30 14:49:14,962] Trial 20 finished with value: 0.683125 and parameters: {'depth': 8, 'learning_rate': 0.11838079185493794, 'random_strength': 16, 'bagging_temperature': 0.7807251939363644, 'l2_leaf_reg': 8.953873536587164, 'scale_pos_weight': 7.8493118446900585}. Best is trial 14 with value: 0.78125.
# [I 2024-01-30 14:49:15,873] Trial 21 finished with value: 0.770625 and parameters: {'depth': 8, 'learning_rate': 0.08959173020369093, 'random_strength': 8, 'bagging_temperature': 0.9982418281720047, 'l2_leaf_reg': 2.3251407811864766, 'scale_pos_weight': 1.0721139103181492}. Best is trial 14 with value: 0.78125.
# [I 2024-01-30 14:49:17,194] Trial 22 finished with value: 0.76375 and parameters: {'depth': 7, 'learning_rate': 0.058090138408044945, 'random_strength': 6, 'bagging_temperature': 0.869080727460248, 'l2_leaf_reg': 1.0093400764902105, 'scale_pos_weight': 1.7756481205099366}. Best is trial 14 with value: 0.78125.
# [I 2024-01-30 14:49:18,150] Trial 23 finished with value: 0.76375 and parameters: {'depth': 9, 'learning_rate': 0.09210293872316415, 'random_strength': 2, 'bagging_temperature': 0.5656791145775786, 'l2_leaf_reg': 13.144681488235669, 'scale_pos_weight': 0.5682820407354373}. Best is trial 14 with value: 0.78125.
# [I 2024-01-30 14:49:19,034] Trial 24 finished with value: 0.75875 and parameters: {'depth': 9, 'learning_rate': 0.14343259546948448, 'random_strength': 9, 'bagging_temperature': 0.723257185236273, 'l2_leaf_reg': 21.047606204518708, 'scale_pos_weight': 1.9799393253593318}. Best is trial 14 with value: 0.78125.
# [I 2024-01-30 14:49:19,802] Trial 25 finished with value: 0.73375 and parameters: {'depth': 5, 'learning_rate': 0.16091799511299967, 'random_strength': 5, 'bagging_temperature': 0.38236501032145503, 'l2_leaf_reg': 6.77456795913762, 'scale_pos_weight': 3.2836683796067754}. Best is trial 14 with value: 0.78125.
# [I 2024-01-30 14:49:20,658] Trial 26 finished with value: 0.774375 and parameters: {'depth': 8, 'learning_rate': 0.10865045634705497, 'random_strength': 7, 'bagging_temperature': 0.17825324628549802, 'l2_leaf_reg': 24.579465810572, 'scale_pos_weight': 0.8757583885525526}. Best is trial 14 with value: 0.78125.
# [I 2024-01-30 14:49:22,104] Trial 27 finished with value: 0.749375 and parameters: {'depth': 6, 'learning_rate': 0.06360333922517152, 'random_strength': 10, 'bagging_temperature': 0.98099782542695, 'l2_leaf_reg': 38.39085593199715, 'scale_pos_weight': 2.4717154161959507}. Best is trial 14 with value: 0.78125.
# [I 2024-01-30 14:49:25,111] Trial 28 finished with value: 0.75875 and parameters: {'depth': 7, 'learning_rate': 0.011368025448637048, 'random_strength': 4, 'bagging_temperature': 0.8906257427229447, 'l2_leaf_reg': 9.525280067141466, 'scale_pos_weight': 1.659193533864133}. Best is trial 14 with value: 0.78125.
# [I 2024-01-30 14:49:26,024] Trial 29 finished with value: 0.72 and parameters: {'depth': 10, 'learning_rate': 0.12918387960106453, 'random_strength': 9, 'bagging_temperature': 0.7989297687530456, 'l2_leaf_reg': 4.713096041885748, 'scale_pos_weight': 4.653245775449832}. Best is trial 14 with value: 0.78125.
# [I 2024-01-30 14:49:26,808] Trial 30 finished with value: 0.7175 and parameters: {'depth': 6, 'learning_rate': 0.09754901878754615, 'random_strength': 11, 'bagging_temperature': 0.3260720526197491, 'l2_leaf_reg': 37.09990232923015, 'scale_pos_weight': 3.9469805663460393}. Best is trial 14 with value: 0.78125.
# [I 2024-01-30 14:49:27,573] Trial 31 finished with value: 0.766875 and parameters: {'depth': 8, 'learning_rate': 0.10600612593642432, 'random_strength': 7, 'bagging_temperature': 0.17863396616371174, 'l2_leaf_reg': 25.67568274270257, 'scale_pos_weight': 0.9184275935304383}. Best is trial 14 with value: 0.78125.
# [I 2024-01-30 14:49:28,204] Trial 32 finished with value: 0.776875 and parameters: {'depth': 8, 'learning_rate': 0.1663925257658384, 'random_strength': 8, 'bagging_temperature': 0.13077361784886157, 'l2_leaf_reg': 13.228643328648719, 'scale_pos_weight': 0.7475019677676313}. Best is trial 14 with value: 0.78125.
# [I 2024-01-30 14:49:28,865] Trial 33 finished with value: 0.754375 and parameters: {'depth': 9, 'learning_rate': 0.17015822682040183, 'random_strength': 5, 'bagging_temperature': 0.1467956555591178, 'l2_leaf_reg': 12.650353688804998, 'scale_pos_weight': 2.094858930723665}. Best is trial 14 with value: 0.78125.
# [I 2024-01-30 14:49:29,347] Trial 34 finished with value: 0.646875 and parameters: {'depth': 8, 'learning_rate': 0.19049535628682346, 'random_strength': 9, 'bagging_temperature': 0.0450317593406538, 'l2_leaf_reg': 1.2690892834812044, 'scale_pos_weight': 0.126379283674794}. Best is trial 14 with value: 0.78125.
# [I 2024-01-30 14:49:30,316] Trial 35 finished with value: 0.769375 and parameters: {'depth': 7, 'learning_rate': 0.13080980205499845, 'random_strength': 3, 'bagging_temperature': 0.01836106457186272, 'l2_leaf_reg': 50.17746755893272, 'scale_pos_weight': 1.458177310957179}. Best is trial 14 with value: 0.78125.
# [I 2024-01-30 14:49:30,897] Trial 36 finished with value: 0.74125 and parameters: {'depth': 8, 'learning_rate': 0.20324677449125528, 'random_strength': 8, 'bagging_temperature': 0.08841897772918597, 'l2_leaf_reg': 21.00871779186893, 'scale_pos_weight': 2.818982390533971}. Best is trial 14 with value: 0.78125.
# [I 2024-01-30 14:49:31,950] Trial 37 finished with value: 0.77375 and parameters: {'depth': 5, 'learning_rate': 0.16473079164950555, 'random_strength': 20, 'bagging_temperature': 0.6855471806132811, 'l2_leaf_reg': 88.55193763827086, 'scale_pos_weight': 0.8293988165533617}. Best is trial 14 with value: 0.78125.
# [I 2024-01-30 14:49:32,867] Trial 38 finished with value: 0.74875 and parameters: {'depth': 6, 'learning_rate': 0.07246641926596761, 'random_strength': 13, 'bagging_temperature': 0.5364593766600245, 'l2_leaf_reg': 12.218372948857251, 'scale_pos_weight': 2.1441161934968695}. Best is trial 14 with value: 0.78125.
# [I 2024-01-30 14:49:33,483] Trial 39 finished with value: 0.76875 and parameters: {'depth': 5, 'learning_rate': 0.14093671285047799, 'random_strength': 6, 'bagging_temperature': 0.433623150776797, 'l2_leaf_reg': 57.36283651432525, 'scale_pos_weight': 1.5146545802497648}. Best is trial 14 with value: 0.78125.
# [I 2024-01-30 14:49:34,995] Trial 40 finished with value: 0.765625 and parameters: {'depth': 7, 'learning_rate': 0.044287858314179515, 'random_strength': 17, 'bagging_temperature': 0.129167227012487, 'l2_leaf_reg': 6.325860511527594, 'scale_pos_weight': 0.4900417623372109}. Best is trial 14 with value: 0.78125.
# [I 2024-01-30 14:49:35,803] Trial 41 finished with value: 0.774375 and parameters: {'depth': 9, 'learning_rate': 0.11031740347546337, 'random_strength': 8, 'bagging_temperature': 0.19822053145202712, 'l2_leaf_reg': 17.63645639501638, 'scale_pos_weight': 0.8129335315558186}. Best is trial 14 with value: 0.78125.
# [I 2024-01-30 14:49:37,907] Trial 42 finished with value: 0.7675 and parameters: {'depth': 8, 'learning_rate': 0.08323278731230532, 'random_strength': 6, 'bagging_temperature': 0.21428666020233758, 'l2_leaf_reg': 24.07905242977467, 'scale_pos_weight': 1.1243682730750082}. Best is trial 14 with value: 0.78125.
# [I 2024-01-30 14:49:38,727] Trial 43 finished with value: 0.748125 and parameters: {'depth': 8, 'learning_rate': 0.17906948250555307, 'random_strength': 4, 'bagging_temperature': 0.3030174195328445, 'l2_leaf_reg': 34.35788692044892, 'scale_pos_weight': 2.7561931451686665}. Best is trial 14 with value: 0.78125.
# [I 2024-01-30 14:49:39,402] Trial 44 finished with value: 0.626875 and parameters: {'depth': 7, 'learning_rate': 0.10496064290684763, 'random_strength': 10, 'bagging_temperature': 0.13845591902089274, 'l2_leaf_reg': 7.142628097513651, 'scale_pos_weight': 0.10066129067739593}. Best is trial 14 with value: 0.78125.
# [I 2024-01-30 14:49:40,294] Trial 45 finished with value: 0.696875 and parameters: {'depth': 9, 'learning_rate': 0.12212619389092152, 'random_strength': 7, 'bagging_temperature': 0.058759373768028506, 'l2_leaf_reg': 13.980838649168348, 'scale_pos_weight': 6.930561352439182}. Best is trial 14 with value: 0.78125.
# [I 2024-01-30 14:49:41,028] Trial 46 finished with value: 0.765 and parameters: {'depth': 8, 'learning_rate': 0.29722650019321695, 'random_strength': 8, 'bagging_temperature': 0.27167024445382465, 'l2_leaf_reg': 45.384661497544265, 'scale_pos_weight': 0.6215121782656139}. Best is trial 14 with value: 0.78125.
# [I 2024-01-30 14:49:42,201] Trial 47 finished with value: 0.75375 and parameters: {'depth': 7, 'learning_rate': 0.14968329408896178, 'random_strength': 4, 'bagging_temperature': 0.5917502447021432, 'l2_leaf_reg': 69.01714548008967, 'scale_pos_weight': 2.4096054378368623}. Best is trial 14 with value: 0.78125.
# [I 2024-01-30 14:49:43,703] Trial 48 finished with value: 0.760625 and parameters: {'depth': 10, 'learning_rate': 0.07539509996773965, 'random_strength': 15, 'bagging_temperature': 0.4840522280253151, 'l2_leaf_reg': 4.3231368225799685, 'scale_pos_weight': 1.5005935639214734}. Best is trial 14 with value: 0.78125.
# [I 2024-01-30 14:49:44,350] Trial 49 finished with value: 0.730625 and parameters: {'depth': 6, 'learning_rate': 0.20113101525795757, 'random_strength': 12, 'bagging_temperature': 0.3917261924830924, 'l2_leaf_reg': 23.03215541632481, 'scale_pos_weight': 3.133681483275648}. Best is trial 14 with value: 0.78125.
# [I 2024-01-30 14:49:45,756] Trial 50 finished with value: 0.778125 and parameters: {'depth': 9, 'learning_rate': 0.04884703005665608, 'random_strength': 6, 'bagging_temperature': 0.09639248541019423, 'l2_leaf_reg': 10.1951965302488, 'scale_pos_weight': 1.1651978048588734}. Best is trial 14 with value: 0.78125.
# [I 2024-01-30 14:49:47,332] Trial 51 finished with value: 0.765625 and parameters: {'depth': 9, 'learning_rate': 0.047136216912399574, 'random_strength': 6, 'bagging_temperature': 0.09423847761575002, 'l2_leaf_reg': 9.479835447543277, 'scale_pos_weight': 1.2067681864828153}. Best is trial 14 with value: 0.78125.
# [I 2024-01-30 14:49:48,865] Trial 52 finished with value: 0.759375 and parameters: {'depth': 10, 'learning_rate': 0.031698164590688006, 'random_strength': 7, 'bagging_temperature': 0.2281225426821723, 'l2_leaf_reg': 0.1297450692108839, 'scale_pos_weight': 0.4548234155782404}. Best is trial 14 with value: 0.78125.
# [I 2024-01-30 14:49:49,503] Trial 53 finished with value: 0.756875 and parameters: {'depth': 9, 'learning_rate': 0.2519990334801809, 'random_strength': 5, 'bagging_temperature': 0.17451854714978005, 'l2_leaf_reg': 16.474149303932286, 'scale_pos_weight': 1.8859986094195658}. Best is trial 14 with value: 0.78125.
# [I 2024-01-30 14:49:50,322] Trial 54 finished with value: 0.77375 and parameters: {'depth': 8, 'learning_rate': 0.13020590526590828, 'random_strength': 9, 'bagging_temperature': 0.006745110804451865, 'l2_leaf_reg': 31.2305852114478, 'scale_pos_weight': 1.1209114467131331}. Best is trial 14 with value: 0.78125.
# [I 2024-01-30 14:49:51,406] Trial 55 finished with value: 0.766875 and parameters: {'depth': 8, 'learning_rate': 0.05500955519834933, 'random_strength': 3, 'bagging_temperature': 0.10597078994023282, 'l2_leaf_reg': 11.172848428556339, 'scale_pos_weight': 0.42445804762828815}. Best is trial 14 with value: 0.78125.
# [I 2024-01-30 14:49:52,168] Trial 56 finished with value: 0.776875 and parameters: {'depth': 9, 'learning_rate': 0.11429800375488017, 'random_strength': 6, 'bagging_temperature': 0.9290353765255319, 'l2_leaf_reg': 4.199195332758849, 'scale_pos_weight': 0.8836910717943693}. Best is trial 14 with value: 0.78125.
# [I 2024-01-30 14:49:52,806] Trial 57 finished with value: 0.68375 and parameters: {'depth': 9, 'learning_rate': 0.09535567594618555, 'random_strength': 2, 'bagging_temperature': 0.9272370501151292, 'l2_leaf_reg': 6.267022708284741, 'scale_pos_weight': 8.223043064878386}. Best is trial 14 with value: 0.78125.
# [I 2024-01-30 14:49:53,500] Trial 58 finished with value: 0.745625 and parameters: {'depth': 9, 'learning_rate': 0.15486607727553295, 'random_strength': 6, 'bagging_temperature': 0.9515727135061581, 'l2_leaf_reg': 3.741765330446185, 'scale_pos_weight': 2.339779054818152}. Best is trial 14 with value: 0.78125.
# [I 2024-01-30 14:49:55,770] Trial 59 finished with value: 0.76875 and parameters: {'depth': 10, 'learning_rate': 0.03469102780613206, 'random_strength': 11, 'bagging_temperature': 0.8433228472327936, 'l2_leaf_reg': 15.552814261152118, 'scale_pos_weight': 1.3905041214365117}. Best is trial 14 with value: 0.78125.
# [I 2024-01-30 14:49:56,554] Trial 60 finished with value: 0.75875 and parameters: {'depth': 4, 'learning_rate': 0.08037021466851352, 'random_strength': 5, 'bagging_temperature': 0.8257665341417774, 'l2_leaf_reg': 0.11380799278520048, 'scale_pos_weight': 1.7466359344155107}. Best is trial 14 with value: 0.78125.
# [I 2024-01-30 14:49:57,292] Trial 61 finished with value: 0.778125 and parameters: {'depth': 8, 'learning_rate': 0.1101453194685236, 'random_strength': 7, 'bagging_temperature': 0.9125554728488695, 'l2_leaf_reg': 10.766263191358433, 'scale_pos_weight': 0.7701537650501674}. Best is trial 14 with value: 0.78125.
# [I 2024-01-30 14:49:58,023] Trial 62 finished with value: 0.783125 and parameters: {'depth': 7, 'learning_rate': 0.11427743882698332, 'random_strength': 8, 'bagging_temperature': 0.8917745903744263, 'l2_leaf_reg': 9.318329820967326, 'scale_pos_weight': 0.7070285272490877}. Best is trial 62 with value: 0.783125.
# [I 2024-01-30 14:49:58,806] Trial 63 finished with value: 0.780625 and parameters: {'depth': 6, 'learning_rate': 0.11427217097926351, 'random_strength': 8, 'bagging_temperature': 0.891334510724948, 'l2_leaf_reg': 9.66376957416781, 'scale_pos_weight': 0.63914787222206}. Best is trial 62 with value: 0.783125.
# [I 2024-01-30 14:49:59,469] Trial 64 finished with value: 0.76375 and parameters: {'depth': 6, 'learning_rate': 0.13939564523560785, 'random_strength': 8, 'bagging_temperature': 0.8906666512890253, 'l2_leaf_reg': 18.728465828609266, 'scale_pos_weight': 0.4582332979166104}. Best is trial 62 with value: 0.783125.
# [I 2024-01-30 14:50:00,059] Trial 65 finished with value: 0.775 and parameters: {'depth': 5, 'learning_rate': 0.17345692908720822, 'random_strength': 10, 'bagging_temperature': 0.7156292523853887, 'l2_leaf_reg': 9.715162894089621, 'scale_pos_weight': 0.5879107848376546}. Best is trial 62 with value: 0.783125.
# [I 2024-01-30 14:50:00,666] Trial 66 finished with value: 0.64125 and parameters: {'depth': 6, 'learning_rate': 0.1271862926506591, 'random_strength': 9, 'bagging_temperature': 0.8089620358825143, 'l2_leaf_reg': 13.745039703332786, 'scale_pos_weight': 0.1039796461221878}. Best is trial 62 with value: 0.783125.
# [I 2024-01-30 14:50:01,255] Trial 67 finished with value: 0.7725 and parameters: {'depth': 7, 'learning_rate': 0.2155210589468857, 'random_strength': 8, 'bagging_temperature': 0.76509673343521, 'l2_leaf_reg': 27.739471606688845, 'scale_pos_weight': 1.1605959823248613}. Best is trial 62 with value: 0.783125.
# [I 2024-01-30 14:50:01,931] Trial 68 finished with value: 0.760625 and parameters: {'depth': 6, 'learning_rate': 0.13726569094758156, 'random_strength': 7, 'bagging_temperature': 0.8979342071082378, 'l2_leaf_reg': 20.022114462065616, 'scale_pos_weight': 1.836430651310717}. Best is trial 62 with value: 0.783125.
# [I 2024-01-30 14:50:02,499] Trial 69 finished with value: 0.775625 and parameters: {'depth': 7, 'learning_rate': 0.18781678852239914, 'random_strength': 9, 'bagging_temperature': 0.9696860079822873, 'l2_leaf_reg': 9.119133104838095, 'scale_pos_weight': 0.6540421229510625}. Best is trial 62 with value: 0.783125.
# [I 2024-01-30 14:50:03,106] Trial 70 finished with value: 0.755 and parameters: {'depth': 6, 'learning_rate': 0.1651278816589496, 'random_strength': 18, 'bagging_temperature': 0.7399263263241171, 'l2_leaf_reg': 15.998169646420159, 'scale_pos_weight': 0.3526761524575266}. Best is trial 62 with value: 0.783125.
# [I 2024-01-30 14:50:03,805] Trial 71 finished with value: 0.7725 and parameters: {'depth': 5, 'learning_rate': 0.11583663425559712, 'random_strength': 6, 'bagging_temperature': 0.9309978944222661, 'l2_leaf_reg': 4.737049684844624, 'scale_pos_weight': 0.9027500802726545}. Best is trial 62 with value: 0.783125.
# [I 2024-01-30 14:50:04,519] Trial 72 finished with value: 0.775625 and parameters: {'depth': 6, 'learning_rate': 0.11527520429752179, 'random_strength': 5, 'bagging_temperature': 0.8635202433892859, 'l2_leaf_reg': 2.8953324072351982, 'scale_pos_weight': 0.8910184170370308}. Best is trial 62 with value: 0.783125.
# [I 2024-01-30 14:50:05,475] Trial 73 finished with value: 0.765 and parameters: {'depth': 7, 'learning_rate': 0.10035742577246416, 'random_strength': 6, 'bagging_temperature': 0.9217133023660247, 'l2_leaf_reg': 11.793581892919814, 'scale_pos_weight': 1.3554444903610234}. Best is trial 62 with value: 0.783125.
# [I 2024-01-30 14:50:06,448] Trial 74 finished with value: 0.766875 and parameters: {'depth': 9, 'learning_rate': 0.08725927597786834, 'random_strength': 4, 'bagging_temperature': 0.6508296442196435, 'l2_leaf_reg': 8.543352343928328, 'scale_pos_weight': 1.556554819951712}. Best is trial 62 with value: 0.783125.
# [I 2024-01-30 14:50:07,176] Trial 75 finished with value: 0.78125 and parameters: {'depth': 5, 'learning_rate': 0.14713389631600737, 'random_strength': 8, 'bagging_temperature': 0.8529664375579878, 'l2_leaf_reg': 6.777131335594248, 'scale_pos_weight': 0.7726086650638258}. Best is trial 62 with value: 0.783125.
# [I 2024-01-30 14:50:07,738] Trial 76 finished with value: 0.745625 and parameters: {'depth': 5, 'learning_rate': 0.15509874947718266, 'random_strength': 8, 'bagging_temperature': 0.7919147128489511, 'l2_leaf_reg': 7.464838146531684, 'scale_pos_weight': 2.1464721874201467}. Best is trial 62 with value: 0.783125.
# [I 2024-01-30 14:50:08,514] Trial 77 finished with value: 0.775 and parameters: {'depth': 4, 'learning_rate': 0.14608356867444897, 'random_strength': 7, 'bagging_temperature': 0.8424623059194947, 'l2_leaf_reg': 11.77758651617265, 'scale_pos_weight': 0.7120518007533624}. Best is trial 62 with value: 0.783125.
# [I 2024-01-30 14:50:09,322] Trial 78 finished with value: 0.768125 and parameters: {'depth': 6, 'learning_rate': 0.13382004876733133, 'random_strength': 10, 'bagging_temperature': 0.8741827031177754, 'l2_leaf_reg': 14.729678337498335, 'scale_pos_weight': 1.1088216409545846}. Best is trial 62 with value: 0.783125.
# [I 2024-01-30 14:50:10,037] Trial 79 finished with value: 0.714375 and parameters: {'depth': 5, 'learning_rate': 0.12276048505910375, 'random_strength': 8, 'bagging_temperature': 0.4416500000265322, 'l2_leaf_reg': 21.364513865270958, 'scale_pos_weight': 4.859143871233122}. Best is trial 62 with value: 0.783125.
# [I 2024-01-30 14:50:10,735] Trial 80 finished with value: 0.7 and parameters: {'depth': 7, 'learning_rate': 0.15693821164956853, 'random_strength': 7, 'bagging_temperature': 0.5414691084377022, 'l2_leaf_reg': 73.04018272274163, 'scale_pos_weight': 6.405774492567273}. Best is trial 62 with value: 0.783125.
# [I 2024-01-30 14:50:11,515] Trial 81 finished with value: 0.776875 and parameters: {'depth': 9, 'learning_rate': 0.10434605388730897, 'random_strength': 6, 'bagging_temperature': 0.9630212350974383, 'l2_leaf_reg': 5.154409197412868, 'scale_pos_weight': 0.9216020107872186}. Best is trial 62 with value: 0.783125.
# [I 2024-01-30 14:50:12,462] Trial 82 finished with value: 0.740625 and parameters: {'depth': 6, 'learning_rate': 0.07242361441146813, 'random_strength': 9, 'bagging_temperature': 0.9060967072862072, 'l2_leaf_reg': 2.767521889064681, 'scale_pos_weight': 0.3239843859559694}. Best is trial 62 with value: 0.783125.
# [I 2024-01-30 14:50:13,156] Trial 83 finished with value: 0.76125 and parameters: {'depth': 8, 'learning_rate': 0.11161889093294336, 'random_strength': 8, 'bagging_temperature': 0.9984015193521341, 'l2_leaf_reg': 7.228240527248419, 'scale_pos_weight': 1.5993578375541482}. Best is trial 62 with value: 0.783125.
# [I 2024-01-30 14:50:13,860] Trial 84 finished with value: 0.7125 and parameters: {'depth': 7, 'learning_rate': 0.1228620987469722, 'random_strength': 5, 'bagging_temperature': 0.8597253267394275, 'l2_leaf_reg': 10.73934970298096, 'scale_pos_weight': 5.273001551491539}. Best is trial 62 with value: 0.783125.
# [I 2024-01-30 14:50:14,483] Trial 85 finished with value: 0.774375 and parameters: {'depth': 5, 'learning_rate': 0.14614290338432276, 'random_strength': 7, 'bagging_temperature': 0.687705067896198, 'l2_leaf_reg': 2.702692514080203, 'scale_pos_weight': 0.747275272361906}. Best is trial 62 with value: 0.783125.
# [I 2024-01-30 14:50:15,346] Trial 86 finished with value: 0.771875 and parameters: {'depth': 10, 'learning_rate': 0.1777316528365721, 'random_strength': 14, 'bagging_temperature': 0.05368482979067865, 'l2_leaf_reg': 5.389521360377741, 'scale_pos_weight': 1.2769971781480525}. Best is trial 62 with value: 0.783125.
# [I 2024-01-30 14:50:16,322] Trial 87 finished with value: 0.735 and parameters: {'depth': 7, 'learning_rate': 0.10027501216289908, 'random_strength': 15, 'bagging_temperature': 0.6152026806068964, 'l2_leaf_reg': 91.49629513715817, 'scale_pos_weight': 0.2844978815433742}. Best is trial 62 with value: 0.783125.
# [I 2024-01-30 14:50:16,983] Trial 88 finished with value: 0.771875 and parameters: {'depth': 6, 'learning_rate': 0.1638844510337369, 'random_strength': 7, 'bagging_temperature': 0.8308806290476042, 'l2_leaf_reg': 17.777192290423848, 'scale_pos_weight': 1.032121840272482}. Best is trial 62 with value: 0.783125.
# [I 2024-01-30 14:50:20,231] Trial 89 finished with value: 0.771875 and parameters: {'depth': 8, 'learning_rate': 0.023759572401139756, 'random_strength': 11, 'bagging_temperature': 0.9453830718665697, 'l2_leaf_reg': 60.45382248865435, 'scale_pos_weight': 0.6054036727126589}. Best is trial 62 with value: 0.783125.
# [I 2024-01-30 14:50:21,862] Trial 90 finished with value: 0.768125 and parameters: {'depth': 9, 'learning_rate': 0.06494127363730717, 'random_strength': 12, 'bagging_temperature': 0.7717571908875231, 'l2_leaf_reg': 13.45115243531491, 'scale_pos_weight': 1.6832447823258476}. Best is trial 62 with value: 0.783125.
# [I 2024-01-30 14:50:22,772] Trial 91 finished with value: 0.77 and parameters: {'depth': 9, 'learning_rate': 0.09268995398071395, 'random_strength': 6, 'bagging_temperature': 0.9691779783915393, 'l2_leaf_reg': 5.240636254224246, 'scale_pos_weight': 0.9499160475902784}. Best is trial 62 with value: 0.783125.
# [I 2024-01-30 14:50:23,597] Trial 92 finished with value: 0.76875 and parameters: {'depth': 9, 'learning_rate': 0.11056798128540525, 'random_strength': 6, 'bagging_temperature': 0.9064894411716747, 'l2_leaf_reg': 7.406120095289787, 'scale_pos_weight': 1.354431878441631}. Best is trial 62 with value: 0.783125.
# [I 2024-01-30 14:50:24,365] Trial 93 finished with value: 0.775 and parameters: {'depth': 9, 'learning_rate': 0.10380648815329693, 'random_strength': 6, 'bagging_temperature': 0.9540489714547105, 'l2_leaf_reg': 2.073193420515502, 'scale_pos_weight': 0.8719345663911916}. Best is trial 62 with value: 0.783125.
# [I 2024-01-30 14:50:25,211] Trial 94 finished with value: 0.775 and parameters: {'depth': 9, 'learning_rate': 0.11817940411641847, 'random_strength': 5, 'bagging_temperature': 0.9694091581264619, 'l2_leaf_reg': 11.022464275491906, 'scale_pos_weight': 0.6826239148317919}. Best is trial 62 with value: 0.783125.
# [I 2024-01-30 14:50:25,858] Trial 95 finished with value: 0.73625 and parameters: {'depth': 8, 'learning_rate': 0.13410869699596475, 'random_strength': 7, 'bagging_temperature': 0.8129263174959276, 'l2_leaf_reg': 4.411047187900326, 'scale_pos_weight': 0.2847745908644479}. Best is trial 62 with value: 0.783125.
# [I 2024-01-30 14:50:26,445] Trial 96 finished with value: 0.759375 and parameters: {'depth': 4, 'learning_rate': 0.12594146349297447, 'random_strength': 4, 'bagging_temperature': 0.11956779831236752, 'l2_leaf_reg': 0.033464487845755286, 'scale_pos_weight': 1.953580331650498}. Best is trial 62 with value: 0.783125.
# [I 2024-01-30 14:50:27,235] Trial 97 finished with value: 0.659375 and parameters: {'depth': 6, 'learning_rate': 0.08106819263340301, 'random_strength': 8, 'bagging_temperature': 0.8846013274179062, 'l2_leaf_reg': 9.039056296900316, 'scale_pos_weight': 9.903845983525734}. Best is trial 62 with value: 0.783125.
# [I 2024-01-30 14:50:28,466] Trial 98 finished with value: 0.72 and parameters: {'depth': 10, 'learning_rate': 0.08775447286767991, 'random_strength': 9, 'bagging_temperature': 0.1582501583871916, 'l2_leaf_reg': 14.464162526382818, 'scale_pos_weight': 4.38393459719444}. Best is trial 62 with value: 0.783125.
# [I 2024-01-30 14:50:29,398] Trial 99 finished with value: 0.77375 and parameters: {'depth': 9, 'learning_rate': 0.1506786397480422, 'random_strength': 10, 'bagging_temperature': 0.9166331399816157, 'l2_leaf_reg': 44.12864554161424, 'scale_pos_weight': 1.0467680846918814}. Best is trial 62 with value: 0.783125.
# [I 2024-01-30 14:50:32,055] A new study created in memory with name: no-name-d46f90bf-a454-4f05-9e43-2dad6127939e
# [I 2024-01-30 14:50:32,688] Trial 0 finished with value: 0.784375 and parameters: {'depth': 9, 'learning_rate': 0.20732693227777543, 'random_strength': 11, 'bagging_temperature': 0.8682511342735246, 'l2_leaf_reg': 15.68231135285867, 'scale_pos_weight': 1.6191122264604458}. Best is trial 0 with value: 0.784375.
# [I 2024-01-30 14:50:35,151] Trial 1 finished with value: 0.780625 and parameters: {'depth': 5, 'learning_rate': 0.02307790050019691, 'random_strength': 9, 'bagging_temperature': 0.8426821580843625, 'l2_leaf_reg': 5.355863400543221, 'scale_pos_weight': 1.5432427467580978}. Best is trial 0 with value: 0.784375.
# [I 2024-01-30 14:50:36,082] Trial 2 finished with value: 0.755 and parameters: {'depth': 8, 'learning_rate': 0.0755507560472638, 'random_strength': 3, 'bagging_temperature': 0.6624850329325701, 'l2_leaf_reg': 43.74089059437801, 'scale_pos_weight': 0.4341316518411724}. Best is trial 0 with value: 0.784375.
# [I 2024-01-30 14:50:36,749] Trial 3 finished with value: 0.704375 and parameters: {'depth': 4, 'learning_rate': 0.26494091043610485, 'random_strength': 4, 'bagging_temperature': 0.437881827995377, 'l2_leaf_reg': 35.72690795114483, 'scale_pos_weight': 6.849878356410969}. Best is trial 0 with value: 0.784375.
# [I 2024-01-30 14:50:37,351] Trial 4 finished with value: 0.72625 and parameters: {'depth': 10, 'learning_rate': 0.24467367904350631, 'random_strength': 2, 'bagging_temperature': 0.5806819394043609, 'l2_leaf_reg': 9.310002833146772, 'scale_pos_weight': 4.297065208374723}. Best is trial 0 with value: 0.784375.
# [I 2024-01-30 14:50:38,280] Trial 5 finished with value: 0.669375 and parameters: {'depth': 10, 'learning_rate': 0.15943659506378194, 'random_strength': 11, 'bagging_temperature': 0.4685936386410898, 'l2_leaf_reg': 57.8302567106916, 'scale_pos_weight': 9.754028328316387}. Best is trial 0 with value: 0.784375.
# [I 2024-01-30 14:50:38,857] Trial 6 finished with value: 0.765 and parameters: {'depth': 8, 'learning_rate': 0.20751058202238035, 'random_strength': 14, 'bagging_temperature': 0.18596108907286857, 'l2_leaf_reg': 48.575515553678414, 'scale_pos_weight': 2.364061627020519}. Best is trial 0 with value: 0.784375.
# [I 2024-01-30 14:50:39,996] Trial 7 finished with value: 0.69625 and parameters: {'depth': 8, 'learning_rate': 0.08000669225692521, 'random_strength': 12, 'bagging_temperature': 0.75511591450323, 'l2_leaf_reg': 9.42178779534127, 'scale_pos_weight': 8.448819489799616}. Best is trial 0 with value: 0.784375.
# [I 2024-01-30 14:50:40,864] Trial 8 finished with value: 0.745625 and parameters: {'depth': 5, 'learning_rate': 0.14131656792554106, 'random_strength': 11, 'bagging_temperature': 0.4307726095876312, 'l2_leaf_reg': 73.61014827675137, 'scale_pos_weight': 3.4605455015349404}. Best is trial 0 with value: 0.784375.
# [I 2024-01-30 14:50:41,638] Trial 9 finished with value: 0.76625 and parameters: {'depth': 4, 'learning_rate': 0.22731825227597824, 'random_strength': 11, 'bagging_temperature': 0.4665708947498697, 'l2_leaf_reg': 11.06597886082179, 'scale_pos_weight': 0.543461695668922}. Best is trial 0 with value: 0.784375.
# [I 2024-01-30 14:50:42,347] Trial 10 finished with value: 0.705 and parameters: {'depth': 7, 'learning_rate': 0.29215648981071385, 'random_strength': 20, 'bagging_temperature': 0.9840096047600336, 'l2_leaf_reg': 96.9410633033727, 'scale_pos_weight': 5.908682193038139}. Best is trial 0 with value: 0.784375.
# [I 2024-01-30 14:50:45,353] Trial 11 finished with value: 0.764375 and parameters: {'depth': 6, 'learning_rate': 0.016314354048808405, 'random_strength': 7, 'bagging_temperature': 0.915185480723377, 'l2_leaf_reg': 26.10897045357214, 'scale_pos_weight': 2.122238393114205}. Best is trial 0 with value: 0.784375.
# [I 2024-01-30 14:50:45,885] Trial 12 finished with value: 0.771875 and parameters: {'depth': 6, 'learning_rate': 0.16493649908697589, 'random_strength': 7, 'bagging_temperature': 0.7959825667347296, 'l2_leaf_reg': 1.5132091631250035, 'scale_pos_weight': 1.9257594615948272}. Best is trial 0 with value: 0.784375.
# [I 2024-01-30 14:50:49,549] Trial 13 finished with value: 0.739375 and parameters: {'depth': 9, 'learning_rate': 0.013045978111850681, 'random_strength': 18, 'bagging_temperature': 0.8370983367379874, 'l2_leaf_reg': 25.095509376985067, 'scale_pos_weight': 3.3937444347443586}. Best is trial 0 with value: 0.784375.
# [I 2024-01-30 14:50:50,514] Trial 14 finished with value: 0.77875 and parameters: {'depth': 6, 'learning_rate': 0.10031196837446768, 'random_strength': 15, 'bagging_temperature': 0.017952665191389827, 'l2_leaf_reg': 22.234830611376672, 'scale_pos_weight': 1.190496537265846}. Best is trial 0 with value: 0.784375.
# [I 2024-01-30 14:50:51,098] Trial 15 finished with value: 0.724375 and parameters: {'depth': 9, 'learning_rate': 0.19489708991079766, 'random_strength': 7, 'bagging_temperature': 0.6796039469756066, 'l2_leaf_reg': 0.8140932813082502, 'scale_pos_weight': 5.0371351123059664}. Best is trial 0 with value: 0.784375.
# [I 2024-01-30 14:50:51,924] Trial 16 finished with value: 0.751875 and parameters: {'depth': 5, 'learning_rate': 0.12245930972959373, 'random_strength': 8, 'bagging_temperature': 0.9922000164304857, 'l2_leaf_reg': 65.43555439424792, 'scale_pos_weight': 2.9918229816918274}. Best is trial 0 with value: 0.784375.
# [I 2024-01-30 14:50:53,729] Trial 17 finished with value: 0.6925 and parameters: {'depth': 7, 'learning_rate': 0.041646469766712046, 'random_strength': 16, 'bagging_temperature': 0.26258618086331564, 'l2_leaf_reg': 34.119771267719145, 'scale_pos_weight': 0.1649143711050225}. Best is trial 0 with value: 0.784375.
# [I 2024-01-30 14:50:54,469] Trial 18 finished with value: 0.72875 and parameters: {'depth': 9, 'learning_rate': 0.1858338595073795, 'random_strength': 13, 'bagging_temperature': 0.8729327745993577, 'l2_leaf_reg': 15.746861094609587, 'scale_pos_weight': 4.432076827797239}. Best is trial 0 with value: 0.784375.
# [I 2024-01-30 14:50:56,278] Trial 19 finished with value: 0.778125 and parameters: {'depth': 5, 'learning_rate': 0.05932574880048144, 'random_strength': 9, 'bagging_temperature': 0.7189287834275994, 'l2_leaf_reg': 84.13185738572719, 'scale_pos_weight': 1.494506169425296}. Best is trial 0 with value: 0.784375.
# [I 2024-01-30 14:50:57,171] Trial 20 finished with value: 0.71 and parameters: {'depth': 7, 'learning_rate': 0.12209085598930762, 'random_strength': 5, 'bagging_temperature': 0.5923101317604016, 'l2_leaf_reg': 35.38596110483793, 'scale_pos_weight': 6.674978331159464}. Best is trial 0 with value: 0.784375.
# [I 2024-01-30 14:50:57,898] Trial 21 finished with value: 0.78125 and parameters: {'depth': 6, 'learning_rate': 0.09716156044260005, 'random_strength': 15, 'bagging_temperature': 0.0036198336354602706, 'l2_leaf_reg': 20.226007788178713, 'scale_pos_weight': 1.1436342826326182}. Best is trial 0 with value: 0.784375.
# [I 2024-01-30 14:50:59,716] Trial 22 finished with value: 0.778125 and parameters: {'depth': 5, 'learning_rate': 0.03893372224027514, 'random_strength': 17, 'bagging_temperature': 0.3062495525246209, 'l2_leaf_reg': 19.84401731252739, 'scale_pos_weight': 1.1927230710909718}. Best is trial 0 with value: 0.784375.
# [I 2024-01-30 14:51:00,444] Trial 23 finished with value: 0.75875 and parameters: {'depth': 6, 'learning_rate': 0.10272802116378767, 'random_strength': 13, 'bagging_temperature': 0.06599946230361203, 'l2_leaf_reg': 2.25132893129041, 'scale_pos_weight': 2.5714124281037405}. Best is trial 0 with value: 0.784375.
# [I 2024-01-30 14:51:01,013] Trial 24 finished with value: 0.738125 and parameters: {'depth': 4, 'learning_rate': 0.17230030237290522, 'random_strength': 10, 'bagging_temperature': 0.5887089360767763, 'l2_leaf_reg': 27.534063771613187, 'scale_pos_weight': 3.9181915615224883}. Best is trial 0 with value: 0.784375.
# [I 2024-01-30 14:51:01,609] Trial 25 finished with value: 0.780625 and parameters: {'depth': 6, 'learning_rate': 0.21703489013904295, 'random_strength': 9, 'bagging_temperature': 0.3497654627362999, 'l2_leaf_reg': 12.106262343980589, 'scale_pos_weight': 1.1109591475717888}. Best is trial 0 with value: 0.784375.
# [I 2024-01-30 14:51:02,354] Trial 26 finished with value: 0.75625 and parameters: {'depth': 5, 'learning_rate': 0.13077842420193198, 'random_strength': 15, 'bagging_temperature': 0.11920284225873612, 'l2_leaf_reg': 44.13130836186044, 'scale_pos_weight': 2.757158224492393}. Best is trial 0 with value: 0.784375.
# [I 2024-01-30 14:51:03,815] Trial 27 finished with value: 0.78 and parameters: {'depth': 7, 'learning_rate': 0.041140365440159546, 'random_strength': 18, 'bagging_temperature': 0.9053967202753102, 'l2_leaf_reg': 16.340542247505006, 'scale_pos_weight': 1.607624268335947}. Best is trial 0 with value: 0.784375.
# [I 2024-01-30 14:51:04,607] Trial 28 finished with value: 0.7775 and parameters: {'depth': 8, 'learning_rate': 0.10035160131918171, 'random_strength': 13, 'bagging_temperature': 0.8128018661390075, 'l2_leaf_reg': 30.674687664918164, 'scale_pos_weight': 1.0404633818182916}. Best is trial 0 with value: 0.784375.
# [I 2024-01-30 14:51:05,697] Trial 29 finished with value: 0.658125 and parameters: {'depth': 7, 'learning_rate': 0.07821933873269932, 'random_strength': 20, 'bagging_temperature': 0.6905643395013523, 'l2_leaf_reg': 55.853138119735284, 'scale_pos_weight': 0.13185199453454266}. Best is trial 0 with value: 0.784375.
# [I 2024-01-30 14:51:06,374] Trial 30 finished with value: 0.78 and parameters: {'depth': 8, 'learning_rate': 0.14576907568444797, 'random_strength': 5, 'bagging_temperature': 0.20798806269502057, 'l2_leaf_reg': 6.727609602801358, 'scale_pos_weight': 0.8429846837280488}. Best is trial 0 with value: 0.784375.
# [I 2024-01-30 14:51:06,907] Trial 31 finished with value: 0.773125 and parameters: {'depth': 6, 'learning_rate': 0.21914820989027703, 'random_strength': 9, 'bagging_temperature': 0.3664017632368103, 'l2_leaf_reg': 15.97059594154737, 'scale_pos_weight': 1.943493411187086}. Best is trial 0 with value: 0.784375.
# [I 2024-01-30 14:51:07,450] Trial 32 finished with value: 0.77375 and parameters: {'depth': 6, 'learning_rate': 0.2487967123311328, 'random_strength': 9, 'bagging_temperature': 0.3556756823957337, 'l2_leaf_reg': 39.352854752475054, 'scale_pos_weight': 0.9749157459553861}. Best is trial 0 with value: 0.784375.
# [I 2024-01-30 14:51:08,101] Trial 33 finished with value: 0.754375 and parameters: {'depth': 4, 'learning_rate': 0.2437406707082111, 'random_strength': 6, 'bagging_temperature': 0.5223571511379745, 'l2_leaf_reg': 13.020372587799955, 'scale_pos_weight': 3.126331811949781}. Best is trial 0 with value: 0.784375.
# [I 2024-01-30 14:51:08,951] Trial 34 finished with value: 0.76875 and parameters: {'depth': 10, 'learning_rate': 0.18326071520268628, 'random_strength': 10, 'bagging_temperature': 0.15896547462514898, 'l2_leaf_reg': 6.261212045052842, 'scale_pos_weight': 0.5693958431356836}. Best is trial 0 with value: 0.784375.
# [I 2024-01-30 14:51:09,455] Trial 35 finished with value: 0.774375 and parameters: {'depth': 5, 'learning_rate': 0.2685226293571274, 'random_strength': 12, 'bagging_temperature': 0.6169739508358086, 'l2_leaf_reg': 19.565599730283857, 'scale_pos_weight': 1.7082811741293549}. Best is trial 0 with value: 0.784375.
# [I 2024-01-30 14:51:09,898] Trial 36 finished with value: 0.76625 and parameters: {'depth': 6, 'learning_rate': 0.20621723695666075, 'random_strength': 2, 'bagging_temperature': 0.004674243534000411, 'l2_leaf_reg': 6.172474708802326, 'scale_pos_weight': 2.3561775509445093}. Best is trial 0 with value: 0.784375.
# [I 2024-01-30 14:51:11,059] Trial 37 finished with value: 0.74 and parameters: {'depth': 5, 'learning_rate': 0.062158628495029365, 'random_strength': 4, 'bagging_temperature': 0.7670840807181656, 'l2_leaf_reg': 40.80388322983616, 'scale_pos_weight': 3.9021815962463284}. Best is trial 0 with value: 0.784375.
# [I 2024-01-30 14:51:11,854] Trial 38 finished with value: 0.685 and parameters: {'depth': 10, 'learning_rate': 0.23008222829007002, 'random_strength': 12, 'bagging_temperature': 0.5253555566354007, 'l2_leaf_reg': 11.417465552852093, 'scale_pos_weight': 9.333102119201751}. Best is trial 0 with value: 0.784375.
# [I 2024-01-30 14:51:12,351] Trial 39 finished with value: 0.698125 and parameters: {'depth': 7, 'learning_rate': 0.27470328868336724, 'random_strength': 8, 'bagging_temperature': 0.41800667697207844, 'l2_leaf_reg': 20.642981571831445, 'scale_pos_weight': 7.5594782491541}. Best is trial 0 with value: 0.784375.
# [I 2024-01-30 14:51:12,873] Trial 40 finished with value: 0.719375 and parameters: {'depth': 4, 'learning_rate': 0.20680842391770915, 'random_strength': 14, 'bagging_temperature': 0.9292680652307362, 'l2_leaf_reg': 29.87976740096347, 'scale_pos_weight': 4.934635953920255}. Best is trial 0 with value: 0.784375.
# [I 2024-01-30 14:51:14,594] Trial 41 finished with value: 0.7825 and parameters: {'depth': 7, 'learning_rate': 0.03311625817798468, 'random_strength': 18, 'bagging_temperature': 0.9013057526905822, 'l2_leaf_reg': 15.835995678672433, 'scale_pos_weight': 1.5947631216968778}. Best is trial 0 with value: 0.784375.
# [I 2024-01-30 14:51:16,820] Trial 42 finished with value: 0.77125 and parameters: {'depth': 6, 'learning_rate': 0.030103648641088682, 'random_strength': 18, 'bagging_temperature': 0.9499285623843823, 'l2_leaf_reg': 9.555411924901449, 'scale_pos_weight': 0.5911897779086939}. Best is trial 0 with value: 0.784375.
# [I 2024-01-30 14:51:18,162] Trial 43 finished with value: 0.76875 and parameters: {'depth': 7, 'learning_rate': 0.05378539333697286, 'random_strength': 16, 'bagging_temperature': 0.8578919727062478, 'l2_leaf_reg': 14.302409065967895, 'scale_pos_weight': 2.3000544091909036}. Best is trial 0 with value: 0.784375.
# [I 2024-01-30 14:51:21,231] Trial 44 finished with value: 0.779375 and parameters: {'depth': 8, 'learning_rate': 0.01668689860117006, 'random_strength': 19, 'bagging_temperature': 0.7495159766663438, 'l2_leaf_reg': 24.64401995174903, 'scale_pos_weight': 1.4531562892219232}. Best is trial 0 with value: 0.784375.
# [I 2024-01-30 14:51:22,354] Trial 45 finished with value: 0.780625 and parameters: {'depth': 6, 'learning_rate': 0.07104018360538539, 'random_strength': 11, 'bagging_temperature': 0.6396847053242035, 'l2_leaf_reg': 3.762764578100113, 'scale_pos_weight': 1.9956059649845885}. Best is trial 0 with value: 0.784375.
# [I 2024-01-30 14:51:24,555] Trial 46 finished with value: 0.715 and parameters: {'depth': 7, 'learning_rate': 0.02531098279467339, 'random_strength': 8, 'bagging_temperature': 0.877838282182995, 'l2_leaf_reg': 9.398879568811614, 'scale_pos_weight': 5.8770489429979245}. Best is trial 0 with value: 0.784375.
# [I 2024-01-30 14:51:25,374] Trial 47 finished with value: 0.765 and parameters: {'depth': 8, 'learning_rate': 0.09396697170611563, 'random_strength': 15, 'bagging_temperature': 0.8105089396669654, 'l2_leaf_reg': 0.6311580762584175, 'scale_pos_weight': 0.6335360869041767}. Best is trial 0 with value: 0.784375.
# [I 2024-01-30 14:51:25,889] Trial 48 finished with value: 0.77875 and parameters: {'depth': 6, 'learning_rate': 0.2550362268980455, 'random_strength': 17, 'bagging_temperature': 0.9962758330681787, 'l2_leaf_reg': 18.59773576935858, 'scale_pos_weight': 1.3008838160600575}. Best is trial 0 with value: 0.784375.
# [I 2024-01-30 14:51:26,506] Trial 49 finished with value: 0.73875 and parameters: {'depth': 5, 'learning_rate': 0.1505241750292396, 'random_strength': 12, 'bagging_temperature': 0.9550833777157287, 'l2_leaf_reg': 52.582980320339736, 'scale_pos_weight': 3.530509002839335}. Best is trial 0 with value: 0.784375.
# [I 2024-01-30 14:51:27,072] Trial 50 finished with value: 0.755625 and parameters: {'depth': 9, 'learning_rate': 0.23329179120160362, 'random_strength': 10, 'bagging_temperature': 0.2694005602534605, 'l2_leaf_reg': 23.223328498751556, 'scale_pos_weight': 2.7451359798759705}. Best is trial 0 with value: 0.784375.
# [I 2024-01-30 14:51:27,965] Trial 51 finished with value: 0.77625 and parameters: {'depth': 6, 'learning_rate': 0.08755561300263015, 'random_strength': 11, 'bagging_temperature': 0.7735215801275567, 'l2_leaf_reg': 4.079473809796109, 'scale_pos_weight': 2.0274427767687317}. Best is trial 0 with value: 0.784375.
# [I 2024-01-30 14:51:28,874] Trial 52 finished with value: 0.775625 and parameters: {'depth': 6, 'learning_rate': 0.07222708852076767, 'random_strength': 11, 'bagging_temperature': 0.6297588736255457, 'l2_leaf_reg': 11.785822707087876, 'scale_pos_weight': 1.8354277600727866}. Best is trial 0 with value: 0.784375.
# ...
# [I 2024-01-30 14:56:22,653] Trial 49 finished with value: 0.765 and parameters: {'depth': 5, 'learning_rate': 0.20892352213856993, 'random_strength': 16, 'bagging_temperature': 0.09465457767109703, 'l2_leaf_reg': 94.06267708821943, 'scale_pos_weight': 2.143799635722772}. Best is trial 11 with value: 0.793125.
# [I 2024-01-30 14:56:23,197] Trial 50 finished with value: 0.78875 and parameters: {'depth': 6, 'learning_rate': 0.18584204343776764, 'random_strength': 17, 'bagging_temperature': 0.16070643063371023, 'l2_leaf_reg': 4.524377332410605, 'scale_pos_weight': 1.042725689715638}. Best is trial 11 with value: 0.793125.
# [I 2024-01-30 14:56:23,772] Trial 51 finished with value: 0.78625 and parameters: {'depth': 6, 'learning_rate': 0.13582550837546897, 'random_strength': 15, 'bagging_temperature': 0.05639066339923757, 'l2_leaf_reg': 5.2550569888367225, 'scale_pos_weight': 1.0371584083471415}. Best is trial 11 with value: 0.793125.
# [I 2024-01-30 14:56:24,298] Trial 52 finished with value: 0.785625 and parameters: {'depth': 6, 'learning_rate': 0.1883160707579489, 'random_strength': 17, 'bagging_temperature': 0.1573424499749838, 'l2_leaf_reg': 4.193653988001281, 'scale_pos_weight': 0.6077301778565004}. Best is trial 11 with value: 0.793125.
# [I 2024-01-30 14:56:24,917] Trial 53 finished with value: 0.776875 and parameters: {'depth': 5, 'learning_rate': 0.15712364218038508, 'random_strength': 13, 'bagging_temperature': 0.2100061613074177, 'l2_leaf_reg': 9.57968517481994, 'scale_pos_weight': 1.6487737122531045}. Best is trial 11 with value: 0.793125.
# [I 2024-01-30 14:56:25,464] Trial 54 finished with value: 0.78875 and parameters: {'depth': 5, 'learning_rate': 0.22239824547746895, 'random_strength': 19, 'bagging_temperature': 0.13422317268294207, 'l2_leaf_reg': 14.470683749438763, 'scale_pos_weight': 1.4432316591968188}. Best is trial 11 with value: 0.793125.
# [I 2024-01-30 14:56:25,989] Trial 55 finished with value: 0.773125 and parameters: {'depth': 6, 'learning_rate': 0.20872716201950267, 'random_strength': 20, 'bagging_temperature': 0.04495974437228827, 'l2_leaf_reg': 21.31400961109474, 'scale_pos_weight': 1.8525672489483038}. Best is trial 11 with value: 0.793125.
# [I 2024-01-30 14:56:26,656] Trial 56 finished with value: 0.79375 and parameters: {'depth': 4, 'learning_rate': 0.2226405473921324, 'random_strength': 18, 'bagging_temperature': 0.2956042210531641, 'l2_leaf_reg': 14.576280907404794, 'scale_pos_weight': 1.41104974520752}. Best is trial 56 with value: 0.79375.
# [I 2024-01-30 14:56:27,190] Trial 57 finished with value: 0.7875 and parameters: {'depth': 4, 'learning_rate': 0.21999932538992845, 'random_strength': 18, 'bagging_temperature': 0.1190227271150018, 'l2_leaf_reg': 15.33258798833742, 'scale_pos_weight': 1.4500204741479443}. Best is trial 56 with value: 0.79375.
# [I 2024-01-30 14:56:27,627] Trial 58 finished with value: 0.753125 and parameters: {'depth': 4, 'learning_rate': 0.2433000930974465, 'random_strength': 19, 'bagging_temperature': 0.0886459846707463, 'l2_leaf_reg': 23.82023075818766, 'scale_pos_weight': 2.4619124258710374}. Best is trial 56 with value: 0.79375.
# [I 2024-01-30 14:56:28,161] Trial 59 finished with value: 0.74625 and parameters: {'depth': 4, 'learning_rate': 0.22022019173915783, 'random_strength': 17, 'bagging_temperature': 0.29916019594751364, 'l2_leaf_reg': 34.31236573013247, 'scale_pos_weight': 2.993708967824708}. Best is trial 56 with value: 0.79375.
# [I 2024-01-30 14:56:28,649] Trial 60 finished with value: 0.7175 and parameters: {'depth': 5, 'learning_rate': 0.18806097790188903, 'random_strength': 19, 'bagging_temperature': 0.2404986486831308, 'l2_leaf_reg': 14.084979718942513, 'scale_pos_weight': 5.317107963775482}. Best is trial 56 with value: 0.79375.
# [I 2024-01-30 14:56:29,194] Trial 61 finished with value: 0.7925 and parameters: {'depth': 6, 'learning_rate': 0.19458914354170087, 'random_strength': 18, 'bagging_temperature': 0.34772276230864707, 'l2_leaf_reg': 9.921709275056509, 'scale_pos_weight': 1.1462985705080169}. Best is trial 56 with value: 0.79375.
# [I 2024-01-30 14:56:29,802] Trial 62 finished with value: 0.78625 and parameters: {'depth': 6, 'learning_rate': 0.19642261583163595, 'random_strength': 18, 'bagging_temperature': 0.4283635011693029, 'l2_leaf_reg': 10.555043847651747, 'scale_pos_weight': 1.156295476684561}. Best is trial 56 with value: 0.79375.
# [I 2024-01-30 14:56:30,283] Trial 63 finished with value: 0.759375 and parameters: {'depth': 6, 'learning_rate': 0.2293792380891559, 'random_strength': 16, 'bagging_temperature': 0.3629836424947184, 'l2_leaf_reg': 18.888801582937248, 'scale_pos_weight': 0.45065828827144183}. Best is trial 56 with value: 0.79375.
# [I 2024-01-30 14:56:30,919] Trial 64 finished with value: 0.7725 and parameters: {'depth': 7, 'learning_rate': 0.18429941767674857, 'random_strength': 18, 'bagging_temperature': 0.2830045537234206, 'l2_leaf_reg': 27.121190913399957, 'scale_pos_weight': 2.1363439339833774}. Best is trial 56 with value: 0.79375.
# [I 2024-01-30 14:56:31,411] Trial 65 finished with value: 0.6675 and parameters: {'depth': 6, 'learning_rate': 0.1999457042773235, 'random_strength': 15, 'bagging_temperature': 0.18691593905402237, 'l2_leaf_reg': 50.82000745425804, 'scale_pos_weight': 9.948361913760916}. Best is trial 56 with value: 0.79375.
# [I 2024-01-30 14:56:31,905] Trial 66 finished with value: 0.785625 and parameters: {'depth': 7, 'learning_rate': 0.2168497834886172, 'random_strength': 20, 'bagging_temperature': 0.46651944367203957, 'l2_leaf_reg': 2.996091614425052, 'scale_pos_weight': 1.460305039493718}. Best is trial 56 with value: 0.79375.
# [I 2024-01-30 14:56:32,452] Trial 67 finished with value: 0.798125 and parameters: {'depth': 5, 'learning_rate': 0.24464151015252755, 'random_strength': 16, 'bagging_temperature': 0.24226055064665894, 'l2_leaf_reg': 8.65702254717879, 'scale_pos_weight': 1.2499778904687175}. Best is trial 67 with value: 0.798125.
# [I 2024-01-30 14:56:32,958] Trial 68 finished with value: 0.785 and parameters: {'depth': 6, 'learning_rate': 0.2473597816123798, 'random_strength': 16, 'bagging_temperature': 0.23648672898572887, 'l2_leaf_reg': 9.225331594172003, 'scale_pos_weight': 1.0656805598580008}. Best is trial 67 with value: 0.798125.
# [I 2024-01-30 14:56:34,324] Trial 69 finished with value: 0.699375 and parameters: {'depth': 5, 'learning_rate': 0.029786498218715162, 'random_strength': 15, 'bagging_temperature': 0.029372201800215547, 'l2_leaf_reg': 2.8571612783080473, 'scale_pos_weight': 7.1176216570479385}. Best is trial 67 with value: 0.798125.
# [I 2024-01-30 14:56:34,984] Trial 70 finished with value: 0.74625 and parameters: {'depth': 4, 'learning_rate': 0.207704333002243, 'random_strength': 13, 'bagging_temperature': 0.3428342952858058, 'l2_leaf_reg': 71.18646837971545, 'scale_pos_weight': 0.31407563613162837}. Best is trial 67 with value: 0.798125.
# [I 2024-01-30 14:56:35,429] Trial 71 finished with value: 0.766875 and parameters: {'depth': 5, 'learning_rate': 0.25493614884702837, 'random_strength': 17, 'bagging_temperature': 0.13757693812175387, 'l2_leaf_reg': 13.170325653090709, 'scale_pos_weight': 1.9219322347885446}. Best is trial 67 with value: 0.798125.
# [I 2024-01-30 14:56:35,968] Trial 72 finished with value: 0.78625 and parameters: {'depth': 5, 'learning_rate': 0.24038042929585704, 'random_strength': 19, 'bagging_temperature': 0.17938049592684027, 'l2_leaf_reg': 8.544905623008233, 'scale_pos_weight': 1.3617688594961288}. Best is trial 67 with value: 0.798125.
# [I 2024-01-30 14:56:36,444] Trial 73 finished with value: 0.783125 and parameters: {'depth': 5, 'learning_rate': 0.227721724223938, 'random_strength': 18, 'bagging_temperature': 0.24370373066381687, 'l2_leaf_reg': 7.246929834316454, 'scale_pos_weight': 0.8423115243462033}. Best is trial 67 with value: 0.798125.
# [I 2024-01-30 14:56:36,930] Trial 74 finished with value: 0.77625 and parameters: {'depth': 6, 'learning_rate': 0.2624653256937595, 'random_strength': 17, 'bagging_temperature': 0.0592709024552832, 'l2_leaf_reg': 11.50045058430738, 'scale_pos_weight': 1.6560657739813736}. Best is trial 67 with value: 0.798125.
# [I 2024-01-30 14:56:37,559] Trial 75 finished with value: 0.788125 and parameters: {'depth': 5, 'learning_rate': 0.18271187199436412, 'random_strength': 18, 'bagging_temperature': 0.09533335139963849, 'l2_leaf_reg': 18.482367860688353, 'scale_pos_weight': 1.209706262596765}. Best is trial 67 with value: 0.798125.
# [I 2024-01-30 14:56:39,198] Trial 76 finished with value: 0.781875 and parameters: {'depth': 5, 'learning_rate': 0.04182142253916954, 'random_strength': 14, 'bagging_temperature': 0.1420509078799259, 'l2_leaf_reg': 3.2235394048524135, 'scale_pos_weight': 0.5959536752663895}. Best is trial 67 with value: 0.798125.
# [I 2024-01-30 14:56:39,672] Trial 77 finished with value: 0.759375 and parameters: {'depth': 6, 'learning_rate': 0.2802191647102238, 'random_strength': 20, 'bagging_temperature': 0.2745686632264045, 'l2_leaf_reg': 14.07200414904603, 'scale_pos_weight': 2.304542911825714}. Best is trial 67 with value: 0.798125.
# [I 2024-01-30 14:56:40,183] Trial 78 finished with value: 0.780625 and parameters: {'depth': 4, 'learning_rate': 0.2236224785560771, 'random_strength': 17, 'bagging_temperature': 0.04197853870515961, 'l2_leaf_reg': 54.89907005259619, 'scale_pos_weight': 1.5274272907310784}. Best is trial 67 with value: 0.798125.
# [I 2024-01-30 14:56:40,830] Trial 79 finished with value: 0.7725 and parameters: {'depth': 10, 'learning_rate': 0.21486135529618278, 'random_strength': 19, 'bagging_temperature': 4.7875426275500316e-05, 'l2_leaf_reg': 0.040114426931757485, 'scale_pos_weight': 0.8614115071896562}. Best is trial 67 with value: 0.798125.
# [I 2024-01-30 14:56:41,377] Trial 80 finished with value: 0.735625 and parameters: {'depth': 6, 'learning_rate': 0.144229148847903, 'random_strength': 12, 'bagging_temperature': 0.1946264671896493, 'l2_leaf_reg': 7.353040435802653, 'scale_pos_weight': 3.7045445498722778}. Best is trial 67 with value: 0.798125.
# [I 2024-01-30 14:56:42,017] Trial 81 finished with value: 0.7875 and parameters: {'depth': 5, 'learning_rate': 0.16394861488937157, 'random_strength': 2, 'bagging_temperature': 0.35944663426599716, 'l2_leaf_reg': 2.3695727109189075, 'scale_pos_weight': 0.9274131109766944}. Best is trial 67 with value: 0.798125.
# [I 2024-01-30 14:56:42,473] Trial 82 finished with value: 0.775 and parameters: {'depth': 5, 'learning_rate': 0.1640357470602648, 'random_strength': 1, 'bagging_temperature': 0.3152177030719878, 'l2_leaf_reg': 5.423028890986425, 'scale_pos_weight': 1.8419851137738763}. Best is trial 67 with value: 0.798125.
# [I 2024-01-30 14:56:43,015] Trial 83 finished with value: 0.668125 and parameters: {'depth': 5, 'learning_rate': 0.20149542487476985, 'random_strength': 16, 'bagging_temperature': 0.41557573220288035, 'l2_leaf_reg': 10.452408095613803, 'scale_pos_weight': 0.14934406844163073}. Best is trial 67 with value: 0.798125.
# [I 2024-01-30 14:56:43,615] Trial 84 finished with value: 0.793125 and parameters: {'depth': 4, 'learning_rate': 0.18169443499383445, 'random_strength': 10, 'bagging_temperature': 0.3979516059201598, 'l2_leaf_reg': 7.026565476509499, 'scale_pos_weight': 1.3140849190777713}. Best is trial 67 with value: 0.798125.
# [I 2024-01-30 14:56:44,423] Trial 85 finished with value: 0.80375 and parameters: {'depth': 4, 'learning_rate': 0.19202663283427418, 'random_strength': 9, 'bagging_temperature': 0.3349685084055967, 'l2_leaf_reg': 15.420693746162856, 'scale_pos_weight': 1.3024521115054957}. Best is trial 85 with value: 0.80375.
# [I 2024-01-30 14:56:45,137] Trial 86 finished with value: 0.798125 and parameters: {'depth': 4, 'learning_rate': 0.17763899017231735, 'random_strength': 9, 'bagging_temperature': 0.3928724052875492, 'l2_leaf_reg': 20.70660105633696, 'scale_pos_weight': 1.1686901330214847}. Best is trial 85 with value: 0.80375.
# [I 2024-01-30 14:56:45,705] Trial 87 finished with value: 0.7625 and parameters: {'depth': 4, 'learning_rate': 0.1766475084179011, 'random_strength': 10, 'bagging_temperature': 0.49883690925518853, 'l2_leaf_reg': 31.059937060988094, 'scale_pos_weight': 2.0864314908155657}. Best is trial 85 with value: 0.80375.
# [I 2024-01-30 14:56:46,327] Trial 88 finished with value: 0.780625 and parameters: {'depth': 4, 'learning_rate': 0.19227462276683613, 'random_strength': 9, 'bagging_temperature': 0.3853332544634808, 'l2_leaf_reg': 17.72236006768395, 'scale_pos_weight': 0.6361397089955123}. Best is trial 85 with value: 0.80375.
# [I 2024-01-30 14:56:46,875] Trial 89 finished with value: 0.745 and parameters: {'depth': 4, 'learning_rate': 0.17119709340209788, 'random_strength': 10, 'bagging_temperature': 0.3311340632250117, 'l2_leaf_reg': 20.963432331224205, 'scale_pos_weight': 2.5656218796397194}. Best is trial 85 with value: 0.80375.
# [I 2024-01-30 14:56:47,752] Trial 90 finished with value: 0.795 and parameters: {'depth': 4, 'learning_rate': 0.17980773178555426, 'random_strength': 8, 'bagging_temperature': 0.4526643004939026, 'l2_leaf_reg': 41.9173767760797, 'scale_pos_weight': 1.2720036860408195}. Best is trial 85 with value: 0.80375.
# [I 2024-01-30 14:56:48,516] Trial 91 finished with value: 0.795 and parameters: {'depth': 4, 'learning_rate': 0.18026529490075655, 'random_strength': 8, 'bagging_temperature': 0.44886503115584725, 'l2_leaf_reg': 42.62447040827681, 'scale_pos_weight': 1.153073066240231}. Best is trial 85 with value: 0.80375.
# [I 2024-01-30 14:56:49,385] Trial 92 finished with value: 0.786875 and parameters: {'depth': 4, 'learning_rate': 0.18001991073762258, 'random_strength': 8, 'bagging_temperature': 0.44091826023131225, 'l2_leaf_reg': 61.30849556035623, 'scale_pos_weight': 1.305746668604366}. Best is trial 85 with value: 0.80375.
# [I 2024-01-30 14:56:49,954] Trial 93 finished with value: 0.780625 and parameters: {'depth': 4, 'learning_rate': 0.19237027879014415, 'random_strength': 8, 'bagging_temperature': 0.5860240729649902, 'l2_leaf_reg': 41.495331073080436, 'scale_pos_weight': 1.6815998184533303}. Best is trial 85 with value: 0.80375.
# [I 2024-01-30 14:56:50,581] Trial 94 finished with value: 0.7925 and parameters: {'depth': 4, 'learning_rate': 0.20139911521732853, 'random_strength': 7, 'bagging_temperature': 0.4764909855988808, 'l2_leaf_reg': 44.72956623431377, 'scale_pos_weight': 1.2906188246297494}. Best is trial 85 with value: 0.80375.
# [I 2024-01-30 14:56:51,110] Trial 95 finished with value: 0.7725 and parameters: {'depth': 4, 'learning_rate': 0.21283464829937515, 'random_strength': 9, 'bagging_temperature': 0.39934994066560975, 'l2_leaf_reg': 40.120966583802385, 'scale_pos_weight': 1.8858700225923712}. Best is trial 85 with value: 0.80375.
# [I 2024-01-30 14:56:51,664] Trial 96 finished with value: 0.72 and parameters: {'depth': 4, 'learning_rate': 0.1695543158596095, 'random_strength': 11, 'bagging_temperature': 0.5283523565419276, 'l2_leaf_reg': 37.01313448719729, 'scale_pos_weight': 4.8416139929995134}. Best is trial 85 with value: 0.80375.
# [I 2024-01-30 14:56:52,294] Trial 97 finished with value: 0.7825 and parameters: {'depth': 4, 'learning_rate': 0.18134004420749592, 'random_strength': 12, 'bagging_temperature': 0.39536363395380114, 'l2_leaf_reg': 45.71295228345774, 'scale_pos_weight': 0.7180679947120006}. Best is trial 85 with value: 0.80375.
# [I 2024-01-30 14:56:53,260] Trial 98 finished with value: 0.770625 and parameters: {'depth': 4, 'learning_rate': 0.1546446054909719, 'random_strength': 9, 'bagging_temperature': 0.35519062525577955, 'l2_leaf_reg': 22.767000090077016, 'scale_pos_weight': 0.420439482389811}. Best is trial 85 with value: 0.80375.
# [I 2024-01-30 14:56:53,918] Trial 99 finished with value: 0.790625 and parameters: {'depth': 4, 'learning_rate': 0.16492966520803448, 'random_strength': 10, 'bagging_temperature': 0.4416053380868866, 'l2_leaf_reg': 25.30408497868201, 'scale_pos_weight': 1.1060934154411912}. Best is trial 85 with value: 0.80375.

# %% [markdown]
# - Catboost平均スコア

# %%
# 全フォールドの平均スコアを計算
cb_average_score = sum(cb_fold_scores) / n_splits
print(f"CatBoost Average accuracy across all folds: {cb_average_score:.4f}")

cb_average_conf = sum(cb_conf_scores) / n_splits
print(f"CatBoost Average conf-matrix across all folds: {cb_average_conf}")
# Out:
# CatBoost Average accuracy across all folds: 0.7722
# CatBoost Average conf-matrix across all folds: [[629.4 183.8]
#  [180.6 606.2]]

# %% [markdown]
# - CB_予測平均

# %%
# 予測の平均を計算
cb_y_test_pred_avg = np.mean(cb_test_predictions, axis=0)

# 最終的な予測結果を整数に変換
cb_y_test_pred_int = (cb_y_test_pred_avg > cb_threshold).astype(int)

# %% [markdown]
# - output

# %%
# 現在の日時を取得してフォーマットする
current_time = datetime.now().strftime("%Y%m%d_%H%M%S")
output = f'../data/output/{current_time}_CatBoost_cv{cb_average_score:.4f}.csv'

submit = pd.DataFrame({
    '0': test['gameId'],
    '1': cb_y_test_pred_int
})

# カラムヘッダー消去して出力
# ヘッダーなしでCSVファイルとして保存
submit.to_csv(output, header=False, index=False)

# %%
submit
# Out:
#          0  1
# 0        9  1
# 1       15  1
# 2       18  0
# 3       23  0
# 4       31  1
# ...    ... ..
# 1995  9971  0
# 1996  9980  0
# 1997  9983  1
# 1998  9996  1
# 1999  9999  0
#
# [2000 rows x 2 columns]

# %% [markdown]
# # 合成

# %% [markdown]
# - 予測リストに追加

# %%
# 予測結果をNumPy配列に変換
cb_predictions = np.array(cb_y_test_pred_int)  # CatBoostの予測結果
lgb_predictions = np.array(lgb_y_test_pred_int)  # LightGBMの予測結果
xgb_predictions = np.array(xgb_y_test_pred_int)  # XGBoostの予測結果

# 3つのモデルの予測結果を組み合わせる
combined_predictions = np.vstack((cb_predictions, lgb_predictions, xgb_predictions))

# 多数決で最終的な予測を決定（行方向に合計し、1.5より大きい場合は1とする）
final_predictions = np.mean(combined_predictions, axis=0) > 0.5
final_predictions = final_predictions.astype(int)

# 最終的な予測をCSVファイルに保存
merge_submit = pd.DataFrame({
    '0': test['gameId'],  # 適切なID列を使用
    '1': final_predictions
})
merge_submit.to_csv(f'../data/output/{current_time}_final_predictions.csv', index=False)

# %%
merge_submit
# Out:
#          0  1
# 0        9  1
# 1       15  1
# 2       18  0
# 3       23  0
# 4       31  1
# ...    ... ..
# 1995  9971  0
# 1996  9980  0
# 1997  9983  1
# 1998  9996  1
# 1999  9999  0
#
# [2000 rows x 2 columns]

# %% [markdown]
# #

# %% [markdown]
# # Logistic classifier
