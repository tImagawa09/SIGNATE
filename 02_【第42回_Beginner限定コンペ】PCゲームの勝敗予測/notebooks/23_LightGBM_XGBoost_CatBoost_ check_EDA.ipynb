# %% [markdown]
# # Baseline

# %% [markdown]
# FEなし =>
#
# **LightGBM**<br>
# LightGBM Average accuracy across all folds ===> 0.7793749999999999<br>
# LightGBM Average conf-matrix across all folds  => [[631.8 181.4] [171.6 615.2]]<br>
#
# **XGboost**<br>
# XGB Average accuracy across all folds =======> 0.7762500000000001<br>
# XGB Average conf-matrix across all folds =====>  [[663.8 149.4] [208.6 578.2]]<br>
#
# **CatBoost**<br>
# CatBoost Average accuracy across all folds ======> 0.7747499999999998<br>
# CatBoost Average conf-matrix across all folds ====> [[637.8 175.4] [185.  601.8]]<br>

# %% [markdown]
# # Library

# %%
import pandas as pd
import numpy as np

import optuna
import xgboost as xgb
import lightgbm as lgb
import catboost as cb

from datetime import datetime
from sklearn.model_selection import train_test_split, KFold
from sklearn.metrics import accuracy_score, confusion_matrix, roc_curve, auc
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# # Data Loading

# %%
train = pd.read_csv('../data/train.csv')
test = pd.read_csv('../data/test.csv')

# %% [markdown]
# # Add New Feature

# %%
# 基準
# lgb = 0.7793749999999999
# xgb = 0.7762500000000001
# Cat = 0.7747499999999998

# %%
def add_features(df):
    # df['assistRate'] = df['blueAssists'] / (df['blueKills'] + 1) # lgb=0.7825, xgb=0.771, cb=0.783
    df['blueHerald'] = (df['blueEliteMonsters'] - df['blueDragons']).clip(lower=0)
    # df['eliteMonsterDragonRatio'] = df['blueEliteMonsters'] / (df['blueDragons'] + 1)
    # df['logTotalGold'] = np.log1p(df['blueTotalGold'])
    # df['logTotalExperience'] = np.log1p(df['blueTotalExperience'])
    # # df['firstBloodKillRatio'] = df['blueFirstBlood'] * df['blueKills']
    # df['totalCombatPoints'] = df['blueKills'] + df['blueDeaths'] + df['blueAssists']

    # total_combat_actions = df['blueKills'] + df['blueDeaths'] + df['blueAssists']
    # df['killRatio'] = df['blueKills'] / total_combat_actions
    # df['deathRatio'] = df['blueDeaths'] / total_combat_actions
    # df['assistRatio'] = df['blueAssists'] / total_combat_actions

    # df['teamStrength'] = df['blueKills'] + df['blueAssists'] + df['blueEliteMonsters']
    # df['dragonKillImpact'] = df['blueDragons'] / (df['blueKills'] + 1)
    # df['eliteMonsterUtilization'] = df['blueEliteMonsters'] / (df['blueKills'] + df['blueAssists'] + 1)
    # df['goldExperienceRatio'] = df['blueTotalGold'] / (df['blueTotalExperience'] + 1)
    # df['teamEfficiency'] = (df['blueKills'] + df['blueAssists'] + df['blueEliteMonsters']) / (df['blueDeaths'] + 1)
    # df['killToMonsterRatio'] = df['blueKills'] / (df['blueEliteMonsters'] + 1)
    # df['avgGoldPerKill'] = df['blueTotalGold'] / (df['blueKills'] + 1)
    # df['expToKillRatio'] = df['blueTotalExperience'] / (df['blueKills'] + 1)
    # df['killsMinusDeaths'] = df['blueKills'] - df['blueDeaths']
    # df['killDeathRatio'] = df['blueKills'] / (df['blueKills'] + df['blueDeaths'])
    # df['avgExperiencePerKill'] = df['blueTotalExperience'] / (df['blueKills'] + 1)
    # df['killDeathDiff'] = (df['blueKills'] - df['blueDeaths']).clip(lower=0)
    # df['eliteMonsterHeraldRatio'] = df['blueEliteMonsters'] / (df['blueHerald'] + 1)
    # df['goldXexperience'] = np.log1p(df['blueTotalGold'] * df['blueTotalExperience'])
    # df['goldPerKill'] = df['blueTotalGold'] / (df['blueKills'] + 1)  # ゼロ除算を防ぐために+1
    # df['experiencePerKill'] = df['blueTotalExperience'] / (df['blueKills'] + 1)  # ゼロ除算を防ぐために+1
    # df['eliteMonstersPerGold'] = df['blueEliteMonsters'] / df['blueTotalGold']
    # df['eliteMonstersPerExperience'] = df['blueEliteMonsters'] / df['blueTotalExperience']

    
    return df

# %% [markdown]
# - apply

# %%
train = add_features(train)
test = add_features(test)

# %% [markdown]
# # Data

# %%
# データの準備
X = train.drop(['blueWins', 'gameId'], axis=1)
y = train['blueWins']
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2, random_state=0)

test_drop_gameId = test.drop('gameId', axis=1)

# test_drop_gameId_temp = test.drop('gameId', axis=1)

# # 特徴量の標準化
# scaler = StandardScaler()
# X_train = scaler.fit_transform(X_train)
# X_val = scaler.transform(X_val)  # 検証データも同じスケーラーを使用して標準化

# # テストデータも同じスケーラーを使用して標準化
# test_drop_gameId_scaled = scaler.transform(test_drop_gameId_temp)

# # NumPy配列からPandasデータフレームに変換
# X_train = pd.DataFrame(X_train, columns=X.columns)
# X_val = pd.DataFrame(X_val, columns=X.columns)
# test_drop_gameId = pd.DataFrame(test_drop_gameId_scaled, columns=test_drop_gameId_temp.columns)

# %% [markdown]
# # Model

# %% [markdown]
# - variable

# %%
n_splits = 5
kf = KFold(n_splits=n_splits, shuffle=True)

lgb_threshold = 0.5
xgb_threshold = 0.5
cb_threshold = 0.5

# 各フォールドでのスコアを保存するリスト
lgb_fold_scores = []
xgb_fold_scores = []
cb_fold_scores = []

# 各フォール度での混同行列を保存するリスト
lgb_conf_scores = []
xgb_conf_scores = []
cb_conf_scores = []

# testを保存するリスト
lgb_test_predictions = []
xgb_test_predictions = []
cb_test_predictions = []

# %% [markdown]
# ## LightGBM

# %%
for train_index, val_index in kf.split(X):
    X_train_fold, X_val_fold = X.iloc[train_index], X.iloc[val_index]
    y_train_fold, y_val_fold = y[train_index], y[val_index]

    # LightGBMではDMatrixの代わりに普通のデータフレームを使用します
    train_data = lgb.Dataset(X_train_fold, label=y_train_fold)
    val_data = lgb.Dataset(X_val_fold, label=y_val_fold, reference=train_data)

    # Optunaでのハイパーパラメータチューニング
    def objective(trial):
        param = {
            'objective': 'binary',
            'metric': 'binary_logloss',
            'verbosity': -1,
            'boosting_type': 'gbdt',
            'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
            'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
            'num_leaves': trial.suggest_int('num_leaves', 2, 256),
            'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
            'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
            'bagging_freq': trial.suggest_int('bagging_freq', 1, 7),
            'min_child_samples': trial.suggest_int('min_child_samples', 5, 100),
            'feature_pre_filter': False,  # 特徴量の事前フィルタリングを無効化
            'min_data_in_leaf': trial.suggest_int('min_data_in_leaf', 20, 100),  # Optunaでこの値を調整する
        }

        callbacks = lgb.early_stopping(stopping_rounds=100, verbose=False)
        gbm = lgb.train(param, train_data, valid_sets=[val_data], num_boost_round=1000, callbacks=[callbacks])
        preds = gbm.predict(X_val_fold, num_iteration=gbm.best_iteration)
        pred_labels = np.rint(preds)
        accuracy = accuracy_score(y_val_fold, pred_labels)
        return accuracy

    lgb_study = optuna.create_study(direction='maximize')
    lgb_study.optimize(objective, n_trials=100)

    # 各フォールドの最適パラメータでモデルを再学習
    lgb_best_params = lgb_study.best_params
    lgb_best_params['objective'] = 'binary'
    lgb_best_params['metric'] = 'binary_logloss'
    lgb_best_params['verbosity'] = -1

    lgb_final = lgb.train(lgb_best_params, train_data, num_boost_round=lgb_study.best_trial.number)

    # 各フォールドのモデル性能を評価
    lgb_y_val_pred = lgb_final.predict(X_val_fold, num_iteration=lgb_final.best_iteration)
    lgb_y_val_pred_int = np.rint(lgb_y_val_pred)
    lgb_fold_accuracy = accuracy_score(y_val_fold, lgb_y_val_pred_int)
    lgb_fold_scores.append(lgb_fold_accuracy)

    # 混同行列
    lgb_conf_matrix = confusion_matrix(y_val_fold, lgb_y_val_pred_int)
    lgb_conf_scores.append(lgb_conf_matrix)


    # テストデータセットでの予測
    lgb_y_test_pred_fold = lgb_final.predict(test_drop_gameId, num_iteration=lgb_final.best_iteration)
    lgb_test_predictions.append(lgb_y_test_pred_fold)
# Out:
# [I 2024-01-29 16:41:22,010] A new study created in memory with name: no-name-5279414d-438a-4d73-a9e7-0d4ea29820f7
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-29 16:41:22,275] Trial 0 finished with value: 0.793125 and parameters: {'lambda_l1': 1.8292927202209387e-08, 'lambda_l2': 0.0018957806710861245, 'num_leaves': 252, 'feature_fraction': 0.6874271548227247, 'bagging_fraction': 0.9626626440076258, 'bagging_freq': 3, 'min_child_samples': 22, 'min_data_in_leaf': 91}. Best is trial 0 with value: 0.793125.
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-29 16:41:22,409] Trial 1 finished with value: 0.785625 and parameters: {'lambda_l1': 2.7301023862076162e-05, 'lambda_l2': 5.6672057929110445e-05, 'num_leaves': 74, 'feature_fraction': 0.6630369742366788, 'bagging_fraction': 0.5831388430982699, 'bagging_freq': 6, 'min_child_samples': 6, 'min_data_in_leaf': 100}. Best is trial 0 with value: 0.793125.
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-29 16:41:22,670] Trial 2 finished with value: 0.79 and parameters: {'lambda_l1': 0.00022201313707514747, 'lambda_l2': 4.673448880909979e-08, 'num_leaves': 218, 'feature_fraction': 0.9660658255928155, 'bagging_fraction': 0.7850334528423075, 'bagging_freq': 4, 'min_child_samples': 53, 'min_data_in_leaf': 25}. Best is trial 0 with value: 0.793125.
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-29 16:41:22,851] Trial 3 finished with value: 0.786875 and parameters: {'lambda_l1': 0.8504785998423979, 'lambda_l2': 0.011570655739209894, 'num_leaves': 184, 'feature_fraction': 0.5355032623047598, 'bagging_fraction': 0.7446531641754092, 'bagging_freq': 4, 'min_child_samples': 71, 'min_data_in_leaf': 83}. Best is trial 0 with value: 0.793125.
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-29 16:41:23,041] Trial 4 finished with value: 0.79125 and parameters: {'lambda_l1': 1.6676406075966127e-08, 'lambda_l2': 2.350589715061818e-05, 'num_leaves': 113, 'feature_fraction': 0.698647370190381, 'bagging_fraction': 0.9903870115790397, 'bagging_freq': 6, 'min_child_samples': 88, 'min_data_in_leaf': 56}. Best is trial 0 with value: 0.793125.
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-29 16:41:23,234] Trial 5 finished with value: 0.79125 and parameters: {'lambda_l1': 3.6675081405931325, 'lambda_l2': 8.229752994951092, 'num_leaves': 92, 'feature_fraction': 0.4176930979865754, 'bagging_fraction': 0.8458975024854771, 'bagging_freq': 3, 'min_child_samples': 28, 'min_data_in_leaf': 66}. Best is trial 0 with value: 0.793125.
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-29 16:41:23,393] Trial 6 finished with value: 0.79 and parameters: {'lambda_l1': 2.596443976108629e-06, 'lambda_l2': 2.350324936757193e-06, 'num_leaves': 140, 'feature_fraction': 0.5352676290299093, 'bagging_fraction': 0.6232441371496954, 'bagging_freq': 2, 'min_child_samples': 35, 'min_data_in_leaf': 98}. Best is trial 0 with value: 0.793125.
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-29 16:41:23,499] Trial 7 finished with value: 0.786875 and parameters: {'lambda_l1': 3.1224277337798646e-08, 'lambda_l2': 8.102510218302793e-07, 'num_leaves': 157, 'feature_fraction': 0.8449267768354749, 'bagging_fraction': 0.4909546673357623, 'bagging_freq': 6, 'min_child_samples': 35, 'min_data_in_leaf': 79}. Best is trial 0 with value: 0.793125.
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-29 16:41:23,607] Trial 8 finished with value: 0.789375 and parameters: {'lambda_l1': 1.1526013227153737e-05, 'lambda_l2': 3.0989500949359803, 'num_leaves': 17, 'feature_fraction': 0.9162713677981092, 'bagging_fraction': 0.8452404780716483, 'bagging_freq': 5, 'min_child_samples': 62, 'min_data_in_leaf': 33}. Best is trial 0 with value: 0.793125.
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-29 16:41:23,779] Trial 9 finished with value: 0.79 and parameters: {'lambda_l1': 1.0018431705814481, 'lambda_l2': 2.40930803877538e-05, 'num_leaves': 47, 'feature_fraction': 0.7903332138913914, 'bagging_fraction': 0.440800805295017, 'bagging_freq': 1, 'min_child_samples': 13, 'min_data_in_leaf': 63}. Best is trial 0 with value: 0.793125.
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-29 16:41:24,115] Trial 10 finished with value: 0.79625 and parameters: {'lambda_l1': 0.009361287766044798, 'lambda_l2': 0.0032194244510641255, 'num_leaves': 251, 'feature_fraction': 0.7854113392623745, 'bagging_fraction': 0.9937039278208335, 'bagging_freq': 1, 'min_child_samples': 97, 'min_data_in_leaf': 46}. Best is trial 10 with value: 0.79625.
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-29 16:41:24,518] Trial 11 finished with value: 0.790625 and parameters: {'lambda_l1': 0.007789376349331236, 'lambda_l2': 0.004766081910059544, 'num_leaves': 250, 'feature_fraction': 0.78130124284994, 'bagging_fraction': 0.9952748015923512, 'bagging_freq': 1, 'min_child_samples': 97, 'min_data_in_leaf': 37}. Best is trial 10 with value: 0.79625.
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-29 16:41:24,819] Trial 12 finished with value: 0.795 and parameters: {'lambda_l1': 0.00791362088280987, 'lambda_l2': 0.0014880073598163282, 'num_leaves': 250, 'feature_fraction': 0.6852482252640609, 'bagging_fraction': 0.9199366016898619, 'bagging_freq': 2, 'min_child_samples': 79, 'min_data_in_leaf': 45}. Best is trial 10 with value: 0.79625.
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-29 16:41:25,048] Trial 13 finished with value: 0.791875 and parameters: {'lambda_l1': 0.017566605572396712, 'lambda_l2': 0.04198665513983, 'num_leaves': 202, 'feature_fraction': 0.9988421421770677, 'bagging_fraction': 0.9029885659703017, 'bagging_freq': 2, 'min_child_samples': 80, 'min_data_in_leaf': 47}. Best is trial 10 with value: 0.79625.
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-29 16:41:25,331] Trial 14 finished with value: 0.799375 and parameters: {'lambda_l1': 0.016470875760103535, 'lambda_l2': 0.0006652087787017443, 'num_leaves': 218, 'feature_fraction': 0.791549748492645, 'bagging_fraction': 0.8828541787171311, 'bagging_freq': 2, 'min_child_samples': 100, 'min_data_in_leaf': 47}. Best is trial 14 with value: 0.799375.
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-29 16:41:25,606] Trial 15 finished with value: 0.795 and parameters: {'lambda_l1': 0.06119169297457465, 'lambda_l2': 0.05908678152809281, 'num_leaves': 178, 'feature_fraction': 0.8832926002779207, 'bagging_fraction': 0.9007734670000489, 'bagging_freq': 1, 'min_child_samples': 100, 'min_data_in_leaf': 52}. Best is trial 14 with value: 0.799375.
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-29 16:41:25,872] Trial 16 finished with value: 0.79 and parameters: {'lambda_l1': 0.001107659445619729, 'lambda_l2': 0.0004988522009941585, 'num_leaves': 213, 'feature_fraction': 0.7853715490460688, 'bagging_fraction': 0.8295691141010968, 'bagging_freq': 3, 'min_child_samples': 90, 'min_data_in_leaf': 72}. Best is trial 14 with value: 0.799375.
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-29 16:41:26,138] Trial 17 finished with value: 0.794375 and parameters: {'lambda_l1': 0.13254009635597278, 'lambda_l2': 0.2905187000630354, 'num_leaves': 223, 'feature_fraction': 0.8696855460501594, 'bagging_fraction': 0.7328934869661219, 'bagging_freq': 2, 'min_child_samples': 66, 'min_data_in_leaf': 38}. Best is trial 14 with value: 0.799375.
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-29 16:41:26,493] Trial 18 finished with value: 0.780625 and parameters: {'lambda_l1': 0.0010157151415144344, 'lambda_l2': 0.00019832041560258968, 'num_leaves': 167, 'feature_fraction': 0.7749534449666087, 'bagging_fraction': 0.9554187620328042, 'bagging_freq': 7, 'min_child_samples': 52, 'min_data_in_leaf': 20}. Best is trial 14 with value: 0.799375.
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-29 16:41:26,779] Trial 19 finished with value: 0.793125 and parameters: {'lambda_l1': 7.821784041690804, 'lambda_l2': 0.00031702798900381564, 'num_leaves': 232, 'feature_fraction': 0.9240940334004796, 'bagging_fraction': 0.8879572049484334, 'bagging_freq': 1, 'min_child_samples': 87, 'min_data_in_leaf': 43}. Best is trial 14 with value: 0.799375.
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-29 16:41:27,001] Trial 20 finished with value: 0.7925 and parameters: {'lambda_l1': 0.17206992864624898, 'lambda_l2': 0.013437169924711312, 'num_leaves': 197, 'feature_fraction': 0.8237157251464339, 'bagging_fraction': 0.7942661852116681, 'bagging_freq': 3, 'min_child_samples': 76, 'min_data_in_leaf': 55}. Best is trial 14 with value: 0.799375.
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-29 16:41:27,290] Trial 21 finished with value: 0.791875 and parameters: {'lambda_l1': 0.005192152115245288, 'lambda_l2': 0.0015914675406970829, 'num_leaves': 253, 'feature_fraction': 0.7551473951036503, 'bagging_fraction': 0.9365947189298497, 'bagging_freq': 2, 'min_child_samples': 95, 'min_data_in_leaf': 49}. Best is trial 14 with value: 0.799375.
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-29 16:41:27,694] Trial 22 finished with value: 0.786875 and parameters: {'lambda_l1': 0.028416888941775176, 'lambda_l2': 0.0010587983076276607, 'num_leaves': 237, 'feature_fraction': 0.7346074409157777, 'bagging_fraction': 0.9992440263205459, 'bagging_freq': 2, 'min_child_samples': 82, 'min_data_in_leaf': 32}. Best is trial 14 with value: 0.799375.
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-29 16:41:27,959] Trial 23 finished with value: 0.78875 and parameters: {'lambda_l1': 0.004651508255620992, 'lambda_l2': 0.005148250634915242, 'num_leaves': 231, 'feature_fraction': 0.6463163734513104, 'bagging_fraction': 0.9152584257338735, 'bagging_freq': 1, 'min_child_samples': 92, 'min_data_in_leaf': 43}. Best is trial 14 with value: 0.799375.
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-29 16:41:28,318] Trial 24 finished with value: 0.79 and parameters: {'lambda_l1': 0.13346239276216068, 'lambda_l2': 0.00027382239505205813, 'num_leaves': 196, 'feature_fraction': 0.7279629136914031, 'bagging_fraction': 0.8746930663149017, 'bagging_freq': 2, 'min_child_samples': 99, 'min_data_in_leaf': 27}. Best is trial 14 with value: 0.799375.
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-29 16:41:28,643] Trial 25 finished with value: 0.793125 and parameters: {'lambda_l1': 0.001062201064999155, 'lambda_l2': 0.17266193554352827, 'num_leaves': 132, 'feature_fraction': 0.8420126239074296, 'bagging_fraction': 0.9389416448119344, 'bagging_freq': 3, 'min_child_samples': 84, 'min_data_in_leaf': 59}. Best is trial 14 with value: 0.799375.
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-29 16:41:29,128] Trial 26 finished with value: 0.795 and parameters: {'lambda_l1': 0.02074960815398814, 'lambda_l2': 9.421289934537177e-05, 'num_leaves': 256, 'feature_fraction': 0.637078944263529, 'bagging_fraction': 0.94307211279961, 'bagging_freq': 1, 'min_child_samples': 73, 'min_data_in_leaf': 43}. Best is trial 14 with value: 0.799375.
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-29 16:41:29,406] Trial 27 finished with value: 0.79875 and parameters: {'lambda_l1': 0.4418930137028243, 'lambda_l2': 0.0013272386534726832, 'num_leaves': 205, 'feature_fraction': 0.7114162827648042, 'bagging_fraction': 0.857516787055383, 'bagging_freq': 4, 'min_child_samples': 65, 'min_data_in_leaf': 68}. Best is trial 14 with value: 0.799375.
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# ...
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-29 16:43:41,034] Trial 90 finished with value: 0.77375 and parameters: {'lambda_l1': 0.5126246553654261, 'lambda_l2': 0.0024925331917537686, 'num_leaves': 2, 'feature_fraction': 0.7383516793016951, 'bagging_fraction': 0.5376310003827397, 'bagging_freq': 1, 'min_child_samples': 54, 'min_data_in_leaf': 95}. Best is trial 79 with value: 0.788125.
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-29 16:43:41,239] Trial 91 finished with value: 0.78375 and parameters: {'lambda_l1': 0.6677840484487678, 'lambda_l2': 0.02815643754670085, 'num_leaves': 21, 'feature_fraction': 0.6989662920197544, 'bagging_fraction': 0.5229771642394777, 'bagging_freq': 1, 'min_child_samples': 31, 'min_data_in_leaf': 94}. Best is trial 79 with value: 0.788125.
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-29 16:43:41,502] Trial 92 finished with value: 0.785625 and parameters: {'lambda_l1': 1.433497232306721, 'lambda_l2': 0.007299716120566115, 'num_leaves': 12, 'feature_fraction': 0.7820221172992465, 'bagging_fraction': 0.43996555830912726, 'bagging_freq': 1, 'min_child_samples': 43, 'min_data_in_leaf': 98}. Best is trial 79 with value: 0.788125.
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-29 16:43:41,766] Trial 93 finished with value: 0.783125 and parameters: {'lambda_l1': 1.4076907132781795, 'lambda_l2': 0.0074821981410441996, 'num_leaves': 10, 'feature_fraction': 0.7693231935988647, 'bagging_fraction': 0.4848149567782727, 'bagging_freq': 1, 'min_child_samples': 48, 'min_data_in_leaf': 89}. Best is trial 79 with value: 0.788125.
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-29 16:43:42,015] Trial 94 finished with value: 0.78375 and parameters: {'lambda_l1': 2.609933734736082, 'lambda_l2': 0.018347730867315844, 'num_leaves': 28, 'feature_fraction': 0.7798122839978273, 'bagging_fraction': 0.5510839639260857, 'bagging_freq': 1, 'min_child_samples': 46, 'min_data_in_leaf': 92}. Best is trial 79 with value: 0.788125.
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-29 16:43:42,413] Trial 95 finished with value: 0.78875 and parameters: {'lambda_l1': 0.14440469545289578, 'lambda_l2': 0.010918818085109978, 'num_leaves': 6, 'feature_fraction': 0.7482826472293896, 'bagging_fraction': 0.4702930456409652, 'bagging_freq': 1, 'min_child_samples': 44, 'min_data_in_leaf': 99}. Best is trial 95 with value: 0.78875.
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-29 16:43:42,653] Trial 96 finished with value: 0.77875 and parameters: {'lambda_l1': 0.18836261220745662, 'lambda_l2': 0.00391444732673134, 'num_leaves': 147, 'feature_fraction': 0.7623860942703299, 'bagging_fraction': 0.46730731905680456, 'bagging_freq': 1, 'min_child_samples': 43, 'min_data_in_leaf': 99}. Best is trial 95 with value: 0.78875.
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-29 16:43:42,852] Trial 97 finished with value: 0.776875 and parameters: {'lambda_l1': 0.35869285920186256, 'lambda_l2': 0.011090088744349766, 'num_leaves': 109, 'feature_fraction': 0.7179146548631906, 'bagging_fraction': 0.4417712549365818, 'bagging_freq': 2, 'min_child_samples': 39, 'min_data_in_leaf': 87}. Best is trial 95 with value: 0.78875.
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-29 16:43:43,125] Trial 98 finished with value: 0.785625 and parameters: {'lambda_l1': 0.13956029669847547, 'lambda_l2': 0.007615243229643626, 'num_leaves': 9, 'feature_fraction': 0.7530252170092965, 'bagging_fraction': 0.4512682478032646, 'bagging_freq': 1, 'min_child_samples': 36, 'min_data_in_leaf': 95}. Best is trial 95 with value: 0.78875.
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-29 16:43:43,288] Trial 99 finished with value: 0.780625 and parameters: {'lambda_l1': 0.05947777335351498, 'lambda_l2': 0.006042852654802093, 'num_leaves': 10, 'feature_fraction': 0.8309997064514699, 'bagging_fraction': 0.44788261959753095, 'bagging_freq': 6, 'min_child_samples': 36, 'min_data_in_leaf': 95}. Best is trial 95 with value: 0.78875.

# %% [markdown]
# - lgb_平均スコア

# %%
# 全フォールドの平均スコアを計算
lgb_average_score = sum(lgb_fold_scores) / n_splits
print(f"LightGBM Average accuracy across all folds: {lgb_average_score}")


lgb_average_conf = sum(lgb_conf_scores) / n_splits
print(f"LightGBM Average conf-matrix across all folds: {lgb_average_conf}")
# Out:
# LightGBM Average accuracy across all folds: 0.7825
# LightGBM Average conf-matrix across all folds: [[639.  174.2]
#  [173.8 613. ]]

# %% [markdown]
# - lgb_予測平均

# %%
# 予測の平均を計算
lgb_y_test_pred_avg = np.mean(lgb_test_predictions, axis=0)

# 最終的な予測結果を整数に変換
lgb_y_test_pred_int = (lgb_y_test_pred_avg > lgb_threshold).astype(int)

# %% [markdown]
# - output

# %%
# 現在の日時を取得してフォーマットする
current_time = datetime.now().strftime("%Y%m%d_%H%M%S")
output = f'../data/output/{current_time}_LightGBM_cv{lgb_average_score:.4f}.csv'

submit = pd.DataFrame({
    '0': test['gameId'],
    '1': lgb_y_test_pred_int
})

# カラムヘッダー消去して出力
# ヘッダーなしでCSVファイルとして保存
submit.to_csv(output, header=False, index=False)

# %%
submit
# Out:
#          0  1
# 0        9  1
# 1       15  1
# 2       18  0
# 3       23  0
# 4       31  1
# ...    ... ..
# 1995  9971  0
# 1996  9980  0
# 1997  9983  1
# 1998  9996  1
# 1999  9999  0
#
# [2000 rows x 2 columns]

# %% [markdown]
# ## XGBoost

# %%
for train_index, val_index in kf.split(X):
    X_train_fold, X_val_fold = X.iloc[train_index], X.iloc[val_index]
    y_train_fold, y_val_fold = y[train_index], y[val_index]

    dtrain = xgb.DMatrix(X_train_fold, label=y_train_fold)
    dval = xgb.DMatrix(X_val_fold, label=y_val_fold)
    dtest = xgb.DMatrix(test_drop_gameId)

    # Optunaでのハイパーパラメータチューニング
    def objective(trial):
        param = {
            'verbosity': 0,
            'objective': 'binary:logistic',
            'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
            'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
            'max_depth': trial.suggest_int('max_depth', 3, 9),
            'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
            'subsample': trial.suggest_float('subsample', 0.5, 1),
            'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1)
        }

        bst = xgb.train(param, dtrain, num_boost_round=1000, evals=[(dval, "eval")], early_stopping_rounds=100, verbose_eval=False)
        preds = bst.predict(dval)
        pred_labels = np.rint(preds)
        accuracy = accuracy_score(y_val_fold, pred_labels)
        return accuracy

    xgb_study = optuna.create_study(direction='maximize')
    xgb_study.optimize(objective, n_trials=100)

    # 各フォールドの最適パラメータでモデルを再学習
    xgb_best_params = xgb_study.best_params
    xgb_best_params['objective'] = 'binary:logistic'
    xgb_best_params['verbosity'] = 0

    xgb_final_bst = xgb.train(xgb_best_params, dtrain, num_boost_round=xgb_study.best_trial.number)

    # 各フォールドのモデル性能を評価
    xgb_y_val_pred = xgb_final_bst.predict(dval)
    xgb_y_val_pred_int = np.rint(xgb_y_val_pred)
    fold_accuracy = accuracy_score(y_val_fold, xgb_y_val_pred_int)
    xgb_fold_scores.append(fold_accuracy)

    # 混同行列
    xgb_conf_matrix = confusion_matrix(y_val_fold, xgb_y_val_pred_int)
    xgb_conf_scores.append(xgb_conf_matrix)

    # テストデータセットでの予測
    xgb_y_test_pred_fold = xgb_final_bst.predict(dtest)
    xgb_test_predictions.append(xgb_y_test_pred_fold)
# Out:
# [I 2024-01-29 16:43:43,481] A new study created in memory with name: no-name-b9bb3dfa-bf3c-4a1c-9c97-bc0365ab7733
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-29 16:43:45,010] Trial 0 finished with value: 0.800625 and parameters: {'alpha': 9.953680181614029e-05, 'lambda': 0.0024121977933234838, 'max_depth': 6, 'eta': 0.006622578819155505, 'subsample': 0.7530002674932708, 'colsample_bytree': 0.9390065037016465}. Best is trial 0 with value: 0.800625.
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-29 16:43:45,226] Trial 1 finished with value: 0.76125 and parameters: {'alpha': 1.1485414935799594e-08, 'lambda': 0.008042106893251343, 'max_depth': 9, 'eta': 0.31018038752986654, 'subsample': 0.5275757284927833, 'colsample_bytree': 0.7371435869281452}. Best is trial 0 with value: 0.800625.
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-29 16:43:47,191] Trial 2 finished with value: 0.51125 and parameters: {'alpha': 0.00208489948156938, 'lambda': 0.13456965933781614, 'max_depth': 7, 'eta': 3.371462021841629e-06, 'subsample': 0.908838769811282, 'colsample_bytree': 0.8278022436115403}. Best is trial 0 with value: 0.800625.
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-29 16:43:48,458] Trial 3 finished with value: 0.51125 and parameters: {'alpha': 0.00014272975432361593, 'lambda': 0.0005062748432092044, 'max_depth': 5, 'eta': 9.519605636379306e-06, 'subsample': 0.7890618961497522, 'colsample_bytree': 0.8693051442811888}. Best is trial 0 with value: 0.800625.
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-29 16:43:49,328] Trial 4 finished with value: 0.51125 and parameters: {'alpha': 0.48673551962194495, 'lambda': 0.16719878826782222, 'max_depth': 3, 'eta': 7.275819508435057e-08, 'subsample': 0.8054787161908176, 'colsample_bytree': 0.9885738245817267}. Best is trial 0 with value: 0.800625.
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-29 16:43:50,469] Trial 5 finished with value: 0.51125 and parameters: {'alpha': 0.045869653813843, 'lambda': 7.471120500219112e-06, 'max_depth': 4, 'eta': 6.394771146715304e-08, 'subsample': 0.5816879455028592, 'colsample_bytree': 0.9421898939635034}. Best is trial 0 with value: 0.800625.
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-29 16:43:52,502] Trial 6 finished with value: 0.748125 and parameters: {'alpha': 1.844118103035518e-06, 'lambda': 0.009302492872710367, 'max_depth': 3, 'eta': 6.589698723616255e-05, 'subsample': 0.6333486933075493, 'colsample_bytree': 0.6729155182033857}. Best is trial 0 with value: 0.800625.
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-29 16:43:53,330] Trial 7 finished with value: 0.791875 and parameters: {'alpha': 8.598973793657875e-05, 'lambda': 7.116497027916779e-06, 'max_depth': 8, 'eta': 0.03592112772576765, 'subsample': 0.6662077927456589, 'colsample_bytree': 0.9585232632217161}. Best is trial 0 with value: 0.800625.
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-29 16:43:56,405] Trial 8 finished with value: 0.51125 and parameters: {'alpha': 2.0662655689717785e-05, 'lambda': 1.4320196157102241e-05, 'max_depth': 7, 'eta': 1.5458721831058914e-07, 'subsample': 0.5538947937887178, 'colsample_bytree': 0.5551577969145789}. Best is trial 0 with value: 0.800625.
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-29 16:44:00,319] Trial 9 finished with value: 0.643125 and parameters: {'alpha': 1.2043252177287289e-06, 'lambda': 0.008559677584944669, 'max_depth': 9, 'eta': 2.0041561628711985e-05, 'subsample': 0.5258983378643283, 'colsample_bytree': 0.8305848100841595}. Best is trial 0 with value: 0.800625.
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-29 16:44:02,155] Trial 10 finished with value: 0.78875 and parameters: {'alpha': 0.0033602712426315335, 'lambda': 5.6007877946251195e-08, 'max_depth': 6, 'eta': 0.0026801459359522997, 'subsample': 0.9813907027229631, 'colsample_bytree': 0.9977526069015498}. Best is trial 0 with value: 0.800625.
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-29 16:44:03,374] Trial 11 finished with value: 0.798125 and parameters: {'alpha': 0.00013323325722063083, 'lambda': 6.0365051170101436e-05, 'max_depth': 7, 'eta': 0.009082399387473053, 'subsample': 0.6907182890798755, 'colsample_bytree': 0.907663792641682}. Best is trial 0 with value: 0.800625.
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-29 16:44:05,005] Trial 12 finished with value: 0.79375 and parameters: {'alpha': 0.0020539412299476383, 'lambda': 0.00033815769546453135, 'max_depth': 6, 'eta': 0.0025421899077545224, 'subsample': 0.710468879376404, 'colsample_bytree': 0.9119700390009681}. Best is trial 0 with value: 0.800625.
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-29 16:44:06,915] Trial 13 finished with value: 0.793125 and parameters: {'alpha': 0.0003548982645947708, 'lambda': 0.00011136788622979261, 'max_depth': 7, 'eta': 0.0011085406055157544, 'subsample': 0.7441730609903892, 'colsample_bytree': 0.8973003512320152}. Best is trial 0 with value: 0.800625.
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-29 16:44:07,091] Trial 14 finished with value: 0.76625 and parameters: {'alpha': 1.266144013368089e-05, 'lambda': 1.4356610774297032e-06, 'max_depth': 5, 'eta': 0.5834741999136921, 'subsample': 0.676179460734345, 'colsample_bytree': 0.8152996957475189}. Best is trial 0 with value: 0.800625.
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-29 16:44:07,853] Trial 15 finished with value: 0.79625 and parameters: {'alpha': 0.039873684121338716, 'lambda': 0.9652511435299195, 'max_depth': 8, 'eta': 0.019312522565025962, 'subsample': 0.8134141637370333, 'colsample_bytree': 0.9162929379371434}. Best is trial 0 with value: 0.800625.
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-29 16:44:09,179] Trial 16 finished with value: 0.786875 and parameters: {'alpha': 4.297351966736412e-06, 'lambda': 0.0008821592951687792, 'max_depth': 5, 'eta': 0.00048053169865591483, 'subsample': 0.6343261090295409, 'colsample_bytree': 0.993912696226207}. Best is trial 0 with value: 0.800625.
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-29 16:44:09,719] Trial 17 finished with value: 0.7975 and parameters: {'alpha': 2.912225702039544e-07, 'lambda': 4.913071723950039e-05, 'max_depth': 8, 'eta': 0.023929344751902386, 'subsample': 0.7352022248774699, 'colsample_bytree': 0.869543510020103}. Best is trial 0 with value: 0.800625.
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-29 16:44:11,354] Trial 18 finished with value: 0.785 and parameters: {'alpha': 5.603960917161613e-05, 'lambda': 7.069554366680544e-07, 'max_depth': 6, 'eta': 0.00022633982767943377, 'subsample': 0.866616309998765, 'colsample_bytree': 0.7590357697366741}. Best is trial 0 with value: 0.800625.
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-29 16:44:13,043] Trial 19 finished with value: 0.79875 and parameters: {'alpha': 0.00030309030504682536, 'lambda': 0.0015761378216114514, 'max_depth': 7, 'eta': 0.004902573912647269, 'subsample': 0.7048585925919735, 'colsample_bytree': 0.9398176285347241}. Best is trial 0 with value: 0.800625.
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-29 16:44:13,280] Trial 20 finished with value: 0.78875 and parameters: {'alpha': 0.0012215776915573775, 'lambda': 0.003040933415599164, 'max_depth': 4, 'eta': 0.20519663923333364, 'subsample': 0.7760154910183589, 'colsample_bytree': 0.9499062396213394}. Best is trial 0 with value: 0.800625.
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-29 16:44:14,766] Trial 21 finished with value: 0.795 and parameters: {'alpha': 0.0003258343755097013, 'lambda': 0.00010142469896760642, 'max_depth': 7, 'eta': 0.006351582117044813, 'subsample': 0.7359135449606908, 'colsample_bytree': 0.9457293844996044}. Best is trial 0 with value: 0.800625.
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-29 16:44:15,110] Trial 22 finished with value: 0.79625 and parameters: {'alpha': 2.591246129395103e-05, 'lambda': 0.0008596278477462792, 'max_depth': 7, 'eta': 0.05810767649219644, 'subsample': 0.7057589718557121, 'colsample_bytree': 0.8780862565819167}. Best is trial 0 with value: 0.800625.
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-29 16:44:16,410] Trial 23 finished with value: 0.801875 and parameters: {'alpha': 0.0003958506962210623, 'lambda': 0.0020228751848082706, 'max_depth': 6, 'eta': 0.007802971471809284, 'subsample': 0.6786787128214737, 'colsample_bytree': 0.9282824383138111}. Best is trial 23 with value: 0.801875.
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-29 16:44:17,856] Trial 24 finished with value: 0.794375 and parameters: {'alpha': 0.0003868170889770218, 'lambda': 0.002206359303742683, 'max_depth': 6, 'eta': 0.001490478256401032, 'subsample': 0.6114800278580708, 'colsample_bytree': 0.9638353442920112}. Best is trial 23 with value: 0.801875.
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-29 16:44:18,144] Trial 25 finished with value: 0.7925 and parameters: {'alpha': 0.006775129509104294, 'lambda': 0.027386080611209087, 'max_depth': 6, 'eta': 0.07835969693581984, 'subsample': 0.6604101029636904, 'colsample_bytree': 0.9319363664714769}. Best is trial 23 with value: 0.801875.
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-29 16:44:19,385] Trial 26 finished with value: 0.80125 and parameters: {'alpha': 0.0005791875887574474, 'lambda': 0.0018145267424829992, 'max_depth': 5, 'eta': 0.006045242815087426, 'subsample': 0.7677974590204655, 'colsample_bytree': 0.8567425283399616}. Best is trial 23 with value: 0.801875.
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-29 16:44:19,528] Trial 27 finished with value: 0.7575 and parameters: {'alpha': 0.010622175774230087, 'lambda': 0.00035409898330824067, 'max_depth': 4, 'eta': 0.9249442656216933, 'subsample': 0.7613651043329235, 'colsample_bytree': 0.8553156783395158}. Best is trial 23 with value: 0.801875.
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-29 16:44:20,715] Trial 28 finished with value: 0.780625 and parameters: {'alpha': 0.0006114797676737523, 'lambda': 0.04239527529877256, 'max_depth': 5, 'eta': 0.0005414367632209729, 'subsample': 0.8308913619804225, 'colsample_bytree': 0.896919989084244}. Best is trial 23 with value: 0.801875.
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-29 16:44:20,949] Trial 29 finished with value: 0.7975 and parameters: {'alpha': 9.004631471294964e-05, 'lambda': 0.004266466503927914, 'max_depth': 5, 'eta': 0.13639361733870983, 'subsample': 0.76732261023458, 'colsample_bytree': 0.7941574820437691}. Best is trial 23 with value: 0.801875.
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-29 16:44:21,995] Trial 30 finished with value: 0.799375 and parameters: {'alpha': 0.0012019902353184756, 'lambda': 0.019903026342818902, 'max_depth': 4, 'eta': 0.016212580414318525, 'subsample': 0.7311241837949763, 'colsample_bytree': 0.8593404968045651}. Best is trial 23 with value: 0.801875.
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-29 16:44:23,003] Trial 31 finished with value: 0.800625 and parameters: {'alpha': 0.0008242314869383135, 'lambda': 0.0100027296784732, 'max_depth': 4, 'eta': 0.01223263548676113, 'subsample': 0.7215147574568651, 'colsample_bytree': 0.8687801854759063}. Best is trial 23 with value: 0.801875.
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-29 16:44:24,212] Trial 32 finished with value: 0.8025 and parameters: {'alpha': 0.0012761128280733482, 'lambda': 0.005617109762541654, 'max_depth': 5, 'eta': 0.007328465261205012, 'subsample': 0.755051471195659, 'colsample_bytree': 0.8913509631597882}. Best is trial 32 with value: 0.8025.
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-29 16:44:24,419] Trial 33 finished with value: 0.7925 and parameters: {'alpha': 0.004570121221932941, 'lambda': 0.0034958522990409793, 'max_depth': 5, 'eta': 0.21887071081653897, 'subsample': 0.7795806020139283, 'colsample_bytree': 0.9003901873192823}. Best is trial 32 with value: 0.8025.
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-29 16:44:25,841] Trial 34 finished with value: 0.79625 and parameters: {'alpha': 4.570844267890887e-05, 'lambda': 0.001671590824943266, 'max_depth': 6, 'eta': 0.0045548113030248315, 'subsample': 0.8293425609948255, 'colsample_bytree': 0.9689424935624391}. Best is trial 32 with value: 0.8025.
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-29 16:44:26,187] Trial 35 finished with value: 0.80375 and parameters: {'alpha': 0.0013095735958081973, 'lambda': 0.07267803062144158, 'max_depth': 5, 'eta': 0.0660029482582637, 'subsample': 0.7972651638752655, 'colsample_bytree': 0.9241801208874256}. Best is trial 35 with value: 0.80375.
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-29 16:44:26,531] Trial 36 finished with value: 0.7925 and parameters: {'alpha': 0.010323390314827709, 'lambda': 0.07157524315994199, 'max_depth': 5, 'eta': 0.09056740616075952, 'subsample': 0.7995654144214942, 'colsample_bytree': 0.8395058477684101}. Best is trial 35 with value: 0.80375.
# ...
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-29 16:51:15,370] Trial 87 finished with value: 0.730625 and parameters: {'alpha': 0.08035104329421089, 'lambda': 2.6700796074412243e-05, 'max_depth': 7, 'eta': 0.9754820300228478, 'subsample': 0.5787192627241797, 'colsample_bytree': 0.5547464681400845}. Best is trial 28 with value: 0.7925.
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-29 16:51:15,551] Trial 88 finished with value: 0.7775 and parameters: {'alpha': 0.17918609260288576, 'lambda': 0.00012781487242729238, 'max_depth': 4, 'eta': 0.3483294230596462, 'subsample': 0.6467783645588, 'colsample_bytree': 0.5278466939014864}. Best is trial 28 with value: 0.7925.
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-29 16:51:16,459] Trial 89 finished with value: 0.78125 and parameters: {'alpha': 0.025307961147292578, 'lambda': 5.485556834852589e-05, 'max_depth': 3, 'eta': 0.013360445298228524, 'subsample': 0.6294997784241343, 'colsample_bytree': 0.545350483308145}. Best is trial 28 with value: 0.7925.
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-29 16:51:17,042] Trial 90 finished with value: 0.785 and parameters: {'alpha': 0.9796396149500358, 'lambda': 4.381478201140405e-05, 'max_depth': 6, 'eta': 0.02888570680498056, 'subsample': 0.5575452238137641, 'colsample_bytree': 0.5092707407895861}. Best is trial 28 with value: 0.7925.
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-29 16:51:17,324] Trial 91 finished with value: 0.77875 and parameters: {'alpha': 0.11309089950267553, 'lambda': 0.00042268141226785717, 'max_depth': 4, 'eta': 0.08886738015295235, 'subsample': 0.6687897067159781, 'colsample_bytree': 0.5236810243971203}. Best is trial 28 with value: 0.7925.
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-29 16:51:18,079] Trial 92 finished with value: 0.785 and parameters: {'alpha': 0.3268353815458245, 'lambda': 0.00019968669121411608, 'max_depth': 5, 'eta': 0.018886262193555887, 'subsample': 0.6946246591148074, 'colsample_bytree': 0.5020270735100687}. Best is trial 28 with value: 0.7925.
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-29 16:51:18,623] Trial 93 finished with value: 0.7825 and parameters: {'alpha': 0.15889971642264925, 'lambda': 0.0001417111657208868, 'max_depth': 4, 'eta': 0.045040638203825256, 'subsample': 0.6570841082818801, 'colsample_bytree': 0.5571891233783388}. Best is trial 28 with value: 0.7925.
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-29 16:51:18,926] Trial 94 finished with value: 0.78375 and parameters: {'alpha': 0.03847082499284234, 'lambda': 3.184685461219865e-05, 'max_depth': 3, 'eta': 0.169035651926382, 'subsample': 0.6819294504735002, 'colsample_bytree': 0.5383883183324377}. Best is trial 28 with value: 0.7925.
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-29 16:51:19,381] Trial 95 finished with value: 0.78 and parameters: {'alpha': 0.2663115166607461, 'lambda': 8.361718167645495e-05, 'max_depth': 4, 'eta': 0.08888974906003042, 'subsample': 0.600801692275074, 'colsample_bytree': 0.5721297431000746}. Best is trial 28 with value: 0.7925.
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-29 16:51:19,571] Trial 96 finished with value: 0.783125 and parameters: {'alpha': 0.05845130350809601, 'lambda': 0.00026939172203503203, 'max_depth': 5, 'eta': 0.21907069880101962, 'subsample': 0.6479158774603534, 'colsample_bytree': 0.5116708695414526}. Best is trial 28 with value: 0.7925.
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-29 16:51:19,732] Trial 97 finished with value: 0.775625 and parameters: {'alpha': 0.67490953905447, 'lambda': 0.00011285956250636695, 'max_depth': 5, 'eta': 0.4824051750402592, 'subsample': 0.6158202465070852, 'colsample_bytree': 0.5324744596005231}. Best is trial 28 with value: 0.7925.
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-29 16:51:20,710] Trial 98 finished with value: 0.790625 and parameters: {'alpha': 0.12436805676582265, 'lambda': 1.710215630653038e-05, 'max_depth': 3, 'eta': 0.036705451220218975, 'subsample': 0.6688124817170935, 'colsample_bytree': 0.5250055878593738}. Best is trial 28 with value: 0.7925.
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_12844\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-29 16:51:21,557] Trial 99 finished with value: 0.783125 and parameters: {'alpha': 0.10654765425693194, 'lambda': 1.8595271458578893e-05, 'max_depth': 3, 'eta': 0.013299059507486239, 'subsample': 0.6365679390633665, 'colsample_bytree': 0.545257565443034}. Best is trial 28 with value: 0.7925.

# %% [markdown]
# - xgb_平均スコア

# %%
# 全フォールドの平均スコアを計算
xgb_average_score = sum(xgb_fold_scores) / n_splits
print(f"XGB Average accuracy across all folds: {xgb_average_score}")

xgb_average_conf = sum(xgb_conf_scores) / n_splits
print(f"XGB Average conf-matrix across all folds: {xgb_average_conf}")
# Out:
# XGB Average accuracy across all folds: 0.771625
# XGB Average conf-matrix across all folds: [[616.8 196.4]
#  [169.  617.8]]

# %% [markdown]
# - xgb_予測平均

# %%
# 予測の平均を計算
xgb_y_test_pred_avg = np.mean(xgb_test_predictions, axis=0)

# 最終的な予測結果を整数に変換
xgb_y_test_pred_int = (xgb_y_test_pred_avg > xgb_threshold).astype(int)

# %% [markdown]
# - output

# %%
# 現在の日時を取得してフォーマットする
current_time = datetime.now().strftime("%Y%m%d_%H%M%S")
output = f'../data/output/{current_time}_XGBoost_cv{xgb_average_score:.4f}.csv'

submit = pd.DataFrame({
    '0': test['gameId'],
    '1': xgb_y_test_pred_int
})

# カラムヘッダー消去して出力
# ヘッダーなしでCSVファイルとして保存
submit.to_csv(output, header=False, index=False)

# %% [markdown]
# ## CatBoost

# %%
for train_index, val_index in kf.split(X):
    X_train_fold, X_val_fold = X.iloc[train_index], X.iloc[val_index]
    y_train_fold, y_val_fold = y[train_index], y[val_index]

    # Optunaでのハイパーパラメータチューニング
    def objective(trial):
        param = {
            'iterations': 1000,
            'depth': trial.suggest_int('depth', 4, 10),
            'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3),
            'random_strength': trial.suggest_int('random_strength', 1, 20),
            'bagging_temperature': trial.suggest_float('bagging_temperature', 0.0, 1.0),
            'l2_leaf_reg': trial.suggest_float('l2_leaf_reg', 1e-3, 100),
            'scale_pos_weight': trial.suggest_float('scale_pos_weight', 0.1, 10.0),
            'loss_function': 'Logloss'
        }

        model = cb.CatBoostClassifier(**param, verbose=False)
        model.fit(X_train_fold, y_train_fold, eval_set=(X_val_fold, y_val_fold), early_stopping_rounds=100)
        preds = model.predict(X_val_fold)
        accuracy = accuracy_score(y_val_fold, preds)
        return accuracy

    cb_study = optuna.create_study(direction='maximize')
    cb_study.optimize(objective, n_trials=100)

    # 各フォールドの最適パラメータでモデルを再学習
    cb_best_params = cb_study.best_params
    cb_best_params['loss_function'] = 'Logloss'
    model_fold = cb.CatBoostClassifier(**cb_best_params, verbose=False)
    model_fold.fit(X_train_fold, y_train_fold)

    # 各フォールドのモデル性能を評価
    cb_y_val_pred = model_fold.predict(X_val_fold)
    cb_fold_accuracy = accuracy_score(y_val_fold, cb_y_val_pred)
    cb_fold_scores.append(cb_fold_accuracy)

    # 混同行列
    cb_conf_matrix = confusion_matrix(y_val_fold, cb_y_val_pred)
    cb_conf_scores.append(cb_conf_matrix)

    # テストデータセットでの予測
    cb_y_test_pred_fold = model_fold.predict(test_drop_gameId)
    cb_test_predictions.append(cb_y_test_pred_fold)
# Out:
# [I 2024-01-29 16:51:21,681] A new study created in memory with name: no-name-ec330ae1-4dab-484c-9231-d29382143e2e
# [I 2024-01-29 16:51:23,070] Trial 0 finished with value: 0.745 and parameters: {'depth': 8, 'learning_rate': 0.2431102319936814, 'random_strength': 6, 'bagging_temperature': 0.5779299609032928, 'l2_leaf_reg': 73.88358079167318, 'scale_pos_weight': 2.9917057837771903}. Best is trial 0 with value: 0.745.
# [I 2024-01-29 16:51:24,462] Trial 1 finished with value: 0.736875 and parameters: {'depth': 8, 'learning_rate': 0.1866977864810573, 'random_strength': 12, 'bagging_temperature': 0.04886941608380724, 'l2_leaf_reg': 87.34985544397104, 'scale_pos_weight': 4.0033023189646055}. Best is trial 0 with value: 0.745.
# [I 2024-01-29 16:51:32,938] Trial 2 finished with value: 0.690625 and parameters: {'depth': 9, 'learning_rate': 0.018940691325842585, 'random_strength': 11, 'bagging_temperature': 0.43972346688847397, 'l2_leaf_reg': 45.902300992116636, 'scale_pos_weight': 7.28476425553005}. Best is trial 0 with value: 0.745.
# [I 2024-01-29 16:51:34,013] Trial 3 finished with value: 0.71375 and parameters: {'depth': 5, 'learning_rate': 0.12688487720860317, 'random_strength': 17, 'bagging_temperature': 0.08118677334689284, 'l2_leaf_reg': 39.72032354098969, 'scale_pos_weight': 5.682842436679093}. Best is trial 0 with value: 0.745.
# [I 2024-01-29 16:51:36,978] Trial 4 finished with value: 0.7375 and parameters: {'depth': 8, 'learning_rate': 0.06881144979836827, 'random_strength': 9, 'bagging_temperature': 0.8433238162439715, 'l2_leaf_reg': 87.27026226785985, 'scale_pos_weight': 3.485362344714216}. Best is trial 0 with value: 0.745.
# [I 2024-01-29 16:51:38,074] Trial 5 finished with value: 0.660625 and parameters: {'depth': 7, 'learning_rate': 0.2819256762843512, 'random_strength': 19, 'bagging_temperature': 0.3367610348528738, 'l2_leaf_reg': 76.24680122150373, 'scale_pos_weight': 9.442453137300943}. Best is trial 0 with value: 0.745.
# [I 2024-01-29 16:51:39,397] Trial 6 finished with value: 0.75375 and parameters: {'depth': 7, 'learning_rate': 0.1661656139541853, 'random_strength': 17, 'bagging_temperature': 0.16814246880408168, 'l2_leaf_reg': 31.451726836177325, 'scale_pos_weight': 0.2730533724534481}. Best is trial 6 with value: 0.75375.
# [I 2024-01-29 16:51:40,977] Trial 7 finished with value: 0.699375 and parameters: {'depth': 8, 'learning_rate': 0.11418142483253468, 'random_strength': 4, 'bagging_temperature': 0.1479189667347327, 'l2_leaf_reg': 22.228115056436007, 'scale_pos_weight': 7.174565362742446}. Best is trial 6 with value: 0.75375.
# [I 2024-01-29 16:51:41,864] Trial 8 finished with value: 0.744375 and parameters: {'depth': 5, 'learning_rate': 0.1411679324192217, 'random_strength': 10, 'bagging_temperature': 0.3478677273188595, 'l2_leaf_reg': 34.8891937789407, 'scale_pos_weight': 2.707743600691269}. Best is trial 6 with value: 0.75375.
# [I 2024-01-29 16:51:44,240] Trial 9 finished with value: 0.740625 and parameters: {'depth': 4, 'learning_rate': 0.08272128796930045, 'random_strength': 6, 'bagging_temperature': 0.2544102031628286, 'l2_leaf_reg': 53.376664299002435, 'scale_pos_weight': 3.407982049300844}. Best is trial 6 with value: 0.75375.
# [I 2024-01-29 16:51:45,913] Trial 10 finished with value: 0.745625 and parameters: {'depth': 10, 'learning_rate': 0.1844068010420964, 'random_strength': 17, 'bagging_temperature': 0.6207788550695461, 'l2_leaf_reg': 0.9046258238816733, 'scale_pos_weight': 0.2800013347204082}. Best is trial 6 with value: 0.75375.
# [I 2024-01-29 16:51:47,893] Trial 11 finished with value: 0.70375 and parameters: {'depth': 10, 'learning_rate': 0.18595718311154735, 'random_strength': 15, 'bagging_temperature': 0.6004478621006939, 'l2_leaf_reg': 9.104067569970022, 'scale_pos_weight': 0.15753528340053316}. Best is trial 6 with value: 0.75375.
# [I 2024-01-29 16:51:48,652] Trial 12 finished with value: 0.715625 and parameters: {'depth': 6, 'learning_rate': 0.19468799409148513, 'random_strength': 20, 'bagging_temperature': 0.7207459594913704, 'l2_leaf_reg': 4.062582412668627, 'scale_pos_weight': 0.18002551163322522}. Best is trial 6 with value: 0.75375.
# [I 2024-01-29 16:51:50,764] Trial 13 finished with value: 0.77 and parameters: {'depth': 10, 'learning_rate': 0.22629273936498512, 'random_strength': 15, 'bagging_temperature': 0.9277326472633675, 'l2_leaf_reg': 5.441387653927148, 'scale_pos_weight': 1.4440359843155166}. Best is trial 13 with value: 0.77.
# [I 2024-01-29 16:51:51,652] Trial 14 finished with value: 0.77375 and parameters: {'depth': 7, 'learning_rate': 0.236121388659142, 'random_strength': 14, 'bagging_temperature': 0.9627042271690429, 'l2_leaf_reg': 19.31637467983917, 'scale_pos_weight': 1.6724466821791562}. Best is trial 14 with value: 0.77375.
# [I 2024-01-29 16:51:52,374] Trial 15 finished with value: 0.769375 and parameters: {'depth': 6, 'learning_rate': 0.23991076865835048, 'random_strength': 14, 'bagging_temperature': 0.977447912434366, 'l2_leaf_reg': 17.73161537672769, 'scale_pos_weight': 1.9747545435988827}. Best is trial 14 with value: 0.77375.
# [I 2024-01-29 16:51:53,602] Trial 16 finished with value: 0.775625 and parameters: {'depth': 9, 'learning_rate': 0.22880273553022987, 'random_strength': 1, 'bagging_temperature': 0.9592010657219563, 'l2_leaf_reg': 16.40283795140348, 'scale_pos_weight': 1.4379311104874564}. Best is trial 16 with value: 0.775625.
# [I 2024-01-29 16:51:55,049] Trial 17 finished with value: 0.77125 and parameters: {'depth': 9, 'learning_rate': 0.2681902806088173, 'random_strength': 1, 'bagging_temperature': 0.8614711595689002, 'l2_leaf_reg': 16.308402911581403, 'scale_pos_weight': 1.6156320185485185}. Best is trial 16 with value: 0.775625.
# [I 2024-01-29 16:51:55,848] Trial 18 finished with value: 0.721875 and parameters: {'depth': 7, 'learning_rate': 0.2957701074545147, 'random_strength': 2, 'bagging_temperature': 0.9852453783911523, 'l2_leaf_reg': 28.270833924955358, 'scale_pos_weight': 4.5154867537399435}. Best is trial 16 with value: 0.775625.
# [I 2024-01-29 16:51:57,425] Trial 19 finished with value: 0.75375 and parameters: {'depth': 9, 'learning_rate': 0.2200910351837028, 'random_strength': 8, 'bagging_temperature': 0.7736675408103595, 'l2_leaf_reg': 15.296237550715073, 'scale_pos_weight': 2.5150403144939917}. Best is trial 16 with value: 0.775625.
# [I 2024-01-29 16:51:58,068] Trial 20 finished with value: 0.7775 and parameters: {'depth': 6, 'learning_rate': 0.26243797244861977, 'random_strength': 12, 'bagging_temperature': 0.7273203406433283, 'l2_leaf_reg': 25.424596112259746, 'scale_pos_weight': 1.344536272122085}. Best is trial 20 with value: 0.7775.
# [I 2024-01-29 16:51:58,867] Trial 21 finished with value: 0.77625 and parameters: {'depth': 6, 'learning_rate': 0.2607632262287953, 'random_strength': 12, 'bagging_temperature': 0.8815384723513735, 'l2_leaf_reg': 26.56269394361463, 'scale_pos_weight': 1.332141660918248}. Best is trial 20 with value: 0.7775.
# [I 2024-01-29 16:51:59,649] Trial 22 finished with value: 0.779375 and parameters: {'depth': 6, 'learning_rate': 0.2560027612614235, 'random_strength': 12, 'bagging_temperature': 0.7428502791130858, 'l2_leaf_reg': 25.408062098772838, 'scale_pos_weight': 1.0904927629472447}. Best is trial 22 with value: 0.779375.
# [I 2024-01-29 16:52:00,414] Trial 23 finished with value: 0.774375 and parameters: {'depth': 6, 'learning_rate': 0.2750669280605691, 'random_strength': 12, 'bagging_temperature': 0.7299003051113546, 'l2_leaf_reg': 25.84221476339459, 'scale_pos_weight': 1.1914362979373279}. Best is trial 22 with value: 0.779375.
# [I 2024-01-29 16:52:01,050] Trial 24 finished with value: 0.748125 and parameters: {'depth': 5, 'learning_rate': 0.2615742135459181, 'random_strength': 13, 'bagging_temperature': 0.8126440520071364, 'l2_leaf_reg': 37.85138574171119, 'scale_pos_weight': 2.2725934933628382}. Best is trial 22 with value: 0.779375.
# [I 2024-01-29 16:52:01,703] Trial 25 finished with value: 0.785625 and parameters: {'depth': 6, 'learning_rate': 0.2971575937574159, 'random_strength': 8, 'bagging_temperature': 0.6701839018895125, 'l2_leaf_reg': 27.628921855500653, 'scale_pos_weight': 0.958698807285475}. Best is trial 25 with value: 0.785625.
# [I 2024-01-29 16:52:02,589] Trial 26 finished with value: 0.7925 and parameters: {'depth': 4, 'learning_rate': 0.29847874459476964, 'random_strength': 7, 'bagging_temperature': 0.6920796559242008, 'l2_leaf_reg': 49.53914939870765, 'scale_pos_weight': 0.8604443688281593}. Best is trial 26 with value: 0.7925.
# [I 2024-01-29 16:52:03,457] Trial 27 finished with value: 0.795 and parameters: {'depth': 4, 'learning_rate': 0.2956413848028474, 'random_strength': 7, 'bagging_temperature': 0.6713527275573616, 'l2_leaf_reg': 50.78182102885437, 'scale_pos_weight': 0.801031317632356}. Best is trial 27 with value: 0.795.
# [I 2024-01-29 16:52:04,206] Trial 28 finished with value: 0.790625 and parameters: {'depth': 4, 'learning_rate': 0.29679055813836186, 'random_strength': 7, 'bagging_temperature': 0.6422097091715391, 'l2_leaf_reg': 54.047432605958534, 'scale_pos_weight': 0.7263665640689833}. Best is trial 27 with value: 0.795.
# [I 2024-01-29 16:52:05,472] Trial 29 finished with value: 0.74625 and parameters: {'depth': 4, 'learning_rate': 0.29853111075154726, 'random_strength': 6, 'bagging_temperature': 0.5309592248621599, 'l2_leaf_reg': 56.603184828633026, 'scale_pos_weight': 2.966739889285619}. Best is trial 27 with value: 0.795.
# [I 2024-01-29 16:52:06,341] Trial 30 finished with value: 0.755 and parameters: {'depth': 4, 'learning_rate': 0.24793338870638545, 'random_strength': 4, 'bagging_temperature': 0.5491323985612867, 'l2_leaf_reg': 60.67866086879104, 'scale_pos_weight': 2.264277519124791}. Best is trial 27 with value: 0.795.
# [I 2024-01-29 16:52:07,157] Trial 31 finished with value: 0.783125 and parameters: {'depth': 4, 'learning_rate': 0.29730773031214774, 'random_strength': 8, 'bagging_temperature': 0.6999822507201879, 'l2_leaf_reg': 45.29342646505041, 'scale_pos_weight': 0.988355728192083}. Best is trial 27 with value: 0.795.
# [I 2024-01-29 16:52:08,034] Trial 32 finished with value: 0.79125 and parameters: {'depth': 5, 'learning_rate': 0.28198390188575434, 'random_strength': 7, 'bagging_temperature': 0.6322110677399551, 'l2_leaf_reg': 63.565131313632634, 'scale_pos_weight': 0.7661277635642778}. Best is trial 27 with value: 0.795.
# [I 2024-01-29 16:52:08,972] Trial 33 finished with value: 0.78625 and parameters: {'depth': 5, 'learning_rate': 0.28024215913547323, 'random_strength': 4, 'bagging_temperature': 0.6409815589393788, 'l2_leaf_reg': 63.31468219385968, 'scale_pos_weight': 0.7351630191936782}. Best is trial 27 with value: 0.795.
# [I 2024-01-29 16:52:09,607] Trial 34 finished with value: 0.761875 and parameters: {'depth': 4, 'learning_rate': 0.2749771514826198, 'random_strength': 7, 'bagging_temperature': 0.49275844843659905, 'l2_leaf_reg': 49.84889073766949, 'scale_pos_weight': 2.0790197742710643}. Best is trial 27 with value: 0.795.
# [I 2024-01-29 16:52:10,263] Trial 35 finished with value: 0.786875 and parameters: {'depth': 5, 'learning_rate': 0.283613874785773, 'random_strength': 10, 'bagging_temperature': 0.6433819935696974, 'l2_leaf_reg': 64.56203428857708, 'scale_pos_weight': 0.4777199468274339}. Best is trial 27 with value: 0.795.
# [I 2024-01-29 16:52:11,220] Trial 36 finished with value: 0.78625 and parameters: {'depth': 4, 'learning_rate': 0.2482960256458785, 'random_strength': 6, 'bagging_temperature': 0.6077895040967276, 'l2_leaf_reg': 44.801554967039806, 'scale_pos_weight': 0.8577243243030852}. Best is trial 27 with value: 0.795.
# [I 2024-01-29 16:52:12,027] Trial 37 finished with value: 0.7475 and parameters: {'depth': 5, 'learning_rate': 0.28461336437224277, 'random_strength': 5, 'bagging_temperature': 0.5754071374371741, 'l2_leaf_reg': 70.93667861609633, 'scale_pos_weight': 3.0248735422142063}. Best is trial 27 with value: 0.795.
# [I 2024-01-29 16:52:13,400] Trial 38 finished with value: 0.786875 and parameters: {'depth': 4, 'learning_rate': 0.21308854244064496, 'random_strength': 9, 'bagging_temperature': 0.4901076565527941, 'l2_leaf_reg': 50.37431372642308, 'scale_pos_weight': 0.6547986356097789}. Best is trial 27 with value: 0.795.
# [I 2024-01-29 16:52:14,090] Trial 39 finished with value: 0.7675 and parameters: {'depth': 5, 'learning_rate': 0.24902186449995253, 'random_strength': 3, 'bagging_temperature': 0.6757305547914764, 'l2_leaf_reg': 41.38796387080683, 'scale_pos_weight': 1.8803642417396698}. Best is trial 27 with value: 0.795.
# [I 2024-01-29 16:52:15,076] Trial 40 finished with value: 0.735 and parameters: {'depth': 4, 'learning_rate': 0.2715160856129535, 'random_strength': 7, 'bagging_temperature': 0.7876133470298433, 'l2_leaf_reg': 57.95587223638996, 'scale_pos_weight': 3.79397189391179}. Best is trial 27 with value: 0.795.
# [I 2024-01-29 16:52:15,757] Trial 41 finished with value: 0.785625 and parameters: {'depth': 5, 'learning_rate': 0.2861651062098916, 'random_strength': 10, 'bagging_temperature': 0.6587850103940737, 'l2_leaf_reg': 65.12399419075497, 'scale_pos_weight': 0.5804680427443084}. Best is trial 27 with value: 0.795.
# [I 2024-01-29 16:52:16,484] Trial 42 finished with value: 0.711875 and parameters: {'depth': 5, 'learning_rate': 0.27789050350743516, 'random_strength': 10, 'bagging_temperature': 0.6361233888944877, 'l2_leaf_reg': 54.320106473488195, 'scale_pos_weight': 0.16853483579694095}. Best is trial 27 with value: 0.795.
# [I 2024-01-29 16:52:17,623] Trial 43 finished with value: 0.785625 and parameters: {'depth': 4, 'learning_rate': 0.2864799987696672, 'random_strength': 9, 'bagging_temperature': 0.563558697858674, 'l2_leaf_reg': 65.49832789642727, 'scale_pos_weight': 0.6818623502490514}. Best is trial 27 with value: 0.795.
# [I 2024-01-29 16:52:18,298] Trial 44 finished with value: 0.76875 and parameters: {'depth': 5, 'learning_rate': 0.2986695408382911, 'random_strength': 7, 'bagging_temperature': 0.6902152772288108, 'l2_leaf_reg': 77.84296740902147, 'scale_pos_weight': 1.8684338540509744}. Best is trial 27 with value: 0.795.
# [I 2024-01-29 16:52:19,099] Trial 45 finished with value: 0.79 and parameters: {'depth': 4, 'learning_rate': 0.26705420209024044, 'random_strength': 5, 'bagging_temperature': 0.5991591341863511, 'l2_leaf_reg': 48.778554191257, 'scale_pos_weight': 0.5906850983190193}. Best is trial 27 with value: 0.795.
# [I 2024-01-29 16:52:19,947] Trial 46 finished with value: 0.6725 and parameters: {'depth': 4, 'learning_rate': 0.2649995183018897, 'random_strength': 5, 'bagging_temperature': 0.5930167722383686, 'l2_leaf_reg': 50.546372807216486, 'scale_pos_weight': 0.11784362039345375}. Best is trial 27 with value: 0.795.
# [I 2024-01-29 16:52:21,018] Trial 47 finished with value: 0.75 and parameters: {'depth': 4, 'learning_rate': 0.23755127161263107, 'random_strength': 5, 'bagging_temperature': 0.4200432751542442, 'l2_leaf_reg': 42.265098493537096, 'scale_pos_weight': 2.6818183969865803}. Best is trial 27 with value: 0.795.
# [I 2024-01-29 16:52:21,817] Trial 48 finished with value: 0.776875 and parameters: {'depth': 4, 'learning_rate': 0.2565973152072579, 'random_strength': 3, 'bagging_temperature': 0.7655589056962306, 'l2_leaf_reg': 36.6502795755284, 'scale_pos_weight': 1.6923336736176993}. Best is trial 27 with value: 0.795.
# [I 2024-01-29 16:52:22,686] Trial 49 finished with value: 0.78625 and parameters: {'depth': 4, 'learning_rate': 0.27353791268182837, 'random_strength': 6, 'bagging_temperature': 0.6044269786767363, 'l2_leaf_reg': 49.424183532769185, 'scale_pos_weight': 1.1502260161755054}. Best is trial 27 with value: 0.795.
# [I 2024-01-29 16:52:23,583] Trial 50 finished with value: 0.785625 and parameters: {'depth': 4, 'learning_rate': 0.2886444639331432, 'random_strength': 7, 'bagging_temperature': 0.529142579685298, 'l2_leaf_reg': 33.31843033114859, 'scale_pos_weight': 0.5627868921288087}. Best is trial 27 with value: 0.795.
# [I 2024-01-29 16:52:24,216] Trial 51 finished with value: 0.78625 and parameters: {'depth': 5, 'learning_rate': 0.28246699175586804, 'random_strength': 8, 'bagging_temperature': 0.6447332039217228, 'l2_leaf_reg': 58.621293592307104, 'scale_pos_weight': 0.5943373560259945}. Best is trial 27 with value: 0.795.
# [I 2024-01-29 16:52:24,885] Trial 52 finished with value: 0.65625 and parameters: {'depth': 5, 'learning_rate': 0.2882965599146014, 'random_strength': 9, 'bagging_temperature': 0.7037241525506941, 'l2_leaf_reg': 55.25721306504216, 'scale_pos_weight': 0.10700011692264816}. Best is trial 27 with value: 0.795.
# [I 2024-01-29 16:52:25,554] Trial 53 finished with value: 0.77875 and parameters: {'depth': 5, 'learning_rate': 0.26860662060045076, 'random_strength': 11, 'bagging_temperature': 0.625129848540465, 'l2_leaf_reg': 53.09294779041953, 'scale_pos_weight': 1.5106891878139797}. Best is trial 27 with value: 0.795.
# [I 2024-01-29 16:52:26,167] Trial 54 finished with value: 0.785625 and parameters: {'depth': 4, 'learning_rate': 0.29784087886965743, 'random_strength': 5, 'bagging_temperature': 0.672856155784888, 'l2_leaf_reg': 46.87089010297797, 'scale_pos_weight': 0.4638497952809476}. Best is trial 27 with value: 0.795.
# [I 2024-01-29 16:52:27,494] Trial 55 finished with value: 0.785625 and parameters: {'depth': 5, 'learning_rate': 0.25466404092405454, 'random_strength': 9, 'bagging_temperature': 0.5843254001713488, 'l2_leaf_reg': 61.023683276017124, 'scale_pos_weight': 1.0230975746956292}. Best is trial 27 with value: 0.795.
# [I 2024-01-29 16:52:28,367] Trial 56 finished with value: 0.776875 and parameters: {'depth': 4, 'learning_rate': 0.26805413393976674, 'random_strength': 11, 'bagging_temperature': 0.8155552461200519, 'l2_leaf_reg': 68.91013778928476, 'scale_pos_weight': 1.5091683825483748}. Best is trial 27 with value: 0.795.
# [I 2024-01-29 16:52:29,207] Trial 57 finished with value: 0.753125 and parameters: {'depth': 5, 'learning_rate': 0.23923054938685664, 'random_strength': 4, 'bagging_temperature': 0.7304237019788818, 'l2_leaf_reg': 40.87739269422357, 'scale_pos_weight': 2.1704459328739567}. Best is trial 27 with value: 0.795.
# [I 2024-01-29 16:52:29,931] Trial 58 finished with value: 0.79 and parameters: {'depth': 4, 'learning_rate': 0.28729565270106233, 'random_strength': 7, 'bagging_temperature': 0.6414668406977423, 'l2_leaf_reg': 53.59105121341368, 'scale_pos_weight': 0.45435800797464554}. Best is trial 27 with value: 0.795.
# [I 2024-01-29 16:52:31,008] Trial 59 finished with value: 0.7775 and parameters: {'depth': 8, 'learning_rate': 0.2999355555006365, 'random_strength': 7, 'bagging_temperature': 0.6945476175271306, 'l2_leaf_reg': 53.35308689136817, 'scale_pos_weight': 1.2394994457875825}. Best is trial 27 with value: 0.795.
# [I 2024-01-29 16:52:31,856] Trial 60 finished with value: 0.78125 and parameters: {'depth': 4, 'learning_rate': 0.26295926672639625, 'random_strength': 6, 'bagging_temperature': 0.7594206614317573, 'l2_leaf_reg': 46.41668427760546, 'scale_pos_weight': 0.9985451190562126}. Best is trial 27 with value: 0.795.
# [I 2024-01-29 16:52:32,893] Trial 61 finished with value: 0.78375 and parameters: {'depth': 4, 'learning_rate': 0.28861710967430937, 'random_strength': 8, 'bagging_temperature': 0.6261735671442422, 'l2_leaf_reg': 58.15934013501658, 'scale_pos_weight': 0.4381623966444099}. Best is trial 27 with value: 0.795.
# [I 2024-01-29 16:52:33,590] Trial 62 finished with value: 0.783125 and parameters: {'depth': 4, 'learning_rate': 0.2798414340809728, 'random_strength': 7, 'bagging_temperature': 0.6473725537884818, 'l2_leaf_reg': 61.84503572491727, 'scale_pos_weight': 0.416164824215386}. Best is trial 27 with value: 0.795.
# [I 2024-01-29 16:52:34,190] Trial 63 finished with value: 0.784375 and parameters: {'depth': 4, 'learning_rate': 0.2896244271347613, 'random_strength': 6, 'bagging_temperature': 0.71718962717416, 'l2_leaf_reg': 55.11677547859412, 'scale_pos_weight': 0.8640226154616153}. Best is trial 27 with value: 0.795.
# [I 2024-01-29 16:52:35,040] Trial 64 finished with value: 0.778125 and parameters: {'depth': 5, 'learning_rate': 0.27700094263583097, 'random_strength': 5, 'bagging_temperature': 0.5629255325581334, 'l2_leaf_reg': 59.944835737020654, 'scale_pos_weight': 1.6679101717844764}. Best is trial 27 with value: 0.795.
# [I 2024-01-29 16:52:35,867] Trial 65 finished with value: 0.78375 and parameters: {'depth': 6, 'learning_rate': 0.25582731148708643, 'random_strength': 8, 'bagging_temperature': 0.6677092886967418, 'l2_leaf_reg': 52.84472250895284, 'scale_pos_weight': 1.3308594064219683}. Best is trial 27 with value: 0.795.
# [I 2024-01-29 16:52:36,596] Trial 66 finished with value: 0.779375 and parameters: {'depth': 4, 'learning_rate': 0.2723754547387081, 'random_strength': 3, 'bagging_temperature': 0.7364239035965201, 'l2_leaf_reg': 48.01577219235792, 'scale_pos_weight': 0.37761936707647575}. Best is trial 27 with value: 0.795.
# [I 2024-01-29 16:52:37,527] Trial 67 finished with value: 0.7875 and parameters: {'depth': 4, 'learning_rate': 0.2912327183841575, 'random_strength': 6, 'bagging_temperature': 0.6023579397124644, 'l2_leaf_reg': 56.86946892990933, 'scale_pos_weight': 0.8275540379279184}. Best is trial 27 with value: 0.795.
# [I 2024-01-29 16:52:38,381] Trial 68 finished with value: 0.785625 and parameters: {'depth': 4, 'learning_rate': 0.2934609558105029, 'random_strength': 4, 'bagging_temperature': 0.6030929646996972, 'l2_leaf_reg': 43.19615996635602, 'scale_pos_weight': 0.8064613970168827}. Best is trial 27 with value: 0.795.
# [I 2024-01-29 16:52:39,332] Trial 69 finished with value: 0.781875 and parameters: {'depth': 4, 'learning_rate': 0.2918216799206561, 'random_strength': 2, 'bagging_temperature': 0.5458902007896621, 'l2_leaf_reg': 38.54222083347667, 'scale_pos_weight': 1.2372039626522908}. Best is trial 27 with value: 0.795.
# [I 2024-01-29 16:52:40,116] Trial 70 finished with value: 0.765 and parameters: {'depth': 4, 'learning_rate': 0.26675450866332334, 'random_strength': 6, 'bagging_temperature': 0.5185695495563867, 'l2_leaf_reg': 57.166993716060325, 'scale_pos_weight': 2.0323909112853276}. Best is trial 27 with value: 0.795.
# [I 2024-01-29 16:52:40,818] Trial 71 finished with value: 0.793125 and parameters: {'depth': 4, 'learning_rate': 0.28177433986769856, 'random_strength': 8, 'bagging_temperature': 0.6198782067806521, 'l2_leaf_reg': 64.67875119036124, 'scale_pos_weight': 0.8260755885960075}. Best is trial 27 with value: 0.795.
# [I 2024-01-29 16:52:41,733] Trial 72 finished with value: 0.79125 and parameters: {'depth': 4, 'learning_rate': 0.27796189604104204, 'random_strength': 8, 'bagging_temperature': 0.5913808940445684, 'l2_leaf_reg': 51.88162609069178, 'scale_pos_weight': 0.9340622132840594}. Best is trial 27 with value: 0.795.
# [I 2024-01-29 16:52:42,910] Trial 73 finished with value: 0.786875 and parameters: {'depth': 4, 'learning_rate': 0.2791880928127044, 'random_strength': 9, 'bagging_temperature': 0.5798865332803882, 'l2_leaf_reg': 51.381541375512185, 'scale_pos_weight': 1.4479959024374582}. Best is trial 27 with value: 0.795.
# [I 2024-01-29 16:52:44,134] Trial 74 finished with value: 0.79125 and parameters: {'depth': 4, 'learning_rate': 0.24520524093897023, 'random_strength': 7, 'bagging_temperature': 0.6848738460152021, 'l2_leaf_reg': 44.66109846988837, 'scale_pos_weight': 1.0541030629136086}. Best is trial 27 with value: 0.795.
# [I 2024-01-29 16:52:45,036] Trial 75 finished with value: 0.7675 and parameters: {'depth': 4, 'learning_rate': 0.24673107301526762, 'random_strength': 8, 'bagging_temperature': 0.6864520610545325, 'l2_leaf_reg': 47.515532533158115, 'scale_pos_weight': 1.7532536391994935}. Best is trial 27 with value: 0.795.
# [I 2024-01-29 16:52:45,703] Trial 76 finished with value: 0.643125 and parameters: {'depth': 5, 'learning_rate': 0.2601125156975957, 'random_strength': 7, 'bagging_temperature': 0.7003881081747636, 'l2_leaf_reg': 45.25050374437548, 'scale_pos_weight': 0.10057339099945545}. Best is trial 27 with value: 0.795.
# [I 2024-01-29 16:52:46,571] Trial 77 finished with value: 0.786875 and parameters: {'depth': 4, 'learning_rate': 0.273940955114456, 'random_strength': 8, 'bagging_temperature': 0.615399093207759, 'l2_leaf_reg': 43.40888165032476, 'scale_pos_weight': 1.0979393152637371}. Best is trial 27 with value: 0.795.
# [I 2024-01-29 16:52:47,721] Trial 78 finished with value: 0.79 and parameters: {'depth': 4, 'learning_rate': 0.23157210704157, 'random_strength': 9, 'bagging_temperature': 0.6701916726421908, 'l2_leaf_reg': 48.61960427431822, 'scale_pos_weight': 0.8047339942007755}. Best is trial 27 with value: 0.795.
# [I 2024-01-29 16:52:48,787] Trial 79 finished with value: 0.759375 and parameters: {'depth': 5, 'learning_rate': 0.2457603248808274, 'random_strength': 5, 'bagging_temperature': 0.7525158393228617, 'l2_leaf_reg': 50.42014812362113, 'scale_pos_weight': 2.2787780615550135}. Best is trial 27 with value: 0.795.
# [I 2024-01-29 16:52:49,822] Trial 80 finished with value: 0.785625 and parameters: {'depth': 4, 'learning_rate': 0.27970911061581305, 'random_strength': 10, 'bagging_temperature': 0.5595335461542502, 'l2_leaf_reg': 60.26307106593811, 'scale_pos_weight': 1.2782255304051615}. Best is trial 27 with value: 0.795.
# [I 2024-01-29 16:52:50,708] Trial 81 finished with value: 0.781875 and parameters: {'depth': 4, 'learning_rate': 0.28321306718577216, 'random_strength': 7, 'bagging_temperature': 0.6514535436750216, 'l2_leaf_reg': 51.786419566474414, 'scale_pos_weight': 0.4821265074002786}. Best is trial 27 with value: 0.795.
# [I 2024-01-29 16:52:51,478] Trial 82 finished with value: 0.7775 and parameters: {'depth': 4, 'learning_rate': 0.2922467444402409, 'random_strength': 7, 'bagging_temperature': 0.6282209575244863, 'l2_leaf_reg': 55.77591694562465, 'scale_pos_weight': 0.376129628521623}. Best is trial 27 with value: 0.795.
# [I 2024-01-29 16:52:52,254] Trial 83 finished with value: 0.78875 and parameters: {'depth': 4, 'learning_rate': 0.2690864313983566, 'random_strength': 8, 'bagging_temperature': 0.7073896347396915, 'l2_leaf_reg': 39.83541831494954, 'scale_pos_weight': 0.7767237252749944}. Best is trial 27 with value: 0.795.
# [I 2024-01-29 16:52:53,175] Trial 84 finished with value: 0.785 and parameters: {'depth': 7, 'learning_rate': 0.2982648845488588, 'random_strength': 6, 'bagging_temperature': 0.5805752358744865, 'l2_leaf_reg': 53.95447294810887, 'scale_pos_weight': 0.9784453457308453}. Best is trial 27 with value: 0.795.
# [I 2024-01-29 16:52:54,117] Trial 85 finished with value: 0.773125 and parameters: {'depth': 8, 'learning_rate': 0.25189110178573954, 'random_strength': 7, 'bagging_temperature': 0.6564019427106371, 'l2_leaf_reg': 62.67169438057398, 'scale_pos_weight': 1.575250905383538}. Best is trial 27 with value: 0.795.
# [I 2024-01-29 16:52:54,857] Trial 86 finished with value: 0.765 and parameters: {'depth': 4, 'learning_rate': 0.2827555034965011, 'random_strength': 8, 'bagging_temperature': 0.6229326004971443, 'l2_leaf_reg': 42.95986939800076, 'scale_pos_weight': 0.2879737371873544}. Best is trial 27 with value: 0.795.
# [I 2024-01-29 16:52:56,200] Trial 87 finished with value: 0.789375 and parameters: {'depth': 4, 'learning_rate': 0.2612687737475629, 'random_strength': 9, 'bagging_temperature': 0.7217573104509817, 'l2_leaf_reg': 48.121091715844194, 'scale_pos_weight': 1.1030636736559432}. Best is trial 27 with value: 0.795.
# [I 2024-01-29 16:52:56,928] Trial 88 finished with value: 0.788125 and parameters: {'depth': 5, 'learning_rate': 0.2742360036285062, 'random_strength': 19, 'bagging_temperature': 0.6799930311885125, 'l2_leaf_reg': 45.1377338571978, 'scale_pos_weight': 0.7150817832144107}. Best is trial 27 with value: 0.795.
# [I 2024-01-29 16:52:57,725] Trial 89 finished with value: 0.783125 and parameters: {'depth': 4, 'learning_rate': 0.2871022199384067, 'random_strength': 6, 'bagging_temperature': 0.598696663243105, 'l2_leaf_reg': 59.22106515711974, 'scale_pos_weight': 1.315345516518943}. Best is trial 27 with value: 0.795.
# [I 2024-01-29 16:52:58,752] Trial 90 finished with value: 0.765625 and parameters: {'depth': 4, 'learning_rate': 0.26865466718245495, 'random_strength': 5, 'bagging_temperature': 0.7812740316634672, 'l2_leaf_reg': 51.297089059338695, 'scale_pos_weight': 1.837785438033204}. Best is trial 27 with value: 0.795.
# [I 2024-01-29 16:52:59,841] Trial 91 finished with value: 0.79375 and parameters: {'depth': 4, 'learning_rate': 0.23416708850598034, 'random_strength': 9, 'bagging_temperature': 0.6671463986143432, 'l2_leaf_reg': 49.1348756558186, 'scale_pos_weight': 0.7641949895966134}. Best is trial 27 with value: 0.795.
# [I 2024-01-29 16:53:00,831] Trial 92 finished with value: 0.796875 and parameters: {'depth': 4, 'learning_rate': 0.24085629962568075, 'random_strength': 9, 'bagging_temperature': 0.6470229556341314, 'l2_leaf_reg': 55.099557435915536, 'scale_pos_weight': 0.6163893380075612}. Best is trial 92 with value: 0.796875.
# [I 2024-01-29 16:53:01,792] Trial 93 finished with value: 0.785625 and parameters: {'depth': 4, 'learning_rate': 0.23946391100069703, 'random_strength': 10, 'bagging_temperature': 0.6847540771833329, 'l2_leaf_reg': 56.07916469063985, 'scale_pos_weight': 0.6268853655014549}. Best is trial 92 with value: 0.796875.
# [I 2024-01-29 16:53:02,827] Trial 94 finished with value: 0.790625 and parameters: {'depth': 4, 'learning_rate': 0.22110591411165137, 'random_strength': 9, 'bagging_temperature': 0.6638696463639102, 'l2_leaf_reg': 50.40163647614933, 'scale_pos_weight': 0.9614304699169637}. Best is trial 92 with value: 0.796875.
# [I 2024-01-29 16:53:03,604] Trial 95 finished with value: 0.78125 and parameters: {'depth': 4, 'learning_rate': 0.21121600742622967, 'random_strength': 9, 'bagging_temperature': 0.6593031618829269, 'l2_leaf_reg': 66.36146713656836, 'scale_pos_weight': 1.027045813643743}. Best is trial 92 with value: 0.796875.
# [I 2024-01-29 16:53:04,400] Trial 96 finished with value: 0.774375 and parameters: {'depth': 4, 'learning_rate': 0.22471209521790272, 'random_strength': 11, 'bagging_temperature': 0.7404578601707882, 'l2_leaf_reg': 51.73941092598472, 'scale_pos_weight': 1.4785559602604703}. Best is trial 92 with value: 0.796875.
# [I 2024-01-29 16:53:05,424] Trial 97 finished with value: 0.764375 and parameters: {'depth': 5, 'learning_rate': 0.25130103419235705, 'random_strength': 8, 'bagging_temperature': 0.7131784173637664, 'l2_leaf_reg': 63.608771818976116, 'scale_pos_weight': 0.31798534886113333}. Best is trial 92 with value: 0.796875.
# [I 2024-01-29 16:53:06,199] Trial 98 finished with value: 0.78125 and parameters: {'depth': 7, 'learning_rate': 0.23681438473997854, 'random_strength': 10, 'bagging_temperature': 0.6292865259235947, 'l2_leaf_reg': 49.27319970617951, 'scale_pos_weight': 0.8713666049371279}. Best is trial 92 with value: 0.796875.
# [I 2024-01-29 16:53:07,036] Trial 99 finished with value: 0.7825 and parameters: {'depth': 5, 'learning_rate': 0.24164905515620055, 'random_strength': 9, 'bagging_temperature': 0.6890274561206301, 'l2_leaf_reg': 58.33424108692235, 'scale_pos_weight': 1.2090597267217902}. Best is trial 92 with value: 0.796875.
# [I 2024-01-29 16:53:10,981] A new study created in memory with name: no-name-3f3061ad-3e9e-4799-848b-c40b549d0ade
# [I 2024-01-29 16:53:12,030] Trial 0 finished with value: 0.729375 and parameters: {'depth': 6, 'learning_rate': 0.10420775283958572, 'random_strength': 18, 'bagging_temperature': 0.9953357118570416, 'l2_leaf_reg': 6.0798489231400685, 'scale_pos_weight': 6.074027518260334}. Best is trial 0 with value: 0.729375.
# [I 2024-01-29 16:53:15,763] Trial 1 finished with value: 0.69375 and parameters: {'depth': 7, 'learning_rate': 0.015170975709274757, 'random_strength': 8, 'bagging_temperature': 0.16945167559505525, 'l2_leaf_reg': 9.234746824928168, 'scale_pos_weight': 8.989340970470021}. Best is trial 0 with value: 0.729375.
# [I 2024-01-29 16:53:17,267] Trial 2 finished with value: 0.705 and parameters: {'depth': 9, 'learning_rate': 0.06533007179529607, 'random_strength': 14, 'bagging_temperature': 0.5196813928211601, 'l2_leaf_reg': 44.52907595457997, 'scale_pos_weight': 7.247846866462877}. Best is trial 0 with value: 0.729375.
# [I 2024-01-29 16:53:18,686] Trial 3 finished with value: 0.77625 and parameters: {'depth': 8, 'learning_rate': 0.0972816012940288, 'random_strength': 17, 'bagging_temperature': 0.8670577093351878, 'l2_leaf_reg': 70.69662937881698, 'scale_pos_weight': 1.9197687977516822}. Best is trial 3 with value: 0.77625.
# [I 2024-01-29 16:53:19,766] Trial 4 finished with value: 0.760625 and parameters: {'depth': 5, 'learning_rate': 0.13326493664810404, 'random_strength': 3, 'bagging_temperature': 0.9486117272800445, 'l2_leaf_reg': 8.721989937649512, 'scale_pos_weight': 2.525385986928856}. Best is trial 3 with value: 0.77625.
# [I 2024-01-29 16:53:21,982] Trial 5 finished with value: 0.718125 and parameters: {'depth': 6, 'learning_rate': 0.04195236868196875, 'random_strength': 6, 'bagging_temperature': 0.6648815373115329, 'l2_leaf_reg': 34.62905291815145, 'scale_pos_weight': 7.052613700970679}. Best is trial 3 with value: 0.77625.
# [I 2024-01-29 16:53:23,505] Trial 6 finished with value: 0.78 and parameters: {'depth': 9, 'learning_rate': 0.09385248817657367, 'random_strength': 6, 'bagging_temperature': 0.35397331489730033, 'l2_leaf_reg': 0.4036622435540983, 'scale_pos_weight': 1.064615091724267}. Best is trial 6 with value: 0.78.
# [I 2024-01-29 16:53:24,399] Trial 7 finished with value: 0.6775 and parameters: {'depth': 4, 'learning_rate': 0.22495348103170387, 'random_strength': 3, 'bagging_temperature': 0.34513911220173743, 'l2_leaf_reg': 53.69904760478284, 'scale_pos_weight': 9.59822394209703}. Best is trial 6 with value: 0.78.
# [I 2024-01-29 16:53:25,548] Trial 8 finished with value: 0.695625 and parameters: {'depth': 9, 'learning_rate': 0.1266468899164737, 'random_strength': 9, 'bagging_temperature': 0.29608111689193395, 'l2_leaf_reg': 11.202334902448975, 'scale_pos_weight': 8.168348637672606}. Best is trial 6 with value: 0.78.
# [I 2024-01-29 16:53:27,665] Trial 9 finished with value: 0.75625 and parameters: {'depth': 10, 'learning_rate': 0.1426330371353729, 'random_strength': 11, 'bagging_temperature': 0.6400175823357892, 'l2_leaf_reg': 46.77046397563183, 'scale_pos_weight': 2.673276536731694}. Best is trial 6 with value: 0.78.
# [I 2024-01-29 16:53:30,388] Trial 10 finished with value: 0.69 and parameters: {'depth': 10, 'learning_rate': 0.19956983920616908, 'random_strength': 1, 'bagging_temperature': 0.08732422443053778, 'l2_leaf_reg': 94.54672844618383, 'scale_pos_weight': 0.18188133271059914}. Best is trial 6 with value: 0.78.
# [I 2024-01-29 16:53:32,337] Trial 11 finished with value: 0.60125 and parameters: {'depth': 8, 'learning_rate': 0.07765380894366283, 'random_strength': 20, 'bagging_temperature': 0.7821613768540139, 'l2_leaf_reg': 73.59034364841094, 'scale_pos_weight': 0.1009755606221836}. Best is trial 6 with value: 0.78.
# [I 2024-01-29 16:53:33,196] Trial 12 finished with value: 0.7425 and parameters: {'depth': 8, 'learning_rate': 0.2924761158571101, 'random_strength': 14, 'bagging_temperature': 0.45189216438755486, 'l2_leaf_reg': 27.456325568584482, 'scale_pos_weight': 3.4118927053726282}. Best is trial 6 with value: 0.78.
# [I 2024-01-29 16:53:35,216] Trial 13 finished with value: 0.7825 and parameters: {'depth': 8, 'learning_rate': 0.08919051812096303, 'random_strength': 15, 'bagging_temperature': 0.011815969359579626, 'l2_leaf_reg': 65.3519174082324, 'scale_pos_weight': 1.5924089369820442}. Best is trial 13 with value: 0.7825.
# [I 2024-01-29 16:53:38,124] Trial 14 finished with value: 0.741875 and parameters: {'depth': 9, 'learning_rate': 0.05193752863139065, 'random_strength': 12, 'bagging_temperature': 0.0056228691472732795, 'l2_leaf_reg': 24.842209273961465, 'scale_pos_weight': 3.7376695558779574}. Best is trial 13 with value: 0.7825.
# [I 2024-01-29 16:53:39,083] Trial 15 finished with value: 0.785625 and parameters: {'depth': 7, 'learning_rate': 0.09077314507956538, 'random_strength': 6, 'bagging_temperature': 0.21678379997269157, 'l2_leaf_reg': 1.7766154814312713, 'scale_pos_weight': 1.318329080663899}. Best is trial 15 with value: 0.785625.
# [I 2024-01-29 16:53:42,333] Trial 16 finished with value: 0.72625 and parameters: {'depth': 7, 'learning_rate': 0.011925883572658127, 'random_strength': 14, 'bagging_temperature': 0.1881145005553121, 'l2_leaf_reg': 60.74331118250209, 'scale_pos_weight': 4.649085557978832}. Best is trial 15 with value: 0.785625.
# [I 2024-01-29 16:53:43,290] Trial 17 finished with value: 0.775625 and parameters: {'depth': 6, 'learning_rate': 0.17907085555492225, 'random_strength': 7, 'bagging_temperature': 0.057820169245436814, 'l2_leaf_reg': 21.09513406238173, 'scale_pos_weight': 1.6739758024374067}. Best is trial 15 with value: 0.785625.
# [I 2024-01-29 16:53:44,767] Trial 18 finished with value: 0.79 and parameters: {'depth': 7, 'learning_rate': 0.10778118700252289, 'random_strength': 10, 'bagging_temperature': 0.16315890117600806, 'l2_leaf_reg': 35.244962998085335, 'scale_pos_weight': 1.1723555439339808}. Best is trial 18 with value: 0.79.
# [I 2024-01-29 16:53:46,010] Trial 19 finished with value: 0.7375 and parameters: {'depth': 7, 'learning_rate': 0.16448573011941892, 'random_strength': 10, 'bagging_temperature': 0.21538022607391027, 'l2_leaf_reg': 34.83604839756101, 'scale_pos_weight': 4.67312035328784}. Best is trial 18 with value: 0.79.
# [I 2024-01-29 16:53:47,566] Trial 20 finished with value: 0.78875 and parameters: {'depth': 5, 'learning_rate': 0.13131121084902034, 'random_strength': 4, 'bagging_temperature': 0.12998318280851948, 'l2_leaf_reg': 21.438163375145173, 'scale_pos_weight': 1.074011212604404}. Best is trial 18 with value: 0.79.
# [I 2024-01-29 16:53:49,078] Trial 21 finished with value: 0.79125 and parameters: {'depth': 4, 'learning_rate': 0.11959142107685661, 'random_strength': 4, 'bagging_temperature': 0.125002766901473, 'l2_leaf_reg': 17.63270907795616, 'scale_pos_weight': 0.9066356742646173}. Best is trial 21 with value: 0.79125.
# [I 2024-01-29 16:53:50,920] Trial 22 finished with value: 0.783125 and parameters: {'depth': 4, 'learning_rate': 0.1212807711480597, 'random_strength': 4, 'bagging_temperature': 0.11529349316389512, 'l2_leaf_reg': 17.87071073727124, 'scale_pos_weight': 0.6016492797858068}. Best is trial 21 with value: 0.79125.
# [I 2024-01-29 16:53:51,976] Trial 23 finished with value: 0.791875 and parameters: {'depth': 5, 'learning_rate': 0.15187946963223498, 'random_strength': 1, 'bagging_temperature': 0.11100900648571566, 'l2_leaf_reg': 15.715891222489793, 'scale_pos_weight': 0.9005939370066038}. Best is trial 23 with value: 0.791875.
# [I 2024-01-29 16:53:52,690] Trial 24 finished with value: 0.76 and parameters: {'depth': 5, 'learning_rate': 0.15580122663369084, 'random_strength': 1, 'bagging_temperature': 0.27640527648539515, 'l2_leaf_reg': 15.92977108864029, 'scale_pos_weight': 2.3047860086240446}. Best is trial 23 with value: 0.791875.
# [I 2024-01-29 16:53:54,080] Trial 25 finished with value: 0.785625 and parameters: {'depth': 4, 'learning_rate': 0.11016835060506638, 'random_strength': 1, 'bagging_temperature': 0.1014527983819708, 'l2_leaf_reg': 32.868498973709826, 'scale_pos_weight': 0.6989617516152971}. Best is trial 23 with value: 0.791875.
# [I 2024-01-29 16:53:54,895] Trial 26 finished with value: 0.7575 and parameters: {'depth': 5, 'learning_rate': 0.1487377141531163, 'random_strength': 3, 'bagging_temperature': 0.05654674573489889, 'l2_leaf_reg': 14.991237652036645, 'scale_pos_weight': 3.182855471166735}. Best is trial 23 with value: 0.791875.
# [I 2024-01-29 16:53:55,948] Trial 27 finished with value: 0.763125 and parameters: {'depth': 4, 'learning_rate': 0.1174225762511865, 'random_strength': 5, 'bagging_temperature': 0.16108466590861448, 'l2_leaf_reg': 27.925283825714494, 'scale_pos_weight': 1.9724388285220946}. Best is trial 23 with value: 0.791875.
# [I 2024-01-29 16:53:56,699] Trial 28 finished with value: 0.783125 and parameters: {'depth': 6, 'learning_rate': 0.17191512326525907, 'random_strength': 2, 'bagging_temperature': 0.23447575550552402, 'l2_leaf_reg': 37.18699257075793, 'scale_pos_weight': 0.8256594427478001}. Best is trial 23 with value: 0.791875.
# [I 2024-01-29 16:53:57,418] Trial 29 finished with value: 0.6625 and parameters: {'depth': 5, 'learning_rate': 0.11197252684458006, 'random_strength': 8, 'bagging_temperature': 0.13850590161872586, 'l2_leaf_reg': 13.319737623808289, 'scale_pos_weight': 0.15957002308730894}. Best is trial 23 with value: 0.791875.
# [I 2024-01-29 16:53:58,679] Trial 30 finished with value: 0.7575 and parameters: {'depth': 4, 'learning_rate': 0.07037903810193866, 'random_strength': 11, 'bagging_temperature': 0.020505639567573286, 'l2_leaf_reg': 6.540173464472755, 'scale_pos_weight': 2.861358096471011}. Best is trial 23 with value: 0.791875.
# [I 2024-01-29 16:53:59,784] Trial 31 finished with value: 0.7875 and parameters: {'depth': 5, 'learning_rate': 0.1351847955995141, 'random_strength': 4, 'bagging_temperature': 0.11371512432840121, 'l2_leaf_reg': 22.00893442869441, 'scale_pos_weight': 1.324617617244392}. Best is trial 23 with value: 0.791875.
# [I 2024-01-29 16:54:01,085] Trial 32 finished with value: 0.794375 and parameters: {'depth': 5, 'learning_rate': 0.1399062742695025, 'random_strength': 4, 'bagging_temperature': 0.14612557877929688, 'l2_leaf_reg': 20.198910968943945, 'scale_pos_weight': 0.9716924336010234}. Best is trial 32 with value: 0.794375.
# [I 2024-01-29 16:54:02,555] Trial 33 finished with value: 0.768125 and parameters: {'depth': 6, 'learning_rate': 0.10921439275077864, 'random_strength': 2, 'bagging_temperature': 0.1958637242402339, 'l2_leaf_reg': 28.25626896136234, 'scale_pos_weight': 2.1159081150000048}. Best is trial 32 with value: 0.794375.
# [I 2024-01-29 16:54:04,086] Trial 34 finished with value: 0.775 and parameters: {'depth': 4, 'learning_rate': 0.14835492899824285, 'random_strength': 8, 'bagging_temperature': 0.2751188479298692, 'l2_leaf_reg': 39.34155756594669, 'scale_pos_weight': 1.6207341669606627}. Best is trial 32 with value: 0.794375.
# [I 2024-01-29 16:54:05,274] Trial 35 finished with value: 0.78375 and parameters: {'depth': 5, 'learning_rate': 0.1039565926163086, 'random_strength': 5, 'bagging_temperature': 0.07275837853408178, 'l2_leaf_reg': 9.26039757870393, 'scale_pos_weight': 0.63787403267151}. Best is trial 32 with value: 0.794375.
# [I 2024-01-29 16:54:06,563] Trial 36 finished with value: 0.765625 and parameters: {'depth': 6, 'learning_rate': 0.08297596432414367, 'random_strength': 2, 'bagging_temperature': 0.1467209444309475, 'l2_leaf_reg': 17.59049234080972, 'scale_pos_weight': 2.165766539236114}. Best is trial 32 with value: 0.794375.
# [I 2024-01-29 16:54:07,772] Trial 37 finished with value: 0.7875 and parameters: {'depth': 5, 'learning_rate': 0.12797862231083101, 'random_strength': 17, 'bagging_temperature': 0.17337136984365814, 'l2_leaf_reg': 6.267816857282581, 'scale_pos_weight': 1.3522957651462475}. Best is trial 32 with value: 0.794375.
# [I 2024-01-29 16:54:09,778] Trial 38 finished with value: 0.76125 and parameters: {'depth': 6, 'learning_rate': 0.05428785929986836, 'random_strength': 7, 'bagging_temperature': 0.3395728217825914, 'l2_leaf_reg': 41.55498207043206, 'scale_pos_weight': 2.5895392260453227}. Best is trial 32 with value: 0.794375.
# [I 2024-01-29 16:54:13,112] Trial 39 finished with value: 0.790625 and parameters: {'depth': 4, 'learning_rate': 0.02962322533863336, 'random_strength': 5, 'bagging_temperature': 0.4046564414331526, 'l2_leaf_reg': 31.974811000513924, 'scale_pos_weight': 0.8254057915846688}. Best is trial 32 with value: 0.794375.
# [I 2024-01-29 16:54:16,429] Trial 40 finished with value: 0.770625 and parameters: {'depth': 4, 'learning_rate': 0.02905517815626253, 'random_strength': 3, 'bagging_temperature': 0.39228568396654645, 'l2_leaf_reg': 11.364927744948396, 'scale_pos_weight': 1.7847730479108852}. Best is trial 32 with value: 0.794375.
# [I 2024-01-29 16:54:18,802] Trial 41 finished with value: 0.79125 and parameters: {'depth': 4, 'learning_rate': 0.06608066700830859, 'random_strength': 5, 'bagging_temperature': 0.25129397511184676, 'l2_leaf_reg': 29.812001369517393, 'scale_pos_weight': 1.0092098864119845}. Best is trial 32 with value: 0.794375.
# [I 2024-01-29 16:54:22,176] Trial 42 finished with value: 0.784375 and parameters: {'depth': 4, 'learning_rate': 0.0372276907394211, 'random_strength': 5, 'bagging_temperature': 0.24544626437398526, 'l2_leaf_reg': 30.74866136225787, 'scale_pos_weight': 0.6697467392015419}. Best is trial 32 with value: 0.794375.
# [I 2024-01-29 16:54:24,325] Trial 43 finished with value: 0.758125 and parameters: {'depth': 4, 'learning_rate': 0.0642432994259749, 'random_strength': 7, 'bagging_temperature': 0.3148418587447069, 'l2_leaf_reg': 24.055848706410483, 'scale_pos_weight': 0.4055193213552635}. Best is trial 32 with value: 0.794375.
# [I 2024-01-29 16:54:27,936] Trial 44 finished with value: 0.790625 and parameters: {'depth': 4, 'learning_rate': 0.02929814764772413, 'random_strength': 6, 'bagging_temperature': 0.2572347699860243, 'l2_leaf_reg': 30.27196303935054, 'scale_pos_weight': 0.812054827054472}. Best is trial 32 with value: 0.794375.
# [I 2024-01-29 16:54:30,850] Trial 45 finished with value: 0.621875 and parameters: {'depth': 5, 'learning_rate': 0.01953857392520733, 'random_strength': 3, 'bagging_temperature': 0.39150029983548684, 'l2_leaf_reg': 19.55355736841992, 'scale_pos_weight': 0.1053423000143312}. Best is trial 32 with value: 0.794375.
# [I 2024-01-29 16:54:33,676] Trial 46 finished with value: 0.794375 and parameters: {'depth': 4, 'learning_rate': 0.047352728188742026, 'random_strength': 4, 'bagging_temperature': 0.3175104627809262, 'l2_leaf_reg': 25.586771749561503, 'scale_pos_weight': 0.9487005401382544}. Best is trial 32 with value: 0.794375.
# [I 2024-01-29 16:54:34,899] Trial 47 finished with value: 0.768125 and parameters: {'depth': 5, 'learning_rate': 0.09293591569753791, 'random_strength': 2, 'bagging_temperature': 0.31083581978550107, 'l2_leaf_reg': 24.675327717934127, 'scale_pos_weight': 1.8946875086719084}. Best is trial 32 with value: 0.794375.
# [I 2024-01-29 16:54:37,344] Trial 48 finished with value: 0.793125 and parameters: {'depth': 4, 'learning_rate': 0.0732183953109606, 'random_strength': 4, 'bagging_temperature': 0.2314786394668259, 'l2_leaf_reg': 11.366267785554571, 'scale_pos_weight': 1.1915068409587697}. Best is trial 32 with value: 0.794375.
# [I 2024-01-29 16:54:38,833] Trial 49 finished with value: 0.763125 and parameters: {'depth': 5, 'learning_rate': 0.08270492753976086, 'random_strength': 1, 'bagging_temperature': 0.20625115941691097, 'l2_leaf_reg': 12.543705543381705, 'scale_pos_weight': 2.433760034382266}. Best is trial 32 with value: 0.794375.
# [I 2024-01-29 16:54:39,876] Trial 50 finished with value: 0.775625 and parameters: {'depth': 4, 'learning_rate': 0.140755956689389, 'random_strength': 4, 'bagging_temperature': 0.07875005265095048, 'l2_leaf_reg': 3.2871369077534673, 'scale_pos_weight': 1.5027465992391462}. Best is trial 32 with value: 0.794375.
# [I 2024-01-29 16:54:41,912] Trial 51 finished with value: 0.791875 and parameters: {'depth': 4, 'learning_rate': 0.07622556498800957, 'random_strength': 4, 'bagging_temperature': 0.24399565382059563, 'l2_leaf_reg': 16.359769459141198, 'scale_pos_weight': 1.1453494420297976}. Best is trial 32 with value: 0.794375.
# [I 2024-01-29 16:54:44,567] Trial 52 finished with value: 0.79 and parameters: {'depth': 4, 'learning_rate': 0.054534610130317324, 'random_strength': 6, 'bagging_temperature': 0.17988855153548594, 'l2_leaf_reg': 8.20957191756304, 'scale_pos_weight': 1.1561621553903496}. Best is trial 32 with value: 0.794375.
# [I 2024-01-29 16:54:46,592] Trial 53 finished with value: 0.753125 and parameters: {'depth': 4, 'learning_rate': 0.09762321058432674, 'random_strength': 4, 'bagging_temperature': 0.29457301713571976, 'l2_leaf_reg': 15.717766744412664, 'scale_pos_weight': 0.3918902661688557}. Best is trial 32 with value: 0.794375.
# ...
# [I 2024-01-29 17:03:43,678] Trial 49 finished with value: 0.76875 and parameters: {'depth': 5, 'learning_rate': 0.15500020589053212, 'random_strength': 7, 'bagging_temperature': 0.6062516113773655, 'l2_leaf_reg': 94.9933329762051, 'scale_pos_weight': 1.3319397877017631}. Best is trial 35 with value: 0.784375.
# [I 2024-01-29 17:03:44,627] Trial 50 finished with value: 0.743125 and parameters: {'depth': 6, 'learning_rate': 0.18669724820077752, 'random_strength': 9, 'bagging_temperature': 0.5059375246733223, 'l2_leaf_reg': 68.54996204833361, 'scale_pos_weight': 2.225441952778123}. Best is trial 35 with value: 0.784375.
# [I 2024-01-29 17:03:45,671] Trial 51 finished with value: 0.776875 and parameters: {'depth': 4, 'learning_rate': 0.1703831456411631, 'random_strength': 6, 'bagging_temperature': 0.4815771492324445, 'l2_leaf_reg': 95.72755847673231, 'scale_pos_weight': 0.7402342029434051}. Best is trial 35 with value: 0.784375.
# [I 2024-01-29 17:03:46,723] Trial 52 finished with value: 0.77625 and parameters: {'depth': 4, 'learning_rate': 0.1458872358081205, 'random_strength': 5, 'bagging_temperature': 0.5401888439997476, 'l2_leaf_reg': 88.67303780983661, 'scale_pos_weight': 0.555485401559913}. Best is trial 35 with value: 0.784375.
# [I 2024-01-29 17:03:48,470] Trial 53 finished with value: 0.7775 and parameters: {'depth': 4, 'learning_rate': 0.16875978270903338, 'random_strength': 4, 'bagging_temperature': 0.4340044221262985, 'l2_leaf_reg': 96.40360677056515, 'scale_pos_weight': 1.158722343194403}. Best is trial 35 with value: 0.784375.
# [I 2024-01-29 17:03:49,458] Trial 54 finished with value: 0.763125 and parameters: {'depth': 5, 'learning_rate': 0.15463532150554307, 'random_strength': 3, 'bagging_temperature': 0.3974929181290367, 'l2_leaf_reg': 81.26897922352241, 'scale_pos_weight': 1.5807412448881895}. Best is trial 35 with value: 0.784375.
# [I 2024-01-29 17:03:51,235] Trial 55 finished with value: 0.7825 and parameters: {'depth': 4, 'learning_rate': 0.18255302067980816, 'random_strength': 8, 'bagging_temperature': 0.6036547483463363, 'l2_leaf_reg': 90.0340155714112, 'scale_pos_weight': 0.9279671865645962}. Best is trial 35 with value: 0.784375.
# [I 2024-01-29 17:03:52,197] Trial 56 finished with value: 0.775 and parameters: {'depth': 8, 'learning_rate': 0.19151947918850748, 'random_strength': 8, 'bagging_temperature': 0.6055119601221053, 'l2_leaf_reg': 85.44321466383096, 'scale_pos_weight': 1.0475314308086394}. Best is trial 35 with value: 0.784375.
# [I 2024-01-29 17:03:53,485] Trial 57 finished with value: 0.756875 and parameters: {'depth': 4, 'learning_rate': 0.17593587937482355, 'random_strength': 11, 'bagging_temperature': 0.6707951662971972, 'l2_leaf_reg': 96.33360251383094, 'scale_pos_weight': 1.8655692942895268}. Best is trial 35 with value: 0.784375.
# [I 2024-01-29 17:03:54,536] Trial 58 finished with value: 0.758125 and parameters: {'depth': 5, 'learning_rate': 0.13831520708464082, 'random_strength': 9, 'bagging_temperature': 0.5607745161119188, 'l2_leaf_reg': 92.92239774656439, 'scale_pos_weight': 0.3375603755626462}. Best is trial 35 with value: 0.784375.
# [I 2024-01-29 17:03:56,667] Trial 59 finished with value: 0.76875 and parameters: {'depth': 9, 'learning_rate': 0.18370754989540228, 'random_strength': 7, 'bagging_temperature': 0.6343178820889378, 'l2_leaf_reg': 78.01147567303988, 'scale_pos_weight': 1.1936822302774552}. Best is trial 35 with value: 0.784375.
# [I 2024-01-29 17:03:57,671] Trial 60 finished with value: 0.643125 and parameters: {'depth': 4, 'learning_rate': 0.14949718476994203, 'random_strength': 6, 'bagging_temperature': 0.7302208489538058, 'l2_leaf_reg': 96.75641583285841, 'scale_pos_weight': 0.10141048349798631}. Best is trial 35 with value: 0.784375.
# [I 2024-01-29 17:03:58,677] Trial 61 finished with value: 0.780625 and parameters: {'depth': 4, 'learning_rate': 0.16450211954254312, 'random_strength': 5, 'bagging_temperature': 0.4816848266955328, 'l2_leaf_reg': 90.02428598598722, 'scale_pos_weight': 0.6385736360199544}. Best is trial 35 with value: 0.784375.
# [I 2024-01-29 17:03:59,657] Trial 62 finished with value: 0.78 and parameters: {'depth': 4, 'learning_rate': 0.17644953690376955, 'random_strength': 2, 'bagging_temperature': 0.5165400529447717, 'l2_leaf_reg': 87.59674571267416, 'scale_pos_weight': 0.73998737458021}. Best is trial 35 with value: 0.784375.
# [I 2024-01-29 17:04:01,157] Trial 63 finished with value: 0.775 and parameters: {'depth': 5, 'learning_rate': 0.16020904430840407, 'random_strength': 4, 'bagging_temperature': 0.586211314971635, 'l2_leaf_reg': 98.40844905681979, 'scale_pos_weight': 0.9603183367578905}. Best is trial 35 with value: 0.784375.
# [I 2024-01-29 17:04:02,861] Trial 64 finished with value: 0.765 and parameters: {'depth': 4, 'learning_rate': 0.16776529722748548, 'random_strength': 3, 'bagging_temperature': 0.461791331923986, 'l2_leaf_reg': 91.02660839115481, 'scale_pos_weight': 1.5134399438549284}. Best is trial 35 with value: 0.784375.
# [I 2024-01-29 17:04:03,795] Trial 65 finished with value: 0.776875 and parameters: {'depth': 4, 'learning_rate': 0.19893343240719105, 'random_strength': 14, 'bagging_temperature': 0.5364395151500453, 'l2_leaf_reg': 86.6221752183532, 'scale_pos_weight': 0.4880593672168726}. Best is trial 35 with value: 0.784375.
# [I 2024-01-29 17:04:05,015] Trial 66 finished with value: 0.745 and parameters: {'depth': 6, 'learning_rate': 0.18033259734048693, 'random_strength': 6, 'bagging_temperature': 0.6595461558110765, 'l2_leaf_reg': 94.5314952129324, 'scale_pos_weight': 2.3062374183183065}. Best is trial 35 with value: 0.784375.
# [I 2024-01-29 17:04:06,051] Trial 67 finished with value: 0.734375 and parameters: {'depth': 5, 'learning_rate': 0.14932653461980488, 'random_strength': 11, 'bagging_temperature': 0.6118629915903874, 'l2_leaf_reg': 99.1639751989169, 'scale_pos_weight': 2.731918710307275}. Best is trial 35 with value: 0.784375.
# [I 2024-01-29 17:04:09,671] Trial 68 finished with value: 0.7725 and parameters: {'depth': 10, 'learning_rate': 0.12867357371836421, 'random_strength': 20, 'bagging_temperature': 0.501208996066752, 'l2_leaf_reg': 82.52918219703184, 'scale_pos_weight': 1.2476194654161588}. Best is trial 35 with value: 0.784375.
# [I 2024-01-29 17:04:10,985] Trial 69 finished with value: 0.774375 and parameters: {'depth': 7, 'learning_rate': 0.17347480163095902, 'random_strength': 1, 'bagging_temperature': 0.5653928251258776, 'l2_leaf_reg': 90.59038735049931, 'scale_pos_weight': 0.8748925210693819}. Best is trial 35 with value: 0.784375.
# [I 2024-01-29 17:04:12,304] Trial 70 finished with value: 0.75625 and parameters: {'depth': 4, 'learning_rate': 0.13884220364884553, 'random_strength': 8, 'bagging_temperature': 0.4337025199440698, 'l2_leaf_reg': 99.96379719548978, 'scale_pos_weight': 1.7287561295318976}. Best is trial 35 with value: 0.784375.
# [I 2024-01-29 17:04:13,439] Trial 71 finished with value: 0.7675 and parameters: {'depth': 4, 'learning_rate': 0.16294526629339817, 'random_strength': 5, 'bagging_temperature': 0.4794707914114297, 'l2_leaf_reg': 89.9798632207907, 'scale_pos_weight': 0.3776957045134433}. Best is trial 35 with value: 0.784375.
# [I 2024-01-29 17:04:14,790] Trial 72 finished with value: 0.77625 and parameters: {'depth': 4, 'learning_rate': 0.162198494066518, 'random_strength': 5, 'bagging_temperature': 0.5278622211630384, 'l2_leaf_reg': 93.86266871352079, 'scale_pos_weight': 0.6857381722246362}. Best is trial 35 with value: 0.784375.
# [I 2024-01-29 17:04:16,323] Trial 73 finished with value: 0.774375 and parameters: {'depth': 4, 'learning_rate': 0.15434281598340266, 'random_strength': 7, 'bagging_temperature': 0.47641521761430394, 'l2_leaf_reg': 85.89503578600356, 'scale_pos_weight': 0.9698861380685067}. Best is trial 35 with value: 0.784375.
# [I 2024-01-29 17:04:17,122] Trial 74 finished with value: 0.755625 and parameters: {'depth': 5, 'learning_rate': 0.18438459044217936, 'random_strength': 6, 'bagging_temperature': 0.5046110703609247, 'l2_leaf_reg': 96.98528318510512, 'scale_pos_weight': 0.32461618450303714}. Best is trial 35 with value: 0.784375.
# [I 2024-01-29 17:04:18,573] Trial 75 finished with value: 0.776875 and parameters: {'depth': 4, 'learning_rate': 0.19673039582850552, 'random_strength': 4, 'bagging_temperature': 0.5557689446659203, 'l2_leaf_reg': 89.84187262494505, 'scale_pos_weight': 1.3824490626140302}. Best is trial 35 with value: 0.784375.
# [I 2024-01-29 17:04:19,535] Trial 76 finished with value: 0.78125 and parameters: {'depth': 7, 'learning_rate': 0.16764845098990608, 'random_strength': 5, 'bagging_temperature': 0.6275463695415359, 'l2_leaf_reg': 59.00670548238892, 'scale_pos_weight': 0.7781656028112774}. Best is trial 35 with value: 0.784375.
# [I 2024-01-29 17:04:20,621] Trial 77 finished with value: 0.753125 and parameters: {'depth': 7, 'learning_rate': 0.17929378591293485, 'random_strength': 2, 'bagging_temperature': 0.703073956442448, 'l2_leaf_reg': 61.131590862995594, 'scale_pos_weight': 1.9611310905824881}. Best is trial 35 with value: 0.784375.
# [I 2024-01-29 17:04:21,711] Trial 78 finished with value: 0.76625 and parameters: {'depth': 7, 'learning_rate': 0.14254883775958455, 'random_strength': 3, 'bagging_temperature': 0.6328661774446465, 'l2_leaf_reg': 58.9312358288193, 'scale_pos_weight': 1.6001941129921158}. Best is trial 35 with value: 0.784375.
# [I 2024-01-29 17:04:22,686] Trial 79 finished with value: 0.775 and parameters: {'depth': 6, 'learning_rate': 0.17084873190920538, 'random_strength': 4, 'bagging_temperature': 0.5987736811124938, 'l2_leaf_reg': 93.62380232955451, 'scale_pos_weight': 1.1713328123146622}. Best is trial 35 with value: 0.784375.
# [I 2024-01-29 17:04:23,475] Trial 80 finished with value: 0.766875 and parameters: {'depth': 7, 'learning_rate': 0.2105048250346816, 'random_strength': 7, 'bagging_temperature': 0.6596271878988241, 'l2_leaf_reg': 79.55703994541896, 'scale_pos_weight': 0.3399307142104479}. Best is trial 35 with value: 0.784375.
# [I 2024-01-29 17:04:24,738] Trial 81 finished with value: 0.77875 and parameters: {'depth': 8, 'learning_rate': 0.16057736626081018, 'random_strength': 5, 'bagging_temperature': 0.5808258884429561, 'l2_leaf_reg': 87.40277372502054, 'scale_pos_weight': 0.8264390667946152}. Best is trial 35 with value: 0.784375.
# [I 2024-01-29 17:04:25,615] Trial 82 finished with value: 0.77625 and parameters: {'depth': 4, 'learning_rate': 0.16495760326007733, 'random_strength': 5, 'bagging_temperature': 0.4501202018959144, 'l2_leaf_reg': 91.82808512871848, 'scale_pos_weight': 0.623368928833636}. Best is trial 35 with value: 0.784375.
# [I 2024-01-29 17:04:26,460] Trial 83 finished with value: 0.78125 and parameters: {'depth': 5, 'learning_rate': 0.15320547710382404, 'random_strength': 6, 'bagging_temperature': 0.5214596257067462, 'l2_leaf_reg': 96.38513032253691, 'scale_pos_weight': 0.8513352593215047}. Best is trial 35 with value: 0.784375.
# [I 2024-01-29 17:04:27,923] Trial 84 finished with value: 0.773125 and parameters: {'depth': 5, 'learning_rate': 0.15063541808422298, 'random_strength': 6, 'bagging_temperature': 0.5323773879524493, 'l2_leaf_reg': 97.36376518807072, 'scale_pos_weight': 1.253290480937482}. Best is trial 35 with value: 0.784375.
# [I 2024-01-29 17:04:28,755] Trial 85 finished with value: 0.78375 and parameters: {'depth': 6, 'learning_rate': 0.1905089414347856, 'random_strength': 4, 'bagging_temperature': 0.6199498223817519, 'l2_leaf_reg': 95.22219069445572, 'scale_pos_weight': 0.9347546418223387}. Best is trial 35 with value: 0.784375.
# [I 2024-01-29 17:04:29,573] Trial 86 finished with value: 0.775 and parameters: {'depth': 6, 'learning_rate': 0.1878642522124801, 'random_strength': 8, 'bagging_temperature': 0.6211399460593475, 'l2_leaf_reg': 94.69020390993497, 'scale_pos_weight': 0.9420624015397113}. Best is trial 35 with value: 0.784375.
# [I 2024-01-29 17:04:30,451] Trial 87 finished with value: 0.76375 and parameters: {'depth': 6, 'learning_rate': 0.17994909897488057, 'random_strength': 7, 'bagging_temperature': 0.5876131303850151, 'l2_leaf_reg': 83.91247871288651, 'scale_pos_weight': 1.424544434219335}. Best is trial 35 with value: 0.784375.
# [I 2024-01-29 17:04:31,386] Trial 88 finished with value: 0.753125 and parameters: {'depth': 6, 'learning_rate': 0.157779510124322, 'random_strength': 3, 'bagging_temperature': 0.6793190153763913, 'l2_leaf_reg': 99.98947331369003, 'scale_pos_weight': 0.2965572566958554}. Best is trial 35 with value: 0.784375.
# [I 2024-01-29 17:04:32,281] Trial 89 finished with value: 0.75125 and parameters: {'depth': 7, 'learning_rate': 0.19654022542495397, 'random_strength': 6, 'bagging_temperature': 0.6526737714358809, 'l2_leaf_reg': 96.95065127617485, 'scale_pos_weight': 2.0314681985401255}. Best is trial 35 with value: 0.784375.
# [I 2024-01-29 17:04:33,067] Trial 90 finished with value: 0.660625 and parameters: {'depth': 7, 'learning_rate': 0.17151754563096436, 'random_strength': 2, 'bagging_temperature': 0.6146544958696403, 'l2_leaf_reg': 92.69406524890947, 'scale_pos_weight': 0.11324044057200078}. Best is trial 35 with value: 0.784375.
# [I 2024-01-29 17:04:34,193] Trial 91 finished with value: 0.78125 and parameters: {'depth': 5, 'learning_rate': 0.14408067859598142, 'random_strength': 4, 'bagging_temperature': 0.5645434665248766, 'l2_leaf_reg': 88.65759138511272, 'scale_pos_weight': 0.5820979240859052}. Best is trial 35 with value: 0.784375.
# [I 2024-01-29 17:04:35,150] Trial 92 finished with value: 0.7825 and parameters: {'depth': 5, 'learning_rate': 0.14490202329203658, 'random_strength': 4, 'bagging_temperature': 0.5674354698515212, 'l2_leaf_reg': 92.51445965350135, 'scale_pos_weight': 0.5193655192861684}. Best is trial 35 with value: 0.784375.
# [I 2024-01-29 17:04:36,217] Trial 93 finished with value: 0.771875 and parameters: {'depth': 5, 'learning_rate': 0.14328219211671736, 'random_strength': 4, 'bagging_temperature': 0.5505916416096756, 'l2_leaf_reg': 85.71052448454745, 'scale_pos_weight': 0.44610409924635686}. Best is trial 35 with value: 0.784375.
# [I 2024-01-29 17:04:37,473] Trial 94 finished with value: 0.780625 and parameters: {'depth': 5, 'learning_rate': 0.13329272651416565, 'random_strength': 4, 'bagging_temperature': 0.5723523745000313, 'l2_leaf_reg': 95.08050383224469, 'scale_pos_weight': 0.6040570114463955}. Best is trial 35 with value: 0.784375.
# [I 2024-01-29 17:04:38,675] Trial 95 finished with value: 0.78375 and parameters: {'depth': 5, 'learning_rate': 0.14886181705069115, 'random_strength': 5, 'bagging_temperature': 0.5163624500757322, 'l2_leaf_reg': 88.35627342893018, 'scale_pos_weight': 0.8784052305600848}. Best is trial 35 with value: 0.784375.
# [I 2024-01-29 17:04:39,642] Trial 96 finished with value: 0.77125 and parameters: {'depth': 5, 'learning_rate': 0.1579185667782531, 'random_strength': 5, 'bagging_temperature': 0.5297868069424087, 'l2_leaf_reg': 92.98887699426922, 'scale_pos_weight': 1.0879598227353482}. Best is trial 35 with value: 0.784375.
# [I 2024-01-29 17:04:40,912] Trial 97 finished with value: 0.781875 and parameters: {'depth': 5, 'learning_rate': 0.14922679446459097, 'random_strength': 5, 'bagging_temperature': 0.5030643746762278, 'l2_leaf_reg': 83.24512766949502, 'scale_pos_weight': 0.8435101736405706}. Best is trial 35 with value: 0.784375.
# [I 2024-01-29 17:04:42,334] Trial 98 finished with value: 0.759375 and parameters: {'depth': 6, 'learning_rate': 0.12631993321652962, 'random_strength': 3, 'bagging_temperature': 0.5968613338706864, 'l2_leaf_reg': 83.1249819389187, 'scale_pos_weight': 1.6421701383144067}. Best is trial 35 with value: 0.784375.
# [I 2024-01-29 17:04:43,629] Trial 99 finished with value: 0.7725 and parameters: {'depth': 5, 'learning_rate': 0.14009697794721804, 'random_strength': 5, 'bagging_temperature': 0.49542052920040885, 'l2_leaf_reg': 86.91297041187983, 'scale_pos_weight': 1.369846101853149}. Best is trial 35 with value: 0.784375.

# %% [markdown]
# - Catboost平均スコア

# %%
# 全フォールドの平均スコアを計算
cb_average_score = sum(cb_fold_scores) / n_splits
print(f"CatBoost Average accuracy across all folds: {cb_average_score}")

cb_average_conf = sum(cb_conf_scores) / n_splits
print(f"CatBoost Average conf-matrix across all folds: {cb_average_conf}")
# Out:
# CatBoost Average accuracy across all folds: 0.7831249999999998
# CatBoost Average conf-matrix across all folds: [[653.6 159.6]
#  [187.4 599.4]]

# %% [markdown]
# - CB_予測平均

# %%
# 予測の平均を計算
cb_y_test_pred_avg = np.mean(cb_test_predictions, axis=0)

# 最終的な予測結果を整数に変換
cb_y_test_pred_int = (cb_y_test_pred_avg > cb_threshold).astype(int)

# %% [markdown]
# - output

# %%
# 現在の日時を取得してフォーマットする
current_time = datetime.now().strftime("%Y%m%d_%H%M%S")
output = f'../data/output/{current_time}_CatBoost_cv{cb_average_score:.4f}.csv'

submit = pd.DataFrame({
    '0': test['gameId'],
    '1': cb_y_test_pred_int
})

# カラムヘッダー消去して出力
# ヘッダーなしでCSVファイルとして保存
submit.to_csv(output, header=False, index=False)

# %%
submit
# Out:
#          0  1
# 0        9  1
# 1       15  1
# 2       18  0
# 3       23  0
# 4       31  0
# ...    ... ..
# 1995  9971  0
# 1996  9980  0
# 1997  9983  1
# 1998  9996  1
# 1999  9999  0
#
# [2000 rows x 2 columns]

# %% [markdown]
# # 合成

# %% [markdown]
# - 予測リストに追加

# %%
# 予測結果をNumPy配列に変換
cb_predictions = np.array(cb_y_test_pred_int)  # CatBoostの予測結果
lgb_predictions = np.array(lgb_y_test_pred_int)  # LightGBMの予測結果
xgb_predictions = np.array(xgb_y_test_pred_int)  # XGBoostの予測結果

# 3つのモデルの予測結果を組み合わせる
combined_predictions = np.vstack((cb_predictions, lgb_predictions, xgb_predictions))

# 多数決で最終的な予測を決定（行方向に合計し、1.5より大きい場合は1とする）
final_predictions = np.mean(combined_predictions, axis=0) > 0.5
final_predictions = final_predictions.astype(int)

# 最終的な予測をCSVファイルに保存
merge_submit = pd.DataFrame({
    '0': test['gameId'],  # 適切なID列を使用
    '1': final_predictions
})
merge_submit.to_csv(f'../data/output/{current_time}_final_predictions.csv', index=False)

# %%
merge_submit
# Out:
#          0  1
# 0        9  1
# 1       15  1
# 2       18  0
# 3       23  0
# 4       31  1
# ...    ... ..
# 1995  9971  0
# 1996  9980  0
# 1997  9983  1
# 1998  9996  1
# 1999  9999  0
#
# [2000 rows x 2 columns]

# %% [markdown]
# #

# %% [markdown]
# # Logistic classifier
