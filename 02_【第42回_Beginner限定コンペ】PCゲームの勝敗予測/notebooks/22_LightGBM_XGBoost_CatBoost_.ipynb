# %% [markdown]
# # Library

# %%
import pandas as pd
import numpy as np

import optuna
import xgboost as xgb
import lightgbm as lgb
import catboost as cb

from datetime import datetime
from sklearn.model_selection import train_test_split, KFold
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# # Data Loading

# %%
train = pd.read_csv('../data/train.csv')
test = pd.read_csv('../data/test.csv')

# %% [markdown]
# # Add New Feature

# %%
def add_features(df):
    df['assistRate'] = df['blueAssists'] / (df['blueKills'] + 1)
    df['blueHerald'] = (df['blueEliteMonsters'] - df['blueDragons']).clip(lower=0)
    df['eliteMonsterDragonRatio'] = df['blueEliteMonsters'] / (df['blueDragons'] + 1)
    df['logTotalGold'] = np.log1p(df['blueTotalGold'])
    df['logTotalExperience'] = np.log1p(df['blueTotalExperience'])
    df['firstBloodKillRatio'] = df['blueFirstBlood'] * df['blueKills']
    df['totalCombatPoints'] = df['blueKills'] + df['blueDeaths'] + df['blueAssists']

    total_combat_actions = df['blueKills'] + df['blueDeaths'] + df['blueAssists']
    df['killRatio'] = df['blueKills'] / total_combat_actions
    df['deathRatio'] = df['blueDeaths'] / total_combat_actions
    df['assistRatio'] = df['blueAssists'] / total_combat_actions

    df['teamStrength'] = df['blueKills'] + df['blueAssists'] + df['blueEliteMonsters']
    df['dragonKillImpact'] = df['blueDragons'] / (df['blueKills'] + 1)
    df['eliteMonsterUtilization'] = df['blueEliteMonsters'] / (df['blueKills'] + df['blueAssists'] + 1)
    df['goldExperienceRatio'] = df['blueTotalGold'] / (df['blueTotalExperience'] + 1)
    df['teamEfficiency'] = (df['blueKills'] + df['blueAssists'] + df['blueEliteMonsters']) / (df['blueDeaths'] + 1)
    df['killToMonsterRatio'] = df['blueKills'] / (df['blueEliteMonsters'] + 1)
    df['avgGoldPerKill'] = df['blueTotalGold'] / (df['blueKills'] + 1)
    df['expToKillRatio'] = df['blueTotalExperience'] / (df['blueKills'] + 1)
    df['killsMinusDeaths'] = df['blueKills'] - df['blueDeaths']
    df['killDeathRatio'] = df['blueKills'] / (df['blueKills'] + df['blueDeaths'])
    df['avgExperiencePerKill'] = df['blueTotalExperience'] / (df['blueKills'] + 1)
    df['killDeathDiff'] = (df['blueKills'] - df['blueDeaths']).clip(lower=0)
    df['eliteMonsterHeraldRatio'] = df['blueEliteMonsters'] / (df['blueHerald'] + 1)
    df['goldXexperience'] = np.log1p(df['blueTotalGold'] * df['blueTotalExperience'])
    df['goldPerKill'] = df['blueTotalGold'] / (df['blueKills'] + 1)  # ゼロ除算を防ぐために+1
    df['experiencePerKill'] = df['blueTotalExperience'] / (df['blueKills'] + 1)  # ゼロ除算を防ぐために+1
    df['eliteMonstersPerGold'] = df['blueEliteMonsters'] / df['blueTotalGold']
    df['eliteMonstersPerExperience'] = df['blueEliteMonsters'] / df['blueTotalExperience']

    
    return df

# %% [markdown]
# - apply

# %%
train = add_features(train)
test = add_features(test)

# %% [markdown]
# # Data

# %%
# データの準備
X = train.drop(['blueWins', 'gameId'], axis=1)
y = train['blueWins']
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2, random_state=0)

test_drop_gameId = test.drop('gameId', axis=1)

# test_drop_gameId_temp = test.drop('gameId', axis=1)

# # 特徴量の標準化
# scaler = StandardScaler()
# X_train = scaler.fit_transform(X_train)
# X_val = scaler.transform(X_val)  # 検証データも同じスケーラーを使用して標準化

# # テストデータも同じスケーラーを使用して標準化
# test_drop_gameId_scaled = scaler.transform(test_drop_gameId_temp)

# # NumPy配列からPandasデータフレームに変換
# X_train = pd.DataFrame(X_train, columns=X.columns)
# X_val = pd.DataFrame(X_val, columns=X.columns)
# test_drop_gameId = pd.DataFrame(test_drop_gameId_scaled, columns=test_drop_gameId_temp.columns)

# %% [markdown]
# # Model

# %% [markdown]
# - variable

# %%
n_splits = 5
kf = KFold(n_splits=n_splits, shuffle=True)

# 各フォールドでのスコアを保存するリスト
lgb_fold_scores = []
xgb_fold_scores = []
cb_fold_scores = []

# testを保存するリスト
lgb_test_predictions = []
xgb_test_predictions = []
cb_test_predictions = []

# %% [markdown]
# ## LightGBM

# %%
for train_index, val_index in kf.split(X):
    X_train_fold, X_val_fold = X.iloc[train_index], X.iloc[val_index]
    y_train_fold, y_val_fold = y[train_index], y[val_index]

    # LightGBMではDMatrixの代わりに普通のデータフレームを使用します
    train_data = lgb.Dataset(X_train_fold, label=y_train_fold)
    val_data = lgb.Dataset(X_val_fold, label=y_val_fold, reference=train_data)

    # Optunaでのハイパーパラメータチューニング
    def objective(trial):
        param = {
            'objective': 'binary',
            'metric': 'binary_logloss',
            'verbosity': -1,
            'boosting_type': 'gbdt',
            'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
            'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
            'num_leaves': trial.suggest_int('num_leaves', 2, 256),
            'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
            'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
            'bagging_freq': trial.suggest_int('bagging_freq', 1, 7),
            'min_child_samples': trial.suggest_int('min_child_samples', 5, 100),
            'feature_pre_filter': False,  # 特徴量の事前フィルタリングを無効化
            'min_data_in_leaf': trial.suggest_int('min_data_in_leaf', 20, 100),  # Optunaでこの値を調整する
        }

        callbacks = lgb.early_stopping(stopping_rounds=50, verbose=False)
        gbm = lgb.train(param, train_data, valid_sets=[val_data], num_boost_round=1000, callbacks=[callbacks])
        preds = gbm.predict(X_val_fold, num_iteration=gbm.best_iteration)
        pred_labels = np.rint(preds)
        accuracy = accuracy_score(y_val_fold, pred_labels)
        return accuracy

    lgb_study = optuna.create_study(direction='maximize')
    lgb_study.optimize(objective, n_trials=100)

    # 各フォールドの最適パラメータでモデルを再学習
    lgb_best_params = lgb_study.best_params
    lgb_best_params['objective'] = 'binary'
    lgb_best_params['metric'] = 'binary_logloss'
    lgb_best_params['verbosity'] = -1

    lgb_final = lgb.train(lgb_best_params, train_data, num_boost_round=lgb_study.best_trial.number)

    # 各フォールドのモデル性能を評価
    lgb_y_val_pred = lgb_final.predict(X_val_fold, num_iteration=lgb_final.best_iteration)
    lgb_y_val_pred_int = np.rint(lgb_y_val_pred)
    lgb_fold_accuracy = accuracy_score(y_val_fold, lgb_y_val_pred_int)
    lgb_fold_scores.append(lgb_fold_accuracy)

    # テストデータセットでの予測
    lgb_y_test_pred_fold = lgb_final.predict(test_drop_gameId, num_iteration=lgb_final.best_iteration)
    lgb_test_predictions.append(lgb_y_test_pred_fold)
# Out:
# [I 2024-01-28 14:26:27,659] A new study created in memory with name: no-name-ef82b6aa-f783-43d7-8ebd-620edcee4bd2
# /tmp/ipykernel_32646/1351893647.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_32646/1351893647.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# /tmp/ipykernel_32646/1351893647.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# /tmp/ipykernel_32646/1351893647.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-28 14:26:28,359] Trial 0 finished with value: 0.78875 and parameters: {'lambda_l1': 0.0014194227825995967, 'lambda_l2': 0.03218185766562547, 'num_leaves': 209, 'feature_fraction': 0.6366522743389558, 'bagging_fraction': 0.5447145607669205, 'bagging_freq': 4, 'min_child_samples': 15, 'min_data_in_leaf': 70}. Best is trial 0 with value: 0.78875.
# /tmp/ipykernel_32646/1351893647.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_32646/1351893647.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# /tmp/ipykernel_32646/1351893647.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# /tmp/ipykernel_32646/1351893647.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-28 14:26:28,976] Trial 1 finished with value: 0.79125 and parameters: {'lambda_l1': 7.6178947776125416e-06, 'lambda_l2': 1.1818039992231066, 'num_leaves': 37, 'feature_fraction': 0.549533278081445, 'bagging_fraction': 0.5825463572915152, 'bagging_freq': 2, 'min_child_samples': 8, 'min_data_in_leaf': 67}. Best is trial 1 with value: 0.79125.
# /tmp/ipykernel_32646/1351893647.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_32646/1351893647.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# /tmp/ipykernel_32646/1351893647.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# /tmp/ipykernel_32646/1351893647.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-28 14:26:30,729] Trial 2 finished with value: 0.786875 and parameters: {'lambda_l1': 4.256262758938912e-07, 'lambda_l2': 2.0708950391459156, 'num_leaves': 147, 'feature_fraction': 0.8885908042962666, 'bagging_fraction': 0.7464011034356506, 'bagging_freq': 3, 'min_child_samples': 51, 'min_data_in_leaf': 96}. Best is trial 1 with value: 0.79125.
# /tmp/ipykernel_32646/1351893647.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_32646/1351893647.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# /tmp/ipykernel_32646/1351893647.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# /tmp/ipykernel_32646/1351893647.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-28 14:26:31,205] Trial 3 finished with value: 0.785 and parameters: {'lambda_l1': 0.00011918962558518184, 'lambda_l2': 1.1839988041051908, 'num_leaves': 254, 'feature_fraction': 0.6850063885166251, 'bagging_fraction': 0.9880533817160563, 'bagging_freq': 1, 'min_child_samples': 45, 'min_data_in_leaf': 23}. Best is trial 1 with value: 0.79125.
# /tmp/ipykernel_32646/1351893647.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_32646/1351893647.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# /tmp/ipykernel_32646/1351893647.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# /tmp/ipykernel_32646/1351893647.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-28 14:26:31,405] Trial 4 finished with value: 0.7875 and parameters: {'lambda_l1': 0.0004542962431377664, 'lambda_l2': 2.0763164516410674e-08, 'num_leaves': 45, 'feature_fraction': 0.8167911022301235, 'bagging_fraction': 0.9871714180108254, 'bagging_freq': 1, 'min_child_samples': 90, 'min_data_in_leaf': 70}. Best is trial 1 with value: 0.79125.
# /tmp/ipykernel_32646/1351893647.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_32646/1351893647.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# /tmp/ipykernel_32646/1351893647.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# /tmp/ipykernel_32646/1351893647.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-28 14:26:31,557] Trial 5 finished with value: 0.786875 and parameters: {'lambda_l1': 0.11317601650257854, 'lambda_l2': 7.556941945165994e-08, 'num_leaves': 140, 'feature_fraction': 0.5194985860319484, 'bagging_fraction': 0.5005578793477343, 'bagging_freq': 5, 'min_child_samples': 74, 'min_data_in_leaf': 63}. Best is trial 1 with value: 0.79125.
# /tmp/ipykernel_32646/1351893647.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_32646/1351893647.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# /tmp/ipykernel_32646/1351893647.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# /tmp/ipykernel_32646/1351893647.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-28 14:26:31,910] Trial 6 finished with value: 0.79125 and parameters: {'lambda_l1': 7.22444192209859e-06, 'lambda_l2': 7.200140559949784e-08, 'num_leaves': 251, 'feature_fraction': 0.6755469477249084, 'bagging_fraction': 0.6139934565304411, 'bagging_freq': 2, 'min_child_samples': 98, 'min_data_in_leaf': 30}. Best is trial 1 with value: 0.79125.
# /tmp/ipykernel_32646/1351893647.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_32646/1351893647.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# /tmp/ipykernel_32646/1351893647.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# /tmp/ipykernel_32646/1351893647.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-28 14:26:32,092] Trial 7 finished with value: 0.784375 and parameters: {'lambda_l1': 0.015660504056856674, 'lambda_l2': 8.089244603993583, 'num_leaves': 49, 'feature_fraction': 0.5973676545689922, 'bagging_fraction': 0.7014087283189577, 'bagging_freq': 1, 'min_child_samples': 28, 'min_data_in_leaf': 97}. Best is trial 1 with value: 0.79125.
# /tmp/ipykernel_32646/1351893647.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_32646/1351893647.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# /tmp/ipykernel_32646/1351893647.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# /tmp/ipykernel_32646/1351893647.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-28 14:26:32,438] Trial 8 finished with value: 0.79 and parameters: {'lambda_l1': 5.110285092366298, 'lambda_l2': 1.4319838122052997, 'num_leaves': 108, 'feature_fraction': 0.516684805837514, 'bagging_fraction': 0.8883654783481879, 'bagging_freq': 7, 'min_child_samples': 39, 'min_data_in_leaf': 53}. Best is trial 1 with value: 0.79125.
# /tmp/ipykernel_32646/1351893647.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_32646/1351893647.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# /tmp/ipykernel_32646/1351893647.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# /tmp/ipykernel_32646/1351893647.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-28 14:26:32,791] Trial 9 finished with value: 0.789375 and parameters: {'lambda_l1': 5.727550614539207e-06, 'lambda_l2': 0.0017724643165648916, 'num_leaves': 122, 'feature_fraction': 0.5488421320325981, 'bagging_fraction': 0.9560486634754406, 'bagging_freq': 1, 'min_child_samples': 80, 'min_data_in_leaf': 35}. Best is trial 1 with value: 0.79125.
# /tmp/ipykernel_32646/1351893647.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_32646/1351893647.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# /tmp/ipykernel_32646/1351893647.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# /tmp/ipykernel_32646/1351893647.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-28 14:26:32,903] Trial 10 finished with value: 0.794375 and parameters: {'lambda_l1': 2.4252448573467366e-08, 'lambda_l2': 2.1508317026620438e-05, 'num_leaves': 12, 'feature_fraction': 0.40288747425141863, 'bagging_fraction': 0.40230431603255257, 'bagging_freq': 5, 'min_child_samples': 6, 'min_data_in_leaf': 80}. Best is trial 10 with value: 0.794375.
# /tmp/ipykernel_32646/1351893647.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_32646/1351893647.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# /tmp/ipykernel_32646/1351893647.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# /tmp/ipykernel_32646/1351893647.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-28 14:26:33,018] Trial 11 finished with value: 0.790625 and parameters: {'lambda_l1': 1.0518565587837259e-08, 'lambda_l2': 2.3142147563718724e-05, 'num_leaves': 7, 'feature_fraction': 0.40637324642013517, 'bagging_fraction': 0.40625814060051635, 'bagging_freq': 6, 'min_child_samples': 10, 'min_data_in_leaf': 82}. Best is trial 10 with value: 0.794375.
# /tmp/ipykernel_32646/1351893647.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_32646/1351893647.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# /tmp/ipykernel_32646/1351893647.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# /tmp/ipykernel_32646/1351893647.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-28 14:26:33,193] Trial 12 finished with value: 0.78875 and parameters: {'lambda_l1': 2.0797661700348046e-08, 'lambda_l2': 1.3828734424780154e-05, 'num_leaves': 10, 'feature_fraction': 0.40244243888550174, 'bagging_fraction': 0.400163655807774, 'bagging_freq': 4, 'min_child_samples': 24, 'min_data_in_leaf': 81}. Best is trial 10 with value: 0.794375.
# /tmp/ipykernel_32646/1351893647.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_32646/1351893647.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# /tmp/ipykernel_32646/1351893647.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# /tmp/ipykernel_32646/1351893647.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-28 14:26:33,443] Trial 13 finished with value: 0.7875 and parameters: {'lambda_l1': 3.402583461017631e-07, 'lambda_l2': 6.519558365137128e-06, 'num_leaves': 68, 'feature_fraction': 0.47431112231980727, 'bagging_fraction': 0.5961697239859833, 'bagging_freq': 3, 'min_child_samples': 9, 'min_data_in_leaf': 50}. Best is trial 10 with value: 0.794375.
# /tmp/ipykernel_32646/1351893647.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_32646/1351893647.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# /tmp/ipykernel_32646/1351893647.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# /tmp/ipykernel_32646/1351893647.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-28 14:26:33,722] Trial 14 finished with value: 0.788125 and parameters: {'lambda_l1': 4.344638900232488e-07, 'lambda_l2': 0.0024286698603614852, 'num_leaves': 83, 'feature_fraction': 0.76626280211435, 'bagging_fraction': 0.8083363318871162, 'bagging_freq': 5, 'min_child_samples': 29, 'min_data_in_leaf': 81}. Best is trial 10 with value: 0.794375.
# /tmp/ipykernel_32646/1351893647.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_32646/1351893647.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# /tmp/ipykernel_32646/1351893647.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# /tmp/ipykernel_32646/1351893647.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-28 14:26:34,581] Trial 15 finished with value: 0.790625 and parameters: {'lambda_l1': 2.1182744877362737e-05, 'lambda_l2': 0.021756253813072043, 'num_leaves': 34, 'feature_fraction': 0.45711134906932527, 'bagging_fraction': 0.48460709534467905, 'bagging_freq': 3, 'min_child_samples': 63, 'min_data_in_leaf': 44}. Best is trial 10 with value: 0.794375.
# /tmp/ipykernel_32646/1351893647.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_32646/1351893647.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# /tmp/ipykernel_32646/1351893647.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# /tmp/ipykernel_32646/1351893647.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-28 14:26:34,855] Trial 16 finished with value: 0.786875 and parameters: {'lambda_l1': 1.271395254350762e-07, 'lambda_l2': 1.1122722255970842e-06, 'num_leaves': 176, 'feature_fraction': 0.964735613827195, 'bagging_fraction': 0.616836585000185, 'bagging_freq': 5, 'min_child_samples': 5, 'min_data_in_leaf': 69}. Best is trial 10 with value: 0.794375.
# /tmp/ipykernel_32646/1351893647.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_32646/1351893647.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# /tmp/ipykernel_32646/1351893647.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# /tmp/ipykernel_32646/1351893647.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-28 14:26:35,053] Trial 17 finished with value: 0.788125 and parameters: {'lambda_l1': 4.440981719269866e-06, 'lambda_l2': 0.00014623672127934577, 'num_leaves': 87, 'feature_fraction': 0.5940050256866187, 'bagging_fraction': 0.4817406745232389, 'bagging_freq': 7, 'min_child_samples': 18, 'min_data_in_leaf': 88}. Best is trial 10 with value: 0.794375.
# /tmp/ipykernel_32646/1351893647.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_32646/1351893647.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# /tmp/ipykernel_32646/1351893647.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# /tmp/ipykernel_32646/1351893647.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-28 14:26:35,274] Trial 18 finished with value: 0.788125 and parameters: {'lambda_l1': 6.526647130884257e-08, 'lambda_l2': 0.05752008511414607, 'num_leaves': 4, 'feature_fraction': 0.4614904627114158, 'bagging_fraction': 0.690003129904997, 'bagging_freq': 2, 'min_child_samples': 36, 'min_data_in_leaf': 62}. Best is trial 10 with value: 0.794375.
# /tmp/ipykernel_32646/1351893647.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_32646/1351893647.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# /tmp/ipykernel_32646/1351893647.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# /tmp/ipykernel_32646/1351893647.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-28 14:26:35,510] Trial 19 finished with value: 0.798125 and parameters: {'lambda_l1': 0.005179322856835333, 'lambda_l2': 0.0002960481079170693, 'num_leaves': 63, 'feature_fraction': 0.741236380153925, 'bagging_fraction': 0.5691764606225319, 'bagging_freq': 6, 'min_child_samples': 59, 'min_data_in_leaf': 74}. Best is trial 19 with value: 0.798125.
# /tmp/ipykernel_32646/1351893647.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_32646/1351893647.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# /tmp/ipykernel_32646/1351893647.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# /tmp/ipykernel_32646/1351893647.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-28 14:26:35,711] Trial 20 finished with value: 0.79375 and parameters: {'lambda_l1': 0.013998629994375136, 'lambda_l2': 0.0002044605750938544, 'num_leaves': 67, 'feature_fraction': 0.751807755927921, 'bagging_fraction': 0.45549153817444066, 'bagging_freq': 6, 'min_child_samples': 70, 'min_data_in_leaf': 88}. Best is trial 19 with value: 0.798125.
# /tmp/ipykernel_32646/1351893647.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_32646/1351893647.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# /tmp/ipykernel_32646/1351893647.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# /tmp/ipykernel_32646/1351893647.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-28 14:26:36,096] Trial 21 finished with value: 0.786875 and parameters: {'lambda_l1': 0.011713738756998831, 'lambda_l2': 0.00025014998736500727, 'num_leaves': 64, 'feature_fraction': 0.7619973932054322, 'bagging_fraction': 0.452410554537912, 'bagging_freq': 6, 'min_child_samples': 57, 'min_data_in_leaf': 90}. Best is trial 19 with value: 0.798125.
# /tmp/ipykernel_32646/1351893647.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_32646/1351893647.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# /tmp/ipykernel_32646/1351893647.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# /tmp/ipykernel_32646/1351893647.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-28 14:26:36,346] Trial 22 finished with value: 0.789375 and parameters: {'lambda_l1': 0.012795103508876627, 'lambda_l2': 1.1604962687941274e-06, 'num_leaves': 94, 'feature_fraction': 0.7475961049765871, 'bagging_fraction': 0.536880041071034, 'bagging_freq': 6, 'min_child_samples': 68, 'min_data_in_leaf': 77}. Best is trial 19 with value: 0.798125.
# /tmp/ipykernel_32646/1351893647.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_32646/1351893647.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# /tmp/ipykernel_32646/1351893647.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# /tmp/ipykernel_32646/1351893647.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-28 14:26:36,654] Trial 23 finished with value: 0.783125 and parameters: {'lambda_l1': 0.07483924546593468, 'lambda_l2': 7.69026255586245e-05, 'num_leaves': 64, 'feature_fraction': 0.8458953906776908, 'bagging_fraction': 0.45096378265467413, 'bagging_freq': 6, 'min_child_samples': 80, 'min_data_in_leaf': 89}. Best is trial 19 with value: 0.798125.
# /tmp/ipykernel_32646/1351893647.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_32646/1351893647.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# /tmp/ipykernel_32646/1351893647.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# /tmp/ipykernel_32646/1351893647.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-28 14:26:36,844] Trial 24 finished with value: 0.783125 and parameters: {'lambda_l1': 2.466376251998885, 'lambda_l2': 0.0009712920910651345, 'num_leaves': 32, 'feature_fraction': 0.7094856691275432, 'bagging_fraction': 0.537401449514691, 'bagging_freq': 7, 'min_child_samples': 58, 'min_data_in_leaf': 100}. Best is trial 19 with value: 0.798125.
# /tmp/ipykernel_32646/1351893647.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_32646/1351893647.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# /tmp/ipykernel_32646/1351893647.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# /tmp/ipykernel_32646/1351893647.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-28 14:26:36,999] Trial 25 finished with value: 0.79125 and parameters: {'lambda_l1': 0.5188711192378525, 'lambda_l2': 1.6054427358268338e-06, 'num_leaves': 112, 'feature_fraction': 0.9146168186527754, 'bagging_fraction': 0.43368291757543337, 'bagging_freq': 5, 'min_child_samples': 48, 'min_data_in_leaf': 75}. Best is trial 19 with value: 0.798125.
# /tmp/ipykernel_32646/1351893647.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_32646/1351893647.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# /tmp/ipykernel_32646/1351893647.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# /tmp/ipykernel_32646/1351893647.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-28 14:26:37,254] Trial 26 finished with value: 0.79 and parameters: {'lambda_l1': 0.0018805283528274157, 'lambda_l2': 0.007381104781247946, 'num_leaves': 27, 'feature_fraction': 0.8141701169484643, 'bagging_fraction': 0.6691720894775876, 'bagging_freq': 6, 'min_child_samples': 66, 'min_data_in_leaf': 86}. Best is trial 19 with value: 0.798125.
# /tmp/ipykernel_32646/1351893647.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_32646/1351893647.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# /tmp/ipykernel_32646/1351893647.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# /tmp/ipykernel_32646/1351893647.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-28 14:26:37,624] Trial 27 finished with value: 0.786875 and parameters: {'lambda_l1': 9.164591531336289e-05, 'lambda_l2': 3.7238238252766594e-05, 'num_leaves': 59, 'feature_fraction': 0.7260137419555152, 'bagging_fraction': 0.4802126573706792, 'bagging_freq': 5, 'min_child_samples': 75, 'min_data_in_leaf': 55}. Best is trial 19 with value: 0.798125.
# /tmp/ipykernel_32646/1351893647.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_32646/1351893647.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# /tmp/ipykernel_32646/1351893647.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# /tmp/ipykernel_32646/1351893647.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-28 14:26:37,806] Trial 28 finished with value: 0.785 and parameters: {'lambda_l1': 0.002513455161940135, 'lambda_l2': 0.00042681407494630954, 'num_leaves': 23, 'feature_fraction': 0.6545856811400461, 'bagging_fraction': 0.5227288486333521, 'bagging_freq': 7, 'min_child_samples': 58, 'min_data_in_leaf': 76}. Best is trial 19 with value: 0.798125.
# /tmp/ipykernel_32646/1351893647.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_32646/1351893647.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# /tmp/ipykernel_32646/1351893647.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# /tmp/ipykernel_32646/1351893647.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-28 14:26:38,031] Trial 29 finished with value: 0.7925 and parameters: {'lambda_l1': 0.08039982023384974, 'lambda_l2': 5.1283240383573385e-06, 'num_leaves': 168, 'feature_fraction': 0.619020397133308, 'bagging_fraction': 0.5577153079906789, 'bagging_freq': 4, 'min_child_samples': 87, 'min_data_in_leaf': 95}. Best is trial 19 with value: 0.798125.
# /tmp/ipykernel_32646/1351893647.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# ...
# /tmp/ipykernel_32646/1351893647.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_32646/1351893647.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# /tmp/ipykernel_32646/1351893647.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# /tmp/ipykernel_32646/1351893647.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-28 14:29:18,566] Trial 90 finished with value: 0.788125 and parameters: {'lambda_l1': 2.7306559125898338e-08, 'lambda_l2': 0.0023021595677415333, 'num_leaves': 248, 'feature_fraction': 0.41573646072060777, 'bagging_fraction': 0.9324784236794436, 'bagging_freq': 6, 'min_child_samples': 72, 'min_data_in_leaf': 34}. Best is trial 2 with value: 0.796875.
# /tmp/ipykernel_32646/1351893647.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_32646/1351893647.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# /tmp/ipykernel_32646/1351893647.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# /tmp/ipykernel_32646/1351893647.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-28 14:29:19,037] Trial 91 finished with value: 0.784375 and parameters: {'lambda_l1': 2.538207498738925e-07, 'lambda_l2': 0.00021937101742375647, 'num_leaves': 188, 'feature_fraction': 0.4675877525289394, 'bagging_fraction': 0.984173829177769, 'bagging_freq': 1, 'min_child_samples': 66, 'min_data_in_leaf': 36}. Best is trial 2 with value: 0.796875.
# /tmp/ipykernel_32646/1351893647.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_32646/1351893647.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# /tmp/ipykernel_32646/1351893647.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# /tmp/ipykernel_32646/1351893647.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-28 14:29:19,435] Trial 92 finished with value: 0.783125 and parameters: {'lambda_l1': 7.520423654462565e-08, 'lambda_l2': 0.00013706838188964226, 'num_leaves': 176, 'feature_fraction': 0.4785605228829666, 'bagging_fraction': 0.924525982014427, 'bagging_freq': 1, 'min_child_samples': 60, 'min_data_in_leaf': 33}. Best is trial 2 with value: 0.796875.
# /tmp/ipykernel_32646/1351893647.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_32646/1351893647.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# /tmp/ipykernel_32646/1351893647.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# /tmp/ipykernel_32646/1351893647.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-28 14:29:19,786] Trial 93 finished with value: 0.794375 and parameters: {'lambda_l1': 7.189052198378674e-07, 'lambda_l2': 8.775296451659015, 'num_leaves': 227, 'feature_fraction': 0.4453280753955865, 'bagging_fraction': 0.9019946720879412, 'bagging_freq': 1, 'min_child_samples': 21, 'min_data_in_leaf': 42}. Best is trial 2 with value: 0.796875.
# /tmp/ipykernel_32646/1351893647.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_32646/1351893647.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# /tmp/ipykernel_32646/1351893647.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# /tmp/ipykernel_32646/1351893647.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-28 14:29:20,050] Trial 94 finished with value: 0.785 and parameters: {'lambda_l1': 3.1534519858099847e-06, 'lambda_l2': 7.234338405043083, 'num_leaves': 223, 'feature_fraction': 0.4483514392699014, 'bagging_fraction': 0.8529880609567331, 'bagging_freq': 1, 'min_child_samples': 24, 'min_data_in_leaf': 43}. Best is trial 2 with value: 0.796875.
# /tmp/ipykernel_32646/1351893647.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_32646/1351893647.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# /tmp/ipykernel_32646/1351893647.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# /tmp/ipykernel_32646/1351893647.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-28 14:29:20,372] Trial 95 finished with value: 0.788125 and parameters: {'lambda_l1': 7.909487930402425e-07, 'lambda_l2': 5.186285583343277, 'num_leaves': 231, 'feature_fraction': 0.4272419558123671, 'bagging_fraction': 0.8812174625585122, 'bagging_freq': 1, 'min_child_samples': 19, 'min_data_in_leaf': 46}. Best is trial 2 with value: 0.796875.
# /tmp/ipykernel_32646/1351893647.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_32646/1351893647.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# /tmp/ipykernel_32646/1351893647.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# /tmp/ipykernel_32646/1351893647.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-28 14:29:20,615] Trial 96 finished with value: 0.77375 and parameters: {'lambda_l1': 1.6731032616832527e-05, 'lambda_l2': 0.8347168916983283, 'num_leaves': 209, 'feature_fraction': 0.7459961343621995, 'bagging_fraction': 0.904006633051943, 'bagging_freq': 2, 'min_child_samples': 27, 'min_data_in_leaf': 95}. Best is trial 2 with value: 0.796875.
# /tmp/ipykernel_32646/1351893647.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_32646/1351893647.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# /tmp/ipykernel_32646/1351893647.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# /tmp/ipykernel_32646/1351893647.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-28 14:29:20,909] Trial 97 finished with value: 0.789375 and parameters: {'lambda_l1': 1.503500910084309e-07, 'lambda_l2': 1.4092697311270928, 'num_leaves': 236, 'feature_fraction': 0.5045002425680603, 'bagging_fraction': 0.8616527143132209, 'bagging_freq': 4, 'min_child_samples': 53, 'min_data_in_leaf': 50}. Best is trial 2 with value: 0.796875.
# /tmp/ipykernel_32646/1351893647.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_32646/1351893647.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# /tmp/ipykernel_32646/1351893647.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# /tmp/ipykernel_32646/1351893647.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-28 14:29:21,283] Trial 98 finished with value: 0.778125 and parameters: {'lambda_l1': 7.069304728406891e-06, 'lambda_l2': 0.08084478809552799, 'num_leaves': 255, 'feature_fraction': 0.998381027701994, 'bagging_fraction': 0.9671215766044449, 'bagging_freq': 1, 'min_child_samples': 17, 'min_data_in_leaf': 41}. Best is trial 2 with value: 0.796875.
# /tmp/ipykernel_32646/1351893647.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_32646/1351893647.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# /tmp/ipykernel_32646/1351893647.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# /tmp/ipykernel_32646/1351893647.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-28 14:29:21,627] Trial 99 finished with value: 0.789375 and parameters: {'lambda_l1': 5.772016132691985e-07, 'lambda_l2': 2.095237825205555e-05, 'num_leaves': 117, 'feature_fraction': 0.4426151810551441, 'bagging_fraction': 0.729453828627365, 'bagging_freq': 2, 'min_child_samples': 23, 'min_data_in_leaf': 39}. Best is trial 2 with value: 0.796875.

# %% [markdown]
# - lgb_平均スコア

# %%
# 全フォールドの平均スコアを計算
lgb_average_score = sum(lgb_fold_scores) / n_splits
print(f"LightGBM Average accuracy across all folds: {lgb_average_score}")
# Out:
# LightGBM Average accuracy across all folds: 0.78025

# %% [markdown]
# - lgb_予測平均

# %%
# 予測の平均を計算
lgb_y_test_pred_avg = np.mean(lgb_test_predictions, axis=0)

# 最終的な予測結果を整数に変換
lgb_y_test_pred_int = (lgb_y_test_pred_avg > 0.5).astype(int)

# %% [markdown]
# - output

# %%
# 現在の日時を取得してフォーマットする
current_time = datetime.now().strftime("%Y%m%d_%H%M%S")
output = f'../data/output/{current_time}_LightGBM_cv{lgb_average_score:.4f}.csv'

submit = pd.DataFrame({
    '0': test['gameId'],
    '1': lgb_y_test_pred_int
})

# カラムヘッダー消去して出力
# ヘッダーなしでCSVファイルとして保存
submit.to_csv(output, header=False, index=False)

# %%
submit
# Out:
#          0  1
# 0        9  1
# 1       15  1
# 2       18  0
# 3       23  0
# 4       31  1
# ...    ... ..
# 1995  9971  0
# 1996  9980  0
# 1997  9983  1
# 1998  9996  1
# 1999  9999  0
#
# [2000 rows x 2 columns]

# %% [markdown]
# ## XGBoost

# %%
for train_index, val_index in kf.split(X):
    X_train_fold, X_val_fold = X.iloc[train_index], X.iloc[val_index]
    y_train_fold, y_val_fold = y[train_index], y[val_index]

    dtrain = xgb.DMatrix(X_train_fold, label=y_train_fold)
    dval = xgb.DMatrix(X_val_fold, label=y_val_fold)
    dtest = xgb.DMatrix(test_drop_gameId)

    # Optunaでのハイパーパラメータチューニング
    def objective(trial):
        param = {
            'verbosity': 0,
            'objective': 'binary:logistic',
            'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
            'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
            'max_depth': trial.suggest_int('max_depth', 3, 9),
            'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
            'subsample': trial.suggest_float('subsample', 0.5, 1),
            'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1)
        }

        bst = xgb.train(param, dtrain, num_boost_round=1000, evals=[(dval, "eval")], early_stopping_rounds=50, verbose_eval=False)
        preds = bst.predict(dval)
        pred_labels = np.rint(preds)
        accuracy = accuracy_score(y_val_fold, pred_labels)
        return accuracy

    xgb_study = optuna.create_study(direction='maximize')
    xgb_study.optimize(objective, n_trials=100)

    # 各フォールドの最適パラメータでモデルを再学習
    xgb_best_params = xgb_study.best_params
    xgb_best_params['objective'] = 'binary:logistic'
    xgb_best_params['verbosity'] = 0

    xgb_final_bst = xgb.train(xgb_best_params, dtrain, num_boost_round=xgb_study.best_trial.number)

    # 各フォールドのモデル性能を評価
    xgb_y_val_pred = xgb_final_bst.predict(dval)
    xgb_y_val_pred_int = np.rint(xgb_y_val_pred)
    fold_accuracy = accuracy_score(y_val_fold, xgb_y_val_pred_int)
    xgb_fold_scores.append(fold_accuracy)

    # テストデータセットでの予測
    xgb_y_test_pred_fold = xgb_final_bst.predict(dtest)
    xgb_test_predictions.append(xgb_y_test_pred_fold)
# Out:
# [I 2024-01-28 14:29:21,761] A new study created in memory with name: no-name-54af3a81-0c81-4815-a68b-a11cb5774c3a
# /tmp/ipykernel_32646/2755269153.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_32646/2755269153.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_32646/2755269153.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-28 14:29:26,166] Trial 0 finished with value: 0.491875 and parameters: {'alpha': 1.2239850039236434e-06, 'lambda': 2.515856410837836e-07, 'max_depth': 8, 'eta': 5.187213187294832e-06, 'subsample': 0.9453774405368586, 'colsample_bytree': 0.946240500120918}. Best is trial 0 with value: 0.491875.
# /tmp/ipykernel_32646/2755269153.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_32646/2755269153.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_32646/2755269153.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-28 14:29:26,332] Trial 1 finished with value: 0.75375 and parameters: {'alpha': 0.0009126475723795543, 'lambda': 0.0003752982859142295, 'max_depth': 5, 'eta': 0.4084202072501253, 'subsample': 0.7350333199733627, 'colsample_bytree': 0.6986765001005288}. Best is trial 1 with value: 0.75375.
# /tmp/ipykernel_32646/2755269153.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_32646/2755269153.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_32646/2755269153.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-28 14:29:30,637] Trial 2 finished with value: 0.7675 and parameters: {'alpha': 1.1426581441694417e-08, 'lambda': 0.00013861204446268945, 'max_depth': 9, 'eta': 0.0024466144613332903, 'subsample': 0.6077621591585416, 'colsample_bytree': 0.8528040429632849}. Best is trial 2 with value: 0.7675.
# /tmp/ipykernel_32646/2755269153.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_32646/2755269153.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_32646/2755269153.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-28 14:29:30,904] Trial 3 finished with value: 0.77125 and parameters: {'alpha': 0.004861516797802255, 'lambda': 0.0028616573433542895, 'max_depth': 6, 'eta': 0.0778555830974676, 'subsample': 0.8714765125855235, 'colsample_bytree': 0.6360508835865064}. Best is trial 3 with value: 0.77125.
# /tmp/ipykernel_32646/2755269153.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_32646/2755269153.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_32646/2755269153.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-28 14:29:34,448] Trial 4 finished with value: 0.768125 and parameters: {'alpha': 1.3839100477585205e-06, 'lambda': 0.009794056574799962, 'max_depth': 8, 'eta': 0.000374366067048373, 'subsample': 0.7334915785289332, 'colsample_bytree': 0.5602333146185128}. Best is trial 3 with value: 0.77125.
# /tmp/ipykernel_32646/2755269153.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_32646/2755269153.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_32646/2755269153.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-28 14:29:34,785] Trial 5 finished with value: 0.766875 and parameters: {'alpha': 0.42301040410470336, 'lambda': 0.0007226786768156514, 'max_depth': 9, 'eta': 0.0658576493790068, 'subsample': 0.5765761282450493, 'colsample_bytree': 0.9657486504818933}. Best is trial 3 with value: 0.77125.
# /tmp/ipykernel_32646/2755269153.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_32646/2755269153.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_32646/2755269153.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-28 14:29:37,987] Trial 6 finished with value: 0.491875 and parameters: {'alpha': 0.0012634435708093936, 'lambda': 2.6956100753083682e-05, 'max_depth': 7, 'eta': 4.041870839666166e-06, 'subsample': 0.6032076431885061, 'colsample_bytree': 0.7208377734918092}. Best is trial 3 with value: 0.77125.
# /tmp/ipykernel_32646/2755269153.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_32646/2755269153.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_32646/2755269153.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-28 14:29:41,735] Trial 7 finished with value: 0.768125 and parameters: {'alpha': 0.00024250669180384755, 'lambda': 0.0007090334721867864, 'max_depth': 8, 'eta': 0.0010835424908580832, 'subsample': 0.7555537216170652, 'colsample_bytree': 0.8021836069842319}. Best is trial 3 with value: 0.77125.
# /tmp/ipykernel_32646/2755269153.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_32646/2755269153.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_32646/2755269153.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-28 14:29:42,988] Trial 8 finished with value: 0.491875 and parameters: {'alpha': 4.686807498943187e-07, 'lambda': 0.17499401590480237, 'max_depth': 3, 'eta': 1.1149370742717107e-07, 'subsample': 0.7517456068925118, 'colsample_bytree': 0.805754653583018}. Best is trial 3 with value: 0.77125.
# /tmp/ipykernel_32646/2755269153.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_32646/2755269153.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_32646/2755269153.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-28 14:29:46,865] Trial 9 finished with value: 0.491875 and parameters: {'alpha': 0.0002380284293114667, 'lambda': 0.02359775463485202, 'max_depth': 8, 'eta': 3.6925824882565447e-06, 'subsample': 0.7601559924593149, 'colsample_bytree': 0.8410155369294181}. Best is trial 3 with value: 0.77125.
# /tmp/ipykernel_32646/2755269153.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_32646/2755269153.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_32646/2755269153.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-28 14:29:47,621] Trial 10 finished with value: 0.77 and parameters: {'alpha': 0.0845154532866761, 'lambda': 1.2969411064859272e-06, 'max_depth': 5, 'eta': 0.02286494386038892, 'subsample': 0.998033221184165, 'colsample_bytree': 0.5387309781184745}. Best is trial 3 with value: 0.77125.
# /tmp/ipykernel_32646/2755269153.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_32646/2755269153.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_32646/2755269153.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-28 14:29:48,342] Trial 11 finished with value: 0.7725 and parameters: {'alpha': 0.08204849216827512, 'lambda': 7.975030666521653e-07, 'max_depth': 5, 'eta': 0.0263143384050313, 'subsample': 0.9933840492217832, 'colsample_bytree': 0.5572226339227005}. Best is trial 11 with value: 0.7725.
# /tmp/ipykernel_32646/2755269153.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_32646/2755269153.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_32646/2755269153.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-28 14:29:48,447] Trial 12 finished with value: 0.75125 and parameters: {'alpha': 0.029365186358062047, 'lambda': 1.325424692343984e-08, 'max_depth': 5, 'eta': 0.7658834944860978, 'subsample': 0.8923339041316914, 'colsample_bytree': 0.625434035970602}. Best is trial 11 with value: 0.7725.
# /tmp/ipykernel_32646/2755269153.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_32646/2755269153.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_32646/2755269153.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-28 14:29:49,748] Trial 13 finished with value: 0.761875 and parameters: {'alpha': 0.009970679625538234, 'lambda': 9.233966697514156e-06, 'max_depth': 3, 'eta': 0.015648467281885067, 'subsample': 0.8765129622702174, 'colsample_bytree': 0.623121573368017}. Best is trial 11 with value: 0.7725.
# /tmp/ipykernel_32646/2755269153.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_32646/2755269153.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_32646/2755269153.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-28 14:29:51,944] Trial 14 finished with value: 0.715 and parameters: {'alpha': 0.00787941783492313, 'lambda': 2.3573631564646067e-08, 'max_depth': 6, 'eta': 5.4354549754415577e-05, 'subsample': 0.8553410186978339, 'colsample_bytree': 0.6199547484715995}. Best is trial 11 with value: 0.7725.
# /tmp/ipykernel_32646/2755269153.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_32646/2755269153.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_32646/2755269153.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-28 14:29:52,319] Trial 15 finished with value: 0.771875 and parameters: {'alpha': 1.6723125411697177e-05, 'lambda': 0.8655619651390786, 'max_depth': 4, 'eta': 0.1177414094321282, 'subsample': 0.9989191498332913, 'colsample_bytree': 0.5360390050543486}. Best is trial 11 with value: 0.7725.
# /tmp/ipykernel_32646/2755269153.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_32646/2755269153.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_32646/2755269153.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-28 14:29:53,901] Trial 16 finished with value: 0.7625 and parameters: {'alpha': 1.8225645829614877e-05, 'lambda': 0.7265712430725891, 'max_depth': 4, 'eta': 0.0056220518199462145, 'subsample': 0.9932872426765393, 'colsample_bytree': 0.5119524083194026}. Best is trial 11 with value: 0.7725.
# /tmp/ipykernel_32646/2755269153.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_32646/2755269153.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_32646/2755269153.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-28 14:29:55,446] Trial 17 finished with value: 0.75125 and parameters: {'alpha': 1.9049993350024046e-05, 'lambda': 3.0486542999009813e-07, 'max_depth': 4, 'eta': 0.00017933425317612743, 'subsample': 0.9436279095841374, 'colsample_bytree': 0.5785429990270397}. Best is trial 11 with value: 0.7725.
# /tmp/ipykernel_32646/2755269153.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_32646/2755269153.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_32646/2755269153.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-28 14:29:55,569] Trial 18 finished with value: 0.76875 and parameters: {'alpha': 1.789437453283795e-05, 'lambda': 6.795646006848222e-06, 'max_depth': 4, 'eta': 0.3980508885115674, 'subsample': 0.8128543711122069, 'colsample_bytree': 0.5012522837484681}. Best is trial 11 with value: 0.7725.
# /tmp/ipykernel_32646/2755269153.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_32646/2755269153.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_32646/2755269153.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-28 14:29:55,987] Trial 19 finished with value: 0.764375 and parameters: {'alpha': 0.33950012869131196, 'lambda': 0.1098710519692405, 'max_depth': 6, 'eta': 0.08798197305617882, 'subsample': 0.6616416366322017, 'colsample_bytree': 0.693945800330485}. Best is trial 11 with value: 0.7725.
# /tmp/ipykernel_32646/2755269153.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_32646/2755269153.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_32646/2755269153.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-28 14:29:57,797] Trial 20 finished with value: 0.491875 and parameters: {'alpha': 8.24352294614927e-08, 'lambda': 1.2817948561427874e-06, 'max_depth': 4, 'eta': 2.3437287117594695e-08, 'subsample': 0.9369555372963798, 'colsample_bytree': 0.5859931804272627}. Best is trial 11 with value: 0.7725.
# /tmp/ipykernel_32646/2755269153.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_32646/2755269153.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_32646/2755269153.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-28 14:29:58,069] Trial 21 finished with value: 0.770625 and parameters: {'alpha': 0.0015605663068906273, 'lambda': 0.010528680453323846, 'max_depth': 6, 'eta': 0.09470259453435043, 'subsample': 0.9066751075423373, 'colsample_bytree': 0.6730272940802989}. Best is trial 11 with value: 0.7725.
# /tmp/ipykernel_32646/2755269153.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_32646/2755269153.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_32646/2755269153.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-28 14:29:59,706] Trial 22 finished with value: 0.77375 and parameters: {'alpha': 0.09794809146384682, 'lambda': 0.003586757359777531, 'max_depth': 5, 'eta': 0.008406221905183555, 'subsample': 0.8177559645454036, 'colsample_bytree': 0.6499365796696936}. Best is trial 22 with value: 0.77375.
# /tmp/ipykernel_32646/2755269153.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_32646/2755269153.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_32646/2755269153.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-28 14:30:01,639] Trial 23 finished with value: 0.76625 and parameters: {'alpha': 0.9979938322843415, 'lambda': 0.7390174287881783, 'max_depth': 5, 'eta': 0.008605697049491554, 'subsample': 0.8220054278374093, 'colsample_bytree': 0.5582528338371388}. Best is trial 22 with value: 0.77375.
# /tmp/ipykernel_32646/2755269153.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_32646/2755269153.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_32646/2755269153.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-28 14:30:02,948] Trial 24 finished with value: 0.755 and parameters: {'alpha': 0.06641960748088167, 'lambda': 0.09255257898240242, 'max_depth': 3, 'eta': 0.0010386634345292873, 'subsample': 0.9781463379367119, 'colsample_bytree': 0.6584045770440384}. Best is trial 22 with value: 0.77375.
# /tmp/ipykernel_32646/2755269153.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_32646/2755269153.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_32646/2755269153.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-28 14:30:04,887] Trial 25 finished with value: 0.694375 and parameters: {'alpha': 0.00011895444681286508, 'lambda': 0.002919559096981497, 'max_depth': 5, 'eta': 4.4654006166735637e-05, 'subsample': 0.6814157374614521, 'colsample_bytree': 0.7448467375666321}. Best is trial 22 with value: 0.77375.
# /tmp/ipykernel_32646/2755269153.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_32646/2755269153.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_32646/2755269153.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-28 14:30:06,077] Trial 26 finished with value: 0.770625 and parameters: {'alpha': 0.07838192254355102, 'lambda': 2.4416326740445214e-05, 'max_depth': 4, 'eta': 0.026566706382533545, 'subsample': 0.7996979255578879, 'colsample_bytree': 0.5954180272506241}. Best is trial 22 with value: 0.77375.
# /tmp/ipykernel_32646/2755269153.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_32646/2755269153.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_32646/2755269153.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-28 14:30:08,701] Trial 27 finished with value: 0.765625 and parameters: {'alpha': 4.483592546310546e-06, 'lambda': 7.54841722615181e-08, 'max_depth': 7, 'eta': 0.002345658755605567, 'subsample': 0.5020619312380603, 'colsample_bytree': 0.545156621397103}. Best is trial 22 with value: 0.77375.
# /tmp/ipykernel_32646/2755269153.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_32646/2755269153.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_32646/2755269153.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-28 14:30:08,818] Trial 28 finished with value: 0.770625 and parameters: {'alpha': 0.018149636452922693, 'lambda': 0.032013589088645926, 'max_depth': 5, 'eta': 0.3896176580099993, 'subsample': 0.9148880302564804, 'colsample_bytree': 0.5328742754313778}. Best is trial 22 with value: 0.77375.
# /tmp/ipykernel_32646/2755269153.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_32646/2755269153.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_32646/2755269153.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-28 14:30:09,039] Trial 29 finished with value: 0.760625 and parameters: {'alpha': 0.1883719252287506, 'lambda': 1.2181762139422084e-06, 'max_depth': 7, 'eta': 0.15541804428926317, 'subsample': 0.9601937074715373, 'colsample_bytree': 0.5861732346239104}. Best is trial 22 with value: 0.77375.
# /tmp/ipykernel_32646/2755269153.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_32646/2755269153.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_32646/2755269153.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-28 14:30:10,914] Trial 30 finished with value: 0.491875 and parameters: {'alpha': 4.0832551886698015e-05, 'lambda': 0.0001326553113292804, 'max_depth': 4, 'eta': 6.656560535718094e-07, 'subsample': 0.8362107618713344, 'colsample_bytree': 0.6621614764708733}. Best is trial 22 with value: 0.77375.
# /tmp/ipykernel_32646/2755269153.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_32646/2755269153.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_32646/2755269153.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-28 14:30:13,380] Trial 31 finished with value: 0.766875 and parameters: {'alpha': 0.003942199960970864, 'lambda': 0.003440265119851625, 'max_depth': 6, 'eta': 0.03300212116339402, 'subsample': 0.9295831315655825, 'colsample_bytree': 0.6371334645541489}. Best is trial 22 with value: 0.77375.
# /tmp/ipykernel_32646/2755269153.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_32646/2755269153.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_32646/2755269153.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-28 14:30:14,319] Trial 32 finished with value: 0.765 and parameters: {'alpha': 0.03287094384978144, 'lambda': 0.0029537364316226007, 'max_depth': 6, 'eta': 0.20933271288352892, 'subsample': 0.8650896883107684, 'colsample_bytree': 0.6092931162599801}. Best is trial 22 with value: 0.77375.
# /tmp/ipykernel_32646/2755269153.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_32646/2755269153.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_32646/2755269153.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-28 14:30:19,326] Trial 33 finished with value: 0.76 and parameters: {'alpha': 0.003208862184558082, 'lambda': 0.0002830629629705623, 'max_depth': 5, 'eta': 0.005017955781660874, 'subsample': 0.9710314403082085, 'colsample_bytree': 0.7092666646475423}. Best is trial 22 with value: 0.77375.
# /tmp/ipykernel_32646/2755269153.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_32646/2755269153.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_32646/2755269153.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-28 14:30:20,696] Trial 34 finished with value: 0.769375 and parameters: {'alpha': 0.0007613432957136959, 'lambda': 4.752947318064355e-05, 'max_depth': 6, 'eta': 0.06538428938879198, 'subsample': 0.9527063752850962, 'colsample_bytree': 0.5231464894024234}. Best is trial 22 with value: 0.77375.
# /tmp/ipykernel_32646/2755269153.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_32646/2755269153.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_32646/2755269153.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-28 14:30:22,394] Trial 35 finished with value: 0.76625 and parameters: {'alpha': 0.0004755321055126155, 'lambda': 0.0013726180204041817, 'max_depth': 5, 'eta': 0.00037080690209813046, 'subsample': 0.7868923506587762, 'colsample_bytree': 0.571957992019776}. Best is trial 22 with value: 0.77375.
# /tmp/ipykernel_32646/2755269153.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_32646/2755269153.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_32646/2755269153.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-28 14:30:22,490] Trial 36 finished with value: 0.755 and parameters: {'alpha': 0.9963281761093427, 'lambda': 0.009118584133202896, 'max_depth': 4, 'eta': 0.6890836315494324, 'subsample': 0.8892801402750544, 'colsample_bytree': 0.9979503992606528}. Best is trial 22 with value: 0.77375.
# /tmp/ipykernel_32646/2755269153.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_32646/2755269153.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_32646/2755269153.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-28 14:30:25,277] Trial 37 finished with value: 0.77125 and parameters: {'alpha': 3.830765927639313e-06, 'lambda': 0.22294846724116757, 'max_depth': 7, 'eta': 0.0020050474078103135, 'subsample': 0.8378824536131014, 'colsample_bytree': 0.7444706816264169}. Best is trial 22 with value: 0.77375.
# /tmp/ipykernel_32646/2755269153.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_32646/2755269153.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_32646/2755269153.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-28 14:30:26,732] Trial 38 finished with value: 0.7675 and parameters: {'alpha': 0.1530912758596592, 'lambda': 0.0003881909326906231, 'max_depth': 5, 'eta': 0.013526486285156897, 'subsample': 0.710723228806423, 'colsample_bytree': 0.8942185832331657}. Best is trial 22 with value: 0.77375.
# /tmp/ipykernel_32646/2755269153.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_32646/2755269153.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_32646/2755269153.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# ...
# [I 2024-01-28 14:41:55,886] Trial 86 finished with value: 0.793125 and parameters: {'alpha': 7.48650807615822e-08, 'lambda': 0.09000936221391494, 'max_depth': 6, 'eta': 4.693101677584962e-05, 'subsample': 0.7237885424117049, 'colsample_bytree': 0.9467193102831019}. Best is trial 86 with value: 0.793125.
# /tmp/ipykernel_32646/2755269153.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_32646/2755269153.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_32646/2755269153.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-28 14:41:58,489] Trial 87 finished with value: 0.7875 and parameters: {'alpha': 1.20412223121238e-06, 'lambda': 0.04099814760537514, 'max_depth': 6, 'eta': 9.174675022399088e-05, 'subsample': 0.7252581140777484, 'colsample_bytree': 0.9493655624371627}. Best is trial 86 with value: 0.793125.
# /tmp/ipykernel_32646/2755269153.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_32646/2755269153.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_32646/2755269153.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-28 14:42:01,073] Trial 88 finished with value: 0.780625 and parameters: {'alpha': 1.492809235124817e-08, 'lambda': 0.10823288039362722, 'max_depth': 6, 'eta': 2.4022043965158928e-05, 'subsample': 0.619992727975903, 'colsample_bytree': 0.9875238314136855}. Best is trial 86 with value: 0.793125.
# /tmp/ipykernel_32646/2755269153.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_32646/2755269153.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_32646/2755269153.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-28 14:42:04,374] Trial 89 finished with value: 0.786875 and parameters: {'alpha': 6.981872897488495e-08, 'lambda': 0.07274593781941907, 'max_depth': 7, 'eta': 5.3651519182957346e-05, 'subsample': 0.7075341697423492, 'colsample_bytree': 0.9663577484204313}. Best is trial 86 with value: 0.793125.
# /tmp/ipykernel_32646/2755269153.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_32646/2755269153.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_32646/2755269153.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-28 14:42:07,465] Trial 90 finished with value: 0.783125 and parameters: {'alpha': 4.45454573113333e-08, 'lambda': 0.005475870005419147, 'max_depth': 7, 'eta': 0.00018805908671086402, 'subsample': 0.5738628192477468, 'colsample_bytree': 0.9996674049267991}. Best is trial 86 with value: 0.793125.
# /tmp/ipykernel_32646/2755269153.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_32646/2755269153.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_32646/2755269153.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-28 14:42:09,961] Trial 91 finished with value: 0.7875 and parameters: {'alpha': 4.67643965807553e-07, 'lambda': 0.014022929669698014, 'max_depth': 6, 'eta': 3.7292255620503146e-05, 'subsample': 0.6844477529869458, 'colsample_bytree': 0.9443301504208644}. Best is trial 86 with value: 0.793125.
# /tmp/ipykernel_32646/2755269153.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_32646/2755269153.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_32646/2755269153.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-28 14:42:12,883] Trial 92 finished with value: 0.728125 and parameters: {'alpha': 8.126263912630313e-08, 'lambda': 0.0249086428746172, 'max_depth': 6, 'eta': 1.074244888250366e-05, 'subsample': 0.6444815653518166, 'colsample_bytree': 0.9659103670355285}. Best is trial 86 with value: 0.793125.
# /tmp/ipykernel_32646/2755269153.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_32646/2755269153.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_32646/2755269153.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-28 14:42:15,155] Trial 93 finished with value: 0.785 and parameters: {'alpha': 3.075485059549212e-07, 'lambda': 0.20408161198740232, 'max_depth': 6, 'eta': 0.00010703620994823386, 'subsample': 0.6762042797693258, 'colsample_bytree': 0.9337842757886577}. Best is trial 86 with value: 0.793125.
# /tmp/ipykernel_32646/2755269153.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_32646/2755269153.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_32646/2755269153.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-28 14:42:18,429] Trial 94 finished with value: 0.785625 and parameters: {'alpha': 1.2216055023978668e-07, 'lambda': 0.055390224801586535, 'max_depth': 8, 'eta': 5.395863702425503e-05, 'subsample': 0.7169331189212393, 'colsample_bytree': 0.9019706921828525}. Best is trial 86 with value: 0.793125.
# /tmp/ipykernel_32646/2755269153.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_32646/2755269153.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_32646/2755269153.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-28 14:42:21,107] Trial 95 finished with value: 0.785625 and parameters: {'alpha': 1.1258646143728974e-06, 'lambda': 0.10461152205109325, 'max_depth': 7, 'eta': 0.0002679972996988365, 'subsample': 0.7028798709093776, 'colsample_bytree': 0.9445059619025382}. Best is trial 86 with value: 0.793125.
# /tmp/ipykernel_32646/2755269153.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_32646/2755269153.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_32646/2755269153.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-28 14:42:23,995] Trial 96 finished with value: 0.76 and parameters: {'alpha': 5.635326382378571e-07, 'lambda': 0.0010974418454623202, 'max_depth': 7, 'eta': 1.586562100070854e-05, 'subsample': 0.734421498119496, 'colsample_bytree': 0.9578642165064518}. Best is trial 86 with value: 0.793125.
# /tmp/ipykernel_32646/2755269153.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_32646/2755269153.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_32646/2755269153.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-28 14:42:26,103] Trial 97 finished with value: 0.52875 and parameters: {'alpha': 2.964930351095733e-06, 'lambda': 0.008244836958186482, 'max_depth': 6, 'eta': 5.139304126712527e-06, 'subsample': 0.7540036876186613, 'colsample_bytree': 0.6882532187806275}. Best is trial 86 with value: 0.793125.
# /tmp/ipykernel_32646/2755269153.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_32646/2755269153.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_32646/2755269153.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-28 14:42:28,625] Trial 98 finished with value: 0.79 and parameters: {'alpha': 1.8278833967207196e-05, 'lambda': 0.01768234722663969, 'max_depth': 7, 'eta': 4.2076011734626015e-05, 'subsample': 0.7786755363208703, 'colsample_bytree': 0.9079146359297212}. Best is trial 86 with value: 0.793125.
# /tmp/ipykernel_32646/2755269153.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_32646/2755269153.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_32646/2755269153.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-28 14:42:31,259] Trial 99 finished with value: 0.78375 and parameters: {'alpha': 0.09461704951492972, 'lambda': 0.03119399891799533, 'max_depth': 7, 'eta': 2.464372463715995e-05, 'subsample': 0.7738029514713071, 'colsample_bytree': 0.8593863178606652}. Best is trial 86 with value: 0.793125.

# %% [markdown]
# - xgb_平均スコア

# %%
# 全フォールドの平均スコアを計算
xgb_average_score = sum(xgb_fold_scores) / n_splits
print(f"XGB Average accuracy across all folds: {xgb_average_score}")
# Out:
# XGB Average accuracy across all folds: 0.7135

# %% [markdown]
# - xgb_予測平均

# %%
# 予測の平均を計算
xgb_y_test_pred_avg = np.mean(xgb_test_predictions, axis=0)

# 最終的な予測結果を整数に変換
xgb_y_test_pred_int = (xgb_y_test_pred_avg > 0.5).astype(int)

# %% [markdown]
# - output

# %%
# 現在の日時を取得してフォーマットする
current_time = datetime.now().strftime("%Y%m%d_%H%M%S")
output = f'../data/output/{current_time}_XGBoost_cv{xgb_average_score:.4f}.csv'

submit = pd.DataFrame({
    '0': test['gameId'],
    '1': xgb_y_test_pred_int
})

# カラムヘッダー消去して出力
# ヘッダーなしでCSVファイルとして保存
submit.to_csv(output, header=False, index=False)

# %% [markdown]
# ## CatBoost

# %%
for train_index, val_index in kf.split(X):
    X_train_fold, X_val_fold = X.iloc[train_index], X.iloc[val_index]
    y_train_fold, y_val_fold = y[train_index], y[val_index]

    # Optunaでのハイパーパラメータチューニング
    def objective(trial):
        param = {
            'iterations': 1000,
            'depth': trial.suggest_int('depth', 4, 10),
            'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3),
            'random_strength': trial.suggest_int('random_strength', 1, 20),
            'bagging_temperature': trial.suggest_float('bagging_temperature', 0.0, 1.0),
            'l2_leaf_reg': trial.suggest_float('l2_leaf_reg', 1e-3, 100),
            'scale_pos_weight': trial.suggest_float('scale_pos_weight', 0.1, 10.0),
            'loss_function': 'Logloss'
        }

        model = cb.CatBoostClassifier(**param, verbose=False)
        model.fit(X_train_fold, y_train_fold, eval_set=(X_val_fold, y_val_fold), early_stopping_rounds=50)
        preds = model.predict(X_val_fold)
        accuracy = accuracy_score(y_val_fold, preds)
        return accuracy

    cb_study = optuna.create_study(direction='maximize')
    cb_study.optimize(objective, n_trials=100)

    # 各フォールドの最適パラメータでモデルを再学習
    cb_best_params = cb_study.best_params
    cb_best_params['loss_function'] = 'Logloss'
    model_fold = cb.CatBoostClassifier(**cb_best_params, verbose=False)
    model_fold.fit(X_train_fold, y_train_fold)

    # 各フォールドのモデル性能を評価
    cb_y_val_pred = model_fold.predict(X_val_fold)
    cb_fold_accuracy = accuracy_score(y_val_fold, cb_y_val_pred)
    cb_fold_scores.append(cb_fold_accuracy)

    # テストデータセットでの予測
    cb_y_test_pred_fold = model_fold.predict(test_drop_gameId)
    cb_test_predictions.append(cb_y_test_pred_fold)
# Out:
# [I 2024-01-28 14:42:31,475] A new study created in memory with name: no-name-1e02d0b2-1365-46ba-91fb-7e0171cbaf69
# [I 2024-01-28 14:42:32,767] Trial 0 finished with value: 0.7225 and parameters: {'depth': 7, 'learning_rate': 0.07781896231373686, 'random_strength': 12, 'bagging_temperature': 0.42496541417245837, 'l2_leaf_reg': 66.42878927549226, 'scale_pos_weight': 0.2478760398671993}. Best is trial 0 with value: 0.7225.
# [I 2024-01-28 14:42:36,787] Trial 1 finished with value: 0.67 and parameters: {'depth': 8, 'learning_rate': 0.013009209332435885, 'random_strength': 4, 'bagging_temperature': 0.02073234002711133, 'l2_leaf_reg': 81.137618520706, 'scale_pos_weight': 9.054773296948554}. Best is trial 0 with value: 0.7225.
# [I 2024-01-28 14:42:38,821] Trial 2 finished with value: 0.775625 and parameters: {'depth': 10, 'learning_rate': 0.16843044024837475, 'random_strength': 20, 'bagging_temperature': 0.743790240373023, 'l2_leaf_reg': 84.87800484472632, 'scale_pos_weight': 0.5462049415151637}. Best is trial 2 with value: 0.775625.
# [I 2024-01-28 14:42:39,468] Trial 3 finished with value: 0.711875 and parameters: {'depth': 5, 'learning_rate': 0.2586072117364293, 'random_strength': 15, 'bagging_temperature': 0.6860701433156989, 'l2_leaf_reg': 94.69427256040764, 'scale_pos_weight': 6.293220281972072}. Best is trial 2 with value: 0.775625.
# [I 2024-01-28 14:42:42,082] Trial 4 finished with value: 0.72875 and parameters: {'depth': 10, 'learning_rate': 0.10148321795057812, 'random_strength': 15, 'bagging_temperature': 0.3762840167686583, 'l2_leaf_reg': 52.098760835703814, 'scale_pos_weight': 5.090355917074867}. Best is trial 2 with value: 0.775625.
# [I 2024-01-28 14:42:44,746] Trial 5 finished with value: 0.714375 and parameters: {'depth': 10, 'learning_rate': 0.13130944165056746, 'random_strength': 10, 'bagging_temperature': 0.01462193563737435, 'l2_leaf_reg': 79.75553072021926, 'scale_pos_weight': 6.060026164036128}. Best is trial 2 with value: 0.775625.
# [I 2024-01-28 14:42:45,093] Trial 6 finished with value: 0.715625 and parameters: {'depth': 5, 'learning_rate': 0.21684247282944205, 'random_strength': 9, 'bagging_temperature': 0.049136359354709946, 'l2_leaf_reg': 3.587655175100072, 'scale_pos_weight': 6.524664945457828}. Best is trial 2 with value: 0.775625.
# [I 2024-01-28 14:42:45,742] Trial 7 finished with value: 0.779375 and parameters: {'depth': 5, 'learning_rate': 0.1532031170967094, 'random_strength': 1, 'bagging_temperature': 0.35822529541318004, 'l2_leaf_reg': 60.084453806510055, 'scale_pos_weight': 1.7439262426658362}. Best is trial 7 with value: 0.779375.
# [I 2024-01-28 14:42:47,653] Trial 8 finished with value: 0.6825 and parameters: {'depth': 10, 'learning_rate': 0.18988042708322844, 'random_strength': 13, 'bagging_temperature': 0.8056172250193019, 'l2_leaf_reg': 61.58641553881671, 'scale_pos_weight': 9.401156592058042}. Best is trial 7 with value: 0.779375.
# [I 2024-01-28 14:42:48,294] Trial 9 finished with value: 0.681875 and parameters: {'depth': 9, 'learning_rate': 0.22036041026409514, 'random_strength': 7, 'bagging_temperature': 0.7122246693057374, 'l2_leaf_reg': 8.849368029893402, 'scale_pos_weight': 9.71211913644117}. Best is trial 7 with value: 0.779375.
# [I 2024-01-28 14:42:50,028] Trial 10 finished with value: 0.7575 and parameters: {'depth': 6, 'learning_rate': 0.038196379062528804, 'random_strength': 1, 'bagging_temperature': 0.2538108072338504, 'l2_leaf_reg': 30.814788781257636, 'scale_pos_weight': 2.6969051567949753}. Best is trial 7 with value: 0.779375.
# [I 2024-01-28 14:42:50,584] Trial 11 finished with value: 0.721875 and parameters: {'depth': 4, 'learning_rate': 0.15685781867661094, 'random_strength': 20, 'bagging_temperature': 0.5807079194846987, 'l2_leaf_reg': 36.96621102824729, 'scale_pos_weight': 0.2445774741980511}. Best is trial 7 with value: 0.779375.
# [I 2024-01-28 14:42:51,362] Trial 12 finished with value: 0.755625 and parameters: {'depth': 7, 'learning_rate': 0.162732269043195, 'random_strength': 18, 'bagging_temperature': 0.9012723230280542, 'l2_leaf_reg': 98.10867794630789, 'scale_pos_weight': 2.5446134011359423}. Best is trial 7 with value: 0.779375.
# [I 2024-01-28 14:42:51,772] Trial 13 finished with value: 0.76125 and parameters: {'depth': 4, 'learning_rate': 0.2975189897222861, 'random_strength': 1, 'bagging_temperature': 0.27964658787667895, 'l2_leaf_reg': 77.96658267095901, 'scale_pos_weight': 2.3731962270062974}. Best is trial 7 with value: 0.779375.
# [I 2024-01-28 14:42:52,648] Trial 14 finished with value: 0.775625 and parameters: {'depth': 8, 'learning_rate': 0.12015172628849378, 'random_strength': 6, 'bagging_temperature': 0.9764712645079046, 'l2_leaf_reg': 41.86722034548779, 'scale_pos_weight': 1.768801255474422}. Best is trial 7 with value: 0.779375.
# [I 2024-01-28 14:42:53,335] Trial 15 finished with value: 0.7425 and parameters: {'depth': 6, 'learning_rate': 0.18501358644415838, 'random_strength': 18, 'bagging_temperature': 0.5402914608372357, 'l2_leaf_reg': 62.241833536989525, 'scale_pos_weight': 3.811334235873045}. Best is trial 7 with value: 0.779375.
# [I 2024-01-28 14:42:54,410] Trial 16 finished with value: 0.785625 and parameters: {'depth': 8, 'learning_rate': 0.07995968748655864, 'random_strength': 4, 'bagging_temperature': 0.6867841280620068, 'l2_leaf_reg': 21.107366635913753, 'scale_pos_weight': 1.20415575312665}. Best is trial 16 with value: 0.785625.
# [I 2024-01-28 14:42:55,632] Trial 17 finished with value: 0.740625 and parameters: {'depth': 8, 'learning_rate': 0.07088253546502395, 'random_strength': 4, 'bagging_temperature': 0.19579371501336684, 'l2_leaf_reg': 18.149773277584462, 'scale_pos_weight': 3.9338131172084534}. Best is trial 16 with value: 0.785625.
# [I 2024-01-28 14:42:56,566] Trial 18 finished with value: 0.785 and parameters: {'depth': 6, 'learning_rate': 0.0821935991244156, 'random_strength': 4, 'bagging_temperature': 0.6114689561970575, 'l2_leaf_reg': 22.77121345163215, 'scale_pos_weight': 1.326395472805147}. Best is trial 16 with value: 0.785625.
# [I 2024-01-28 14:42:57,633] Trial 19 finished with value: 0.739375 and parameters: {'depth': 6, 'learning_rate': 0.05651616278187375, 'random_strength': 4, 'bagging_temperature': 0.6291522088303987, 'l2_leaf_reg': 21.881547462408058, 'scale_pos_weight': 3.7272524318842795}. Best is trial 16 with value: 0.785625.
# [I 2024-01-28 14:42:59,001] Trial 20 finished with value: 0.70625 and parameters: {'depth': 9, 'learning_rate': 0.09706180879742268, 'random_strength': 7, 'bagging_temperature': 0.5028350326082993, 'l2_leaf_reg': 20.051241634783544, 'scale_pos_weight': 7.881102892901211}. Best is trial 16 with value: 0.785625.
# [I 2024-01-28 14:43:01,554] Trial 21 finished with value: 0.78375 and parameters: {'depth': 5, 'learning_rate': 0.028377265442153084, 'random_strength': 2, 'bagging_temperature': 0.4278324391038093, 'l2_leaf_reg': 48.74568633715799, 'scale_pos_weight': 1.4644608972284794}. Best is trial 16 with value: 0.785625.
# [I 2024-01-28 14:43:04,196] Trial 22 finished with value: 0.7925 and parameters: {'depth': 6, 'learning_rate': 0.02923814046460489, 'random_strength': 3, 'bagging_temperature': 0.45738852246372314, 'l2_leaf_reg': 30.10576035314809, 'scale_pos_weight': 1.2536993295611185}. Best is trial 22 with value: 0.7925.
# [I 2024-01-28 14:43:05,708] Trial 23 finished with value: 0.7925 and parameters: {'depth': 7, 'learning_rate': 0.05424508813155686, 'random_strength': 5, 'bagging_temperature': 0.8242322346718878, 'l2_leaf_reg': 30.988524979933015, 'scale_pos_weight': 0.9176272512200858}. Best is trial 22 with value: 0.7925.
# [I 2024-01-28 14:43:07,330] Trial 24 finished with value: 0.795625 and parameters: {'depth': 7, 'learning_rate': 0.050734638603400384, 'random_strength': 8, 'bagging_temperature': 0.8525531236613784, 'l2_leaf_reg': 33.66830714081496, 'scale_pos_weight': 1.002767060585625}. Best is trial 24 with value: 0.795625.
# [I 2024-01-28 14:43:08,989] Trial 25 finished with value: 0.754375 and parameters: {'depth': 7, 'learning_rate': 0.04505847930466993, 'random_strength': 8, 'bagging_temperature': 0.8447398596916643, 'l2_leaf_reg': 32.46860378130921, 'scale_pos_weight': 2.8644705482485446}. Best is trial 24 with value: 0.795625.
# [I 2024-01-28 14:43:12,307] Trial 26 finished with value: 0.790625 and parameters: {'depth': 7, 'learning_rate': 0.010371553608729378, 'random_strength': 6, 'bagging_temperature': 0.9986531597517966, 'l2_leaf_reg': 44.597035899327686, 'scale_pos_weight': 0.9046969350254415}. Best is trial 24 with value: 0.795625.
# [I 2024-01-28 14:43:13,929] Trial 27 finished with value: 0.7475 and parameters: {'depth': 6, 'learning_rate': 0.05781625446716748, 'random_strength': 11, 'bagging_temperature': 0.8601808265099983, 'l2_leaf_reg': 30.52485552371626, 'scale_pos_weight': 3.3029061803955155}. Best is trial 24 with value: 0.795625.
# [I 2024-01-28 14:43:16,109] Trial 28 finished with value: 0.726875 and parameters: {'depth': 7, 'learning_rate': 0.029732806095588156, 'random_strength': 6, 'bagging_temperature': 0.7796095095233737, 'l2_leaf_reg': 12.569131165090674, 'scale_pos_weight': 5.09348395541064}. Best is trial 24 with value: 0.795625.
# [I 2024-01-28 14:43:16,698] Trial 29 finished with value: 0.74375 and parameters: {'depth': 7, 'learning_rate': 0.1129338364837125, 'random_strength': 3, 'bagging_temperature': 0.9230590729961267, 'l2_leaf_reg': 37.782662300162066, 'scale_pos_weight': 0.39727163731111803}. Best is trial 24 with value: 0.795625.
# [I 2024-01-28 14:43:18,908] Trial 30 finished with value: 0.760625 and parameters: {'depth': 9, 'learning_rate': 0.06764856972629814, 'random_strength': 9, 'bagging_temperature': 0.455423777454923, 'l2_leaf_reg': 51.19095195289326, 'scale_pos_weight': 2.1938425134702753}. Best is trial 24 with value: 0.795625.
# [I 2024-01-28 14:43:22,124] Trial 31 finished with value: 0.781875 and parameters: {'depth': 7, 'learning_rate': 0.010349011698908766, 'random_strength': 6, 'bagging_temperature': 0.9928419823036947, 'l2_leaf_reg': 43.520899292490284, 'scale_pos_weight': 0.7707170681220807}. Best is trial 24 with value: 0.795625.
# [I 2024-01-28 14:43:25,646] Trial 32 finished with value: 0.7975 and parameters: {'depth': 8, 'learning_rate': 0.02042594828682621, 'random_strength': 5, 'bagging_temperature': 0.906406331669291, 'l2_leaf_reg': 28.811165456530333, 'scale_pos_weight': 0.9148897773399653}. Best is trial 32 with value: 0.7975.
# [I 2024-01-28 14:43:27,177] Trial 33 finished with value: 0.71 and parameters: {'depth': 8, 'learning_rate': 0.04301537761432256, 'random_strength': 5, 'bagging_temperature': 0.8960423982543833, 'l2_leaf_reg': 26.091751486075843, 'scale_pos_weight': 0.22178045775459487}. Best is trial 32 with value: 0.7975.
# [I 2024-01-28 14:43:29,814] Trial 34 finished with value: 0.766875 and parameters: {'depth': 8, 'learning_rate': 0.02556846825956425, 'random_strength': 3, 'bagging_temperature': 0.7709649490547019, 'l2_leaf_reg': 35.853743241503764, 'scale_pos_weight': 1.9976206012608693}. Best is trial 32 with value: 0.7975.
# [I 2024-01-28 14:43:31,171] Trial 35 finished with value: 0.79375 and parameters: {'depth': 6, 'learning_rate': 0.05123974314822678, 'random_strength': 8, 'bagging_temperature': 0.817569930568585, 'l2_leaf_reg': 28.483859634200513, 'scale_pos_weight': 1.1426698467591623}. Best is trial 32 with value: 0.7975.
# [I 2024-01-28 14:43:31,963] Trial 36 finished with value: 0.75125 and parameters: {'depth': 6, 'learning_rate': 0.0831295081252166, 'random_strength': 12, 'bagging_temperature': 0.6569257807484918, 'l2_leaf_reg': 15.192382741294855, 'scale_pos_weight': 3.157675641489104}. Best is trial 32 with value: 0.7975.
# [I 2024-01-28 14:43:34,516] Trial 37 finished with value: 0.78 and parameters: {'depth': 5, 'learning_rate': 0.025109471489490793, 'random_strength': 8, 'bagging_temperature': 0.9357469803818864, 'l2_leaf_reg': 26.192094424208072, 'scale_pos_weight': 1.5381422289614144}. Best is trial 32 with value: 0.7975.
# [I 2024-01-28 14:43:34,959] Trial 38 finished with value: 0.720625 and parameters: {'depth': 6, 'learning_rate': 0.13066687424903062, 'random_strength': 9, 'bagging_temperature': 0.7638823678541218, 'l2_leaf_reg': 0.04467377903420555, 'scale_pos_weight': 4.602389975521072}. Best is trial 32 with value: 0.7975.
# [I 2024-01-28 14:43:36,346] Trial 39 finished with value: 0.780625 and parameters: {'depth': 5, 'learning_rate': 0.10054433683108444, 'random_strength': 10, 'bagging_temperature': 0.7216607390893658, 'l2_leaf_reg': 55.57603518477153, 'scale_pos_weight': 0.7537531916275868}. Best is trial 32 with value: 0.7975.
# [I 2024-01-28 14:43:40,167] Trial 40 finished with value: 0.70625 and parameters: {'depth': 9, 'learning_rate': 0.04223066968682103, 'random_strength': 8, 'bagging_temperature': 0.37558779844732004, 'l2_leaf_reg': 41.09472943143248, 'scale_pos_weight': 6.986364047941815}. Best is trial 32 with value: 0.7975.
# [I 2024-01-28 14:43:41,821] Trial 41 finished with value: 0.798125 and parameters: {'depth': 7, 'learning_rate': 0.06145709757377593, 'random_strength': 5, 'bagging_temperature': 0.8329094310148716, 'l2_leaf_reg': 26.997488820124218, 'scale_pos_weight': 1.035462692310207}. Best is trial 41 with value: 0.798125.
# [I 2024-01-28 14:43:42,734] Trial 42 finished with value: 0.660625 and parameters: {'depth': 7, 'learning_rate': 0.0634064884073, 'random_strength': 2, 'bagging_temperature': 0.8284348703540289, 'l2_leaf_reg': 8.925354680531829, 'scale_pos_weight': 0.11955011334751031}. Best is trial 41 with value: 0.798125.
# [I 2024-01-28 14:43:46,961] Trial 43 finished with value: 0.765 and parameters: {'depth': 8, 'learning_rate': 0.01956049368746124, 'random_strength': 7, 'bagging_temperature': 0.8689343453268419, 'l2_leaf_reg': 26.167916179850216, 'scale_pos_weight': 2.1012301974143126}. Best is trial 41 with value: 0.798125.
# [I 2024-01-28 14:43:48,625] Trial 44 finished with value: 0.789375 and parameters: {'depth': 6, 'learning_rate': 0.046991142453689766, 'random_strength': 5, 'bagging_temperature': 0.9470833643065181, 'l2_leaf_reg': 35.07582995367421, 'scale_pos_weight': 1.234125245807638}. Best is trial 41 with value: 0.798125.
# [I 2024-01-28 14:43:50,409] Trial 45 finished with value: 0.775625 and parameters: {'depth': 7, 'learning_rate': 0.033623093975356885, 'random_strength': 3, 'bagging_temperature': 0.32202716146639315, 'l2_leaf_reg': 27.115422440859017, 'scale_pos_weight': 0.591486959957433}. Best is trial 41 with value: 0.798125.
# [I 2024-01-28 14:43:51,313] Trial 46 finished with value: 0.7725 and parameters: {'depth': 6, 'learning_rate': 0.09170737073515382, 'random_strength': 7, 'bagging_temperature': 0.11978127476079392, 'l2_leaf_reg': 15.025730492203685, 'scale_pos_weight': 1.916460985630748}. Best is trial 41 with value: 0.798125.
# [I 2024-01-28 14:43:52,681] Trial 47 finished with value: 0.79625 and parameters: {'depth': 8, 'learning_rate': 0.07373024988283738, 'random_strength': 10, 'bagging_temperature': 0.5056652159157922, 'l2_leaf_reg': 70.33077611557772, 'scale_pos_weight': 1.0503159978895527}. Best is trial 41 with value: 0.798125.
# [I 2024-01-28 14:43:53,787] Trial 48 finished with value: 0.760625 and parameters: {'depth': 8, 'learning_rate': 0.10980164134710382, 'random_strength': 13, 'bagging_temperature': 0.7407678290198394, 'l2_leaf_reg': 70.59513873228322, 'scale_pos_weight': 2.6106748737744345}. Best is trial 41 with value: 0.798125.
# [I 2024-01-28 14:43:55,886] Trial 49 finished with value: 0.770625 and parameters: {'depth': 9, 'learning_rate': 0.07059074137523527, 'random_strength': 11, 'bagging_temperature': 0.8087948405517246, 'l2_leaf_reg': 87.52902773654421, 'scale_pos_weight': 1.6952595472301533}. Best is trial 41 with value: 0.798125.
# [I 2024-01-28 14:43:56,685] Trial 50 finished with value: 0.790625 and parameters: {'depth': 8, 'learning_rate': 0.2604454969952572, 'random_strength': 14, 'bagging_temperature': 0.5576952892402116, 'l2_leaf_reg': 70.14728502280458, 'scale_pos_weight': 0.9850393611153672}. Best is trial 41 with value: 0.798125.
# [I 2024-01-28 14:43:58,925] Trial 51 finished with value: 0.770625 and parameters: {'depth': 7, 'learning_rate': 0.051576941632233704, 'random_strength': 10, 'bagging_temperature': 0.8869763044841881, 'l2_leaf_reg': 40.35281497664838, 'scale_pos_weight': 0.533591622287753}. Best is trial 41 with value: 0.798125.
# [I 2024-01-28 14:44:01,349] Trial 52 finished with value: 0.79625 and parameters: {'depth': 8, 'learning_rate': 0.03798483228936223, 'random_strength': 8, 'bagging_temperature': 0.4804478258948205, 'l2_leaf_reg': 45.68476450679632, 'scale_pos_weight': 1.202516061428168}. Best is trial 41 with value: 0.798125.
# [I 2024-01-28 14:44:02,995] Trial 53 finished with value: 0.696875 and parameters: {'depth': 8, 'learning_rate': 0.07647718011307579, 'random_strength': 9, 'bagging_temperature': 0.6723232081541818, 'l2_leaf_reg': 53.98011768949151, 'scale_pos_weight': 8.676126811673496}. Best is trial 41 with value: 0.798125.
# [I 2024-01-28 14:44:04,737] Trial 54 finished with value: 0.774375 and parameters: {'depth': 9, 'learning_rate': 0.08661725364300073, 'random_strength': 8, 'bagging_temperature': 0.6051330411678927, 'l2_leaf_reg': 58.11778193139628, 'scale_pos_weight': 1.7570102535141627}. Best is trial 41 with value: 0.798125.
# [I 2024-01-28 14:44:06,754] Trial 55 finished with value: 0.75625 and parameters: {'depth': 8, 'learning_rate': 0.06430938305113078, 'random_strength': 11, 'bagging_temperature': 0.48507879006603555, 'l2_leaf_reg': 47.67811633931359, 'scale_pos_weight': 2.3309470698442576}. Best is trial 41 with value: 0.798125.
# [I 2024-01-28 14:44:07,629] Trial 56 finished with value: 0.630625 and parameters: {'depth': 8, 'learning_rate': 0.13992121633412352, 'random_strength': 7, 'bagging_temperature': 0.5242621032163989, 'l2_leaf_reg': 87.79139578623989, 'scale_pos_weight': 0.10056818637124398}. Best is trial 41 with value: 0.798125.
# [I 2024-01-28 14:44:11,841] Trial 57 finished with value: 0.795 and parameters: {'depth': 9, 'learning_rate': 0.03517197552284159, 'random_strength': 12, 'bagging_temperature': 0.22883112862198407, 'l2_leaf_reg': 64.31013322333543, 'scale_pos_weight': 1.1356712566036888}. Best is trial 41 with value: 0.798125.
# [I 2024-01-28 14:44:22,360] Trial 58 finished with value: 0.78125 and parameters: {'depth': 10, 'learning_rate': 0.018612094229991123, 'random_strength': 16, 'bagging_temperature': 0.18388020822961715, 'l2_leaf_reg': 74.33942555309137, 'scale_pos_weight': 1.4848008877494265}. Best is trial 41 with value: 0.798125.
# [I 2024-01-28 14:44:29,159] Trial 59 finished with value: 0.753125 and parameters: {'depth': 10, 'learning_rate': 0.03671425552802108, 'random_strength': 12, 'bagging_temperature': 0.07281279124642859, 'l2_leaf_reg': 67.37106342020857, 'scale_pos_weight': 2.9068720687802494}. Best is trial 41 with value: 0.798125.
# [I 2024-01-28 14:44:30,322] Trial 60 finished with value: 0.775 and parameters: {'depth': 9, 'learning_rate': 0.17732568877065194, 'random_strength': 13, 'bagging_temperature': 0.2419027275730286, 'l2_leaf_reg': 81.98255678635135, 'scale_pos_weight': 0.6210886800843907}. Best is trial 41 with value: 0.798125.
# [I 2024-01-28 14:44:32,804] Trial 61 finished with value: 0.794375 and parameters: {'depth': 8, 'learning_rate': 0.04977668851419288, 'random_strength': 10, 'bagging_temperature': 0.31736488165025906, 'l2_leaf_reg': 46.05489492066274, 'scale_pos_weight': 1.0456428886555758}. Best is trial 41 with value: 0.798125.
# [I 2024-01-28 14:44:33,415] Trial 62 finished with value: 0.793125 and parameters: {'depth': 8, 'learning_rate': 0.20704859309114107, 'random_strength': 10, 'bagging_temperature': 0.2935429836430904, 'l2_leaf_reg': 62.990729944957764, 'scale_pos_weight': 1.0503902148983926}. Best is trial 41 with value: 0.798125.
# [I 2024-01-28 14:44:36,677] Trial 63 finished with value: 0.781875 and parameters: {'depth': 9, 'learning_rate': 0.037780806684650406, 'random_strength': 9, 'bagging_temperature': 0.3379380313564851, 'l2_leaf_reg': 47.60318431879505, 'scale_pos_weight': 1.5194761789349243}. Best is trial 41 with value: 0.798125.
# [I 2024-01-28 14:44:38,460] Trial 64 finished with value: 0.76375 and parameters: {'depth': 8, 'learning_rate': 0.061174373027952506, 'random_strength': 11, 'bagging_temperature': 0.41433846505885275, 'l2_leaf_reg': 58.23179340359912, 'scale_pos_weight': 0.4671810812522239}. Best is trial 41 with value: 0.798125.
# [I 2024-01-28 14:44:44,056] Trial 65 finished with value: 0.714375 and parameters: {'depth': 9, 'learning_rate': 0.01885178362696921, 'random_strength': 14, 'bagging_temperature': 0.24507706287085007, 'l2_leaf_reg': 63.68924171805106, 'scale_pos_weight': 5.6800389162793135}. Best is trial 41 with value: 0.798125.
# [I 2024-01-28 14:44:45,583] Trial 66 finished with value: 0.794375 and parameters: {'depth': 7, 'learning_rate': 0.0742100931280884, 'random_strength': 5, 'bagging_temperature': 0.19611289923702974, 'l2_leaf_reg': 38.080298832362125, 'scale_pos_weight': 0.9197744043276587}. Best is trial 41 with value: 0.798125.
# [I 2024-01-28 14:44:47,457] Trial 67 finished with value: 0.7525 and parameters: {'depth': 8, 'learning_rate': 0.05513492170709552, 'random_strength': 12, 'bagging_temperature': 0.1447408503248056, 'l2_leaf_reg': 44.73332008294808, 'scale_pos_weight': 2.403353900903374}. Best is trial 41 with value: 0.798125.
# [I 2024-01-28 14:44:49,647] Trial 68 finished with value: 0.785625 and parameters: {'depth': 7, 'learning_rate': 0.03797969364838232, 'random_strength': 10, 'bagging_temperature': 0.4075124929096785, 'l2_leaf_reg': 74.80427451026895, 'scale_pos_weight': 1.3420690098523942}. Best is trial 41 with value: 0.798125.
# [I 2024-01-28 14:44:52,535] Trial 69 finished with value: 0.76625 and parameters: {'depth': 9, 'learning_rate': 0.04575424595635296, 'random_strength': 9, 'bagging_temperature': 0.2817516896761824, 'l2_leaf_reg': 33.67651417703409, 'scale_pos_weight': 1.951233527251656}. Best is trial 41 with value: 0.798125.
# [I 2024-01-28 14:44:55,467] Trial 70 finished with value: 0.739375 and parameters: {'depth': 7, 'learning_rate': 0.024527841949334078, 'random_strength': 6, 'bagging_temperature': 0.7020749402338791, 'l2_leaf_reg': 53.90283680654653, 'scale_pos_weight': 0.33997666617762823}. Best is trial 41 with value: 0.798125.
# [I 2024-01-28 14:44:56,719] Trial 71 finished with value: 0.79 and parameters: {'depth': 7, 'learning_rate': 0.07559475463363692, 'random_strength': 4, 'bagging_temperature': 0.15884634142588872, 'l2_leaf_reg': 38.11268523503055, 'scale_pos_weight': 0.8505789305619871}. Best is trial 41 with value: 0.798125.
# [I 2024-01-28 14:44:57,748] Trial 72 finished with value: 0.794375 and parameters: {'depth': 7, 'learning_rate': 0.09001733697033842, 'random_strength': 6, 'bagging_temperature': 0.22229311490762071, 'l2_leaf_reg': 38.926584075435265, 'scale_pos_weight': 1.1372292112574924}. Best is trial 41 with value: 0.798125.
# [I 2024-01-28 14:44:59,088] Trial 73 finished with value: 0.773125 and parameters: {'depth': 8, 'learning_rate': 0.07237209720396766, 'random_strength': 5, 'bagging_temperature': 0.08646543661414119, 'l2_leaf_reg': 45.65609233642413, 'scale_pos_weight': 1.6912743460956627}. Best is trial 41 with value: 0.798125.
# [I 2024-01-28 14:45:00,353] Trial 74 finished with value: 0.789375 and parameters: {'depth': 7, 'learning_rate': 0.05734785304621347, 'random_strength': 2, 'bagging_temperature': 0.3141452666071883, 'l2_leaf_reg': 23.98768895095261, 'scale_pos_weight': 0.8348542500432595}. Best is trial 41 with value: 0.798125.
# [I 2024-01-28 14:45:04,500] Trial 75 finished with value: 0.788125 and parameters: {'depth': 8, 'learning_rate': 0.014030094689017319, 'random_strength': 5, 'bagging_temperature': 0.19988415941874121, 'l2_leaf_reg': 32.045529586487675, 'scale_pos_weight': 1.3375254031911197}. Best is trial 41 with value: 0.798125.
# [I 2024-01-28 14:45:06,909] Trial 76 finished with value: 0.780625 and parameters: {'depth': 7, 'learning_rate': 0.029395400896494426, 'random_strength': 8, 'bagging_temperature': 0.9630408502833395, 'l2_leaf_reg': 41.83647583746374, 'scale_pos_weight': 0.6404487595984726}. Best is trial 41 with value: 0.798125.
# [I 2024-01-28 14:45:08,096] Trial 77 finished with value: 0.791875 and parameters: {'depth': 8, 'learning_rate': 0.10726635254766434, 'random_strength': 7, 'bagging_temperature': 0.21913283803841638, 'l2_leaf_reg': 52.0290772634725, 'scale_pos_weight': 1.0803639397288793}. Best is trial 41 with value: 0.798125.
# [I 2024-01-28 14:45:09,435] Trial 78 finished with value: 0.74 and parameters: {'depth': 7, 'learning_rate': 0.06321483742036146, 'random_strength': 12, 'bagging_temperature': 0.3443869429336386, 'l2_leaf_reg': 35.41980704192035, 'scale_pos_weight': 0.33272127776931804}. Best is trial 41 with value: 0.798125.
# [I 2024-01-28 14:45:11,423] Trial 79 finished with value: 0.7625 and parameters: {'depth': 8, 'learning_rate': 0.0497252475267882, 'random_strength': 5, 'bagging_temperature': 0.9048798749475471, 'l2_leaf_reg': 49.96101277969785, 'scale_pos_weight': 2.1786350385015574}. Best is trial 41 with value: 0.798125.
# [I 2024-01-28 14:45:12,294] Trial 80 finished with value: 0.74625 and parameters: {'depth': 7, 'learning_rate': 0.09597445378425945, 'random_strength': 4, 'bagging_temperature': 0.012533910202223941, 'l2_leaf_reg': 18.730178908101852, 'scale_pos_weight': 3.5429651594647593}. Best is trial 41 with value: 0.798125.
# [I 2024-01-28 14:45:13,071] Trial 81 finished with value: 0.790625 and parameters: {'depth': 7, 'learning_rate': 0.1187721062327559, 'random_strength': 6, 'bagging_temperature': 0.2638636914774065, 'l2_leaf_reg': 29.632624654184426, 'scale_pos_weight': 1.2081037304402167}. Best is trial 41 with value: 0.798125.
# [I 2024-01-28 14:45:14,037] Trial 82 finished with value: 0.778125 and parameters: {'depth': 7, 'learning_rate': 0.08940090451246156, 'random_strength': 6, 'bagging_temperature': 0.2048170743619653, 'l2_leaf_reg': 37.58599276517654, 'scale_pos_weight': 1.5801459744482267}. Best is trial 41 with value: 0.798125.
# [I 2024-01-28 14:45:15,216] Trial 83 finished with value: 0.79875 and parameters: {'depth': 7, 'learning_rate': 0.07887593730072064, 'random_strength': 5, 'bagging_temperature': 0.13576344903827364, 'l2_leaf_reg': 40.86156245622093, 'scale_pos_weight': 0.9511754407184229}. Best is trial 83 with value: 0.79875.
# [I 2024-01-28 14:45:16,445] Trial 84 finished with value: 0.73625 and parameters: {'depth': 8, 'learning_rate': 0.08117794610078714, 'random_strength': 3, 'bagging_temperature': 0.17296625593173803, 'l2_leaf_reg': 42.88548119464897, 'scale_pos_weight': 4.3199154501726715}. Best is trial 83 with value: 0.79875.
# [I 2024-01-28 14:45:18,394] Trial 85 finished with value: 0.78875 and parameters: {'depth': 7, 'learning_rate': 0.04236881591359881, 'random_strength': 4, 'bagging_temperature': 0.11829176984097742, 'l2_leaf_reg': 33.20086750932771, 'scale_pos_weight': 0.8165803315138718}. Best is trial 83 with value: 0.79875.
# [I 2024-01-28 14:45:21,247] Trial 86 finished with value: 0.769375 and parameters: {'depth': 10, 'learning_rate': 0.06914968713607926, 'random_strength': 7, 'bagging_temperature': 0.14850949346607714, 'l2_leaf_reg': 23.66938239067276, 'scale_pos_weight': 1.9233131089958206}. Best is trial 83 with value: 0.79875.
# [I 2024-01-28 14:45:23,861] Trial 87 finished with value: 0.765 and parameters: {'depth': 8, 'learning_rate': 0.0313209384192586, 'random_strength': 10, 'bagging_temperature': 0.8547297623293281, 'l2_leaf_reg': 46.32612493602703, 'scale_pos_weight': 0.5116229500378989}. Best is trial 83 with value: 0.79875.
# [I 2024-01-28 14:45:25,344] Trial 88 finished with value: 0.791875 and parameters: {'depth': 7, 'learning_rate': 0.0540563442975151, 'random_strength': 11, 'bagging_temperature': 0.37810924317671524, 'l2_leaf_reg': 39.952646228154464, 'scale_pos_weight': 0.9829316165823468}. Best is trial 83 with value: 0.79875.
# [I 2024-01-28 14:45:26,920] Trial 89 finished with value: 0.78375 and parameters: {'depth': 9, 'learning_rate': 0.07818630394053404, 'random_strength': 9, 'bagging_temperature': 0.788555740811252, 'l2_leaf_reg': 28.346607505299012, 'scale_pos_weight': 1.4006620066006632}. Best is trial 83 with value: 0.79875.
# [I 2024-01-28 14:45:28,912] Trial 90 finished with value: 0.783125 and parameters: {'depth': 8, 'learning_rate': 0.04746138999749057, 'random_strength': 5, 'bagging_temperature': 0.11156038215763486, 'l2_leaf_reg': 35.30285559434061, 'scale_pos_weight': 0.7158405741124296}. Best is trial 83 with value: 0.79875.
# [I 2024-01-28 14:45:29,933] Trial 91 finished with value: 0.795 and parameters: {'depth': 7, 'learning_rate': 0.0938818246426262, 'random_strength': 6, 'bagging_temperature': 0.23131646225519642, 'l2_leaf_reg': 38.36635996098808, 'scale_pos_weight': 1.1422679359377406}. Best is trial 83 with value: 0.79875.
# [I 2024-01-28 14:45:30,928] Trial 92 finished with value: 0.769375 and parameters: {'depth': 7, 'learning_rate': 0.10362169688027832, 'random_strength': 5, 'bagging_temperature': 0.05520130816956739, 'l2_leaf_reg': 42.11670345556198, 'scale_pos_weight': 1.837904051919423}. Best is trial 83 with value: 0.79875.
# [I 2024-01-28 14:45:32,788] Trial 93 finished with value: 0.70625 and parameters: {'depth': 7, 'learning_rate': 0.05933112323515766, 'random_strength': 6, 'bagging_temperature': 0.4529957085403086, 'l2_leaf_reg': 48.7382123514566, 'scale_pos_weight': 7.186814902873996}. Best is trial 83 with value: 0.79875.
# [I 2024-01-28 14:45:34,190] Trial 94 finished with value: 0.739375 and parameters: {'depth': 6, 'learning_rate': 0.06599225124258987, 'random_strength': 8, 'bagging_temperature': 0.5760402324199008, 'l2_leaf_reg': 31.84936100924401, 'scale_pos_weight': 0.3231729114831162}. Best is trial 83 with value: 0.79875.
# [I 2024-01-28 14:45:37,661] Trial 95 finished with value: 0.793125 and parameters: {'depth': 7, 'learning_rate': 0.02175532052248457, 'random_strength': 7, 'bagging_temperature': 0.2958798819012409, 'l2_leaf_reg': 66.81339338244501, 'scale_pos_weight': 1.1305475282211594}. Best is trial 83 with value: 0.79875.
# [I 2024-01-28 14:45:40,492] Trial 96 finished with value: 0.778125 and parameters: {'depth': 7, 'learning_rate': 0.03553099232551395, 'random_strength': 4, 'bagging_temperature': 0.6467652524812231, 'l2_leaf_reg': 43.8745043704279, 'scale_pos_weight': 1.5820489590999083}. Best is trial 83 with value: 0.79875.
# [I 2024-01-28 14:45:41,762] Trial 97 finished with value: 0.648125 and parameters: {'depth': 8, 'learning_rate': 0.0727137069223273, 'random_strength': 4, 'bagging_temperature': 0.9225354110970526, 'l2_leaf_reg': 37.22545501300392, 'scale_pos_weight': 0.10440325421532237}. Best is trial 83 with value: 0.79875.
# [I 2024-01-28 14:45:43,238] Trial 98 finished with value: 0.78625 and parameters: {'depth': 8, 'learning_rate': 0.09647548914801948, 'random_strength': 8, 'bagging_temperature': 0.22383215592094427, 'l2_leaf_reg': 71.61537562828165, 'scale_pos_weight': 1.327499381788333}. Best is trial 83 with value: 0.79875.
# [I 2024-01-28 14:45:44,819] Trial 99 finished with value: 0.7925 and parameters: {'depth': 7, 'learning_rate': 0.08516264354786984, 'random_strength': 13, 'bagging_temperature': 0.17936948900849586, 'l2_leaf_reg': 79.30881754156054, 'scale_pos_weight': 0.9021107231049308}. Best is trial 83 with value: 0.79875.
# [I 2024-01-28 14:45:47,899] A new study created in memory with name: no-name-850ca935-b208-4e69-aeed-3d30b5559618
# [I 2024-01-28 14:45:48,293] Trial 0 finished with value: 0.7075 and parameters: {'depth': 4, 'learning_rate': 0.19677891280179102, 'random_strength': 16, 'bagging_temperature': 0.22000925844206087, 'l2_leaf_reg': 5.139349195262017, 'scale_pos_weight': 5.164991172834408}. Best is trial 0 with value: 0.7075.
# [I 2024-01-28 14:45:48,806] Trial 1 finished with value: 0.725625 and parameters: {'depth': 5, 'learning_rate': 0.1945322488673088, 'random_strength': 3, 'bagging_temperature': 0.22315718499728943, 'l2_leaf_reg': 40.156816241555944, 'scale_pos_weight': 3.2959979676735967}. Best is trial 1 with value: 0.725625.
# [I 2024-01-28 14:45:50,022] Trial 2 finished with value: 0.718125 and parameters: {'depth': 9, 'learning_rate': 0.1480676695101086, 'random_strength': 14, 'bagging_temperature': 0.12411140698808754, 'l2_leaf_reg': 44.055172723405654, 'scale_pos_weight': 4.033621776198605}. Best is trial 1 with value: 0.725625.
# [I 2024-01-28 14:45:50,667] Trial 3 finished with value: 0.7425 and parameters: {'depth': 5, 'learning_rate': 0.21928207969790708, 'random_strength': 14, 'bagging_temperature': 0.6997230205208448, 'l2_leaf_reg': 56.07465714780189, 'scale_pos_weight': 2.4553742310430198}. Best is trial 3 with value: 0.7425.
# [I 2024-01-28 14:45:51,371] Trial 4 finished with value: 0.733125 and parameters: {'depth': 6, 'learning_rate': 0.20791792040817142, 'random_strength': 11, 'bagging_temperature': 0.24555008566013892, 'l2_leaf_reg': 77.85818941631801, 'scale_pos_weight': 3.201884708056281}. Best is trial 3 with value: 0.7425.
# [I 2024-01-28 14:45:52,108] Trial 5 finished with value: 0.714375 and parameters: {'depth': 6, 'learning_rate': 0.14254499916269553, 'random_strength': 9, 'bagging_temperature': 0.48455563615212927, 'l2_leaf_reg': 17.07020943243445, 'scale_pos_weight': 4.568610379334052}. Best is trial 3 with value: 0.7425.
# [I 2024-01-28 14:45:52,882] Trial 6 finished with value: 0.724375 and parameters: {'depth': 9, 'learning_rate': 0.18860710281314122, 'random_strength': 17, 'bagging_temperature': 0.28490031513055103, 'l2_leaf_reg': 8.524889213718522, 'scale_pos_weight': 3.721446010012562}. Best is trial 3 with value: 0.7425.
# [I 2024-01-28 14:45:53,369] Trial 7 finished with value: 0.775 and parameters: {'depth': 7, 'learning_rate': 0.256850082631033, 'random_strength': 13, 'bagging_temperature': 0.7766074699882072, 'l2_leaf_reg': 18.526185908844802, 'scale_pos_weight': 0.5373809991175759}. Best is trial 7 with value: 0.775.
# [I 2024-01-28 14:45:54,223] Trial 8 finished with value: 0.775625 and parameters: {'depth': 7, 'learning_rate': 0.14907729242618167, 'random_strength': 11, 'bagging_temperature': 0.4056187388894422, 'l2_leaf_reg': 66.45600402735236, 'scale_pos_weight': 1.2157578171300927}. Best is trial 8 with value: 0.775625.
# [I 2024-01-28 14:45:55,870] Trial 9 finished with value: 0.69875 and parameters: {'depth': 4, 'learning_rate': 0.06186820002793916, 'random_strength': 19, 'bagging_temperature': 0.07243771521580933, 'l2_leaf_reg': 91.6443605472031, 'scale_pos_weight': 6.358318538190539}. Best is trial 8 with value: 0.775625.
# [I 2024-01-28 14:45:57,932] Trial 10 finished with value: 0.660625 and parameters: {'depth': 10, 'learning_rate': 0.06885373429346357, 'random_strength': 6, 'bagging_temperature': 0.9993180349348452, 'l2_leaf_reg': 68.18823012916704, 'scale_pos_weight': 8.50735982983421}. Best is trial 8 with value: 0.775625.
# [I 2024-01-28 14:45:58,371] Trial 11 finished with value: 0.776875 and parameters: {'depth': 8, 'learning_rate': 0.2884085892865132, 'random_strength': 8, 'bagging_temperature': 0.6931416031622577, 'l2_leaf_reg': 28.15294675945182, 'scale_pos_weight': 0.7358388990331033}. Best is trial 11 with value: 0.776875.
# [I 2024-01-28 14:45:58,819] Trial 12 finished with value: 0.72 and parameters: {'depth': 8, 'learning_rate': 0.29386599881379355, 'random_strength': 8, 'bagging_temperature': 0.493975387089249, 'l2_leaf_reg': 31.29411128613918, 'scale_pos_weight': 0.22495494049541842}. Best is trial 11 with value: 0.776875.
# [I 2024-01-28 14:46:00,404] Trial 13 finished with value: 0.76375 and parameters: {'depth': 8, 'learning_rate': 0.10363618177209083, 'random_strength': 5, 'bagging_temperature': 0.6484623337048567, 'l2_leaf_reg': 62.11097691478338, 'scale_pos_weight': 1.61450244416748}. Best is trial 11 with value: 0.776875.
# [I 2024-01-28 14:46:03,286] Trial 14 finished with value: 0.763125 and parameters: {'depth': 7, 'learning_rate': 0.024942223213720305, 'random_strength': 11, 'bagging_temperature': 0.40454972587839816, 'l2_leaf_reg': 29.500676667546823, 'scale_pos_weight': 1.5346201915519382}. Best is trial 11 with value: 0.776875.
# [I 2024-01-28 14:46:03,937] Trial 15 finished with value: 0.685625 and parameters: {'depth': 8, 'learning_rate': 0.2929999087012563, 'random_strength': 7, 'bagging_temperature': 0.9580938340971409, 'l2_leaf_reg': 95.38285125723448, 'scale_pos_weight': 6.246672034713699}. Best is trial 11 with value: 0.776875.
# [I 2024-01-28 14:46:05,370] Trial 16 finished with value: 0.659375 and parameters: {'depth': 10, 'learning_rate': 0.11212119176431193, 'random_strength': 1, 'bagging_temperature': 0.5938865519552274, 'l2_leaf_reg': 77.58485338349963, 'scale_pos_weight': 9.632619941328969}. Best is trial 11 with value: 0.776875.
# [I 2024-01-28 14:46:05,989] Trial 17 finished with value: 0.768125 and parameters: {'depth': 6, 'learning_rate': 0.23808177314956092, 'random_strength': 10, 'bagging_temperature': 0.855304300468142, 'l2_leaf_reg': 49.22001141172542, 'scale_pos_weight': 1.5599288346450624}. Best is trial 11 with value: 0.776875.
# [I 2024-01-28 14:46:06,930] Trial 18 finished with value: 0.755625 and parameters: {'depth': 9, 'learning_rate': 0.16982884740100895, 'random_strength': 4, 'bagging_temperature': 0.41712571987195346, 'l2_leaf_reg': 33.67002457732971, 'scale_pos_weight': 0.3480103174262289}. Best is trial 11 with value: 0.776875.
# [I 2024-01-28 14:46:07,839] Trial 19 finished with value: 0.735 and parameters: {'depth': 7, 'learning_rate': 0.11566777303243406, 'random_strength': 12, 'bagging_temperature': 0.5827941761112982, 'l2_leaf_reg': 69.43570711588254, 'scale_pos_weight': 2.4413567332207573}. Best is trial 11 with value: 0.776875.
# [I 2024-01-28 14:46:08,426] Trial 20 finished with value: 0.70125 and parameters: {'depth': 8, 'learning_rate': 0.26162962696705544, 'random_strength': 8, 'bagging_temperature': 0.7923026047329715, 'l2_leaf_reg': 20.166153749443005, 'scale_pos_weight': 5.859500783196515}. Best is trial 11 with value: 0.776875.
# [I 2024-01-28 14:46:08,902] Trial 21 finished with value: 0.784375 and parameters: {'depth': 7, 'learning_rate': 0.26728895271161357, 'random_strength': 13, 'bagging_temperature': 0.7526015536427475, 'l2_leaf_reg': 17.931726556249302, 'scale_pos_weight': 0.9029259575531251}. Best is trial 21 with value: 0.784375.
# [I 2024-01-28 14:46:09,334] Trial 22 finished with value: 0.768125 and parameters: {'depth': 7, 'learning_rate': 0.2697403202227961, 'random_strength': 16, 'bagging_temperature': 0.8716102162288184, 'l2_leaf_reg': 25.61075301470048, 'scale_pos_weight': 1.0791081644144906}. Best is trial 21 with value: 0.784375.
# [I 2024-01-28 14:46:09,786] Trial 23 finished with value: 0.740625 and parameters: {'depth': 7, 'learning_rate': 0.24061569556260173, 'random_strength': 10, 'bagging_temperature': 0.721192351890198, 'l2_leaf_reg': 1.4819191441473905, 'scale_pos_weight': 2.3739135193499425}. Best is trial 21 with value: 0.784375.
# [I 2024-01-28 14:46:10,166] Trial 24 finished with value: 0.7825 and parameters: {'depth': 6, 'learning_rate': 0.2998404465180042, 'random_strength': 13, 'bagging_temperature': 0.3606425814332338, 'l2_leaf_reg': 10.806456075857978, 'scale_pos_weight': 1.0225271634220912}. Best is trial 21 with value: 0.784375.
# [I 2024-01-28 14:46:10,637] Trial 25 finished with value: 0.7525 and parameters: {'depth': 5, 'learning_rate': 0.2989041118325391, 'random_strength': 20, 'bagging_temperature': 0.5715919739991981, 'l2_leaf_reg': 10.44591408157104, 'scale_pos_weight': 2.0543901982675448}. Best is trial 21 with value: 0.784375.
# [I 2024-01-28 14:46:11,045] Trial 26 finished with value: 0.680625 and parameters: {'depth': 6, 'learning_rate': 0.274346792566296, 'random_strength': 14, 'bagging_temperature': 0.32370812921722913, 'l2_leaf_reg': 13.773310543137164, 'scale_pos_weight': 0.1547177063351759}. Best is trial 21 with value: 0.784375.
# [I 2024-01-28 14:46:11,653] Trial 27 finished with value: 0.691875 and parameters: {'depth': 8, 'learning_rate': 0.2468447290599571, 'random_strength': 16, 'bagging_temperature': 0.6657610178989579, 'l2_leaf_reg': 24.649011031984685, 'scale_pos_weight': 7.434796249666105}. Best is trial 21 with value: 0.784375.
# [I 2024-01-28 14:46:12,382] Trial 28 finished with value: 0.783125 and parameters: {'depth': 6, 'learning_rate': 0.2259717674719698, 'random_strength': 13, 'bagging_temperature': 0.8955173416686459, 'l2_leaf_reg': 36.81315377562092, 'scale_pos_weight': 0.9297890889281356}. Best is trial 21 with value: 0.784375.
# [I 2024-01-28 14:46:12,740] Trial 29 finished with value: 0.72875 and parameters: {'depth': 4, 'learning_rate': 0.23046267211553625, 'random_strength': 17, 'bagging_temperature': 0.9209669063874213, 'l2_leaf_reg': 0.6484922754647489, 'scale_pos_weight': 2.93656830847459}. Best is trial 21 with value: 0.784375.
# [I 2024-01-28 14:46:13,151] Trial 30 finished with value: 0.70375 and parameters: {'depth': 5, 'learning_rate': 0.27075526685472545, 'random_strength': 13, 'bagging_temperature': 0.8126988086294851, 'l2_leaf_reg': 38.28466561814611, 'scale_pos_weight': 5.1141069971013104}. Best is trial 21 with value: 0.784375.
# [I 2024-01-28 14:46:13,609] Trial 31 finished with value: 0.7825 and parameters: {'depth': 6, 'learning_rate': 0.2782707955093297, 'random_strength': 15, 'bagging_temperature': 0.7375872035103308, 'l2_leaf_reg': 24.270796982928445, 'scale_pos_weight': 0.9223761768079222}. Best is trial 21 with value: 0.784375.
# [I 2024-01-28 14:46:14,039] Trial 32 finished with value: 0.77875 and parameters: {'depth': 6, 'learning_rate': 0.27838990282760334, 'random_strength': 15, 'bagging_temperature': 0.8649892333174607, 'l2_leaf_reg': 6.887016138794946, 'scale_pos_weight': 0.8874664828383172}. Best is trial 21 with value: 0.784375.
# [I 2024-01-28 14:46:14,715] Trial 33 finished with value: 0.761875 and parameters: {'depth': 6, 'learning_rate': 0.22415939372360294, 'random_strength': 18, 'bagging_temperature': 0.7551637454325267, 'l2_leaf_reg': 38.845042209140395, 'scale_pos_weight': 1.928618266770077}. Best is trial 21 with value: 0.784375.
# [I 2024-01-28 14:46:15,384] Trial 34 finished with value: 0.781875 and parameters: {'depth': 5, 'learning_rate': 0.2533709893428106, 'random_strength': 13, 'bagging_temperature': 0.9378959927562616, 'l2_leaf_reg': 46.17464584052949, 'scale_pos_weight': 1.0689719699370732}. Best is trial 21 with value: 0.784375.
# [I 2024-01-28 14:46:15,931] Trial 35 finished with value: 0.725 and parameters: {'depth': 5, 'learning_rate': 0.20964390051381596, 'random_strength': 15, 'bagging_temperature': 0.16361008531837262, 'l2_leaf_reg': 54.69675374412893, 'scale_pos_weight': 3.070866825999739}. Best is trial 21 with value: 0.784375.
# [I 2024-01-28 14:46:16,454] Trial 36 finished with value: 0.72125 and parameters: {'depth': 6, 'learning_rate': 0.18645788607343017, 'random_strength': 12, 'bagging_temperature': 0.6373190942586844, 'l2_leaf_reg': 21.114767131407763, 'scale_pos_weight': 3.7582578279191248}. Best is trial 21 with value: 0.784375.
# [I 2024-01-28 14:46:16,821] Trial 37 finished with value: 0.73 and parameters: {'depth': 6, 'learning_rate': 0.28160743941064387, 'random_strength': 15, 'bagging_temperature': 0.33317301313145326, 'l2_leaf_reg': 12.474038075963065, 'scale_pos_weight': 2.8127463499521514}. Best is trial 21 with value: 0.784375.
# [I 2024-01-28 14:46:17,452] Trial 38 finished with value: 0.759375 and parameters: {'depth': 6, 'learning_rate': 0.20479108428179477, 'random_strength': 14, 'bagging_temperature': 0.5524899769148199, 'l2_leaf_reg': 35.57382965662465, 'scale_pos_weight': 2.0155013044729833}. Best is trial 21 with value: 0.784375.
# [I 2024-01-28 14:46:17,891] Trial 39 finished with value: 0.708125 and parameters: {'depth': 5, 'learning_rate': 0.2548993380237972, 'random_strength': 12, 'bagging_temperature': 0.01909432744721362, 'l2_leaf_reg': 42.26644212881907, 'scale_pos_weight': 4.288360660806143}. Best is trial 21 with value: 0.784375.
# [I 2024-01-28 14:46:18,482] Trial 40 finished with value: 0.7825 and parameters: {'depth': 7, 'learning_rate': 0.16710008054694953, 'random_strength': 13, 'bagging_temperature': 0.7323484896986602, 'l2_leaf_reg': 15.473338707416325, 'scale_pos_weight': 0.6880041898088669}. Best is trial 21 with value: 0.784375.
# [I 2024-01-28 14:46:19,013] Trial 41 finished with value: 0.775 and parameters: {'depth': 7, 'learning_rate': 0.16355716939526135, 'random_strength': 13, 'bagging_temperature': 0.7428227891584153, 'l2_leaf_reg': 16.307004084491112, 'scale_pos_weight': 0.6777211709092466}. Best is trial 21 with value: 0.784375.
# [I 2024-01-28 14:46:19,546] Trial 42 finished with value: 0.771875 and parameters: {'depth': 7, 'learning_rate': 0.1786339734428689, 'random_strength': 17, 'bagging_temperature': 0.8256518574491974, 'l2_leaf_reg': 23.514740219781075, 'scale_pos_weight': 1.4279199215656757}. Best is trial 21 with value: 0.784375.
# [I 2024-01-28 14:46:20,219] Trial 43 finished with value: 0.773125 and parameters: {'depth': 6, 'learning_rate': 0.13474618501042024, 'random_strength': 12, 'bagging_temperature': 0.8771009313858463, 'l2_leaf_reg': 5.042129415588792, 'scale_pos_weight': 0.7136994222672044}. Best is trial 21 with value: 0.784375.
# [I 2024-01-28 14:46:20,847] Trial 44 finished with value: 0.77875 and parameters: {'depth': 6, 'learning_rate': 0.21868228354580854, 'random_strength': 15, 'bagging_temperature': 0.7110714549183701, 'l2_leaf_reg': 16.632072324437576, 'scale_pos_weight': 1.1983628576905805}. Best is trial 21 with value: 0.784375.
# [I 2024-01-28 14:46:21,326] Trial 45 finished with value: 0.706875 and parameters: {'depth': 7, 'learning_rate': 0.2605750774579756, 'random_strength': 14, 'bagging_temperature': 0.4316248055228762, 'l2_leaf_reg': 27.88425473354364, 'scale_pos_weight': 0.18366583875041642}. Best is trial 21 with value: 0.784375.
# [I 2024-01-28 14:46:21,776] Trial 46 finished with value: 0.746875 and parameters: {'depth': 7, 'learning_rate': 0.28414437927467034, 'random_strength': 10, 'bagging_temperature': 0.984260919339925, 'l2_leaf_reg': 11.222683327889454, 'scale_pos_weight': 1.8776856687426902}. Best is trial 21 with value: 0.784375.
# [I 2024-01-28 14:46:22,440] Trial 47 finished with value: 0.75 and parameters: {'depth': 7, 'learning_rate': 0.23408340131699665, 'random_strength': 11, 'bagging_temperature': 0.5317912335324583, 'l2_leaf_reg': 20.109455146499826, 'scale_pos_weight': 2.465487366546065}. Best is trial 21 with value: 0.784375.
# [I 2024-01-28 14:46:22,956] Trial 48 finished with value: 0.725625 and parameters: {'depth': 6, 'learning_rate': 0.19362398911473616, 'random_strength': 14, 'bagging_temperature': 0.7654376667715868, 'l2_leaf_reg': 32.80900999529038, 'scale_pos_weight': 3.458841591587184}. Best is trial 21 with value: 0.784375.
# [I 2024-01-28 14:46:23,405] Trial 49 finished with value: 0.785625 and parameters: {'depth': 4, 'learning_rate': 0.26385000442039175, 'random_strength': 9, 'bagging_temperature': 0.6162613136083088, 'l2_leaf_reg': 5.979817908163431, 'scale_pos_weight': 0.7488010906549895}. Best is trial 49 with value: 0.785625.
# [I 2024-01-28 14:46:23,802] Trial 50 finished with value: 0.763125 and parameters: {'depth': 4, 'learning_rate': 0.29832437139048434, 'random_strength': 9, 'bagging_temperature': 0.45480912596641593, 'l2_leaf_reg': 4.2714953264678766, 'scale_pos_weight': 1.46079672205992}. Best is trial 49 with value: 0.785625.
# [I 2024-01-28 14:46:24,330] Trial 51 finished with value: 0.780625 and parameters: {'depth': 4, 'learning_rate': 0.2653192481140649, 'random_strength': 9, 'bagging_temperature': 0.6108612660220691, 'l2_leaf_reg': 8.580124293536578, 'scale_pos_weight': 0.5380572455048838}. Best is trial 49 with value: 0.785625.
# [I 2024-01-28 14:46:24,867] Trial 52 finished with value: 0.77875 and parameters: {'depth': 5, 'learning_rate': 0.24743909482613155, 'random_strength': 13, 'bagging_temperature': 0.6761114328151467, 'l2_leaf_reg': 14.568189429491063, 'scale_pos_weight': 0.9266317596160415}. Best is trial 49 with value: 0.785625.
# ...
# [I 2024-01-28 14:53:52,257] Trial 49 finished with value: 0.705 and parameters: {'depth': 4, 'learning_rate': 0.043401168251059, 'random_strength': 10, 'bagging_temperature': 0.4144601179489801, 'l2_leaf_reg': 65.44049448998155, 'scale_pos_weight': 5.940444588133481}. Best is trial 27 with value: 0.803125.
# [I 2024-01-28 14:53:53,158] Trial 50 finished with value: 0.79875 and parameters: {'depth': 6, 'learning_rate': 0.1266737694587576, 'random_strength': 16, 'bagging_temperature': 0.7738834192522555, 'l2_leaf_reg': 27.501167552734536, 'scale_pos_weight': 1.1129607846648324}. Best is trial 27 with value: 0.803125.
# [I 2024-01-28 14:53:54,762] Trial 51 finished with value: 0.803125 and parameters: {'depth': 5, 'learning_rate': 0.1610379209679993, 'random_strength': 20, 'bagging_temperature': 0.08859606313246132, 'l2_leaf_reg': 90.40926260623107, 'scale_pos_weight': 0.5644376484724614}. Best is trial 27 with value: 0.803125.
# [I 2024-01-28 14:53:56,207] Trial 52 finished with value: 0.795625 and parameters: {'depth': 5, 'learning_rate': 0.17536386137694862, 'random_strength': 20, 'bagging_temperature': 0.11908017611981606, 'l2_leaf_reg': 80.28098662056803, 'scale_pos_weight': 0.48923315860594485}. Best is trial 27 with value: 0.803125.
# [I 2024-01-28 14:53:57,339] Trial 53 finished with value: 0.785 and parameters: {'depth': 5, 'learning_rate': 0.15750176766993285, 'random_strength': 19, 'bagging_temperature': 0.053842705667593, 'l2_leaf_reg': 90.53757197059451, 'scale_pos_weight': 0.5145058673162777}. Best is trial 27 with value: 0.803125.
# [I 2024-01-28 14:53:58,516] Trial 54 finished with value: 0.76125 and parameters: {'depth': 6, 'learning_rate': 0.10084323608776484, 'random_strength': 20, 'bagging_temperature': 0.049968155135201406, 'l2_leaf_reg': 96.29778710761798, 'scale_pos_weight': 2.1839070193036845}. Best is trial 27 with value: 0.803125.
# [I 2024-01-28 14:53:59,967] Trial 55 finished with value: 0.643125 and parameters: {'depth': 5, 'learning_rate': 0.1132965614811416, 'random_strength': 18, 'bagging_temperature': 0.16030457009333837, 'l2_leaf_reg': 84.46715261905901, 'scale_pos_weight': 0.10037666843747506}. Best is trial 27 with value: 0.803125.
# [I 2024-01-28 14:54:00,956] Trial 56 finished with value: 0.79625 and parameters: {'depth': 7, 'learning_rate': 0.12859951193437028, 'random_strength': 19, 'bagging_temperature': 0.2254382173569229, 'l2_leaf_reg': 99.80092549090074, 'scale_pos_weight': 1.1935283903464415}. Best is trial 27 with value: 0.803125.
# [I 2024-01-28 14:54:02,292] Trial 57 finished with value: 0.7925 and parameters: {'depth': 4, 'learning_rate': 0.14946405283478106, 'random_strength': 16, 'bagging_temperature': 0.5037268603802321, 'l2_leaf_reg': 76.61696639668334, 'scale_pos_weight': 1.570373482204807}. Best is trial 27 with value: 0.803125.
# [I 2024-01-28 14:54:04,917] Trial 58 finished with value: 0.80125 and parameters: {'depth': 5, 'learning_rate': 0.07396755388829963, 'random_strength': 18, 'bagging_temperature': 0.27935618343768304, 'l2_leaf_reg': 69.35113143238493, 'scale_pos_weight': 0.8577204285635208}. Best is trial 27 with value: 0.803125.
# [I 2024-01-28 14:54:06,850] Trial 59 finished with value: 0.75125 and parameters: {'depth': 6, 'learning_rate': 0.06738117294261754, 'random_strength': 17, 'bagging_temperature': 0.2617853461707564, 'l2_leaf_reg': 70.48479684097674, 'scale_pos_weight': 2.7664312641805617}. Best is trial 27 with value: 0.803125.
# [I 2024-01-28 14:54:09,938] Trial 60 finished with value: 0.775 and parameters: {'depth': 5, 'learning_rate': 0.029042913715874946, 'random_strength': 18, 'bagging_temperature': 0.3679014980576816, 'l2_leaf_reg': 53.179468103975665, 'scale_pos_weight': 1.6502841400100117}. Best is trial 27 with value: 0.803125.
# [I 2024-01-28 14:54:11,607] Trial 61 finished with value: 0.80125 and parameters: {'depth': 5, 'learning_rate': 0.08141439249614119, 'random_strength': 19, 'bagging_temperature': 0.20097794985590128, 'l2_leaf_reg': 61.958281736574676, 'scale_pos_weight': 0.934171273421832}. Best is trial 27 with value: 0.803125.
# [I 2024-01-28 14:54:13,554] Trial 62 finished with value: 0.775 and parameters: {'depth': 5, 'learning_rate': 0.07504170186535114, 'random_strength': 20, 'bagging_temperature': 0.19280791044297296, 'l2_leaf_reg': 62.40622718849075, 'scale_pos_weight': 0.38737119375643964}. Best is trial 27 with value: 0.803125.
# [I 2024-01-28 14:54:15,278] Trial 63 finished with value: 0.73125 and parameters: {'depth': 5, 'learning_rate': 0.08654030786072556, 'random_strength': 18, 'bagging_temperature': 0.2938455310860112, 'l2_leaf_reg': 67.31552794893938, 'scale_pos_weight': 4.530763415315313}. Best is trial 27 with value: 0.803125.
# [I 2024-01-28 14:54:16,806] Trial 64 finished with value: 0.79625 and parameters: {'depth': 5, 'learning_rate': 0.09234250788515716, 'random_strength': 20, 'bagging_temperature': 0.12853595554071323, 'l2_leaf_reg': 44.90926462602801, 'scale_pos_weight': 1.321972389299873}. Best is trial 27 with value: 0.803125.
# [I 2024-01-28 14:54:18,644] Trial 65 finished with value: 0.79375 and parameters: {'depth': 6, 'learning_rate': 0.05988002229282973, 'random_strength': 15, 'bagging_temperature': 0.21319417604625407, 'l2_leaf_reg': 54.818523949222794, 'scale_pos_weight': 0.6637067158965442}. Best is trial 27 with value: 0.803125.
# [I 2024-01-28 14:54:20,654] Trial 66 finished with value: 0.671875 and parameters: {'depth': 5, 'learning_rate': 0.07723321406380881, 'random_strength': 19, 'bagging_temperature': 0.2603126150079632, 'l2_leaf_reg': 59.62868161835724, 'scale_pos_weight': 9.31066382618171}. Best is trial 27 with value: 0.803125.
# [I 2024-01-28 14:54:21,757] Trial 67 finished with value: 0.760625 and parameters: {'depth': 6, 'learning_rate': 0.10519989113283817, 'random_strength': 17, 'bagging_temperature': 0.3280828583446427, 'l2_leaf_reg': 73.93118090978518, 'scale_pos_weight': 2.1574305908207116}. Best is trial 27 with value: 0.803125.
# [I 2024-01-28 14:54:22,599] Trial 68 finished with value: 0.791875 and parameters: {'depth': 5, 'learning_rate': 0.18299243126318251, 'random_strength': 18, 'bagging_temperature': 0.17731858171695733, 'l2_leaf_reg': 70.04627860393134, 'scale_pos_weight': 1.0779307316248095}. Best is trial 27 with value: 0.803125.
# [I 2024-01-28 14:54:23,412] Trial 69 finished with value: 0.778125 and parameters: {'depth': 5, 'learning_rate': 0.19979712598331087, 'random_strength': 20, 'bagging_temperature': 0.4714511199337541, 'l2_leaf_reg': 65.21129555449606, 'scale_pos_weight': 1.6511886661191215}. Best is trial 27 with value: 0.803125.
# [I 2024-01-28 14:54:24,560] Trial 70 finished with value: 0.715625 and parameters: {'depth': 8, 'learning_rate': 0.16056920545732212, 'random_strength': 4, 'bagging_temperature': 0.036272166730038996, 'l2_leaf_reg': 77.99677484550703, 'scale_pos_weight': 5.462173433879651}. Best is trial 27 with value: 0.803125.
# [I 2024-01-28 14:54:26,253] Trial 71 finished with value: 0.803125 and parameters: {'depth': 4, 'learning_rate': 0.11895958303664837, 'random_strength': 19, 'bagging_temperature': 0.0811872922011699, 'l2_leaf_reg': 86.0917081772772, 'scale_pos_weight': 0.868350639626995}. Best is trial 27 with value: 0.803125.
# [I 2024-01-28 14:54:27,543] Trial 72 finished with value: 0.8 and parameters: {'depth': 4, 'learning_rate': 0.1164446344961057, 'random_strength': 19, 'bagging_temperature': 0.09850188025480865, 'l2_leaf_reg': 86.8332734019436, 'scale_pos_weight': 0.8859534202232782}. Best is trial 27 with value: 0.803125.
# [I 2024-01-28 14:54:28,983] Trial 73 finished with value: 0.76625 and parameters: {'depth': 5, 'learning_rate': 0.14259598436928309, 'random_strength': 18, 'bagging_temperature': 0.08220916193677441, 'l2_leaf_reg': 88.9500585347459, 'scale_pos_weight': 0.32974427301146225}. Best is trial 27 with value: 0.803125.
# [I 2024-01-28 14:54:30,751] Trial 74 finished with value: 0.80125 and parameters: {'depth': 4, 'learning_rate': 0.13309915972954375, 'random_strength': 20, 'bagging_temperature': 0.14117237036258865, 'l2_leaf_reg': 85.38549887014665, 'scale_pos_weight': 0.69143998448532}. Best is trial 27 with value: 0.803125.
# [I 2024-01-28 14:54:31,809] Trial 75 finished with value: 0.789375 and parameters: {'depth': 4, 'learning_rate': 0.13238282225513143, 'random_strength': 19, 'bagging_temperature': 0.1479503223801285, 'l2_leaf_reg': 94.50844443250064, 'scale_pos_weight': 1.2029115460402562}. Best is trial 27 with value: 0.803125.
# [I 2024-01-28 14:54:33,105] Trial 76 finished with value: 0.796875 and parameters: {'depth': 4, 'learning_rate': 0.16703770015165542, 'random_strength': 17, 'bagging_temperature': 0.22973442462731128, 'l2_leaf_reg': 83.72910316700538, 'scale_pos_weight': 0.6291024501159733}. Best is trial 27 with value: 0.803125.
# [I 2024-01-28 14:54:33,978] Trial 77 finished with value: 0.7675 and parameters: {'depth': 4, 'learning_rate': 0.15266193976666492, 'random_strength': 16, 'bagging_temperature': 0.1304371179356015, 'l2_leaf_reg': 90.38054212285715, 'scale_pos_weight': 0.342715158298995}. Best is trial 27 with value: 0.803125.
# [I 2024-01-28 14:54:35,518] Trial 78 finished with value: 0.799375 and parameters: {'depth': 4, 'learning_rate': 0.14033661662556346, 'random_strength': 12, 'bagging_temperature': 0.29950084752852846, 'l2_leaf_reg': 72.59612691647182, 'scale_pos_weight': 1.3933234100424752}. Best is trial 27 with value: 0.803125.
# [I 2024-01-28 14:54:37,479] Trial 79 finished with value: 0.78 and parameters: {'depth': 5, 'learning_rate': 0.09491286383826388, 'random_strength': 20, 'bagging_temperature': 0.36091557849374684, 'l2_leaf_reg': 86.15453751225573, 'scale_pos_weight': 1.7969355186552487}. Best is trial 27 with value: 0.803125.
# [I 2024-01-28 14:54:40,322] Trial 80 finished with value: 0.8025 and parameters: {'depth': 4, 'learning_rate': 0.07988510876800305, 'random_strength': 18, 'bagging_temperature': 0.19787625456841984, 'l2_leaf_reg': 93.1917139739292, 'scale_pos_weight': 0.7541189150890234}. Best is trial 27 with value: 0.803125.
# [I 2024-01-28 14:54:43,204] Trial 81 finished with value: 0.79875 and parameters: {'depth': 4, 'learning_rate': 0.07876913021382673, 'random_strength': 18, 'bagging_temperature': 0.19173796159251014, 'l2_leaf_reg': 96.70877430203932, 'scale_pos_weight': 0.7773332741550413}. Best is trial 27 with value: 0.803125.
# [I 2024-01-28 14:54:45,985] Trial 82 finished with value: 0.793125 and parameters: {'depth': 4, 'learning_rate': 0.06848987918468685, 'random_strength': 19, 'bagging_temperature': 0.2731716999554801, 'l2_leaf_reg': 81.66236487425724, 'scale_pos_weight': 1.001621668557003}. Best is trial 27 with value: 0.803125.
# [I 2024-01-28 14:54:48,761] Trial 83 finished with value: 0.79875 and parameters: {'depth': 4, 'learning_rate': 0.05505431714595506, 'random_strength': 19, 'bagging_temperature': 0.10857407005796502, 'l2_leaf_reg': 47.45351167924722, 'scale_pos_weight': 0.5789251409655323}. Best is trial 27 with value: 0.803125.
# [I 2024-01-28 14:54:50,362] Trial 84 finished with value: 0.67125 and parameters: {'depth': 5, 'learning_rate': 0.11775640710197743, 'random_strength': 20, 'bagging_temperature': 0.15640906233595256, 'l2_leaf_reg': 91.9789593996249, 'scale_pos_weight': 0.12076813754358717}. Best is trial 27 with value: 0.803125.
# [I 2024-01-28 14:54:51,679] Trial 85 finished with value: 0.794375 and parameters: {'depth': 4, 'learning_rate': 0.10981138601486083, 'random_strength': 18, 'bagging_temperature': 0.034729058534001246, 'l2_leaf_reg': 79.7508209786479, 'scale_pos_weight': 1.3013305719347068}. Best is trial 27 with value: 0.803125.
# [I 2024-01-28 14:54:54,458] Trial 86 finished with value: 0.765625 and parameters: {'depth': 4, 'learning_rate': 0.03901350550404574, 'random_strength': 17, 'bagging_temperature': 0.9850757128762843, 'l2_leaf_reg': 37.96602842106159, 'scale_pos_weight': 2.024233697375114}. Best is trial 27 with value: 0.803125.
# [I 2024-01-28 14:54:55,721] Trial 87 finished with value: 0.79875 and parameters: {'depth': 5, 'learning_rate': 0.13149567094216152, 'random_strength': 6, 'bagging_temperature': 0.23824117950268447, 'l2_leaf_reg': 88.9506342989893, 'scale_pos_weight': 0.8525096465610171}. Best is trial 27 with value: 0.803125.
# [I 2024-01-28 14:54:58,001] Trial 88 finished with value: 0.761875 and parameters: {'depth': 5, 'learning_rate': 0.09213755718746655, 'random_strength': 13, 'bagging_temperature': 0.39328974258620764, 'l2_leaf_reg': 93.96954733124419, 'scale_pos_weight': 2.3962349947697055}. Best is trial 27 with value: 0.803125.
# [I 2024-01-28 14:55:00,371] Trial 89 finished with value: 0.789375 and parameters: {'depth': 4, 'learning_rate': 0.08347623602652993, 'random_strength': 19, 'bagging_temperature': 0.18134324183875628, 'l2_leaf_reg': 83.86086661599236, 'scale_pos_weight': 1.4993189628272836}. Best is trial 27 with value: 0.803125.
# [I 2024-01-28 14:55:02,738] Trial 90 finished with value: 0.7775 and parameters: {'depth': 5, 'learning_rate': 0.06950822225664804, 'random_strength': 20, 'bagging_temperature': 0.13265702682156819, 'l2_leaf_reg': 76.18820215202842, 'scale_pos_weight': 0.41625634852117527}. Best is trial 27 with value: 0.803125.
# [I 2024-01-28 14:55:04,419] Trial 91 finished with value: 0.798125 and parameters: {'depth': 5, 'learning_rate': 0.10351761219615743, 'random_strength': 20, 'bagging_temperature': 0.07986032626362947, 'l2_leaf_reg': 77.91717907808503, 'scale_pos_weight': 1.0592526272042966}. Best is trial 27 with value: 0.803125.
# [I 2024-01-28 14:55:06,384] Trial 92 finished with value: 0.795625 and parameters: {'depth': 6, 'learning_rate': 0.09997695315593595, 'random_strength': 19, 'bagging_temperature': 0.10953388657375501, 'l2_leaf_reg': 67.76715211799078, 'scale_pos_weight': 0.705694902098318}. Best is trial 27 with value: 0.803125.
# [I 2024-01-28 14:55:07,875] Trial 93 finished with value: 0.79375 and parameters: {'depth': 5, 'learning_rate': 0.11859133041150742, 'random_strength': 18, 'bagging_temperature': 0.21050733607138344, 'l2_leaf_reg': 72.28904954355178, 'scale_pos_weight': 0.9302979190919543}. Best is trial 27 with value: 0.803125.
# [I 2024-01-28 14:55:09,339] Trial 94 finished with value: 0.750625 and parameters: {'depth': 7, 'learning_rate': 0.10767447817146701, 'random_strength': 20, 'bagging_temperature': 0.008769243723744408, 'l2_leaf_reg': 97.6477319643288, 'scale_pos_weight': 0.292374320146218}. Best is trial 27 with value: 0.803125.
# [I 2024-01-28 14:55:12,289] Trial 95 finished with value: 0.79625 and parameters: {'depth': 5, 'learning_rate': 0.04714063307636327, 'random_strength': 19, 'bagging_temperature': 0.061678639408933617, 'l2_leaf_reg': 64.3355171353186, 'scale_pos_weight': 1.2202536738682777}. Best is trial 27 with value: 0.803125.
# [I 2024-01-28 14:55:14,064] Trial 96 finished with value: 0.696875 and parameters: {'depth': 4, 'learning_rate': 0.12276626179721782, 'random_strength': 18, 'bagging_temperature': 0.8882348781026429, 'l2_leaf_reg': 85.53213147530984, 'scale_pos_weight': 7.3519739700770295}. Best is trial 27 with value: 0.803125.
# [I 2024-01-28 14:55:14,833] Trial 97 finished with value: 0.77125 and parameters: {'depth': 6, 'learning_rate': 0.1363426757102027, 'random_strength': 20, 'bagging_temperature': 0.1650669856326322, 'l2_leaf_reg': 82.46994914699162, 'scale_pos_weight': 1.6826856057203177}. Best is trial 27 with value: 0.803125.
# [I 2024-01-28 14:55:15,446] Trial 98 finished with value: 0.785625 and parameters: {'depth': 5, 'learning_rate': 0.14692317240183886, 'random_strength': 17, 'bagging_temperature': 0.08163610251604067, 'l2_leaf_reg': 0.19673732169781744, 'scale_pos_weight': 0.4422529991761765}. Best is trial 27 with value: 0.803125.
# [I 2024-01-28 14:55:16,707] Trial 99 finished with value: 0.799375 and parameters: {'depth': 5, 'learning_rate': 0.1804427607588059, 'random_strength': 19, 'bagging_temperature': 0.542031784997645, 'l2_leaf_reg': 75.0729944965408, 'scale_pos_weight': 0.7471323198778799}. Best is trial 27 with value: 0.803125.

# %% [markdown]
# - Catboost平均スコア

# %%
# 全フォールドの平均スコアを計算
cb_average_score = sum(cb_fold_scores) / n_splits
print(f"CatBoost Average accuracy across all folds: {cb_average_score}")
# Out:
# CatBoost Average accuracy across all folds: 0.7793749999999999

# %% [markdown]
# - CB_予測平均

# %%
# 予測の平均を計算
cb_y_test_pred_avg = np.mean(cb_test_predictions, axis=0)

# 最終的な予測結果を整数に変換
cb_y_test_pred_int = (cb_y_test_pred_avg > 0.5).astype(int)

# %% [markdown]
# - output

# %%
# 現在の日時を取得してフォーマットする
current_time = datetime.now().strftime("%Y%m%d_%H%M%S")
output = f'../data/output/{current_time}_CatBoost_cv{cb_average_score:.4f}.csv'

submit = pd.DataFrame({
    '0': test['gameId'],
    '1': cb_y_test_pred_int
})

# カラムヘッダー消去して出力
# ヘッダーなしでCSVファイルとして保存
submit.to_csv(output, header=False, index=False)

# %%
submit
# Out:
#          0  1
# 0        9  1
# 1       15  1
# 2       18  0
# 3       23  0
# 4       31  1
# ...    ... ..
# 1995  9971  0
# 1996  9980  0
# 1997  9983  1
# 1998  9996  1
# 1999  9999  0
#
# [2000 rows x 2 columns]

# %% [markdown]
# # 合成

# %% [markdown]
# - 予測リストに追加

# %%
# 予測結果をNumPy配列に変換
cb_predictions = np.array(cb_y_test_pred_int)  # CatBoostの予測結果
lgb_predictions = np.array(lgb_y_test_pred_int)  # LightGBMの予測結果
xgb_predictions = np.array(xgb_y_test_pred_int)  # XGBoostの予測結果

# 3つのモデルの予測結果を組み合わせる
combined_predictions = np.vstack((cb_predictions, lgb_predictions, xgb_predictions))

# 多数決で最終的な予測を決定（行方向に合計し、1.5より大きい場合は1とする）
final_predictions = np.mean(combined_predictions, axis=0) > 0.5
final_predictions = final_predictions.astype(int)

# 最終的な予測をCSVファイルに保存
merge_submit = pd.DataFrame({
    '0': test['gameId'],  # 適切なID列を使用
    '1': final_predictions
})
merge_submit.to_csv(f'../data/output/{current_time}_final_predictions.csv', index=False)

# %%
merge_submit
# Out:
#          0  1
# 0        9  1
# 1       15  1
# 2       18  0
# 3       23  0
# 4       31  1
# ...    ... ..
# 1995  9971  0
# 1996  9980  0
# 1997  9983  1
# 1998  9996  1
# 1999  9999  0
#
# [2000 rows x 2 columns]

# %% [markdown]
# ## RandomForest
