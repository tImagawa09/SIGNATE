# %% [markdown]
# # Library

# %%
import pandas as pd
import numpy as np

import optuna
import xgboost as xgb
import lightgbm as lgb
import catboost as cb

from datetime import datetime
from sklearn.model_selection import train_test_split, KFold
from sklearn.metrics import accuracy_score, confusion_matrix, roc_curve, auc
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# # Data Loading

# %%
train = pd.read_csv('../data/train.csv')
test = pd.read_csv('../data/test.csv')

# %% [markdown]
# # Add New Feature

# %%
def add_features(df):
    df['assistRate'] = df['blueAssists'] / (df['blueKills'] + 1)
    df['blueHerald'] = (df['blueEliteMonsters'] - df['blueDragons']).clip(lower=0)
    df['eliteMonsterDragonRatio'] = df['blueEliteMonsters'] / (df['blueDragons'] + 1)
    df['logTotalGold'] = np.log1p(df['blueTotalGold'])
    df['logTotalExperience'] = np.log1p(df['blueTotalExperience'])
    # df['firstBloodKillRatio'] = df['blueFirstBlood'] * df['blueKills']
    df['totalCombatPoints'] = df['blueKills'] + df['blueDeaths'] + df['blueAssists']

    total_combat_actions = df['blueKills'] + df['blueDeaths'] + df['blueAssists']
    df['killRatio'] = df['blueKills'] / total_combat_actions
    df['deathRatio'] = df['blueDeaths'] / total_combat_actions
    df['assistRatio'] = df['blueAssists'] / total_combat_actions

    df['teamStrength'] = df['blueKills'] + df['blueAssists'] + df['blueEliteMonsters']
    df['dragonKillImpact'] = df['blueDragons'] / (df['blueKills'] + 1)
    df['eliteMonsterUtilization'] = df['blueEliteMonsters'] / (df['blueKills'] + df['blueAssists'] + 1)
    df['goldExperienceRatio'] = df['blueTotalGold'] / (df['blueTotalExperience'] + 1)
    df['teamEfficiency'] = (df['blueKills'] + df['blueAssists'] + df['blueEliteMonsters']) / (df['blueDeaths'] + 1)
    df['killToMonsterRatio'] = df['blueKills'] / (df['blueEliteMonsters'] + 1)
    df['avgGoldPerKill'] = df['blueTotalGold'] / (df['blueKills'] + 1)
    df['expToKillRatio'] = df['blueTotalExperience'] / (df['blueKills'] + 1)
    df['killsMinusDeaths'] = df['blueKills'] - df['blueDeaths']
    df['killDeathRatio'] = df['blueKills'] / (df['blueKills'] + df['blueDeaths'])
    df['avgExperiencePerKill'] = df['blueTotalExperience'] / (df['blueKills'] + 1)
    df['killDeathDiff'] = (df['blueKills'] - df['blueDeaths']).clip(lower=0)
    df['eliteMonsterHeraldRatio'] = df['blueEliteMonsters'] / (df['blueHerald'] + 1)
    df['goldXexperience'] = np.log1p(df['blueTotalGold'] * df['blueTotalExperience'])
    df['goldPerKill'] = df['blueTotalGold'] / (df['blueKills'] + 1)  # ゼロ除算を防ぐために+1
    df['experiencePerKill'] = df['blueTotalExperience'] / (df['blueKills'] + 1)  # ゼロ除算を防ぐために+1
    df['eliteMonstersPerGold'] = df['blueEliteMonsters'] / df['blueTotalGold']
    df['eliteMonstersPerExperience'] = df['blueEliteMonsters'] / df['blueTotalExperience']

    
    return df

# %% [markdown]
# - apply

# %%
train = add_features(train)
test = add_features(test)

# %% [markdown]
# # Data

# %%
# データの準備
X = train.drop(['blueWins', 'gameId'], axis=1)
y = train['blueWins']
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2, random_state=0)

test_drop_gameId = test.drop('gameId', axis=1)

# test_drop_gameId_temp = test.drop('gameId', axis=1)

# # 特徴量の標準化
# scaler = StandardScaler()
# X_train = scaler.fit_transform(X_train)
# X_val = scaler.transform(X_val)  # 検証データも同じスケーラーを使用して標準化

# # テストデータも同じスケーラーを使用して標準化
# test_drop_gameId_scaled = scaler.transform(test_drop_gameId_temp)

# # NumPy配列からPandasデータフレームに変換
# X_train = pd.DataFrame(X_train, columns=X.columns)
# X_val = pd.DataFrame(X_val, columns=X.columns)
# test_drop_gameId = pd.DataFrame(test_drop_gameId_scaled, columns=test_drop_gameId_temp.columns)

# %% [markdown]
# # Model

# %% [markdown]
# - variable

# %%
n_splits = 4
kf = KFold(n_splits=n_splits, shuffle=True)

lgb_threshold = 0.5
xgb_threshold = 0.5
cb_threshold = 0.5

# 各フォールドでのスコアを保存するリスト
lgb_fold_scores = []
xgb_fold_scores = []
cb_fold_scores = []

# 各フォール度での混同行列を保存するリスト
lgb_conf_scores = []
xgb_conf_scores = []
cb_conf_scores = []

# testを保存するリスト
lgb_test_predictions = []
xgb_test_predictions = []
cb_test_predictions = []

# %% [markdown]
# ## LightGBM

# %%
for train_index, val_index in kf.split(X):
    X_train_fold, X_val_fold = X.iloc[train_index], X.iloc[val_index]
    y_train_fold, y_val_fold = y[train_index], y[val_index]

    # LightGBMではDMatrixの代わりに普通のデータフレームを使用します
    train_data = lgb.Dataset(X_train_fold, label=y_train_fold)
    val_data = lgb.Dataset(X_val_fold, label=y_val_fold, reference=train_data)

    # Optunaでのハイパーパラメータチューニング
    def objective(trial):
        param = {
            'objective': 'binary',
            'metric': 'binary_logloss',
            'verbosity': -1,
            'boosting_type': 'gbdt',
            'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
            'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
            'num_leaves': trial.suggest_int('num_leaves', 2, 256),
            'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
            'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
            'bagging_freq': trial.suggest_int('bagging_freq', 1, 7),
            'min_child_samples': trial.suggest_int('min_child_samples', 5, 100),
            'feature_pre_filter': False,  # 特徴量の事前フィルタリングを無効化
            'min_data_in_leaf': trial.suggest_int('min_data_in_leaf', 20, 100),  # Optunaでこの値を調整する
        }

        callbacks = lgb.early_stopping(stopping_rounds=100, verbose=False)
        gbm = lgb.train(param, train_data, valid_sets=[val_data], num_boost_round=1000, callbacks=[callbacks])
        preds = gbm.predict(X_val_fold, num_iteration=gbm.best_iteration)
        pred_labels = np.rint(preds)
        accuracy = accuracy_score(y_val_fold, pred_labels)
        return accuracy

    lgb_study = optuna.create_study(direction='maximize')
    lgb_study.optimize(objective, n_trials=100)

    # 各フォールドの最適パラメータでモデルを再学習
    lgb_best_params = lgb_study.best_params
    lgb_best_params['objective'] = 'binary'
    lgb_best_params['metric'] = 'binary_logloss'
    lgb_best_params['verbosity'] = -1

    lgb_final = lgb.train(lgb_best_params, train_data, num_boost_round=lgb_study.best_trial.number)

    # 各フォールドのモデル性能を評価
    lgb_y_val_pred = lgb_final.predict(X_val_fold, num_iteration=lgb_final.best_iteration)
    lgb_y_val_pred_int = np.rint(lgb_y_val_pred)
    lgb_fold_accuracy = accuracy_score(y_val_fold, lgb_y_val_pred_int)
    lgb_fold_scores.append(lgb_fold_accuracy)

    # 混同行列
    lgb_conf_matrix = confusion_matrix(y_val_fold, lgb_y_val_pred_int)
    lgb_conf_scores.append(lgb_conf_matrix)


    # テストデータセットでの予測
    lgb_y_test_pred_fold = lgb_final.predict(test_drop_gameId, num_iteration=lgb_final.best_iteration)
    lgb_test_predictions.append(lgb_y_test_pred_fold)
# Out:
# [I 2024-01-29 13:53:26,296] A new study created in memory with name: no-name-9afdaf51-ca45-40c6-a532-4b804403e6ae
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-29 13:53:26,503] Trial 0 finished with value: 0.78 and parameters: {'lambda_l1': 0.0005704789124811092, 'lambda_l2': 6.982185439265371e-06, 'num_leaves': 12, 'feature_fraction': 0.47445665684336463, 'bagging_fraction': 0.6262429194416748, 'bagging_freq': 3, 'min_child_samples': 74, 'min_data_in_leaf': 82}. Best is trial 0 with value: 0.78.
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-29 13:53:26,817] Trial 1 finished with value: 0.7745 and parameters: {'lambda_l1': 0.009500953986325635, 'lambda_l2': 2.0339750850250913e-06, 'num_leaves': 28, 'feature_fraction': 0.9218119904306901, 'bagging_fraction': 0.41649334455740045, 'bagging_freq': 3, 'min_child_samples': 53, 'min_data_in_leaf': 71}. Best is trial 0 with value: 0.78.
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-29 13:53:27,126] Trial 2 finished with value: 0.7735 and parameters: {'lambda_l1': 1.3557543531141594e-05, 'lambda_l2': 5.6026082036363324e-08, 'num_leaves': 81, 'feature_fraction': 0.8849231339579352, 'bagging_fraction': 0.8142123849496616, 'bagging_freq': 1, 'min_child_samples': 67, 'min_data_in_leaf': 90}. Best is trial 0 with value: 0.78.
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-29 13:53:27,428] Trial 3 finished with value: 0.7745 and parameters: {'lambda_l1': 4.2237580876884264e-07, 'lambda_l2': 0.11800227865810521, 'num_leaves': 164, 'feature_fraction': 0.9292234934296301, 'bagging_fraction': 0.6320894497208674, 'bagging_freq': 7, 'min_child_samples': 59, 'min_data_in_leaf': 77}. Best is trial 0 with value: 0.78.
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-29 13:53:27,728] Trial 4 finished with value: 0.7775 and parameters: {'lambda_l1': 1.7771801340390577e-08, 'lambda_l2': 7.345810730338117e-05, 'num_leaves': 151, 'feature_fraction': 0.7907872020329245, 'bagging_fraction': 0.8602251626485177, 'bagging_freq': 6, 'min_child_samples': 94, 'min_data_in_leaf': 69}. Best is trial 0 with value: 0.78.
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-29 13:53:28,040] Trial 5 finished with value: 0.7735 and parameters: {'lambda_l1': 0.0007941902437436658, 'lambda_l2': 1.6302535358771911e-06, 'num_leaves': 137, 'feature_fraction': 0.7357830066217478, 'bagging_fraction': 0.9120695088041649, 'bagging_freq': 5, 'min_child_samples': 91, 'min_data_in_leaf': 97}. Best is trial 0 with value: 0.78.
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-29 13:53:28,185] Trial 6 finished with value: 0.766 and parameters: {'lambda_l1': 1.6688316041939155e-07, 'lambda_l2': 1.8668796566196223e-08, 'num_leaves': 36, 'feature_fraction': 0.6452754570480205, 'bagging_fraction': 0.46587114328193674, 'bagging_freq': 6, 'min_child_samples': 71, 'min_data_in_leaf': 31}. Best is trial 0 with value: 0.78.
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-29 13:53:28,376] Trial 7 finished with value: 0.771 and parameters: {'lambda_l1': 5.656406143493609e-06, 'lambda_l2': 0.0015007097103738505, 'num_leaves': 154, 'feature_fraction': 0.5440252668242153, 'bagging_fraction': 0.49058446548527057, 'bagging_freq': 7, 'min_child_samples': 13, 'min_data_in_leaf': 51}. Best is trial 0 with value: 0.78.
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-29 13:53:28,626] Trial 8 finished with value: 0.7805 and parameters: {'lambda_l1': 1.2408146912543984e-06, 'lambda_l2': 3.09377730328186e-05, 'num_leaves': 46, 'feature_fraction': 0.9856104116552412, 'bagging_fraction': 0.8925347107812471, 'bagging_freq': 5, 'min_child_samples': 71, 'min_data_in_leaf': 89}. Best is trial 8 with value: 0.7805.
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-29 13:53:29,031] Trial 9 finished with value: 0.7725 and parameters: {'lambda_l1': 0.0020084247353768453, 'lambda_l2': 0.0054352491458422685, 'num_leaves': 189, 'feature_fraction': 0.5798863877896311, 'bagging_fraction': 0.8899448998491717, 'bagging_freq': 1, 'min_child_samples': 32, 'min_data_in_leaf': 83}. Best is trial 8 with value: 0.7805.
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-29 13:53:29,271] Trial 10 finished with value: 0.784 and parameters: {'lambda_l1': 6.285747072418983, 'lambda_l2': 0.06400313708376114, 'num_leaves': 237, 'feature_fraction': 0.8174716690417642, 'bagging_fraction': 0.9570050631942413, 'bagging_freq': 4, 'min_child_samples': 39, 'min_data_in_leaf': 52}. Best is trial 10 with value: 0.784.
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-29 13:53:29,600] Trial 11 finished with value: 0.7825 and parameters: {'lambda_l1': 1.439373475667484, 'lambda_l2': 2.7606541216705542, 'num_leaves': 256, 'feature_fraction': 0.8254044327195088, 'bagging_fraction': 0.9920906571105652, 'bagging_freq': 4, 'min_child_samples': 35, 'min_data_in_leaf': 49}. Best is trial 10 with value: 0.784.
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-29 13:53:29,894] Trial 12 finished with value: 0.7825 and parameters: {'lambda_l1': 5.5757699409614965, 'lambda_l2': 3.1811894434479124, 'num_leaves': 255, 'feature_fraction': 0.8306942212775441, 'bagging_fraction': 0.9988405247991932, 'bagging_freq': 3, 'min_child_samples': 31, 'min_data_in_leaf': 49}. Best is trial 10 with value: 0.784.
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-29 13:53:30,176] Trial 13 finished with value: 0.7845 and parameters: {'lambda_l1': 8.036706337128523, 'lambda_l2': 6.612245854025986, 'num_leaves': 256, 'feature_fraction': 0.7808782194989998, 'bagging_fraction': 0.9899402756862978, 'bagging_freq': 4, 'min_child_samples': 35, 'min_data_in_leaf': 34}. Best is trial 13 with value: 0.7845.
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-29 13:53:30,539] Trial 14 finished with value: 0.775 and parameters: {'lambda_l1': 0.2789859495330597, 'lambda_l2': 0.13897424039618242, 'num_leaves': 214, 'feature_fraction': 0.7252187379178143, 'bagging_fraction': 0.7421589194765345, 'bagging_freq': 4, 'min_child_samples': 15, 'min_data_in_leaf': 28}. Best is trial 13 with value: 0.7845.
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-29 13:53:30,871] Trial 15 finished with value: 0.7845 and parameters: {'lambda_l1': 8.759036541065703, 'lambda_l2': 9.658801736620422, 'num_leaves': 218, 'feature_fraction': 0.6852464017422893, 'bagging_fraction': 0.9630113801026177, 'bagging_freq': 2, 'min_child_samples': 43, 'min_data_in_leaf': 38}. Best is trial 13 with value: 0.7845.
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-29 13:53:31,207] Trial 16 finished with value: 0.787 and parameters: {'lambda_l1': 0.22830898905150263, 'lambda_l2': 9.136388781553075, 'num_leaves': 207, 'feature_fraction': 0.6728962826122434, 'bagging_fraction': 0.8187835373743304, 'bagging_freq': 2, 'min_child_samples': 43, 'min_data_in_leaf': 38}. Best is trial 16 with value: 0.787.
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-29 13:53:31,506] Trial 17 finished with value: 0.7755 and parameters: {'lambda_l1': 0.10474610101142096, 'lambda_l2': 0.6937353324092757, 'num_leaves': 97, 'feature_fraction': 0.40427283376466955, 'bagging_fraction': 0.8046372313109598, 'bagging_freq': 2, 'min_child_samples': 23, 'min_data_in_leaf': 21}. Best is trial 16 with value: 0.787.
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-29 13:53:31,786] Trial 18 finished with value: 0.779 and parameters: {'lambda_l1': 0.04553794205450168, 'lambda_l2': 8.767524324183041, 'num_leaves': 191, 'feature_fraction': 0.6265850154958441, 'bagging_fraction': 0.8140548939088074, 'bagging_freq': 2, 'min_child_samples': 47, 'min_data_in_leaf': 40}. Best is trial 16 with value: 0.787.
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-29 13:53:32,209] Trial 19 finished with value: 0.7825 and parameters: {'lambda_l1': 0.2822376575370134, 'lambda_l2': 0.01683148619289544, 'num_leaves': 188, 'feature_fraction': 0.7512298570584381, 'bagging_fraction': 0.929166248477802, 'bagging_freq': 5, 'min_child_samples': 23, 'min_data_in_leaf': 20}. Best is trial 16 with value: 0.787.
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-29 13:53:32,491] Trial 20 finished with value: 0.774 and parameters: {'lambda_l1': 0.014725740255526244, 'lambda_l2': 0.6808582556659041, 'num_leaves': 218, 'feature_fraction': 0.6975109857516849, 'bagging_fraction': 0.7219873745431903, 'bagging_freq': 3, 'min_child_samples': 55, 'min_data_in_leaf': 60}. Best is trial 16 with value: 0.787.
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-29 13:53:32,922] Trial 21 finished with value: 0.7795 and parameters: {'lambda_l1': 1.1504679923089711, 'lambda_l2': 7.953213923914986, 'num_leaves': 220, 'feature_fraction': 0.6729452679371882, 'bagging_fraction': 0.9531196586167942, 'bagging_freq': 2, 'min_child_samples': 43, 'min_data_in_leaf': 36}. Best is trial 16 with value: 0.787.
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-29 13:53:33,144] Trial 22 finished with value: 0.7865 and parameters: {'lambda_l1': 7.219273958197562, 'lambda_l2': 1.0261948513590076, 'num_leaves': 234, 'feature_fraction': 0.681739245146411, 'bagging_fraction': 0.999614680151514, 'bagging_freq': 1, 'min_child_samples': 47, 'min_data_in_leaf': 41}. Best is trial 16 with value: 0.787.
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-29 13:53:33,488] Trial 23 finished with value: 0.7775 and parameters: {'lambda_l1': 0.7907849857264053, 'lambda_l2': 0.6129069957824145, 'num_leaves': 238, 'feature_fraction': 0.7652121588452454, 'bagging_fraction': 0.852978012702627, 'bagging_freq': 1, 'min_child_samples': 25, 'min_data_in_leaf': 44}. Best is trial 16 with value: 0.787.
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-29 13:53:33,946] Trial 24 finished with value: 0.781 and parameters: {'lambda_l1': 1.8618586513806041, 'lambda_l2': 1.0446042792613208, 'num_leaves': 197, 'feature_fraction': 0.6217258217831673, 'bagging_fraction': 0.993959948828477, 'bagging_freq': 1, 'min_child_samples': 5, 'min_data_in_leaf': 28}. Best is trial 16 with value: 0.787.
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-29 13:53:34,316] Trial 25 finished with value: 0.7805 and parameters: {'lambda_l1': 0.18164023832800139, 'lambda_l2': 0.15364006206342817, 'num_leaves': 239, 'feature_fraction': 0.7111050481952416, 'bagging_fraction': 0.9166858110256256, 'bagging_freq': 2, 'min_child_samples': 59, 'min_data_in_leaf': 57}. Best is trial 16 with value: 0.787.
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-29 13:53:34,598] Trial 26 finished with value: 0.784 and parameters: {'lambda_l1': 6.8796744572222295, 'lambda_l2': 0.031170175522292395, 'num_leaves': 170, 'feature_fraction': 0.749756571993591, 'bagging_fraction': 0.9538465916986065, 'bagging_freq': 1, 'min_child_samples': 49, 'min_data_in_leaf': 33}. Best is trial 16 with value: 0.787.
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-29 13:53:35,226] Trial 27 finished with value: 0.7755 and parameters: {'lambda_l1': 0.038556911857716196, 'lambda_l2': 1.6900592943098405, 'num_leaves': 103, 'feature_fraction': 0.646475622211552, 'bagging_fraction': 0.8652654331337535, 'bagging_freq': 3, 'min_child_samples': 85, 'min_data_in_leaf': 41}. Best is trial 16 with value: 0.787.
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# ...
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-29 13:55:36,788] Trial 90 finished with value: 0.7865 and parameters: {'lambda_l1': 0.001775296761470327, 'lambda_l2': 0.43256127597012456, 'num_leaves': 33, 'feature_fraction': 0.828039438014314, 'bagging_fraction': 0.5898924972816136, 'bagging_freq': 5, 'min_child_samples': 45, 'min_data_in_leaf': 98}. Best is trial 6 with value: 0.796.
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-29 13:55:37,100] Trial 91 finished with value: 0.788 and parameters: {'lambda_l1': 0.0035275374774963947, 'lambda_l2': 0.196197133512351, 'num_leaves': 27, 'feature_fraction': 0.9154162310252312, 'bagging_fraction': 0.6016206372099039, 'bagging_freq': 5, 'min_child_samples': 36, 'min_data_in_leaf': 96}. Best is trial 6 with value: 0.796.
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-29 13:55:37,352] Trial 92 finished with value: 0.7955 and parameters: {'lambda_l1': 0.002786199647964082, 'lambda_l2': 0.26811136675751807, 'num_leaves': 17, 'feature_fraction': 0.8793154509099034, 'bagging_fraction': 0.6186169698234224, 'bagging_freq': 4, 'min_child_samples': 49, 'min_data_in_leaf': 100}. Best is trial 6 with value: 0.796.
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-29 13:55:37,643] Trial 93 finished with value: 0.785 and parameters: {'lambda_l1': 0.006867984490766955, 'lambda_l2': 0.04177677203977405, 'num_leaves': 17, 'feature_fraction': 0.8780823616850666, 'bagging_fraction': 0.6176165424887596, 'bagging_freq': 4, 'min_child_samples': 49, 'min_data_in_leaf': 100}. Best is trial 6 with value: 0.796.
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-29 13:55:37,921] Trial 94 finished with value: 0.787 and parameters: {'lambda_l1': 0.0011702771475165074, 'lambda_l2': 0.10370023893865075, 'num_leaves': 22, 'feature_fraction': 0.89532736454031, 'bagging_fraction': 0.574016390106231, 'bagging_freq': 4, 'min_child_samples': 59, 'min_data_in_leaf': 95}. Best is trial 6 with value: 0.796.
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-29 13:55:38,248] Trial 95 finished with value: 0.789 and parameters: {'lambda_l1': 0.0026828288582213555, 'lambda_l2': 2.349942428310187, 'num_leaves': 6, 'feature_fraction': 0.8459925654520537, 'bagging_fraction': 0.6351353826437413, 'bagging_freq': 4, 'min_child_samples': 48, 'min_data_in_leaf': 98}. Best is trial 6 with value: 0.796.
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-29 13:55:38,623] Trial 96 finished with value: 0.789 and parameters: {'lambda_l1': 0.017341935210066883, 'lambda_l2': 0.5470566173869287, 'num_leaves': 8, 'feature_fraction': 0.8647737856741834, 'bagging_fraction': 0.5503645591437493, 'bagging_freq': 4, 'min_child_samples': 40, 'min_data_in_leaf': 89}. Best is trial 6 with value: 0.796.
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-29 13:55:39,004] Trial 97 finished with value: 0.792 and parameters: {'lambda_l1': 0.005027213721846508, 'lambda_l2': 0.975590527461846, 'num_leaves': 15, 'feature_fraction': 0.8823605933487453, 'bagging_fraction': 0.6444385931851676, 'bagging_freq': 5, 'min_child_samples': 52, 'min_data_in_leaf': 94}. Best is trial 6 with value: 0.796.
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-29 13:55:39,251] Trial 98 finished with value: 0.79 and parameters: {'lambda_l1': 0.008381444720400163, 'lambda_l2': 0.2707720742031978, 'num_leaves': 12, 'feature_fraction': 0.9299862205983371, 'bagging_fraction': 0.6489934065543873, 'bagging_freq': 5, 'min_child_samples': 53, 'min_data_in_leaf': 94}. Best is trial 6 with value: 0.796.
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\729934341.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-29 13:55:39,534] Trial 99 finished with value: 0.7875 and parameters: {'lambda_l1': 0.0018320576505619294, 'lambda_l2': 1.0409802431902768, 'num_leaves': 17, 'feature_fraction': 0.8819023471726825, 'bagging_fraction': 0.6340862342138118, 'bagging_freq': 5, 'min_child_samples': 51, 'min_data_in_leaf': 100}. Best is trial 6 with value: 0.796.

# %% [markdown]
# - lgb_平均スコア

# %%
# 全フォールドの平均スコアを計算
lgb_average_score = sum(lgb_fold_scores) / n_splits
print(f"LightGBM Average accuracy across all folds: {lgb_average_score}")


lgb_average_conf = sum(lgb_conf_scores) / n_splits
print(f"LightGBM Average conf-matrix across all folds: {lgb_average_conf}")
# Out:
# LightGBM Average accuracy across all folds: 0.7706250000000001
# LightGBM Average conf-matrix across all folds: [[770.75 245.75]
#  [213.   770.5 ]]

# %% [markdown]
# - lgb_予測平均

# %%
# 予測の平均を計算
lgb_y_test_pred_avg = np.mean(lgb_test_predictions, axis=0)

# 最終的な予測結果を整数に変換
lgb_y_test_pred_int = (lgb_y_test_pred_avg > lgb_threshold).astype(int)

# %% [markdown]
# - output

# %%
# 現在の日時を取得してフォーマットする
current_time = datetime.now().strftime("%Y%m%d_%H%M%S")
output = f'../data/output/{current_time}_LightGBM_cv{lgb_average_score:.4f}.csv'

submit = pd.DataFrame({
    '0': test['gameId'],
    '1': lgb_y_test_pred_int
})

# カラムヘッダー消去して出力
# ヘッダーなしでCSVファイルとして保存
submit.to_csv(output, header=False, index=False)

# %%
submit
# Out:
#          0  1
# 0        9  1
# 1       15  1
# 2       18  0
# 3       23  0
# 4       31  1
# ...    ... ..
# 1995  9971  0
# 1996  9980  0
# 1997  9983  1
# 1998  9996  1
# 1999  9999  0
#
# [2000 rows x 2 columns]

# %% [markdown]
# ## XGBoost

# %%
for train_index, val_index in kf.split(X):
    X_train_fold, X_val_fold = X.iloc[train_index], X.iloc[val_index]
    y_train_fold, y_val_fold = y[train_index], y[val_index]

    dtrain = xgb.DMatrix(X_train_fold, label=y_train_fold)
    dval = xgb.DMatrix(X_val_fold, label=y_val_fold)
    dtest = xgb.DMatrix(test_drop_gameId)

    # Optunaでのハイパーパラメータチューニング
    def objective(trial):
        param = {
            'verbosity': 0,
            'objective': 'binary:logistic',
            'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
            'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
            'max_depth': trial.suggest_int('max_depth', 3, 9),
            'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
            'subsample': trial.suggest_float('subsample', 0.5, 1),
            'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1)
        }

        bst = xgb.train(param, dtrain, num_boost_round=1000, evals=[(dval, "eval")], early_stopping_rounds=100, verbose_eval=False)
        preds = bst.predict(dval)
        pred_labels = np.rint(preds)
        accuracy = accuracy_score(y_val_fold, pred_labels)
        return accuracy

    xgb_study = optuna.create_study(direction='maximize')
    xgb_study.optimize(objective, n_trials=100)

    # 各フォールドの最適パラメータでモデルを再学習
    xgb_best_params = xgb_study.best_params
    xgb_best_params['objective'] = 'binary:logistic'
    xgb_best_params['verbosity'] = 0

    xgb_final_bst = xgb.train(xgb_best_params, dtrain, num_boost_round=xgb_study.best_trial.number)

    # 各フォールドのモデル性能を評価
    xgb_y_val_pred = xgb_final_bst.predict(dval)
    xgb_y_val_pred_int = np.rint(xgb_y_val_pred)
    fold_accuracy = accuracy_score(y_val_fold, xgb_y_val_pred_int)
    xgb_fold_scores.append(fold_accuracy)

    # 混同行列
    xgb_conf_matrix = confusion_matrix(y_val_fold, xgb_y_val_pred_int)
    xgb_conf_scores.append(xgb_conf_matrix)

    # テストデータセットでの予測
    xgb_y_test_pred_fold = xgb_final_bst.predict(dtest)
    xgb_test_predictions.append(xgb_y_test_pred_fold)
# Out:
# [I 2024-01-29 13:55:39,710] A new study created in memory with name: no-name-0af07aa8-c57e-432c-8e30-ceade5fcc2ca
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-29 13:55:45,279] Trial 0 finished with value: 0.7725 and parameters: {'alpha': 2.42106846133571e-05, 'lambda': 0.22401467487862906, 'max_depth': 9, 'eta': 0.0009695264879520253, 'subsample': 0.5969254685627335, 'colsample_bytree': 0.9637210467975192}. Best is trial 0 with value: 0.7725.
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-29 13:55:45,885] Trial 1 finished with value: 0.7785 and parameters: {'alpha': 0.004353632784853184, 'lambda': 0.005108251615192868, 'max_depth': 6, 'eta': 0.021413348490325758, 'subsample': 0.9710383168035224, 'colsample_bytree': 0.6832994390557645}. Best is trial 1 with value: 0.7785.
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-29 13:55:47,431] Trial 2 finished with value: 0.7755 and parameters: {'alpha': 0.00011412276015061421, 'lambda': 0.008690696773094598, 'max_depth': 3, 'eta': 0.011582086523702616, 'subsample': 0.6782254882582297, 'colsample_bytree': 0.841044477485698}. Best is trial 1 with value: 0.7785.
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-29 13:55:49,583] Trial 3 finished with value: 0.505 and parameters: {'alpha': 3.588898672234902e-07, 'lambda': 0.021784679399645006, 'max_depth': 5, 'eta': 8.239809071539636e-07, 'subsample': 0.6486700256839526, 'colsample_bytree': 0.8932656009197646}. Best is trial 1 with value: 0.7785.
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-29 13:55:51,318] Trial 4 finished with value: 0.767 and parameters: {'alpha': 0.0577008586028576, 'lambda': 0.005552373456304658, 'max_depth': 4, 'eta': 0.0010012633531320835, 'subsample': 0.8197447104687294, 'colsample_bytree': 0.7996784482832029}. Best is trial 1 with value: 0.7785.
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-29 13:55:55,643] Trial 5 finished with value: 0.7665 and parameters: {'alpha': 9.186728214579947e-07, 'lambda': 0.02644820420403171, 'max_depth': 8, 'eta': 0.001400510380490729, 'subsample': 0.8622767186038225, 'colsample_bytree': 0.9279751451943593}. Best is trial 1 with value: 0.7785.
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-29 13:55:56,994] Trial 6 finished with value: 0.7475 and parameters: {'alpha': 4.8976623266217066e-05, 'lambda': 9.831110626220102e-06, 'max_depth': 3, 'eta': 8.157094886101293e-05, 'subsample': 0.6017984963023186, 'colsample_bytree': 0.8085479843985305}. Best is trial 1 with value: 0.7785.
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-29 13:55:57,327] Trial 7 finished with value: 0.7555 and parameters: {'alpha': 1.8666282245683796e-08, 'lambda': 4.6647072387957134e-08, 'max_depth': 7, 'eta': 0.26333822603950185, 'subsample': 0.8291733826151786, 'colsample_bytree': 0.8916706505549783}. Best is trial 1 with value: 0.7785.
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-29 13:55:57,580] Trial 8 finished with value: 0.7705 and parameters: {'alpha': 1.1074547725515224e-08, 'lambda': 0.04258862797487909, 'max_depth': 3, 'eta': 0.1466861534365395, 'subsample': 0.551294582772258, 'colsample_bytree': 0.5443782645549216}. Best is trial 1 with value: 0.7785.
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-29 13:56:00,589] Trial 9 finished with value: 0.505 and parameters: {'alpha': 0.03549598601204724, 'lambda': 0.0006307194549791023, 'max_depth': 7, 'eta': 3.876844521739062e-07, 'subsample': 0.656475438491705, 'colsample_bytree': 0.5075211412913876}. Best is trial 1 with value: 0.7785.
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-29 13:56:03,718] Trial 10 finished with value: 0.505 and parameters: {'alpha': 0.003916422945354584, 'lambda': 0.6059336176956087, 'max_depth': 6, 'eta': 1.866527588835743e-05, 'subsample': 0.9883389856845856, 'colsample_bytree': 0.6676159834888356}. Best is trial 1 with value: 0.7785.
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-29 13:56:04,777] Trial 11 finished with value: 0.7815 and parameters: {'alpha': 0.0012685356670200758, 'lambda': 0.0004077763616358855, 'max_depth': 5, 'eta': 0.019883179171713068, 'subsample': 0.7257640082678007, 'colsample_bytree': 0.7017116450877989}. Best is trial 11 with value: 0.7815.
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-29 13:56:05,041] Trial 12 finished with value: 0.7345 and parameters: {'alpha': 0.3893731561008829, 'lambda': 0.00011026658998604452, 'max_depth': 5, 'eta': 0.7006282443953034, 'subsample': 0.7593148796428351, 'colsample_bytree': 0.6974190326235191}. Best is trial 11 with value: 0.7815.
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-29 13:56:05,849] Trial 13 finished with value: 0.7785 and parameters: {'alpha': 0.0016840949723018245, 'lambda': 0.00047541327580233187, 'max_depth': 5, 'eta': 0.022341573708442534, 'subsample': 0.9479208770514161, 'colsample_bytree': 0.7088574412529824}. Best is trial 11 with value: 0.7815.
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-29 13:56:08,601] Trial 14 finished with value: 0.505 and parameters: {'alpha': 0.0008039532071999225, 'lambda': 7.128741366684685e-06, 'max_depth': 6, 'eta': 1.2728570086493348e-08, 'subsample': 0.7326357642941281, 'colsample_bytree': 0.6486187812586538}. Best is trial 11 with value: 0.7815.
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-29 13:56:09,431] Trial 15 finished with value: 0.773 and parameters: {'alpha': 0.012802130592259812, 'lambda': 0.0013045333609350267, 'max_depth': 7, 'eta': 0.017634709960998377, 'subsample': 0.9086605105690945, 'colsample_bytree': 0.6052520855474274}. Best is trial 11 with value: 0.7815.
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-29 13:56:09,978] Trial 16 finished with value: 0.7775 and parameters: {'alpha': 0.503909376484661, 'lambda': 4.916682735055766e-05, 'max_depth': 4, 'eta': 0.05961837568031884, 'subsample': 0.8987326197695849, 'colsample_bytree': 0.746567879119173}. Best is trial 11 with value: 0.7815.
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-29 13:56:10,225] Trial 17 finished with value: 0.758 and parameters: {'alpha': 0.0009688458086587242, 'lambda': 0.845910311692786, 'max_depth': 6, 'eta': 0.4728925745336719, 'subsample': 0.985583485135556, 'colsample_bytree': 0.6012209199458411}. Best is trial 11 with value: 0.7815.
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-29 13:56:11,939] Trial 18 finished with value: 0.7785 and parameters: {'alpha': 0.010921955320396593, 'lambda': 0.0018370998090836228, 'max_depth': 4, 'eta': 0.010689938502173809, 'subsample': 0.7709268912562492, 'colsample_bytree': 0.7528632121981607}. Best is trial 11 with value: 0.7815.
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-29 13:56:12,288] Trial 19 finished with value: 0.722 and parameters: {'alpha': 0.0003724443758829104, 'lambda': 0.10816566667905879, 'max_depth': 8, 'eta': 0.9626823039646739, 'subsample': 0.500237608686809, 'colsample_bytree': 0.7464128627207922}. Best is trial 11 with value: 0.7815.
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-29 13:56:14,572] Trial 20 finished with value: 0.779 and parameters: {'alpha': 0.10087620017426542, 'lambda': 0.0053978044783074145, 'max_depth': 5, 'eta': 0.003786926194793617, 'subsample': 0.7200318933294849, 'colsample_bytree': 0.996312435510771}. Best is trial 11 with value: 0.7815.
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-29 13:56:17,144] Trial 21 finished with value: 0.7765 and parameters: {'alpha': 0.11295153352845869, 'lambda': 0.005804483472081325, 'max_depth': 5, 'eta': 0.0037718846824112066, 'subsample': 0.7095642211145184, 'colsample_bytree': 0.9467102936511788}. Best is trial 11 with value: 0.7815.
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-29 13:56:17,592] Trial 22 finished with value: 0.774 and parameters: {'alpha': 0.006525157072030098, 'lambda': 0.1060761420766243, 'max_depth': 6, 'eta': 0.06773895827886174, 'subsample': 0.7706105134769888, 'colsample_bytree': 0.8364334990682664}. Best is trial 11 with value: 0.7815.
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-29 13:56:20,149] Trial 23 finished with value: 0.773 and parameters: {'alpha': 0.10476146718464321, 'lambda': 0.0031464130131981017, 'max_depth': 5, 'eta': 0.0021371691171342745, 'subsample': 0.8030264622870242, 'colsample_bytree': 0.992162151601555}. Best is trial 11 with value: 0.7815.
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-29 13:56:20,584] Trial 24 finished with value: 0.777 and parameters: {'alpha': 0.8791279054247844, 'lambda': 0.000256898771947363, 'max_depth': 4, 'eta': 0.08831453092117521, 'subsample': 0.7224276755479877, 'colsample_bytree': 0.6485330057351747}. Best is trial 11 with value: 0.7815.
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-29 13:56:24,124] Trial 25 finished with value: 0.7695 and parameters: {'alpha': 0.021204001292263495, 'lambda': 0.018094979121716245, 'max_depth': 6, 'eta': 0.0002903205839442503, 'subsample': 0.8529130640127812, 'colsample_bytree': 0.7774762302410919}. Best is trial 11 with value: 0.7815.
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-29 13:56:26,367] Trial 26 finished with value: 0.7815 and parameters: {'alpha': 0.0026323502927523474, 'lambda': 0.0013629359580899793, 'max_depth': 5, 'eta': 0.006631770715254859, 'subsample': 0.7847349779867773, 'colsample_bytree': 0.99983341525335}. Best is trial 11 with value: 0.7815.
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-29 13:56:28,286] Trial 27 finished with value: 0.7725 and parameters: {'alpha': 0.13487941626160282, 'lambda': 0.0004075342866504223, 'max_depth': 4, 'eta': 0.0050241173525347, 'subsample': 0.780649930719461, 'colsample_bytree': 0.9895719768937434}. Best is trial 11 with value: 0.7815.
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-29 13:56:30,656] Trial 28 finished with value: 0.7755 and parameters: {'alpha': 0.02679032801421673, 'lambda': 0.00011306537018846929, 'max_depth': 5, 'eta': 0.0003789683524168132, 'subsample': 0.7109496162829801, 'colsample_bytree': 0.9162147235061169}. Best is trial 11 with value: 0.7815.
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-29 13:56:32,646] Trial 29 finished with value: 0.7735 and parameters: {'alpha': 0.00018413894449612338, 'lambda': 0.0013979499741561684, 'max_depth': 4, 'eta': 0.004832712070921463, 'subsample': 0.7441119819990435, 'colsample_bytree': 0.9659213968000215}. Best is trial 11 with value: 0.7815.
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-29 13:56:34,997] Trial 30 finished with value: 0.7785 and parameters: {'alpha': 0.0022707017428751372, 'lambda': 0.1987973153198703, 'max_depth': 5, 'eta': 0.0006262017477230859, 'subsample': 0.6852732590765815, 'colsample_bytree': 0.9999281789597083}. Best is trial 11 with value: 0.7815.
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-29 13:56:35,704] Trial 31 finished with value: 0.775 and parameters: {'alpha': 0.004177504565964362, 'lambda': 0.004834641402678432, 'max_depth': 7, 'eta': 0.032028543594901954, 'subsample': 0.8014926636248916, 'colsample_bytree': 0.9518029855091861}. Best is trial 11 with value: 0.7815.
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-29 13:56:36,863] Trial 32 finished with value: 0.7765 and parameters: {'alpha': 0.00036434718542878875, 'lambda': 0.011790330371278369, 'max_depth': 6, 'eta': 0.013274737467700148, 'subsample': 0.7460884790479066, 'colsample_bytree': 0.8818488748668396}. Best is trial 11 with value: 0.7815.
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-29 13:56:37,168] Trial 33 finished with value: 0.768 and parameters: {'alpha': 0.005814327062924152, 'lambda': 0.0020644479361321953, 'max_depth': 5, 'eta': 0.21168382810535305, 'subsample': 0.6834651580558475, 'colsample_bytree': 0.8665109102540351}. Best is trial 11 with value: 0.7815.
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-29 13:56:37,873] Trial 34 finished with value: 0.7755 and parameters: {'alpha': 0.0014732326555699316, 'lambda': 0.008720728087155336, 'max_depth': 6, 'eta': 0.033415673320796736, 'subsample': 0.6344978358791709, 'colsample_bytree': 0.97497937796257}. Best is trial 11 with value: 0.7815.
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-29 13:56:40,320] Trial 35 finished with value: 0.763 and parameters: {'alpha': 0.00011775780824316116, 'lambda': 0.04292441902541796, 'max_depth': 9, 'eta': 0.007834534895882365, 'subsample': 0.8769488065170299, 'colsample_bytree': 0.9344596265373172}. Best is trial 11 with value: 0.7815.
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-29 13:56:43,486] Trial 36 finished with value: 0.777 and parameters: {'alpha': 3.4710270423735574e-05, 'lambda': 0.014267706797815057, 'max_depth': 5, 'eta': 0.003052650130447039, 'subsample': 0.8438864517679724, 'colsample_bytree': 0.9128342734633773}. Best is trial 11 with value: 0.7815.
# ...
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-29 14:03:56,136] Trial 87 finished with value: 0.787 and parameters: {'alpha': 0.02323538790764449, 'lambda': 2.0586883855637867e-07, 'max_depth': 4, 'eta': 0.004819542047518105, 'subsample': 0.906583205225532, 'colsample_bytree': 0.6092345267776098}. Best is trial 81 with value: 0.79.
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-29 14:03:57,785] Trial 88 finished with value: 0.7845 and parameters: {'alpha': 0.07621321630525825, 'lambda': 1.6932711925690215e-07, 'max_depth': 4, 'eta': 0.005745607569386731, 'subsample': 0.9677039733769829, 'colsample_bytree': 0.601823882383405}. Best is trial 81 with value: 0.79.
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-29 14:03:59,556] Trial 89 finished with value: 0.782 and parameters: {'alpha': 0.024074332807428826, 'lambda': 4.1004888122996506e-07, 'max_depth': 5, 'eta': 0.004919836294000536, 'subsample': 0.9298163919056582, 'colsample_bytree': 0.6120787891205831}. Best is trial 81 with value: 0.79.
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-29 14:04:01,288] Trial 90 finished with value: 0.7805 and parameters: {'alpha': 0.01256897263757958, 'lambda': 4.602494778934659e-08, 'max_depth': 4, 'eta': 0.0022954958958077147, 'subsample': 0.9111004603959548, 'colsample_bytree': 0.5880605671958098}. Best is trial 81 with value: 0.79.
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-29 14:04:02,222] Trial 91 finished with value: 0.7865 and parameters: {'alpha': 0.031510534723117455, 'lambda': 6.34624665484828e-07, 'max_depth': 4, 'eta': 0.02008549813485189, 'subsample': 0.9363279213793062, 'colsample_bytree': 0.6355370225625855}. Best is trial 81 with value: 0.79.
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-29 14:04:03,088] Trial 92 finished with value: 0.785 and parameters: {'alpha': 0.049885415670923666, 'lambda': 5.566231465445503e-07, 'max_depth': 4, 'eta': 0.02130588842838944, 'subsample': 0.9464491700958892, 'colsample_bytree': 0.6241596910267307}. Best is trial 81 with value: 0.79.
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-29 14:04:04,670] Trial 93 finished with value: 0.782 and parameters: {'alpha': 0.029179198641703912, 'lambda': 1.279554740282629e-07, 'max_depth': 4, 'eta': 0.002648202519147812, 'subsample': 0.9371357349579705, 'colsample_bytree': 0.6336221181821249}. Best is trial 81 with value: 0.79.
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-29 14:04:05,275] Trial 94 finished with value: 0.782 and parameters: {'alpha': 0.13330295241293671, 'lambda': 7.714027379074463e-07, 'max_depth': 4, 'eta': 0.037306712071105724, 'subsample': 0.9204423862231654, 'colsample_bytree': 0.6586259459913631}. Best is trial 81 with value: 0.79.
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-29 14:04:06,083] Trial 95 finished with value: 0.7815 and parameters: {'alpha': 0.08057356322725207, 'lambda': 2.580324072365079e-07, 'max_depth': 5, 'eta': 0.020718535432828807, 'subsample': 0.8869435702186703, 'colsample_bytree': 0.6141687281692878}. Best is trial 81 with value: 0.79.
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-29 14:04:07,822] Trial 96 finished with value: 0.783 and parameters: {'alpha': 0.010075890374466155, 'lambda': 1.4206972221957035e-06, 'max_depth': 4, 'eta': 0.009258213113517731, 'subsample': 0.907673740836868, 'colsample_bytree': 0.5976023253826414}. Best is trial 81 with value: 0.79.
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-29 14:04:08,277] Trial 97 finished with value: 0.777 and parameters: {'alpha': 0.018528377243722104, 'lambda': 1.6627987769012452e-07, 'max_depth': 4, 'eta': 0.054823017462799245, 'subsample': 0.9402294894145733, 'colsample_bytree': 0.635905978562571}. Best is trial 81 with value: 0.79.
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-29 14:04:10,107] Trial 98 finished with value: 0.78 and parameters: {'alpha': 0.041295417394043674, 'lambda': 3.241626572313518e-06, 'max_depth': 5, 'eta': 0.007652246659223346, 'subsample': 0.9648263030101366, 'colsample_bytree': 0.6048924885364115}. Best is trial 81 with value: 0.79.
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\104161\AppData\Local\Temp\ipykernel_29416\458249601.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-29 14:04:11,705] Trial 99 finished with value: 0.783 and parameters: {'alpha': 0.19289294732334575, 'lambda': 3.5073573941587817e-07, 'max_depth': 4, 'eta': 0.0036220088708190457, 'subsample': 0.9276100873116659, 'colsample_bytree': 0.6620128895479904}. Best is trial 81 with value: 0.79.

# %% [markdown]
# - xgb_平均スコア

# %%
# 全フォールドの平均スコアを計算
xgb_average_score = sum(xgb_fold_scores) / n_splits
print(f"XGB Average accuracy across all folds: {xgb_average_score}")

xgb_average_conf = sum(xgb_conf_scores) / n_splits
print(f"XGB Average conf-matrix across all folds: {xgb_average_conf}")
# Out:
# XGB Average accuracy across all folds: 0.77
# XGB Average conf-matrix across all folds: [[762.5 254. ]
#  [206.  777.5]]

# %% [markdown]
# - xgb_予測平均

# %%
# 予測の平均を計算
xgb_y_test_pred_avg = np.mean(xgb_test_predictions, axis=0)

# 最終的な予測結果を整数に変換
xgb_y_test_pred_int = (xgb_y_test_pred_avg > xgb_threshold).astype(int)

# %% [markdown]
# - output

# %%
# 現在の日時を取得してフォーマットする
current_time = datetime.now().strftime("%Y%m%d_%H%M%S")
output = f'../data/output/{current_time}_XGBoost_cv{xgb_average_score:.4f}.csv'

submit = pd.DataFrame({
    '0': test['gameId'],
    '1': xgb_y_test_pred_int
})

# カラムヘッダー消去して出力
# ヘッダーなしでCSVファイルとして保存
submit.to_csv(output, header=False, index=False)

# %% [markdown]
# ## CatBoost

# %%
for train_index, val_index in kf.split(X):
    X_train_fold, X_val_fold = X.iloc[train_index], X.iloc[val_index]
    y_train_fold, y_val_fold = y[train_index], y[val_index]

    # Optunaでのハイパーパラメータチューニング
    def objective(trial):
        param = {
            'iterations': 1000,
            'depth': trial.suggest_int('depth', 4, 10),
            'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3),
            'random_strength': trial.suggest_int('random_strength', 1, 20),
            'bagging_temperature': trial.suggest_float('bagging_temperature', 0.0, 1.0),
            'l2_leaf_reg': trial.suggest_float('l2_leaf_reg', 1e-3, 100),
            'scale_pos_weight': trial.suggest_float('scale_pos_weight', 0.1, 10.0),
            'loss_function': 'Logloss'
        }

        model = cb.CatBoostClassifier(**param, verbose=False)
        model.fit(X_train_fold, y_train_fold, eval_set=(X_val_fold, y_val_fold), early_stopping_rounds=100)
        preds = model.predict(X_val_fold)
        accuracy = accuracy_score(y_val_fold, preds)
        return accuracy

    cb_study = optuna.create_study(direction='maximize')
    cb_study.optimize(objective, n_trials=100)

    # 各フォールドの最適パラメータでモデルを再学習
    cb_best_params = cb_study.best_params
    cb_best_params['loss_function'] = 'Logloss'
    model_fold = cb.CatBoostClassifier(**cb_best_params, verbose=False)
    model_fold.fit(X_train_fold, y_train_fold)

    # 各フォールドのモデル性能を評価
    cb_y_val_pred = model_fold.predict(X_val_fold)
    cb_fold_accuracy = accuracy_score(y_val_fold, cb_y_val_pred)
    cb_fold_scores.append(cb_fold_accuracy)

    # 混同行列
    cb_conf_matrix = confusion_matrix(y_val_fold, cb_y_val_pred)
    cb_conf_scores.append(cb_conf_matrix)

    # テストデータセットでの予測
    cb_y_test_pred_fold = model_fold.predict(test_drop_gameId)
    cb_test_predictions.append(cb_y_test_pred_fold)
# Out:
# [I 2024-01-29 14:04:11,935] A new study created in memory with name: no-name-1fa5c85d-d084-4387-8658-6f9418d34226
# [I 2024-01-29 14:04:13,093] Trial 0 finished with value: 0.707 and parameters: {'depth': 7, 'learning_rate': 0.29148363477623773, 'random_strength': 14, 'bagging_temperature': 0.4348089347935692, 'l2_leaf_reg': 33.092886987383935, 'scale_pos_weight': 5.920971661138992}. Best is trial 0 with value: 0.707.
# [I 2024-01-29 14:04:17,094] Trial 1 finished with value: 0.7125 and parameters: {'depth': 10, 'learning_rate': 0.19855954180469565, 'random_strength': 2, 'bagging_temperature': 0.3166317883746238, 'l2_leaf_reg': 91.2104658344991, 'scale_pos_weight': 4.479957075156587}. Best is trial 1 with value: 0.7125.
# [I 2024-01-29 14:04:21,353] Trial 2 finished with value: 0.708 and parameters: {'depth': 10, 'learning_rate': 0.19952416607618192, 'random_strength': 19, 'bagging_temperature': 0.7332348831895464, 'l2_leaf_reg': 10.410608790077328, 'scale_pos_weight': 5.7636845575714934}. Best is trial 1 with value: 0.7125.
# [I 2024-01-29 14:04:22,030] Trial 3 finished with value: 0.7355 and parameters: {'depth': 5, 'learning_rate': 0.2895706955934987, 'random_strength': 1, 'bagging_temperature': 0.8839390241068193, 'l2_leaf_reg': 87.3686337236566, 'scale_pos_weight': 2.76716349342138}. Best is trial 3 with value: 0.7355.
# [I 2024-01-29 14:04:23,263] Trial 4 finished with value: 0.7145 and parameters: {'depth': 8, 'learning_rate': 0.2680658045878666, 'random_strength': 9, 'bagging_temperature': 0.2706478909320059, 'l2_leaf_reg': 34.58869853601518, 'scale_pos_weight': 4.634588812057715}. Best is trial 3 with value: 0.7355.
# [I 2024-01-29 14:04:27,702] Trial 5 finished with value: 0.6935 and parameters: {'depth': 10, 'learning_rate': 0.11936795373176348, 'random_strength': 7, 'bagging_temperature': 0.5186228284335782, 'l2_leaf_reg': 13.315838803175675, 'scale_pos_weight': 7.11341647467974}. Best is trial 3 with value: 0.7355.
# [I 2024-01-29 14:04:28,906] Trial 6 finished with value: 0.677 and parameters: {'depth': 7, 'learning_rate': 0.11331508608870072, 'random_strength': 4, 'bagging_temperature': 0.8623338309800882, 'l2_leaf_reg': 45.32507764620787, 'scale_pos_weight': 8.09339798712267}. Best is trial 3 with value: 0.7355.
# [I 2024-01-29 14:04:33,177] Trial 7 finished with value: 0.7465 and parameters: {'depth': 10, 'learning_rate': 0.184173741941922, 'random_strength': 6, 'bagging_temperature': 0.7626896770907742, 'l2_leaf_reg': 62.16387800647488, 'scale_pos_weight': 0.41447531980627395}. Best is trial 7 with value: 0.7465.
# [I 2024-01-29 14:04:34,718] Trial 8 finished with value: 0.701 and parameters: {'depth': 9, 'learning_rate': 0.22806785589852765, 'random_strength': 9, 'bagging_temperature': 0.847622434473085, 'l2_leaf_reg': 3.1724971536953737, 'scale_pos_weight': 4.2486286466191565}. Best is trial 7 with value: 0.7465.
# [I 2024-01-29 14:04:35,629] Trial 9 finished with value: 0.7125 and parameters: {'depth': 4, 'learning_rate': 0.118999116459559, 'random_strength': 2, 'bagging_temperature': 0.09944514940648697, 'l2_leaf_reg': 24.413091396158322, 'scale_pos_weight': 5.750247450663305}. Best is trial 7 with value: 0.7465.
# [I 2024-01-29 14:04:38,107] Trial 10 finished with value: 0.7645 and parameters: {'depth': 6, 'learning_rate': 0.05150275425350681, 'random_strength': 15, 'bagging_temperature': 0.6766952702587066, 'l2_leaf_reg': 66.07593233025173, 'scale_pos_weight': 0.6138797359144814}. Best is trial 10 with value: 0.7645.
# [I 2024-01-29 14:04:41,618] Trial 11 finished with value: 0.673 and parameters: {'depth': 6, 'learning_rate': 0.027921389206941954, 'random_strength': 15, 'bagging_temperature': 0.6558538242668339, 'l2_leaf_reg': 64.38696632357588, 'scale_pos_weight': 0.15878304298651852}. Best is trial 10 with value: 0.7645.
# [I 2024-01-29 14:04:44,146] Trial 12 finished with value: 0.7455 and parameters: {'depth': 6, 'learning_rate': 0.03484458051418657, 'random_strength': 13, 'bagging_temperature': 0.6670346172070932, 'l2_leaf_reg': 64.20636651065473, 'scale_pos_weight': 0.38976334243019883}. Best is trial 10 with value: 0.7645.
# [I 2024-01-29 14:04:47,605] Trial 13 finished with value: 0.754 and parameters: {'depth': 8, 'learning_rate': 0.0598557791036277, 'random_strength': 19, 'bagging_temperature': 0.9685344155961872, 'l2_leaf_reg': 63.8272206746205, 'scale_pos_weight': 1.9889410179699403}. Best is trial 10 with value: 0.7645.
# [I 2024-01-29 14:04:50,560] Trial 14 finished with value: 0.751 and parameters: {'depth': 8, 'learning_rate': 0.08128828725600488, 'random_strength': 20, 'bagging_temperature': 0.9962468391245508, 'l2_leaf_reg': 79.78540375337398, 'scale_pos_weight': 2.061181251391556}. Best is trial 10 with value: 0.7645.
# [I 2024-01-29 14:04:52,867] Trial 15 finished with value: 0.7565 and parameters: {'depth': 6, 'learning_rate': 0.06028985310188406, 'random_strength': 17, 'bagging_temperature': 0.9962427598311644, 'l2_leaf_reg': 75.4808166742308, 'scale_pos_weight': 1.8178609725700046}. Best is trial 10 with value: 0.7645.
# [I 2024-01-29 14:04:56,712] Trial 16 finished with value: 0.721 and parameters: {'depth': 5, 'learning_rate': 0.014775882613199828, 'random_strength': 16, 'bagging_temperature': 0.5643860737552168, 'l2_leaf_reg': 99.10377677725663, 'scale_pos_weight': 2.892776515777334}. Best is trial 10 with value: 0.7645.
# [I 2024-01-29 14:04:59,447] Trial 17 finished with value: 0.6575 and parameters: {'depth': 6, 'learning_rate': 0.05425607919248099, 'random_strength': 17, 'bagging_temperature': 0.7763493189290875, 'l2_leaf_reg': 75.935216154362, 'scale_pos_weight': 9.779816610222131}. Best is trial 10 with value: 0.7645.
# [I 2024-01-29 14:05:02,997] Trial 18 finished with value: 0.756 and parameters: {'depth': 4, 'learning_rate': 0.010638874815946317, 'random_strength': 12, 'bagging_temperature': 0.9726821026930802, 'l2_leaf_reg': 51.99831330892669, 'scale_pos_weight': 1.3202960577425298}. Best is trial 10 with value: 0.7645.
# [I 2024-01-29 14:05:04,767] Trial 19 finished with value: 0.769 and parameters: {'depth': 5, 'learning_rate': 0.0800371520291926, 'random_strength': 18, 'bagging_temperature': 0.6210839373214738, 'l2_leaf_reg': 75.68582680303892, 'scale_pos_weight': 1.3659191127000896}. Best is trial 19 with value: 0.769.
# [I 2024-01-29 14:05:06,248] Trial 20 finished with value: 0.7265 and parameters: {'depth': 5, 'learning_rate': 0.09307421284999207, 'random_strength': 11, 'bagging_temperature': 0.6017173847861738, 'l2_leaf_reg': 73.5213400524412, 'scale_pos_weight': 2.997753034236056}. Best is trial 19 with value: 0.769.
# [I 2024-01-29 14:05:08,721] Trial 21 finished with value: 0.773 and parameters: {'depth': 6, 'learning_rate': 0.059264063029084345, 'random_strength': 18, 'bagging_temperature': 0.6642994902642735, 'l2_leaf_reg': 81.41437776700371, 'scale_pos_weight': 1.2506768878256564}. Best is trial 21 with value: 0.773.
# [I 2024-01-29 14:05:09,861] Trial 22 finished with value: 0.7725 and parameters: {'depth': 5, 'learning_rate': 0.14280014513608158, 'random_strength': 18, 'bagging_temperature': 0.6555800375059926, 'l2_leaf_reg': 84.75727830152238, 'scale_pos_weight': 1.0605163187929483}. Best is trial 21 with value: 0.773.
# [I 2024-01-29 14:05:11,191] Trial 23 finished with value: 0.771 and parameters: {'depth': 5, 'learning_rate': 0.147045651507455, 'random_strength': 18, 'bagging_temperature': 0.5138442679707695, 'l2_leaf_reg': 84.84274920678745, 'scale_pos_weight': 1.1628362183529068}. Best is trial 21 with value: 0.773.
# [I 2024-01-29 14:05:12,428] Trial 24 finished with value: 0.7735 and parameters: {'depth': 4, 'learning_rate': 0.15100035759791947, 'random_strength': 20, 'bagging_temperature': 0.45520170974140883, 'l2_leaf_reg': 86.90209394449755, 'scale_pos_weight': 1.0567964331879134}. Best is trial 24 with value: 0.7735.
# [I 2024-01-29 14:05:13,710] Trial 25 finished with value: 0.7265 and parameters: {'depth': 4, 'learning_rate': 0.15276461862904475, 'random_strength': 20, 'bagging_temperature': 0.4311447965063671, 'l2_leaf_reg': 99.21607791612884, 'scale_pos_weight': 3.401070361581125}. Best is trial 24 with value: 0.7735.
# [I 2024-01-29 14:05:15,195] Trial 26 finished with value: 0.781 and parameters: {'depth': 4, 'learning_rate': 0.1351162444041498, 'random_strength': 20, 'bagging_temperature': 0.5553376038364881, 'l2_leaf_reg': 91.41900244548344, 'scale_pos_weight': 1.025234617698942}. Best is trial 26 with value: 0.781.
# [I 2024-01-29 14:05:16,099] Trial 27 finished with value: 0.742 and parameters: {'depth': 4, 'learning_rate': 0.1723579681166411, 'random_strength': 20, 'bagging_temperature': 0.45431675310694664, 'l2_leaf_reg': 91.58342528211139, 'scale_pos_weight': 2.05045515622574}. Best is trial 26 with value: 0.781.
# [I 2024-01-29 14:05:17,487] Trial 28 finished with value: 0.7275 and parameters: {'depth': 4, 'learning_rate': 0.1373337110670797, 'random_strength': 16, 'bagging_temperature': 0.538684139681419, 'l2_leaf_reg': 94.90987345185111, 'scale_pos_weight': 3.6551452447844226}. Best is trial 26 with value: 0.781.
# [I 2024-01-29 14:05:19,287] Trial 29 finished with value: 0.6725 and parameters: {'depth': 7, 'learning_rate': 0.1008355144795276, 'random_strength': 14, 'bagging_temperature': 0.433133083314514, 'l2_leaf_reg': 83.54676608521468, 'scale_pos_weight': 0.16593013229470555}. Best is trial 26 with value: 0.781.
# [I 2024-01-29 14:05:20,176] Trial 30 finished with value: 0.743 and parameters: {'depth': 4, 'learning_rate': 0.16557692199630916, 'random_strength': 20, 'bagging_temperature': 0.3744472405958529, 'l2_leaf_reg': 93.01810874276192, 'scale_pos_weight': 2.2868485150955573}. Best is trial 26 with value: 0.781.
# [I 2024-01-29 14:05:21,871] Trial 31 finished with value: 0.7715 and parameters: {'depth': 5, 'learning_rate': 0.13619042451238564, 'random_strength': 18, 'bagging_temperature': 0.5578332510555762, 'l2_leaf_reg': 86.16266501099359, 'scale_pos_weight': 1.1743086874242046}. Best is trial 26 with value: 0.781.
# [I 2024-01-29 14:05:23,409] Trial 32 finished with value: 0.767 and parameters: {'depth': 5, 'learning_rate': 0.1303675123388577, 'random_strength': 17, 'bagging_temperature': 0.5874427234646482, 'l2_leaf_reg': 88.74917815017295, 'scale_pos_weight': 0.7917601602008866}. Best is trial 26 with value: 0.781.
# [I 2024-01-29 14:05:24,882] Trial 33 finished with value: 0.765 and parameters: {'depth': 7, 'learning_rate': 0.1652999277938752, 'random_strength': 19, 'bagging_temperature': 0.7149969011834524, 'l2_leaf_reg': 80.90455340296654, 'scale_pos_weight': 1.6037423268358442}. Best is trial 26 with value: 0.781.
# [I 2024-01-29 14:05:26,591] Trial 34 finished with value: 0.7715 and parameters: {'depth': 4, 'learning_rate': 0.14854697610775008, 'random_strength': 18, 'bagging_temperature': 0.6229006255163411, 'l2_leaf_reg': 92.96353747544981, 'scale_pos_weight': 0.9292568456557418}. Best is trial 26 with value: 0.781.
# [I 2024-01-29 14:05:27,658] Trial 35 finished with value: 0.745 and parameters: {'depth': 5, 'learning_rate': 0.1926896086574697, 'random_strength': 16, 'bagging_temperature': 0.4762654985497722, 'l2_leaf_reg': 99.61666648690594, 'scale_pos_weight': 2.4602009899418906}. Best is trial 26 with value: 0.781.
# [I 2024-01-29 14:05:29,040] Trial 36 finished with value: 0.756 and parameters: {'depth': 6, 'learning_rate': 0.10464205825717995, 'random_strength': 19, 'bagging_temperature': 0.7065628232787498, 'l2_leaf_reg': 85.08784963545698, 'scale_pos_weight': 1.5705653634541963}. Best is trial 26 with value: 0.781.
# [I 2024-01-29 14:05:31,072] Trial 37 finished with value: 0.7695 and parameters: {'depth': 4, 'learning_rate': 0.12868485402907523, 'random_strength': 14, 'bagging_temperature': 0.5016417345618617, 'l2_leaf_reg': 88.7815263434572, 'scale_pos_weight': 0.8882464654874884}. Best is trial 26 with value: 0.781.
# [I 2024-01-29 14:05:32,074] Trial 38 finished with value: 0.7405 and parameters: {'depth': 5, 'learning_rate': 0.2072758921802889, 'random_strength': 20, 'bagging_temperature': 0.36858775523629606, 'l2_leaf_reg': 71.63395299371646, 'scale_pos_weight': 2.4966384821363956}. Best is trial 26 with value: 0.781.
# [I 2024-01-29 14:05:33,405] Trial 39 finished with value: 0.623 and parameters: {'depth': 4, 'learning_rate': 0.11657733029725376, 'random_strength': 17, 'bagging_temperature': 0.7702014664526479, 'l2_leaf_reg': 81.70269567637318, 'scale_pos_weight': 0.10106875013675809}. Best is trial 26 with value: 0.781.
# [I 2024-01-29 14:05:35,264] Trial 40 finished with value: 0.778 and parameters: {'depth': 5, 'learning_rate': 0.18153589153903057, 'random_strength': 9, 'bagging_temperature': 0.568654195558417, 'l2_leaf_reg': 91.82311308984472, 'scale_pos_weight': 0.7507320906685678}. Best is trial 26 with value: 0.781.
# [I 2024-01-29 14:05:36,656] Trial 41 finished with value: 0.7655 and parameters: {'depth': 5, 'learning_rate': 0.1746312116826793, 'random_strength': 9, 'bagging_temperature': 0.5681102119429596, 'l2_leaf_reg': 89.98113047558112, 'scale_pos_weight': 0.7037763458620607}. Best is trial 26 with value: 0.781.
# [I 2024-01-29 14:05:37,996] Trial 42 finished with value: 0.76 and parameters: {'depth': 6, 'learning_rate': 0.15985784750751283, 'random_strength': 10, 'bagging_temperature': 0.6423362888188849, 'l2_leaf_reg': 95.11193307980116, 'scale_pos_weight': 1.6706454953681928}. Best is trial 26 with value: 0.781.
# [I 2024-01-29 14:05:39,031] Trial 43 finished with value: 0.7675 and parameters: {'depth': 5, 'learning_rate': 0.1791854038807215, 'random_strength': 7, 'bagging_temperature': 0.5215497276046048, 'l2_leaf_reg': 79.97099243987932, 'scale_pos_weight': 0.8118825950556255}. Best is trial 26 with value: 0.781.
# [I 2024-01-29 14:05:40,323] Trial 44 finished with value: 0.7665 and parameters: {'depth': 4, 'learning_rate': 0.21089011118185286, 'random_strength': 7, 'bagging_temperature': 0.6091177438434974, 'l2_leaf_reg': 87.43978271835957, 'scale_pos_weight': 1.2545280889923307}. Best is trial 26 with value: 0.781.
# [I 2024-01-29 14:05:41,370] Trial 45 finished with value: 0.7575 and parameters: {'depth': 6, 'learning_rate': 0.18962971913481486, 'random_strength': 5, 'bagging_temperature': 0.6660221935346297, 'l2_leaf_reg': 94.93160184601206, 'scale_pos_weight': 0.4908779436414318}. Best is trial 26 with value: 0.781.
# [I 2024-01-29 14:05:42,475] Trial 46 finished with value: 0.7565 and parameters: {'depth': 5, 'learning_rate': 0.14473408207762944, 'random_strength': 8, 'bagging_temperature': 0.7104449695339061, 'l2_leaf_reg': 78.94295731442243, 'scale_pos_weight': 1.7474754751109525}. Best is trial 26 with value: 0.781.
# [I 2024-01-29 14:05:43,700] Trial 47 finished with value: 0.7385 and parameters: {'depth': 6, 'learning_rate': 0.12478223156573566, 'random_strength': 12, 'bagging_temperature': 0.48543732550884866, 'l2_leaf_reg': 70.54786058668815, 'scale_pos_weight': 2.370381931903803}. Best is trial 26 with value: 0.781.
# [I 2024-01-29 14:05:45,114] Trial 48 finished with value: 0.764 and parameters: {'depth': 4, 'learning_rate': 0.15540283415157372, 'random_strength': 3, 'bagging_temperature': 0.5545510922355449, 'l2_leaf_reg': 88.89556742695865, 'scale_pos_weight': 0.5050081122492979}. Best is trial 26 with value: 0.781.
# [I 2024-01-29 14:05:48,662] Trial 49 finished with value: 0.625 and parameters: {'depth': 9, 'learning_rate': 0.11321717346411145, 'random_strength': 19, 'bagging_temperature': 0.6702150543017142, 'l2_leaf_reg': 84.58911180893674, 'scale_pos_weight': 0.1023943417767138}. Best is trial 26 with value: 0.781.
# [I 2024-01-29 14:05:49,700] Trial 50 finished with value: 0.755 and parameters: {'depth': 4, 'learning_rate': 0.24135350213034265, 'random_strength': 19, 'bagging_temperature': 0.8050591037328844, 'l2_leaf_reg': 77.14475772382521, 'scale_pos_weight': 1.9485740145248491}. Best is trial 26 with value: 0.781.
# [I 2024-01-29 14:05:50,994] Trial 51 finished with value: 0.7675 and parameters: {'depth': 5, 'learning_rate': 0.13808218115880244, 'random_strength': 18, 'bagging_temperature': 0.5805221480409142, 'l2_leaf_reg': 84.45631722646263, 'scale_pos_weight': 1.474948035769093}. Best is trial 26 with value: 0.781.
# [I 2024-01-29 14:05:52,335] Trial 52 finished with value: 0.7775 and parameters: {'depth': 5, 'learning_rate': 0.13602768773393697, 'random_strength': 15, 'bagging_temperature': 0.5403705516784673, 'l2_leaf_reg': 69.62413949247617, 'scale_pos_weight': 1.1079611876734936}. Best is trial 26 with value: 0.781.
# [I 2024-01-29 14:05:54,118] Trial 53 finished with value: 0.775 and parameters: {'depth': 6, 'learning_rate': 0.18080994430830713, 'random_strength': 15, 'bagging_temperature': 0.6415686229664914, 'l2_leaf_reg': 81.30632824073457, 'scale_pos_weight': 1.0345364347312362}. Best is trial 26 with value: 0.781.
# [I 2024-01-29 14:05:55,232] Trial 54 finished with value: 0.765 and parameters: {'depth': 6, 'learning_rate': 0.17981943399942069, 'random_strength': 15, 'bagging_temperature': 0.5356492825159405, 'l2_leaf_reg': 69.3216485943751, 'scale_pos_weight': 0.5788926793524612}. Best is trial 26 with value: 0.781.
# [I 2024-01-29 14:05:56,964] Trial 55 finished with value: 0.7695 and parameters: {'depth': 7, 'learning_rate': 0.1632573675203866, 'random_strength': 10, 'bagging_temperature': 0.61746978726821, 'l2_leaf_reg': 78.35690764647316, 'scale_pos_weight': 1.0468273827399364}. Best is trial 26 with value: 0.781.
# [I 2024-01-29 14:05:58,179] Trial 56 finished with value: 0.771 and parameters: {'depth': 6, 'learning_rate': 0.20205180325142147, 'random_strength': 12, 'bagging_temperature': 0.5853086320502615, 'l2_leaf_reg': 73.95692421885587, 'scale_pos_weight': 1.3263214047825649}. Best is trial 26 with value: 0.781.
# [I 2024-01-29 14:05:59,697] Trial 57 finished with value: 0.7615 and parameters: {'depth': 7, 'learning_rate': 0.18418239851228008, 'random_strength': 13, 'bagging_temperature': 0.4899096509231333, 'l2_leaf_reg': 60.358238453019595, 'scale_pos_weight': 1.8732477073460738}. Best is trial 26 with value: 0.781.
# [I 2024-01-29 14:06:00,918] Trial 58 finished with value: 0.728 and parameters: {'depth': 6, 'learning_rate': 0.15684845422410315, 'random_strength': 14, 'bagging_temperature': 0.730952702263761, 'l2_leaf_reg': 81.39890182540476, 'scale_pos_weight': 2.8442818670556353}. Best is trial 26 with value: 0.781.
# [I 2024-01-29 14:06:01,949] Trial 59 finished with value: 0.75 and parameters: {'depth': 5, 'learning_rate': 0.1712192217782342, 'random_strength': 11, 'bagging_temperature': 0.5405646990432017, 'l2_leaf_reg': 68.45582246456101, 'scale_pos_weight': 0.39549342938975784}. Best is trial 26 with value: 0.781.
# [I 2024-01-29 14:06:04,499] Trial 60 finished with value: 0.7475 and parameters: {'depth': 8, 'learning_rate': 0.12365897032761194, 'random_strength': 16, 'bagging_temperature': 0.689138448823078, 'l2_leaf_reg': 91.64454977133842, 'scale_pos_weight': 2.1862751607820248}. Best is trial 26 with value: 0.781.
# [I 2024-01-29 14:06:06,094] Trial 61 finished with value: 0.7675 and parameters: {'depth': 5, 'learning_rate': 0.1539298648762569, 'random_strength': 17, 'bagging_temperature': 0.6227976319755093, 'l2_leaf_reg': 82.50868369757927, 'scale_pos_weight': 0.8655446270841072}. Best is trial 26 with value: 0.781.
# [I 2024-01-29 14:06:07,320] Trial 62 finished with value: 0.7765 and parameters: {'depth': 4, 'learning_rate': 0.14028985199956845, 'random_strength': 20, 'bagging_temperature': 0.6617564295410869, 'l2_leaf_reg': 86.84353467068816, 'scale_pos_weight': 1.1826233391761196}. Best is trial 26 with value: 0.781.
# [I 2024-01-29 14:06:10,078] Trial 63 finished with value: 0.7685 and parameters: {'depth': 4, 'learning_rate': 0.08474776182671004, 'random_strength': 20, 'bagging_temperature': 0.6426934147649642, 'l2_leaf_reg': 75.69296504433528, 'scale_pos_weight': 1.371923502116432}. Best is trial 26 with value: 0.781.
# [I 2024-01-29 14:06:12,689] Trial 64 finished with value: 0.761 and parameters: {'depth': 4, 'learning_rate': 0.07011331193341587, 'random_strength': 19, 'bagging_temperature': 0.752168317992117, 'l2_leaf_reg': 96.99211430371298, 'scale_pos_weight': 1.5792861329371588}. Best is trial 26 with value: 0.781.
# [I 2024-01-29 14:06:14,562] Trial 65 finished with value: 0.776 and parameters: {'depth': 4, 'learning_rate': 0.10710794609919266, 'random_strength': 20, 'bagging_temperature': 0.6869725252868912, 'l2_leaf_reg': 90.66697079082492, 'scale_pos_weight': 1.0689491873542272}. Best is trial 26 with value: 0.781.
# [I 2024-01-29 14:06:16,054] Trial 66 finished with value: 0.774 and parameters: {'depth': 4, 'learning_rate': 0.14168808052730308, 'random_strength': 8, 'bagging_temperature': 0.6906312034773435, 'l2_leaf_reg': 91.19864076779446, 'scale_pos_weight': 1.0156661648526981}. Best is trial 26 with value: 0.781.
# [I 2024-01-29 14:06:17,597] Trial 67 finished with value: 0.7695 and parameters: {'depth': 4, 'learning_rate': 0.1308719074951051, 'random_strength': 8, 'bagging_temperature': 0.6916525803935673, 'l2_leaf_reg': 92.1252722624157, 'scale_pos_weight': 0.5941487123684744}. Best is trial 26 with value: 0.781.
# [I 2024-01-29 14:06:18,922] Trial 68 finished with value: 0.753 and parameters: {'depth': 4, 'learning_rate': 0.11075775380528273, 'random_strength': 6, 'bagging_temperature': 0.7313576222899605, 'l2_leaf_reg': 97.1421449191601, 'scale_pos_weight': 1.81988227453228}. Best is trial 26 with value: 0.781.
# [I 2024-01-29 14:06:20,550] Trial 69 finished with value: 0.7685 and parameters: {'depth': 4, 'learning_rate': 0.14131745135814197, 'random_strength': 9, 'bagging_temperature': 0.5915474547437823, 'l2_leaf_reg': 89.53555721764866, 'scale_pos_weight': 1.0557334352431536}. Best is trial 26 with value: 0.781.
# [I 2024-01-29 14:06:22,214] Trial 70 finished with value: 0.748 and parameters: {'depth': 5, 'learning_rate': 0.10503928857675002, 'random_strength': 10, 'bagging_temperature': 0.6411480764389463, 'l2_leaf_reg': 86.99223354059625, 'scale_pos_weight': 0.3942415176951184}. Best is trial 26 with value: 0.781.
# [I 2024-01-29 14:06:23,478] Trial 71 finished with value: 0.7715 and parameters: {'depth': 4, 'learning_rate': 0.15062774941895476, 'random_strength': 8, 'bagging_temperature': 0.5660307600751544, 'l2_leaf_reg': 92.68139155955248, 'scale_pos_weight': 1.0069713328999315}. Best is trial 26 with value: 0.781.
# [I 2024-01-29 14:06:25,343] Trial 72 finished with value: 0.7735 and parameters: {'depth': 4, 'learning_rate': 0.13467274543630894, 'random_strength': 20, 'bagging_temperature': 0.5118979660253538, 'l2_leaf_reg': 87.05537127711109, 'scale_pos_weight': 0.718033283838208}. Best is trial 26 with value: 0.781.
# [I 2024-01-29 14:06:26,493] Trial 73 finished with value: 0.7555 and parameters: {'depth': 4, 'learning_rate': 0.14623091786965153, 'random_strength': 20, 'bagging_temperature': 0.6939402495474788, 'l2_leaf_reg': 96.87168004528269, 'scale_pos_weight': 1.5106843816839546}. Best is trial 26 with value: 0.781.
# [I 2024-01-29 14:06:27,886] Trial 74 finished with value: 0.7465 and parameters: {'depth': 4, 'learning_rate': 0.11998924544937528, 'random_strength': 19, 'bagging_temperature': 0.46230685462236176, 'l2_leaf_reg': 91.02549699385565, 'scale_pos_weight': 2.1255220478647727}. Best is trial 26 with value: 0.781.
# [I 2024-01-29 14:06:29,171] Trial 75 finished with value: 0.772 and parameters: {'depth': 4, 'learning_rate': 0.16459323157854833, 'random_strength': 13, 'bagging_temperature': 0.5964830835316896, 'l2_leaf_reg': 83.47491467953041, 'scale_pos_weight': 1.1651388613863625}. Best is trial 26 with value: 0.781.
# [I 2024-01-29 14:06:30,521] Trial 76 finished with value: 0.7375 and parameters: {'depth': 5, 'learning_rate': 0.13118292592522007, 'random_strength': 6, 'bagging_temperature': 0.5369506871424446, 'l2_leaf_reg': 94.67783176598589, 'scale_pos_weight': 2.5954013296628506}. Best is trial 26 with value: 0.781.
# [I 2024-01-29 14:06:31,966] Trial 77 finished with value: 0.7495 and parameters: {'depth': 4, 'learning_rate': 0.14025061126970478, 'random_strength': 1, 'bagging_temperature': 0.6428774669429475, 'l2_leaf_reg': 86.67242715726837, 'scale_pos_weight': 0.3744303091681923}. Best is trial 26 with value: 0.781.
# [I 2024-01-29 14:06:33,867] Trial 78 finished with value: 0.7705 and parameters: {'depth': 4, 'learning_rate': 0.12433398705552698, 'random_strength': 9, 'bagging_temperature': 0.6692473872953254, 'l2_leaf_reg': 89.88461109829002, 'scale_pos_weight': 0.7140319179458305}. Best is trial 26 with value: 0.781.
# [I 2024-01-29 14:06:35,002] Trial 79 finished with value: 0.7645 and parameters: {'depth': 5, 'learning_rate': 0.17146404722484718, 'random_strength': 17, 'bagging_temperature': 0.7921826280174052, 'l2_leaf_reg': 77.54976629121458, 'scale_pos_weight': 1.415589214083013}. Best is trial 26 with value: 0.781.
# [I 2024-01-29 14:06:36,371] Trial 80 finished with value: 0.758 and parameters: {'depth': 4, 'learning_rate': 0.15918646200294578, 'random_strength': 19, 'bagging_temperature': 0.5126588105185594, 'l2_leaf_reg': 99.95594888905066, 'scale_pos_weight': 1.8011454857732012}. Best is trial 26 with value: 0.781.
# [I 2024-01-29 14:06:37,384] Trial 81 finished with value: 0.769 and parameters: {'depth': 4, 'learning_rate': 0.13489966732693695, 'random_strength': 20, 'bagging_temperature': 0.5164701288160538, 'l2_leaf_reg': 87.64305576225547, 'scale_pos_weight': 0.8236189171272724}. Best is trial 26 with value: 0.781.
# [I 2024-01-29 14:06:38,582] Trial 82 finished with value: 0.7685 and parameters: {'depth': 4, 'learning_rate': 0.14837694592626352, 'random_strength': 20, 'bagging_temperature': 0.5644837925972038, 'l2_leaf_reg': 80.43921474754687, 'scale_pos_weight': 0.9799549677411448}. Best is trial 26 with value: 0.781.
# [I 2024-01-29 14:06:40,859] Trial 83 finished with value: 0.777 and parameters: {'depth': 4, 'learning_rate': 0.1158834288162991, 'random_strength': 18, 'bagging_temperature': 0.4498336619849225, 'l2_leaf_reg': 86.57523212281814, 'scale_pos_weight': 1.196072272431104}. Best is trial 26 with value: 0.781.
# [I 2024-01-29 14:06:43,010] Trial 84 finished with value: 0.7775 and parameters: {'depth': 5, 'learning_rate': 0.09708886067258175, 'random_strength': 18, 'bagging_temperature': 0.395500438212107, 'l2_leaf_reg': 82.74204879136063, 'scale_pos_weight': 1.1514330103516017}. Best is trial 26 with value: 0.781.
# [I 2024-01-29 14:06:44,546] Trial 85 finished with value: 0.7315 and parameters: {'depth': 5, 'learning_rate': 0.09106121856406997, 'random_strength': 18, 'bagging_temperature': 0.4084823458725003, 'l2_leaf_reg': 82.4432912803638, 'scale_pos_weight': 0.3022737474799282}. Best is trial 26 with value: 0.781.
# [I 2024-01-29 14:06:46,587] Trial 86 finished with value: 0.771 and parameters: {'depth': 5, 'learning_rate': 0.11680217978091594, 'random_strength': 16, 'bagging_temperature': 0.6096918636953568, 'l2_leaf_reg': 90.21348685536344, 'scale_pos_weight': 1.2535351712895568}. Best is trial 26 with value: 0.781.
# [I 2024-01-29 14:06:48,168] Trial 87 finished with value: 0.7505 and parameters: {'depth': 5, 'learning_rate': 0.09786181224894361, 'random_strength': 15, 'bagging_temperature': 0.46682360171774123, 'l2_leaf_reg': 84.48057388328988, 'scale_pos_weight': 2.0488156051093527}. Best is trial 26 with value: 0.781.
# [I 2024-01-29 14:06:49,765] Trial 88 finished with value: 0.7645 and parameters: {'depth': 5, 'learning_rate': 0.11387946419927554, 'random_strength': 18, 'bagging_temperature': 0.49165417662757716, 'l2_leaf_reg': 93.77562091917612, 'scale_pos_weight': 1.528290308144551}. Best is trial 26 with value: 0.781.
# [I 2024-01-29 14:06:51,432] Trial 89 finished with value: 0.765 and parameters: {'depth': 5, 'learning_rate': 0.10762822938763214, 'random_strength': 17, 'bagging_temperature': 0.4436836679554323, 'l2_leaf_reg': 79.4748013180585, 'scale_pos_weight': 0.5479930874285708}. Best is trial 26 with value: 0.781.
# [I 2024-01-29 14:06:52,647] Trial 90 finished with value: 0.7545 and parameters: {'depth': 4, 'learning_rate': 0.12546555786803784, 'random_strength': 19, 'bagging_temperature': 0.3126389864868408, 'l2_leaf_reg': 73.39592158986655, 'scale_pos_weight': 1.6939209580230812}. Best is trial 26 with value: 0.781.
# [I 2024-01-29 14:06:53,841] Trial 91 finished with value: 0.7735 and parameters: {'depth': 4, 'learning_rate': 0.14167036006819902, 'random_strength': 19, 'bagging_temperature': 0.47188800920345536, 'l2_leaf_reg': 86.37520999981436, 'scale_pos_weight': 1.1565609679897095}. Best is trial 26 with value: 0.781.
# [I 2024-01-29 14:06:56,254] Trial 92 finished with value: 0.7605 and parameters: {'depth': 4, 'learning_rate': 0.09912110684891048, 'random_strength': 20, 'bagging_temperature': 0.4204002432623494, 'l2_leaf_reg': 88.44666759322286, 'scale_pos_weight': 0.6460829237994219}. Best is trial 26 with value: 0.781.
# [I 2024-01-29 14:06:58,225] Trial 93 finished with value: 0.771 and parameters: {'depth': 4, 'learning_rate': 0.12979374285141893, 'random_strength': 18, 'bagging_temperature': 0.5445879548406137, 'l2_leaf_reg': 91.25493857093869, 'scale_pos_weight': 0.9354491924813169}. Best is trial 26 with value: 0.781.
# [I 2024-01-29 14:06:59,328] Trial 94 finished with value: 0.7685 and parameters: {'depth': 4, 'learning_rate': 0.15220939633392352, 'random_strength': 20, 'bagging_temperature': 0.408200845803204, 'l2_leaf_reg': 83.09087380158579, 'scale_pos_weight': 1.312924972631417}. Best is trial 26 with value: 0.781.
# [I 2024-01-29 14:07:00,908] Trial 95 finished with value: 0.724 and parameters: {'depth': 5, 'learning_rate': 0.10970822697220214, 'random_strength': 11, 'bagging_temperature': 0.4449328272264481, 'l2_leaf_reg': 85.41225696411885, 'scale_pos_weight': 0.285481418451357}. Best is trial 26 with value: 0.781.
# [I 2024-01-29 14:07:06,823] Trial 96 finished with value: 0.748 and parameters: {'depth': 10, 'learning_rate': 0.12062925984121073, 'random_strength': 8, 'bagging_temperature': 0.5802361461142814, 'l2_leaf_reg': 93.9045753180854, 'scale_pos_weight': 1.9348995716637263}. Best is trial 26 with value: 0.781.
# [I 2024-01-29 14:07:09,034] Trial 97 finished with value: 0.775 and parameters: {'depth': 4, 'learning_rate': 0.11860357720508201, 'random_strength': 19, 'bagging_temperature': 0.6302638025997367, 'l2_leaf_reg': 96.9355477866506, 'scale_pos_weight': 1.079591824163253}. Best is trial 26 with value: 0.781.
# [I 2024-01-29 14:07:10,807] Trial 98 finished with value: 0.7725 and parameters: {'depth': 4, 'learning_rate': 0.11700367090082053, 'random_strength': 19, 'bagging_temperature': 0.627656886375134, 'l2_leaf_reg': 97.11722390171126, 'scale_pos_weight': 0.8222638718889542}. Best is trial 26 with value: 0.781.
# [I 2024-01-29 14:07:12,575] Trial 99 finished with value: 0.76 and parameters: {'depth': 5, 'learning_rate': 0.10363708677271563, 'random_strength': 18, 'bagging_temperature': 0.7146996374194543, 'l2_leaf_reg': 95.1670664888288, 'scale_pos_weight': 1.629587571805215}. Best is trial 26 with value: 0.781.
# [I 2024-01-29 14:07:16,310] A new study created in memory with name: no-name-b058eae2-ad49-45c9-b068-8ba7565a292e
# [I 2024-01-29 14:07:17,511] Trial 0 finished with value: 0.7385 and parameters: {'depth': 5, 'learning_rate': 0.20413766068364111, 'random_strength': 1, 'bagging_temperature': 0.8688721173711702, 'l2_leaf_reg': 73.96362061230698, 'scale_pos_weight': 2.343275882545317}. Best is trial 0 with value: 0.7385.
# [I 2024-01-29 14:07:19,374] Trial 1 finished with value: 0.6835 and parameters: {'depth': 5, 'learning_rate': 0.13001335885803575, 'random_strength': 5, 'bagging_temperature': 0.7409776587487648, 'l2_leaf_reg': 37.01888649314232, 'scale_pos_weight': 7.483068368513742}. Best is trial 0 with value: 0.7385.
# [I 2024-01-29 14:07:22,739] Trial 2 finished with value: 0.674 and parameters: {'depth': 4, 'learning_rate': 0.03164549811986898, 'random_strength': 6, 'bagging_temperature': 0.6123033077197181, 'l2_leaf_reg': 18.68951795456957, 'scale_pos_weight': 8.359603203929206}. Best is trial 0 with value: 0.7385.
# [I 2024-01-29 14:07:28,769] Trial 3 finished with value: 0.737 and parameters: {'depth': 10, 'learning_rate': 0.2832571355210018, 'random_strength': 2, 'bagging_temperature': 0.6401074103994712, 'l2_leaf_reg': 91.8730058154907, 'scale_pos_weight': 2.7584178519764952}. Best is trial 0 with value: 0.7385.
# [I 2024-01-29 14:07:40,851] Trial 4 finished with value: 0.6715 and parameters: {'depth': 10, 'learning_rate': 0.08709290110470455, 'random_strength': 12, 'bagging_temperature': 0.6984257417268345, 'l2_leaf_reg': 97.33247793556828, 'scale_pos_weight': 8.404435119968532}. Best is trial 0 with value: 0.7385.
# [I 2024-01-29 14:07:43,049] Trial 5 finished with value: 0.6745 and parameters: {'depth': 8, 'learning_rate': 0.21296615728470428, 'random_strength': 17, 'bagging_temperature': 0.5875660008819772, 'l2_leaf_reg': 75.42651085470168, 'scale_pos_weight': 7.979230523847896}. Best is trial 0 with value: 0.7385.
# [I 2024-01-29 14:07:44,643] Trial 6 finished with value: 0.711 and parameters: {'depth': 5, 'learning_rate': 0.15702382933309292, 'random_strength': 4, 'bagging_temperature': 0.4474598813018925, 'l2_leaf_reg': 79.19722262594361, 'scale_pos_weight': 4.551498507895814}. Best is trial 0 with value: 0.7385.
# [I 2024-01-29 14:07:49,163] Trial 7 finished with value: 0.7075 and parameters: {'depth': 8, 'learning_rate': 0.0701327135771609, 'random_strength': 10, 'bagging_temperature': 0.9438494871509405, 'l2_leaf_reg': 87.73508242800978, 'scale_pos_weight': 4.314747709083804}. Best is trial 0 with value: 0.7385.
# [I 2024-01-29 14:07:55,321] Trial 8 finished with value: 0.7325 and parameters: {'depth': 7, 'learning_rate': 0.015649840309083625, 'random_strength': 6, 'bagging_temperature': 0.20947653094345042, 'l2_leaf_reg': 95.60306566376644, 'scale_pos_weight': 2.326151540169678}. Best is trial 0 with value: 0.7385.
# [I 2024-01-29 14:07:57,001] Trial 9 finished with value: 0.688 and parameters: {'depth': 8, 'learning_rate': 0.2233662552474516, 'random_strength': 6, 'bagging_temperature': 0.5974566365310534, 'l2_leaf_reg': 16.437974940361073, 'scale_pos_weight': 7.08631388988596}. Best is trial 0 with value: 0.7385.
# [I 2024-01-29 14:07:57,909] Trial 10 finished with value: 0.697 and parameters: {'depth': 6, 'learning_rate': 0.2854631932012178, 'random_strength': 19, 'bagging_temperature': 0.9609228501508694, 'l2_leaf_reg': 62.22416977356219, 'scale_pos_weight': 0.2044690953254351}. Best is trial 0 with value: 0.7385.
# [I 2024-01-29 14:08:02,633] Trial 11 finished with value: 0.733 and parameters: {'depth': 10, 'learning_rate': 0.29804093573716833, 'random_strength': 1, 'bagging_temperature': 0.8026131258570276, 'l2_leaf_reg': 66.60545204789587, 'scale_pos_weight': 2.530435384410165}. Best is trial 0 with value: 0.7385.
# [I 2024-01-29 14:08:03,586] Trial 12 finished with value: 0.7355 and parameters: {'depth': 4, 'learning_rate': 0.24058322684821878, 'random_strength': 1, 'bagging_temperature': 0.41939616213422176, 'l2_leaf_reg': 54.865043366493396, 'scale_pos_weight': 2.7273297903567264}. Best is trial 0 with value: 0.7385.
# [I 2024-01-29 14:08:06,471] Trial 13 finished with value: 0.781 and parameters: {'depth': 9, 'learning_rate': 0.26047798999391747, 'random_strength': 10, 'bagging_temperature': 0.8075122829359513, 'l2_leaf_reg': 76.85497027428534, 'scale_pos_weight': 0.6554753908593449}. Best is trial 13 with value: 0.781.
# [I 2024-01-29 14:08:09,353] Trial 14 finished with value: 0.7325 and parameters: {'depth': 9, 'learning_rate': 0.1820109279577219, 'random_strength': 11, 'bagging_temperature': 0.849853037001382, 'l2_leaf_reg': 73.10607026693589, 'scale_pos_weight': 0.29770837170915304}. Best is trial 13 with value: 0.781.
# [I 2024-01-29 14:08:10,396] Trial 15 finished with value: 0.7635 and parameters: {'depth': 6, 'learning_rate': 0.24840564807621407, 'random_strength': 14, 'bagging_temperature': 0.9962181093075579, 'l2_leaf_reg': 50.171757614032714, 'scale_pos_weight': 1.525659457871903}. Best is trial 13 with value: 0.781.
# [I 2024-01-29 14:08:11,895] Trial 16 finished with value: 0.7755 and parameters: {'depth': 7, 'learning_rate': 0.2551871580400694, 'random_strength': 15, 'bagging_temperature': 0.9742200404648615, 'l2_leaf_reg': 42.0083757922196, 'scale_pos_weight': 1.1281598043749939}. Best is trial 13 with value: 0.781.
# [I 2024-01-29 14:08:13,280] Trial 17 finished with value: 0.785 and parameters: {'depth': 7, 'learning_rate': 0.2616828943894583, 'random_strength': 15, 'bagging_temperature': 0.7991026597097741, 'l2_leaf_reg': 40.61079215968525, 'scale_pos_weight': 1.0136682722129764}. Best is trial 17 with value: 0.785.
# [I 2024-01-29 14:08:15,254] Trial 18 finished with value: 0.719 and parameters: {'depth': 9, 'learning_rate': 0.26443604725897046, 'random_strength': 9, 'bagging_temperature': 0.7623108368865833, 'l2_leaf_reg': 1.8007530873476298, 'scale_pos_weight': 3.7471656485948808}. Best is trial 17 with value: 0.785.
# [I 2024-01-29 14:08:17,877] Trial 19 finished with value: 0.7035 and parameters: {'depth': 9, 'learning_rate': 0.29785283257348427, 'random_strength': 20, 'bagging_temperature': 0.8362336014623236, 'l2_leaf_reg': 58.373163793944855, 'scale_pos_weight': 5.681941683198687}. Best is trial 17 with value: 0.785.
# [I 2024-01-29 14:08:19,459] Trial 20 finished with value: 0.7765 and parameters: {'depth': 7, 'learning_rate': 0.22803920095915026, 'random_strength': 14, 'bagging_temperature': 0.02419160961921063, 'l2_leaf_reg': 42.43326554149615, 'scale_pos_weight': 1.1823506583382994}. Best is trial 17 with value: 0.785.
# [I 2024-01-29 14:08:21,242] Trial 21 finished with value: 0.7805 and parameters: {'depth': 7, 'learning_rate': 0.2277512301120948, 'random_strength': 13, 'bagging_temperature': 0.0476575548417858, 'l2_leaf_reg': 42.57615732753188, 'scale_pos_weight': 1.149744108060293}. Best is trial 17 with value: 0.785.
# [I 2024-01-29 14:08:22,356] Trial 22 finished with value: 0.776 and parameters: {'depth': 6, 'learning_rate': 0.26485584521533023, 'random_strength': 8, 'bagging_temperature': 0.4888156008079512, 'l2_leaf_reg': 33.08302446541123, 'scale_pos_weight': 0.7287567929861811}. Best is trial 17 with value: 0.785.
# [I 2024-01-29 14:08:24,021] Trial 23 finished with value: 0.6555 and parameters: {'depth': 8, 'learning_rate': 0.20148719844345908, 'random_strength': 12, 'bagging_temperature': 0.36517671772344223, 'l2_leaf_reg': 49.78496119155231, 'scale_pos_weight': 0.14662856979522232}. Best is trial 17 with value: 0.785.
# [I 2024-01-29 14:08:25,455] Trial 24 finished with value: 0.7645 and parameters: {'depth': 7, 'learning_rate': 0.2356452488565954, 'random_strength': 16, 'bagging_temperature': 0.7259935212530136, 'l2_leaf_reg': 67.20545867027889, 'scale_pos_weight': 1.5571180689222222}. Best is trial 17 with value: 0.785.
# [I 2024-01-29 14:08:26,598] Trial 25 finished with value: 0.767 and parameters: {'depth': 6, 'learning_rate': 0.2697317107226552, 'random_strength': 13, 'bagging_temperature': 0.3224221080470418, 'l2_leaf_reg': 82.71955234144573, 'scale_pos_weight': 1.6662727374168478}. Best is trial 17 with value: 0.785.
# [I 2024-01-29 14:08:27,953] Trial 26 finished with value: 0.6525 and parameters: {'depth': 7, 'learning_rate': 0.2551082755347992, 'random_strength': 18, 'bagging_temperature': 0.672728369213611, 'l2_leaf_reg': 50.482507166188306, 'scale_pos_weight': 9.763659769487855}. Best is trial 17 with value: 0.785.
# [I 2024-01-29 14:08:31,301] Trial 27 finished with value: 0.7775 and parameters: {'depth': 9, 'learning_rate': 0.1842185083930128, 'random_strength': 8, 'bagging_temperature': 0.5237796678471691, 'l2_leaf_reg': 86.07774229372131, 'scale_pos_weight': 0.6510758112755186}. Best is trial 17 with value: 0.785.
# [I 2024-01-29 14:08:33,558] Trial 28 finished with value: 0.727 and parameters: {'depth': 8, 'learning_rate': 0.23591957428470228, 'random_strength': 15, 'bagging_temperature': 0.8963192504847313, 'l2_leaf_reg': 63.524920968926615, 'scale_pos_weight': 3.3468390524459832}. Best is trial 17 with value: 0.785.
# [I 2024-01-29 14:08:35,118] Trial 29 finished with value: 0.755 and parameters: {'depth': 6, 'learning_rate': 0.2059547097580039, 'random_strength': 11, 'bagging_temperature': 0.7860570526862175, 'l2_leaf_reg': 71.23816935960554, 'scale_pos_weight': 1.8040252576289508}. Best is trial 17 with value: 0.785.
# [I 2024-01-29 14:08:36,540] Trial 30 finished with value: 0.788 and parameters: {'depth': 7, 'learning_rate': 0.2769992335758905, 'random_strength': 17, 'bagging_temperature': 0.8951852283280097, 'l2_leaf_reg': 58.037186755014915, 'scale_pos_weight': 0.8867992311859872}. Best is trial 30 with value: 0.788.
# [I 2024-01-29 14:08:38,181] Trial 31 finished with value: 0.7835 and parameters: {'depth': 7, 'learning_rate': 0.2781070100220302, 'random_strength': 17, 'bagging_temperature': 0.8869853217982178, 'l2_leaf_reg': 57.554569488845296, 'scale_pos_weight': 1.0570283860888803}. Best is trial 30 with value: 0.788.
# [I 2024-01-29 14:08:39,752] Trial 32 finished with value: 0.744 and parameters: {'depth': 8, 'learning_rate': 0.27261549122775897, 'random_strength': 17, 'bagging_temperature': 0.907002262009024, 'l2_leaf_reg': 58.11567731601668, 'scale_pos_weight': 2.0864696198204924}. Best is trial 30 with value: 0.788.
# [I 2024-01-29 14:08:40,750] Trial 33 finished with value: 0.783 and parameters: {'depth': 5, 'learning_rate': 0.27979206086871905, 'random_strength': 20, 'bagging_temperature': 0.850106872936712, 'l2_leaf_reg': 77.27234673400864, 'scale_pos_weight': 0.7944464887954632}. Best is trial 30 with value: 0.788.
# [I 2024-01-29 14:08:42,080] Trial 34 finished with value: 0.7565 and parameters: {'depth': 5, 'learning_rate': 0.2821050340813354, 'random_strength': 20, 'bagging_temperature': 0.8504723975286423, 'l2_leaf_reg': 64.92921141876968, 'scale_pos_weight': 1.9598290965604674}. Best is trial 30 with value: 0.788.
# [I 2024-01-29 14:08:43,295] Trial 35 finished with value: 0.792 and parameters: {'depth': 4, 'learning_rate': 0.2833305523361925, 'random_strength': 18, 'bagging_temperature': 0.9053196076042899, 'l2_leaf_reg': 69.36025909096914, 'scale_pos_weight': 1.0667577262344632}. Best is trial 35 with value: 0.792.
# [I 2024-01-29 14:08:44,462] Trial 36 finished with value: 0.743 and parameters: {'depth': 4, 'learning_rate': 0.2989249657159836, 'random_strength': 18, 'bagging_temperature': 0.916757324114441, 'l2_leaf_reg': 58.02854285971451, 'scale_pos_weight': 2.6853787621752985}. Best is trial 35 with value: 0.792.
# [I 2024-01-29 14:08:45,859] Trial 37 finished with value: 0.726 and parameters: {'depth': 5, 'learning_rate': 0.24627035814161782, 'random_strength': 17, 'bagging_temperature': 0.7429489957107915, 'l2_leaf_reg': 68.71133250612938, 'scale_pos_weight': 3.2429556030358153}. Best is trial 35 with value: 0.792.
# [I 2024-01-29 14:08:46,817] Trial 38 finished with value: 0.779 and parameters: {'depth': 4, 'learning_rate': 0.2815736246428485, 'random_strength': 18, 'bagging_temperature': 0.894518346252879, 'l2_leaf_reg': 73.406946998097, 'scale_pos_weight': 1.3048136509040766}. Best is trial 35 with value: 0.792.
# [I 2024-01-29 14:08:47,959] Trial 39 finished with value: 0.7455 and parameters: {'depth': 6, 'learning_rate': 0.2589993307577745, 'random_strength': 16, 'bagging_temperature': 0.9987326588292241, 'l2_leaf_reg': 33.39633422388845, 'scale_pos_weight': 2.3000537370340464}. Best is trial 35 with value: 0.792.
# [I 2024-01-29 14:08:49,708] Trial 40 finished with value: 0.75 and parameters: {'depth': 7, 'learning_rate': 0.2472092071144634, 'random_strength': 16, 'bagging_temperature': 0.924680579342965, 'l2_leaf_reg': 61.903341725877105, 'scale_pos_weight': 1.943215581221596}. Best is trial 35 with value: 0.792.
# [I 2024-01-29 14:08:50,574] Trial 41 finished with value: 0.7875 and parameters: {'depth': 5, 'learning_rate': 0.2771673661019219, 'random_strength': 19, 'bagging_temperature': 0.8662890832173928, 'l2_leaf_reg': 77.13979844179079, 'scale_pos_weight': 0.8326543822627805}. Best is trial 35 with value: 0.792.
# [I 2024-01-29 14:08:51,357] Trial 42 finished with value: 0.6115 and parameters: {'depth': 4, 'learning_rate': 0.27419380872085364, 'random_strength': 19, 'bagging_temperature': 0.6803944678141147, 'l2_leaf_reg': 82.72987497492394, 'scale_pos_weight': 0.10138039320819947}. Best is trial 35 with value: 0.792.
# [I 2024-01-29 14:08:52,211] Trial 43 finished with value: 0.778 and parameters: {'depth': 5, 'learning_rate': 0.2867600202432776, 'random_strength': 19, 'bagging_temperature': 0.8087007000580151, 'l2_leaf_reg': 71.75696459818448, 'scale_pos_weight': 1.0433244367761223}. Best is trial 35 with value: 0.792.
# [I 2024-01-29 14:08:53,212] Trial 44 finished with value: 0.786 and parameters: {'depth': 4, 'learning_rate': 0.29488232947095705, 'random_strength': 17, 'bagging_temperature': 0.9435204812799008, 'l2_leaf_reg': 68.6855592094164, 'scale_pos_weight': 0.654129555895134}. Best is trial 35 with value: 0.792.
# [I 2024-01-29 14:08:54,422] Trial 45 finished with value: 0.783 and parameters: {'depth': 4, 'learning_rate': 0.2993302730330358, 'random_strength': 15, 'bagging_temperature': 0.9428452298155003, 'l2_leaf_reg': 69.00453093834832, 'scale_pos_weight': 0.7115763750066849}. Best is trial 35 with value: 0.792.
# [I 2024-01-29 14:08:56,071] Trial 46 finished with value: 0.7735 and parameters: {'depth': 4, 'learning_rate': 0.2887977336842184, 'random_strength': 18, 'bagging_temperature': 0.9559793602906458, 'l2_leaf_reg': 90.21097881641019, 'scale_pos_weight': 1.5023754546795094}. Best is trial 35 with value: 0.792.
# [I 2024-01-29 14:08:57,154] Trial 47 finished with value: 0.7625 and parameters: {'depth': 5, 'learning_rate': 0.26470009572275033, 'random_strength': 19, 'bagging_temperature': 0.775415638477997, 'l2_leaf_reg': 78.220782491968, 'scale_pos_weight': 0.47218152093122356}. Best is trial 35 with value: 0.792.
# [I 2024-01-29 14:08:58,669] Trial 48 finished with value: 0.7485 and parameters: {'depth': 4, 'learning_rate': 0.25252702079693856, 'random_strength': 17, 'bagging_temperature': 0.8702426588075391, 'l2_leaf_reg': 96.95126689879413, 'scale_pos_weight': 2.230919706852858}. Best is trial 35 with value: 0.792.
# [I 2024-01-29 14:08:59,586] Trial 49 finished with value: 0.76 and parameters: {'depth': 4, 'learning_rate': 0.2882858162867182, 'random_strength': 16, 'bagging_temperature': 0.9540694179137881, 'l2_leaf_reg': 74.78656082167035, 'scale_pos_weight': 0.4319539176280257}. Best is trial 35 with value: 0.792.
# [I 2024-01-29 14:09:00,840] Trial 50 finished with value: 0.763 and parameters: {'depth': 5, 'learning_rate': 0.2668419064191725, 'random_strength': 4, 'bagging_temperature': 0.8210602030656164, 'l2_leaf_reg': 80.75033324401934, 'scale_pos_weight': 1.6817937789006487}. Best is trial 35 with value: 0.792.
# [I 2024-01-29 14:09:02,237] Trial 51 finished with value: 0.7785 and parameters: {'depth': 6, 'learning_rate': 0.2754857108830659, 'random_strength': 18, 'bagging_temperature': 0.871651781518187, 'l2_leaf_reg': 63.58228301128117, 'scale_pos_weight': 0.9981843443562931}. Best is trial 35 with value: 0.792.
# [I 2024-01-29 14:09:03,616] Trial 52 finished with value: 0.783 and parameters: {'depth': 7, 'learning_rate': 0.28938447630498737, 'random_strength': 17, 'bagging_temperature': 0.8960545941949701, 'l2_leaf_reg': 69.02781199348969, 'scale_pos_weight': 1.2870643336217151}. Best is trial 35 with value: 0.792.
# [I 2024-01-29 14:09:05,482] Trial 53 finished with value: 0.7615 and parameters: {'depth': 8, 'learning_rate': 0.27550763694135244, 'random_strength': 14, 'bagging_temperature': 0.9940350801028828, 'l2_leaf_reg': 53.705513054114924, 'scale_pos_weight': 0.4195945661303918}. Best is trial 35 with value: 0.792.
# [I 2024-01-29 14:09:06,733] Trial 54 finished with value: 0.7825 and parameters: {'depth': 5, 'learning_rate': 0.24326724166143493, 'random_strength': 15, 'bagging_temperature': 0.9374189169806929, 'l2_leaf_reg': 60.48996181700548, 'scale_pos_weight': 0.8576839390183567}. Best is trial 35 with value: 0.792.
# ...
# [I 2024-01-29 14:14:43,854] Trial 49 finished with value: 0.77 and parameters: {'depth': 7, 'learning_rate': 0.1959201510216274, 'random_strength': 16, 'bagging_temperature': 0.9998331958699647, 'l2_leaf_reg': 86.58264759948153, 'scale_pos_weight': 1.7555697046795276}. Best is trial 23 with value: 0.7855.
# [I 2024-01-29 14:14:45,647] Trial 50 finished with value: 0.7805 and parameters: {'depth': 4, 'learning_rate': 0.2970880994083266, 'random_strength': 19, 'bagging_temperature': 0.9456707713230994, 'l2_leaf_reg': 95.26827103613994, 'scale_pos_weight': 1.2551157075916488}. Best is trial 23 with value: 0.7855.
# [I 2024-01-29 14:14:46,911] Trial 51 finished with value: 0.7805 and parameters: {'depth': 4, 'learning_rate': 0.28103966725296103, 'random_strength': 19, 'bagging_temperature': 0.9149268649310311, 'l2_leaf_reg': 95.51502499575477, 'scale_pos_weight': 1.1756642860728588}. Best is trial 23 with value: 0.7855.
# [I 2024-01-29 14:14:48,068] Trial 52 finished with value: 0.784 and parameters: {'depth': 4, 'learning_rate': 0.27964814429181867, 'random_strength': 20, 'bagging_temperature': 0.904964655026878, 'l2_leaf_reg': 95.65867573772132, 'scale_pos_weight': 1.2704200611370993}. Best is trial 23 with value: 0.7855.
# [I 2024-01-29 14:14:49,326] Trial 53 finished with value: 0.772 and parameters: {'depth': 4, 'learning_rate': 0.2923417113123691, 'random_strength': 20, 'bagging_temperature': 0.8715665010843785, 'l2_leaf_reg': 99.67176827395181, 'scale_pos_weight': 1.5819437138738726}. Best is trial 23 with value: 0.7855.
# [I 2024-01-29 14:14:50,542] Trial 54 finished with value: 0.757 and parameters: {'depth': 4, 'learning_rate': 0.2682572113279241, 'random_strength': 18, 'bagging_temperature': 0.9568638427929136, 'l2_leaf_reg': 92.48734601423978, 'scale_pos_weight': 0.44619433071210224}. Best is trial 23 with value: 0.7855.
# [I 2024-01-29 14:14:51,759] Trial 55 finished with value: 0.759 and parameters: {'depth': 4, 'learning_rate': 0.297199309931955, 'random_strength': 4, 'bagging_temperature': 0.9040186144086002, 'l2_leaf_reg': 88.9824115006685, 'scale_pos_weight': 2.290011119310058}. Best is trial 23 with value: 0.7855.
# [I 2024-01-29 14:14:52,914] Trial 56 finished with value: 0.7835 and parameters: {'depth': 5, 'learning_rate': 0.2858424239706089, 'random_strength': 17, 'bagging_temperature': 0.9553523180191905, 'l2_leaf_reg': 96.5500565617172, 'scale_pos_weight': 1.2623772360163128}. Best is trial 23 with value: 0.7855.
# [I 2024-01-29 14:14:54,216] Trial 57 finished with value: 0.7525 and parameters: {'depth': 5, 'learning_rate': 0.2743249179021923, 'random_strength': 17, 'bagging_temperature': 0.8633450829994685, 'l2_leaf_reg': 91.31156567099104, 'scale_pos_weight': 2.5778997667730943}. Best is trial 23 with value: 0.7855.
# [I 2024-01-29 14:14:55,158] Trial 58 finished with value: 0.768 and parameters: {'depth': 5, 'learning_rate': 0.26255737458742945, 'random_strength': 16, 'bagging_temperature': 0.9778998649915652, 'l2_leaf_reg': 85.57374928619123, 'scale_pos_weight': 1.7075374636787424}. Best is trial 23 with value: 0.7855.
# [I 2024-01-29 14:14:56,171] Trial 59 finished with value: 0.771 and parameters: {'depth': 5, 'learning_rate': 0.28629431127982113, 'random_strength': 14, 'bagging_temperature': 0.7972382051517963, 'l2_leaf_reg': 97.94452109527876, 'scale_pos_weight': 0.5558494333916234}. Best is trial 23 with value: 0.7855.
# [I 2024-01-29 14:14:57,461] Trial 60 finished with value: 0.7845 and parameters: {'depth': 5, 'learning_rate': 0.2621494388984265, 'random_strength': 20, 'bagging_temperature': 0.8468519979177163, 'l2_leaf_reg': 96.8308919936302, 'scale_pos_weight': 1.168750312011031}. Best is trial 23 with value: 0.7855.
# [I 2024-01-29 14:14:58,555] Trial 61 finished with value: 0.7765 and parameters: {'depth': 5, 'learning_rate': 0.25908370452676577, 'random_strength': 20, 'bagging_temperature': 0.852620039715632, 'l2_leaf_reg': 96.81696510953304, 'scale_pos_weight': 1.0460427869598878}. Best is trial 23 with value: 0.7855.
# [I 2024-01-29 14:14:59,988] Trial 62 finished with value: 0.7675 and parameters: {'depth': 5, 'learning_rate': 0.2762358187179408, 'random_strength': 18, 'bagging_temperature': 0.9286029874383279, 'l2_leaf_reg': 94.06490776562762, 'scale_pos_weight': 2.029370198701922}. Best is trial 23 with value: 0.7855.
# [I 2024-01-29 14:15:01,453] Trial 63 finished with value: 0.776 and parameters: {'depth': 5, 'learning_rate': 0.23464429999116543, 'random_strength': 20, 'bagging_temperature': 0.8993610293473228, 'l2_leaf_reg': 86.9286189786908, 'scale_pos_weight': 1.3798931156170877}. Best is trial 23 with value: 0.7855.
# [I 2024-01-29 14:15:04,317] Trial 64 finished with value: 0.775 and parameters: {'depth': 9, 'learning_rate': 0.26721959093143083, 'random_strength': 19, 'bagging_temperature': 0.9662591031407216, 'l2_leaf_reg': 97.35479160631563, 'scale_pos_weight': 0.7668161634558066}. Best is trial 23 with value: 0.7855.
# [I 2024-01-29 14:15:05,686] Trial 65 finished with value: 0.7625 and parameters: {'depth': 6, 'learning_rate': 0.24432182747306047, 'random_strength': 18, 'bagging_temperature': 0.8789997534650799, 'l2_leaf_reg': 91.09055479387081, 'scale_pos_weight': 0.5221640460644229}. Best is trial 23 with value: 0.7855.
# [I 2024-01-29 14:15:06,935] Trial 66 finished with value: 0.646 and parameters: {'depth': 4, 'learning_rate': 0.28642808892506005, 'random_strength': 11, 'bagging_temperature': 0.9360387285162505, 'l2_leaf_reg': 99.57889365776734, 'scale_pos_weight': 0.10331582718063426}. Best is trial 23 with value: 0.7855.
# [I 2024-01-29 14:15:08,101] Trial 67 finished with value: 0.783 and parameters: {'depth': 5, 'learning_rate': 0.2564058645550075, 'random_strength': 20, 'bagging_temperature': 0.8423257465931429, 'l2_leaf_reg': 77.040277089921, 'scale_pos_weight': 1.1743256236769792}. Best is trial 23 with value: 0.7855.
# [I 2024-01-29 14:15:09,686] Trial 68 finished with value: 0.7705 and parameters: {'depth': 6, 'learning_rate': 0.25551860185296943, 'random_strength': 20, 'bagging_temperature': 0.7790463853354868, 'l2_leaf_reg': 78.12196505913856, 'scale_pos_weight': 1.958828611391242}. Best is trial 23 with value: 0.7855.
# [I 2024-01-29 14:15:10,891] Trial 69 finished with value: 0.77 and parameters: {'depth': 5, 'learning_rate': 0.2358645270404629, 'random_strength': 20, 'bagging_temperature': 0.7213078482108765, 'l2_leaf_reg': 83.51817159833524, 'scale_pos_weight': 1.5858196321285618}. Best is trial 23 with value: 0.7855.
# [I 2024-01-29 14:15:12,048] Trial 70 finished with value: 0.774 and parameters: {'depth': 4, 'learning_rate': 0.24905015978285588, 'random_strength': 19, 'bagging_temperature': 0.842405200171496, 'l2_leaf_reg': 90.28036324603681, 'scale_pos_weight': 0.7312936697205665}. Best is trial 23 with value: 0.7855.
# [I 2024-01-29 14:15:13,231] Trial 71 finished with value: 0.7865 and parameters: {'depth': 5, 'learning_rate': 0.2767103015027391, 'random_strength': 19, 'bagging_temperature': 0.8277297913375414, 'l2_leaf_reg': 93.10016871681191, 'scale_pos_weight': 1.1943690838145713}. Best is trial 71 with value: 0.7865.
# [I 2024-01-29 14:15:14,448] Trial 72 finished with value: 0.7765 and parameters: {'depth': 5, 'learning_rate': 0.29937855403416547, 'random_strength': 18, 'bagging_temperature': 0.823989489270347, 'l2_leaf_reg': 93.00610825125484, 'scale_pos_weight': 1.0241778443467235}. Best is trial 71 with value: 0.7865.
# [I 2024-01-29 14:15:15,647] Trial 73 finished with value: 0.775 and parameters: {'depth': 5, 'learning_rate': 0.26103138116225333, 'random_strength': 20, 'bagging_temperature': 0.8615387837396711, 'l2_leaf_reg': 93.84359269163537, 'scale_pos_weight': 1.4406995280808568}. Best is trial 71 with value: 0.7865.
# [I 2024-01-29 14:15:17,195] Trial 74 finished with value: 0.7655 and parameters: {'depth': 5, 'learning_rate': 0.28145666380655915, 'random_strength': 17, 'bagging_temperature': 0.8937035608336469, 'l2_leaf_reg': 87.05000428367174, 'scale_pos_weight': 2.4285676069494913}. Best is trial 71 with value: 0.7865.
# [I 2024-01-29 14:15:18,810] Trial 75 finished with value: 0.7685 and parameters: {'depth': 5, 'learning_rate': 0.2510624504870641, 'random_strength': 19, 'bagging_temperature': 0.9665938387369178, 'l2_leaf_reg': 97.5510542298756, 'scale_pos_weight': 1.9105925080188384}. Best is trial 71 with value: 0.7865.
# [I 2024-01-29 14:15:20,026] Trial 76 finished with value: 0.7555 and parameters: {'depth': 6, 'learning_rate': 0.27659631256874306, 'random_strength': 18, 'bagging_temperature': 0.7427221297991291, 'l2_leaf_reg': 88.7893178074452, 'scale_pos_weight': 0.39556028747650274}. Best is trial 71 with value: 0.7865.
# [I 2024-01-29 14:15:21,374] Trial 77 finished with value: 0.787 and parameters: {'depth': 4, 'learning_rate': 0.29011086405689945, 'random_strength': 20, 'bagging_temperature': 0.7852878479149155, 'l2_leaf_reg': 84.63544850906968, 'scale_pos_weight': 0.8914602828220167}. Best is trial 77 with value: 0.787.
# [I 2024-01-29 14:15:22,463] Trial 78 finished with value: 0.7385 and parameters: {'depth': 4, 'learning_rate': 0.2899006641659567, 'random_strength': 19, 'bagging_temperature': 0.8128534556621813, 'l2_leaf_reg': 81.8833003963836, 'scale_pos_weight': 2.909837890129556}. Best is trial 77 with value: 0.787.
# [I 2024-01-29 14:15:23,542] Trial 79 finished with value: 0.7775 and parameters: {'depth': 4, 'learning_rate': 0.26505574252904635, 'random_strength': 17, 'bagging_temperature': 0.6961136225079876, 'l2_leaf_reg': 85.1166543443235, 'scale_pos_weight': 0.7961442135533474}. Best is trial 77 with value: 0.787.
# [I 2024-01-29 14:15:24,771] Trial 80 finished with value: 0.771 and parameters: {'depth': 4, 'learning_rate': 0.28089676994935875, 'random_strength': 18, 'bagging_temperature': 0.7998964710262395, 'l2_leaf_reg': 83.93159484543612, 'scale_pos_weight': 1.4282892311813913}. Best is trial 77 with value: 0.787.
# [I 2024-01-29 14:15:25,977] Trial 81 finished with value: 0.7815 and parameters: {'depth': 5, 'learning_rate': 0.29111823580478735, 'random_strength': 20, 'bagging_temperature': 0.8982109001933464, 'l2_leaf_reg': 92.37666945639882, 'scale_pos_weight': 1.0618145866661963}. Best is trial 77 with value: 0.787.
# [I 2024-01-29 14:15:27,157] Trial 82 finished with value: 0.7485 and parameters: {'depth': 5, 'learning_rate': 0.2896032351866872, 'random_strength': 20, 'bagging_temperature': 0.8460938319506112, 'l2_leaf_reg': 77.70466734550685, 'scale_pos_weight': 0.362501583939704}. Best is trial 77 with value: 0.787.
# [I 2024-01-29 14:15:28,505] Trial 83 finished with value: 0.779 and parameters: {'depth': 4, 'learning_rate': 0.2714655220187667, 'random_strength': 19, 'bagging_temperature': 0.880645064459659, 'l2_leaf_reg': 94.02883585233033, 'scale_pos_weight': 0.9714334149467141}. Best is trial 77 with value: 0.787.
# [I 2024-01-29 14:15:29,673] Trial 84 finished with value: 0.774 and parameters: {'depth': 5, 'learning_rate': 0.2923213591749243, 'random_strength': 20, 'bagging_temperature': 0.7861274266181639, 'l2_leaf_reg': 96.98174564201634, 'scale_pos_weight': 1.7469245531844293}. Best is trial 77 with value: 0.787.
# [I 2024-01-29 14:15:31,255] Trial 85 finished with value: 0.7825 and parameters: {'depth': 5, 'learning_rate': 0.25705781704843095, 'random_strength': 6, 'bagging_temperature': 0.9106063777484021, 'l2_leaf_reg': 89.07860590228866, 'scale_pos_weight': 1.2768850409516184}. Best is trial 77 with value: 0.787.
# [I 2024-01-29 14:15:32,685] Trial 86 finished with value: 0.7765 and parameters: {'depth': 4, 'learning_rate': 0.25938443279644374, 'random_strength': 7, 'bagging_temperature': 0.8311297504597899, 'l2_leaf_reg': 89.66055801983465, 'scale_pos_weight': 1.2453054578108416}. Best is trial 77 with value: 0.787.
# [I 2024-01-29 14:15:33,953] Trial 87 finished with value: 0.7715 and parameters: {'depth': 5, 'learning_rate': 0.24225481258224463, 'random_strength': 2, 'bagging_temperature': 0.9818320422798885, 'l2_leaf_reg': 87.30074287059259, 'scale_pos_weight': 1.6115754025151685}. Best is trial 77 with value: 0.787.
# [I 2024-01-29 14:15:35,452] Trial 88 finished with value: 0.765 and parameters: {'depth': 4, 'learning_rate': 0.2529585584926059, 'random_strength': 5, 'bagging_temperature': 0.91318169522422, 'l2_leaf_reg': 80.34115369812832, 'scale_pos_weight': 2.1258791673453437}. Best is trial 77 with value: 0.787.
# [I 2024-01-29 14:15:37,268] Trial 89 finished with value: 0.7775 and parameters: {'depth': 8, 'learning_rate': 0.2783988503623217, 'random_strength': 9, 'bagging_temperature': 0.7691997312103293, 'l2_leaf_reg': 82.13773180549063, 'scale_pos_weight': 0.6278894889930663}. Best is trial 77 with value: 0.787.
# [I 2024-01-29 14:15:38,752] Trial 90 finished with value: 0.7715 and parameters: {'depth': 5, 'learning_rate': 0.26580158265941, 'random_strength': 10, 'bagging_temperature': 0.9524978840619087, 'l2_leaf_reg': 85.69269002901585, 'scale_pos_weight': 0.8270297228162614}. Best is trial 77 with value: 0.787.
# [I 2024-01-29 14:15:40,300] Trial 91 finished with value: 0.787 and parameters: {'depth': 5, 'learning_rate': 0.28608316468145084, 'random_strength': 12, 'bagging_temperature': 0.8609935257317346, 'l2_leaf_reg': 92.02466493288868, 'scale_pos_weight': 1.2265090911907912}. Best is trial 77 with value: 0.787.
# [I 2024-01-29 14:15:41,787] Trial 92 finished with value: 0.7805 and parameters: {'depth': 5, 'learning_rate': 0.2713978826637308, 'random_strength': 12, 'bagging_temperature': 0.8571959831437037, 'l2_leaf_reg': 90.63864334165365, 'scale_pos_weight': 1.3577558617793954}. Best is trial 77 with value: 0.787.
# [I 2024-01-29 14:15:42,747] Trial 93 finished with value: 0.7435 and parameters: {'depth': 5, 'learning_rate': 0.28370250455869717, 'random_strength': 7, 'bagging_temperature': 0.8275310649288753, 'l2_leaf_reg': 95.58588721590432, 'scale_pos_weight': 0.3337686723878742}. Best is trial 77 with value: 0.787.
# [I 2024-01-29 14:15:43,849] Trial 94 finished with value: 0.769 and parameters: {'depth': 6, 'learning_rate': 0.2984948610980919, 'random_strength': 5, 'bagging_temperature': 0.918222974478707, 'l2_leaf_reg': 93.42542133115279, 'scale_pos_weight': 1.3068868699195424}. Best is trial 77 with value: 0.787.
# [I 2024-01-29 14:15:45,062] Trial 95 finished with value: 0.762 and parameters: {'depth': 5, 'learning_rate': 0.2753048189200723, 'random_strength': 6, 'bagging_temperature': 0.7980770157055669, 'l2_leaf_reg': 88.28351287524427, 'scale_pos_weight': 1.8193924116867892}. Best is trial 77 with value: 0.787.
# [I 2024-01-29 14:15:46,019] Trial 96 finished with value: 0.7815 and parameters: {'depth': 5, 'learning_rate': 0.2591403549710651, 'random_strength': 13, 'bagging_temperature': 0.8797130088804452, 'l2_leaf_reg': 98.54009372380982, 'scale_pos_weight': 0.9072881195791159}. Best is trial 77 with value: 0.787.
# [I 2024-01-29 14:15:47,173] Trial 97 finished with value: 0.772 and parameters: {'depth': 4, 'learning_rate': 0.28522624639961136, 'random_strength': 15, 'bagging_temperature': 0.9854087163524596, 'l2_leaf_reg': 96.46398706335515, 'scale_pos_weight': 0.5782577371047094}. Best is trial 77 with value: 0.787.
# [I 2024-01-29 14:15:48,646] Trial 98 finished with value: 0.772 and parameters: {'depth': 5, 'learning_rate': 0.2303035250001853, 'random_strength': 12, 'bagging_temperature': 0.9499196257000339, 'l2_leaf_reg': 90.28111359832504, 'scale_pos_weight': 1.5793439004025018}. Best is trial 77 with value: 0.787.
# [I 2024-01-29 14:15:49,943] Trial 99 finished with value: 0.7535 and parameters: {'depth': 6, 'learning_rate': 0.24057763677089117, 'random_strength': 1, 'bagging_temperature': 0.8677941652835405, 'l2_leaf_reg': 85.42929900959788, 'scale_pos_weight': 2.0162315535304627}. Best is trial 77 with value: 0.787.

# %% [markdown]
# - Catboost平均スコア

# %%
# 全フォールドの平均スコアを計算
cb_average_score = sum(cb_fold_scores) / n_splits
print(f"CatBoost Average accuracy across all folds: {cb_average_score}")

cb_average_conf = sum(cb_conf_scores) / n_splits
print(f"CatBoost Average conf-matrix across all folds: {cb_average_conf}")
# Out:
# CatBoost Average accuracy across all folds: 0.777875
# CatBoost Average conf-matrix across all folds: [[799.5  217.  ]
#  [227.25 756.25]]

# %% [markdown]
# - CB_予測平均

# %%
# 予測の平均を計算
cb_y_test_pred_avg = np.mean(cb_test_predictions, axis=0)

# 最終的な予測結果を整数に変換
cb_y_test_pred_int = (cb_y_test_pred_avg > cb_threshold).astype(int)

# %% [markdown]
# - output

# %%
# 現在の日時を取得してフォーマットする
current_time = datetime.now().strftime("%Y%m%d_%H%M%S")
output = f'../data/output/{current_time}_CatBoost_cv{cb_average_score:.4f}.csv'

submit = pd.DataFrame({
    '0': test['gameId'],
    '1': cb_y_test_pred_int
})

# カラムヘッダー消去して出力
# ヘッダーなしでCSVファイルとして保存
submit.to_csv(output, header=False, index=False)

# %%
submit
# Out:
#          0  1
# 0        9  1
# 1       15  1
# 2       18  1
# 3       23  0
# 4       31  1
# ...    ... ..
# 1995  9971  0
# 1996  9980  0
# 1997  9983  1
# 1998  9996  1
# 1999  9999  0
#
# [2000 rows x 2 columns]

# %% [markdown]
# # 合成

# %% [markdown]
# - 予測リストに追加

# %%
# 予測結果をNumPy配列に変換
cb_predictions = np.array(cb_y_test_pred_int)  # CatBoostの予測結果
lgb_predictions = np.array(lgb_y_test_pred_int)  # LightGBMの予測結果
xgb_predictions = np.array(xgb_y_test_pred_int)  # XGBoostの予測結果

# 3つのモデルの予測結果を組み合わせる
combined_predictions = np.vstack((cb_predictions, lgb_predictions, xgb_predictions))

# 多数決で最終的な予測を決定（行方向に合計し、1.5より大きい場合は1とする）
final_predictions = np.mean(combined_predictions, axis=0) > 0.5
final_predictions = final_predictions.astype(int)

# 最終的な予測をCSVファイルに保存
merge_submit = pd.DataFrame({
    '0': test['gameId'],  # 適切なID列を使用
    '1': final_predictions
})
merge_submit.to_csv(f'../data/output/{current_time}_final_predictions.csv', index=False)

# %%
merge_submit
# Out:
#          0  1
# 0        9  1
# 1       15  1
# 2       18  0
# 3       23  0
# 4       31  1
# ...    ... ..
# 1995  9971  0
# 1996  9980  0
# 1997  9983  1
# 1998  9996  1
# 1999  9999  0
#
# [2000 rows x 2 columns]

# %% [markdown]
# #

# %% [markdown]
# # Logistic classifier
