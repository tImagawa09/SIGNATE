# %% [markdown]
# # Library

# %%
import pandas as pd
import numpy as np

import optuna
import xgboost as xgb
import lightgbm as lgb
import catboost as cb

from datetime import datetime
from sklearn.model_selection import train_test_split, KFold
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# # Data Loading

# %%
train = pd.read_csv('../data/train.csv')
test = pd.read_csv('../data/test.csv')

# %% [markdown]
# # Add New Feature

# %%
def add_features(df):
    df['assistRate'] = df['blueAssists'] / (df['blueKills'] + 1)
    df['blueHerald'] = (df['blueEliteMonsters'] - df['blueDragons']).clip(lower=0)
    df['eliteMonsterDragonRatio'] = df['blueEliteMonsters'] / (df['blueDragons'] + 1)
    df['logTotalGold'] = np.log1p(df['blueTotalGold'])
    df['logTotalExperience'] = np.log1p(df['blueTotalExperience'])
    df['firstBloodKillRatio'] = df['blueFirstBlood'] * df['blueKills']
    df['totalCombatPoints'] = df['blueKills'] + df['blueDeaths'] + df['blueAssists']

    total_combat_actions = df['blueKills'] + df['blueDeaths'] + df['blueAssists']
    df['killRatio'] = df['blueKills'] / total_combat_actions
    df['deathRatio'] = df['blueDeaths'] / total_combat_actions
    df['assistRatio'] = df['blueAssists'] / total_combat_actions

    df['teamStrength'] = df['blueKills'] + df['blueAssists'] + df['blueEliteMonsters']
    df['dragonKillImpact'] = df['blueDragons'] / (df['blueKills'] + 1)
    df['eliteMonsterUtilization'] = df['blueEliteMonsters'] / (df['blueKills'] + df['blueAssists'] + 1)
    df['goldExperienceRatio'] = df['blueTotalGold'] / (df['blueTotalExperience'] + 1)
    df['teamEfficiency'] = (df['blueKills'] + df['blueAssists'] + df['blueEliteMonsters']) / (df['blueDeaths'] + 1)
    df['killToMonsterRatio'] = df['blueKills'] / (df['blueEliteMonsters'] + 1)
    df['avgGoldPerKill'] = df['blueTotalGold'] / (df['blueKills'] + 1)
    df['expToKillRatio'] = df['blueTotalExperience'] / (df['blueKills'] + 1)
    df['killsMinusDeaths'] = df['blueKills'] - df['blueDeaths']
    df['killDeathRatio'] = df['blueKills'] / (df['blueKills'] + df['blueDeaths'])
    df['avgExperiencePerKill'] = df['blueTotalExperience'] / (df['blueKills'] + 1)
    df['killDeathDiff'] = (df['blueKills'] - df['blueDeaths']).clip(lower=0)
    df['eliteMonsterHeraldRatio'] = df['blueEliteMonsters'] / (df['blueHerald'] + 1)
    df['goldXexperience'] = np.log1p(df['blueTotalGold'] * df['blueTotalExperience'])
    df['goldPerKill'] = df['blueTotalGold'] / (df['blueKills'] + 1)  # ゼロ除算を防ぐために+1
    df['experiencePerKill'] = df['blueTotalExperience'] / (df['blueKills'] + 1)  # ゼロ除算を防ぐために+1
    df['eliteMonstersPerGold'] = df['blueEliteMonsters'] / df['blueTotalGold']
    df['eliteMonstersPerExperience'] = df['blueEliteMonsters'] / df['blueTotalExperience']

    
    return df

# %% [markdown]
# - apply

# %%
train = add_features(train)
test = add_features(test)

# %% [markdown]
# # Data

# %%
# データの準備
X = train.drop(['blueWins', 'gameId'], axis=1)
y = train['blueWins']
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2, random_state=0)

test_drop_gameId = test.drop('gameId', axis=1)

# test_drop_gameId_temp = test.drop('gameId', axis=1)

# # 特徴量の標準化
# scaler = StandardScaler()
# X_train = scaler.fit_transform(X_train)
# X_val = scaler.transform(X_val)  # 検証データも同じスケーラーを使用して標準化

# # テストデータも同じスケーラーを使用して標準化
# test_drop_gameId_scaled = scaler.transform(test_drop_gameId_temp)

# # NumPy配列からPandasデータフレームに変換
# X_train = pd.DataFrame(X_train, columns=X.columns)
# X_val = pd.DataFrame(X_val, columns=X.columns)
# test_drop_gameId = pd.DataFrame(test_drop_gameId_scaled, columns=test_drop_gameId_temp.columns)

# %% [markdown]
# # Model

# %% [markdown]
# - variable

# %%
n_splits = 5
kf = KFold(n_splits=n_splits, shuffle=True)

# 各フォールドでのスコアを保存するリスト
lgb_fold_scores = []
xgb_fold_scores = []
cb_fold_scores = []

# testを保存するリスト
lgb_test_predictions = []
xgb_test_predictions = []
cb_test_predictions = []

# %% [markdown]
# ## LightGBM

# %%
for train_index, val_index in kf.split(X):
    X_train_fold, X_val_fold = X.iloc[train_index], X.iloc[val_index]
    y_train_fold, y_val_fold = y[train_index], y[val_index]

    # LightGBMではDMatrixの代わりに普通のデータフレームを使用します
    train_data = lgb.Dataset(X_train_fold, label=y_train_fold)
    val_data = lgb.Dataset(X_val_fold, label=y_val_fold, reference=train_data)

    # Optunaでのハイパーパラメータチューニング
    def objective(trial):
        param = {
            'objective': 'binary',
            'metric': 'binary_logloss',
            'verbosity': -1,
            'boosting_type': 'gbdt',
            'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
            'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
            'num_leaves': trial.suggest_int('num_leaves', 2, 256),
            'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
            'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
            'bagging_freq': trial.suggest_int('bagging_freq', 1, 7),
            'min_child_samples': trial.suggest_int('min_child_samples', 5, 100),
            'feature_pre_filter': False,  # 特徴量の事前フィルタリングを無効化
            'min_data_in_leaf': trial.suggest_int('min_data_in_leaf', 20, 100),  # Optunaでこの値を調整する
        }

        callbacks = lgb.early_stopping(stopping_rounds=50, verbose=False)
        gbm = lgb.train(param, train_data, valid_sets=[val_data], num_boost_round=1000, callbacks=[callbacks])
        preds = gbm.predict(X_val_fold, num_iteration=gbm.best_iteration)
        pred_labels = np.rint(preds)
        accuracy = accuracy_score(y_val_fold, pred_labels)
        return accuracy

    lgb_study = optuna.create_study(direction='maximize')
    lgb_study.optimize(objective, n_trials=100)

    # 各フォールドの最適パラメータでモデルを再学習
    lgb_best_params = lgb_study.best_params
    lgb_best_params['objective'] = 'binary'
    lgb_best_params['metric'] = 'binary_logloss'
    lgb_best_params['verbosity'] = -1

    lgb_final = lgb.train(lgb_best_params, train_data, num_boost_round=lgb_study.best_trial.number)

    # 各フォールドのモデル性能を評価
    lgb_y_val_pred = lgb_final.predict(X_val_fold, num_iteration=lgb_final.best_iteration)
    lgb_y_val_pred_int = np.rint(lgb_y_val_pred)
    lgb_fold_accuracy = accuracy_score(y_val_fold, lgb_y_val_pred_int)
    lgb_fold_scores.append(lgb_fold_accuracy)

    # テストデータセットでの予測
    lgb_y_test_pred_fold = lgb_final.predict(test_drop_gameId, num_iteration=lgb_final.best_iteration)
    lgb_test_predictions.append(lgb_y_test_pred_fold)
# Out:
# [I 2024-01-28 13:23:32,178] A new study created in memory with name: no-name-c16c8857-8c1a-460e-9460-36257569d4ac
# /tmp/ipykernel_17145/1351893647.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_17145/1351893647.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# /tmp/ipykernel_17145/1351893647.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# /tmp/ipykernel_17145/1351893647.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-28 13:23:32,577] Trial 0 finished with value: 0.7775 and parameters: {'lambda_l1': 0.14446063397028677, 'lambda_l2': 1.9540539107885817e-06, 'num_leaves': 206, 'feature_fraction': 0.823551803705272, 'bagging_fraction': 0.5578735099477603, 'bagging_freq': 3, 'min_child_samples': 52, 'min_data_in_leaf': 79}. Best is trial 0 with value: 0.7775.
# /tmp/ipykernel_17145/1351893647.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_17145/1351893647.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# /tmp/ipykernel_17145/1351893647.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# /tmp/ipykernel_17145/1351893647.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-28 13:23:32,814] Trial 1 finished with value: 0.78625 and parameters: {'lambda_l1': 0.00017544127445742112, 'lambda_l2': 4.4644128205313513e-07, 'num_leaves': 131, 'feature_fraction': 0.9221164465022469, 'bagging_fraction': 0.7148740147734485, 'bagging_freq': 6, 'min_child_samples': 8, 'min_data_in_leaf': 83}. Best is trial 1 with value: 0.78625.
# /tmp/ipykernel_17145/1351893647.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_17145/1351893647.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# /tmp/ipykernel_17145/1351893647.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# /tmp/ipykernel_17145/1351893647.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-28 13:23:32,905] Trial 2 finished with value: 0.790625 and parameters: {'lambda_l1': 1.4296109740868696e-06, 'lambda_l2': 0.0006205086984394856, 'num_leaves': 14, 'feature_fraction': 0.6931643536085186, 'bagging_fraction': 0.8649928765765316, 'bagging_freq': 2, 'min_child_samples': 84, 'min_data_in_leaf': 26}. Best is trial 2 with value: 0.790625.
# /tmp/ipykernel_17145/1351893647.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_17145/1351893647.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# /tmp/ipykernel_17145/1351893647.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# /tmp/ipykernel_17145/1351893647.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-28 13:23:33,061] Trial 3 finished with value: 0.785625 and parameters: {'lambda_l1': 0.0017216967712504572, 'lambda_l2': 0.8307601003781361, 'num_leaves': 178, 'feature_fraction': 0.900355316590105, 'bagging_fraction': 0.5420904671962998, 'bagging_freq': 3, 'min_child_samples': 98, 'min_data_in_leaf': 58}. Best is trial 2 with value: 0.790625.
# /tmp/ipykernel_17145/1351893647.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_17145/1351893647.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# /tmp/ipykernel_17145/1351893647.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# /tmp/ipykernel_17145/1351893647.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-28 13:23:33,297] Trial 4 finished with value: 0.793125 and parameters: {'lambda_l1': 1.0176631613360592, 'lambda_l2': 0.014120706751050743, 'num_leaves': 241, 'feature_fraction': 0.6208489619578307, 'bagging_fraction': 0.9624505487260466, 'bagging_freq': 7, 'min_child_samples': 12, 'min_data_in_leaf': 42}. Best is trial 4 with value: 0.793125.
# /tmp/ipykernel_17145/1351893647.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_17145/1351893647.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# /tmp/ipykernel_17145/1351893647.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# /tmp/ipykernel_17145/1351893647.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-28 13:23:33,547] Trial 5 finished with value: 0.79125 and parameters: {'lambda_l1': 0.000817360651616173, 'lambda_l2': 2.519116399006806e-07, 'num_leaves': 93, 'feature_fraction': 0.8821432989143363, 'bagging_fraction': 0.8384215927074334, 'bagging_freq': 1, 'min_child_samples': 25, 'min_data_in_leaf': 35}. Best is trial 4 with value: 0.793125.
# /tmp/ipykernel_17145/1351893647.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_17145/1351893647.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# /tmp/ipykernel_17145/1351893647.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# /tmp/ipykernel_17145/1351893647.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-28 13:23:33,806] Trial 6 finished with value: 0.7925 and parameters: {'lambda_l1': 4.239479804204568e-06, 'lambda_l2': 0.0018378627674308116, 'num_leaves': 154, 'feature_fraction': 0.40822236134735534, 'bagging_fraction': 0.6852528124775791, 'bagging_freq': 1, 'min_child_samples': 77, 'min_data_in_leaf': 29}. Best is trial 4 with value: 0.793125.
# /tmp/ipykernel_17145/1351893647.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_17145/1351893647.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# /tmp/ipykernel_17145/1351893647.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# /tmp/ipykernel_17145/1351893647.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-28 13:23:33,968] Trial 7 finished with value: 0.785625 and parameters: {'lambda_l1': 1.6773361585690627, 'lambda_l2': 8.394686393351607e-07, 'num_leaves': 213, 'feature_fraction': 0.9584612119120415, 'bagging_fraction': 0.5589163448178983, 'bagging_freq': 3, 'min_child_samples': 29, 'min_data_in_leaf': 60}. Best is trial 4 with value: 0.793125.
# /tmp/ipykernel_17145/1351893647.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_17145/1351893647.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# /tmp/ipykernel_17145/1351893647.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# /tmp/ipykernel_17145/1351893647.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-28 13:23:34,112] Trial 8 finished with value: 0.7925 and parameters: {'lambda_l1': 0.12339036868982531, 'lambda_l2': 4.5082567740228466e-05, 'num_leaves': 37, 'feature_fraction': 0.5200829604552087, 'bagging_fraction': 0.737547838496776, 'bagging_freq': 4, 'min_child_samples': 70, 'min_data_in_leaf': 100}. Best is trial 4 with value: 0.793125.
# /tmp/ipykernel_17145/1351893647.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_17145/1351893647.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# /tmp/ipykernel_17145/1351893647.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# /tmp/ipykernel_17145/1351893647.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-28 13:23:34,409] Trial 9 finished with value: 0.79 and parameters: {'lambda_l1': 7.649204519567764e-07, 'lambda_l2': 0.6006299596941787, 'num_leaves': 118, 'feature_fraction': 0.8132857730121373, 'bagging_fraction': 0.8527491822366535, 'bagging_freq': 6, 'min_child_samples': 29, 'min_data_in_leaf': 35}. Best is trial 4 with value: 0.793125.
# /tmp/ipykernel_17145/1351893647.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_17145/1351893647.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# /tmp/ipykernel_17145/1351893647.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# /tmp/ipykernel_17145/1351893647.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-28 13:23:34,669] Trial 10 finished with value: 0.793125 and parameters: {'lambda_l1': 1.0662050498995746e-08, 'lambda_l2': 0.017189729134169086, 'num_leaves': 248, 'feature_fraction': 0.6502127649545796, 'bagging_fraction': 0.957168003333279, 'bagging_freq': 7, 'min_child_samples': 51, 'min_data_in_leaf': 48}. Best is trial 4 with value: 0.793125.
# /tmp/ipykernel_17145/1351893647.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_17145/1351893647.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# /tmp/ipykernel_17145/1351893647.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# /tmp/ipykernel_17145/1351893647.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-28 13:23:34,935] Trial 11 finished with value: 0.791875 and parameters: {'lambda_l1': 4.4174903295711235e-08, 'lambda_l2': 0.030276317652161728, 'num_leaves': 249, 'feature_fraction': 0.6727816605904041, 'bagging_fraction': 0.9990193407994143, 'bagging_freq': 7, 'min_child_samples': 54, 'min_data_in_leaf': 47}. Best is trial 4 with value: 0.793125.
# /tmp/ipykernel_17145/1351893647.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_17145/1351893647.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# /tmp/ipykernel_17145/1351893647.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# /tmp/ipykernel_17145/1351893647.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-28 13:23:35,125] Trial 12 finished with value: 0.79 and parameters: {'lambda_l1': 7.107757021026564, 'lambda_l2': 0.02316888940421511, 'num_leaves': 254, 'feature_fraction': 0.595803208990608, 'bagging_fraction': 0.991714412299207, 'bagging_freq': 7, 'min_child_samples': 9, 'min_data_in_leaf': 46}. Best is trial 4 with value: 0.793125.
# /tmp/ipykernel_17145/1351893647.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_17145/1351893647.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# /tmp/ipykernel_17145/1351893647.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# /tmp/ipykernel_17145/1351893647.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-28 13:23:35,346] Trial 13 finished with value: 0.794375 and parameters: {'lambda_l1': 1.6144926197988002e-08, 'lambda_l2': 6.173291342747157, 'num_leaves': 215, 'feature_fraction': 0.5654979497320155, 'bagging_fraction': 0.9210012647528422, 'bagging_freq': 5, 'min_child_samples': 44, 'min_data_in_leaf': 47}. Best is trial 13 with value: 0.794375.
# /tmp/ipykernel_17145/1351893647.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_17145/1351893647.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# /tmp/ipykernel_17145/1351893647.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# /tmp/ipykernel_17145/1351893647.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-28 13:23:35,465] Trial 14 finished with value: 0.79875 and parameters: {'lambda_l1': 0.04486700786657141, 'lambda_l2': 8.906177387206693, 'num_leaves': 206, 'feature_fraction': 0.5273716206266088, 'bagging_fraction': 0.413702927531467, 'bagging_freq': 5, 'min_child_samples': 41, 'min_data_in_leaf': 70}. Best is trial 14 with value: 0.79875.
# /tmp/ipykernel_17145/1351893647.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_17145/1351893647.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# /tmp/ipykernel_17145/1351893647.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# /tmp/ipykernel_17145/1351893647.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-28 13:23:35,679] Trial 15 finished with value: 0.795 and parameters: {'lambda_l1': 0.013206268987444989, 'lambda_l2': 7.480050537339456, 'num_leaves': 192, 'feature_fraction': 0.5053442364285893, 'bagging_fraction': 0.4361041461891729, 'bagging_freq': 5, 'min_child_samples': 41, 'min_data_in_leaf': 73}. Best is trial 14 with value: 0.79875.
# /tmp/ipykernel_17145/1351893647.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_17145/1351893647.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# /tmp/ipykernel_17145/1351893647.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# /tmp/ipykernel_17145/1351893647.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-28 13:23:35,803] Trial 16 finished with value: 0.7925 and parameters: {'lambda_l1': 0.012567389433504151, 'lambda_l2': 8.509611645447631, 'num_leaves': 172, 'feature_fraction': 0.4567089421329429, 'bagging_fraction': 0.409552495750307, 'bagging_freq': 5, 'min_child_samples': 39, 'min_data_in_leaf': 75}. Best is trial 14 with value: 0.79875.
# /tmp/ipykernel_17145/1351893647.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_17145/1351893647.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# /tmp/ipykernel_17145/1351893647.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# /tmp/ipykernel_17145/1351893647.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-28 13:23:35,931] Trial 17 finished with value: 0.796875 and parameters: {'lambda_l1': 3.79919377718693e-05, 'lambda_l2': 0.3468289902523386, 'num_leaves': 190, 'feature_fraction': 0.49973486564101754, 'bagging_fraction': 0.41692754705191765, 'bagging_freq': 5, 'min_child_samples': 66, 'min_data_in_leaf': 71}. Best is trial 14 with value: 0.79875.
# /tmp/ipykernel_17145/1351893647.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_17145/1351893647.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# /tmp/ipykernel_17145/1351893647.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# /tmp/ipykernel_17145/1351893647.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-28 13:23:36,059] Trial 18 finished with value: 0.785625 and parameters: {'lambda_l1': 4.255119584780417e-05, 'lambda_l2': 0.3303673555955646, 'num_leaves': 72, 'feature_fraction': 0.4061156339792479, 'bagging_fraction': 0.4850757136759448, 'bagging_freq': 4, 'min_child_samples': 66, 'min_data_in_leaf': 89}. Best is trial 14 with value: 0.79875.
# /tmp/ipykernel_17145/1351893647.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_17145/1351893647.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# /tmp/ipykernel_17145/1351893647.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# /tmp/ipykernel_17145/1351893647.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-28 13:23:36,255] Trial 19 finished with value: 0.7875 and parameters: {'lambda_l1': 2.187915993591365e-05, 'lambda_l2': 1.4290226399296932e-08, 'num_leaves': 151, 'feature_fraction': 0.7582694041412423, 'bagging_fraction': 0.6236140028779353, 'bagging_freq': 6, 'min_child_samples': 67, 'min_data_in_leaf': 65}. Best is trial 14 with value: 0.79875.
# /tmp/ipykernel_17145/1351893647.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_17145/1351893647.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# /tmp/ipykernel_17145/1351893647.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# /tmp/ipykernel_17145/1351893647.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-28 13:23:36,395] Trial 20 finished with value: 0.7925 and parameters: {'lambda_l1': 0.006061836130202573, 'lambda_l2': 3.7615690807959947e-05, 'num_leaves': 157, 'feature_fraction': 0.5448586106330171, 'bagging_fraction': 0.47493644428336124, 'bagging_freq': 5, 'min_child_samples': 93, 'min_data_in_leaf': 92}. Best is trial 14 with value: 0.79875.
# /tmp/ipykernel_17145/1351893647.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_17145/1351893647.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# /tmp/ipykernel_17145/1351893647.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# /tmp/ipykernel_17145/1351893647.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-28 13:23:36,573] Trial 21 finished with value: 0.790625 and parameters: {'lambda_l1': 0.03430485819551655, 'lambda_l2': 1.6291078271829564, 'num_leaves': 193, 'feature_fraction': 0.503930450272667, 'bagging_fraction': 0.40829707186529585, 'bagging_freq': 5, 'min_child_samples': 40, 'min_data_in_leaf': 70}. Best is trial 14 with value: 0.79875.
# /tmp/ipykernel_17145/1351893647.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_17145/1351893647.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# /tmp/ipykernel_17145/1351893647.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# /tmp/ipykernel_17145/1351893647.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-28 13:23:36,729] Trial 22 finished with value: 0.79375 and parameters: {'lambda_l1': 0.00013791096805544753, 'lambda_l2': 0.10562823809502905, 'num_leaves': 222, 'feature_fraction': 0.47770230885491294, 'bagging_fraction': 0.4655646255165576, 'bagging_freq': 4, 'min_child_samples': 61, 'min_data_in_leaf': 70}. Best is trial 14 with value: 0.79875.
# /tmp/ipykernel_17145/1351893647.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_17145/1351893647.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# /tmp/ipykernel_17145/1351893647.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# /tmp/ipykernel_17145/1351893647.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-28 13:23:36,896] Trial 23 finished with value: 0.79375 and parameters: {'lambda_l1': 0.0022966157597398844, 'lambda_l2': 0.15423207311365525, 'num_leaves': 188, 'feature_fraction': 0.46175352307761897, 'bagging_fraction': 0.438460662028194, 'bagging_freq': 6, 'min_child_samples': 36, 'min_data_in_leaf': 58}. Best is trial 14 with value: 0.79875.
# /tmp/ipykernel_17145/1351893647.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_17145/1351893647.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# /tmp/ipykernel_17145/1351893647.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# /tmp/ipykernel_17145/1351893647.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-28 13:23:37,027] Trial 24 finished with value: 0.79125 and parameters: {'lambda_l1': 0.05379306270856042, 'lambda_l2': 2.8657084336317813, 'num_leaves': 227, 'feature_fraction': 0.5894230880167959, 'bagging_fraction': 0.5216197455266773, 'bagging_freq': 4, 'min_child_samples': 20, 'min_data_in_leaf': 84}. Best is trial 14 with value: 0.79875.
# /tmp/ipykernel_17145/1351893647.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_17145/1351893647.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# /tmp/ipykernel_17145/1351893647.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# /tmp/ipykernel_17145/1351893647.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-28 13:23:37,197] Trial 25 finished with value: 0.789375 and parameters: {'lambda_l1': 0.6428846349819255, 'lambda_l2': 0.0029211570617708174, 'num_leaves': 129, 'feature_fraction': 0.53896164926698, 'bagging_fraction': 0.6238460983617659, 'bagging_freq': 5, 'min_child_samples': 46, 'min_data_in_leaf': 71}. Best is trial 14 with value: 0.79875.
# /tmp/ipykernel_17145/1351893647.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_17145/1351893647.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# /tmp/ipykernel_17145/1351893647.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# /tmp/ipykernel_17145/1351893647.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-28 13:23:37,333] Trial 26 finished with value: 0.790625 and parameters: {'lambda_l1': 0.012725201466249999, 'lambda_l2': 9.640483471918495, 'num_leaves': 198, 'feature_fraction': 0.44850969428998366, 'bagging_fraction': 0.4001555071924165, 'bagging_freq': 6, 'min_child_samples': 59, 'min_data_in_leaf': 63}. Best is trial 14 with value: 0.79875.
# /tmp/ipykernel_17145/1351893647.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_17145/1351893647.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# /tmp/ipykernel_17145/1351893647.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# /tmp/ipykernel_17145/1351893647.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-28 13:23:37,482] Trial 27 finished with value: 0.788125 and parameters: {'lambda_l1': 0.00035529770838302745, 'lambda_l2': 1.203969576304114, 'num_leaves': 171, 'feature_fraction': 0.7419011824247332, 'bagging_fraction': 0.5007650185647896, 'bagging_freq': 4, 'min_child_samples': 79, 'min_data_in_leaf': 76}. Best is trial 14 with value: 0.79875.
# /tmp/ipykernel_17145/1351893647.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_17145/1351893647.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# /tmp/ipykernel_17145/1351893647.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# /tmp/ipykernel_17145/1351893647.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-28 13:23:37,662] Trial 28 finished with value: 0.78875 and parameters: {'lambda_l1': 1.7990602240101057e-07, 'lambda_l2': 0.08640056186723254, 'num_leaves': 233, 'feature_fraction': 0.6301853922254658, 'bagging_fraction': 0.6057805407146384, 'bagging_freq': 5, 'min_child_samples': 34, 'min_data_in_leaf': 54}. Best is trial 14 with value: 0.79875.
# /tmp/ipykernel_17145/1351893647.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_17145/1351893647.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# /tmp/ipykernel_17145/1351893647.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# /tmp/ipykernel_17145/1351893647.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-28 13:23:37,820] Trial 29 finished with value: 0.794375 and parameters: {'lambda_l1': 1.3725596251249246e-05, 'lambda_l2': 5.0763780335898385e-05, 'num_leaves': 206, 'feature_fraction': 0.49273368118165906, 'bagging_fraction': 0.44442166590437254, 'bagging_freq': 3, 'min_child_samples': 50, 'min_data_in_leaf': 80}. Best is trial 14 with value: 0.79875.
# /tmp/ipykernel_17145/1351893647.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# ...
# /tmp/ipykernel_17145/1351893647.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_17145/1351893647.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# /tmp/ipykernel_17145/1351893647.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# /tmp/ipykernel_17145/1351893647.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-28 13:25:10,639] Trial 90 finished with value: 0.779375 and parameters: {'lambda_l1': 0.00035248671621336666, 'lambda_l2': 5.507146652298375e-07, 'num_leaves': 223, 'feature_fraction': 0.4797635901111489, 'bagging_fraction': 0.9346383045442428, 'bagging_freq': 1, 'min_child_samples': 77, 'min_data_in_leaf': 58}. Best is trial 80 with value: 0.78875.
# /tmp/ipykernel_17145/1351893647.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_17145/1351893647.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# /tmp/ipykernel_17145/1351893647.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# /tmp/ipykernel_17145/1351893647.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-28 13:25:10,877] Trial 91 finished with value: 0.783125 and parameters: {'lambda_l1': 0.00011459636472071337, 'lambda_l2': 9.396498577088184e-05, 'num_leaves': 189, 'feature_fraction': 0.41552907630019176, 'bagging_fraction': 0.986059663129422, 'bagging_freq': 2, 'min_child_samples': 65, 'min_data_in_leaf': 53}. Best is trial 80 with value: 0.78875.
# /tmp/ipykernel_17145/1351893647.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_17145/1351893647.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# /tmp/ipykernel_17145/1351893647.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# /tmp/ipykernel_17145/1351893647.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-28 13:25:11,124] Trial 92 finished with value: 0.781875 and parameters: {'lambda_l1': 5.164176396450544e-05, 'lambda_l2': 0.0007595638346681277, 'num_leaves': 199, 'feature_fraction': 0.4476335689035508, 'bagging_fraction': 0.9748903972787603, 'bagging_freq': 2, 'min_child_samples': 66, 'min_data_in_leaf': 51}. Best is trial 80 with value: 0.78875.
# /tmp/ipykernel_17145/1351893647.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_17145/1351893647.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# /tmp/ipykernel_17145/1351893647.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# /tmp/ipykernel_17145/1351893647.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-28 13:25:11,388] Trial 93 finished with value: 0.781875 and parameters: {'lambda_l1': 0.0008827964654387323, 'lambda_l2': 0.00015044830999024573, 'num_leaves': 185, 'feature_fraction': 0.4028980864938698, 'bagging_fraction': 0.9549147719971167, 'bagging_freq': 2, 'min_child_samples': 57, 'min_data_in_leaf': 63}. Best is trial 80 with value: 0.78875.
# /tmp/ipykernel_17145/1351893647.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_17145/1351893647.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# /tmp/ipykernel_17145/1351893647.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# /tmp/ipykernel_17145/1351893647.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-28 13:25:11,669] Trial 94 finished with value: 0.78125 and parameters: {'lambda_l1': 8.87221945540652e-05, 'lambda_l2': 5.137422052462955e-05, 'num_leaves': 214, 'feature_fraction': 0.46870157726986383, 'bagging_fraction': 0.9953583724871238, 'bagging_freq': 2, 'min_child_samples': 61, 'min_data_in_leaf': 55}. Best is trial 80 with value: 0.78875.
# /tmp/ipykernel_17145/1351893647.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_17145/1351893647.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# /tmp/ipykernel_17145/1351893647.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# /tmp/ipykernel_17145/1351893647.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-28 13:25:11,882] Trial 95 finished with value: 0.785 and parameters: {'lambda_l1': 0.000407260931673569, 'lambda_l2': 2.641502120337818e-05, 'num_leaves': 194, 'feature_fraction': 0.43677161391285546, 'bagging_fraction': 0.9699745979884431, 'bagging_freq': 1, 'min_child_samples': 52, 'min_data_in_leaf': 57}. Best is trial 80 with value: 0.78875.
# /tmp/ipykernel_17145/1351893647.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_17145/1351893647.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# /tmp/ipykernel_17145/1351893647.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# /tmp/ipykernel_17145/1351893647.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-28 13:25:12,132] Trial 96 finished with value: 0.7775 and parameters: {'lambda_l1': 0.0002107743895670436, 'lambda_l2': 8.028871515569275e-05, 'num_leaves': 206, 'feature_fraction': 0.5124379910974083, 'bagging_fraction': 0.9825545714634203, 'bagging_freq': 3, 'min_child_samples': 69, 'min_data_in_leaf': 52}. Best is trial 80 with value: 0.78875.
# /tmp/ipykernel_17145/1351893647.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_17145/1351893647.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# /tmp/ipykernel_17145/1351893647.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# /tmp/ipykernel_17145/1351893647.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-28 13:25:12,324] Trial 97 finished with value: 0.7875 and parameters: {'lambda_l1': 0.0013810804749337248, 'lambda_l2': 1.4936621386287603e-05, 'num_leaves': 248, 'feature_fraction': 0.41923526199925776, 'bagging_fraction': 0.8961263782909202, 'bagging_freq': 2, 'min_child_samples': 73, 'min_data_in_leaf': 85}. Best is trial 80 with value: 0.78875.
# /tmp/ipykernel_17145/1351893647.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_17145/1351893647.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# /tmp/ipykernel_17145/1351893647.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# /tmp/ipykernel_17145/1351893647.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-28 13:25:12,526] Trial 98 finished with value: 0.78 and parameters: {'lambda_l1': 0.0024936691748135716, 'lambda_l2': 1.2971576596103535e-05, 'num_leaves': 249, 'feature_fraction': 0.44767484432148863, 'bagging_fraction': 0.9220815758358185, 'bagging_freq': 2, 'min_child_samples': 72, 'min_data_in_leaf': 87}. Best is trial 80 with value: 0.78875.
# /tmp/ipykernel_17145/1351893647.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_17145/1351893647.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# /tmp/ipykernel_17145/1351893647.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# /tmp/ipykernel_17145/1351893647.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# [I 2024-01-28 13:25:12,756] Trial 99 finished with value: 0.77875 and parameters: {'lambda_l1': 0.004965349125678511, 'lambda_l2': 8.241091536551308e-06, 'num_leaves': 246, 'feature_fraction': 0.48563355769119126, 'bagging_fraction': 0.898471505380645, 'bagging_freq': 1, 'min_child_samples': 86, 'min_data_in_leaf': 61}. Best is trial 80 with value: 0.78875.

# %% [markdown]
# - lgb_平均スコア

# %%
# 全フォールドの平均スコアを計算
lgb_average_score = sum(lgb_fold_scores) / n_splits
print(f"LightGBM Average accuracy across all folds: {lgb_average_score}")
# Out:
# LightGBM Average accuracy across all folds: 0.7825

# %% [markdown]
# - lgb_予測平均

# %%
# 予測の平均を計算
lgb_y_test_pred_avg = np.mean(lgb_test_predictions, axis=0)

# 最終的な予測結果を整数に変換
lgb_y_test_pred_int = (lgb_y_test_pred_avg > 0.5).astype(int)

# %% [markdown]
# - output

# %%
# 現在の日時を取得してフォーマットする
current_time = datetime.now().strftime("%Y%m%d_%H%M%S")
output = f'../data/output/{current_time}_LightGBM_cv{lgb_average_score:.4f}.csv'

submit = pd.DataFrame({
    '0': test['gameId'],
    '1': lgb_y_test_pred_int
})

# カラムヘッダー消去して出力
# ヘッダーなしでCSVファイルとして保存
submit.to_csv(output, header=False, index=False)

# %%
submit
# Out:
#          0  1
# 0        9  1
# 1       15  1
# 2       18  1
# 3       23  0
# 4       31  1
# ...    ... ..
# 1995  9971  0
# 1996  9980  0
# 1997  9983  1
# 1998  9996  1
# 1999  9999  0
#
# [2000 rows x 2 columns]

# %% [markdown]
# ## XGBoost

# %%
for train_index, val_index in kf.split(X):
    X_train_fold, X_val_fold = X.iloc[train_index], X.iloc[val_index]
    y_train_fold, y_val_fold = y[train_index], y[val_index]

    dtrain = xgb.DMatrix(X_train_fold, label=y_train_fold)
    dval = xgb.DMatrix(X_val_fold, label=y_val_fold)
    dtest = xgb.DMatrix(test_drop_gameId)

    # Optunaでのハイパーパラメータチューニング
    def objective(trial):
        param = {
            'verbosity': 0,
            'objective': 'binary:logistic',
            'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
            'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
            'max_depth': trial.suggest_int('max_depth', 3, 9),
            'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
            'subsample': trial.suggest_float('subsample', 0.5, 1),
            'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1)
        }

        bst = xgb.train(param, dtrain, num_boost_round=1000, evals=[(dval, "eval")], early_stopping_rounds=50, verbose_eval=False)
        preds = bst.predict(dval)
        pred_labels = np.rint(preds)
        accuracy = accuracy_score(y_val_fold, pred_labels)
        return accuracy

    xgb_study = optuna.create_study(direction='maximize')
    xgb_study.optimize(objective, n_trials=100)

    # 各フォールドの最適パラメータでモデルを再学習
    xgb_best_params = xgb_study.best_params
    xgb_best_params['objective'] = 'binary:logistic'
    xgb_best_params['verbosity'] = 0

    xgb_final_bst = xgb.train(xgb_best_params, dtrain, num_boost_round=xgb_study.best_trial.number)

    # 各フォールドのモデル性能を評価
    xgb_y_val_pred = xgb_final_bst.predict(dval)
    xgb_y_val_pred_int = np.rint(xgb_y_val_pred)
    fold_accuracy = accuracy_score(y_val_fold, xgb_y_val_pred_int)
    xgb_fold_scores.append(fold_accuracy)

    # テストデータセットでの予測
    xgb_y_test_pred_fold = xgb_final_bst.predict(dtest)
    xgb_test_predictions.append(xgb_y_test_pred_fold)
# Out:
# [I 2024-01-28 13:25:13,061] A new study created in memory with name: no-name-7d55ae16-403b-4236-861a-fb1c9fca02de
# /tmp/ipykernel_17145/2755269153.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_17145/2755269153.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_17145/2755269153.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-28 13:25:16,720] Trial 0 finished with value: 0.78125 and parameters: {'alpha': 0.1643802844301823, 'lambda': 0.4118773366204541, 'max_depth': 9, 'eta': 0.0018604438104187612, 'subsample': 0.8047077015188477, 'colsample_bytree': 0.895352962749242}. Best is trial 0 with value: 0.78125.
# /tmp/ipykernel_17145/2755269153.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_17145/2755269153.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_17145/2755269153.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-28 13:25:20,187] Trial 1 finished with value: 0.5225 and parameters: {'alpha': 3.342727372540969e-05, 'lambda': 0.05258742228446596, 'max_depth': 9, 'eta': 8.009544323282864e-07, 'subsample': 0.527858308344481, 'colsample_bytree': 0.9733937924212166}. Best is trial 0 with value: 0.78125.
# /tmp/ipykernel_17145/2755269153.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_17145/2755269153.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_17145/2755269153.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-28 13:25:22,874] Trial 2 finished with value: 0.5225 and parameters: {'alpha': 3.6799468444041303e-07, 'lambda': 2.1152979758934122e-07, 'max_depth': 8, 'eta': 1.5092119142539086e-07, 'subsample': 0.7541428956119357, 'colsample_bytree': 0.5715603718686859}. Best is trial 0 with value: 0.78125.
# /tmp/ipykernel_17145/2755269153.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_17145/2755269153.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_17145/2755269153.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-28 13:25:26,206] Trial 3 finished with value: 0.780625 and parameters: {'alpha': 7.621943455251958e-06, 'lambda': 0.014378287981517865, 'max_depth': 9, 'eta': 0.0018815799564876937, 'subsample': 0.9178898630080481, 'colsample_bytree': 0.6394096315720191}. Best is trial 0 with value: 0.78125.
# /tmp/ipykernel_17145/2755269153.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_17145/2755269153.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_17145/2755269153.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-28 13:25:26,759] Trial 4 finished with value: 0.778125 and parameters: {'alpha': 5.676557989634774e-07, 'lambda': 0.00021380815487191738, 'max_depth': 7, 'eta': 0.01909984893564164, 'subsample': 0.6732629816988712, 'colsample_bytree': 0.9799632330221599}. Best is trial 0 with value: 0.78125.
# /tmp/ipykernel_17145/2755269153.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_17145/2755269153.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_17145/2755269153.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-28 13:25:28,278] Trial 5 finished with value: 0.5225 and parameters: {'alpha': 8.1662261447686e-08, 'lambda': 5.011925574446865e-07, 'max_depth': 5, 'eta': 1.1522009443270326e-08, 'subsample': 0.8461788157754218, 'colsample_bytree': 0.7461669893719994}. Best is trial 0 with value: 0.78125.
# /tmp/ipykernel_17145/2755269153.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_17145/2755269153.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_17145/2755269153.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-28 13:25:28,505] Trial 6 finished with value: 0.78375 and parameters: {'alpha': 0.003915678203572026, 'lambda': 0.1800800029815965, 'max_depth': 5, 'eta': 0.08947595969265464, 'subsample': 0.9144195975455804, 'colsample_bytree': 0.8862621540161957}. Best is trial 6 with value: 0.78375.
# /tmp/ipykernel_17145/2755269153.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_17145/2755269153.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_17145/2755269153.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-28 13:25:29,823] Trial 7 finished with value: 0.7625 and parameters: {'alpha': 0.0007360958020709355, 'lambda': 0.0001679627059695458, 'max_depth': 4, 'eta': 9.801107130470191e-05, 'subsample': 0.511059986668361, 'colsample_bytree': 0.9562031398003383}. Best is trial 6 with value: 0.78375.
# /tmp/ipykernel_17145/2755269153.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_17145/2755269153.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_17145/2755269153.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-28 13:25:30,018] Trial 8 finished with value: 0.7875 and parameters: {'alpha': 0.5493202259209234, 'lambda': 1.7197246943543773e-07, 'max_depth': 5, 'eta': 0.15876640369338957, 'subsample': 0.6325298373252553, 'colsample_bytree': 0.9243869185068296}. Best is trial 8 with value: 0.7875.
# /tmp/ipykernel_17145/2755269153.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_17145/2755269153.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_17145/2755269153.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-28 13:25:30,558] Trial 9 finished with value: 0.788125 and parameters: {'alpha': 1.793926713383074e-06, 'lambda': 0.005017977333124696, 'max_depth': 4, 'eta': 0.025972664649430186, 'subsample': 0.5019882021885452, 'colsample_bytree': 0.9225066176673062}. Best is trial 9 with value: 0.788125.
# /tmp/ipykernel_17145/2755269153.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_17145/2755269153.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_17145/2755269153.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-28 13:25:31,508] Trial 10 finished with value: 0.690625 and parameters: {'alpha': 1.0167268056623669e-05, 'lambda': 0.002448810650181423, 'max_depth': 3, 'eta': 1.809854176079533e-05, 'subsample': 0.6219799930881479, 'colsample_bytree': 0.8044662389512665}. Best is trial 9 with value: 0.788125.
# /tmp/ipykernel_17145/2755269153.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_17145/2755269153.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_17145/2755269153.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-28 13:25:31,608] Trial 11 finished with value: 0.7475 and parameters: {'alpha': 0.9821236711957385, 'lambda': 2.8068650219533557e-06, 'max_depth': 6, 'eta': 0.7235220615370254, 'subsample': 0.6168705065499818, 'colsample_bytree': 0.7994175344510202}. Best is trial 9 with value: 0.788125.
# /tmp/ipykernel_17145/2755269153.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_17145/2755269153.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_17145/2755269153.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-28 13:25:31,680] Trial 12 finished with value: 0.765 and parameters: {'alpha': 1.6637671546360885e-08, 'lambda': 2.079054639045285e-08, 'max_depth': 3, 'eta': 0.8539428521939076, 'subsample': 0.5854609016257482, 'colsample_bytree': 0.891451314041018}. Best is trial 9 with value: 0.788125.
# /tmp/ipykernel_17145/2755269153.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_17145/2755269153.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_17145/2755269153.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-28 13:25:32,919] Trial 13 finished with value: 0.78875 and parameters: {'alpha': 0.006949241450254306, 'lambda': 7.429286353054685e-06, 'max_depth': 5, 'eta': 0.0092271847329176, 'subsample': 0.6816366930362255, 'colsample_bytree': 0.7214276380201562}. Best is trial 13 with value: 0.78875.
# /tmp/ipykernel_17145/2755269153.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_17145/2755269153.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_17145/2755269153.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-28 13:25:34,284] Trial 14 finished with value: 0.77125 and parameters: {'alpha': 0.004464647355086143, 'lambda': 1.0059522554007948e-05, 'max_depth': 4, 'eta': 0.0037332469570839064, 'subsample': 0.7085397568882557, 'colsample_bytree': 0.6969053787897435}. Best is trial 13 with value: 0.78875.
# /tmp/ipykernel_17145/2755269153.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_17145/2755269153.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_17145/2755269153.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-28 13:25:35,883] Trial 15 finished with value: 0.781875 and parameters: {'alpha': 0.0002949038510309691, 'lambda': 0.0010164939206779471, 'max_depth': 6, 'eta': 0.00021527233242717094, 'subsample': 0.5568017506256067, 'colsample_bytree': 0.5217705272745021}. Best is trial 13 with value: 0.78875.
# /tmp/ipykernel_17145/2755269153.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_17145/2755269153.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_17145/2755269153.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-28 13:25:37,078] Trial 16 finished with value: 0.7775 and parameters: {'alpha': 0.048676772859088877, 'lambda': 1.0658731398219736e-05, 'max_depth': 4, 'eta': 0.011677209212746214, 'subsample': 0.9985206937082762, 'colsample_bytree': 0.8145487960451446}. Best is trial 13 with value: 0.78875.
# /tmp/ipykernel_17145/2755269153.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_17145/2755269153.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_17145/2755269153.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-28 13:25:39,383] Trial 17 finished with value: 0.780625 and parameters: {'alpha': 0.0123039568794289, 'lambda': 0.006049221549999894, 'max_depth': 7, 'eta': 0.0002759156392424553, 'subsample': 0.7245152182924959, 'colsample_bytree': 0.671109741510878}. Best is trial 13 with value: 0.78875.
# /tmp/ipykernel_17145/2755269153.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_17145/2755269153.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_17145/2755269153.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-28 13:25:39,752] Trial 18 finished with value: 0.785 and parameters: {'alpha': 1.4475974223551428e-06, 'lambda': 4.929926145235762e-05, 'max_depth': 4, 'eta': 0.04586504981277601, 'subsample': 0.7958280137226739, 'colsample_bytree': 0.7266615702531475}. Best is trial 13 with value: 0.78875.
# /tmp/ipykernel_17145/2755269153.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_17145/2755269153.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_17145/2755269153.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-28 13:25:41,526] Trial 19 finished with value: 0.714375 and parameters: {'alpha': 0.00014367830698492815, 'lambda': 0.0005198398392254176, 'max_depth': 6, 'eta': 1.667045677010028e-05, 'subsample': 0.6784733008728338, 'colsample_bytree': 0.6177329041667368}. Best is trial 13 with value: 0.78875.
# /tmp/ipykernel_17145/2755269153.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_17145/2755269153.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_17145/2755269153.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-28 13:25:42,536] Trial 20 finished with value: 0.76875 and parameters: {'alpha': 0.0009648076291716884, 'lambda': 2.6806391299000703e-05, 'max_depth': 3, 'eta': 0.0035320277741581205, 'subsample': 0.500264623081502, 'colsample_bytree': 0.8300319431868781}. Best is trial 13 with value: 0.78875.
# /tmp/ipykernel_17145/2755269153.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_17145/2755269153.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_17145/2755269153.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-28 13:25:42,671] Trial 21 finished with value: 0.775625 and parameters: {'alpha': 0.9703531198988126, 'lambda': 1.3066049861375728e-08, 'max_depth': 5, 'eta': 0.18562998402440042, 'subsample': 0.6385880114972406, 'colsample_bytree': 0.9228176167698069}. Best is trial 13 with value: 0.78875.
# /tmp/ipykernel_17145/2755269153.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_17145/2755269153.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_17145/2755269153.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-28 13:25:42,795] Trial 22 finished with value: 0.7875 and parameters: {'alpha': 0.056300040673170924, 'lambda': 4.296420037573895e-07, 'max_depth': 5, 'eta': 0.2237443563332406, 'subsample': 0.5773578029153184, 'colsample_bytree': 0.7748108057229499}. Best is trial 13 with value: 0.78875.
# /tmp/ipykernel_17145/2755269153.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_17145/2755269153.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_17145/2755269153.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-28 13:25:43,456] Trial 23 finished with value: 0.788125 and parameters: {'alpha': 0.17417090295433105, 'lambda': 1.8102265893670806e-06, 'max_depth': 5, 'eta': 0.018055143631240854, 'subsample': 0.6496915180688431, 'colsample_bytree': 0.842771266697389}. Best is trial 13 with value: 0.78875.
# /tmp/ipykernel_17145/2755269153.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_17145/2755269153.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_17145/2755269153.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-28 13:25:44,282] Trial 24 finished with value: 0.78375 and parameters: {'alpha': 0.0301135492633601, 'lambda': 3.47134277867083e-06, 'max_depth': 4, 'eta': 0.0162816214834953, 'subsample': 0.7574058637161576, 'colsample_bytree': 0.8520278324868428}. Best is trial 13 with value: 0.78875.
# /tmp/ipykernel_17145/2755269153.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_17145/2755269153.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_17145/2755269153.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-28 13:25:46,155] Trial 25 finished with value: 0.7775 and parameters: {'alpha': 0.17098620108801046, 'lambda': 8.20539060278644e-07, 'max_depth': 6, 'eta': 0.0005114541485212645, 'subsample': 0.6731636194491297, 'colsample_bytree': 0.8611288281695272}. Best is trial 13 with value: 0.78875.
# /tmp/ipykernel_17145/2755269153.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_17145/2755269153.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_17145/2755269153.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-28 13:25:48,523] Trial 26 finished with value: 0.765625 and parameters: {'alpha': 3.30686349010775e-05, 'lambda': 0.02569571172890674, 'max_depth': 7, 'eta': 4.084916409711069e-05, 'subsample': 0.5576306007982493, 'colsample_bytree': 0.7697983295545905}. Best is trial 13 with value: 0.78875.
# /tmp/ipykernel_17145/2755269153.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_17145/2755269153.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_17145/2755269153.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-28 13:25:49,007] Trial 27 finished with value: 0.77875 and parameters: {'alpha': 0.005943612431758097, 'lambda': 8.7515905050682e-08, 'max_depth': 5, 'eta': 0.029405886076578316, 'subsample': 0.7076373058990802, 'colsample_bytree': 0.7177151647090495}. Best is trial 13 with value: 0.78875.
# /tmp/ipykernel_17145/2755269153.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_17145/2755269153.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_17145/2755269153.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-28 13:25:50,098] Trial 28 finished with value: 0.776875 and parameters: {'alpha': 4.4984061176664236e-06, 'lambda': 2.199281675127509e-06, 'max_depth': 4, 'eta': 0.006228640027423886, 'subsample': 0.8003352231997782, 'colsample_bytree': 0.9412043936575455}. Best is trial 13 with value: 0.78875.
# /tmp/ipykernel_17145/2755269153.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_17145/2755269153.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_17145/2755269153.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-28 13:25:51,128] Trial 29 finished with value: 0.759375 and parameters: {'alpha': 0.1671466788457067, 'lambda': 0.8421620461784606, 'max_depth': 3, 'eta': 0.0011173673461510071, 'subsample': 0.5917731323489968, 'colsample_bytree': 0.859447492589524}. Best is trial 13 with value: 0.78875.
# /tmp/ipykernel_17145/2755269153.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_17145/2755269153.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_17145/2755269153.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-28 13:25:52,912] Trial 30 finished with value: 0.779375 and parameters: {'alpha': 0.001641898879440312, 'lambda': 6.680382511933319e-05, 'max_depth': 6, 'eta': 0.0009816704991869288, 'subsample': 0.8675759354426231, 'colsample_bytree': 0.9026733014108448}. Best is trial 13 with value: 0.78875.
# /tmp/ipykernel_17145/2755269153.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_17145/2755269153.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_17145/2755269153.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-28 13:25:53,104] Trial 31 finished with value: 0.7825 and parameters: {'alpha': 0.24864747390219072, 'lambda': 1.5419805490871468e-07, 'max_depth': 5, 'eta': 0.07924212831785928, 'subsample': 0.646362644065857, 'colsample_bytree': 0.9231796699164305}. Best is trial 13 with value: 0.78875.
# /tmp/ipykernel_17145/2755269153.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_17145/2755269153.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_17145/2755269153.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-28 13:25:53,238] Trial 32 finished with value: 0.78375 and parameters: {'alpha': 0.28878490897319453, 'lambda': 1.2124716054561227e-05, 'max_depth': 5, 'eta': 0.26910993725949117, 'subsample': 0.658122633249585, 'colsample_bytree': 0.9958861477236216}. Best is trial 13 with value: 0.78875.
# /tmp/ipykernel_17145/2755269153.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_17145/2755269153.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_17145/2755269153.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-28 13:25:53,526] Trial 33 finished with value: 0.790625 and parameters: {'alpha': 0.01661000860463729, 'lambda': 4.4112807800345035e-08, 'max_depth': 4, 'eta': 0.057490716965242425, 'subsample': 0.5473743385260557, 'colsample_bytree': 0.9498552670184475}. Best is trial 33 with value: 0.790625.
# /tmp/ipykernel_17145/2755269153.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_17145/2755269153.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_17145/2755269153.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-28 13:25:54,624] Trial 34 finished with value: 0.781875 and parameters: {'alpha': 0.02782459370725629, 'lambda': 1.3807421526900913e-06, 'max_depth': 4, 'eta': 0.00785882571478484, 'subsample': 0.5370390064315532, 'colsample_bytree': 0.9740287226240099}. Best is trial 33 with value: 0.790625.
# /tmp/ipykernel_17145/2755269153.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_17145/2755269153.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_17145/2755269153.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-28 13:25:55,153] Trial 35 finished with value: 0.783125 and parameters: {'alpha': 2.741264311659919e-05, 'lambda': 5.065345190473712e-08, 'max_depth': 4, 'eta': 0.02710837939910903, 'subsample': 0.5320179548525602, 'colsample_bytree': 0.8729619762519001}. Best is trial 33 with value: 0.790625.
# /tmp/ipykernel_17145/2755269153.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_17145/2755269153.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_17145/2755269153.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-28 13:25:56,187] Trial 36 finished with value: 0.5225 and parameters: {'alpha': 0.01073935289019588, 'lambda': 0.0752960896492609, 'max_depth': 3, 'eta': 2.7762576972101647e-06, 'subsample': 0.6021878781115821, 'colsample_bytree': 0.8404201749867126}. Best is trial 33 with value: 0.790625.
# /tmp/ipykernel_17145/2755269153.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_17145/2755269153.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_17145/2755269153.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-28 13:25:57,749] Trial 37 finished with value: 0.771875 and parameters: {'alpha': 1.4587378572021656e-07, 'lambda': 3.845372461728264e-08, 'max_depth': 5, 'eta': 0.002413281973952533, 'subsample': 0.5545510789371085, 'colsample_bytree': 0.959256345164009}. Best is trial 33 with value: 0.790625.
# /tmp/ipykernel_17145/2755269153.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_17145/2755269153.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_17145/2755269153.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-28 13:25:58,035] Trial 38 finished with value: 0.77125 and parameters: {'alpha': 9.976972833444289e-05, 'lambda': 0.00041227186488560473, 'max_depth': 9, 'eta': 0.052446150073968904, 'subsample': 0.758001608803103, 'colsample_bytree': 0.6331056495331977}. Best is trial 33 with value: 0.790625.
# /tmp/ipykernel_17145/2755269153.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_17145/2755269153.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_17145/2755269153.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# ...
# [I 2024-01-28 13:35:26,804] Trial 86 finished with value: 0.786875 and parameters: {'alpha': 0.00021884953690051094, 'lambda': 6.191655968288126e-08, 'max_depth': 3, 'eta': 0.06050401399785513, 'subsample': 0.5658772344046406, 'colsample_bytree': 0.5016909706732506}. Best is trial 80 with value: 0.79125.
# /tmp/ipykernel_17145/2755269153.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_17145/2755269153.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_17145/2755269153.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-28 13:35:27,148] Trial 87 finished with value: 0.776875 and parameters: {'alpha': 3.666272999117709e-05, 'lambda': 2.280670091749758e-08, 'max_depth': 4, 'eta': 0.025524866716721956, 'subsample': 0.6142100061218153, 'colsample_bytree': 0.8072815378334295}. Best is trial 80 with value: 0.79125.
# /tmp/ipykernel_17145/2755269153.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_17145/2755269153.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_17145/2755269153.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-28 13:35:28,105] Trial 88 finished with value: 0.78125 and parameters: {'alpha': 1.3295208413066831e-05, 'lambda': 1.1076056912504747e-08, 'max_depth': 3, 'eta': 0.0122342064313221, 'subsample': 0.5543744988752739, 'colsample_bytree': 0.759945140171993}. Best is trial 80 with value: 0.79125.
# /tmp/ipykernel_17145/2755269153.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_17145/2755269153.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_17145/2755269153.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-28 13:35:29,237] Trial 89 finished with value: 0.779375 and parameters: {'alpha': 7.903485626293895e-06, 'lambda': 2.329597314247304e-07, 'max_depth': 4, 'eta': 0.0033165315295648015, 'subsample': 0.5123428797740313, 'colsample_bytree': 0.5297683154684604}. Best is trial 80 with value: 0.79125.
# /tmp/ipykernel_17145/2755269153.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_17145/2755269153.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_17145/2755269153.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-28 13:35:29,366] Trial 90 finished with value: 0.779375 and parameters: {'alpha': 2.2262204892289443e-05, 'lambda': 3.832301261311557e-08, 'max_depth': 3, 'eta': 0.20854165558907803, 'subsample': 0.5838597510973736, 'colsample_bytree': 0.740828849259806}. Best is trial 80 with value: 0.79125.
# /tmp/ipykernel_17145/2755269153.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_17145/2755269153.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_17145/2755269153.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-28 13:35:29,499] Trial 91 finished with value: 0.7825 and parameters: {'alpha': 1.1319732469990807e-05, 'lambda': 4.4769166357503987e-07, 'max_depth': 3, 'eta': 0.2494634600268032, 'subsample': 0.5426295483018861, 'colsample_bytree': 0.8163758385063062}. Best is trial 80 with value: 0.79125.
# /tmp/ipykernel_17145/2755269153.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_17145/2755269153.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_17145/2755269153.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-28 13:35:29,585] Trial 92 finished with value: 0.73375 and parameters: {'alpha': 5.297229841113133e-06, 'lambda': 3.557448807270913e-07, 'max_depth': 3, 'eta': 0.9915354469644913, 'subsample': 0.5547203912850971, 'colsample_bytree': 0.8036387230012509}. Best is trial 80 with value: 0.79125.
# /tmp/ipykernel_17145/2755269153.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_17145/2755269153.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_17145/2755269153.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-28 13:35:29,833] Trial 93 finished with value: 0.7825 and parameters: {'alpha': 9.363086905669411e-06, 'lambda': 1.1315990462474285e-07, 'max_depth': 3, 'eta': 0.08593092873193392, 'subsample': 0.5249778297158675, 'colsample_bytree': 0.8448008776183316}. Best is trial 80 with value: 0.79125.
# /tmp/ipykernel_17145/2755269153.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_17145/2755269153.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_17145/2755269153.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-28 13:35:29,936] Trial 94 finished with value: 0.790625 and parameters: {'alpha': 7.059840477979612e-07, 'lambda': 9.776801963745416e-07, 'max_depth': 3, 'eta': 0.2894388769836455, 'subsample': 0.5732105117904122, 'colsample_bytree': 0.8160163052836935}. Best is trial 80 with value: 0.79125.
# /tmp/ipykernel_17145/2755269153.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_17145/2755269153.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_17145/2755269153.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-28 13:35:30,508] Trial 95 finished with value: 0.781875 and parameters: {'alpha': 5.848368634346296e-07, 'lambda': 6.468554033285308e-08, 'max_depth': 3, 'eta': 0.038865033132411894, 'subsample': 0.5709168618400172, 'colsample_bytree': 0.86140948808348}. Best is trial 80 with value: 0.79125.
# /tmp/ipykernel_17145/2755269153.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_17145/2755269153.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_17145/2755269153.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-28 13:35:30,647] Trial 96 finished with value: 0.78625 and parameters: {'alpha': 1.956128619558044e-06, 'lambda': 1.590751622057867e-07, 'max_depth': 3, 'eta': 0.15479925416661866, 'subsample': 0.5943484072432258, 'colsample_bytree': 0.5703340825973612}. Best is trial 80 with value: 0.79125.
# /tmp/ipykernel_17145/2755269153.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_17145/2755269153.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_17145/2755269153.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-28 13:35:30,759] Trial 97 finished with value: 0.75875 and parameters: {'alpha': 8.031133359745229e-07, 'lambda': 8.005971879247145e-07, 'max_depth': 5, 'eta': 0.44307610504218814, 'subsample': 0.5115737531151389, 'colsample_bytree': 0.7886066887387856}. Best is trial 80 with value: 0.79125.
# /tmp/ipykernel_17145/2755269153.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_17145/2755269153.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_17145/2755269153.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-28 13:35:31,098] Trial 98 finished with value: 0.790625 and parameters: {'alpha': 4.0257899888280284e-07, 'lambda': 3.358512446555189e-08, 'max_depth': 3, 'eta': 0.06048934603489379, 'subsample': 0.5315352664436294, 'colsample_bytree': 0.772243068868384}. Best is trial 80 with value: 0.79125.
# /tmp/ipykernel_17145/2755269153.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /tmp/ipykernel_17145/2755269153.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /tmp/ipykernel_17145/2755269153.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 1e-8, 1.0),
# [I 2024-01-28 13:35:32,250] Trial 99 finished with value: 0.7325 and parameters: {'alpha': 1.417794947654938e-07, 'lambda': 2.4482136935105543e-07, 'max_depth': 4, 'eta': 5.7813072120560226e-05, 'subsample': 0.6226708462681525, 'colsample_bytree': 0.7005442081527308}. Best is trial 80 with value: 0.79125.

# %% [markdown]
# - xgb_平均スコア

# %%
# 全フォールドの平均スコアを計算
xgb_average_score = sum(xgb_fold_scores) / n_splits
print(f"XGB Average accuracy across all folds: {xgb_average_score}")
# Out:
# XGB Average accuracy across all folds: 0.773875

# %% [markdown]
# - xgb_予測平均

# %%
# 予測の平均を計算
xgb_y_test_pred_avg = np.mean(xgb_test_predictions, axis=0)

# 最終的な予測結果を整数に変換
xgb_y_test_pred_int = (xgb_y_test_pred_avg > 0.5).astype(int)

# %% [markdown]
# - output

# %%
# 現在の日時を取得してフォーマットする
current_time = datetime.now().strftime("%Y%m%d_%H%M%S")
output = f'../data/output/{current_time}_XGBoost_cv{xgb_average_score:.4f}.csv'

submit = pd.DataFrame({
    '0': test['gameId'],
    '1': xgb_y_test_pred_int
})

# カラムヘッダー消去して出力
# ヘッダーなしでCSVファイルとして保存
submit.to_csv(output, header=False, index=False)

# %% [markdown]
# ## CatBoost

# %%
for train_index, val_index in kf.split(X):
    X_train_fold, X_val_fold = X.iloc[train_index], X.iloc[val_index]
    y_train_fold, y_val_fold = y[train_index], y[val_index]

    # Optunaでのハイパーパラメータチューニング
    def objective(trial):
        param = {
            'iterations': 1000,
            'depth': trial.suggest_int('depth', 4, 10),
            'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3),
            'random_strength': trial.suggest_int('random_strength', 1, 20),
            'bagging_temperature': trial.suggest_float('bagging_temperature', 0.0, 1.0),
            'l2_leaf_reg': trial.suggest_float('l2_leaf_reg', 1e-3, 100),
            'scale_pos_weight': trial.suggest_float('scale_pos_weight', 0.1, 10.0),
            'loss_function': 'Logloss'
        }

        model = cb.CatBoostClassifier(**param, verbose=False)
        model.fit(X_train_fold, y_train_fold, eval_set=(X_val_fold, y_val_fold), early_stopping_rounds=50)
        preds = model.predict(X_val_fold)
        accuracy = accuracy_score(y_val_fold, preds)
        return accuracy

    cb_study = optuna.create_study(direction='maximize')
    cb_study.optimize(objective, n_trials=100)

    # 各フォールドの最適パラメータでモデルを再学習
    cb_best_params = cb_study.best_params
    cb_best_params['loss_function'] = 'Logloss'
    model_fold = cb.CatBoostClassifier(**cb_best_params, verbose=False)
    model_fold.fit(X_train_fold, y_train_fold)

    # 各フォールドのモデル性能を評価
    cb_y_val_pred = model_fold.predict(X_val_fold)
    cb_fold_accuracy = accuracy_score(y_val_fold, cb_y_val_pred)
    cb_fold_scores.append(cb_fold_accuracy)

    # テストデータセットでの予測
    cb_y_test_pred_fold = model_fold.predict(test_drop_gameId)
    cb_test_predictions.append(cb_y_test_pred_fold)
# Out:
# [I 2024-01-28 13:35:32,361] A new study created in memory with name: no-name-5812fa33-4cd4-4c53-90a4-7ba530121dbb
# [I 2024-01-28 13:35:32,817] Trial 0 finished with value: 0.72375 and parameters: {'depth': 5, 'learning_rate': 0.28225054627699603, 'random_strength': 7, 'bagging_temperature': 0.5363999562852277, 'l2_leaf_reg': 1.6144086252433827, 'scale_pos_weight': 4.367663233977826}. Best is trial 0 with value: 0.72375.
# [I 2024-01-28 13:35:33,559] Trial 1 finished with value: 0.763125 and parameters: {'depth': 8, 'learning_rate': 0.13115271161798325, 'random_strength': 8, 'bagging_temperature': 0.32675740028195366, 'l2_leaf_reg': 31.365779274932223, 'scale_pos_weight': 1.8108466864660258}. Best is trial 1 with value: 0.763125.
# [I 2024-01-28 13:35:34,244] Trial 2 finished with value: 0.769375 and parameters: {'depth': 5, 'learning_rate': 0.16939042752981975, 'random_strength': 16, 'bagging_temperature': 0.9630271431711523, 'l2_leaf_reg': 29.815379482464557, 'scale_pos_weight': 1.938591556660435}. Best is trial 2 with value: 0.769375.
# [I 2024-01-28 13:35:35,057] Trial 3 finished with value: 0.690625 and parameters: {'depth': 5, 'learning_rate': 0.09348800426027161, 'random_strength': 12, 'bagging_temperature': 0.5077250765123977, 'l2_leaf_reg': 54.71361431550948, 'scale_pos_weight': 7.466038733783332}. Best is trial 2 with value: 0.769375.
# [I 2024-01-28 13:35:37,263] Trial 4 finished with value: 0.71 and parameters: {'depth': 10, 'learning_rate': 0.0945120215169135, 'random_strength': 11, 'bagging_temperature': 0.5598735770285628, 'l2_leaf_reg': 48.19617179442365, 'scale_pos_weight': 0.19035626416109303}. Best is trial 2 with value: 0.769375.
# [I 2024-01-28 13:35:37,895] Trial 5 finished with value: 0.693125 and parameters: {'depth': 8, 'learning_rate': 0.12042994331397561, 'random_strength': 7, 'bagging_temperature': 0.7559393364027409, 'l2_leaf_reg': 10.861101328578881, 'scale_pos_weight': 7.689973533765557}. Best is trial 2 with value: 0.769375.
# [I 2024-01-28 13:35:39,235] Trial 6 finished with value: 0.68375 and parameters: {'depth': 10, 'learning_rate': 0.28435496755711964, 'random_strength': 10, 'bagging_temperature': 0.8457646399471385, 'l2_leaf_reg': 66.3983170968007, 'scale_pos_weight': 8.402673097418353}. Best is trial 2 with value: 0.769375.
# [I 2024-01-28 13:35:43,006] Trial 7 finished with value: 0.798125 and parameters: {'depth': 8, 'learning_rate': 0.048196826600982304, 'random_strength': 15, 'bagging_temperature': 0.17274477007592015, 'l2_leaf_reg': 74.34922476111637, 'scale_pos_weight': 1.0694179967722084}. Best is trial 7 with value: 0.798125.
# [I 2024-01-28 13:35:44,219] Trial 8 finished with value: 0.78875 and parameters: {'depth': 9, 'learning_rate': 0.1483032134335013, 'random_strength': 5, 'bagging_temperature': 0.03946281445683841, 'l2_leaf_reg': 26.14187143475892, 'scale_pos_weight': 0.6490704749408973}. Best is trial 7 with value: 0.798125.
# [I 2024-01-28 13:35:44,763] Trial 9 finished with value: 0.78 and parameters: {'depth': 8, 'learning_rate': 0.22085091809372687, 'random_strength': 5, 'bagging_temperature': 0.5076429955232659, 'l2_leaf_reg': 19.13107679702714, 'scale_pos_weight': 1.2554473023720327}. Best is trial 7 with value: 0.798125.
# [I 2024-01-28 13:35:47,502] Trial 10 finished with value: 0.71625 and parameters: {'depth': 6, 'learning_rate': 0.01517514728248337, 'random_strength': 20, 'bagging_temperature': 0.0126452547375836, 'l2_leaf_reg': 97.5377323828478, 'scale_pos_weight': 3.934746600951979}. Best is trial 7 with value: 0.798125.
# [I 2024-01-28 13:35:50,871] Trial 11 finished with value: 0.7225 and parameters: {'depth': 9, 'learning_rate': 0.01957039934815483, 'random_strength': 2, 'bagging_temperature': 0.010986086527365102, 'l2_leaf_reg': 85.9368648805771, 'scale_pos_weight': 3.360059952588221}. Best is trial 7 with value: 0.798125.
# [I 2024-01-28 13:35:52,761] Trial 12 finished with value: 0.736875 and parameters: {'depth': 7, 'learning_rate': 0.05759687653806424, 'random_strength': 15, 'bagging_temperature': 0.20490707113088902, 'l2_leaf_reg': 74.13959362850812, 'scale_pos_weight': 2.726281821309297}. Best is trial 7 with value: 0.798125.
# [I 2024-01-28 13:35:53,653] Trial 13 finished with value: 0.70625 and parameters: {'depth': 9, 'learning_rate': 0.18885665410661695, 'random_strength': 3, 'bagging_temperature': 0.20355728288855768, 'l2_leaf_reg': 43.38289958798971, 'scale_pos_weight': 5.59754136341462}. Best is trial 7 with value: 0.798125.
# [I 2024-01-28 13:35:54,194] Trial 14 finished with value: 0.74375 and parameters: {'depth': 7, 'learning_rate': 0.22585440327750822, 'random_strength': 15, 'bagging_temperature': 0.18138076624494204, 'l2_leaf_reg': 66.85483025884213, 'scale_pos_weight': 0.33738934090372596}. Best is trial 7 with value: 0.798125.
# [I 2024-01-28 13:35:55,933] Trial 15 finished with value: 0.71125 and parameters: {'depth': 9, 'learning_rate': 0.06151977228282591, 'random_strength': 20, 'bagging_temperature': 0.33931468189909997, 'l2_leaf_reg': 36.7574100835855, 'scale_pos_weight': 5.4494773145229}. Best is trial 7 with value: 0.798125.
# [I 2024-01-28 13:35:57,563] Trial 16 finished with value: 0.789375 and parameters: {'depth': 4, 'learning_rate': 0.053801329688881086, 'random_strength': 1, 'bagging_temperature': 0.12303470380330742, 'l2_leaf_reg': 80.61470618912927, 'scale_pos_weight': 1.0686035338889064}. Best is trial 7 with value: 0.798125.
# [I 2024-01-28 13:35:59,461] Trial 17 finished with value: 0.7375 and parameters: {'depth': 4, 'learning_rate': 0.05227266965191098, 'random_strength': 17, 'bagging_temperature': 0.35721749887005305, 'l2_leaf_reg': 87.87019517700249, 'scale_pos_weight': 2.718267808933143}. Best is trial 7 with value: 0.798125.
# [I 2024-01-28 13:36:00,652] Trial 18 finished with value: 0.663125 and parameters: {'depth': 4, 'learning_rate': 0.09061432919230117, 'random_strength': 13, 'bagging_temperature': 0.13387622997940735, 'l2_leaf_reg': 78.72971035701156, 'scale_pos_weight': 9.899540875670876}. Best is trial 7 with value: 0.798125.
# [I 2024-01-28 13:36:02,051] Trial 19 finished with value: 0.75 and parameters: {'depth': 6, 'learning_rate': 0.04006071675989322, 'random_strength': 1, 'bagging_temperature': 0.67023989086553, 'l2_leaf_reg': 59.17030788085321, 'scale_pos_weight': 1.9931282704650934}. Best is trial 7 with value: 0.798125.
# [I 2024-01-28 13:36:03,520] Trial 20 finished with value: 0.70375 and parameters: {'depth': 6, 'learning_rate': 0.0801844352702416, 'random_strength': 18, 'bagging_temperature': 0.3997937386204617, 'l2_leaf_reg': 98.86524419912503, 'scale_pos_weight': 6.30742074277224}. Best is trial 7 with value: 0.798125.
# [I 2024-01-28 13:36:04,504] Trial 21 finished with value: 0.79125 and parameters: {'depth': 8, 'learning_rate': 0.12712345763594818, 'random_strength': 4, 'bagging_temperature': 0.0864501509379311, 'l2_leaf_reg': 81.98483178339983, 'scale_pos_weight': 0.9824223117114359}. Best is trial 7 with value: 0.798125.
# [I 2024-01-28 13:36:05,463] Trial 22 finished with value: 0.789375 and parameters: {'depth': 8, 'learning_rate': 0.11846405311259511, 'random_strength': 4, 'bagging_temperature': 0.11853129830615372, 'l2_leaf_reg': 86.7943179602859, 'scale_pos_weight': 1.300499247912443}. Best is trial 7 with value: 0.798125.
# [I 2024-01-28 13:36:07,711] Trial 23 finished with value: 0.733125 and parameters: {'depth': 7, 'learning_rate': 0.03333883454397529, 'random_strength': 1, 'bagging_temperature': 0.27366306031000054, 'l2_leaf_reg': 70.70913408504622, 'scale_pos_weight': 2.737659003028485}. Best is trial 7 with value: 0.798125.
# [I 2024-01-28 13:36:09,276] Trial 24 finished with value: 0.7875 and parameters: {'depth': 7, 'learning_rate': 0.06656348435630444, 'random_strength': 9, 'bagging_temperature': 0.10014719454357465, 'l2_leaf_reg': 85.10808416445205, 'scale_pos_weight': 1.081060596589956}. Best is trial 7 with value: 0.798125.
# [I 2024-01-28 13:36:10,220] Trial 25 finished with value: 0.73125 and parameters: {'depth': 8, 'learning_rate': 0.1912327400226981, 'random_strength': 13, 'bagging_temperature': 0.27487946886921777, 'l2_leaf_reg': 78.22113865434991, 'scale_pos_weight': 3.5019031629379027}. Best is trial 7 with value: 0.798125.
# [I 2024-01-28 13:36:11,031] Trial 26 finished with value: 0.65125 and parameters: {'depth': 6, 'learning_rate': 0.14158246425065824, 'random_strength': 3, 'bagging_temperature': 0.412244819175849, 'l2_leaf_reg': 63.73213879444925, 'scale_pos_weight': 0.10992948202734265}. Best is trial 7 with value: 0.798125.
# [I 2024-01-28 13:36:12,424] Trial 27 finished with value: 0.74875 and parameters: {'depth': 7, 'learning_rate': 0.1110719296873827, 'random_strength': 5, 'bagging_temperature': 0.08889947503009558, 'l2_leaf_reg': 91.65384144707104, 'scale_pos_weight': 2.301046408126208}. Best is trial 7 with value: 0.798125.
# [I 2024-01-28 13:36:15,536] Trial 28 finished with value: 0.78 and parameters: {'depth': 9, 'learning_rate': 0.038175896777451965, 'random_strength': 1, 'bagging_temperature': 0.2668089838718861, 'l2_leaf_reg': 76.60183614872119, 'scale_pos_weight': 1.211502304575688}. Best is trial 7 with value: 0.798125.
# [I 2024-01-28 13:36:16,007] Trial 29 finished with value: 0.7225 and parameters: {'depth': 4, 'learning_rate': 0.24300085707237246, 'random_strength': 7, 'bagging_temperature': 0.1817781584442208, 'l2_leaf_reg': 60.069917476903896, 'scale_pos_weight': 3.923327882168149}. Best is trial 7 with value: 0.798125.
# [I 2024-01-28 13:36:17,617] Trial 30 finished with value: 0.723125 and parameters: {'depth': 5, 'learning_rate': 0.07594047061710699, 'random_strength': 3, 'bagging_temperature': 0.07830740896266083, 'l2_leaf_reg': 82.25343967769635, 'scale_pos_weight': 4.448972108550345}. Best is trial 7 with value: 0.798125.
# [I 2024-01-28 13:36:19,081] Trial 31 finished with value: 0.79375 and parameters: {'depth': 8, 'learning_rate': 0.1126248409537107, 'random_strength': 4, 'bagging_temperature': 0.1445711845764654, 'l2_leaf_reg': 91.71445302382463, 'scale_pos_weight': 1.1728827862979392}. Best is trial 7 with value: 0.798125.
# [I 2024-01-28 13:36:20,415] Trial 32 finished with value: 0.7675 and parameters: {'depth': 8, 'learning_rate': 0.16384203029522368, 'random_strength': 6, 'bagging_temperature': 0.15183156914173251, 'l2_leaf_reg': 93.28888127463483, 'scale_pos_weight': 1.6750470322016402}. Best is trial 7 with value: 0.798125.
# [I 2024-01-28 13:36:21,668] Trial 33 finished with value: 0.778125 and parameters: {'depth': 8, 'learning_rate': 0.10294536676151164, 'random_strength': 9, 'bagging_temperature': 0.2329862301815882, 'l2_leaf_reg': 71.52060609351142, 'scale_pos_weight': 0.6336069631908696}. Best is trial 7 with value: 0.798125.
# [I 2024-01-28 13:36:23,162] Trial 34 finished with value: 0.748125 and parameters: {'depth': 8, 'learning_rate': 0.13661983455018037, 'random_strength': 4, 'bagging_temperature': 0.05304016293320886, 'l2_leaf_reg': 91.97102361033596, 'scale_pos_weight': 2.2790098684467814}. Best is trial 7 with value: 0.798125.
# [I 2024-01-28 13:36:24,798] Trial 35 finished with value: 0.786875 and parameters: {'depth': 7, 'learning_rate': 0.08186015262556968, 'random_strength': 2, 'bagging_temperature': 0.5973348157863619, 'l2_leaf_reg': 99.658135106358, 'scale_pos_weight': 0.9408058188198816}. Best is trial 7 with value: 0.798125.
# [I 2024-01-28 13:36:25,818] Trial 36 finished with value: 0.768125 and parameters: {'depth': 10, 'learning_rate': 0.18039010811518957, 'random_strength': 6, 'bagging_temperature': 0.43321567769553976, 'l2_leaf_reg': 0.4800310279850777, 'scale_pos_weight': 1.6928802011320159}. Best is trial 7 with value: 0.798125.
# [I 2024-01-28 13:36:27,330] Trial 37 finished with value: 0.780625 and parameters: {'depth': 9, 'learning_rate': 0.12970881026399123, 'random_strength': 8, 'bagging_temperature': 0.2929463040815337, 'l2_leaf_reg': 52.51158903186547, 'scale_pos_weight': 1.6399339040724645}. Best is trial 7 with value: 0.798125.
# [I 2024-01-28 13:36:28,984] Trial 38 finished with value: 0.789375 and parameters: {'depth': 8, 'learning_rate': 0.09780792798072163, 'random_strength': 11, 'bagging_temperature': 0.15564947024391762, 'l2_leaf_reg': 82.42301858261297, 'scale_pos_weight': 0.6603443178053969}. Best is trial 7 with value: 0.798125.
# [I 2024-01-28 13:36:29,834] Trial 39 finished with value: 0.7325 and parameters: {'depth': 6, 'learning_rate': 0.1624808998658287, 'random_strength': 2, 'bagging_temperature': 0.06111903374442406, 'l2_leaf_reg': 70.02712574414834, 'scale_pos_weight': 3.2357888106046735}. Best is trial 7 with value: 0.798125.
# [I 2024-01-28 13:36:35,212] Trial 40 finished with value: 0.74625 and parameters: {'depth': 9, 'learning_rate': 0.024712005762360836, 'random_strength': 4, 'bagging_temperature': 0.9429294476526857, 'l2_leaf_reg': 93.94562106634908, 'scale_pos_weight': 2.338116322734984}. Best is trial 7 with value: 0.798125.
# [I 2024-01-28 13:36:36,089] Trial 41 finished with value: 0.781875 and parameters: {'depth': 8, 'learning_rate': 0.11693873537907883, 'random_strength': 5, 'bagging_temperature': 0.12221240654550918, 'l2_leaf_reg': 89.53199161057724, 'scale_pos_weight': 1.327260019571519}. Best is trial 7 with value: 0.798125.
# [I 2024-01-28 13:36:37,320] Trial 42 finished with value: 0.785 and parameters: {'depth': 8, 'learning_rate': 0.12514004323971278, 'random_strength': 4, 'bagging_temperature': 0.22158459044706508, 'l2_leaf_reg': 81.73273923037226, 'scale_pos_weight': 0.636986470914132}. Best is trial 7 with value: 0.798125.
# [I 2024-01-28 13:36:38,297] Trial 43 finished with value: 0.64625 and parameters: {'depth': 8, 'learning_rate': 0.15111217837382745, 'random_strength': 7, 'bagging_temperature': 0.10998332987620665, 'l2_leaf_reg': 87.28534373116317, 'scale_pos_weight': 0.10566342792200889}. Best is trial 7 with value: 0.798125.
# [I 2024-01-28 13:36:39,616] Trial 44 finished with value: 0.775625 and parameters: {'depth': 5, 'learning_rate': 0.07008934183100249, 'random_strength': 3, 'bagging_temperature': 0.01817289589133181, 'l2_leaf_reg': 76.99986955262608, 'scale_pos_weight': 1.4408693680232068}. Best is trial 7 with value: 0.798125.
# [I 2024-01-28 13:36:41,225] Trial 45 finished with value: 0.795625 and parameters: {'depth': 8, 'learning_rate': 0.11136968276888486, 'random_strength': 6, 'bagging_temperature': 0.16632750722591633, 'l2_leaf_reg': 96.1004621783697, 'scale_pos_weight': 0.9442490554947494}. Best is trial 7 with value: 0.798125.
# [I 2024-01-28 13:36:43,759] Trial 46 finished with value: 0.76625 and parameters: {'depth': 9, 'learning_rate': 0.08892003607297516, 'random_strength': 6, 'bagging_temperature': 0.0012187534214669754, 'l2_leaf_reg': 96.21550333765809, 'scale_pos_weight': 1.9643866332212767}. Best is trial 7 with value: 0.798125.
# [I 2024-01-28 13:36:45,880] Trial 47 finished with value: 0.778125 and parameters: {'depth': 7, 'learning_rate': 0.05003562852185549, 'random_strength': 13, 'bagging_temperature': 0.24129113563672455, 'l2_leaf_reg': 82.42020039460363, 'scale_pos_weight': 0.6135038350209355}. Best is trial 7 with value: 0.798125.
# [I 2024-01-28 13:36:47,310] Trial 48 finished with value: 0.7925 and parameters: {'depth': 9, 'learning_rate': 0.10340459889393919, 'random_strength': 15, 'bagging_temperature': 0.3097708900006436, 'l2_leaf_reg': 74.29997466133295, 'scale_pos_weight': 0.8781549543277247}. Best is trial 7 with value: 0.798125.
# [I 2024-01-28 13:36:49,986] Trial 49 finished with value: 0.739375 and parameters: {'depth': 10, 'learning_rate': 0.09996020990131388, 'random_strength': 14, 'bagging_temperature': 0.457089408059705, 'l2_leaf_reg': 45.03580066248764, 'scale_pos_weight': 2.9365295262333366}. Best is trial 7 with value: 0.798125.
# [I 2024-01-28 13:36:51,354] Trial 50 finished with value: 0.70375 and parameters: {'depth': 9, 'learning_rate': 0.14192511327502647, 'random_strength': 16, 'bagging_temperature': 0.1859815746941832, 'l2_leaf_reg': 73.0247462944296, 'scale_pos_weight': 6.455932195267035}. Best is trial 7 with value: 0.798125.
# [I 2024-01-28 13:36:53,025] Trial 51 finished with value: 0.793125 and parameters: {'depth': 8, 'learning_rate': 0.11536581899047743, 'random_strength': 18, 'bagging_temperature': 0.3150629893162941, 'l2_leaf_reg': 64.87283829410984, 'scale_pos_weight': 0.9383592783599344}. Best is trial 7 with value: 0.798125.
# [I 2024-01-28 13:36:54,034] Trial 52 finished with value: 0.79625 and parameters: {'depth': 8, 'learning_rate': 0.11117177831581279, 'random_strength': 19, 'bagging_temperature': 0.32077733802790814, 'l2_leaf_reg': 64.65840112525538, 'scale_pos_weight': 0.8675949285717032}. Best is trial 7 with value: 0.798125.
# [I 2024-01-28 13:36:55,682] Trial 53 finished with value: 0.751875 and parameters: {'depth': 9, 'learning_rate': 0.09916340785054123, 'random_strength': 19, 'bagging_temperature': 0.35812957260239, 'l2_leaf_reg': 64.62044184868833, 'scale_pos_weight': 0.3751753068832361}. Best is trial 7 with value: 0.798125.
# [I 2024-01-28 13:36:57,023] Trial 54 finished with value: 0.765625 and parameters: {'depth': 8, 'learning_rate': 0.10881293085395047, 'random_strength': 18, 'bagging_temperature': 0.3250923001154279, 'l2_leaf_reg': 54.7431911376517, 'scale_pos_weight': 2.0278610270660105}. Best is trial 7 with value: 0.798125.
# [I 2024-01-28 13:36:58,395] Trial 55 finished with value: 0.795 and parameters: {'depth': 7, 'learning_rate': 0.1148398677903506, 'random_strength': 17, 'bagging_temperature': 0.31115791711635543, 'l2_leaf_reg': 58.39895589499688, 'scale_pos_weight': 0.7380914446018632}. Best is trial 7 with value: 0.798125.
# [I 2024-01-28 13:36:59,544] Trial 56 finished with value: 0.746875 and parameters: {'depth': 7, 'learning_rate': 0.08735412094683763, 'random_strength': 17, 'bagging_temperature': 0.35763485572095566, 'l2_leaf_reg': 57.98838610536022, 'scale_pos_weight': 0.3421410677841372}. Best is trial 7 with value: 0.798125.
# [I 2024-01-28 13:37:00,322] Trial 57 finished with value: 0.678125 and parameters: {'depth': 7, 'learning_rate': 0.17446700932604967, 'random_strength': 19, 'bagging_temperature': 0.5448470114163835, 'l2_leaf_reg': 67.65518039001395, 'scale_pos_weight': 9.062671473999977}. Best is trial 7 with value: 0.798125.
# [I 2024-01-28 13:37:01,237] Trial 58 finished with value: 0.77375 and parameters: {'depth': 7, 'learning_rate': 0.11701182035440791, 'random_strength': 17, 'bagging_temperature': 0.4734055834916671, 'l2_leaf_reg': 38.37353408180698, 'scale_pos_weight': 1.5404235526571255}. Best is trial 7 with value: 0.798125.
# [I 2024-01-28 13:37:02,376] Trial 59 finished with value: 0.79 and parameters: {'depth': 8, 'learning_rate': 0.15037924840590183, 'random_strength': 19, 'bagging_temperature': 0.24519941423127106, 'l2_leaf_reg': 62.4310885879182, 'scale_pos_weight': 0.8406665240628075}. Best is trial 7 with value: 0.798125.
# [I 2024-01-28 13:37:06,139] Trial 60 finished with value: 0.75875 and parameters: {'depth': 8, 'learning_rate': 0.012457262859527252, 'random_strength': 20, 'bagging_temperature': 0.3832051097045496, 'l2_leaf_reg': 10.14284615420663, 'scale_pos_weight': 1.9530999506177535}. Best is trial 7 with value: 0.798125.
# [I 2024-01-28 13:37:07,537] Trial 61 finished with value: 0.79375 and parameters: {'depth': 9, 'learning_rate': 0.10700387182345811, 'random_strength': 16, 'bagging_temperature': 0.30639981830361906, 'l2_leaf_reg': 48.65961154801691, 'scale_pos_weight': 0.9362295261008349}. Best is trial 7 with value: 0.798125.
# [I 2024-01-28 13:37:08,742] Trial 62 finished with value: 0.789375 and parameters: {'depth': 8, 'learning_rate': 0.13264932932170478, 'random_strength': 16, 'bagging_temperature': 0.3046418985756781, 'l2_leaf_reg': 47.100660134441085, 'scale_pos_weight': 1.2288762741748487}. Best is trial 7 with value: 0.798125.
# [I 2024-01-28 13:37:09,305] Trial 63 finished with value: 0.755 and parameters: {'depth': 7, 'learning_rate': 0.29482119012554087, 'random_strength': 18, 'bagging_temperature': 0.15909844362088227, 'l2_leaf_reg': 50.63151632556986, 'scale_pos_weight': 0.35218891899142446}. Best is trial 7 with value: 0.798125.
# [I 2024-01-28 13:37:12,123] Trial 64 finished with value: 0.75375 and parameters: {'depth': 10, 'learning_rate': 0.1086678210626663, 'random_strength': 14, 'bagging_temperature': 0.21741441240474652, 'l2_leaf_reg': 55.7190843890822, 'scale_pos_weight': 2.5018704304279997}. Best is trial 7 with value: 0.798125.
# [I 2024-01-28 13:37:14,115] Trial 65 finished with value: 0.786875 and parameters: {'depth': 9, 'learning_rate': 0.07392864953266196, 'random_strength': 17, 'bagging_temperature': 0.26463881582821924, 'l2_leaf_reg': 38.89480493720647, 'scale_pos_weight': 1.1205992654176915}. Best is trial 7 with value: 0.798125.
# [I 2024-01-28 13:37:14,974] Trial 66 finished with value: 0.76875 and parameters: {'depth': 7, 'learning_rate': 0.12378871357260848, 'random_strength': 18, 'bagging_temperature': 0.3962840959250992, 'l2_leaf_reg': 61.257068985600114, 'scale_pos_weight': 0.4676489860796254}. Best is trial 7 with value: 0.798125.
# [I 2024-01-28 13:37:15,749] Trial 67 finished with value: 0.778125 and parameters: {'depth': 8, 'learning_rate': 0.13901493963455933, 'random_strength': 15, 'bagging_temperature': 0.19227199860656782, 'l2_leaf_reg': 30.09883607089588, 'scale_pos_weight': 1.473763321820106}. Best is trial 7 with value: 0.798125.
# [I 2024-01-28 13:37:16,670] Trial 68 finished with value: 0.795 and parameters: {'depth': 8, 'learning_rate': 0.2085409995344783, 'random_strength': 16, 'bagging_temperature': 0.3430855221019687, 'l2_leaf_reg': 50.40245648458426, 'scale_pos_weight': 0.7750904100476282}. Best is trial 7 with value: 0.798125.
# [I 2024-01-28 13:37:17,328] Trial 69 finished with value: 0.791875 and parameters: {'depth': 9, 'learning_rate': 0.24410520592445067, 'random_strength': 16, 'bagging_temperature': 0.43426358845650376, 'l2_leaf_reg': 48.96640094950726, 'scale_pos_weight': 0.7406828000122188}. Best is trial 7 with value: 0.798125.
# [I 2024-01-28 13:37:17,805] Trial 70 finished with value: 0.69125 and parameters: {'depth': 8, 'learning_rate': 0.2570403681340035, 'random_strength': 14, 'bagging_temperature': 0.3443881149656171, 'l2_leaf_reg': 25.08831662317379, 'scale_pos_weight': 7.106039185068467}. Best is trial 7 with value: 0.798125.
# [I 2024-01-28 13:37:18,387] Trial 71 finished with value: 0.786875 and parameters: {'depth': 8, 'learning_rate': 0.2136385273833911, 'random_strength': 17, 'bagging_temperature': 0.28243005500665563, 'l2_leaf_reg': 41.672888592937895, 'scale_pos_weight': 0.9433692943765174}. Best is trial 7 with value: 0.798125.
# [I 2024-01-28 13:37:19,090] Trial 72 finished with value: 0.765 and parameters: {'depth': 8, 'learning_rate': 0.19802004215604074, 'random_strength': 12, 'bagging_temperature': 0.5106549313673177, 'l2_leaf_reg': 51.826015210754456, 'scale_pos_weight': 1.7932545468816492}. Best is trial 7 with value: 0.798125.
# [I 2024-01-28 13:37:19,763] Trial 73 finished with value: 0.678125 and parameters: {'depth': 7, 'learning_rate': 0.16136194965254, 'random_strength': 20, 'bagging_temperature': 0.3314546429368337, 'l2_leaf_reg': 57.95742846610257, 'scale_pos_weight': 0.15038581535486129}. Best is trial 7 with value: 0.798125.
# [I 2024-01-28 13:37:21,423] Trial 74 finished with value: 0.7925 and parameters: {'depth': 8, 'learning_rate': 0.061256939896644325, 'random_strength': 15, 'bagging_temperature': 0.3770860836907439, 'l2_leaf_reg': 66.08194890308948, 'scale_pos_weight': 1.1684467195304236}. Best is trial 7 with value: 0.798125.
# [I 2024-01-28 13:37:23,284] Trial 75 finished with value: 0.7175 and parameters: {'depth': 9, 'learning_rate': 0.08243992091238866, 'random_strength': 19, 'bagging_temperature': 0.2567455976266137, 'l2_leaf_reg': 67.5409936980134, 'scale_pos_weight': 4.991637258892061}. Best is trial 7 with value: 0.798125.
# [I 2024-01-28 13:37:24,596] Trial 76 finished with value: 0.7825 and parameters: {'depth': 7, 'learning_rate': 0.1133601416802586, 'random_strength': 16, 'bagging_temperature': 0.5938973569910158, 'l2_leaf_reg': 56.11821383120526, 'scale_pos_weight': 1.4166796695870767}. Best is trial 7 with value: 0.798125.
# [I 2024-01-28 13:37:25,817] Trial 77 finished with value: 0.773125 and parameters: {'depth': 6, 'learning_rate': 0.08980669733256513, 'random_strength': 18, 'bagging_temperature': 0.21968738063031146, 'l2_leaf_reg': 45.34956296255747, 'scale_pos_weight': 0.5186963640835902}. Best is trial 7 with value: 0.798125.
# [I 2024-01-28 13:37:26,872] Trial 78 finished with value: 0.76125 and parameters: {'depth': 8, 'learning_rate': 0.12297633667154584, 'random_strength': 10, 'bagging_temperature': 0.14656270211017086, 'l2_leaf_reg': 34.093951966469916, 'scale_pos_weight': 2.176254292402219}. Best is trial 7 with value: 0.798125.
# [I 2024-01-28 13:37:27,956] Trial 79 finished with value: 0.790625 and parameters: {'depth': 8, 'learning_rate': 0.21170885165840553, 'random_strength': 8, 'bagging_temperature': 0.29651111859193036, 'l2_leaf_reg': 95.4392962743858, 'scale_pos_weight': 0.9841956235999293}. Best is trial 7 with value: 0.798125.
# [I 2024-01-28 13:37:29,644] Trial 80 finished with value: 0.765625 and parameters: {'depth': 9, 'learning_rate': 0.14379753634229298, 'random_strength': 17, 'bagging_temperature': 0.7245058584518366, 'l2_leaf_reg': 89.33529234429011, 'scale_pos_weight': 1.7777109106769586}. Best is trial 7 with value: 0.798125.
# [I 2024-01-28 13:37:31,575] Trial 81 finished with value: 0.786875 and parameters: {'depth': 9, 'learning_rate': 0.10512089150678147, 'random_strength': 15, 'bagging_temperature': 0.3119429712635657, 'l2_leaf_reg': 73.29022001812169, 'scale_pos_weight': 0.9123266981565766}. Best is trial 7 with value: 0.798125.
# [I 2024-01-28 13:37:33,118] Trial 82 finished with value: 0.78875 and parameters: {'depth': 9, 'learning_rate': 0.09705075372630081, 'random_strength': 12, 'bagging_temperature': 0.3161435394465868, 'l2_leaf_reg': 74.6066054490335, 'scale_pos_weight': 0.7588884076083162}. Best is trial 7 with value: 0.798125.
# [I 2024-01-28 13:37:35,744] Trial 83 finished with value: 0.78375 and parameters: {'depth': 10, 'learning_rate': 0.12851280393055303, 'random_strength': 16, 'bagging_temperature': 0.1735042701645757, 'l2_leaf_reg': 69.30116862238407, 'scale_pos_weight': 1.2267230851981248}. Best is trial 7 with value: 0.798125.
# [I 2024-01-28 13:37:37,341] Trial 84 finished with value: 0.769375 and parameters: {'depth': 8, 'learning_rate': 0.11362760927229337, 'random_strength': 14, 'bagging_temperature': 0.2859131430757361, 'l2_leaf_reg': 84.71313214791806, 'scale_pos_weight': 0.436919425110867}. Best is trial 7 with value: 0.798125.
# [I 2024-01-28 13:37:38,356] Trial 85 finished with value: 0.7675 and parameters: {'depth': 9, 'learning_rate': 0.1343669787719886, 'random_strength': 18, 'bagging_temperature': 0.20110412969372218, 'l2_leaf_reg': 60.65231463248647, 'scale_pos_weight': 1.5690653740056}. Best is trial 7 with value: 0.798125.
# [I 2024-01-28 13:37:39,300] Trial 86 finished with value: 0.79 and parameters: {'depth': 8, 'learning_rate': 0.15681761023918134, 'random_strength': 15, 'bagging_temperature': 0.42658873034128997, 'l2_leaf_reg': 53.351135291891104, 'scale_pos_weight': 0.740251824006716}. Best is trial 7 with value: 0.798125.
# [I 2024-01-28 13:37:41,556] Trial 87 finished with value: 0.721875 and parameters: {'depth': 7, 'learning_rate': 0.0456967859620749, 'random_strength': 19, 'bagging_temperature': 0.3635780147441908, 'l2_leaf_reg': 78.88405977185734, 'scale_pos_weight': 0.23533458462878576}. Best is trial 7 with value: 0.798125.
# [I 2024-01-28 13:37:43,326] Trial 88 finished with value: 0.78375 and parameters: {'depth': 9, 'learning_rate': 0.10536343269127185, 'random_strength': 16, 'bagging_temperature': 0.24264013054124564, 'l2_leaf_reg': 57.979236531360065, 'scale_pos_weight': 1.0447488552035211}. Best is trial 7 with value: 0.798125.
# [I 2024-01-28 13:37:46,324] Trial 89 finished with value: 0.778125 and parameters: {'depth': 8, 'learning_rate': 0.030474766994312195, 'random_strength': 13, 'bagging_temperature': 0.03988543126944277, 'l2_leaf_reg': 64.75679878434265, 'scale_pos_weight': 1.3562550758159893}. Best is trial 7 with value: 0.798125.
# [I 2024-01-28 13:37:47,368] Trial 90 finished with value: 0.769375 and parameters: {'depth': 8, 'learning_rate': 0.09491024007343506, 'random_strength': 15, 'bagging_temperature': 0.4718940293473398, 'l2_leaf_reg': 70.86390205502933, 'scale_pos_weight': 0.5172981929182414}. Best is trial 7 with value: 0.798125.
# [I 2024-01-28 13:37:49,280] Trial 91 finished with value: 0.790625 and parameters: {'depth': 8, 'learning_rate': 0.059588314837007356, 'random_strength': 15, 'bagging_temperature': 0.3762205216968987, 'l2_leaf_reg': 63.267749738262005, 'scale_pos_weight': 1.1353094863677757}. Best is trial 7 with value: 0.798125.
# [I 2024-01-28 13:37:50,795] Trial 92 finished with value: 0.785 and parameters: {'depth': 8, 'learning_rate': 0.07907399140064045, 'random_strength': 17, 'bagging_temperature': 0.33078016797752213, 'l2_leaf_reg': 75.46496783205649, 'scale_pos_weight': 0.7446289173770528}. Best is trial 7 with value: 0.798125.
# [I 2024-01-28 13:37:53,052] Trial 93 finished with value: 0.768125 and parameters: {'depth': 8, 'learning_rate': 0.06271485749173823, 'random_strength': 16, 'bagging_temperature': 0.38849157797589406, 'l2_leaf_reg': 65.69997282345847, 'scale_pos_weight': 1.6510562726449318}. Best is trial 7 with value: 0.798125.
# [I 2024-01-28 13:37:55,492] Trial 94 finished with value: 0.783125 and parameters: {'depth': 7, 'learning_rate': 0.06732403164857251, 'random_strength': 14, 'bagging_temperature': 0.3492935645776547, 'l2_leaf_reg': 97.76630417324363, 'scale_pos_weight': 1.2656682911764123}. Best is trial 7 with value: 0.798125.
# [I 2024-01-28 13:37:56,971] Trial 95 finished with value: 0.756875 and parameters: {'depth': 8, 'learning_rate': 0.08594972847361967, 'random_strength': 18, 'bagging_temperature': 0.2690739674870357, 'l2_leaf_reg': 66.77461731674377, 'scale_pos_weight': 2.081276772732803}. Best is trial 7 with value: 0.798125.
# [I 2024-01-28 13:37:58,415] Trial 96 finished with value: 0.754375 and parameters: {'depth': 9, 'learning_rate': 0.11804951221622224, 'random_strength': 17, 'bagging_temperature': 0.06966601008674266, 'l2_leaf_reg': 42.12735075493373, 'scale_pos_weight': 2.4560430952455046}. Best is trial 7 with value: 0.798125.
# [I 2024-01-28 13:38:00,497] Trial 97 finished with value: 0.7975 and parameters: {'depth': 8, 'learning_rate': 0.042486705618605826, 'random_strength': 15, 'bagging_temperature': 0.13213463297353287, 'l2_leaf_reg': 46.878775876202226, 'scale_pos_weight': 0.8787971606309305}. Best is trial 7 with value: 0.798125.
# [I 2024-01-28 13:38:04,535] Trial 98 finished with value: 0.74125 and parameters: {'depth': 9, 'learning_rate': 0.023347427529255033, 'random_strength': 16, 'bagging_temperature': 0.13461606801557444, 'l2_leaf_reg': 47.62138892478212, 'scale_pos_weight': 0.3266155125747705}. Best is trial 7 with value: 0.798125.
# [I 2024-01-28 13:38:09,734] Trial 99 finished with value: 0.7875 and parameters: {'depth': 10, 'learning_rate': 0.04196058884228372, 'random_strength': 5, 'bagging_temperature': 0.09651308856338141, 'l2_leaf_reg': 53.29999957026887, 'scale_pos_weight': 0.8673180949468847}. Best is trial 7 with value: 0.798125.
# [I 2024-01-28 13:38:13,220] A new study created in memory with name: no-name-91089c94-cf2f-487f-beef-3046e1265e9e
# [I 2024-01-28 13:38:13,675] Trial 0 finished with value: 0.695 and parameters: {'depth': 8, 'learning_rate': 0.246477003801663, 'random_strength': 7, 'bagging_temperature': 0.43684622205006507, 'l2_leaf_reg': 85.8801063230207, 'scale_pos_weight': 6.398716043544882}. Best is trial 0 with value: 0.695.
# [I 2024-01-28 13:38:14,666] Trial 1 finished with value: 0.78 and parameters: {'depth': 9, 'learning_rate': 0.0997643149201559, 'random_strength': 19, 'bagging_temperature': 0.40173201863686814, 'l2_leaf_reg': 11.371829180238104, 'scale_pos_weight': 1.1903196603755555}. Best is trial 1 with value: 0.78.
# [I 2024-01-28 13:38:17,198] Trial 2 finished with value: 0.733125 and parameters: {'depth': 5, 'learning_rate': 0.015761376407043927, 'random_strength': 6, 'bagging_temperature': 0.26233847044627656, 'l2_leaf_reg': 63.50177145977002, 'scale_pos_weight': 2.7966293814410697}. Best is trial 1 with value: 0.78.
# [I 2024-01-28 13:38:18,421] Trial 3 finished with value: 0.70125 and parameters: {'depth': 10, 'learning_rate': 0.12099104846094547, 'random_strength': 1, 'bagging_temperature': 0.754418694299612, 'l2_leaf_reg': 25.19827423858001, 'scale_pos_weight': 6.5264971252124}. Best is trial 1 with value: 0.78.
# [I 2024-01-28 13:38:20,636] Trial 4 finished with value: 0.705625 and parameters: {'depth': 4, 'learning_rate': 0.025381807585412607, 'random_strength': 4, 'bagging_temperature': 0.22818024480803545, 'l2_leaf_reg': 67.39574780964347, 'scale_pos_weight': 6.351219323332814}. Best is trial 1 with value: 0.78.
# [I 2024-01-28 13:38:21,264] Trial 5 finished with value: 0.69125 and parameters: {'depth': 6, 'learning_rate': 0.22787118454576732, 'random_strength': 9, 'bagging_temperature': 0.32236565806439144, 'l2_leaf_reg': 88.44482090301166, 'scale_pos_weight': 7.917694707906932}. Best is trial 1 with value: 0.78.
# [I 2024-01-28 13:38:22,763] Trial 6 finished with value: 0.72875 and parameters: {'depth': 9, 'learning_rate': 0.06330615151879941, 'random_strength': 19, 'bagging_temperature': 0.5105496090942345, 'l2_leaf_reg': 23.68782017683202, 'scale_pos_weight': 3.853311451291082}. Best is trial 1 with value: 0.78.
# [I 2024-01-28 13:38:23,789] Trial 7 finished with value: 0.679375 and parameters: {'depth': 10, 'learning_rate': 0.21341919944795765, 'random_strength': 1, 'bagging_temperature': 0.39970090503141587, 'l2_leaf_reg': 17.60250709118584, 'scale_pos_weight': 8.639416211291065}. Best is trial 1 with value: 0.78.
# [I 2024-01-28 13:38:24,474] Trial 8 finished with value: 0.734375 and parameters: {'depth': 5, 'learning_rate': 0.14582588317536088, 'random_strength': 5, 'bagging_temperature': 0.13916677681030054, 'l2_leaf_reg': 65.09888076152612, 'scale_pos_weight': 3.3962382182956876}. Best is trial 1 with value: 0.78.
# [I 2024-01-28 13:38:25,126] Trial 9 finished with value: 0.69625 and parameters: {'depth': 4, 'learning_rate': 0.17395674657284255, 'random_strength': 19, 'bagging_temperature': 0.2508566433410965, 'l2_leaf_reg': 52.68459178090723, 'scale_pos_weight': 7.703044790857465}. Best is trial 1 with value: 0.78.
# [I 2024-01-28 13:38:25,831] Trial 10 finished with value: 0.77 and parameters: {'depth': 8, 'learning_rate': 0.09646049890846348, 'random_strength': 14, 'bagging_temperature': 0.9943779262848865, 'l2_leaf_reg': 0.11084407891122083, 'scale_pos_weight': 1.3394249550023596}. Best is trial 1 with value: 0.78.
# [I 2024-01-28 13:38:26,528] Trial 11 finished with value: 0.7275 and parameters: {'depth': 8, 'learning_rate': 0.09596768267150516, 'random_strength': 14, 'bagging_temperature': 0.8338360407064962, 'l2_leaf_reg': 4.548611635674397, 'scale_pos_weight': 0.23096837704974527}. Best is trial 1 with value: 0.78.
# [I 2024-01-28 13:38:27,305] Trial 12 finished with value: 0.735625 and parameters: {'depth': 8, 'learning_rate': 0.08199535598711817, 'random_strength': 14, 'bagging_temperature': 0.9660826523740462, 'l2_leaf_reg': 1.5937521115667157, 'scale_pos_weight': 0.3025255279688719}. Best is trial 1 with value: 0.78.
# [I 2024-01-28 13:38:27,852] Trial 13 finished with value: 0.765 and parameters: {'depth': 7, 'learning_rate': 0.1725708503180547, 'random_strength': 15, 'bagging_temperature': 0.6287454233859153, 'l2_leaf_reg': 37.24457774002805, 'scale_pos_weight': 1.7474964971524045}. Best is trial 1 with value: 0.78.
# [I 2024-01-28 13:38:29,448] Trial 14 finished with value: 0.76625 and parameters: {'depth': 9, 'learning_rate': 0.05846640134611104, 'random_strength': 17, 'bagging_temperature': 0.027221884260329565, 'l2_leaf_reg': 12.179108495101389, 'scale_pos_weight': 1.7579983538468023}. Best is trial 1 with value: 0.78.
# [I 2024-01-28 13:38:30,080] Trial 15 finished with value: 0.7175 and parameters: {'depth': 7, 'learning_rate': 0.12606885890796396, 'random_strength': 11, 'bagging_temperature': 0.6446583042781404, 'l2_leaf_reg': 35.97054653916784, 'scale_pos_weight': 4.897657416579319}. Best is trial 1 with value: 0.78.
# [I 2024-01-28 13:38:31,432] Trial 16 finished with value: 0.765625 and parameters: {'depth': 9, 'learning_rate': 0.10677894476833913, 'random_strength': 20, 'bagging_temperature': 0.9579813732058797, 'l2_leaf_reg': 35.34318272245349, 'scale_pos_weight': 1.7008879623274518}. Best is trial 1 with value: 0.78.
# [I 2024-01-28 13:38:32,995] Trial 17 finished with value: 0.675 and parameters: {'depth': 8, 'learning_rate': 0.04906134538572067, 'random_strength': 11, 'bagging_temperature': 0.6190722387667198, 'l2_leaf_reg': 9.680029805174657, 'scale_pos_weight': 9.894125764473426}. Best is trial 1 with value: 0.78.
# [I 2024-01-28 13:38:34,140] Trial 18 finished with value: 0.7875 and parameters: {'depth': 10, 'learning_rate': 0.15569068950223341, 'random_strength': 16, 'bagging_temperature': 0.7992927234629121, 'l2_leaf_reg': 0.7156202026997267, 'scale_pos_weight': 1.0556372654001271}. Best is trial 18 with value: 0.7875.
# [I 2024-01-28 13:38:35,080] Trial 19 finished with value: 0.718125 and parameters: {'depth': 10, 'learning_rate': 0.2814603550737359, 'random_strength': 17, 'bagging_temperature': 0.7988268826602282, 'l2_leaf_reg': 25.442251677563355, 'scale_pos_weight': 4.381832375482535}. Best is trial 18 with value: 0.7875.
# [I 2024-01-28 13:38:35,899] Trial 20 finished with value: 0.743125 and parameters: {'depth': 9, 'learning_rate': 0.19354717856966974, 'random_strength': 17, 'bagging_temperature': 0.5307640600500205, 'l2_leaf_reg': 49.63582652656066, 'scale_pos_weight': 2.8443758113077626}. Best is trial 18 with value: 0.7875.
# [I 2024-01-28 13:38:37,239] Trial 21 finished with value: 0.775 and parameters: {'depth': 10, 'learning_rate': 0.1388696587009744, 'random_strength': 13, 'bagging_temperature': 0.907491245245149, 'l2_leaf_reg': 1.0645313008088693, 'scale_pos_weight': 1.1602737924729354}. Best is trial 18 with value: 0.7875.
# [I 2024-01-28 13:38:38,711] Trial 22 finished with value: 0.781875 and parameters: {'depth': 10, 'learning_rate': 0.13806708233863965, 'random_strength': 12, 'bagging_temperature': 0.8722292127227452, 'l2_leaf_reg': 14.496602118746514, 'scale_pos_weight': 0.7809084108520586}. Best is trial 18 with value: 0.7875.
# [I 2024-01-28 13:38:39,991] Trial 23 finished with value: 0.754375 and parameters: {'depth': 10, 'learning_rate': 0.17402638640443033, 'random_strength': 16, 'bagging_temperature': 0.7481759108643292, 'l2_leaf_reg': 14.525226432696295, 'scale_pos_weight': 2.4493213595668246}. Best is trial 18 with value: 0.7875.
# [I 2024-01-28 13:38:40,815] Trial 24 finished with value: 0.783125 and parameters: {'depth': 9, 'learning_rate': 0.16519151028508, 'random_strength': 12, 'bagging_temperature': 0.8539293729024585, 'l2_leaf_reg': 19.696066555408116, 'scale_pos_weight': 0.7696364311434661}. Best is trial 18 with value: 0.7875.
# [I 2024-01-28 13:38:42,032] Trial 25 finished with value: 0.756875 and parameters: {'depth': 10, 'learning_rate': 0.15648238289586436, 'random_strength': 12, 'bagging_temperature': 0.8786932546122767, 'l2_leaf_reg': 19.77926165835011, 'scale_pos_weight': 0.41578555851864885}. Best is trial 18 with value: 0.7875.
# [I 2024-01-28 13:38:42,685] Trial 26 finished with value: 0.775 and parameters: {'depth': 9, 'learning_rate': 0.2025026619057187, 'random_strength': 9, 'bagging_temperature': 0.6977588605391087, 'l2_leaf_reg': 30.63016627206195, 'scale_pos_weight': 0.6097897879048884}. Best is trial 18 with value: 0.7875.
# [I 2024-01-28 13:38:44,493] Trial 27 finished with value: 0.758125 and parameters: {'depth': 10, 'learning_rate': 0.16118654839343455, 'random_strength': 9, 'bagging_temperature': 0.8639590576909527, 'l2_leaf_reg': 45.05139036096496, 'scale_pos_weight': 2.2531853772749098}. Best is trial 18 with value: 0.7875.
# [I 2024-01-28 13:38:45,014] Trial 28 finished with value: 0.728125 and parameters: {'depth': 9, 'learning_rate': 0.24094077650582993, 'random_strength': 12, 'bagging_temperature': 0.7785933122875164, 'l2_leaf_reg': 7.651400296284237, 'scale_pos_weight': 3.677662165557931}. Best is trial 18 with value: 0.7875.
# [I 2024-01-28 13:38:45,522] Trial 29 finished with value: 0.781875 and parameters: {'depth': 8, 'learning_rate': 0.2649501439480464, 'random_strength': 10, 'bagging_temperature': 0.6955713948060436, 'l2_leaf_reg': 79.46876237415418, 'scale_pos_weight': 0.8587945322532393}. Best is trial 18 with value: 0.7875.
# [I 2024-01-28 13:38:47,342] Trial 30 finished with value: 0.7575 and parameters: {'depth': 10, 'learning_rate': 0.18734688575769506, 'random_strength': 15, 'bagging_temperature': 0.9014390736989002, 'l2_leaf_reg': 99.74102616074381, 'scale_pos_weight': 2.264522986457357}. Best is trial 18 with value: 0.7875.
# [I 2024-01-28 13:38:47,912] Trial 31 finished with value: 0.784375 and parameters: {'depth': 8, 'learning_rate': 0.2900491744135622, 'random_strength': 8, 'bagging_temperature': 0.7330092615469982, 'l2_leaf_reg': 78.23833267091445, 'scale_pos_weight': 0.7616992061606167}. Best is trial 18 with value: 0.7875.
# [I 2024-01-28 13:38:48,585] Trial 32 finished with value: 0.779375 and parameters: {'depth': 9, 'learning_rate': 0.2959163100944448, 'random_strength': 7, 'bagging_temperature': 0.8128222554856837, 'l2_leaf_reg': 74.5002463552175, 'scale_pos_weight': 1.0370923150699933}. Best is trial 18 with value: 0.7875.
# [I 2024-01-28 13:38:49,345] Trial 33 finished with value: 0.658125 and parameters: {'depth': 8, 'learning_rate': 0.13059013567510572, 'random_strength': 7, 'bagging_temperature': 0.5740982420239199, 'l2_leaf_reg': 93.00141590831261, 'scale_pos_weight': 0.1036052142695113}. Best is trial 18 with value: 0.7875.
# [I 2024-01-28 13:38:49,811] Trial 34 finished with value: 0.739375 and parameters: {'depth': 7, 'learning_rate': 0.25296828939139515, 'random_strength': 8, 'bagging_temperature': 0.9203256889989316, 'l2_leaf_reg': 54.32712853059176, 'scale_pos_weight': 2.9455599673077963}. Best is trial 18 with value: 0.7875.
# [I 2024-01-28 13:38:50,542] Trial 35 finished with value: 0.706875 and parameters: {'depth': 9, 'learning_rate': 0.21574724757985864, 'random_strength': 12, 'bagging_temperature': 0.737361934964908, 'l2_leaf_reg': 18.965467614101836, 'scale_pos_weight': 5.95952682678962}. Best is trial 18 with value: 0.7875.
# [I 2024-01-28 13:38:51,871] Trial 36 finished with value: 0.769375 and parameters: {'depth': 10, 'learning_rate': 0.11869988769091905, 'random_strength': 4, 'bagging_temperature': 0.6946258974647945, 'l2_leaf_reg': 7.654551172643335, 'scale_pos_weight': 1.5176979460712055}. Best is trial 18 with value: 0.7875.
# [I 2024-01-28 13:38:54,028] Trial 37 finished with value: 0.781875 and parameters: {'depth': 9, 'learning_rate': 0.07798525107499236, 'random_strength': 13, 'bagging_temperature': 0.8427622384578854, 'l2_leaf_reg': 71.3193179947678, 'scale_pos_weight': 0.7887129151110083}. Best is trial 18 with value: 0.7875.
# [I 2024-01-28 13:38:54,528] Trial 38 finished with value: 0.75125 and parameters: {'depth': 6, 'learning_rate': 0.23346091527437055, 'random_strength': 6, 'bagging_temperature': 0.7767589780639104, 'l2_leaf_reg': 58.81382431033844, 'scale_pos_weight': 2.4918030623756455}. Best is trial 18 with value: 0.7875.
# [I 2024-01-28 13:39:00,104] Trial 39 finished with value: 0.761875 and parameters: {'depth': 10, 'learning_rate': 0.031302617675492084, 'random_strength': 10, 'bagging_temperature': 0.9477576521230433, 'l2_leaf_reg': 29.731912942113535, 'scale_pos_weight': 1.8240412156150394}. Best is trial 18 with value: 0.7875.
# [I 2024-01-28 13:39:01,326] Trial 40 finished with value: 0.735 and parameters: {'depth': 9, 'learning_rate': 0.11118288921384555, 'random_strength': 8, 'bagging_temperature': 0.5740177321228024, 'l2_leaf_reg': 82.35747021869068, 'scale_pos_weight': 3.230623358674128}. Best is trial 18 with value: 0.7875.
# [I 2024-01-28 13:39:01,988] Trial 41 finished with value: 0.7825 and parameters: {'depth': 8, 'learning_rate': 0.27318039533870025, 'random_strength': 10, 'bagging_temperature': 0.6897184222999335, 'l2_leaf_reg': 77.84780077920793, 'scale_pos_weight': 0.8517155183458134}. Best is trial 18 with value: 0.7875.
# [I 2024-01-28 13:39:02,686] Trial 42 finished with value: 0.789375 and parameters: {'depth': 8, 'learning_rate': 0.26457412107944417, 'random_strength': 10, 'bagging_temperature': 0.711760431898048, 'l2_leaf_reg': 71.92990870193177, 'scale_pos_weight': 0.941880482237139}. Best is trial 42 with value: 0.789375.
# [I 2024-01-28 13:39:03,311] Trial 43 finished with value: 0.7625 and parameters: {'depth': 8, 'learning_rate': 0.2669620440551888, 'random_strength': 8, 'bagging_temperature': 0.6752653254346284, 'l2_leaf_reg': 75.6370170330706, 'scale_pos_weight': 2.081613827509991}. Best is trial 42 with value: 0.789375.
# [I 2024-01-28 13:39:03,948] Trial 44 finished with value: 0.779375 and parameters: {'depth': 7, 'learning_rate': 0.295684091941707, 'random_strength': 10, 'bagging_temperature': 0.4844509815082357, 'l2_leaf_reg': 88.38181593840567, 'scale_pos_weight': 1.194129934765818}. Best is trial 42 with value: 0.789375.
# [I 2024-01-28 13:39:04,249] Trial 45 finished with value: 0.66625 and parameters: {'depth': 6, 'learning_rate': 0.2809805352518205, 'random_strength': 2, 'bagging_temperature': 0.7366343211507901, 'l2_leaf_reg': 69.07534630046668, 'scale_pos_weight': 0.12373242874912016}. Best is trial 42 with value: 0.789375.
# [I 2024-01-28 13:39:04,819] Trial 46 finished with value: 0.775625 and parameters: {'depth': 8, 'learning_rate': 0.2581151694972163, 'random_strength': 6, 'bagging_temperature': 0.43398322704982295, 'l2_leaf_reg': 61.129032902568234, 'scale_pos_weight': 1.4308735221426763}. Best is trial 42 with value: 0.789375.
# [I 2024-01-28 13:39:05,215] Trial 47 finished with value: 0.77625 and parameters: {'depth': 7, 'learning_rate': 0.2793719870406338, 'random_strength': 9, 'bagging_temperature': 0.5855560978241452, 'l2_leaf_reg': 84.41115474842579, 'scale_pos_weight': 0.5649553103445878}. Best is trial 42 with value: 0.789375.
# [I 2024-01-28 13:39:05,938] Trial 48 finished with value: 0.695 and parameters: {'depth': 8, 'learning_rate': 0.21776954583345312, 'random_strength': 11, 'bagging_temperature': 0.8266423362001473, 'l2_leaf_reg': 93.1828442938983, 'scale_pos_weight': 7.129385846219857}. Best is trial 42 with value: 0.789375.
# [I 2024-01-28 13:39:06,584] Trial 49 finished with value: 0.71 and parameters: {'depth': 7, 'learning_rate': 0.23795346105337092, 'random_strength': 18, 'bagging_temperature': 0.6442750199728325, 'l2_leaf_reg': 78.78798871215615, 'scale_pos_weight': 5.469091032351731}. Best is trial 42 with value: 0.789375.
# [I 2024-01-28 13:39:07,131] Trial 50 finished with value: 0.779375 and parameters: {'depth': 8, 'learning_rate': 0.2722289845646839, 'random_strength': 5, 'bagging_temperature': 0.713559410637808, 'l2_leaf_reg': 64.80944795922066, 'scale_pos_weight': 1.1064367401947877}. Best is trial 42 with value: 0.789375.
# [I 2024-01-28 13:39:08,192] Trial 51 finished with value: 0.785 and parameters: {'depth': 9, 'learning_rate': 0.14180409101889155, 'random_strength': 13, 'bagging_temperature': 0.7812264565871786, 'l2_leaf_reg': 72.01708184932757, 'scale_pos_weight': 0.7936411194591899}. Best is trial 42 with value: 0.789375.
# [I 2024-01-28 13:39:09,492] Trial 52 finished with value: 0.776875 and parameters: {'depth': 9, 'learning_rate': 0.16642907937663484, 'random_strength': 13, 'bagging_temperature': 0.7742274777297421, 'l2_leaf_reg': 73.42212253061818, 'scale_pos_weight': 0.5583222274401896}. Best is trial 42 with value: 0.789375.
# ...
# [I 2024-01-28 13:43:48,482] Trial 49 finished with value: 0.74 and parameters: {'depth': 4, 'learning_rate': 0.17233103393090435, 'random_strength': 5, 'bagging_temperature': 0.45607988262966337, 'l2_leaf_reg': 99.38010918662137, 'scale_pos_weight': 1.7928861457364058}. Best is trial 25 with value: 0.776875.
# [I 2024-01-28 13:43:48,977] Trial 50 finished with value: 0.69625 and parameters: {'depth': 6, 'learning_rate': 0.20455853517616202, 'random_strength': 12, 'bagging_temperature': 0.5319125064513859, 'l2_leaf_reg': 38.69031832583963, 'scale_pos_weight': 0.16939693568591185}. Best is trial 25 with value: 0.776875.
# [I 2024-01-28 13:43:50,782] Trial 51 finished with value: 0.76875 and parameters: {'depth': 6, 'learning_rate': 0.0458659637800779, 'random_strength': 13, 'bagging_temperature': 0.4498463915965206, 'l2_leaf_reg': 43.124004989219145, 'scale_pos_weight': 0.9424471461539514}. Best is trial 25 with value: 0.776875.
# [I 2024-01-28 13:43:51,861] Trial 52 finished with value: 0.78 and parameters: {'depth': 5, 'learning_rate': 0.058428988460691875, 'random_strength': 15, 'bagging_temperature': 0.4986311356379117, 'l2_leaf_reg': 45.350033951431215, 'scale_pos_weight': 0.7179474154224148}. Best is trial 52 with value: 0.78.
# [I 2024-01-28 13:43:52,726] Trial 53 finished with value: 0.740625 and parameters: {'depth': 5, 'learning_rate': 0.07193368969297131, 'random_strength': 14, 'bagging_temperature': 0.5014474353528762, 'l2_leaf_reg': 50.7400803511875, 'scale_pos_weight': 1.5036356722382402}. Best is trial 52 with value: 0.78.
# [I 2024-01-28 13:43:54,154] Trial 54 finished with value: 0.774375 and parameters: {'depth': 4, 'learning_rate': 0.060016814229075025, 'random_strength': 15, 'bagging_temperature': 0.6198809741706308, 'l2_leaf_reg': 57.81159282984614, 'scale_pos_weight': 0.5671415242114268}. Best is trial 52 with value: 0.78.
# [I 2024-01-28 13:43:55,036] Trial 55 finished with value: 0.7675 and parameters: {'depth': 4, 'learning_rate': 0.08491347645449207, 'random_strength': 15, 'bagging_temperature': 0.6450286027803166, 'l2_leaf_reg': 57.51580677136979, 'scale_pos_weight': 0.48129320732485115}. Best is trial 52 with value: 0.78.
# [I 2024-01-28 13:43:56,405] Trial 56 finished with value: 0.73 and parameters: {'depth': 4, 'learning_rate': 0.06123710697883533, 'random_strength': 18, 'bagging_temperature': 0.6104443003928084, 'l2_leaf_reg': 67.95579310723338, 'scale_pos_weight': 2.1124921027029138}. Best is trial 52 with value: 0.78.
# [I 2024-01-28 13:43:57,025] Trial 57 finished with value: 0.7275 and parameters: {'depth': 4, 'learning_rate': 0.13988212191554789, 'random_strength': 16, 'bagging_temperature': 0.6945259568673837, 'l2_leaf_reg': 19.562150483117584, 'scale_pos_weight': 2.4738414103384168}. Best is trial 52 with value: 0.78.
# [I 2024-01-28 13:43:57,511] Trial 58 finished with value: 0.7625 and parameters: {'depth': 5, 'learning_rate': 0.2228330212567582, 'random_strength': 15, 'bagging_temperature': 0.008523377236417828, 'l2_leaf_reg': 95.16340742805617, 'scale_pos_weight': 1.289537114784876}. Best is trial 52 with value: 0.78.
# [I 2024-01-28 13:43:58,125] Trial 59 finished with value: 0.623125 and parameters: {'depth': 4, 'learning_rate': 0.1032710417586562, 'random_strength': 17, 'bagging_temperature': 0.8293183363133714, 'l2_leaf_reg': 75.92141732181231, 'scale_pos_weight': 0.117857290724808}. Best is trial 52 with value: 0.78.
# [I 2024-01-28 13:43:58,686] Trial 60 finished with value: 0.6625 and parameters: {'depth': 5, 'learning_rate': 0.09315109598396787, 'random_strength': 19, 'bagging_temperature': 0.7260854215389636, 'l2_leaf_reg': 0.12392712306334275, 'scale_pos_weight': 8.564306336373033}. Best is trial 52 with value: 0.78.
# [I 2024-01-28 13:43:59,663] Trial 61 finished with value: 0.765 and parameters: {'depth': 5, 'learning_rate': 0.0557531698093062, 'random_strength': 14, 'bagging_temperature': 0.5310783488338807, 'l2_leaf_reg': 30.66197207896849, 'scale_pos_weight': 0.8874486900706264}. Best is trial 52 with value: 0.78.
# [I 2024-01-28 13:44:01,695] Trial 62 finished with value: 0.760625 and parameters: {'depth': 4, 'learning_rate': 0.04048649155702698, 'random_strength': 16, 'bagging_temperature': 0.39121847483526995, 'l2_leaf_reg': 45.04369465121307, 'scale_pos_weight': 0.4585051266857394}. Best is trial 52 with value: 0.78.
# [I 2024-01-28 13:44:04,470] Trial 63 finished with value: 0.771875 and parameters: {'depth': 6, 'learning_rate': 0.022005222074398357, 'random_strength': 13, 'bagging_temperature': 0.5738738189093441, 'l2_leaf_reg': 37.8246266220917, 'scale_pos_weight': 0.808521831532459}. Best is trial 52 with value: 0.78.
# [I 2024-01-28 13:44:06,812] Trial 64 finished with value: 0.741875 and parameters: {'depth': 4, 'learning_rate': 0.020486965380509578, 'random_strength': 11, 'bagging_temperature': 0.6641302730239121, 'l2_leaf_reg': 37.139266830387214, 'scale_pos_weight': 1.4675149015281101}. Best is trial 52 with value: 0.78.
# [I 2024-01-28 13:44:08,622] Trial 65 finished with value: 0.729375 and parameters: {'depth': 5, 'learning_rate': 0.029699610526893357, 'random_strength': 13, 'bagging_temperature': 0.5805213270598051, 'l2_leaf_reg': 33.44817918825774, 'scale_pos_weight': 1.9466892306594814}. Best is trial 52 with value: 0.78.
# [I 2024-01-28 13:44:09,338] Trial 66 finished with value: 0.763125 and parameters: {'depth': 7, 'learning_rate': 0.07264019265303108, 'random_strength': 2, 'bagging_temperature': 0.7604686360917994, 'l2_leaf_reg': 13.35363775838097, 'scale_pos_weight': 1.122659581027613}. Best is trial 52 with value: 0.78.
# [I 2024-01-28 13:44:10,340] Trial 67 finished with value: 0.774375 and parameters: {'depth': 6, 'learning_rate': 0.07983919827303854, 'random_strength': 20, 'bagging_temperature': 0.59989325568455, 'l2_leaf_reg': 52.75344750830145, 'scale_pos_weight': 0.8149105837734857}. Best is trial 52 with value: 0.78.
# [I 2024-01-28 13:44:11,542] Trial 68 finished with value: 0.7675 and parameters: {'depth': 5, 'learning_rate': 0.11646712219199559, 'random_strength': 20, 'bagging_temperature': 0.7263606961717961, 'l2_leaf_reg': 52.75364553026008, 'scale_pos_weight': 0.46762756774453323}. Best is trial 52 with value: 0.78.
# [I 2024-01-28 13:44:12,528] Trial 69 finished with value: 0.736875 and parameters: {'depth': 6, 'learning_rate': 0.08034463870993193, 'random_strength': 20, 'bagging_temperature': 0.6043471884105894, 'l2_leaf_reg': 61.539020424034256, 'scale_pos_weight': 1.64082262614378}. Best is trial 52 with value: 0.78.
# [I 2024-01-28 13:44:13,439] Trial 70 finished with value: 0.71125 and parameters: {'depth': 4, 'learning_rate': 0.13107294253806817, 'random_strength': 18, 'bagging_temperature': 0.6156872245218106, 'l2_leaf_reg': 56.52801632523849, 'scale_pos_weight': 3.773352210027268}. Best is trial 52 with value: 0.78.
# [I 2024-01-28 13:44:14,466] Trial 71 finished with value: 0.7775 and parameters: {'depth': 6, 'learning_rate': 0.06314768754635129, 'random_strength': 19, 'bagging_temperature': 0.6656221797233406, 'l2_leaf_reg': 47.04347738469752, 'scale_pos_weight': 0.7577429850165426}. Best is trial 52 with value: 0.78.
# [I 2024-01-28 13:44:15,611] Trial 72 finished with value: 0.760625 and parameters: {'depth': 6, 'learning_rate': 0.06333523366015553, 'random_strength': 19, 'bagging_temperature': 0.6751247506433994, 'l2_leaf_reg': 50.597183683276135, 'scale_pos_weight': 0.4175381825165491}. Best is trial 52 with value: 0.78.
# [I 2024-01-28 13:44:16,728] Trial 73 finished with value: 0.769375 and parameters: {'depth': 6, 'learning_rate': 0.08939010913571721, 'random_strength': 18, 'bagging_temperature': 0.6377785586039952, 'l2_leaf_reg': 46.88455904192161, 'scale_pos_weight': 0.9927095686660405}. Best is trial 52 with value: 0.78.
# [I 2024-01-28 13:44:17,676] Trial 74 finished with value: 0.754375 and parameters: {'depth': 6, 'learning_rate': 0.07652871620054708, 'random_strength': 17, 'bagging_temperature': 0.71131334218051, 'l2_leaf_reg': 53.827459314060064, 'scale_pos_weight': 1.284025213425382}. Best is trial 52 with value: 0.78.
# [I 2024-01-28 13:44:19,507] Trial 75 finished with value: 0.769375 and parameters: {'depth': 7, 'learning_rate': 0.05673550097980641, 'random_strength': 18, 'bagging_temperature': 0.7671525778413505, 'l2_leaf_reg': 66.57947260231732, 'scale_pos_weight': 0.6188023136751898}. Best is trial 52 with value: 0.78.
# [I 2024-01-28 13:44:21,451] Trial 76 finished with value: 0.750625 and parameters: {'depth': 7, 'learning_rate': 0.044350643849313434, 'random_strength': 20, 'bagging_temperature': 0.9059745612662442, 'l2_leaf_reg': 59.66339274860761, 'scale_pos_weight': 0.34214497035930147}. Best is trial 52 with value: 0.78.
# [I 2024-01-28 13:44:23,877] Trial 77 finished with value: 0.774375 and parameters: {'depth': 5, 'learning_rate': 0.03200774890016774, 'random_strength': 19, 'bagging_temperature': 0.5373161318920394, 'l2_leaf_reg': 41.618365290713136, 'scale_pos_weight': 0.7308474358619942}. Best is trial 52 with value: 0.78.
# [I 2024-01-28 13:44:24,256] Trial 78 finished with value: 0.781875 and parameters: {'depth': 5, 'learning_rate': 0.284033479658654, 'random_strength': 20, 'bagging_temperature': 0.5506054391985843, 'l2_leaf_reg': 40.529652374506384, 'scale_pos_weight': 0.7844433076113865}. Best is trial 78 with value: 0.781875.
# [I 2024-01-28 13:44:26,680] Trial 79 finished with value: 0.74625 and parameters: {'depth': 5, 'learning_rate': 0.033343842608558584, 'random_strength': 19, 'bagging_temperature': 0.5545598280489095, 'l2_leaf_reg': 40.66690487155757, 'scale_pos_weight': 1.538621658851391}. Best is trial 78 with value: 0.781875.
# [I 2024-01-28 13:44:27,838] Trial 80 finished with value: 0.7625 and parameters: {'depth': 5, 'learning_rate': 0.06415030852997368, 'random_strength': 20, 'bagging_temperature': 0.42228895263474614, 'l2_leaf_reg': 43.97255230211966, 'scale_pos_weight': 1.1409658583499487}. Best is trial 78 with value: 0.781875.
# [I 2024-01-28 13:44:28,399] Trial 81 finished with value: 0.77875 and parameters: {'depth': 5, 'learning_rate': 0.2522838989048777, 'random_strength': 19, 'bagging_temperature': 0.5193781804653955, 'l2_leaf_reg': 47.903428267513625, 'scale_pos_weight': 0.7403436593771676}. Best is trial 78 with value: 0.781875.
# [I 2024-01-28 13:44:30,145] Trial 82 finished with value: 0.77 and parameters: {'depth': 5, 'learning_rate': 0.05001241362157912, 'random_strength': 19, 'bagging_temperature': 0.5080945252503595, 'l2_leaf_reg': 48.70612037207676, 'scale_pos_weight': 0.9018900854708949}. Best is trial 78 with value: 0.781875.
# [I 2024-01-28 13:44:30,662] Trial 83 finished with value: 0.77375 and parameters: {'depth': 4, 'learning_rate': 0.28257831485566026, 'random_strength': 20, 'bagging_temperature': 0.5810114298451456, 'l2_leaf_reg': 51.98961169194667, 'scale_pos_weight': 0.7084498121766776}. Best is trial 78 with value: 0.781875.
# [I 2024-01-28 13:44:31,028] Trial 84 finished with value: 0.628125 and parameters: {'depth': 5, 'learning_rate': 0.25345975692627287, 'random_strength': 19, 'bagging_temperature': 0.526999920793461, 'l2_leaf_reg': 41.89980570307772, 'scale_pos_weight': 0.10801465540677013}. Best is trial 78 with value: 0.781875.
# [I 2024-01-28 13:44:31,501] Trial 85 finished with value: 0.685 and parameters: {'depth': 5, 'learning_rate': 0.2829039341397541, 'random_strength': 17, 'bagging_temperature': 0.476299197799817, 'l2_leaf_reg': 55.775808658762784, 'scale_pos_weight': 6.710807758021929}. Best is trial 78 with value: 0.781875.
# [I 2024-01-28 13:44:31,843] Trial 86 finished with value: 0.738125 and parameters: {'depth': 4, 'learning_rate': 0.29845312994893425, 'random_strength': 18, 'bagging_temperature': 0.6197524048292223, 'l2_leaf_reg': 47.89514484934863, 'scale_pos_weight': 1.828694720458711}. Best is trial 78 with value: 0.781875.
# [I 2024-01-28 13:44:32,324] Trial 87 finished with value: 0.700625 and parameters: {'depth': 5, 'learning_rate': 0.26773860067261, 'random_strength': 20, 'bagging_temperature': 0.6609746029618434, 'l2_leaf_reg': 45.86324165874568, 'scale_pos_weight': 5.1902552124709285}. Best is trial 78 with value: 0.781875.
# [I 2024-01-28 13:44:32,878] Trial 88 finished with value: 0.76625 and parameters: {'depth': 5, 'learning_rate': 0.26594777195548264, 'random_strength': 18, 'bagging_temperature': 0.19812222816204988, 'l2_leaf_reg': 33.018815916610826, 'scale_pos_weight': 1.2263644756559828}. Best is trial 78 with value: 0.781875.
# [I 2024-01-28 13:44:33,273] Trial 89 finished with value: 0.746875 and parameters: {'depth': 4, 'learning_rate': 0.28136515495047604, 'random_strength': 19, 'bagging_temperature': 0.4886034155357012, 'l2_leaf_reg': 39.45643311900356, 'scale_pos_weight': 0.34167844521562746}. Best is trial 78 with value: 0.781875.
# [I 2024-01-28 13:44:33,761] Trial 90 finished with value: 0.776875 and parameters: {'depth': 4, 'learning_rate': 0.23999802464293235, 'random_strength': 19, 'bagging_temperature': 0.5562883737670452, 'l2_leaf_reg': 54.11234255686482, 'scale_pos_weight': 0.6929393167679119}. Best is trial 78 with value: 0.781875.
# [I 2024-01-28 13:44:34,146] Trial 91 finished with value: 0.775625 and parameters: {'depth': 4, 'learning_rate': 0.243634147571488, 'random_strength': 19, 'bagging_temperature': 0.5569912367623228, 'l2_leaf_reg': 53.709986617932344, 'scale_pos_weight': 0.7196742503082253}. Best is trial 78 with value: 0.781875.
# [I 2024-01-28 13:44:34,641] Trial 92 finished with value: 0.765625 and parameters: {'depth': 4, 'learning_rate': 0.2389311081072386, 'random_strength': 20, 'bagging_temperature': 0.5583965424901173, 'l2_leaf_reg': 58.7336024932325, 'scale_pos_weight': 1.0225120359365627}. Best is trial 78 with value: 0.781875.
# [I 2024-01-28 13:44:35,064] Trial 93 finished with value: 0.77125 and parameters: {'depth': 4, 'learning_rate': 0.24013261856268353, 'random_strength': 18, 'bagging_temperature': 0.5888803929674005, 'l2_leaf_reg': 54.84816014207655, 'scale_pos_weight': 0.6582135938943315}. Best is trial 78 with value: 0.781875.
# [I 2024-01-28 13:44:35,461] Trial 94 finished with value: 0.759375 and parameters: {'depth': 4, 'learning_rate': 0.2276113105723506, 'random_strength': 17, 'bagging_temperature': 0.6235663285377552, 'l2_leaf_reg': 62.5365401783245, 'scale_pos_weight': 1.4099145879442787}. Best is trial 78 with value: 0.781875.
# [I 2024-01-28 13:44:35,788] Trial 95 finished with value: 0.753125 and parameters: {'depth': 4, 'learning_rate': 0.24980114433443668, 'random_strength': 19, 'bagging_temperature': 0.3352783137080766, 'l2_leaf_reg': 51.023162688114965, 'scale_pos_weight': 0.3625819570992303}. Best is trial 78 with value: 0.781875.
# [I 2024-01-28 13:44:36,326] Trial 96 finished with value: 0.7725 and parameters: {'depth': 4, 'learning_rate': 0.25793183106584644, 'random_strength': 20, 'bagging_temperature': 0.6513452878519881, 'l2_leaf_reg': 65.87409387976626, 'scale_pos_weight': 0.8509454156139833}. Best is trial 78 with value: 0.781875.
# [I 2024-01-28 13:44:36,828] Trial 97 finished with value: 0.749375 and parameters: {'depth': 4, 'learning_rate': 0.23552065783749498, 'random_strength': 18, 'bagging_temperature': 0.6859692343866554, 'l2_leaf_reg': 60.63515522857058, 'scale_pos_weight': 1.688109688757522}. Best is trial 78 with value: 0.781875.
# [I 2024-01-28 13:44:37,330] Trial 98 finished with value: 0.77 and parameters: {'depth': 4, 'learning_rate': 0.2090022906655477, 'random_strength': 19, 'bagging_temperature': 0.44083229655002715, 'l2_leaf_reg': 4.769733644936577, 'scale_pos_weight': 1.0880127312048633}. Best is trial 78 with value: 0.781875.
# [I 2024-01-28 13:44:37,748] Trial 99 finished with value: 0.768125 and parameters: {'depth': 4, 'learning_rate': 0.27216427405320803, 'random_strength': 17, 'bagging_temperature': 0.5176413192479731, 'l2_leaf_reg': 49.54059260207262, 'scale_pos_weight': 0.5431998580100893}. Best is trial 78 with value: 0.781875.

# %% [markdown]
# - Catboost平均スコア

# %%
# 全フォールドの平均スコアを計算
cb_average_score = sum(cb_fold_scores) / n_splits
print(f"CatBoost Average accuracy across all folds: {cb_average_score}")
# Out:
# CatBoost Average accuracy across all folds: 0.7745

# %% [markdown]
# - CB_予測平均

# %%
# 予測の平均を計算
cb_y_test_pred_avg = np.mean(cb_test_predictions, axis=0)

# 最終的な予測結果を整数に変換
cb_y_test_pred_int = (cb_y_test_pred_avg > 0.5).astype(int)

# %% [markdown]
# - output

# %%
# 現在の日時を取得してフォーマットする
current_time = datetime.now().strftime("%Y%m%d_%H%M%S")
output = f'../data/output/{current_time}_CatBoost_cv{cb_average_score:.4f}.csv'

submit = pd.DataFrame({
    '0': test['gameId'],
    '1': cb_y_test_pred_int
})

# カラムヘッダー消去して出力
# ヘッダーなしでCSVファイルとして保存
submit.to_csv(output, header=False, index=False)

# %%
submit
# Out:
#          0  1
# 0        9  1
# 1       15  1
# 2       18  1
# 3       23  0
# 4       31  0
# ...    ... ..
# 1995  9971  0
# 1996  9980  0
# 1997  9983  1
# 1998  9996  1
# 1999  9999  0
#
# [2000 rows x 2 columns]

# %% [markdown]
# ## RandomForest
